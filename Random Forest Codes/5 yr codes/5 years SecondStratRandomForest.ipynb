# %% [markdown]
# Team Efficiency all-in-all uses = League Points, 3Ps Made, Assists, Turnovers, Field Goal Attempts, Field Goals Made, Free Throws Attempted, Free Throws Made, Offensive Rebounds, Total Rebounds, Steals, Blocks, and Personal Fouls thus remove these from the X set to remove redundancy
#
# Same case for factor, VOP, and DRB since they are part of getting the team efficiency engineered stat
#
# Thus, X should contain 3Ps Attempted, Defensive Rebounds, Average Points, Attendees, and Team Efficiency
#
# The data used here is from the 2013-2014 up to the 2017-2018 season.

# %%
import numpy as np
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/1eiyZ2Z8F-IIZp5KE-WqCK3vzKEeO2gDYTQbWfjB5MWQ/edit#gid=0'
csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

df = pd.read_csv(csv_export_url)

X_stats = ['3Ps Attempted', 'Defensive Rebounds', 'Average Points', 'Attendees', 'Team Efficiency']
Y_stats = ['Make Playoffs']

df['Attendees'] = pd.to_numeric(df['Attendees'], downcast='integer')

df['Make Playoffs'] = df['Make Playoffs'].replace({"Y" : 1, "N" : 0})

GSW1 = df['Team Name and Instance'].str.contains("Golden State Warriors") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notGSW1 = ~df['Team Name and Instance'].str.contains("Golden State Warriors") & df['Team Name and Instance'].str.contains("(Games 1-20)")

SAS1 = df['Team Name and Instance'].str.contains("San Antonio Spurs") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notSAS1 = ~df['Team Name and Instance'].str.contains("San Antonio Spurs") & df['Team Name and Instance'].str.contains("(Games 1-20)")

HOU1 = df['Team Name and Instance'].str.contains("Houston Rockets") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notHOU1 = ~df['Team Name and Instance'].str.contains("Houston Rockets") & df['Team Name and Instance'].str.contains("(Games 1-20)")

LAC1 = df['Team Name and Instance'].str.contains("Los Angeles Clippers") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notLAC1 = ~df['Team Name and Instance'].str.contains("Los Angeles Clippers") & df['Team Name and Instance'].str.contains("(Games 1-20)")

UTAH1 = df['Team Name and Instance'].str.contains("Utah Jazz") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notUTAH1 = ~df['Team Name and Instance'].str.contains("Utah Jazz") & df['Team Name and Instance'].str.contains("(Games 1-20)")

OKC1 = df['Team Name and Instance'].str.contains("Oklahoma City Thunder") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notOKC1 = ~df['Team Name and Instance'].str.contains("Oklahoma City Thunder") & df['Team Name and Instance'].str.contains("(Games 1-20)")

MEM1 = df['Team Name and Instance'].str.contains("Memphis Grizzlies") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notMEM1 = ~df['Team Name and Instance'].str.contains("Memphis Grizzlies") & df['Team Name and Instance'].str.contains("(Games 1-20)")

POR1 = df['Team Name and Instance'].str.contains("Portland Trailblazers") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notPOR1 = ~df['Team Name and Instance'].str.contains("Portland Trailblazers") & df['Team Name and Instance'].str.contains("(Games 1-20)")

DEN1 = df['Team Name and Instance'].str.contains("Denver Nuggets") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notDEN1 = ~df['Team Name and Instance'].str.contains("Denver Nuggets") & df['Team Name and Instance'].str.contains("(Games 1-20)")

NOP1 = df['Team Name and Instance'].str.contains("New Orleans Pelicans") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notNOP1 = ~df['Team Name and Instance'].str.contains("New Orleans Pelicans") & df['Team Name and Instance'].str.contains("(Games 1-20)")

DAL1 = df['Team Name and Instance'].str.contains("Dallas Mavericks") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notDAL1 = ~df['Team Name and Instance'].str.contains("Dallas Mavericks") & df['Team Name and Instance'].str.contains("(Games 1-20)")

SAC1 = df['Team Name and Instance'].str.contains("Sacramento Kings") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notSAC1 = ~df['Team Name and Instance'].str.contains("Sacramento Kings") & df['Team Name and Instance'].str.contains("(Games 1-20)")

MIN1 = df['Team Name and Instance'].str.contains("Minnesota Timberwolves") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notMIN1 = ~df['Team Name and Instance'].str.contains("Minnesota Timberwolves") & df['Team Name and Instance'].str.contains("(Games 1-20)")

LAL1 = df['Team Name and Instance'].str.contains("Los Angeles Lakers") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notLAL1 = ~df['Team Name and Instance'].str.contains("Los Angeles Lakers") & df['Team Name and Instance'].str.contains("(Games 1-20)")

PHO1 = df['Team Name and Instance'].str.contains("Phoenix Suns") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notPHO1 = ~df['Team Name and Instance'].str.contains("Phoenix Suns") & df['Team Name and Instance'].str.contains("(Games 1-20)")

BOS1 = df['Team Name and Instance'].str.contains("Boston Celtics") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notBOS1 = ~df['Team Name and Instance'].str.contains("Boston Celtics") & df['Team Name and Instance'].str.contains("(Games 1-20)")

CLE1 = df['Team Name and Instance'].str.contains("Cleveland Cavaliers") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notCLE1 = ~df['Team Name and Instance'].str.contains("Cleveland Cavaliers") & df['Team Name and Instance'].str.contains("(Games 1-20)")

TOR1 = df['Team Name and Instance'].str.contains("Toronto Raptors") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notTOR1 = ~df['Team Name and Instance'].str.contains("Toronto Raptors") & df['Team Name and Instance'].str.contains("(Games 1-20)")

WAS1 = df['Team Name and Instance'].str.contains("Washington Wizards") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notWAS1 = ~df['Team Name and Instance'].str.contains("Washington Wizards") & df['Team Name and Instance'].str.contains("(Games 1-20)")

ATL1 = df['Team Name and Instance'].str.contains("Atlanta Hawks") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notATL1 = ~df['Team Name and Instance'].str.contains("Atlanta Hawks") & df['Team Name and Instance'].str.contains("(Games 1-20)")

MIL1 = df['Team Name and Instance'].str.contains("Milwaukee Bucks") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notMIL1 = ~df['Team Name and Instance'].str.contains("Milwaukee Bucks") & df['Team Name and Instance'].str.contains("(Games 1-20)")

IND1 = df['Team Name and Instance'].str.contains("Indiana Pacers") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notIND1 = ~df['Team Name and Instance'].str.contains("Indiana Pacers") & df['Team Name and Instance'].str.contains("(Games 1-20)")

CHI1 = df['Team Name and Instance'].str.contains("Chicago Bulls") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notCHI1 = ~df['Team Name and Instance'].str.contains("Chicago Bulls") & df['Team Name and Instance'].str.contains("(Games 1-20)")

MIA1 = df['Team Name and Instance'].str.contains("Miami Heat") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notMIA1 = ~df['Team Name and Instance'].str.contains("Miami Heat") & df['Team Name and Instance'].str.contains("(Games 1-20)")

DET1 = df['Team Name and Instance'].str.contains("Detroit Pistons") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notDET1 = ~df['Team Name and Instance'].str.contains("Detroit Pistons") & df['Team Name and Instance'].str.contains("(Games 1-20)")

CHA1 = df['Team Name and Instance'].str.contains("Charlotte Hornets") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notCHA1 = ~df['Team Name and Instance'].str.contains("Charlotte Hornets") & df['Team Name and Instance'].str.contains("(Games 1-20)")

NYK1 = df['Team Name and Instance'].str.contains("New York Knicks") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notNYK1 = ~df['Team Name and Instance'].str.contains("New York Knicks") & df['Team Name and Instance'].str.contains("(Games 1-20)")

ORL1 = df['Team Name and Instance'].str.contains("Orlando Magic") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notORL1 = ~df['Team Name and Instance'].str.contains("Orlando Magic") & df['Team Name and Instance'].str.contains("(Games 1-20)")

PHI1 = df['Team Name and Instance'].str.contains("Philadelphia 76ers") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notPHI1 = ~df['Team Name and Instance'].str.contains("Philadelphia 76ers") & df['Team Name and Instance'].str.contains("(Games 1-20)")

BKN1 = df['Team Name and Instance'].str.contains("Brooklyn Nets") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notBKN1 = ~df['Team Name and Instance'].str.contains("Brooklyn Nets") & df['Team Name and Instance'].str.contains("(Games 1-20)")

GSW2 = df['Team Name and Instance'].str.contains("Golden State Warriors") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notGSW2 = ~df['Team Name and Instance'].str.contains("Golden State Warriors") & df['Team Name and Instance'].str.contains("(Games 21-41)")

SAS2 = df['Team Name and Instance'].str.contains("San Antonio Spurs") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notSAS2 = ~df['Team Name and Instance'].str.contains("San Antonio Spurs") & df['Team Name and Instance'].str.contains("(Games 21-41)")

HOU2 = df['Team Name and Instance'].str.contains("Houston Rockets") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notHOU2 = ~df['Team Name and Instance'].str.contains("Houston Rockets") & df['Team Name and Instance'].str.contains("(Games 21-41)")

LAC2 = df['Team Name and Instance'].str.contains("Los Angeles Clippers") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notLAC2 = ~df['Team Name and Instance'].str.contains("Los Angeles Clippers") & df['Team Name and Instance'].str.contains("(Games 21-41)")

UTAH2 = df['Team Name and Instance'].str.contains("Utah Jazz") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notUTAH2 = ~df['Team Name and Instance'].str.contains("Utah Jazz") & df['Team Name and Instance'].str.contains("(Games 21-41)")

OKC2 = df['Team Name and Instance'].str.contains("Oklahoma City Thunder") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notOKC2 = ~df['Team Name and Instance'].str.contains("Oklahoma City Thunder") & df['Team Name and Instance'].str.contains("(Games 21-41)")

MEM2 = df['Team Name and Instance'].str.contains("Memphis Grizzlies") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notMEM2 = ~df['Team Name and Instance'].str.contains("Memphis Grizzlies") & df['Team Name and Instance'].str.contains("(Games 21-41)")

POR2 = df['Team Name and Instance'].str.contains("Portland Trailblazers") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notPOR2 = ~df['Team Name and Instance'].str.contains("Portland Trailblazers") & df['Team Name and Instance'].str.contains("(Games 21-41)")

DEN2 = df['Team Name and Instance'].str.contains("Denver Nuggets") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notDEN2 = ~df['Team Name and Instance'].str.contains("Denver Nuggets") & df['Team Name and Instance'].str.contains("(Games 21-41)")

NOP2 = df['Team Name and Instance'].str.contains("New Orleans Pelicans") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notNOP2 = ~df['Team Name and Instance'].str.contains("New Orleans Pelicans") & df['Team Name and Instance'].str.contains("(Games 21-41)")

DAL2 = df['Team Name and Instance'].str.contains("Dallas Mavericks") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notDAL2 = ~df['Team Name and Instance'].str.contains("Dallas Mavericks") & df['Team Name and Instance'].str.contains("(Games 21-41)")

SAC2 = df['Team Name and Instance'].str.contains("Sacramento Kings") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notSAC2 = ~df['Team Name and Instance'].str.contains("Sacramento Kings") & df['Team Name and Instance'].str.contains("(Games 21-41)")

MIN2 = df['Team Name and Instance'].str.contains("Minnesota Timberwolves") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notMIN2 = ~df['Team Name and Instance'].str.contains("Minnesota Timberwolves") & df['Team Name and Instance'].str.contains("(Games 21-41)")

LAL2 = df['Team Name and Instance'].str.contains("Los Angeles Lakers") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notLAL2 = ~df['Team Name and Instance'].str.contains("Los Angeles Lakers") & df['Team Name and Instance'].str.contains("(Games 21-41)")

PHO2 = df['Team Name and Instance'].str.contains("Phoenix Suns") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notPHO2 = ~df['Team Name and Instance'].str.contains("Phoenix Suns") & df['Team Name and Instance'].str.contains("(Games 21-41)")

BOS2 = df['Team Name and Instance'].str.contains("Boston Celtics") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notBOS2 = ~df['Team Name and Instance'].str.contains("Boston Celtics") & df['Team Name and Instance'].str.contains("(Games 21-41)")

CLE2 = df['Team Name and Instance'].str.contains("Cleveland Cavaliers") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notCLE2 = ~df['Team Name and Instance'].str.contains("Cleveland Cavaliers") & df['Team Name and Instance'].str.contains("(Games 21-41)")

TOR2 = df['Team Name and Instance'].str.contains("Toronto Raptors") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notTOR2 = ~df['Team Name and Instance'].str.contains("Toronto Raptors") & df['Team Name and Instance'].str.contains("(Games 21-41)")

WAS2 = df['Team Name and Instance'].str.contains("Washington Wizards") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notWAS2 = ~df['Team Name and Instance'].str.contains("Washington Wizards") & df['Team Name and Instance'].str.contains("(Games 21-41)")

ATL2 = df['Team Name and Instance'].str.contains("Atlanta Hawks") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notATL2 = ~df['Team Name and Instance'].str.contains("Atlanta Hawks") & df['Team Name and Instance'].str.contains("(Games 21-41)")

MIL2 = df['Team Name and Instance'].str.contains("Milwaukee Bucks") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notMIL2 = ~df['Team Name and Instance'].str.contains("Milwaukee Bucks") & df['Team Name and Instance'].str.contains("(Games 21-41)")

IND2 = df['Team Name and Instance'].str.contains("Indiana Pacers") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notIND2 = ~df['Team Name and Instance'].str.contains("Indiana Pacers") & df['Team Name and Instance'].str.contains("(Games 21-41)")

CHI2 = df['Team Name and Instance'].str.contains("Chicago Bulls") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notCHI2 = ~df['Team Name and Instance'].str.contains("Chicago Bulls") & df['Team Name and Instance'].str.contains("(Games 21-41)")

MIA2 = df['Team Name and Instance'].str.contains("Miami Heat") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notMIA2 = ~df['Team Name and Instance'].str.contains("Miami Heat") & df['Team Name and Instance'].str.contains("(Games 21-41)")

DET2 = df['Team Name and Instance'].str.contains("Detroit Pistons") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notDET2 = ~df['Team Name and Instance'].str.contains("Detroit Pistons") & df['Team Name and Instance'].str.contains("(Games 21-41)")

CHA2 = df['Team Name and Instance'].str.contains("Charlotte Hornets") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notCHA2 = ~df['Team Name and Instance'].str.contains("Charlotte Hornets") & df['Team Name and Instance'].str.contains("(Games 21-41)")

NYK2 = df['Team Name and Instance'].str.contains("New York Knicks") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notNYK2 = ~df['Team Name and Instance'].str.contains("New York Knicks") & df['Team Name and Instance'].str.contains("(Games 21-41)")

ORL2 = df['Team Name and Instance'].str.contains("Orlando Magic") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notORL2 = ~df['Team Name and Instance'].str.contains("Orlando Magic") & df['Team Name and Instance'].str.contains("(Games 21-41)")

PHI2 = df['Team Name and Instance'].str.contains("Philadelphia 76ers") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notPHI2 = ~df['Team Name and Instance'].str.contains("Philadelphia 76ers") & df['Team Name and Instance'].str.contains("(Games 21-41)")

BKN2 = df['Team Name and Instance'].str.contains("Brooklyn Nets") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notBKN2 = ~df['Team Name and Instance'].str.contains("Brooklyn Nets") & df['Team Name and Instance'].str.contains("(Games 21-41)")


GSW3 = df['Team Name and Instance'].str.contains("Golden State Warriors") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notGSW3 = ~df['Team Name and Instance'].str.contains("Golden State Warriors") & df['Team Name and Instance'].str.contains("(Games 42-61)")

SAS3 = df['Team Name and Instance'].str.contains("San Antonio Spurs") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notSAS3 = ~df['Team Name and Instance'].str.contains("San Antonio Spurs") & df['Team Name and Instance'].str.contains("(Games 42-61)")

HOU3 = df['Team Name and Instance'].str.contains("Houston Rockets") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notHOU3 = ~df['Team Name and Instance'].str.contains("Houston Rockets") & df['Team Name and Instance'].str.contains("(Games 42-61)")

LAC3 = df['Team Name and Instance'].str.contains("Los Angeles Clippers") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notLAC3 = ~df['Team Name and Instance'].str.contains("Los Angeles Clippers") & df['Team Name and Instance'].str.contains("(Games 42-61)")

UTAH3 = df['Team Name and Instance'].str.contains("Utah Jazz") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notUTAH3 = ~df['Team Name and Instance'].str.contains("Utah Jazz") & df['Team Name and Instance'].str.contains("(Games 42-61)")

OKC3 = df['Team Name and Instance'].str.contains("Oklahoma City Thunder") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notOKC3 = ~df['Team Name and Instance'].str.contains("Oklahoma City Thunder") & df['Team Name and Instance'].str.contains("(Games 42-61)")

MEM3 = df['Team Name and Instance'].str.contains("Memphis Grizzlies") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notMEM3 = ~df['Team Name and Instance'].str.contains("Memphis Grizzlies") & df['Team Name and Instance'].str.contains("(Games 42-61)")

POR3 = df['Team Name and Instance'].str.contains("Portland Trailblazers") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notPOR3 = ~df['Team Name and Instance'].str.contains("Portland Trailblazers") & df['Team Name and Instance'].str.contains("(Games 42-61)")

DEN3 = df['Team Name and Instance'].str.contains("Denver Nuggets") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notDEN3 = ~df['Team Name and Instance'].str.contains("Denver Nuggets") & df['Team Name and Instance'].str.contains("(Games 42-61)")

NOP3 = df['Team Name and Instance'].str.contains("New Orleans Pelicans") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notNOP3 = ~df['Team Name and Instance'].str.contains("New Orleans Pelicans") & df['Team Name and Instance'].str.contains("(Games 42-61)")

DAL3 = df['Team Name and Instance'].str.contains("Dallas Mavericks") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notDAL3 = ~df['Team Name and Instance'].str.contains("Dallas Mavericks") & df['Team Name and Instance'].str.contains("(Games 42-61)")

SAC3 = df['Team Name and Instance'].str.contains("Sacramento Kings") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notSAC3 = ~df['Team Name and Instance'].str.contains("Sacramento Kings") & df['Team Name and Instance'].str.contains("(Games 42-61)")

MIN3 = df['Team Name and Instance'].str.contains("Minnesota Timberwolves") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notMIN3 = ~df['Team Name and Instance'].str.contains("Minnesota Timberwolves") & df['Team Name and Instance'].str.contains("(Games 42-61)")

LAL3 = df['Team Name and Instance'].str.contains("Los Angeles Lakers") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notLAL3 = ~df['Team Name and Instance'].str.contains("Los Angeles Lakers") & df['Team Name and Instance'].str.contains("(Games 42-61)")

PHO3 = df['Team Name and Instance'].str.contains("Phoenix Suns") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notPHO3 = ~df['Team Name and Instance'].str.contains("Phoenix Suns") & df['Team Name and Instance'].str.contains("(Games 42-61)")

BOS3 = df['Team Name and Instance'].str.contains("Boston Celtics") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notBOS3 = ~df['Team Name and Instance'].str.contains("Boston Celtics") & df['Team Name and Instance'].str.contains("(Games 42-61)")

CLE3 = df['Team Name and Instance'].str.contains("Cleveland Cavaliers") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notCLE3 = ~df['Team Name and Instance'].str.contains("Cleveland Cavaliers") & df['Team Name and Instance'].str.contains("(Games 42-61)")

TOR3 = df['Team Name and Instance'].str.contains("Toronto Raptors") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notTOR3 = ~df['Team Name and Instance'].str.contains("Toronto Raptors") & df['Team Name and Instance'].str.contains("(Games 42-61)")

WAS3 = df['Team Name and Instance'].str.contains("Washington Wizards") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notWAS3 = ~df['Team Name and Instance'].str.contains("Washington Wizards") & df['Team Name and Instance'].str.contains("(Games 42-61)")

ATL3 = df['Team Name and Instance'].str.contains("Atlanta Hawks") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notATL3 = ~df['Team Name and Instance'].str.contains("Atlanta Hawks") & df['Team Name and Instance'].str.contains("(Games 42-61)")

MIL3 = df['Team Name and Instance'].str.contains("Milwaukee Bucks") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notMIL3 = ~df['Team Name and Instance'].str.contains("Milwaukee Bucks") & df['Team Name and Instance'].str.contains("(Games 42-61)")

IND3 = df['Team Name and Instance'].str.contains("Indiana Pacers") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notIND3 = ~df['Team Name and Instance'].str.contains("Indiana Pacers") & df['Team Name and Instance'].str.contains("(Games 42-61)")

CHI3 = df['Team Name and Instance'].str.contains("Chicago Bulls") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notCHI3 = ~df['Team Name and Instance'].str.contains("Chicago Bulls") & df['Team Name and Instance'].str.contains("(Games 42-61)")

MIA3 = df['Team Name and Instance'].str.contains("Miami Heat") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notMIA3 = ~df['Team Name and Instance'].str.contains("Miami Heat") & df['Team Name and Instance'].str.contains("(Games 42-61)")

DET3 = df['Team Name and Instance'].str.contains("Detroit Pistons") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notDET3 = ~df['Team Name and Instance'].str.contains("Detroit Pistons") & df['Team Name and Instance'].str.contains("(Games 42-61)")

CHA3 = df['Team Name and Instance'].str.contains("Charlotte Hornets") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notCHA3 = ~df['Team Name and Instance'].str.contains("Charlotte Hornets") & df['Team Name and Instance'].str.contains("(Games 42-61)")

NYK3 = df['Team Name and Instance'].str.contains("New York Knicks") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notNYK3 = ~df['Team Name and Instance'].str.contains("New York Knicks") & df['Team Name and Instance'].str.contains("(Games 42-61)")

ORL3 = df['Team Name and Instance'].str.contains("Orlando Magic") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notORL3 = ~df['Team Name and Instance'].str.contains("Orlando Magic") & df['Team Name and Instance'].str.contains("(Games 42-61)")

PHI3 = df['Team Name and Instance'].str.contains("Philadelphia 76ers") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notPHI3 = ~df['Team Name and Instance'].str.contains("Philadelphia 76ers") & df['Team Name and Instance'].str.contains("(Games 42-61)")

BKN3 = df['Team Name and Instance'].str.contains("Brooklyn Nets") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notBKN3 = ~df['Team Name and Instance'].str.contains("Brooklyn Nets") & df['Team Name and Instance'].str.contains("(Games 42-61)")

GSW4 = df['Team Name and Instance'].str.contains("Golden State Warriors") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notGSW4 = ~df['Team Name and Instance'].str.contains("Golden State Warriors") & df['Team Name and Instance'].str.contains("(Games 62-82)")

SAS4 = df['Team Name and Instance'].str.contains("San Antonio Spurs") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notSAS4 = ~df['Team Name and Instance'].str.contains("San Antonio Spurs") & df['Team Name and Instance'].str.contains("(Games 62-82)")

HOU4 = df['Team Name and Instance'].str.contains("Houston Rockets") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notHOU4 = ~df['Team Name and Instance'].str.contains("Houston Rockets") & df['Team Name and Instance'].str.contains("(Games 62-82)")

LAC4 = df['Team Name and Instance'].str.contains("Los Angeles Clippers") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notLAC4 = ~df['Team Name and Instance'].str.contains("Los Angeles Clippers") & df['Team Name and Instance'].str.contains("(Games 62-82)")

UTAH4 = df['Team Name and Instance'].str.contains("Utah Jazz") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notUTAH4 = ~df['Team Name and Instance'].str.contains("Utah Jazz") & df['Team Name and Instance'].str.contains("(Games 62-82)")

OKC4 = df['Team Name and Instance'].str.contains("Oklahoma City Thunder") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notOKC4 = ~df['Team Name and Instance'].str.contains("Oklahoma City Thunder") & df['Team Name and Instance'].str.contains("(Games 62-82)")

MEM4 = df['Team Name and Instance'].str.contains("Memphis Grizzlies") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notMEM4 = ~df['Team Name and Instance'].str.contains("Memphis Grizzlies") & df['Team Name and Instance'].str.contains("(Games 62-82)")

POR4 = df['Team Name and Instance'].str.contains("Portland Trailblazers") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notPOR4 = ~df['Team Name and Instance'].str.contains("Portland Trailblazers") & df['Team Name and Instance'].str.contains("(Games 62-82)")

DEN4 = df['Team Name and Instance'].str.contains("Denver Nuggets") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notDEN4 = ~df['Team Name and Instance'].str.contains("Denver Nuggets") & df['Team Name and Instance'].str.contains("(Games 62-82)")

NOP4 = df['Team Name and Instance'].str.contains("New Orleans Pelicans") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notNOP4 = ~df['Team Name and Instance'].str.contains("New Orleans Pelicans") & df['Team Name and Instance'].str.contains("(Games 62-82)")

DAL4 = df['Team Name and Instance'].str.contains("Dallas Mavericks") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notDAL4 = ~df['Team Name and Instance'].str.contains("Dallas Mavericks") & df['Team Name and Instance'].str.contains("(Games 62-82)")

SAC4 = df['Team Name and Instance'].str.contains("Sacramento Kings") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notSAC4 = ~df['Team Name and Instance'].str.contains("Sacramento Kings") & df['Team Name and Instance'].str.contains("(Games 62-82)")

MIN4 = df['Team Name and Instance'].str.contains("Minnesota Timberwolves") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notMIN4 = ~df['Team Name and Instance'].str.contains("Minnesota Timberwolves") & df['Team Name and Instance'].str.contains("(Games 62-82)")

LAL4 = df['Team Name and Instance'].str.contains("Los Angeles Lakers") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notLAL4 = ~df['Team Name and Instance'].str.contains("Los Angeles Lakers") & df['Team Name and Instance'].str.contains("(Games 62-82)")

PHO4 = df['Team Name and Instance'].str.contains("Phoenix Suns") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notPHO4 = ~df['Team Name and Instance'].str.contains("Phoenix Suns") & df['Team Name and Instance'].str.contains("(Games 62-82)")

BOS4 = df['Team Name and Instance'].str.contains("Boston Celtics") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notBOS4 = ~df['Team Name and Instance'].str.contains("Boston Celtics") & df['Team Name and Instance'].str.contains("(Games 62-82)")

CLE4 = df['Team Name and Instance'].str.contains("Cleveland Cavaliers") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notCLE4 = ~df['Team Name and Instance'].str.contains("Cleveland Cavaliers") & df['Team Name and Instance'].str.contains("(Games 62-82)")

TOR4 = df['Team Name and Instance'].str.contains("Toronto Raptors") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notTOR4 = ~df['Team Name and Instance'].str.contains("Toronto Raptors") & df['Team Name and Instance'].str.contains("(Games 62-82)")

WAS4 = df['Team Name and Instance'].str.contains("Washington Wizards") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notWAS4 = ~df['Team Name and Instance'].str.contains("Washington Wizards") & df['Team Name and Instance'].str.contains("(Games 62-82)")

ATL4 = df['Team Name and Instance'].str.contains("Atlanta Hawks") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notATL4 = ~df['Team Name and Instance'].str.contains("Atlanta Hawks") & df['Team Name and Instance'].str.contains("(Games 62-82)")

MIL4 = df['Team Name and Instance'].str.contains("Milwaukee Bucks") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notMIL4 = ~df['Team Name and Instance'].str.contains("Milwaukee Bucks") & df['Team Name and Instance'].str.contains("(Games 62-82)")

IND4 = df['Team Name and Instance'].str.contains("Indiana Pacers") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notIND4 = ~df['Team Name and Instance'].str.contains("Indiana Pacers") & df['Team Name and Instance'].str.contains("(Games 62-82)")

CHI4 = df['Team Name and Instance'].str.contains("Chicago Bulls") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notCHI4 = ~df['Team Name and Instance'].str.contains("Chicago Bulls") & df['Team Name and Instance'].str.contains("(Games 62-82)")

MIA4 = df['Team Name and Instance'].str.contains("Miami Heat") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notMIA4 = ~df['Team Name and Instance'].str.contains("Miami Heat") & df['Team Name and Instance'].str.contains("(Games 62-82)")

DET4 = df['Team Name and Instance'].str.contains("Detroit Pistons") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notDET4 = ~df['Team Name and Instance'].str.contains("Detroit Pistons") & df['Team Name and Instance'].str.contains("(Games 62-82)")

CHA4 = df['Team Name and Instance'].str.contains("Charlotte Hornets") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notCHA4 = ~df['Team Name and Instance'].str.contains("Charlotte Hornets") & df['Team Name and Instance'].str.contains("(Games 62-82)")

NYK4 = df['Team Name and Instance'].str.contains("New York Knicks") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notNYK4 = ~df['Team Name and Instance'].str.contains("New York Knicks") & df['Team Name and Instance'].str.contains("(Games 62-82)")

ORL4 = df['Team Name and Instance'].str.contains("Orlando Magic") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notORL4 = ~df['Team Name and Instance'].str.contains("Orlando Magic") & df['Team Name and Instance'].str.contains("(Games 62-82)")

PHI4 = df['Team Name and Instance'].str.contains("Philadelphia 76ers") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notPHI4 = ~df['Team Name and Instance'].str.contains("Philadelphia 76ers") & df['Team Name and Instance'].str.contains("(Games 62-82)")

BKN4 = df['Team Name and Instance'].str.contains("Brooklyn Nets") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notBKN4 = ~df['Team Name and Instance'].str.contains("Brooklyn Nets") & df['Team Name and Instance'].str.contains("(Games 62-82)")

# %%
#set the data to be predicted for first quarter

X_GSW_data = df.loc[GSW1, X_stats]
y_GSW_data = df.loc[GSW1, Y_stats]

X_SAS_data = df.loc[SAS1, X_stats]
y_SAS_data = df.loc[SAS1, Y_stats]

X_HOU_data = df.loc[HOU1, X_stats]
y_HOU_data = df.loc[HOU1, Y_stats]

X_LAC_data = df.loc[LAC1, X_stats]
y_LAC_data = df.loc[LAC1, Y_stats]

X_UTAH_data = df.loc[UTAH1, X_stats]
y_UTAH_data = df.loc[UTAH1, Y_stats]

X_OKC_data = df.loc[OKC1, X_stats]
y_OKC_data = df.loc[OKC1, Y_stats]

X_MEM_data = df.loc[MEM1, X_stats]
y_MEM_data = df.loc[MEM1, Y_stats]

X_POR_data = df.loc[POR1, X_stats]
y_POR_data = df.loc[POR1, Y_stats]

X_DEN_data = df.loc[DEN1, X_stats]
y_DEN_data = df.loc[DEN1, Y_stats]

X_NOP_data = df.loc[NOP1, X_stats]
y_NOP_data = df.loc[NOP1, Y_stats]

X_DAL_data = df.loc[DAL1, X_stats]
y_DAL_data = df.loc[DAL1, Y_stats]

X_SAC_data = df.loc[SAC1, X_stats]
y_SAC_data = df.loc[SAC1, Y_stats]

X_MIN_data = df.loc[MIN1, X_stats]
y_MIN_data = df.loc[MIN1, Y_stats]

X_LAL_data = df.loc[LAL1, X_stats]
y_LAL_data = df.loc[LAL1, Y_stats]

X_PHO_data = df.loc[PHO1, X_stats]
y_PHO_data = df.loc[PHO1, Y_stats]

X_BOS_data = df.loc[BOS1, X_stats]
y_BOS_data = df.loc[BOS1, Y_stats]

X_CLE_data = df.loc[CLE1, X_stats]
y_CLE_data = df.loc[CLE1, Y_stats]

X_TOR_data = df.loc[TOR1, X_stats]
y_TOR_data = df.loc[TOR1, Y_stats]

X_WAS_data = df.loc[WAS1, X_stats]
y_WAS_data = df.loc[WAS1, Y_stats]

X_ATL_data = df.loc[ATL1, X_stats]
y_ATL_data = df.loc[ATL1, Y_stats]

X_MIL_data = df.loc[MIL1, X_stats]
y_MIL_data = df.loc[MIL1, Y_stats]

X_IND_data = df.loc[IND1, X_stats]
y_IND_data = df.loc[IND1, Y_stats]

X_CHI_data = df.loc[CHI1, X_stats]
y_CHI_data = df.loc[CHI1, Y_stats]

X_MIA_data = df.loc[MIA1, X_stats]
y_MIA_data = df.loc[MIA1, Y_stats]

X_DET_data = df.loc[DET1, X_stats]
y_DET_data = df.loc[DET1, Y_stats]

X_CHA_data = df.loc[CHA1, X_stats]
y_CHA_data = df.loc[CHA1, Y_stats]

X_NYK_data = df.loc[NYK1, X_stats]
y_NYK_data = df.loc[NYK1, Y_stats]

X_ORL_data = df.loc[ORL1, X_stats]
y_ORL_data = df.loc[ORL1, Y_stats]

X_PHI_data = df.loc[PHI1, X_stats]
y_PHI_data = df.loc[PHI1, Y_stats]

X_BKN_data = df.loc[BKN1, X_stats]
y_BKN_data = df.loc[BKN1, Y_stats]

# %%
#set the training dataset for first half of the season.
#this will not include the team itself

X_GSW_train = df.loc[notGSW1, X_stats]
y_GSW_train = df.loc[notGSW1, Y_stats]

X_SAS_train = df.loc[notSAS1, X_stats]
y_SAS_train = df.loc[notSAS1, Y_stats]

X_HOU_train = df.loc[notHOU1, X_stats]
y_HOU_train = df.loc[notHOU1, Y_stats]

X_LAC_train = df.loc[notLAC1, X_stats]
y_LAC_train = df.loc[notLAC1, Y_stats]

X_UTAH_train = df.loc[notUTAH1, X_stats]
y_UTAH_train = df.loc[notUTAH1, Y_stats]

X_OKC_train = df.loc[notOKC1, X_stats]
y_OKC_train = df.loc[notOKC1, Y_stats]

X_MEM_train = df.loc[notMEM1, X_stats]
y_MEM_train = df.loc[notMEM1, Y_stats]

X_POR_train = df.loc[notPOR1, X_stats]
y_POR_train = df.loc[notPOR1, Y_stats]

X_DEN_train = df.loc[notDEN1, X_stats]
y_DEN_train = df.loc[notDEN1, Y_stats]

X_NOP_train = df.loc[notNOP1, X_stats]
y_NOP_train = df.loc[notNOP1, Y_stats]

X_DAL_train = df.loc[notDAL1, X_stats]
y_DAL_train = df.loc[notDAL1, Y_stats]

X_SAC_train = df.loc[notSAC1, X_stats]
y_SAC_train = df.loc[notSAC1, Y_stats]

X_MIN_train = df.loc[notMIN1, X_stats]
y_MIN_train = df.loc[notMIN1, Y_stats]

X_LAL_train = df.loc[notLAL1, X_stats]
y_LAL_train = df.loc[notLAL1, Y_stats]

X_PHO_train = df.loc[notPHO1, X_stats]
y_PHO_train = df.loc[notPHO1, Y_stats]

X_BOS_train = df.loc[notBOS1, X_stats]
y_BOS_train = df.loc[notBOS1, Y_stats]

X_CLE_train = df.loc[notCLE1, X_stats]
y_CLE_train = df.loc[notCLE1, Y_stats]

X_TOR_train = df.loc[notTOR1, X_stats]
y_TOR_train = df.loc[notTOR1, Y_stats]

X_WAS_train = df.loc[notWAS1, X_stats]
y_WAS_train = df.loc[notWAS1, Y_stats]

X_ATL_train = df.loc[notPHO1, X_stats]
y_ATL_train = df.loc[notPHO1, Y_stats]

X_MIL_train = df.loc[notMIL1, X_stats]
y_MIL_train = df.loc[notMIL1, Y_stats]

X_IND_train = df.loc[notIND1, X_stats]
y_IND_train = df.loc[notIND1, Y_stats]

X_CHI_train = df.loc[notCHI1, X_stats]
y_CHI_train = df.loc[notCHI1, Y_stats]

X_MIA_train = df.loc[notMIA1, X_stats]
y_MIA_train = df.loc[notMIA1, Y_stats]

X_DET_train = df.loc[notDET1, X_stats]
y_DET_train = df.loc[notDET1, Y_stats]

X_CHA_train = df.loc[notCHA1, X_stats]
y_CHA_train = df.loc[notCHA1, Y_stats]

X_NYK_train = df.loc[notNYK1, X_stats]
y_NYK_train = df.loc[notNYK1, Y_stats]

X_ORL_train = df.loc[notORL1, X_stats]
y_ORL_train = df.loc[notORL1, Y_stats]

X_PHI_train = df.loc[notPHI1, X_stats]
y_PHI_train = df.loc[notPHI1, Y_stats]

X_BKN_train = df.loc[notBKN1, X_stats]
y_BKN_train = df.loc[notBKN1, Y_stats]

# %%
#scale features

from sklearn.preprocessing import StandardScaler

sc_GSW = StandardScaler()
X_GSW_train = sc_GSW.fit_transform(X_GSW_train)
X_GSW_data = sc_GSW.transform(X_GSW_data)

sc_SAS = StandardScaler()
X_SAS_train = sc_SAS.fit_transform(X_SAS_train)
X_SAS_data = sc_SAS.transform(X_SAS_data)

sc_HOU = StandardScaler()
X_HOU_train = sc_HOU.fit_transform(X_HOU_train)
X_HOU_data = sc_HOU.transform(X_HOU_data)

sc_LAC = StandardScaler()
X_LAC_train = sc_LAC.fit_transform(X_LAC_train)
X_LAC_data = sc_LAC.transform(X_LAC_data)

sc_UTAH = StandardScaler()
X_UTAH_train = sc_UTAH.fit_transform(X_UTAH_train)
X_UTAH_data = sc_UTAH.transform(X_UTAH_data)

sc_OKC = StandardScaler()
X_OKC_train = sc_OKC.fit_transform(X_OKC_train)
X_OKC_data = sc_OKC.transform(X_OKC_data)

sc_MEM = StandardScaler()
X_MEM_train = sc_MEM.fit_transform(X_MEM_train)
X_MEM_data = sc_MEM.transform(X_MEM_data)

sc_POR = StandardScaler()
X_POR_train = sc_POR.fit_transform(X_POR_train)
X_POR_data = sc_POR.transform(X_POR_data)

sc_DEN = StandardScaler()
X_DEN_train = sc_DEN.fit_transform(X_DEN_train)
X_DEN_data = sc_DEN.transform(X_DEN_data)

sc_NOP = StandardScaler()
X_NOP_train = sc_NOP.fit_transform(X_NOP_train)
X_NOP_data = sc_NOP.transform(X_NOP_data)

sc_DAL = StandardScaler()
X_DAL_train = sc_DAL.fit_transform(X_DAL_train)
X_DAL_data = sc_DAL.transform(X_DAL_data)

sc_SAC = StandardScaler()
X_SAC_train = sc_SAC.fit_transform(X_SAC_train)
X_SAC_data = sc_SAC.transform(X_SAC_data)

sc_MIN = StandardScaler()
X_MIN_train = sc_MIN.fit_transform(X_MIN_train)
X_MIN_data = sc_MIN.transform(X_MIN_data)

sc_LAL = StandardScaler()
X_LAL_train = sc_LAL.fit_transform(X_LAL_train)
X_LAL_data = sc_LAL.transform(X_LAL_data)

sc_PHO = StandardScaler()
X_PHO_train = sc_PHO.fit_transform(X_PHO_train)
X_PHO_data = sc_PHO.transform(X_PHO_data)

sc_BOS = StandardScaler()
X_BOS_train = sc_BOS.fit_transform(X_BOS_train)
X_BOS_data = sc_BOS.transform(X_BOS_data)

sc_CLE = StandardScaler()
X_CLE_train = sc_CLE.fit_transform(X_CLE_train)
X_CLE_data = sc_CLE.transform(X_CLE_data)

sc_TOR = StandardScaler()
X_TOR_train = sc_TOR.fit_transform(X_TOR_train)
X_TOR_data = sc_TOR.transform(X_TOR_data)

sc_WAS = StandardScaler()
X_WAS_train = sc_WAS.fit_transform(X_WAS_train)
X_WAS_data = sc_WAS.transform(X_WAS_data)

sc_ATL = StandardScaler()
X_ATL_train = sc_ATL.fit_transform(X_ATL_train)
X_ATL_data = sc_ATL.transform(X_ATL_data)

sc_MIL = StandardScaler()
X_MIL_train = sc_MIL.fit_transform(X_MIL_train)
X_MIL_data = sc_MIL.transform(X_MIL_data)

sc_IND = StandardScaler()
X_IND_train = sc_IND.fit_transform(X_IND_train)
X_IND_data = sc_IND.transform(X_IND_data)

sc_CHI = StandardScaler()
X_CHI_train = sc_CHI.fit_transform(X_CHI_train)
X_CHI_data = sc_CHI.transform(X_CHI_data)

sc_MIA = StandardScaler()
X_MIA_train = sc_MIA.fit_transform(X_MIA_train)
X_MIA_data = sc_MIA.transform(X_MIA_data)

sc_DET = StandardScaler()
X_DET_train = sc_DET.fit_transform(X_DET_train)
X_DET_data = sc_DET.transform(X_DET_data)

sc_CHA = StandardScaler()
X_CHA_train = sc_CHA.fit_transform(X_CHA_train)
X_CHA_data = sc_CHA.transform(X_CHA_data)

sc_NYK = StandardScaler()
X_NYK_train = sc_NYK.fit_transform(X_NYK_train)
X_NYK_data = sc_NYK.transform(X_NYK_data)

sc_ORL = StandardScaler()
X_ORL_train = sc_ORL.fit_transform(X_ORL_train)
X_ORL_data = sc_ORL.transform(X_ORL_data)

sc_PHI = StandardScaler()
X_PHI_train = sc_PHI.fit_transform(X_PHI_train)
X_PHI_data = sc_PHI.transform(X_PHI_data)

sc_BKN = StandardScaler()
X_BKN_train = sc_BKN.fit_transform(X_BKN_train)
X_BKN_data = sc_BKN.transform(X_BKN_data)

# %%
from sklearn.ensemble import RandomForestRegressor

reg_GSW = RandomForestRegressor(n_estimators=20, random_state=0)
reg_GSW.fit(X_GSW_train, y_GSW_train)
y_pred_GSW = reg_GSW.predict(X_GSW_data)

reg_SAS = RandomForestRegressor(n_estimators=20, random_state=0)
reg_SAS.fit(X_SAS_train, y_SAS_train)
y_pred_SAS = reg_SAS.predict(X_SAS_data)

reg_HOU = RandomForestRegressor(n_estimators=20, random_state=0)
reg_HOU.fit(X_HOU_train, y_HOU_train)
y_pred_HOU = reg_HOU.predict(X_HOU_data)

reg_LAC = RandomForestRegressor(n_estimators=20, random_state=0)
reg_LAC.fit(X_LAC_train, y_LAC_train)
y_pred_LAC = reg_LAC.predict(X_LAC_data)

reg_UTAH = RandomForestRegressor(n_estimators=20, random_state=0)
reg_UTAH.fit(X_UTAH_train, y_UTAH_train)
y_pred_UTAH = reg_UTAH.predict(X_UTAH_data)

reg_OKC = RandomForestRegressor(n_estimators=20, random_state=0)
reg_OKC.fit(X_OKC_train, y_OKC_train)
y_pred_OKC = reg_OKC.predict(X_OKC_data)

reg_MEM = RandomForestRegressor(n_estimators=20, random_state=0)
reg_MEM.fit(X_MEM_train, y_MEM_train)
y_pred_MEM = reg_MEM.predict(X_MEM_data)

reg_POR = RandomForestRegressor(n_estimators=20, random_state=0)
reg_POR.fit(X_POR_train, y_POR_train)
y_pred_POR = reg_POR.predict(X_POR_data)

reg_DEN = RandomForestRegressor(n_estimators=20, random_state=0)
reg_DEN.fit(X_DEN_train, y_DEN_train)
y_pred_DEN = reg_DEN.predict(X_DEN_data)

reg_NOP = RandomForestRegressor(n_estimators=20, random_state=0)
reg_NOP.fit(X_NOP_train, y_NOP_train)
y_pred_NOP = reg_NOP.predict(X_NOP_data)

reg_DAL = RandomForestRegressor(n_estimators=20, random_state=0)
reg_DAL.fit(X_DAL_train, y_DAL_train)
y_pred_DAL = reg_DAL.predict(X_DAL_data)

reg_SAC = RandomForestRegressor(n_estimators=20, random_state=0)
reg_SAC.fit(X_SAC_train, y_SAC_train)
y_pred_SAC = reg_SAC.predict(X_SAC_data)

reg_MIN = RandomForestRegressor(n_estimators=20, random_state=0)
reg_MIN.fit(X_MIN_train, y_MIN_train)
y_pred_MIN = reg_MIN.predict(X_MIN_data)

reg_LAL = RandomForestRegressor(n_estimators=20, random_state=0)
reg_LAL.fit(X_LAL_train, y_LAL_train)
y_pred_LAL = reg_LAL.predict(X_LAL_data)

reg_PHO = RandomForestRegressor(n_estimators=20, random_state=0)
reg_PHO.fit(X_PHO_train, y_PHO_train)
y_pred_PHO = reg_PHO.predict(X_PHO_data)

reg_BOS = RandomForestRegressor(n_estimators=20, random_state=0)
reg_BOS.fit(X_BOS_train, y_BOS_train)
y_pred_BOS = reg_BOS.predict(X_BOS_data)

reg_CLE = RandomForestRegressor(n_estimators=20, random_state=0)
reg_CLE.fit(X_CLE_train, y_CLE_train)
y_pred_CLE = reg_CLE.predict(X_CLE_data)

reg_TOR = RandomForestRegressor(n_estimators=20, random_state=0)
reg_TOR.fit(X_TOR_train, y_TOR_train)
y_pred_TOR = reg_TOR.predict(X_TOR_data)

reg_WAS = RandomForestRegressor(n_estimators=20, random_state=0)
reg_WAS.fit(X_WAS_train, y_WAS_train)
y_pred_WAS = reg_WAS.predict(X_WAS_data)

reg_ATL = RandomForestRegressor(n_estimators=20, random_state=0)
reg_ATL.fit(X_ATL_train, y_ATL_train)
y_pred_ATL = reg_ATL.predict(X_ATL_data)

reg_MIL = RandomForestRegressor(n_estimators=20, random_state=0)
reg_MIL.fit(X_MIL_train, y_MIL_train)
y_pred_MIL = reg_MIL.predict(X_MIL_data)

reg_IND = RandomForestRegressor(n_estimators=20, random_state=0)
reg_IND.fit(X_IND_train, y_IND_train)
y_pred_IND = reg_IND.predict(X_IND_data)

reg_CHI = RandomForestRegressor(n_estimators=20, random_state=0)
reg_CHI.fit(X_CHI_train, y_CHI_train)
y_pred_CHI = reg_CHI.predict(X_CHI_data)

reg_MIA = RandomForestRegressor(n_estimators=20, random_state=0)
reg_MIA.fit(X_MIA_train, y_MIA_train)
y_pred_MIA = reg_MIA.predict(X_MIA_data)

reg_DET = RandomForestRegressor(n_estimators=20, random_state=0)
reg_DET.fit(X_DET_train, y_DET_train)
y_pred_DET = reg_DET.predict(X_DET_data)

reg_CHA = RandomForestRegressor(n_estimators=20, random_state=0)
reg_CHA.fit(X_CHA_train, y_CHA_train)
y_pred_CHA = reg_CHA.predict(X_CHA_data)

reg_NYK = RandomForestRegressor(n_estimators=20, random_state=0)
reg_NYK.fit(X_NYK_train, y_NYK_train)
y_pred_NYK = reg_NYK.predict(X_NYK_data)

reg_ORL = RandomForestRegressor(n_estimators=20, random_state=0)
reg_ORL.fit(X_ORL_train, y_ORL_train)
y_pred_ORL = reg_ORL.predict(X_ORL_data)

reg_PHI = RandomForestRegressor(n_estimators=20, random_state=0)
reg_PHI.fit(X_PHI_train, y_PHI_train)
y_pred_PHI = reg_PHI.predict(X_PHI_data)

reg_BKN = RandomForestRegressor(n_estimators=20, random_state=0)
reg_BKN.fit(X_BKN_train, y_BKN_train)
y_pred_BKN = reg_BKN.predict(X_BKN_data)

# %%
#self accuracy

#since the prediction values are continuous, and the truth values are binary
#sklearn.metrics would print out an error of how the classification metrics
#can't handle a mix of binary and continuous targets, thus the accuracy
#will then be computed by 100 - percent error of the predicted and the actual

if y_GSW_data.values.item(0) > 0:
  percent_error = abs((y_pred_GSW.item(0) - y_GSW_data.values.item(0)) / y_GSW_data.values.item(0))
else:
  percent_error = abs((y_pred_GSW.item(0) - y_GSW_data.values.item(0)) / (y_GSW_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for GSW: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for GSW: 99.9%

# %%
if y_SAS_data.values.item(0) > 0:
  percent_error = abs((y_pred_SAS.item(0) - y_SAS_data.values.item(0)) / y_SAS_data.values.item(0))
else:
  percent_error = abs((y_pred_SAS.item(0) - y_SAS_data.values.item(0)) / (y_SAS_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for SAS: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for SAS: 99.95%

# %%
if y_HOU_data.values.item(0) > 0:
  percent_error = abs((y_pred_HOU.item(0) - y_HOU_data.values.item(0)) / y_HOU_data.values.item(0))
else:
  percent_error = abs((y_pred_HOU.item(0) - y_HOU_data.values.item(0)) / (y_HOU_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for HOU: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for HOU: 99.9%

# %%
if y_LAC_data.values.item(0) > 0:
  percent_error = abs((y_pred_LAC.item(0) - y_LAC_data.values.item(0)) / y_LAC_data.values.item(0))
else:
  percent_error = abs((y_pred_LAC.item(0) - y_LAC_data.values.item(0)) / (y_LAC_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for LAC: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for LAC: 99.5%

# %%
if y_UTAH_data.values.item(0) > 0:
  percent_error = abs((y_pred_UTAH.item(0) - y_UTAH_data.values.item(0)) / y_UTAH_data.values.item(0))
else:
  percent_error = abs((y_pred_UTAH.item(0) - y_UTAH_data.values.item(0)) / (y_UTAH_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for UTAH: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for UTAH: 99.55%

# %%
if y_OKC_data.values.item(0) > 0:
  percent_error = abs((y_pred_OKC.item(0) - y_OKC_data.values.item(0)) / y_OKC_data.values.item(0))
else:
  percent_error = abs((y_pred_OKC.item(0) - y_OKC_data.values.item(0)) / (y_OKC_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for OKC: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for OKC: 99.45%

# %%
if y_MEM_data.values.item(0) > 0:
  percent_error = abs((y_pred_MEM.item(0) - y_MEM_data.values.item(0)) / y_MEM_data.values.item(0))
else:
  percent_error = abs((y_pred_MEM.item(0) - y_MEM_data.values.item(0)) / (y_MEM_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for MEM: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for MEM: 99.15%

# %%
if y_POR_data.values.item(0) > 0:
  percent_error = abs((y_pred_POR.item(0) - y_POR_data.values.item(0)) / y_POR_data.values.item(0))
else:
  percent_error = abs((y_pred_POR.item(0) - y_POR_data.values.item(0)) / (y_POR_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for POR: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for POR: 99.15%

# %%
if y_DEN_data.values.item(0) > 0:
  percent_error = abs((y_pred_DEN.item(0) - y_DEN_data.values.item(0)) / y_DEN_data.values.item(0))
else:
  percent_error = abs((y_pred_DEN.item(0) - y_DEN_data.values.item(0)) / (y_DEN_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for DEN: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for DEN: 99.65%

# %%
if y_NOP_data.values.item(0) > 0:
  percent_error = abs((y_pred_NOP.item(0) - y_NOP_data.values.item(0)) / y_NOP_data.values.item(0))
else:
  percent_error = abs((y_pred_NOP.item(0) - y_NOP_data.values.item(0)) / (y_NOP_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for NOP: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for NOP: 99.25%

# %%
if y_DAL_data.values.item(0) > 0:
  percent_error = abs((y_pred_DAL.item(0) - y_DAL_data.values.item(0)) / y_DAL_data.values.item(0))
else:
  percent_error = abs((y_pred_DAL.item(0) - y_DAL_data.values.item(0)) / (y_DAL_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for DAL: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for DAL: 99.4%

# %%
if y_SAC_data.values.item(0) > 0:
  percent_error = abs((y_pred_SAC.item(0) - y_SAC_data.values.item(0)) / y_SAC_data.values.item(0))
else:
  percent_error = abs((y_pred_SAC.item(0) - y_SAC_data.values.item(0)) / (y_SAC_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for SAC: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for SAC: 99.9%

# %%
if y_MIN_data.values.item(0) > 0:
  percent_error = abs((y_pred_MIN.item(0) - y_MIN_data.values.item(0)) / y_MIN_data.values.item(0))
else:
  percent_error = abs((y_pred_MIN.item(0) - y_MIN_data.values.item(0)) / (y_MIN_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for MIN: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for MIN: 99.55%

# %%
if y_LAL_data.values.item(0) > 0:
  percent_error = abs((y_pred_LAL.item(0) - y_LAL_data.values.item(0)) / y_LAL_data.values.item(0))
else:
  percent_error = abs((y_pred_LAL.item(0) - y_LAL_data.values.item(0)) / (y_LAL_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for LAL: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for LAL: 99.9%

# %%
if y_PHO_data.values.item(0) > 0:
  percent_error = abs((y_pred_PHO.item(0) - y_PHO_data.values.item(0)) / y_PHO_data.values.item(0))
else:
  percent_error = abs((y_pred_PHO.item(0) - y_PHO_data.values.item(0)) / (y_PHO_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for PHO: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for PHO: 99.75%

# %%
if y_BOS_data.values.item(0) > 0:
  percent_error = abs((y_pred_BOS.item(0) - y_BOS_data.values.item(0)) / y_BOS_data.values.item(0))
else:
  percent_error = abs((y_pred_BOS.item(0) - y_BOS_data.values.item(0)) / (y_BOS_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for BOS: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for BOS: 99.45%

# %%
if y_CLE_data.values.item(0) > 0:
  percent_error = abs((y_pred_CLE.item(0) - y_CLE_data.values.item(0)) / y_CLE_data.values.item(0))
else:
  percent_error = abs((y_pred_CLE.item(0) - y_CLE_data.values.item(0)) / (y_CLE_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for CLE: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for CLE: 99.45%

# %%
if y_TOR_data.values.item(0) > 0:
  percent_error = abs((y_pred_TOR.item(0) - y_TOR_data.values.item(0)) / y_TOR_data.values.item(0))
else:
  percent_error = abs((y_pred_TOR.item(0) - y_TOR_data.values.item(0)) / (y_TOR_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for TOR: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for TOR: 99.3%

# %%
if y_WAS_data.values.item(0) > 0:
  percent_error = abs((y_pred_WAS.item(0) - y_WAS_data.values.item(0)) / y_WAS_data.values.item(0))
else:
  percent_error = abs((y_pred_WAS.item(0) - y_WAS_data.values.item(0)) / (y_WAS_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for WAS: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for WAS: 99.5%

# %%
if y_ATL_data.values.item(0) > 0:
  percent_error = abs((y_pred_ATL.item(0) - y_ATL_data.values.item(0)) / y_ATL_data.values.item(0))
else:
  percent_error = abs((y_pred_ATL.item(0) - y_ATL_data.values.item(0)) / (y_ATL_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for ATL: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for ATL: 99.6%

# %%
if y_MIL_data.values.item(0) > 0:
  percent_error = abs((y_pred_MIL.item(0) - y_MIL_data.values.item(0)) / y_MIL_data.values.item(0))
else:
  percent_error = abs((y_pred_MIL.item(0) - y_MIL_data.values.item(0)) / (y_MIL_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for MIL: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for MIL: 99.2%

# %%
if y_IND_data.values.item(0) > 0:
  percent_error = abs((y_pred_IND.item(0) - y_IND_data.values.item(0)) / y_IND_data.values.item(0))
else:
  percent_error = abs((y_pred_IND.item(0) - y_IND_data.values.item(0)) / (y_IND_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for IND: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for IND: 99.3%

# %%
if y_CHI_data.values.item(0) > 0:
  percent_error = abs((y_pred_CHI.item(0) - y_CHI_data.values.item(0)) / y_CHI_data.values.item(0))
else:
  percent_error = abs((y_pred_CHI.item(0) - y_CHI_data.values.item(0)) / (y_CHI_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for CHI: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for CHI: 99.15%

# %%
if y_MIA_data.values.item(0) > 0:
  percent_error = abs((y_pred_MIA.item(0) - y_MIA_data.values.item(0)) / y_MIA_data.values.item(0))
else:
  percent_error = abs((y_pred_MIA.item(0) - y_MIA_data.values.item(0)) / (y_MIA_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for MIA: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for MIA: 99.5%

# %%
if y_DET_data.values.item(0) > 0:
  percent_error = abs((y_pred_DET.item(0) - y_DET_data.values.item(0)) / y_DET_data.values.item(0))
else:
  percent_error = abs((y_pred_DET.item(0) - y_DET_data.values.item(0)) / (y_DET_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for DET: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for DET: 99.6%

# %%
if y_CHA_data.values.item(0) > 0:
  percent_error = abs((y_pred_CHA.item(0) - y_CHA_data.values.item(0)) / y_CHA_data.values.item(0))
else:
  percent_error = abs((y_pred_CHA.item(0) - y_CHA_data.values.item(0)) / (y_CHA_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for CHA: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for CHA: 99.65%

# %%
if y_NYK_data.values.item(0) > 0:
  percent_error = abs((y_pred_NYK.item(0) - y_NYK_data.values.item(0)) / y_NYK_data.values.item(0))
else:
  percent_error = abs((y_pred_NYK.item(0) - y_NYK_data.values.item(0)) / (y_NYK_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for NYK: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for NYK: 99.55%

# %%
if y_ORL_data.values.item(0) > 0:
  percent_error = abs((y_pred_ORL.item(0) - y_ORL_data.values.item(0)) / y_ORL_data.values.item(0))
else:
  percent_error = abs((y_pred_ORL.item(0) - y_ORL_data.values.item(0)) / (y_ORL_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for ORL: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for ORL: 99.8%

# %%
if y_PHI_data.values.item(0) > 0:
  percent_error = abs((y_pred_PHI.item(0) - y_PHI_data.values.item(0)) / y_PHI_data.values.item(0))
else:
  percent_error = abs((y_pred_PHI.item(0) - y_PHI_data.values.item(0)) / (y_PHI_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for PHI: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for PHI: 99.8%

# %%
if y_BKN_data.values.item(0) > 0:
  percent_error = abs((y_pred_BKN.item(0) - y_BKN_data.values.item(0)) / y_BKN_data.values.item(0))
else:
  percent_error = abs((y_pred_BKN.item(0) - y_BKN_data.values.item(0)) / (y_BKN_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for BKN: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for BKN: 99.5%

# %%
west_dict = {
    "Golden State Warriors" : y_pred_GSW.item(0),
    "San Antonio Spurs" : y_pred_SAS.item(0),
    "Houston Rockets": y_pred_HOU.item(0),
    "Los Angeles Clippers": y_pred_LAC.item(0),
    "Utah Jazz" : y_pred_UTAH.item(0),
    "Oklahoma City Thunder" : y_pred_OKC.item(0),
    "Memphis Grizzlies" : y_pred_MEM.item(0),
    "Portland Trailblazers" : y_pred_POR.item(0),
    "Denver Nuggets" : y_pred_DEN.item(0),
    "New Orleans Pelicans" : y_pred_NOP.item(0),
    "Dallas Mavericks" : y_pred_DAL.item(0),
    "Sacramento Kings" : y_pred_SAC.item(0),
    "Minnesota Timberwolves" : y_pred_MIN.item(0),
    "Los Angeles Lakers" : y_pred_LAL.item(0),
    "Phoenix Suns" : y_pred_PHO.item(0)
}

print("Making the Western Conference Playoffs:\n")

for a, b in west_dict.items():
  if b >= 0.5:
    print("%s will make the playoffs in the Western Conference!" % a)

east_dict = {
    "Boston Celtics" : y_pred_BOS.item(0),
    "Cleveland Cavaliers" : y_pred_CLE.item(0),
    "Toronto Raptors" : y_pred_TOR.item(0),
    "Washington Wizards" : y_pred_WAS.item(0),
    "Atlanta Hawks" : y_pred_ATL.item(0),
    "Milwaukee Bucks" : y_pred_MIL.item(0),
    "Indiana Pacers" : y_pred_IND.item(0),
    "Chicago Bulls" : y_pred_CHI.item(0),
    "Miami Heat" : y_pred_MIA.item(0),
    "Detroit Pistons" : y_pred_DET.item(0),
    "Charlotte Hornets" : y_pred_CHA.item(0),
    "New York Knicks" : y_pred_NYK.item(0),
    "Orlando Magic" : y_pred_ORL.item(0),
    "Philadelphia 76ers" : y_pred_PHI.item(0),
    "Brooklyn Nets" : y_pred_BKN.item(0)
}

print("\nMaking the Eastern Conference Playoffs:\n")

for a, b in east_dict.items():
  if b >= 0.5:
    print("%s will make the playoffs in the Eastern Conference!" % a)
# Out:
# Making the Western Conference Playoffs:
#
# Golden State Warriors will make the playoffs in the Western Conference!
# San Antonio Spurs will make the playoffs in the Western Conference!
# Houston Rockets will make the playoffs in the Western Conference!
# Los Angeles Clippers will make the playoffs in the Western Conference!
# Portland Trailblazers will make the playoffs in the Western Conference!
# Denver Nuggets will make the playoffs in the Western Conference!
# New Orleans Pelicans will make the playoffs in the Western Conference!
# Dallas Mavericks will make the playoffs in the Western Conference!
# Los Angeles Lakers will make the playoffs in the Western Conference!
#
# Making the Eastern Conference Playoffs:
#
# Cleveland Cavaliers will make the playoffs in the Eastern Conference!
# Toronto Raptors will make the playoffs in the Eastern Conference!
# Washington Wizards will make the playoffs in the Eastern Conference!
# ...

# %%
X_GSW_data2 = df.loc[GSW2, X_stats]
y_GSW_data2 = df.loc[GSW2, Y_stats]

X_SAS_data2 = df.loc[SAS2, X_stats]
y_SAS_data2 = df.loc[SAS2, Y_stats]

X_HOU_data2 = df.loc[HOU2, X_stats]
y_HOU_data2 = df.loc[HOU2, Y_stats]

X_LAC_data2 = df.loc[LAC2, X_stats]
y_LAC_data2 = df.loc[LAC2, Y_stats]

X_UTAH_data2 = df.loc[UTAH2, X_stats]
y_UTAH_data2 = df.loc[UTAH2, Y_stats]

X_OKC_data2 = df.loc[OKC2, X_stats]
y_OKC_data2 = df.loc[OKC2, Y_stats]

X_MEM_data2 = df.loc[MEM2, X_stats]
y_MEM_data2 = df.loc[MEM2, Y_stats]

X_POR_data2 = df.loc[POR2, X_stats]
y_POR_data2 = df.loc[POR2, Y_stats]

X_DEN_data2 = df.loc[DEN2, X_stats]
y_DEN_data2 = df.loc[DEN2, Y_stats]

X_NOP_data2 = df.loc[NOP2, X_stats]
y_NOP_data2 = df.loc[NOP2, Y_stats]

X_DAL_data2 = df.loc[DAL2, X_stats]
y_DAL_data2 = df.loc[DAL2, Y_stats]

X_SAC_data2 = df.loc[SAC2, X_stats]
y_SAC_data2 = df.loc[SAC2, Y_stats]

X_MIN_data2 = df.loc[MIN2, X_stats]
y_MIN_data2 = df.loc[MIN2, Y_stats]

X_LAL_data2 = df.loc[LAL2, X_stats]
y_LAL_data2 = df.loc[LAL2, Y_stats]

X_PHO_data2 = df.loc[PHO2, X_stats]
y_PHO_data2 = df.loc[PHO2, Y_stats]

X_BOS_data2 = df.loc[BOS2, X_stats]
y_BOS_data2 = df.loc[BOS2, Y_stats]

X_CLE_data2 = df.loc[CLE2, X_stats]
y_CLE_data2 = df.loc[CLE2, Y_stats]

X_TOR_data2 = df.loc[TOR2, X_stats]
y_TOR_data2 = df.loc[TOR2, Y_stats]

X_WAS_data2 = df.loc[WAS2, X_stats]
y_WAS_data2 = df.loc[WAS2, Y_stats]

X_ATL_data2 = df.loc[ATL2, X_stats]
y_ATL_data2 = df.loc[ATL2, Y_stats]

X_MIL_data2 = df.loc[MIL2, X_stats]
y_MIL_data2 = df.loc[MIL2, Y_stats]

X_IND_data2 = df.loc[IND2, X_stats]
y_IND_data2 = df.loc[IND2, Y_stats]

X_CHI_data2 = df.loc[CHI2, X_stats]
y_CHI_data2 = df.loc[CHI2, Y_stats]

X_MIA_data2 = df.loc[MIA2, X_stats]
y_MIA_data2 = df.loc[MIA2, Y_stats]

X_DET_data2 = df.loc[DET2, X_stats]
y_DET_data2 = df.loc[DET2, Y_stats]

X_CHA_data2 = df.loc[CHA2, X_stats]
y_CHA_data2 = df.loc[CHA2, Y_stats]

X_NYK_data2 = df.loc[NYK2, X_stats]
y_NYK_data2 = df.loc[NYK2, Y_stats]

X_ORL_data2 = df.loc[ORL2, X_stats]
y_ORL_data2 = df.loc[ORL2, Y_stats]

X_PHI_data2 = df.loc[PHI2, X_stats]
y_PHI_data2 = df.loc[PHI2, Y_stats]

X_BKN_data2 = df.loc[BKN2, X_stats]
y_BKN_data2 = df.loc[BKN2, Y_stats]

# %%
X_GSW_train2 = df.loc[notGSW2, X_stats]
y_GSW_train2 = df.loc[notGSW2, Y_stats]

X_SAS_train2 = df.loc[notSAS2, X_stats]
y_SAS_train2 = df.loc[notSAS2, Y_stats]

X_HOU_train2 = df.loc[notHOU2, X_stats]
y_HOU_train2 = df.loc[notHOU2, Y_stats]

X_LAC_train2 = df.loc[notLAC2, X_stats]
y_LAC_train2 = df.loc[notLAC2, Y_stats]

X_UTAH_train2 = df.loc[notUTAH2, X_stats]
y_UTAH_train2 = df.loc[notUTAH2, Y_stats]

X_OKC_train2 = df.loc[notOKC2, X_stats]
y_OKC_train2 = df.loc[notOKC2, Y_stats]

X_MEM_train2 = df.loc[notMEM2, X_stats]
y_MEM_train2 = df.loc[notMEM2, Y_stats]

X_POR_train2 = df.loc[notPOR2, X_stats]
y_POR_train2 = df.loc[notPOR2, Y_stats]

X_DEN_train2 = df.loc[notDEN2, X_stats]
y_DEN_train2 = df.loc[notDEN2, Y_stats]

X_NOP_train2 = df.loc[notNOP2, X_stats]
y_NOP_train2 = df.loc[notNOP2, Y_stats]

X_DAL_train2 = df.loc[notDAL2, X_stats]
y_DAL_train2 = df.loc[notDAL2, Y_stats]

X_SAC_train2 = df.loc[notSAC2, X_stats]
y_SAC_train2 = df.loc[notSAC2, Y_stats]

X_MIN_train2 = df.loc[notMIN2, X_stats]
y_MIN_train2 = df.loc[notMIN2, Y_stats]

X_LAL_train2 = df.loc[notLAL2, X_stats]
y_LAL_train2 = df.loc[notLAL2, Y_stats]

X_PHO_train2 = df.loc[notPHO2, X_stats]
y_PHO_train2 = df.loc[notPHO2, Y_stats]

X_BOS_train2 = df.loc[notBOS2, X_stats]
y_BOS_train2 = df.loc[notBOS2, Y_stats]

X_CLE_train2 = df.loc[notCLE2, X_stats]
y_CLE_train2 = df.loc[notCLE2, Y_stats]

X_TOR_train2 = df.loc[notTOR2, X_stats]
y_TOR_train2 = df.loc[notTOR2, Y_stats]

X_WAS_train2 = df.loc[notWAS2, X_stats]
y_WAS_train2 = df.loc[notWAS2, Y_stats]

X_ATL_train2 = df.loc[notPHO2, X_stats]
y_ATL_train2 = df.loc[notPHO2, Y_stats]

X_MIL_train2 = df.loc[notMIL2, X_stats]
y_MIL_train2 = df.loc[notMIL2, Y_stats]

X_IND_train2 = df.loc[notIND2, X_stats]
y_IND_train2 = df.loc[notIND2, Y_stats]

X_CHI_train2 = df.loc[notCHI2, X_stats]
y_CHI_train2 = df.loc[notCHI2, Y_stats]

X_MIA_train2 = df.loc[notMIA2, X_stats]
y_MIA_train2 = df.loc[notMIA2, Y_stats]

X_DET_train2 = df.loc[notDET2, X_stats]
y_DET_train2 = df.loc[notDET2, Y_stats]

X_CHA_train2 = df.loc[notCHA2, X_stats]
y_CHA_train2 = df.loc[notCHA2, Y_stats]

X_NYK_train2 = df.loc[notNYK2, X_stats]
y_NYK_train2 = df.loc[notNYK2, Y_stats]

X_ORL_train2 = df.loc[notORL2, X_stats]
y_ORL_train2 = df.loc[notORL2, Y_stats]

X_PHI_train2 = df.loc[notPHI2, X_stats]
y_PHI_train2 = df.loc[notPHI2, Y_stats]

X_BKN_train2 = df.loc[notBKN2, X_stats]
y_BKN_train2 = df.loc[notBKN2, Y_stats]

# %%
#scale features

from sklearn.preprocessing import StandardScaler

sc_GSW2 = StandardScaler()
X_GSW_train2 = sc_GSW2.fit_transform(X_GSW_train2)
X_GSW_data2 = sc_GSW2.transform(X_GSW_data2)

sc_SAS2 = StandardScaler()
X_SAS_train2 = sc_SAS2.fit_transform(X_SAS_train2)
X_SAS_data2 = sc_SAS2.transform(X_SAS_data2)

sc_HOU2 = StandardScaler()
X_HOU_train2 = sc_HOU2.fit_transform(X_HOU_train2)
X_HOU_data2 = sc_HOU2.transform(X_HOU_data2)

sc_LAC2 = StandardScaler()
X_LAC_train2 = sc_LAC2.fit_transform(X_LAC_train2)
X_LAC_data2 = sc_LAC.transform(X_LAC_data2)

sc_UTAH2 = StandardScaler()
X_UTAH_train2 = sc_UTAH2.fit_transform(X_UTAH_train2)
X_UTAH_data2 = sc_UTAH2.transform(X_UTAH_data2)

sc_OKC2 = StandardScaler()
X_OKC_train2 = sc_OKC2.fit_transform(X_OKC_train2)
X_OKC_data2 = sc_OKC2.transform(X_OKC_data2)

sc_MEM2 = StandardScaler()
X_MEM_train2 = sc_MEM2.fit_transform(X_MEM_train2)
X_MEM_data2 = sc_MEM.transform(X_MEM_data2)

sc_POR2 = StandardScaler()
X_POR_train2 = sc_POR2.fit_transform(X_POR_train2)
X_POR_data2 = sc_POR.transform(X_POR_data2)

sc_DEN2 = StandardScaler()
X_DEN_train2 = sc_DEN2.fit_transform(X_DEN_train2)
X_DEN_data2 = sc_DEN2.transform(X_DEN_data2)

sc_NOP2 = StandardScaler()
X_NOP_train2 = sc_NOP2.fit_transform(X_NOP_train2)
X_NOP_data2 = sc_NOP2.transform(X_NOP_data2)

sc_DAL2 = StandardScaler()
X_DAL_train2 = sc_DAL2.fit_transform(X_DAL_train2)
X_DAL_data2 = sc_DAL2.transform(X_DAL_data2)

sc_SAC2 = StandardScaler()
X_SAC_train2 = sc_SAC2.fit_transform(X_SAC_train2)
X_SAC_data2 = sc_SAC2.transform(X_SAC_data2)

sc_MIN2 = StandardScaler()
X_MIN_train2 = sc_MIN2.fit_transform(X_MIN_train2)
X_MIN_data2 = sc_MIN2.transform(X_MIN_data2)

sc_LAL2 = StandardScaler()
X_LAL_train2 = sc_LAL2.fit_transform(X_LAL_train2)
X_LAL_data2 = sc_LAL2.transform(X_LAL_data2)

sc_PHO2 = StandardScaler()
X_PHO_train2 = sc_PHO2.fit_transform(X_PHO_train2)
X_PHO_data2 = sc_PHO2.transform(X_PHO_data2)

sc_BOS2 = StandardScaler()
X_BOS_train2 = sc_BOS2.fit_transform(X_BOS_train2)
X_BOS_data2 = sc_BOS2.transform(X_BOS_data2)

sc_CLE2 = StandardScaler()
X_CLE_train2 = sc_CLE2.fit_transform(X_CLE_train2)
X_CLE_data2 = sc_CLE2.transform(X_CLE_data2)

sc_TOR2 = StandardScaler()
X_TOR_train2 = sc_TOR2.fit_transform(X_TOR_train2)
X_TOR_data2 = sc_TOR2.transform(X_TOR_data2)

sc_WAS2 = StandardScaler()
X_WAS_train2 = sc_WAS2.fit_transform(X_WAS_train2)
X_WAS_data2 = sc_WAS2.transform(X_WAS_data2)

sc_ATL2 = StandardScaler()
X_ATL_train2 = sc_ATL2.fit_transform(X_ATL_train2)
X_ATL_data2 = sc_ATL2.transform(X_ATL_data2)

sc_MIL2 = StandardScaler()
X_MIL_train2 = sc_MIL2.fit_transform(X_MIL_train2)
X_MIL_data2 = sc_MIL2.transform(X_MIL_data2)

sc_IND2 = StandardScaler()
X_IND_train2 = sc_IND2.fit_transform(X_IND_train2)
X_IND_data2 = sc_IND2.transform(X_IND_data2)

sc_CHI2 = StandardScaler()
X_CHI_train2 = sc_CHI2.fit_transform(X_CHI_train2)
X_CHI_data2 = sc_CHI2.transform(X_CHI_data2)

sc_MIA2 = StandardScaler()
X_MIA_train2 = sc_MIA2.fit_transform(X_MIA_train2)
X_MIA_data2 = sc_MIA2.transform(X_MIA_data2)

sc_DET2 = StandardScaler()
X_DET_train2 = sc_DET2.fit_transform(X_DET_train2)
X_DET_data2 = sc_DET2.transform(X_DET_data2)

sc_CHA2 = StandardScaler()
X_CHA_train2 = sc_CHA2.fit_transform(X_CHA_train2)
X_CHA_data2 = sc_CHA2.transform(X_CHA_data2)

sc_NYK2 = StandardScaler()
X_NYK_train2 = sc_NYK2.fit_transform(X_NYK_train2)
X_NYK_data2 = sc_NYK2.transform(X_NYK_data2)

sc_ORL2 = StandardScaler()
X_ORL_train2 = sc_ORL2.fit_transform(X_ORL_train2)
X_ORL_data2 = sc_ORL2.transform(X_ORL_data2)

sc_PHI2 = StandardScaler()
X_PHI_train2 = sc_PHI2.fit_transform(X_PHI_train2)
X_PHI_data2 = sc_PHI2.transform(X_PHI_data2)

sc_BKN2 = StandardScaler()
X_BKN_train2 = sc_BKN2.fit_transform(X_BKN_train2)
X_BKN_data2 = sc_BKN2.transform(X_BKN_data2)

# %%
from sklearn.ensemble import RandomForestRegressor

reg_GSW2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_GSW2.fit(X_GSW_train2, y_GSW_train2)
y_pred_GSW2 = reg_GSW2.predict(X_GSW_data2)

reg_SAS2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_SAS2.fit(X_SAS_train2, y_SAS_train2)
y_pred_SAS2 = reg_SAS2.predict(X_SAS_data2)

reg_HOU2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_HOU2.fit(X_HOU_train2, y_HOU_train2)
y_pred_HOU2 = reg_HOU2.predict(X_HOU_data2)

reg_LAC2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_LAC2.fit(X_LAC_train2, y_LAC_train2)
y_pred_LAC2 = reg_LAC2.predict(X_LAC_data2)

reg_UTAH2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_UTAH2.fit(X_UTAH_train2, y_UTAH_train2)
y_pred_UTAH2 = reg_UTAH2.predict(X_UTAH_data2)

reg_OKC2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_OKC2.fit(X_OKC_train2, y_OKC_train2)
y_pred_OKC2 = reg_OKC2.predict(X_OKC_data2)

reg_MEM2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_MEM2.fit(X_MEM_train2, y_MEM_train2)
y_pred_MEM2 = reg_MEM2.predict(X_MEM_data2)

reg_POR2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_POR2.fit(X_POR_train2, y_POR_train2)
y_pred_POR2 = reg_POR2.predict(X_POR_data2)

reg_DEN2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_DEN2.fit(X_DEN_train2, y_DEN_train2)
y_pred_DEN2 = reg_DEN2.predict(X_DEN_data2)

reg_NOP2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_NOP2.fit(X_NOP_train2, y_NOP_train2)
y_pred_NOP2 = reg_NOP2.predict(X_NOP_data2)

reg_DAL2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_DAL2.fit(X_DAL_train2, y_DAL_train2)
y_pred_DAL2 = reg_DAL2.predict(X_DAL_data2)

reg_SAC2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_SAC2.fit(X_SAC_train2, y_SAC_train2)
y_pred_SAC2 = reg_SAC2.predict(X_SAC_data2)

reg_MIN2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_MIN2.fit(X_MIN_train2, y_MIN_train2)
y_pred_MIN2 = reg_MIN2.predict(X_MIN_data2)

reg_LAL2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_LAL2.fit(X_LAL_train2, y_LAL_train2)
y_pred_LAL2 = reg_LAL2.predict(X_LAL_data2)

reg_PHO2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_PHO2.fit(X_PHO_train2, y_PHO_train2)
y_pred_PHO2 = reg_PHO2.predict(X_PHO_data2)

reg_BOS2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_BOS2.fit(X_BOS_train2, y_BOS_train2)
y_pred_BOS2 = reg_BOS2.predict(X_BOS_data2)

reg_CLE2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_CLE2.fit(X_CLE_train2, y_CLE_train2)
y_pred_CLE2 = reg_CLE2.predict(X_CLE_data2)

reg_TOR2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_TOR2.fit(X_TOR_train2, y_TOR_train2)
y_pred_TOR2 = reg_TOR2.predict(X_TOR_data2)

reg_WAS2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_WAS2.fit(X_WAS_train2, y_WAS_train2)
y_pred_WAS2 = reg_WAS2.predict(X_WAS_data2)

reg_ATL2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_ATL2.fit(X_ATL_train2, y_ATL_train2)
y_pred_ATL2 = reg_ATL2.predict(X_ATL_data2)

reg_MIL2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_MIL2.fit(X_MIL_train2, y_MIL_train2)
y_pred_MIL2 = reg_MIL2.predict(X_MIL_data2)

reg_IND2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_IND2.fit(X_IND_train2, y_IND_train2)
y_pred_IND2 = reg_IND2.predict(X_IND_data2)

reg_CHI2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_CHI2.fit(X_CHI_train2, y_CHI_train2)
y_pred_CHI2 = reg_CHI2.predict(X_CHI_data2)

reg_MIA2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_MIA2.fit(X_MIA_train2, y_MIA_train2)
y_pred_MIA2 = reg_MIA2.predict(X_MIA_data2)

reg_DET2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_DET2.fit(X_DET_train2, y_DET_train2)
y_pred_DET2 = reg_DET2.predict(X_DET_data2)

reg_CHA2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_CHA2.fit(X_CHA_train2, y_CHA_train2)
y_pred_CHA2 = reg_CHA2.predict(X_CHA_data2)

reg_NYK2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_NYK2.fit(X_NYK_train2, y_NYK_train2)
y_pred_NYK2 = reg_NYK2.predict(X_NYK_data2)

reg_ORL2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_ORL2.fit(X_ORL_train2, y_ORL_train2)
y_pred_ORL2 = reg_ORL2.predict(X_ORL_data2)

reg_PHI2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_PHI2.fit(X_PHI_train2, y_PHI_train2)
y_pred_PHI2 = reg_PHI2.predict(X_PHI_data2)

reg_BKN2 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_BKN2.fit(X_BKN_train2, y_BKN_train2)
y_pred_BKN2 = reg_BKN2.predict(X_BKN_data2)

# %%
#self accuracy

#since the prediction values are continuous, and the truth values are binary
#sklearn.metrics would print out an error of how the classification metrics
#can't handle a mix of binary and continuous targets, thus the accuracy
#will then be computed by 100 - percent error of the predicted and the actual

if y_GSW_data2.values.item(0) > 0:
  percent_error = abs((y_pred_GSW2.item(0) - y_GSW_data2.values.item(0)) / y_GSW_data2.values.item(0))
else:
  percent_error = abs((y_pred_GSW2.item(0) - y_GSW_data2.values.item(0)) / (y_GSW_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for GSW: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for GSW: 99.7%

# %%
if y_SAS_data2.values.item(0) > 0:
  percent_error = abs((y_pred_SAS2.item(0) - y_SAS_data2.values.item(0)) / y_SAS_data2.values.item(0))
else:
  percent_error = abs((y_pred_SAS2.item(0) - y_SAS_data2.values.item(0)) / (y_SAS_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for SAS: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for SAS: 99.6%

# %%
if y_HOU_data2.values.item(0) > 0:
  percent_error = abs((y_pred_HOU2.item(0) - y_HOU_data2.values.item(0)) / y_HOU_data2.values.item(0))
else:
  percent_error = abs((y_pred_HOU2.item(0) - y_HOU_data2.values.item(0)) / (y_HOU_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for HOU: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for HOU: 99.8%

# %%
if y_LAC_data2.values.item(0) > 0:
  percent_error = abs((y_pred_LAC2.item(0) - y_LAC_data2.values.item(0)) / y_LAC_data2.values.item(0))
else:
  percent_error = abs((y_pred_LAC2.item(0) - y_LAC_data2.values.item(0)) / (y_LAC_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for LAC: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for LAC: 99.7%

# %%
if y_UTAH_data2.values.item(0) > 0:
  percent_error = abs((y_pred_UTAH2.item(0) - y_UTAH_data2.values.item(0)) / y_UTAH_data2.values.item(0))
else:
  percent_error = abs((y_pred_UTAH2.item(0) - y_UTAH_data2.values.item(0)) / (y_UTAH_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for UTAH: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for UTAH: 99.7%

# %%
if y_OKC_data2.values.item(0) > 0:
  percent_error = abs((y_pred_OKC2.item(0) - y_OKC_data2.values.item(0)) / y_OKC_data2.values.item(0))
else:
  percent_error = abs((y_pred_OKC2.item(0) - y_OKC_data2.values.item(0)) / (y_OKC_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for OKC: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for OKC: 99.8%

# %%
if y_MEM_data2.values.item(0) > 0:
  percent_error = abs((y_pred_MEM2.item(0) - y_MEM_data2.values.item(0)) / y_MEM_data2.values.item(0))
else:
  percent_error = abs((y_pred_MEM2.item(0) - y_MEM_data2.values.item(0)) / (y_MEM_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for MEM: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for MEM: 99.75%

# %%
if y_POR_data2.values.item(0) > 0:
  percent_error = abs((y_pred_POR2.item(0) - y_POR_data2.values.item(0)) / y_POR_data2.values.item(0))
else:
  percent_error = abs((y_pred_POR2.item(0) - y_POR_data2.values.item(0)) / (y_POR_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for POR: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for POR: 99.1%

# %%
if y_DEN_data.values.item(0) > 0:
  percent_error = abs((y_pred_DEN.item(0) - y_DEN_data.values.item(0)) / y_DEN_data.values.item(0))
else:
  percent_error = abs((y_pred_DEN.item(0) - y_DEN_data.values.item(0)) / (y_DEN_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for DEN: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for DEN: 99.65%

# %%
if y_NOP_data2.values.item(0) > 0:
  percent_error = abs((y_pred_NOP2.item(0) - y_NOP_data2.values.item(0)) / y_NOP_data2.values.item(0))
else:
  percent_error = abs((y_pred_NOP2.item(0) - y_NOP_data2.values.item(0)) / (y_NOP_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for NOP: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for NOP: 99.5%

# %%
if y_DAL_data2.values.item(0) > 0:
  percent_error = abs((y_pred_DAL2.item(0) - y_DAL_data2.values.item(0)) / y_DAL_data2.values.item(0))
else:
  percent_error = abs((y_pred_DAL2.item(0) - y_DAL_data2.values.item(0)) / (y_DAL_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for DAL: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for DAL: 99.0%

# %%
if y_SAC_data2.values.item(0) > 0:
  percent_error = abs((y_pred_SAC2.item(0) - y_SAC_data2.values.item(0)) / y_SAC_data2.values.item(0))
else:
  percent_error = abs((y_pred_SAC2.item(0) - y_SAC_data2.values.item(0)) / (y_SAC_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for SAC: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for SAC: 99.95%

# %%
if y_MIN_data.values.item(0) > 0:
  percent_error = abs((y_pred_MIN.item(0) - y_MIN_data.values.item(0)) / y_MIN_data.values.item(0))
else:
  percent_error = abs((y_pred_MIN.item(0) - y_MIN_data.values.item(0)) / (y_MIN_data.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for MIN: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for MIN: 99.55%

# %%
if y_LAL_data2.values.item(0) > 0:
  percent_error = abs((y_pred_LAL2.item(0) - y_LAL_data2.values.item(0)) / y_LAL_data2.values.item(0))
else:
  percent_error = abs((y_pred_LAL2.item(0) - y_LAL_data2.values.item(0)) / (y_LAL_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for LAL: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for LAL: 99.3%

# %%
if y_PHO_data2.values.item(0) > 0:
  percent_error = abs((y_pred_PHO2.item(0) - y_PHO_data2.values.item(0)) / y_PHO_data2.values.item(0))
else:
  percent_error = abs((y_pred_PHO2.item(0) - y_PHO_data2.values.item(0)) / (y_PHO_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for PHO: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for PHO: 99.55%

# %%
if y_BOS_data2.values.item(0) > 0:
  percent_error = abs((y_pred_BOS2.item(0) - y_BOS_data2.values.item(0)) / y_BOS_data2.values.item(0))
else:
  percent_error = abs((y_pred_BOS2.item(0) - y_BOS_data2.values.item(0)) / (y_BOS_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for BOS: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for BOS: 99.4%

# %%
if y_CLE_data2.values.item(0) > 0:
  percent_error = abs((y_pred_CLE2.item(0) - y_CLE_data2.values.item(0)) / y_CLE_data2.values.item(0))
else:
  percent_error = abs((y_pred_CLE2.item(0) - y_CLE_data2.values.item(0)) / (y_CLE_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for CLE: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for CLE: 99.3%

# %%
if y_TOR_data2.values.item(0) > 0:
  percent_error = abs((y_pred_TOR2.item(0) - y_TOR_data2.values.item(0)) / y_TOR_data2.values.item(0))
else:
  percent_error = abs((y_pred_TOR2.item(0) - y_TOR_data2.values.item(0)) / (y_TOR_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for TOR: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for TOR: 99.6%

# %%
if y_WAS_data2.values.item(0) > 0:
  percent_error = abs((y_pred_WAS2.item(0) - y_WAS_data2.values.item(0)) / y_WAS_data2.values.item(0))
else:
  percent_error = abs((y_pred_WAS2.item(0) - y_WAS_data2.values.item(0)) / (y_WAS_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for WAS: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for WAS: 99.75%

# %%
if y_ATL_data2.values.item(0) > 0:
  percent_error = abs((y_pred_ATL2.item(0) - y_ATL_data2.values.item(0)) / y_ATL_data2.values.item(0))
else:
  percent_error = abs((y_pred_ATL2.item(0) - y_ATL_data2.values.item(0)) / (y_ATL_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for ATL: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for ATL: 99.85%

# %%
if y_MIL_data2.values.item(0) > 0:
  percent_error = abs((y_pred_MIL2.item(0) - y_MIL_data2.values.item(0)) / y_MIL_data2.values.item(0))
else:
  percent_error = abs((y_pred_MIL2.item(0) - y_MIL_data2.values.item(0)) / (y_MIL_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for MIL: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for MIL: 99.05%

# %%
if y_IND_data2.values.item(0) > 0:
  percent_error = abs((y_pred_IND2.item(0) - y_IND_data2.values.item(0)) / y_IND_data2.values.item(0))
else:
  percent_error = abs((y_pred_IND2.item(0) - y_IND_data2.values.item(0)) / (y_IND_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for IND: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for IND: 99.2%

# %%
if y_CHI_data2.values.item(0) > 0:
  percent_error = abs((y_pred_CHI2.item(0) - y_CHI_data2.values.item(0)) / y_CHI_data2.values.item(0))
else:
  percent_error = abs((y_pred_CHI2.item(0) - y_CHI_data2.values.item(0)) / (y_CHI_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for CHI: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for CHI: 99.15%

# %%
if y_MIA_data2.values.item(0) > 0:
  percent_error = abs((y_pred_MIA2.item(0) - y_MIA_data2.values.item(0)) / y_MIA_data2.values.item(0))
else:
  percent_error = abs((y_pred_MIA2.item(0) - y_MIA_data2.values.item(0)) / (y_MIA_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for MIA: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for MIA: 99.5%

# %%
if y_DET_data2.values.item(0) > 0:
  percent_error = abs((y_pred_DET2.item(0) - y_DET_data2.values.item(0)) / y_DET_data2.values.item(0))
else:
  percent_error = abs((y_pred_DET2.item(0) - y_DET_data2.values.item(0)) / (y_DET_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for DET: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for DET: 99.65%

# %%
if y_CHA_data2.values.item(0) > 0:
  percent_error = abs((y_pred_CHA2.item(0) - y_CHA_data2.values.item(0)) / y_CHA_data2.values.item(0))
else:
  percent_error = abs((y_pred_CHA2.item(0) - y_CHA_data2.values.item(0)) / (y_CHA_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for CHA: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for CHA: 99.8%

# %%
if y_NYK_data2.values.item(0) > 0:
  percent_error = abs((y_pred_NYK2.item(0) - y_NYK_data2.values.item(0)) / y_NYK_data2.values.item(0))
else:
  percent_error = abs((y_pred_NYK2.item(0) - y_NYK_data2.values.item(0)) / (y_NYK_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for NYK: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for NYK: 99.35%

# %%
if y_ORL_data2.values.item(0) > 0:
  percent_error = abs((y_pred_ORL2.item(0) - y_ORL_data2.values.item(0)) / y_ORL_data2.values.item(0))
else:
  percent_error = abs((y_pred_ORL2.item(0) - y_ORL_data2.values.item(0)) / (y_ORL_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for ORL: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for ORL: 99.55%

# %%
if y_PHI_data2.values.item(0) > 0:
  percent_error = abs((y_pred_PHI2.item(0) - y_PHI_data2.values.item(0)) / y_PHI_data2.values.item(0))
else:
  percent_error = abs((y_pred_PHI2.item(0) - y_PHI_data2.values.item(0)) / (y_PHI_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for PHI: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for PHI: 99.8%

# %%
if y_BKN_data2.values.item(0) > 0:
  percent_error = abs((y_pred_BKN2.item(0) - y_BKN_data2.values.item(0)) / y_BKN_data2.values.item(0))
else:
  percent_error = abs((y_pred_BKN2.item(0) - y_BKN_data2.values.item(0)) / (y_BKN_data2.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for BKN: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for BKN: 99.2%

# %%
west_dict = {
    "Golden State Warriors" : y_pred_GSW2.item(0),
    "San Antonio Spurs" : y_pred_SAS2.item(0),
    "Houston Rockets": y_pred_HOU2.item(0),
    "Los Angeles Clippers": y_pred_LAC2.item(0),
    "Utah Jazz" : y_pred_UTAH2.item(0),
    "Oklahoma City Thunder" : y_pred_OKC2.item(0),
    "Memphis Grizzlies" : y_pred_MEM2.item(0),
    "Portland Trailblazers" : y_pred_POR2.item(0),
    "Denver Nuggets" : y_pred_DEN2.item(0),
    "New Orleans Pelicans" : y_pred_NOP2.item(0),
    "Dallas Mavericks" : y_pred_DAL2.item(0),
    "Sacramento Kings" : y_pred_SAC2.item(0),
    "Minnesota Timberwolves" : y_pred_MIN2.item(0),
    "Los Angeles Lakers" : y_pred_LAL2.item(0),
    "Phoenix Suns" : y_pred_PHO2.item(0)
}

print("Making the Western Conference Playoffs:\n")

for a, b in west_dict.items():
  if b >= 0.5:
    print("%s will make the playoffs in the Western Conference!" % a)

east_dict = {
    "Boston Celtics" : y_pred_BOS2.item(0),
    "Cleveland Cavaliers" : y_pred_CLE2.item(0),
    "Toronto Raptors" : y_pred_TOR2.item(0),
    "Washington Wizards" : y_pred_WAS2.item(0),
    "Atlanta Hawks" : y_pred_ATL2.item(0),
    "Milwaukee Bucks" : y_pred_MIL2.item(0),
    "Indiana Pacers" : y_pred_IND2.item(0),
    "Chicago Bulls" : y_pred_CHI2.item(0),
    "Miami Heat" : y_pred_MIA2.item(0),
    "Detroit Pistons" : y_pred_DET2.item(0),
    "Charlotte Hornets" : y_pred_CHA2.item(0),
    "New York Knicks" : y_pred_NYK2.item(0),
    "Orlando Magic" : y_pred_ORL2.item(0),
    "Philadelphia 76ers" : y_pred_PHI2.item(0),
    "Brooklyn Nets" : y_pred_BKN2.item(0)
}

print("\nMaking the Eastern Conference Playoffs:\n")

for a, b in east_dict.items():
  if b >= 0.5:
    print("%s will make the playoffs in the Eastern Conference!" % a)
# Out:
# Making the Western Conference Playoffs:
#
# Golden State Warriors will make the playoffs in the Western Conference!
# San Antonio Spurs will make the playoffs in the Western Conference!
# Houston Rockets will make the playoffs in the Western Conference!
# Los Angeles Clippers will make the playoffs in the Western Conference!
# Oklahoma City Thunder will make the playoffs in the Western Conference!
# Memphis Grizzlies will make the playoffs in the Western Conference!
# Portland Trailblazers will make the playoffs in the Western Conference!
# Denver Nuggets will make the playoffs in the Western Conference!
# New Orleans Pelicans will make the playoffs in the Western Conference!
# Dallas Mavericks will make the playoffs in the Western Conference!
#
# Making the Eastern Conference Playoffs:
#
# Cleveland Cavaliers will make the playoffs in the Eastern Conference!
# Atlanta Hawks will make the playoffs in the Eastern Conference!
# ...

# %%
#set the data to be predicted for third quarter

X_GSW_data3 = df.loc[GSW3, X_stats]
y_GSW_data3 = df.loc[GSW3, Y_stats]

X_SAS_data3 = df.loc[SAS3, X_stats]
y_SAS_data3 = df.loc[SAS3, Y_stats]

X_HOU_data3 = df.loc[HOU3, X_stats]
y_HOU_data3 = df.loc[HOU3, Y_stats]

X_LAC_data3 = df.loc[LAC3, X_stats]
y_LAC_data3 = df.loc[LAC3, Y_stats]

X_UTAH_data3 = df.loc[UTAH3, X_stats]
y_UTAH_data3 = df.loc[UTAH3, Y_stats]

X_OKC_data3 = df.loc[OKC3, X_stats]
y_OKC_data3 = df.loc[OKC3, Y_stats]

X_MEM_data3 = df.loc[MEM3, X_stats]
y_MEM_data3 = df.loc[MEM3, Y_stats]

X_POR_data3 = df.loc[POR3, X_stats]
y_POR_data3 = df.loc[POR3, Y_stats]

X_DEN_data3 = df.loc[DEN3, X_stats]
y_DEN_data3 = df.loc[DEN3, Y_stats]

X_NOP_data3 = df.loc[NOP3, X_stats]
y_NOP_data3 = df.loc[NOP3, Y_stats]

X_DAL_data3 = df.loc[DAL3, X_stats]
y_DAL_data3 = df.loc[DAL3, Y_stats]

X_SAC_data3 = df.loc[SAC3, X_stats]
y_SAC_data3 = df.loc[SAC3, Y_stats]

X_MIN_data3 = df.loc[MIN3, X_stats]
y_MIN_data3 = df.loc[MIN3, Y_stats]

X_LAL_data3 = df.loc[LAL3, X_stats]
y_LAL_data3 = df.loc[LAL3, Y_stats]

X_PHO_data3 = df.loc[PHO3, X_stats]
y_PHO_data3 = df.loc[PHO3, Y_stats]

X_BOS_data3 = df.loc[BOS3, X_stats]
y_BOS_data3 = df.loc[BOS3, Y_stats]

X_CLE_data3 = df.loc[CLE3, X_stats]
y_CLE_data3 = df.loc[CLE3, Y_stats]

X_TOR_data3 = df.loc[TOR3, X_stats]
y_TOR_data3 = df.loc[TOR3, Y_stats]

X_WAS_data3 = df.loc[WAS3, X_stats]
y_WAS_data3 = df.loc[WAS3, Y_stats]

X_ATL_data3 = df.loc[ATL3, X_stats]
y_ATL_data3 = df.loc[ATL3, Y_stats]

X_MIL_data3 = df.loc[MIL3, X_stats]
y_MIL_data3 = df.loc[MIL3, Y_stats]

X_IND_data3 = df.loc[IND3, X_stats]
y_IND_data3 = df.loc[IND3, Y_stats]

X_CHI_data3 = df.loc[CHI3, X_stats]
y_CHI_data3 = df.loc[CHI3, Y_stats]

X_MIA_data3 = df.loc[MIA3, X_stats]
y_MIA_data3 = df.loc[MIA3, Y_stats]

X_DET_data3 = df.loc[DET3, X_stats]
y_DET_data3 = df.loc[DET3, Y_stats]

X_CHA_data3 = df.loc[CHA3, X_stats]
y_CHA_data3 = df.loc[CHA3, Y_stats]

X_NYK_data3 = df.loc[NYK3, X_stats]
y_NYK_data3 = df.loc[NYK3, Y_stats]

X_ORL_data3 = df.loc[ORL3, X_stats]
y_ORL_data3 = df.loc[ORL3, Y_stats]

X_PHI_data3 = df.loc[PHI3, X_stats]
y_PHI_data3 = df.loc[PHI3, Y_stats]

X_BKN_data3 = df.loc[BKN3, X_stats]
y_BKN_data3 = df.loc[BKN3, Y_stats]

# %%
#set the training dataset for third quarter of the season.
#this will not include the team itself

X_GSW_train3 = df.loc[notGSW3, X_stats]
y_GSW_train3 = df.loc[notGSW3, Y_stats]

X_SAS_train3 = df.loc[notSAS3, X_stats]
y_SAS_train3 = df.loc[notSAS3, Y_stats]

X_HOU_train3 = df.loc[notHOU3, X_stats]
y_HOU_train3 = df.loc[notHOU3, Y_stats]

X_LAC_train3 = df.loc[notLAC3, X_stats]
y_LAC_train3 = df.loc[notLAC3, Y_stats]

X_UTAH_train3 = df.loc[notUTAH3, X_stats]
y_UTAH_train3 = df.loc[notUTAH3, Y_stats]

X_OKC_train3 = df.loc[notOKC3, X_stats]
y_OKC_train3 = df.loc[notOKC3, Y_stats]

X_MEM_train3 = df.loc[notMEM3, X_stats]
y_MEM_train3 = df.loc[notMEM3, Y_stats]

X_POR_train3 = df.loc[notPOR3, X_stats]
y_POR_train3 = df.loc[notPOR3, Y_stats]

X_DEN_train3 = df.loc[notDEN3, X_stats]
y_DEN_train3 = df.loc[notDEN3, Y_stats]

X_NOP_train3 = df.loc[notNOP3, X_stats]
y_NOP_train3 = df.loc[notNOP3, Y_stats]

X_DAL_train3 = df.loc[notDAL3, X_stats]
y_DAL_train3 = df.loc[notDAL3, Y_stats]

X_SAC_train3 = df.loc[notSAC3, X_stats]
y_SAC_train3 = df.loc[notSAC3, Y_stats]

X_MIN_train3 = df.loc[notMIN3, X_stats]
y_MIN_train3 = df.loc[notMIN3, Y_stats]

X_LAL_train3 = df.loc[notLAL3, X_stats]
y_LAL_train3 = df.loc[notLAL3, Y_stats]

X_PHO_train3 = df.loc[notPHO3, X_stats]
y_PHO_train3 = df.loc[notPHO3, Y_stats]

X_BOS_train3 = df.loc[notBOS3, X_stats]
y_BOS_train3 = df.loc[notBOS3, Y_stats]

X_CLE_train3 = df.loc[notCLE3, X_stats]
y_CLE_train3 = df.loc[notCLE3, Y_stats]

X_TOR_train3 = df.loc[notTOR3, X_stats]
y_TOR_train3 = df.loc[notTOR3, Y_stats]

X_WAS_train3 = df.loc[notWAS3, X_stats]
y_WAS_train3 = df.loc[notWAS3, Y_stats]

X_ATL_train3 = df.loc[notPHO3, X_stats]
y_ATL_train3 = df.loc[notPHO3, Y_stats]

X_MIL_train3 = df.loc[notMIL3, X_stats]
y_MIL_train3 = df.loc[notMIL3, Y_stats]

X_IND_train3 = df.loc[notIND3, X_stats]
y_IND_train3 = df.loc[notIND3, Y_stats]

X_CHI_train3 = df.loc[notCHI3, X_stats]
y_CHI_train3 = df.loc[notCHI3, Y_stats]

X_MIA_train3 = df.loc[notMIA3, X_stats]
y_MIA_train3 = df.loc[notMIA3, Y_stats]

X_DET_train3 = df.loc[notDET3, X_stats]
y_DET_train3 = df.loc[notDET3, Y_stats]

X_CHA_train3 = df.loc[notCHA3, X_stats]
y_CHA_train3 = df.loc[notCHA3, Y_stats]

X_NYK_train3 = df.loc[notNYK3, X_stats]
y_NYK_train3 = df.loc[notNYK3, Y_stats]

X_ORL_train3 = df.loc[notORL3, X_stats]
y_ORL_train3 = df.loc[notORL3, Y_stats]

X_PHI_train3 = df.loc[notPHI3, X_stats]
y_PHI_train3 = df.loc[notPHI3, Y_stats]

X_BKN_train3 = df.loc[notBKN3, X_stats]
y_BKN_train3 = df.loc[notBKN3, Y_stats]

# %%
#scale features

from sklearn.preprocessing import StandardScaler

sc_GSW3 = StandardScaler()
X_GSW_train3 = sc_GSW3.fit_transform(X_GSW_train3)
X_GSW_data3 = sc_GSW3.transform(X_GSW_data3)

sc_SAS3 = StandardScaler()
X_SAS_train3 = sc_SAS3.fit_transform(X_SAS_train3)
X_SAS_data3 = sc_SAS3.transform(X_SAS_data3)

sc_HOU3 = StandardScaler()
X_HOU_train3 = sc_HOU3.fit_transform(X_HOU_train3)
X_HOU_data3 = sc_HOU3.transform(X_HOU_data3)

sc_LAC3 = StandardScaler()
X_LAC_train3 = sc_LAC3.fit_transform(X_LAC_train3)
X_LAC_data3 = sc_LAC3.transform(X_LAC_data3)

sc_UTAH3 = StandardScaler()
X_UTAH_train3 = sc_UTAH3.fit_transform(X_UTAH_train3)
X_UTAH_data3 = sc_UTAH3.transform(X_UTAH_data3)

sc_OKC3 = StandardScaler()
X_OKC_train3 = sc_OKC3.fit_transform(X_OKC_train3)
X_OKC_data3 = sc_OKC3.transform(X_OKC_data3)

sc_MEM3 = StandardScaler()
X_MEM_train3 = sc_MEM3.fit_transform(X_MEM_train3)
X_MEM_data3 = sc_MEM3.transform(X_MEM_data3)

sc_POR3 = StandardScaler()
X_POR_train3 = sc_POR3.fit_transform(X_POR_train3)
X_POR_data3 = sc_POR3.transform(X_POR_data3)

sc_DEN3 = StandardScaler()
X_DEN_train3 = sc_DEN3.fit_transform(X_DEN_train3)
X_DEN_data3 = sc_DEN3.transform(X_DEN_data3)

sc_NOP3 = StandardScaler()
X_NOP_train3 = sc_NOP3.fit_transform(X_NOP_train3)
X_NOP_data3 = sc_NOP3.transform(X_NOP_data3)

sc_DAL3 = StandardScaler()
X_DAL_train3 = sc_DAL3.fit_transform(X_DAL_train3)
X_DAL_data3 = sc_DAL3.transform(X_DAL_data3)

sc_SAC3 = StandardScaler()
X_SAC_train3 = sc_SAC3.fit_transform(X_SAC_train3)
X_SAC_data3 = sc_SAC3.transform(X_SAC_data3)

sc_MIN3 = StandardScaler()
X_MIN_train3 = sc_MIN3.fit_transform(X_MIN_train3)
X_MIN_data3 = sc_MIN3.transform(X_MIN_data3)

sc_LAL3 = StandardScaler()
X_LAL_train3 = sc_LAL3.fit_transform(X_LAL_train3)
X_LAL_data3 = sc_LAL3.transform(X_LAL_data3)

sc_PHO3 = StandardScaler()
X_PHO_train3 = sc_PHO3.fit_transform(X_PHO_train3)
X_PHO_data3 = sc_PHO3.transform(X_PHO_data3)

sc_BOS3 = StandardScaler()
X_BOS_train3 = sc_BOS3.fit_transform(X_BOS_train3)
X_BOS_data3 = sc_BOS3.transform(X_BOS_data3)

sc_CLE3 = StandardScaler()
X_CLE_train3 = sc_CLE3.fit_transform(X_CLE_train3)
X_CLE_data3 = sc_CLE3.transform(X_CLE_data3)

sc_TOR3 = StandardScaler()
X_TOR_train3 = sc_TOR3.fit_transform(X_TOR_train3)
X_TOR_data3 = sc_TOR3.transform(X_TOR_data3)

sc_WAS3 = StandardScaler()
X_WAS_train3 = sc_WAS3.fit_transform(X_WAS_train3)
X_WAS_data3 = sc_WAS3.transform(X_WAS_data3)

sc_ATL3 = StandardScaler()
X_ATL_train3 = sc_ATL3.fit_transform(X_ATL_train3)
X_ATL_data3 = sc_ATL3.transform(X_ATL_data3)

sc_MIL3 = StandardScaler()
X_MIL_train3 = sc_MIL3.fit_transform(X_MIL_train3)
X_MIL_data3 = sc_MIL3.transform(X_MIL_data3)

sc_IND3 = StandardScaler()
X_IND_train3 = sc_IND3.fit_transform(X_IND_train3)
X_IND_data3 = sc_IND3.transform(X_IND_data3)

sc_CHI3 = StandardScaler()
X_CHI_train3 = sc_CHI3.fit_transform(X_CHI_train3)
X_CHI_data3 = sc_CHI3.transform(X_CHI_data3)

sc_MIA3 = StandardScaler()
X_MIA_train3 = sc_MIA3.fit_transform(X_MIA_train3)
X_MIA_data3 = sc_MIA3.transform(X_MIA_data3)

sc_DET3 = StandardScaler()
X_DET_train3 = sc_DET3.fit_transform(X_DET_train3)
X_DET_data3 = sc_DET3.transform(X_DET_data3)

sc_CHA3 = StandardScaler()
X_CHA_train3 = sc_CHA3.fit_transform(X_CHA_train3)
X_CHA_data3 = sc_CHA3.transform(X_CHA_data3)

sc_NYK3 = StandardScaler()
X_NYK_train3 = sc_NYK3.fit_transform(X_NYK_train3)
X_NYK_data3 = sc_NYK3.transform(X_NYK_data3)

sc_ORL3 = StandardScaler()
X_ORL_train3 = sc_ORL3.fit_transform(X_ORL_train3)
X_ORL_data3 = sc_ORL3.transform(X_ORL_data3)

sc_PHI3 = StandardScaler()
X_PHI_train3 = sc_PHI3.fit_transform(X_PHI_train3)
X_PHI_data3 = sc_PHI3.transform(X_PHI_data3)

sc_BKN3 = StandardScaler()
X_BKN_train3 = sc_BKN3.fit_transform(X_BKN_train3)
X_BKN_data3 = sc_BKN3.transform(X_BKN_data3)

# %%
reg_GSW3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_GSW3.fit(X_GSW_train3, y_GSW_train3)
y_pred_GSW3 = reg_GSW3.predict(X_GSW_data3)

reg_SAS3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_SAS3.fit(X_SAS_train3, y_SAS_train3)
y_pred_SAS3 = reg_SAS3.predict(X_SAS_data3)

reg_HOU3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_HOU3.fit(X_HOU_train3, y_HOU_train3)
y_pred_HOU3 = reg_HOU3.predict(X_HOU_data3)

reg_LAC3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_LAC3.fit(X_LAC_train3, y_LAC_train3)
y_pred_LAC3 = reg_LAC3.predict(X_LAC_data3)

reg_UTAH3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_UTAH3.fit(X_UTAH_train3, y_UTAH_train3)
y_pred_UTAH3 = reg_UTAH3.predict(X_UTAH_data3)

reg_OKC3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_OKC3.fit(X_OKC_train3, y_OKC_train3)
y_pred_OKC3 = reg_OKC3.predict(X_OKC_data3)

reg_MEM3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_MEM3.fit(X_MEM_train3, y_MEM_train3)
y_pred_MEM3 = reg_MEM3.predict(X_MEM_data3)

reg_POR3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_POR3.fit(X_POR_train3, y_POR_train3)
y_pred_POR3 = reg_POR3.predict(X_POR_data3)

reg_DEN3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_DEN3.fit(X_DEN_train3, y_DEN_train3)
y_pred_DEN3 = reg_DEN3.predict(X_DEN_data3)

reg_NOP3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_NOP3.fit(X_NOP_train3, y_NOP_train3)
y_pred_NOP3 = reg_NOP3.predict(X_NOP_data3)

reg_DAL3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_DAL3.fit(X_DAL_train3, y_DAL_train3)
y_pred_DAL3 = reg_DAL3.predict(X_DAL_data3)

reg_SAC3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_SAC3.fit(X_SAC_train3, y_SAC_train3)
y_pred_SAC3 = reg_SAC3.predict(X_SAC_data3)

reg_MIN3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_MIN3.fit(X_MIN_train3, y_MIN_train3)
y_pred_MIN3 = reg_MIN3.predict(X_MIN_data3)

reg_LAL3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_LAL3.fit(X_LAL_train3, y_LAL_train3)
y_pred_LAL3 = reg_LAL3.predict(X_LAL_data3)

reg_PHO3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_PHO3.fit(X_PHO_train3, y_PHO_train3)
y_pred_PHO3 = reg_PHO3.predict(X_PHO_data3)

reg_BOS3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_BOS3.fit(X_BOS_train3, y_BOS_train3)
y_pred_BOS3 = reg_BOS3.predict(X_BOS_data3)

reg_CLE3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_CLE3.fit(X_CLE_train3, y_CLE_train3)
y_pred_CLE3 = reg_CLE3.predict(X_CLE_data3)

reg_TOR3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_TOR3.fit(X_TOR_train3, y_TOR_train3)
y_pred_TOR3 = reg_TOR3.predict(X_TOR_data3)

reg_WAS3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_WAS3.fit(X_WAS_train3, y_WAS_train3)
y_pred_WAS3 = reg_WAS3.predict(X_WAS_data3)

reg_ATL3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_ATL3.fit(X_ATL_train3, y_ATL_train3)
y_pred_ATL3 = reg_ATL3.predict(X_ATL_data3)

reg_MIL3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_MIL3.fit(X_MIL_train3, y_MIL_train3)
y_pred_MIL3 = reg_MIL3.predict(X_MIL_data3)

reg_IND3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_IND3.fit(X_IND_train3, y_IND_train3)
y_pred_IND3 = reg_IND3.predict(X_IND_data3)

reg_CHI3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_CHI3.fit(X_CHI_train3, y_CHI_train3)
y_pred_CHI3 = reg_CHI3.predict(X_CHI_data3)

reg_MIA3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_MIA3.fit(X_MIA_train3, y_MIA_train3)
y_pred_MIA3 = reg_MIA3.predict(X_MIA_data3)

reg_DET3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_DET3.fit(X_DET_train3, y_DET_train3)
y_pred_DET3 = reg_DET3.predict(X_DET_data3)

reg_CHA3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_CHA3.fit(X_CHA_train3, y_CHA_train3)
y_pred_CHA3 = reg_CHA3.predict(X_CHA_data3)

reg_NYK3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_NYK3.fit(X_NYK_train3, y_NYK_train3)
y_pred_NYK3 = reg_NYK3.predict(X_NYK_data3)

reg_ORL3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_ORL3.fit(X_ORL_train3, y_ORL_train3)
y_pred_ORL3 = reg_ORL3.predict(X_ORL_data3)

reg_PHI3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_PHI3.fit(X_PHI_train3, y_PHI_train3)
y_pred_PHI3 = reg_PHI3.predict(X_PHI_data3)

reg_BKN3 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_BKN3.fit(X_BKN_train3, y_BKN_train3)
y_pred_BKN3 = reg_BKN3.predict(X_BKN_data3)

# %%
#self accuracy

#since the prediction values are continuous, and the truth values are binary
#sklearn.metrics would print out an error of how the classification metrics
#can't handle a mix of binary and continuous targets, thus the accuracy
#will then be computed by 100 - percent error of the predicted and the actual

if y_GSW_data3.values.item(0) > 0:
  percent_error = abs((y_pred_GSW3.item(0) - y_GSW_data3.values.item(0)) / y_GSW_data3.values.item(0))
else:
  percent_error = abs((y_pred_GSW3.item(0) - y_GSW_data3.values.item(0)) / (y_GSW_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for GSW: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for GSW: 99.8%

# %%
if y_SAS_data3.values.item(0) > 0:
  percent_error = abs((y_pred_SAS3.item(0) - y_SAS_data3.values.item(0)) / y_SAS_data3.values.item(0))
else:
  percent_error = abs((y_pred_SAS3.item(0) - y_SAS_data3.values.item(0)) / (y_SAS_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for SAS: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for SAS: 99.6%

# %%
if y_HOU_data3.values.item(0) > 0:
  percent_error = abs((y_pred_HOU3.item(0) - y_HOU_data3.values.item(0)) / y_HOU_data3.values.item(0))
else:
  percent_error = abs((y_pred_HOU3.item(0) - y_HOU_data3.values.item(0)) / (y_HOU_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for HOU: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for HOU: 99.65%

# %%
if y_LAC_data3.values.item(0) > 0:
  percent_error = abs((y_pred_LAC3.item(0) - y_LAC_data3.values.item(0)) / y_LAC_data3.values.item(0))
else:
  percent_error = abs((y_pred_LAC3.item(0) - y_LAC_data3.values.item(0)) / (y_LAC_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for LAC: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for LAC: 99.7%

# %%
if y_UTAH_data3.values.item(0) > 0:
  percent_error = abs((y_pred_UTAH3.item(0) - y_UTAH_data3.values.item(0)) / y_UTAH_data3.values.item(0))
else:
  percent_error = abs((y_pred_UTAH3.item(0) - y_UTAH_data3.values.item(0)) / (y_UTAH_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for UTAH: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for UTAH: 99.65%

# %%
if y_OKC_data3.values.item(0) > 0:
  percent_error = abs((y_pred_OKC3.item(0) - y_OKC_data3.values.item(0)) / y_OKC_data3.values.item(0))
else:
  percent_error = abs((y_pred_OKC3.item(0) - y_OKC_data3.values.item(0)) / (y_OKC_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for OKC: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for OKC: 99.85%

# %%
if y_MEM_data3.values.item(0) > 0:
  percent_error = abs((y_pred_MEM3.item(0) - y_MEM_data3.values.item(0)) / y_MEM_data3.values.item(0))
else:
  percent_error = abs((y_pred_MEM3.item(0) - y_MEM_data3.values.item(0)) / (y_MEM_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for MEM: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for MEM: 99.35%

# %%
if y_POR_data3.values.item(0) > 0:
  percent_error = abs((y_pred_POR3.item(0) - y_POR_data3.values.item(0)) / y_POR_data3.values.item(0))
else:
  percent_error = abs((y_pred_POR3.item(0) - y_POR_data3.values.item(0)) / (y_POR_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for POR: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for POR: 99.4%

# %%
if y_DEN_data3.values.item(0) > 0:
  percent_error = abs((y_pred_DEN3.item(0) - y_DEN_data3.values.item(0)) / y_DEN_data3.values.item(0))
else:
  percent_error = abs((y_pred_DEN3.item(0) - y_DEN_data3.values.item(0)) / (y_DEN_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for DEN: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for DEN: 99.05%

# %%
if y_NOP_data3.values.item(0) > 0:
  percent_error = abs((y_pred_NOP3.item(0) - y_NOP_data3.values.item(0)) / y_NOP_data3.values.item(0))
else:
  percent_error = abs((y_pred_NOP3.item(0) - y_NOP_data3.values.item(0)) / (y_NOP_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for NOP: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for NOP: 99.75%

# %%
if y_DAL_data3.values.item(0) > 0:
  percent_error = abs((y_pred_DAL3.item(0) - y_DAL_data3.values.item(0)) / y_DAL_data3.values.item(0))
else:
  percent_error = abs((y_pred_DAL3.item(0) - y_DAL_data3.values.item(0)) / (y_DAL_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for DAL: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for DAL: 99.15%

# %%
if y_SAC_data3.values.item(0) > 0:
  percent_error = abs((y_pred_SAC3.item(0) - y_SAC_data3.values.item(0)) / y_SAC_data3.values.item(0))
else:
  percent_error = abs((y_pred_SAC3.item(0) - y_SAC_data3.values.item(0)) / (y_SAC_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for SAC: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for SAC: 99.45%

# %%
if y_MIN_data3.values.item(0) > 0:
  percent_error = abs((y_pred_MIN3.item(0) - y_MIN_data3.values.item(0)) / y_MIN_data3.values.item(0))
else:
  percent_error = abs((y_pred_MIN3.item(0) - y_MIN_data3.values.item(0)) / (y_MIN_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for MIN: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for MIN: 99.7%

# %%
if y_LAL_data3.values.item(0) > 0:
  percent_error = abs((y_pred_LAL3.item(0) - y_LAL_data3.values.item(0)) / y_LAL_data3.values.item(0))
else:
  percent_error = abs((y_pred_LAL3.item(0) - y_LAL_data3.values.item(0)) / (y_LAL_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for LAL: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for LAL: 99.95%

# %%
if y_PHO_data3.values.item(0) > 0:
  percent_error = abs((y_pred_PHO3.item(0) - y_PHO_data3.values.item(0)) / y_PHO_data3.values.item(0))
else:
  percent_error = abs((y_pred_PHO3.item(0) - y_PHO_data3.values.item(0)) / (y_PHO_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for PHO: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for PHO: 99.6%

# %%
if y_BOS_data3.values.item(0) > 0:
  percent_error = abs((y_pred_BOS3.item(0) - y_BOS_data3.values.item(0)) / y_BOS_data3.values.item(0))
else:
  percent_error = abs((y_pred_BOS3.item(0) - y_BOS_data3.values.item(0)) / (y_BOS_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for BOS: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for BOS: 99.15%

# %%
if y_CLE_data3.values.item(0) > 0:
  percent_error = abs((y_pred_CLE3.item(0) - y_CLE_data3.values.item(0)) / y_CLE_data3.values.item(0))
else:
  percent_error = abs((y_pred_CLE3.item(0) - y_CLE_data3.values.item(0)) / (y_CLE_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for CLE: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for CLE: 99.8%

# %%
if y_TOR_data3.values.item(0) > 0:
  percent_error = abs((y_pred_TOR3.item(0) - y_TOR_data3.values.item(0)) / y_TOR_data3.values.item(0))
else:
  percent_error = abs((y_pred_TOR3.item(0) - y_TOR_data3.values.item(0)) / (y_TOR_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for TOR: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for TOR: 99.3%

# %%
if y_WAS_data3.values.item(0) > 0:
  percent_error = abs((y_pred_WAS3.item(0) - y_WAS_data3.values.item(0)) / y_WAS_data3.values.item(0))
else:
  percent_error = abs((y_pred_WAS3.item(0) - y_WAS_data3.values.item(0)) / (y_WAS_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for WAS: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for WAS: 99.3%

# %%
if y_ATL_data3.values.item(0) > 0:
  percent_error = abs((y_pred_ATL3.item(0) - y_ATL_data3.values.item(0)) / y_ATL_data3.values.item(0))
else:
  percent_error = abs((y_pred_ATL3.item(0) - y_ATL_data3.values.item(0)) / (y_ATL_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for ATL: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for ATL: 99.75%

# %%
if y_MIL_data3.values.item(0) > 0:
  percent_error = abs((y_pred_MIL3.item(0) - y_MIL_data3.values.item(0)) / y_MIL_data3.values.item(0))
else:
  percent_error = abs((y_pred_MIL3.item(0) - y_MIL_data3.values.item(0)) / (y_MIL_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for MIL: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for MIL: 99.35%

# %%
if y_IND_data3.values.item(0) > 0:
  percent_error = abs((y_pred_IND3.item(0) - y_IND_data3.values.item(0)) / y_IND_data3.values.item(0))
else:
  percent_error = abs((y_pred_IND3.item(0) - y_IND_data3.values.item(0)) / (y_IND_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for IND: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for IND: 99.5%

# %%
if y_CHI_data3.values.item(0) > 0:
  percent_error = abs((y_pred_CHI3.item(0) - y_CHI_data3.values.item(0)) / y_CHI_data3.values.item(0))
else:
  percent_error = abs((y_pred_CHI3.item(0) - y_CHI_data3.values.item(0)) / (y_CHI_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for CHI: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for CHI: 99.65%

# %%
if y_MIA_data3.values.item(0) > 0:
  percent_error = abs((y_pred_MIA3.item(0) - y_MIA_data3.values.item(0)) / y_MIA_data3.values.item(0))
else:
  percent_error = abs((y_pred_MIA3.item(0) - y_MIA_data3.values.item(0)) / (y_MIA_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for MIA: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for MIA: 99.5%

# %%
if y_DET_data3.values.item(0) > 0:
  percent_error = abs((y_pred_DET3.item(0) - y_DET_data3.values.item(0)) / y_DET_data3.values.item(0))
else:
  percent_error = abs((y_pred_DET3.item(0) - y_DET_data3.values.item(0)) / (y_DET_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for DET: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for DET: 99.85%

# %%
if y_CHA_data3.values.item(0) > 0:
  percent_error = abs((y_pred_CHA3.item(0) - y_CHA_data3.values.item(0)) / y_CHA_data3.values.item(0))
else:
  percent_error = abs((y_pred_CHA3.item(0) - y_CHA_data3.values.item(0)) / (y_CHA_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for CHA: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for CHA: 99.55%

# %%
if y_NYK_data3.values.item(0) > 0:
  percent_error = abs((y_pred_NYK3.item(0) - y_NYK_data3.values.item(0)) / y_NYK_data3.values.item(0))
else:
  percent_error = abs((y_pred_NYK3.item(0) - y_NYK_data3.values.item(0)) / (y_NYK_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for NYK: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for NYK: 99.7%

# %%
if y_ORL_data3.values.item(0) > 0:
  percent_error = abs((y_pred_ORL3.item(0) - y_ORL_data3.values.item(0)) / y_ORL_data3.values.item(0))
else:
  percent_error = abs((y_pred_ORL3.item(0) - y_ORL_data3.values.item(0)) / (y_ORL_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for ORL: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for ORL: 99.95%

# %%
if y_PHI_data3.values.item(0) > 0:
  percent_error = abs((y_pred_PHI3.item(0) - y_PHI_data3.values.item(0)) / y_PHI_data3.values.item(0))
else:
  percent_error = abs((y_pred_PHI3.item(0) - y_PHI_data3.values.item(0)) / (y_PHI_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for PHI: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for PHI: 99.35%

# %%
if y_BKN_data3.values.item(0) > 0:
  percent_error = abs((y_pred_BKN3.item(0) - y_BKN_data3.values.item(0)) / y_BKN_data3.values.item(0))
else:
  percent_error = abs((y_pred_BKN3.item(0) - y_BKN_data3.values.item(0)) / (y_BKN_data3.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for BKN: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for BKN: 99.35%

# %%
west_dict = {
    "Golden State Warriors" : y_pred_GSW3.item(0),
    "San Antonio Spurs" : y_pred_SAS3.item(0),
    "Houston Rockets": y_pred_HOU3.item(0),
    "Los Angeles Clippers": y_pred_LAC3.item(0),
    "Utah Jazz" : y_pred_UTAH3.item(0),
    "Oklahoma City Thunder" : y_pred_OKC3.item(0),
    "Memphis Grizzlies" : y_pred_MEM3.item(0),
    "Portland Trailblazers" : y_pred_POR3.item(0),
    "Denver Nuggets" : y_pred_DEN3.item(0),
    "New Orleans Pelicans" : y_pred_NOP3.item(0),
    "Dallas Mavericks" : y_pred_DAL3.item(0),
    "Sacramento Kings" : y_pred_SAC3.item(0),
    "Minnesota Timberwolves" : y_pred_MIN3.item(0),
    "Los Angeles Lakers" : y_pred_LAL3.item(0),
    "Phoenix Suns" : y_pred_PHO3.item(0)
}

print("Making the Western Conference Playoffs:\n")

for a, b in west_dict.items():
  if b >= 0.5:
    print("%s will make the playoffs in the Western Conference!" % a)

east_dict = {
    "Boston Celtics" : y_pred_BOS3.item(0),
    "Cleveland Cavaliers" : y_pred_CLE3.item(0),
    "Toronto Raptors" : y_pred_TOR3.item(0),
    "Washington Wizards" : y_pred_WAS3.item(0),
    "Atlanta Hawks" : y_pred_ATL3.item(0),
    "Milwaukee Bucks" : y_pred_MIL3.item(0),
    "Indiana Pacers" : y_pred_IND3.item(0),
    "Chicago Bulls" : y_pred_CHI3.item(0),
    "Miami Heat" : y_pred_MIA3.item(0),
    "Detroit Pistons" : y_pred_DET3.item(0),
    "Charlotte Hornets" : y_pred_CHA3.item(0),
    "New York Knicks" : y_pred_NYK3.item(0),
    "Orlando Magic" : y_pred_ORL3.item(0),
    "Philadelphia 76ers" : y_pred_PHI3.item(0),
    "Brooklyn Nets" : y_pred_BKN3.item(0)
}

print("\nMaking the Eastern Conference Playoffs:\n")

for a, b in east_dict.items():
  if b >= 0.5:
    print("%s will make the playoffs in the Eastern Conference!" % a)
# Out:
# Making the Western Conference Playoffs:
#
# Golden State Warriors will make the playoffs in the Western Conference!
# San Antonio Spurs will make the playoffs in the Western Conference!
# Houston Rockets will make the playoffs in the Western Conference!
# Los Angeles Clippers will make the playoffs in the Western Conference!
# Oklahoma City Thunder will make the playoffs in the Western Conference!
# Portland Trailblazers will make the playoffs in the Western Conference!
# Dallas Mavericks will make the playoffs in the Western Conference!
# Sacramento Kings will make the playoffs in the Western Conference!
# Los Angeles Lakers will make the playoffs in the Western Conference!
#
# Making the Eastern Conference Playoffs:
#
# Toronto Raptors will make the playoffs in the Eastern Conference!
# Washington Wizards will make the playoffs in the Eastern Conference!
# Atlanta Hawks will make the playoffs in the Eastern Conference!
# ...

# %%
#set the data to be predicted for fourth quarter

X_GSW_data4 = df.loc[GSW4, X_stats]
y_GSW_data4 = df.loc[GSW4, Y_stats]

X_SAS_data4 = df.loc[SAS4, X_stats]
y_SAS_data4 = df.loc[SAS4, Y_stats]

X_HOU_data4 = df.loc[HOU4, X_stats]
y_HOU_data4 = df.loc[HOU4, Y_stats]

X_LAC_data4 = df.loc[LAC4, X_stats]
y_LAC_data4 = df.loc[LAC4, Y_stats]

X_UTAH_data4 = df.loc[UTAH4, X_stats]
y_UTAH_data4 = df.loc[UTAH4, Y_stats]

X_OKC_data4 = df.loc[OKC4, X_stats]
y_OKC_data4 = df.loc[OKC4, Y_stats]

X_MEM_data4 = df.loc[MEM4, X_stats]
y_MEM_data4 = df.loc[MEM4, Y_stats]

X_POR_data4 = df.loc[POR4, X_stats]
y_POR_data4 = df.loc[POR4, Y_stats]

X_DEN_data4 = df.loc[DEN4, X_stats]
y_DEN_data4 = df.loc[DEN4, Y_stats]

X_NOP_data4 = df.loc[NOP4, X_stats]
y_NOP_data4 = df.loc[NOP4, Y_stats]

X_DAL_data4 = df.loc[DAL4, X_stats]
y_DAL_data4 = df.loc[DAL4, Y_stats]

X_SAC_data4 = df.loc[SAC4, X_stats]
y_SAC_data4 = df.loc[SAC4, Y_stats]

X_MIN_data4 = df.loc[MIN4, X_stats]
y_MIN_data4 = df.loc[MIN4, Y_stats]

X_LAL_data4 = df.loc[LAL4, X_stats]
y_LAL_data4 = df.loc[LAL4, Y_stats]

X_PHO_data4 = df.loc[PHO4, X_stats]
y_PHO_data4 = df.loc[PHO4, Y_stats]

X_BOS_data4 = df.loc[BOS4, X_stats]
y_BOS_data4 = df.loc[BOS4, Y_stats]

X_CLE_data4 = df.loc[CLE4, X_stats]
y_CLE_data4 = df.loc[CLE4, Y_stats]

X_TOR_data4 = df.loc[TOR4, X_stats]
y_TOR_data4 = df.loc[TOR4, Y_stats]

X_WAS_data4 = df.loc[WAS4, X_stats]
y_WAS_data4 = df.loc[WAS4, Y_stats]

X_ATL_data4 = df.loc[ATL4, X_stats]
y_ATL_data4 = df.loc[ATL4, Y_stats]

X_MIL_data4 = df.loc[MIL4, X_stats]
y_MIL_data4 = df.loc[MIL4, Y_stats]

X_IND_data4 = df.loc[IND4, X_stats]
y_IND_data4 = df.loc[IND4, Y_stats]

X_CHI_data4 = df.loc[CHI4, X_stats]
y_CHI_data4 = df.loc[CHI4, Y_stats]

X_MIA_data4 = df.loc[MIA4, X_stats]
y_MIA_data4 = df.loc[MIA4, Y_stats]

X_DET_data4 = df.loc[DET4, X_stats]
y_DET_data4 = df.loc[DET4, Y_stats]

X_CHA_data4 = df.loc[CHA4, X_stats]
y_CHA_data4 = df.loc[CHA4, Y_stats]

X_NYK_data4 = df.loc[NYK4, X_stats]
y_NYK_data4 = df.loc[NYK4, Y_stats]

X_ORL_data4 = df.loc[ORL4, X_stats]
y_ORL_data4 = df.loc[ORL4, Y_stats]

X_PHI_data4 = df.loc[PHI4, X_stats]
y_PHI_data4 = df.loc[PHI4, Y_stats]

X_BKN_data4 = df.loc[BKN4, X_stats]
y_BKN_data4 = df.loc[BKN4, Y_stats]

# %%
#set the training dataset for first half of the season.
#this will not include the team itself

X_GSW_train4 = df.loc[notGSW4, X_stats]
y_GSW_train4 = df.loc[notGSW4, Y_stats]

X_SAS_train4 = df.loc[notSAS4, X_stats]
y_SAS_train4 = df.loc[notSAS4, Y_stats]

X_HOU_train4 = df.loc[notHOU4, X_stats]
y_HOU_train4 = df.loc[notHOU4, Y_stats]

X_LAC_train4 = df.loc[notLAC4, X_stats]
y_LAC_train4 = df.loc[notLAC4, Y_stats]

X_UTAH_train4 = df.loc[notUTAH4, X_stats]
y_UTAH_train4 = df.loc[notUTAH4, Y_stats]

X_OKC_train4 = df.loc[notOKC4, X_stats]
y_OKC_train4 = df.loc[notOKC4, Y_stats]

X_MEM_train4 = df.loc[notMEM4, X_stats]
y_MEM_train4 = df.loc[notMEM4, Y_stats]

X_POR_train4 = df.loc[notPOR4, X_stats]
y_POR_train4 = df.loc[notPOR4, Y_stats]

X_DEN_train4 = df.loc[notDEN4, X_stats]
y_DEN_train4 = df.loc[notDEN4, Y_stats]

X_NOP_train4 = df.loc[notNOP4, X_stats]
y_NOP_train4 = df.loc[notNOP4, Y_stats]

X_DAL_train4 = df.loc[notDAL4, X_stats]
y_DAL_train4 = df.loc[notDAL4, Y_stats]

X_SAC_train4 = df.loc[notSAC4, X_stats]
y_SAC_train4 = df.loc[notSAC4, Y_stats]

X_MIN_train4 = df.loc[notMIN4, X_stats]
y_MIN_train4 = df.loc[notMIN4, Y_stats]

X_LAL_train4 = df.loc[notLAL4, X_stats]
y_LAL_train4 = df.loc[notLAL4, Y_stats]

X_PHO_train4 = df.loc[notPHO4, X_stats]
y_PHO_train4 = df.loc[notPHO4, Y_stats]

X_BOS_train4 = df.loc[notBOS4, X_stats]
y_BOS_train4 = df.loc[notBOS4, Y_stats]

X_CLE_train4 = df.loc[notCLE4, X_stats]
y_CLE_train4 = df.loc[notCLE4, Y_stats]

X_TOR_train4 = df.loc[notTOR4, X_stats]
y_TOR_train4 = df.loc[notTOR4, Y_stats]

X_WAS_train4 = df.loc[notWAS4, X_stats]
y_WAS_train4 = df.loc[notWAS4, Y_stats]

X_ATL_train4 = df.loc[notPHO4, X_stats]
y_ATL_train4 = df.loc[notPHO4, Y_stats]

X_MIL_train4 = df.loc[notMIL4, X_stats]
y_MIL_train4 = df.loc[notMIL4, Y_stats]

X_IND_train4 = df.loc[notIND4, X_stats]
y_IND_train4 = df.loc[notIND4, Y_stats]

X_CHI_train4 = df.loc[notCHI4, X_stats]
y_CHI_train4 = df.loc[notCHI4, Y_stats]

X_MIA_train4 = df.loc[notMIA4, X_stats]
y_MIA_train4 = df.loc[notMIA4, Y_stats]

X_DET_train4 = df.loc[notDET4, X_stats]
y_DET_train4 = df.loc[notDET4, Y_stats]

X_CHA_train4 = df.loc[notCHA4, X_stats]
y_CHA_train4 = df.loc[notCHA4, Y_stats]

X_NYK_train4 = df.loc[notNYK4, X_stats]
y_NYK_train4 = df.loc[notNYK4, Y_stats]

X_ORL_train4 = df.loc[notORL4, X_stats]
y_ORL_train4 = df.loc[notORL4, Y_stats]

X_PHI_train4 = df.loc[notPHI4, X_stats]
y_PHI_train4 = df.loc[notPHI4, Y_stats]

X_BKN_train4 = df.loc[notBKN4, X_stats]
y_BKN_train4 = df.loc[notBKN4, Y_stats]

# %%
#scale features

from sklearn.preprocessing import StandardScaler

sc_GSW4 = StandardScaler()
X_GSW_train4 = sc_GSW4.fit_transform(X_GSW_train4)
X_GSW_data4 = sc_GSW4.transform(X_GSW_data4)

sc_SAS4 = StandardScaler()
X_SAS_train4 = sc_SAS4.fit_transform(X_SAS_train4)
X_SAS_data4 = sc_SAS4.transform(X_SAS_data4)

sc_HOU4 = StandardScaler()
X_HOU_train4 = sc_HOU4.fit_transform(X_HOU_train4)
X_HOU_data4 = sc_HOU4.transform(X_HOU_data4)

sc_LAC4 = StandardScaler()
X_LAC_train4 = sc_LAC4.fit_transform(X_LAC_train4)
X_LAC_data4 = sc_LAC4.transform(X_LAC_data4)

sc_UTAH4 = StandardScaler()
X_UTAH_train4 = sc_UTAH4.fit_transform(X_UTAH_train4)
X_UTAH_data4 = sc_UTAH4.transform(X_UTAH_data4)

sc_OKC4 = StandardScaler()
X_OKC_train4 = sc_OKC4.fit_transform(X_OKC_train4)
X_OKC_data4 = sc_OKC4.transform(X_OKC_data4)

sc_MEM4 = StandardScaler()
X_MEM_train4 = sc_MEM4.fit_transform(X_MEM_train4)
X_MEM_data4 = sc_MEM4.transform(X_MEM_data4)

sc_POR4 = StandardScaler()
X_POR_train4 = sc_POR4.fit_transform(X_POR_train4)
X_POR_data4 = sc_POR4.transform(X_POR_data4)

sc_DEN4 = StandardScaler()
X_DEN_train4 = sc_DEN4.fit_transform(X_DEN_train4)
X_DEN_data4 = sc_DEN4.transform(X_DEN_data4)

sc_NOP4 = StandardScaler()
X_NOP_train4 = sc_NOP4.fit_transform(X_NOP_train4)
X_NOP_data4 = sc_NOP4.transform(X_NOP_data4)

sc_DAL4 = StandardScaler()
X_DAL_train4 = sc_DAL4.fit_transform(X_DAL_train4)
X_DAL_data4 = sc_DAL4.transform(X_DAL_data4)

sc_SAC4 = StandardScaler()
X_SAC_train4 = sc_SAC4.fit_transform(X_SAC_train4)
X_SAC_data4 = sc_SAC4.transform(X_SAC_data4)

sc_MIN4 = StandardScaler()
X_MIN_train4 = sc_MIN4.fit_transform(X_MIN_train4)
X_MIN_data4 = sc_MIN4.transform(X_MIN_data4)

sc_LAL4 = StandardScaler()
X_LAL_train4 = sc_LAL4.fit_transform(X_LAL_train4)
X_LAL_data4 = sc_LAL4.transform(X_LAL_data4)

sc_PHO4 = StandardScaler()
X_PHO_train4 = sc_PHO4.fit_transform(X_PHO_train4)
X_PHO_data4 = sc_PHO4.transform(X_PHO_data4)

sc_BOS4 = StandardScaler()
X_BOS_train4 = sc_BOS4.fit_transform(X_BOS_train4)
X_BOS_data4 = sc_BOS4.transform(X_BOS_data4)

sc_CLE4 = StandardScaler()
X_CLE_train4 = sc_CLE4.fit_transform(X_CLE_train4)
X_CLE_data4 = sc_CLE4.transform(X_CLE_data4)

sc_TOR4 = StandardScaler()
X_TOR_train4 = sc_TOR4.fit_transform(X_TOR_train4)
X_TOR_data4 = sc_TOR4.transform(X_TOR_data4)

sc_WAS4 = StandardScaler()
X_WAS_train4 = sc_WAS4.fit_transform(X_WAS_train4)
X_WAS_data4 = sc_WAS4.transform(X_WAS_data4)

sc_ATL4 = StandardScaler()
X_ATL_train4 = sc_ATL4.fit_transform(X_ATL_train4)
X_ATL_data4 = sc_ATL4.transform(X_ATL_data4)

sc_MIL4 = StandardScaler()
X_MIL_train4 = sc_MIL4.fit_transform(X_MIL_train4)
X_MIL_data4 = sc_MIL4.transform(X_MIL_data4)

sc_IND4 = StandardScaler()
X_IND_train4 = sc_IND4.fit_transform(X_IND_train4)
X_IND_data4 = sc_IND4.transform(X_IND_data4)

sc_CHI4 = StandardScaler()
X_CHI_train4 = sc_CHI4.fit_transform(X_CHI_train4)
X_CHI_data4 = sc_CHI4.transform(X_CHI_data4)

sc_MIA4 = StandardScaler()
X_MIA_train4 = sc_MIA4.fit_transform(X_MIA_train4)
X_MIA_data4 = sc_MIA4.transform(X_MIA_data4)

sc_DET4 = StandardScaler()
X_DET_train4 = sc_DET4.fit_transform(X_DET_train4)
X_DET_data4 = sc_DET4.transform(X_DET_data4)

sc_CHA4 = StandardScaler()
X_CHA_train4 = sc_CHA4.fit_transform(X_CHA_train4)
X_CHA_data4 = sc_CHA4.transform(X_CHA_data4)

sc_NYK4 = StandardScaler()
X_NYK_train4 = sc_NYK4.fit_transform(X_NYK_train4)
X_NYK_data4 = sc_NYK4.transform(X_NYK_data4)

sc_ORL4 = StandardScaler()
X_ORL_train4 = sc_ORL4.fit_transform(X_ORL_train4)
X_ORL_data4 = sc_ORL4.transform(X_ORL_data4)

sc_PHI4 = StandardScaler()
X_PHI_train4 = sc_PHI4.fit_transform(X_PHI_train4)
X_PHI_data4 = sc_PHI4.transform(X_PHI_data4)

sc_BKN4 = StandardScaler()
X_BKN_train4 = sc_BKN4.fit_transform(X_BKN_train4)
X_BKN_data4 = sc_BKN4.transform(X_BKN_data4)

# %%
from sklearn.ensemble import RandomForestRegressor

reg_GSW4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_GSW4.fit(X_GSW_train4, y_GSW_train4)
y_pred_GSW4 = reg_GSW4.predict(X_GSW_data4)

reg_SAS4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_SAS4.fit(X_SAS_train4, y_SAS_train4)
y_pred_SAS4 = reg_SAS4.predict(X_SAS_data4)

reg_HOU4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_HOU4.fit(X_HOU_train4, y_HOU_train4)
y_pred_HOU4 = reg_HOU4.predict(X_HOU_data4)

reg_LAC4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_LAC4.fit(X_LAC_train4, y_LAC_train4)
y_pred_LAC4 = reg_LAC4.predict(X_LAC_data4)

reg_UTAH4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_UTAH4.fit(X_UTAH_train4, y_UTAH_train4)
y_pred_UTAH4 = reg_UTAH4.predict(X_UTAH_data4)

reg_OKC4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_OKC4.fit(X_OKC_train4, y_OKC_train4)
y_pred_OKC4 = reg_OKC4.predict(X_OKC_data4)

reg_MEM4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_MEM4.fit(X_MEM_train4, y_MEM_train4)
y_pred_MEM4 = reg_MEM4.predict(X_MEM_data4)

reg_POR4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_POR4.fit(X_POR_train4, y_POR_train4)
y_pred_POR4 = reg_POR4.predict(X_POR_data4)

reg_DEN4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_DEN4.fit(X_DEN_train4, y_DEN_train4)
y_pred_DEN4 = reg_DEN4.predict(X_DEN_data4)

reg_NOP4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_NOP4.fit(X_NOP_train4, y_NOP_train4)
y_pred_NOP4 = reg_NOP4.predict(X_NOP_data4)

reg_DAL4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_DAL4.fit(X_DAL_train4, y_DAL_train4)
y_pred_DAL4 = reg_DAL4.predict(X_DAL_data4)

reg_SAC4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_SAC4.fit(X_SAC_train4, y_SAC_train4)
y_pred_SAC4 = reg_SAC4.predict(X_SAC_data4)

reg_MIN4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_MIN4.fit(X_MIN_train4, y_MIN_train4)
y_pred_MIN4 = reg_MIN4.predict(X_MIN_data4)

reg_LAL4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_LAL4.fit(X_LAL_train4, y_LAL_train4)
y_pred_LAL4 = reg_LAL4.predict(X_LAL_data4)

reg_PHO4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_PHO4.fit(X_PHO_train4, y_PHO_train4)
y_pred_PHO4 = reg_PHO4.predict(X_PHO_data4)

reg_BOS4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_BOS4.fit(X_BOS_train4, y_BOS_train4)
y_pred_BOS4 = reg_BOS4.predict(X_BOS_data4)

reg_CLE4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_CLE4.fit(X_CLE_train4, y_CLE_train4)
y_pred_CLE4 = reg_CLE4.predict(X_CLE_data4)

reg_TOR4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_TOR4.fit(X_TOR_train4, y_TOR_train4)
y_pred_TOR4 = reg_TOR4.predict(X_TOR_data4)

reg_WAS4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_WAS4.fit(X_WAS_train4, y_WAS_train4)
y_pred_WAS4 = reg_WAS4.predict(X_WAS_data4)

reg_ATL4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_ATL4.fit(X_ATL_train4, y_ATL_train4)
y_pred_ATL4 = reg_ATL4.predict(X_ATL_data4)

reg_MIL4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_MIL4.fit(X_MIL_train4, y_MIL_train4)
y_pred_MIL4 = reg_MIL4.predict(X_MIL_data4)

reg_IND4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_IND4.fit(X_IND_train4, y_IND_train4)
y_pred_IND4 = reg_IND4.predict(X_IND_data4)

reg_CHI4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_CHI4.fit(X_CHI_train4, y_CHI_train4)
y_pred_CHI4 = reg_CHI4.predict(X_CHI_data4)

reg_MIA4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_MIA4.fit(X_MIA_train4, y_MIA_train4)
y_pred_MIA4 = reg_MIA4.predict(X_MIA_data4)

reg_DET4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_DET4.fit(X_DET_train4, y_DET_train4)
y_pred_DET4 = reg_DET4.predict(X_DET_data4)

reg_CHA4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_CHA4.fit(X_CHA_train4, y_CHA_train4)
y_pred_CHA4 = reg_CHA4.predict(X_CHA_data4)

reg_NYK4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_NYK4.fit(X_NYK_train4, y_NYK_train4)
y_pred_NYK4 = reg_NYK4.predict(X_NYK_data4)

reg_ORL4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_ORL4.fit(X_ORL_train4, y_ORL_train4)
y_pred_ORL4 = reg_ORL4.predict(X_ORL_data4)

reg_PHI4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_PHI4.fit(X_PHI_train4, y_PHI_train4)
y_pred_PHI4 = reg_PHI4.predict(X_PHI_data4)

reg_BKN4 = RandomForestRegressor(n_estimators=20, random_state=0)
reg_BKN4.fit(X_BKN_train4, y_BKN_train4)
y_pred_BKN4 = reg_BKN4.predict(X_BKN_data4)

# %%
#self accuracy

#since the prediction values are continuous, and the truth values are binary
#sklearn.metrics would print out an error of how the classification metrics
#can't handle a mix of binary and continuous targets, thus the accuracy
#will then be computed by 100 - percent error of the predicted and the actual

if y_GSW_data4.values.item(0) > 0:
  percent_error = abs((y_pred_GSW4.item(0) - y_GSW_data4.values.item(0)) / y_GSW_data4.values.item(0))
else:
  percent_error = abs((y_pred_GSW4.item(0) - y_GSW_data4.values.item(0)) / (y_GSW_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for GSW: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for GSW: 99.7%

# %%
if y_SAS_data4.values.item(0) > 0:
  percent_error = abs((y_pred_SAS4.item(0) - y_SAS_data4.values.item(0)) / y_SAS_data4.values.item(0))
else:
  percent_error = abs((y_pred_SAS4.item(0) - y_SAS_data4.values.item(0)) / (y_SAS_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for SAS: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for SAS: 99.55%

# %%
if y_HOU_data4.values.item(0) > 0:
  percent_error = abs((y_pred_HOU4.item(0) - y_HOU_data4.values.item(0)) / y_HOU_data4.values.item(0))
else:
  percent_error = abs((y_pred_HOU4.item(0) - y_HOU_data4.values.item(0)) / (y_HOU_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for HOU: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for HOU: 99.2%

# %%
if y_LAC_data4.values.item(0) > 0:
  percent_error = abs((y_pred_LAC4.item(0) - y_LAC_data4.values.item(0)) / y_LAC_data4.values.item(0))
else:
  percent_error = abs((y_pred_LAC4.item(0) - y_LAC_data4.values.item(0)) / (y_LAC_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for LAC: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for LAC: 99.55%

# %%
if y_UTAH_data4.values.item(0) > 0:
  percent_error = abs((y_pred_UTAH4.item(0) - y_UTAH_data4.values.item(0)) / y_UTAH_data4.values.item(0))
else:
  percent_error = abs((y_pred_UTAH4.item(0) - y_UTAH_data4.values.item(0)) / (y_UTAH_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for UTAH: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for UTAH: 99.45%

# %%
if y_OKC_data4.values.item(0) > 0:
  percent_error = abs((y_pred_OKC4.item(0) - y_OKC_data4.values.item(0)) / y_OKC_data4.values.item(0))
else:
  percent_error = abs((y_pred_OKC4.item(0) - y_OKC_data4.values.item(0)) / (y_OKC_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for OKC: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for OKC: 99.9%

# %%
if y_MEM_data4.values.item(0) > 0:
  percent_error = abs((y_pred_MEM4.item(0) - y_MEM_data4.values.item(0)) / y_MEM_data4.values.item(0))
else:
  percent_error = abs((y_pred_MEM4.item(0) - y_MEM_data4.values.item(0)) / (y_MEM_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for MEM: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for MEM: 99.3%

# %%
if y_POR_data4.values.item(0) > 0:
  percent_error = abs((y_pred_POR4.item(0) - y_POR_data4.values.item(0)) / y_POR_data4.values.item(0))
else:
  percent_error = abs((y_pred_POR4.item(0) - y_POR_data4.values.item(0)) / (y_POR_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for POR: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for POR: 99.25%

# %%
if y_DEN_data4.values.item(0) > 0:
  percent_error = abs((y_pred_DEN4.item(0) - y_DEN_data4.values.item(0)) / y_DEN_data4.values.item(0))
else:
  percent_error = abs((y_pred_DEN4.item(0) - y_DEN_data4.values.item(0)) / (y_DEN_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for DEN: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for DEN: 99.15%

# %%
if y_NOP_data4.values.item(0) > 0:
  percent_error = abs((y_pred_NOP4.item(0) - y_NOP_data4.values.item(0)) / y_NOP_data4.values.item(0))
else:
  percent_error = abs((y_pred_NOP4.item(0) - y_NOP_data4.values.item(0)) / (y_NOP_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for NOP: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for NOP: 99.5%

# %%
if y_DAL_data4.values.item(0) > 0:
  percent_error = abs((y_pred_DAL4.item(0) - y_DAL_data4.values.item(0)) / y_DAL_data4.values.item(0))
else:
  percent_error = abs((y_pred_DAL4.item(0) - y_DAL_data4.values.item(0)) / (y_DAL_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for DAL: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for DAL: 99.4%

# %%
if y_SAC_data4.values.item(0) > 0:
  percent_error = abs((y_pred_SAC4.item(0) - y_SAC_data4.values.item(0)) / y_SAC_data4.values.item(0))
else:
  percent_error = abs((y_pred_SAC4.item(0) - y_SAC_data4.values.item(0)) / (y_SAC_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for SAC: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for SAC: 99.8%

# %%
if y_MIN_data4.values.item(0) > 0:
  percent_error = abs((y_pred_MIN4.item(0) - y_MIN_data4.values.item(0)) / y_MIN_data4.values.item(0))
else:
  percent_error = abs((y_pred_MIN4.item(0) - y_MIN_data4.values.item(0)) / (y_MIN_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for MIN: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for MIN: 99.05%

# %%
if y_LAL_data4.values.item(0) > 0:
  percent_error = abs((y_pred_LAL4.item(0) - y_LAL_data4.values.item(0)) / y_LAL_data4.values.item(0))
else:
  percent_error = abs((y_pred_LAL4.item(0) - y_LAL_data4.values.item(0)) / (y_LAL_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for LAL: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for LAL: 99.95%

# %%
if y_PHO_data4.values.item(0) > 0:
  percent_error = abs((y_pred_PHO4.item(0) - y_PHO_data4.values.item(0)) / y_PHO_data4.values.item(0))
else:
  percent_error = abs((y_pred_PHO4.item(0) - y_PHO_data4.values.item(0)) / (y_PHO_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for PHO: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for PHO: 99.9%

# %%
if y_BOS_data4.values.item(0) > 0:
  percent_error = abs((y_pred_BOS4.item(0) - y_BOS_data4.values.item(0)) / y_BOS_data4.values.item(0))
else:
  percent_error = abs((y_pred_BOS4.item(0) - y_BOS_data4.values.item(0)) / (y_BOS_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for BOS: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for BOS: 99.35%

# %%
if y_CLE_data4.values.item(0) > 0:
  percent_error = abs((y_pred_CLE4.item(0) - y_CLE_data4.values.item(0)) / y_CLE_data4.values.item(0))
else:
  percent_error = abs((y_pred_CLE4.item(0) - y_CLE_data4.values.item(0)) / (y_CLE_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for CLE: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for CLE: 99.85%

# %%
if y_TOR_data4.values.item(0) > 0:
  percent_error = abs((y_pred_TOR4.item(0) - y_TOR_data4.values.item(0)) / y_TOR_data4.values.item(0))
else:
  percent_error = abs((y_pred_TOR4.item(0) - y_TOR_data4.values.item(0)) / (y_TOR_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for TOR: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for TOR: 99.85%

# %%
if y_WAS_data4.values.item(0) > 0:
  percent_error = abs((y_pred_WAS4.item(0) - y_WAS_data4.values.item(0)) / y_WAS_data4.values.item(0))
else:
  percent_error = abs((y_pred_WAS4.item(0) - y_WAS_data4.values.item(0)) / (y_WAS_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for WAS: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for WAS: 99.85%

# %%
if y_ATL_data4.values.item(0) > 0:
  percent_error = abs((y_pred_ATL4.item(0) - y_ATL_data4.values.item(0)) / y_ATL_data4.values.item(0))
else:
  percent_error = abs((y_pred_ATL4.item(0) - y_ATL_data4.values.item(0)) / (y_ATL_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for ATL: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for ATL: 99.55%

# %%
if y_MIL_data4.values.item(0) > 0:
  percent_error = abs((y_pred_MIL4.item(0) - y_MIL_data4.values.item(0)) / y_MIL_data4.values.item(0))
else:
  percent_error = abs((y_pred_MIL4.item(0) - y_MIL_data4.values.item(0)) / (y_MIL_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for MIL: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for MIL: 99.45%

# %%
if y_IND_data4.values.item(0) > 0:
  percent_error = abs((y_pred_IND4.item(0) - y_IND_data4.values.item(0)) / y_IND_data4.values.item(0))
else:
  percent_error = abs((y_pred_IND4.item(0) - y_IND_data4.values.item(0)) / (y_IND_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for IND: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for IND: 99.6%

# %%
if y_CHI_data4.values.item(0) > 0:
  percent_error = abs((y_pred_CHI4.item(0) - y_CHI_data4.values.item(0)) / y_CHI_data4.values.item(0))
else:
  percent_error = abs((y_pred_CHI4.item(0) - y_CHI_data4.values.item(0)) / (y_CHI_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for CHI: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for CHI: 99.6%

# %%
if y_MIA_data4.values.item(0) > 0:
  percent_error = abs((y_pred_MIA4.item(0) - y_MIA_data4.values.item(0)) / y_MIA_data4.values.item(0))
else:
  percent_error = abs((y_pred_MIA4.item(0) - y_MIA_data4.values.item(0)) / (y_MIA_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for MIA: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for MIA: 99.7%

# %%
if y_DET_data4.values.item(0) > 0:
  percent_error = abs((y_pred_DET4.item(0) - y_DET_data4.values.item(0)) / y_DET_data4.values.item(0))
else:
  percent_error = abs((y_pred_DET4.item(0) - y_DET_data4.values.item(0)) / (y_DET_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for DET: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for DET: 99.5%

# %%
if y_CHA_data4.values.item(0) > 0:
  percent_error = abs((y_pred_CHA4.item(0) - y_CHA_data4.values.item(0)) / y_CHA_data4.values.item(0))
else:
  percent_error = abs((y_pred_CHA4.item(0) - y_CHA_data4.values.item(0)) / (y_CHA_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for CHA: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for CHA: 99.65%

# %%
if y_NYK_data4.values.item(0) > 0:
  percent_error = abs((y_pred_NYK4.item(0) - y_NYK_data4.values.item(0)) / y_NYK_data4.values.item(0))
else:
  percent_error = abs((y_pred_NYK4.item(0) - y_NYK_data4.values.item(0)) / (y_NYK_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for NYK: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for NYK: 99.8%

# %%
if y_ORL_data4.values.item(0) > 0:
  percent_error = abs((y_pred_ORL4.item(0) - y_ORL_data4.values.item(0)) / y_ORL_data4.values.item(0))
else:
  percent_error = abs((y_pred_ORL4.item(0) - y_ORL_data4.values.item(0)) / (y_ORL_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for ORL: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for ORL: 99.85%

# %%
if y_PHI_data4.values.item(0) > 0:
  percent_error = abs((y_pred_PHI4.item(0) - y_PHI_data4.values.item(0)) / y_PHI_data4.values.item(0))
else:
  percent_error = abs((y_pred_PHI4.item(0) - y_PHI_data4.values.item(0)) / (y_PHI_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for PHI: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for PHI: 99.2%

# %%
if y_BKN_data4.values.item(0) > 0:
  percent_error = abs((y_pred_BKN4.item(0) - y_BKN_data4.values.item(0)) / y_BKN_data4.values.item(0))
else:
  percent_error = abs((y_pred_BKN4.item(0) - y_BKN_data4.values.item(0)) / (y_BKN_data4.values.item(0) + 1))
'%.2f'%percent_error #2 decimal places
print("Accuracy for BKN: {0}%".format((100.0 - percent_error)))
# Out:
# Accuracy for BKN: 99.75%

# %%
west_dict = {
    "Golden State Warriors" : y_pred_GSW4.item(0),
    "San Antonio Spurs" : y_pred_SAS4.item(0),
    "Houston Rockets": y_pred_HOU4.item(0),
    "Los Angeles Clippers": y_pred_LAC4.item(0),
    "Utah Jazz" : y_pred_UTAH4.item(0),
    "Oklahoma City Thunder" : y_pred_OKC4.item(0),
    "Memphis Grizzlies" : y_pred_MEM4.item(0),
    "Portland Trailblazers" : y_pred_POR4.item(0),
    "Denver Nuggets" : y_pred_DEN4.item(0),
    "New Orleans Pelicans" : y_pred_NOP4.item(0),
    "Dallas Mavericks" : y_pred_DAL4.item(0),
    "Sacramento Kings" : y_pred_SAC4.item(0),
    "Minnesota Timberwolves" : y_pred_MIN4.item(0),
    "Los Angeles Lakers" : y_pred_LAL4.item(0),
    "Phoenix Suns" : y_pred_PHO4.item(0)
}

print("Making the Western Conference Playoffs:\n")

for a, b in west_dict.items():
  if b >= 0.5:
    print("%s will make the playoffs in the Western Conference!" % a)

east_dict = {
    "Boston Celtics" : y_pred_BOS4.item(0),
    "Cleveland Cavaliers" : y_pred_CLE4.item(0),
    "Toronto Raptors" : y_pred_TOR4.item(0),
    "Washington Wizards" : y_pred_WAS4.item(0),
    "Atlanta Hawks" : y_pred_ATL4.item(0),
    "Milwaukee Bucks" : y_pred_MIL4.item(0),
    "Indiana Pacers" : y_pred_IND4.item(0),
    "Chicago Bulls" : y_pred_CHI4.item(0),
    "Miami Heat" : y_pred_MIA4.item(0),
    "Detroit Pistons" : y_pred_DET4.item(0),
    "Charlotte Hornets" : y_pred_CHA4.item(0),
    "New York Knicks" : y_pred_NYK4.item(0),
    "Orlando Magic" : y_pred_ORL4.item(0),
    "Philadelphia 76ers" : y_pred_PHI4.item(0),
    "Brooklyn Nets" : y_pred_BKN4.item(0)
}

print("\nMaking the Eastern Conference Playoffs:\n")

for a, b in east_dict.items():
  if b >= 0.5:
    print("%s will make the playoffs in the Eastern Conference!" % a)
# Out:
# Making the Western Conference Playoffs:
#
# Golden State Warriors will make the playoffs in the Western Conference!
# San Antonio Spurs will make the playoffs in the Western Conference!
# Los Angeles Clippers will make the playoffs in the Western Conference!
# Utah Jazz will make the playoffs in the Western Conference!
# Oklahoma City Thunder will make the playoffs in the Western Conference!
# Portland Trailblazers will make the playoffs in the Western Conference!
# New Orleans Pelicans will make the playoffs in the Western Conference!
# Dallas Mavericks will make the playoffs in the Western Conference!
# Minnesota Timberwolves will make the playoffs in the Western Conference!
# Los Angeles Lakers will make the playoffs in the Western Conference!
#
# Making the Eastern Conference Playoffs:
#
# Atlanta Hawks will make the playoffs in the Eastern Conference!
# Indiana Pacers will make the playoffs in the Eastern Conference!
# ...
