# %% [markdown]
# Team Efficiency all-in-all uses = League Points, 3Ps Made, Assists, Turnovers, Field Goal Attempts, Field Goals Made, Free Throws Attempted, Free Throws Made, Offensive Rebounds, Total Rebounds, Steals, Blocks, and Personal Fouls thus remove these from the X set to remove redundancy
#
# Same case for factor, VOP, and DRB since they are part of getting the team efficiency engineered stat
#
# Thus, X should contain 3Ps Attempted, Defensive Rebounds, Average Points, Attendees, and Team Efficiency
#
# The data used here is a consolidated dataset from the 2013-2014 season up to 2017-2018 season.

# %%
import numpy as np
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/1EDgOU55F0lSr68o5MDXzT50asqY6OeiC59dArlqVj0o/edit#gid=0'
csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

df = pd.read_csv(csv_export_url)
#df.describe()

X_stats = ['3Ps Attempted', 'Defensive Rebounds', 'Average Points', 'Attendees', 'Team Efficiency']
Y_stats = ['Team Performance']

GSW1 = df['Team Name and Instance'].str.contains("Golden State Warriors") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notGSW1 = ~df['Team Name and Instance'].str.contains("Golden State Warriors") & df['Team Name and Instance'].str.contains("(Games 1-20)")

SAS1 = df['Team Name and Instance'].str.contains("San Antonio Spurs") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notSAS1 = ~df['Team Name and Instance'].str.contains("San Antonio Spurs") & df['Team Name and Instance'].str.contains("(Games 1-20)")

HOU1 = df['Team Name and Instance'].str.contains("Houston Rockets") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notHOU1 = ~df['Team Name and Instance'].str.contains("Houston Rockets") & df['Team Name and Instance'].str.contains("(Games 1-20)")

LAC1 = df['Team Name and Instance'].str.contains("Los Angeles Clippers") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notLAC1 = ~df['Team Name and Instance'].str.contains("Los Angeles Clippers") & df['Team Name and Instance'].str.contains("(Games 1-20)")

UTAH1 = df['Team Name and Instance'].str.contains("Utah Jazz") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notUTAH1 = ~df['Team Name and Instance'].str.contains("Utah Jazz") & df['Team Name and Instance'].str.contains("(Games 1-20)")

OKC1 = df['Team Name and Instance'].str.contains("Oklahoma City Thunder") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notOKC1 = ~df['Team Name and Instance'].str.contains("Oklahoma City Thunder") & df['Team Name and Instance'].str.contains("(Games 1-20)")

MEM1 = df['Team Name and Instance'].str.contains("Memphis Grizzlies") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notMEM1 = ~df['Team Name and Instance'].str.contains("Memphis Grizzlies") & df['Team Name and Instance'].str.contains("(Games 1-20)")

POR1 = df['Team Name and Instance'].str.contains("Portland Trailblazers") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notPOR1 = ~df['Team Name and Instance'].str.contains("Portland Trailblazers") & df['Team Name and Instance'].str.contains("(Games 1-20)")

DEN1 = df['Team Name and Instance'].str.contains("Denver Nuggets") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notDEN1 = ~df['Team Name and Instance'].str.contains("Denver Nuggets") & df['Team Name and Instance'].str.contains("(Games 1-20)")

NOP1 = df['Team Name and Instance'].str.contains("New Orleans Pelicans") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notNOP1 = ~df['Team Name and Instance'].str.contains("New Orleans Pelicans") & df['Team Name and Instance'].str.contains("(Games 1-20)")

DAL1 = df['Team Name and Instance'].str.contains("Dallas Mavericks") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notDAL1 = ~df['Team Name and Instance'].str.contains("Dallas Mavericks") & df['Team Name and Instance'].str.contains("(Games 1-20)")

SAC1 = df['Team Name and Instance'].str.contains("Sacramento Kings") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notSAC1 = ~df['Team Name and Instance'].str.contains("Sacramento Kings") & df['Team Name and Instance'].str.contains("(Games 1-20)")

MIN1 = df['Team Name and Instance'].str.contains("Minnesota Timberwolves") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notMIN1 = ~df['Team Name and Instance'].str.contains("Minnesota Timberwolves") & df['Team Name and Instance'].str.contains("(Games 1-20)")

LAL1 = df['Team Name and Instance'].str.contains("Los Angeles Lakers") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notLAL1 = ~df['Team Name and Instance'].str.contains("Los Angeles Lakers") & df['Team Name and Instance'].str.contains("(Games 1-20)")

PHO1 = df['Team Name and Instance'].str.contains("Phoenix Suns") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notPHO1 = ~df['Team Name and Instance'].str.contains("Phoenix Suns") & df['Team Name and Instance'].str.contains("(Games 1-20)")

BOS1 = df['Team Name and Instance'].str.contains("Boston Celtics") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notBOS1 = ~df['Team Name and Instance'].str.contains("Boston Celtics") & df['Team Name and Instance'].str.contains("(Games 1-20)")

CLE1 = df['Team Name and Instance'].str.contains("Cleveland Cavaliers") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notCLE1 = ~df['Team Name and Instance'].str.contains("Cleveland Cavaliers") & df['Team Name and Instance'].str.contains("(Games 1-20)")

TOR1 = df['Team Name and Instance'].str.contains("Toronto Raptors") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notTOR1 = ~df['Team Name and Instance'].str.contains("Toronto Raptors") & df['Team Name and Instance'].str.contains("(Games 1-20)")

WAS1 = df['Team Name and Instance'].str.contains("Washington Wizards") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notWAS1 = ~df['Team Name and Instance'].str.contains("Washington Wizards") & df['Team Name and Instance'].str.contains("(Games 1-20)")

ATL1 = df['Team Name and Instance'].str.contains("Atlanta Hawks") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notATL1 = ~df['Team Name and Instance'].str.contains("Atlanta Hawks") & df['Team Name and Instance'].str.contains("(Games 1-20)")

MIL1 = df['Team Name and Instance'].str.contains("Milwaukee Bucks") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notMIL1 = ~df['Team Name and Instance'].str.contains("Milwaukee Bucks") & df['Team Name and Instance'].str.contains("(Games 1-20)")

IND1 = df['Team Name and Instance'].str.contains("Indiana Pacers") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notIND1 = ~df['Team Name and Instance'].str.contains("Indiana Pacers") & df['Team Name and Instance'].str.contains("(Games 1-20)")

CHI1 = df['Team Name and Instance'].str.contains("Chicago Bulls") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notCHI1 = ~df['Team Name and Instance'].str.contains("Chicago Bulls") & df['Team Name and Instance'].str.contains("(Games 1-20)")

MIA1 = df['Team Name and Instance'].str.contains("Miami Heat") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notMIA1 = ~df['Team Name and Instance'].str.contains("Miami Heat") & df['Team Name and Instance'].str.contains("(Games 1-20)")

DET1 = df['Team Name and Instance'].str.contains("Detroit Pistons") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notDET1 = ~df['Team Name and Instance'].str.contains("Detroit Pistons") & df['Team Name and Instance'].str.contains("(Games 1-20)")

CHA1 = df['Team Name and Instance'].str.contains("Charlotte Hornets") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notCHA1 = ~df['Team Name and Instance'].str.contains("Charlotte Hornets") & df['Team Name and Instance'].str.contains("(Games 1-20)")

NYK1 = df['Team Name and Instance'].str.contains("New York Knicks") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notNYK1 = ~df['Team Name and Instance'].str.contains("New York Knicks") & df['Team Name and Instance'].str.contains("(Games 1-20)")

ORL1 = df['Team Name and Instance'].str.contains("Orlando Magic") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notORL1 = ~df['Team Name and Instance'].str.contains("Orlando Magic") & df['Team Name and Instance'].str.contains("(Games 1-20)")

PHI1 = df['Team Name and Instance'].str.contains("Philadelphia 76ers") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notPHI1 = ~df['Team Name and Instance'].str.contains("Philadelphia 76ers") & df['Team Name and Instance'].str.contains("(Games 1-20)")

BKN1 = df['Team Name and Instance'].str.contains("Brooklyn Nets") & df['Team Name and Instance'].str.contains("(Games 1-20)")
notBKN1 = ~df['Team Name and Instance'].str.contains("Brooklyn Nets") & df['Team Name and Instance'].str.contains("(Games 1-20)")

GSW2 = df['Team Name and Instance'].str.contains("Golden State Warriors") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notGSW2 = ~df['Team Name and Instance'].str.contains("Golden State Warriors") & df['Team Name and Instance'].str.contains("(Games 21-41)")

SAS2 = df['Team Name and Instance'].str.contains("San Antonio Spurs") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notSAS2 = ~df['Team Name and Instance'].str.contains("San Antonio Spurs") & df['Team Name and Instance'].str.contains("(Games 21-41)")

HOU2 = df['Team Name and Instance'].str.contains("Houston Rockets") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notHOU2 = ~df['Team Name and Instance'].str.contains("Houston Rockets") & df['Team Name and Instance'].str.contains("(Games 21-41)")

LAC2 = df['Team Name and Instance'].str.contains("Los Angeles Clippers") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notLAC2 = ~df['Team Name and Instance'].str.contains("Los Angeles Clippers") & df['Team Name and Instance'].str.contains("(Games 21-41)")

UTAH2 = df['Team Name and Instance'].str.contains("Utah Jazz") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notUTAH2 = ~df['Team Name and Instance'].str.contains("Utah Jazz") & df['Team Name and Instance'].str.contains("(Games 21-41)")

OKC2 = df['Team Name and Instance'].str.contains("Oklahoma City Thunder") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notOKC2 = ~df['Team Name and Instance'].str.contains("Oklahoma City Thunder") & df['Team Name and Instance'].str.contains("(Games 21-41)")

MEM2 = df['Team Name and Instance'].str.contains("Memphis Grizzlies") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notMEM2 = ~df['Team Name and Instance'].str.contains("Memphis Grizzlies") & df['Team Name and Instance'].str.contains("(Games 21-41)")

POR2 = df['Team Name and Instance'].str.contains("Portland Trailblazers") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notPOR2 = ~df['Team Name and Instance'].str.contains("Portland Trailblazers") & df['Team Name and Instance'].str.contains("(Games 21-41)")

DEN2 = df['Team Name and Instance'].str.contains("Denver Nuggets") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notDEN2 = ~df['Team Name and Instance'].str.contains("Denver Nuggets") & df['Team Name and Instance'].str.contains("(Games 21-41)")

NOP2 = df['Team Name and Instance'].str.contains("New Orleans Pelicans") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notNOP2 = ~df['Team Name and Instance'].str.contains("New Orleans Pelicans") & df['Team Name and Instance'].str.contains("(Games 21-41)")

DAL2 = df['Team Name and Instance'].str.contains("Dallas Mavericks") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notDAL2 = ~df['Team Name and Instance'].str.contains("Dallas Mavericks") & df['Team Name and Instance'].str.contains("(Games 21-41)")

SAC2 = df['Team Name and Instance'].str.contains("Sacramento Kings") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notSAC2 = ~df['Team Name and Instance'].str.contains("Sacramento Kings") & df['Team Name and Instance'].str.contains("(Games 21-41)")

MIN2 = df['Team Name and Instance'].str.contains("Minnesota Timberwolves") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notMIN2 = ~df['Team Name and Instance'].str.contains("Minnesota Timberwolves") & df['Team Name and Instance'].str.contains("(Games 21-41)")

LAL2 = df['Team Name and Instance'].str.contains("Los Angeles Lakers") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notLAL2 = ~df['Team Name and Instance'].str.contains("Los Angeles Lakers") & df['Team Name and Instance'].str.contains("(Games 21-41)")

PHO2 = df['Team Name and Instance'].str.contains("Phoenix Suns") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notPHO2 = ~df['Team Name and Instance'].str.contains("Phoenix Suns") & df['Team Name and Instance'].str.contains("(Games 21-41)")

BOS2 = df['Team Name and Instance'].str.contains("Boston Celtics") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notBOS2 = ~df['Team Name and Instance'].str.contains("Boston Celtics") & df['Team Name and Instance'].str.contains("(Games 21-41)")

CLE2 = df['Team Name and Instance'].str.contains("Cleveland Cavaliers") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notCLE2 = ~df['Team Name and Instance'].str.contains("Cleveland Cavaliers") & df['Team Name and Instance'].str.contains("(Games 21-41)")

TOR2 = df['Team Name and Instance'].str.contains("Toronto Raptors") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notTOR2 = ~df['Team Name and Instance'].str.contains("Toronto Raptors") & df['Team Name and Instance'].str.contains("(Games 21-41)")

WAS2 = df['Team Name and Instance'].str.contains("Washington Wizards") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notWAS2 = ~df['Team Name and Instance'].str.contains("Washington Wizards") & df['Team Name and Instance'].str.contains("(Games 21-41)")

ATL2 = df['Team Name and Instance'].str.contains("Atlanta Hawks") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notATL2 = ~df['Team Name and Instance'].str.contains("Atlanta Hawks") & df['Team Name and Instance'].str.contains("(Games 21-41)")

MIL2 = df['Team Name and Instance'].str.contains("Milwaukee Bucks") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notMIL2 = ~df['Team Name and Instance'].str.contains("Milwaukee Bucks") & df['Team Name and Instance'].str.contains("(Games 21-41)")

IND2 = df['Team Name and Instance'].str.contains("Indiana Pacers") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notIND2 = ~df['Team Name and Instance'].str.contains("Indiana Pacers") & df['Team Name and Instance'].str.contains("(Games 21-41)")

CHI2 = df['Team Name and Instance'].str.contains("Chicago Bulls") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notCHI2 = ~df['Team Name and Instance'].str.contains("Chicago Bulls") & df['Team Name and Instance'].str.contains("(Games 21-41)")

MIA2 = df['Team Name and Instance'].str.contains("Miami Heat") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notMIA2 = ~df['Team Name and Instance'].str.contains("Miami Heat") & df['Team Name and Instance'].str.contains("(Games 21-41)")

DET2 = df['Team Name and Instance'].str.contains("Detroit Pistons") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notDET2 = ~df['Team Name and Instance'].str.contains("Detroit Pistons") & df['Team Name and Instance'].str.contains("(Games 21-41)")

CHA2 = df['Team Name and Instance'].str.contains("Charlotte Hornets") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notCHA2 = ~df['Team Name and Instance'].str.contains("Charlotte Hornets") & df['Team Name and Instance'].str.contains("(Games 21-41)")

NYK2 = df['Team Name and Instance'].str.contains("New York Knicks") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notNYK2 = ~df['Team Name and Instance'].str.contains("New York Knicks") & df['Team Name and Instance'].str.contains("(Games 21-41)")

ORL2 = df['Team Name and Instance'].str.contains("Orlando Magic") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notORL2 = ~df['Team Name and Instance'].str.contains("Orlando Magic") & df['Team Name and Instance'].str.contains("(Games 21-41)")

PHI2 = df['Team Name and Instance'].str.contains("Philadelphia 76ers") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notPHI2 = ~df['Team Name and Instance'].str.contains("Philadelphia 76ers") & df['Team Name and Instance'].str.contains("(Games 21-41)")

BKN2 = df['Team Name and Instance'].str.contains("Brooklyn Nets") & df['Team Name and Instance'].str.contains("(Games 21-41)")
notBKN2 = ~df['Team Name and Instance'].str.contains("Brooklyn Nets") & df['Team Name and Instance'].str.contains("(Games 21-41)")


GSW3 = df['Team Name and Instance'].str.contains("Golden State Warriors") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notGSW3 = ~df['Team Name and Instance'].str.contains("Golden State Warriors") & df['Team Name and Instance'].str.contains("(Games 42-61)")

SAS3 = df['Team Name and Instance'].str.contains("San Antonio Spurs") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notSAS3 = ~df['Team Name and Instance'].str.contains("San Antonio Spurs") & df['Team Name and Instance'].str.contains("(Games 42-61)")

HOU3 = df['Team Name and Instance'].str.contains("Houston Rockets") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notHOU3 = ~df['Team Name and Instance'].str.contains("Houston Rockets") & df['Team Name and Instance'].str.contains("(Games 42-61)")

LAC3 = df['Team Name and Instance'].str.contains("Los Angeles Clippers") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notLAC3 = ~df['Team Name and Instance'].str.contains("Los Angeles Clippers") & df['Team Name and Instance'].str.contains("(Games 42-61)")

UTAH3 = df['Team Name and Instance'].str.contains("Utah Jazz") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notUTAH3 = ~df['Team Name and Instance'].str.contains("Utah Jazz") & df['Team Name and Instance'].str.contains("(Games 42-61)")

OKC3 = df['Team Name and Instance'].str.contains("Oklahoma City Thunder") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notOKC3 = ~df['Team Name and Instance'].str.contains("Oklahoma City Thunder") & df['Team Name and Instance'].str.contains("(Games 42-61)")

MEM3 = df['Team Name and Instance'].str.contains("Memphis Grizzlies") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notMEM3 = ~df['Team Name and Instance'].str.contains("Memphis Grizzlies") & df['Team Name and Instance'].str.contains("(Games 42-61)")

POR3 = df['Team Name and Instance'].str.contains("Portland Trailblazers") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notPOR3 = ~df['Team Name and Instance'].str.contains("Portland Trailblazers") & df['Team Name and Instance'].str.contains("(Games 42-61)")

DEN3 = df['Team Name and Instance'].str.contains("Denver Nuggets") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notDEN3 = ~df['Team Name and Instance'].str.contains("Denver Nuggets") & df['Team Name and Instance'].str.contains("(Games 42-61)")

NOP3 = df['Team Name and Instance'].str.contains("New Orleans Pelicans") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notNOP3 = ~df['Team Name and Instance'].str.contains("New Orleans Pelicans") & df['Team Name and Instance'].str.contains("(Games 42-61)")

DAL3 = df['Team Name and Instance'].str.contains("Dallas Mavericks") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notDAL3 = ~df['Team Name and Instance'].str.contains("Dallas Mavericks") & df['Team Name and Instance'].str.contains("(Games 42-61)")

SAC3 = df['Team Name and Instance'].str.contains("Sacramento Kings") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notSAC3 = ~df['Team Name and Instance'].str.contains("Sacramento Kings") & df['Team Name and Instance'].str.contains("(Games 42-61)")

MIN3 = df['Team Name and Instance'].str.contains("Minnesota Timberwolves") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notMIN3 = ~df['Team Name and Instance'].str.contains("Minnesota Timberwolves") & df['Team Name and Instance'].str.contains("(Games 42-61)")

LAL3 = df['Team Name and Instance'].str.contains("Los Angeles Lakers") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notLAL3 = ~df['Team Name and Instance'].str.contains("Los Angeles Lakers") & df['Team Name and Instance'].str.contains("(Games 42-61)")

PHO3 = df['Team Name and Instance'].str.contains("Phoenix Suns") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notPHO3 = ~df['Team Name and Instance'].str.contains("Phoenix Suns") & df['Team Name and Instance'].str.contains("(Games 42-61)")

BOS3 = df['Team Name and Instance'].str.contains("Boston Celtics") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notBOS3 = ~df['Team Name and Instance'].str.contains("Boston Celtics") & df['Team Name and Instance'].str.contains("(Games 42-61)")

CLE3 = df['Team Name and Instance'].str.contains("Cleveland Cavaliers") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notCLE3 = ~df['Team Name and Instance'].str.contains("Cleveland Cavaliers") & df['Team Name and Instance'].str.contains("(Games 42-61)")

TOR3 = df['Team Name and Instance'].str.contains("Toronto Raptors") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notTOR3 = ~df['Team Name and Instance'].str.contains("Toronto Raptors") & df['Team Name and Instance'].str.contains("(Games 42-61)")

WAS3 = df['Team Name and Instance'].str.contains("Washington Wizards") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notWAS3 = ~df['Team Name and Instance'].str.contains("Washington Wizards") & df['Team Name and Instance'].str.contains("(Games 42-61)")

ATL3 = df['Team Name and Instance'].str.contains("Atlanta Hawks") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notATL3 = ~df['Team Name and Instance'].str.contains("Atlanta Hawks") & df['Team Name and Instance'].str.contains("(Games 42-61)")

MIL3 = df['Team Name and Instance'].str.contains("Milwaukee Bucks") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notMIL3 = ~df['Team Name and Instance'].str.contains("Milwaukee Bucks") & df['Team Name and Instance'].str.contains("(Games 42-61)")

IND3 = df['Team Name and Instance'].str.contains("Indiana Pacers") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notIND3 = ~df['Team Name and Instance'].str.contains("Indiana Pacers") & df['Team Name and Instance'].str.contains("(Games 42-61)")

CHI3 = df['Team Name and Instance'].str.contains("Chicago Bulls") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notCHI3 = ~df['Team Name and Instance'].str.contains("Chicago Bulls") & df['Team Name and Instance'].str.contains("(Games 42-61)")

MIA3 = df['Team Name and Instance'].str.contains("Miami Heat") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notMIA3 = ~df['Team Name and Instance'].str.contains("Miami Heat") & df['Team Name and Instance'].str.contains("(Games 42-61)")

DET3 = df['Team Name and Instance'].str.contains("Detroit Pistons") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notDET3 = ~df['Team Name and Instance'].str.contains("Detroit Pistons") & df['Team Name and Instance'].str.contains("(Games 42-61)")

CHA3 = df['Team Name and Instance'].str.contains("Charlotte Hornets") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notCHA3 = ~df['Team Name and Instance'].str.contains("Charlotte Hornets") & df['Team Name and Instance'].str.contains("(Games 42-61)")

NYK3 = df['Team Name and Instance'].str.contains("New York Knicks") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notNYK3 = ~df['Team Name and Instance'].str.contains("New York Knicks") & df['Team Name and Instance'].str.contains("(Games 42-61)")

ORL3 = df['Team Name and Instance'].str.contains("Orlando Magic") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notORL3 = ~df['Team Name and Instance'].str.contains("Orlando Magic") & df['Team Name and Instance'].str.contains("(Games 42-61)")

PHI3 = df['Team Name and Instance'].str.contains("Philadelphia 76ers") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notPHI3 = ~df['Team Name and Instance'].str.contains("Philadelphia 76ers") & df['Team Name and Instance'].str.contains("(Games 42-61)")

BKN3 = df['Team Name and Instance'].str.contains("Brooklyn Nets") & df['Team Name and Instance'].str.contains("(Games 42-61)")
notBKN3 = ~df['Team Name and Instance'].str.contains("Brooklyn Nets") & df['Team Name and Instance'].str.contains("(Games 42-61)")

GSW4 = df['Team Name and Instance'].str.contains("Golden State Warriors") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notGSW4 = ~df['Team Name and Instance'].str.contains("Golden State Warriors") & df['Team Name and Instance'].str.contains("(Games 62-82)")

SAS4 = df['Team Name and Instance'].str.contains("San Antonio Spurs") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notSAS4 = ~df['Team Name and Instance'].str.contains("San Antonio Spurs") & df['Team Name and Instance'].str.contains("(Games 62-82)")

HOU4 = df['Team Name and Instance'].str.contains("Houston Rockets") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notHOU4 = ~df['Team Name and Instance'].str.contains("Houston Rockets") & df['Team Name and Instance'].str.contains("(Games 62-82)")

LAC4 = df['Team Name and Instance'].str.contains("Los Angeles Clippers") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notLAC4 = ~df['Team Name and Instance'].str.contains("Los Angeles Clippers") & df['Team Name and Instance'].str.contains("(Games 62-82)")

UTAH4 = df['Team Name and Instance'].str.contains("Utah Jazz") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notUTAH4 = ~df['Team Name and Instance'].str.contains("Utah Jazz") & df['Team Name and Instance'].str.contains("(Games 62-82)")

OKC4 = df['Team Name and Instance'].str.contains("Oklahoma City Thunder") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notOKC4 = ~df['Team Name and Instance'].str.contains("Oklahoma City Thunder") & df['Team Name and Instance'].str.contains("(Games 62-82)")

MEM4 = df['Team Name and Instance'].str.contains("Memphis Grizzlies") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notMEM4 = ~df['Team Name and Instance'].str.contains("Memphis Grizzlies") & df['Team Name and Instance'].str.contains("(Games 62-82)")

POR4 = df['Team Name and Instance'].str.contains("Portland Trailblazers") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notPOR4 = ~df['Team Name and Instance'].str.contains("Portland Trailblazers") & df['Team Name and Instance'].str.contains("(Games 62-82)")

DEN4 = df['Team Name and Instance'].str.contains("Denver Nuggets") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notDEN4 = ~df['Team Name and Instance'].str.contains("Denver Nuggets") & df['Team Name and Instance'].str.contains("(Games 62-82)")

NOP4 = df['Team Name and Instance'].str.contains("New Orleans Pelicans") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notNOP4 = ~df['Team Name and Instance'].str.contains("New Orleans Pelicans") & df['Team Name and Instance'].str.contains("(Games 62-82)")

DAL4 = df['Team Name and Instance'].str.contains("Dallas Mavericks") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notDAL4 = ~df['Team Name and Instance'].str.contains("Dallas Mavericks") & df['Team Name and Instance'].str.contains("(Games 62-82)")

SAC4 = df['Team Name and Instance'].str.contains("Sacramento Kings") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notSAC4 = ~df['Team Name and Instance'].str.contains("Sacramento Kings") & df['Team Name and Instance'].str.contains("(Games 62-82)")

MIN4 = df['Team Name and Instance'].str.contains("Minnesota Timberwolves") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notMIN4 = ~df['Team Name and Instance'].str.contains("Minnesota Timberwolves") & df['Team Name and Instance'].str.contains("(Games 62-82)")

LAL4 = df['Team Name and Instance'].str.contains("Los Angeles Lakers") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notLAL4 = ~df['Team Name and Instance'].str.contains("Los Angeles Lakers") & df['Team Name and Instance'].str.contains("(Games 62-82)")

PHO4 = df['Team Name and Instance'].str.contains("Phoenix Suns") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notPHO4 = ~df['Team Name and Instance'].str.contains("Phoenix Suns") & df['Team Name and Instance'].str.contains("(Games 62-82)")

BOS4 = df['Team Name and Instance'].str.contains("Boston Celtics") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notBOS4 = ~df['Team Name and Instance'].str.contains("Boston Celtics") & df['Team Name and Instance'].str.contains("(Games 62-82)")

CLE4 = df['Team Name and Instance'].str.contains("Cleveland Cavaliers") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notCLE4 = ~df['Team Name and Instance'].str.contains("Cleveland Cavaliers") & df['Team Name and Instance'].str.contains("(Games 62-82)")

TOR4 = df['Team Name and Instance'].str.contains("Toronto Raptors") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notTOR4 = ~df['Team Name and Instance'].str.contains("Toronto Raptors") & df['Team Name and Instance'].str.contains("(Games 62-82)")

WAS4 = df['Team Name and Instance'].str.contains("Washington Wizards") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notWAS4 = ~df['Team Name and Instance'].str.contains("Washington Wizards") & df['Team Name and Instance'].str.contains("(Games 62-82)")

ATL4 = df['Team Name and Instance'].str.contains("Atlanta Hawks") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notATL4 = ~df['Team Name and Instance'].str.contains("Atlanta Hawks") & df['Team Name and Instance'].str.contains("(Games 62-82)")

MIL4 = df['Team Name and Instance'].str.contains("Milwaukee Bucks") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notMIL4 = ~df['Team Name and Instance'].str.contains("Milwaukee Bucks") & df['Team Name and Instance'].str.contains("(Games 62-82)")

IND4 = df['Team Name and Instance'].str.contains("Indiana Pacers") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notIND4 = ~df['Team Name and Instance'].str.contains("Indiana Pacers") & df['Team Name and Instance'].str.contains("(Games 62-82)")

CHI4 = df['Team Name and Instance'].str.contains("Chicago Bulls") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notCHI4 = ~df['Team Name and Instance'].str.contains("Chicago Bulls") & df['Team Name and Instance'].str.contains("(Games 62-82)")

MIA4 = df['Team Name and Instance'].str.contains("Miami Heat") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notMIA4 = ~df['Team Name and Instance'].str.contains("Miami Heat") & df['Team Name and Instance'].str.contains("(Games 62-82)")

DET4 = df['Team Name and Instance'].str.contains("Detroit Pistons") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notDET4 = ~df['Team Name and Instance'].str.contains("Detroit Pistons") & df['Team Name and Instance'].str.contains("(Games 62-82)")

CHA4 = df['Team Name and Instance'].str.contains("Charlotte Hornets") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notCHA4 = ~df['Team Name and Instance'].str.contains("Charlotte Hornets") & df['Team Name and Instance'].str.contains("(Games 62-82)")

NYK4 = df['Team Name and Instance'].str.contains("New York Knicks") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notNYK4 = ~df['Team Name and Instance'].str.contains("New York Knicks") & df['Team Name and Instance'].str.contains("(Games 62-82)")

ORL4 = df['Team Name and Instance'].str.contains("Orlando Magic") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notORL4 = ~df['Team Name and Instance'].str.contains("Orlando Magic") & df['Team Name and Instance'].str.contains("(Games 62-82)")

PHI4 = df['Team Name and Instance'].str.contains("Philadelphia 76ers") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notPHI4 = ~df['Team Name and Instance'].str.contains("Philadelphia 76ers") & df['Team Name and Instance'].str.contains("(Games 62-82)")

BKN4 = df['Team Name and Instance'].str.contains("Brooklyn Nets") & df['Team Name and Instance'].str.contains("(Games 62-82)")
notBKN4 = ~df['Team Name and Instance'].str.contains("Brooklyn Nets") & df['Team Name and Instance'].str.contains("(Games 62-82)")

# %%
#set the data to be predicted for first quarter

X_GSW_data = df.loc[GSW1, X_stats]
y_GSW_data = df.loc[GSW1, Y_stats]

X_SAS_data = df.loc[SAS1, X_stats]
y_SAS_data = df.loc[SAS1, Y_stats]

X_HOU_data = df.loc[HOU1, X_stats]
y_HOU_data = df.loc[HOU1, Y_stats]

X_LAC_data = df.loc[LAC1, X_stats]
y_LAC_data = df.loc[LAC1, Y_stats]

X_UTAH_data = df.loc[UTAH1, X_stats]
y_UTAH_data = df.loc[UTAH1, Y_stats]

X_OKC_data = df.loc[OKC1, X_stats]
y_OKC_data = df.loc[OKC1, Y_stats]

X_MEM_data = df.loc[MEM1, X_stats]
y_MEM_data = df.loc[MEM1, Y_stats]

X_POR_data = df.loc[POR1, X_stats]
y_POR_data = df.loc[POR1, Y_stats]

X_DEN_data = df.loc[DEN1, X_stats]
y_DEN_data = df.loc[DEN1, Y_stats]

X_NOP_data = df.loc[NOP1, X_stats]
y_NOP_data = df.loc[NOP1, Y_stats]

X_DAL_data = df.loc[DAL1, X_stats]
y_DAL_data = df.loc[DAL1, Y_stats]

X_SAC_data = df.loc[SAC1, X_stats]
y_SAC_data = df.loc[SAC1, Y_stats]

X_MIN_data = df.loc[MIN1, X_stats]
y_MIN_data = df.loc[MIN1, Y_stats]

X_LAL_data = df.loc[LAL1, X_stats]
y_LAL_data = df.loc[LAL1, Y_stats]

X_PHO_data = df.loc[PHO1, X_stats]
y_PHO_data = df.loc[PHO1, Y_stats]

X_BOS_data = df.loc[BOS1, X_stats]
y_BOS_data = df.loc[BOS1, Y_stats]

X_CLE_data = df.loc[CLE1, X_stats]
y_CLE_data = df.loc[CLE1, Y_stats]

X_TOR_data = df.loc[TOR1, X_stats]
y_TOR_data = df.loc[TOR1, Y_stats]

X_WAS_data = df.loc[WAS1, X_stats]
y_WAS_data = df.loc[WAS1, Y_stats]

X_ATL_data = df.loc[ATL1, X_stats]
y_ATL_data = df.loc[ATL1, Y_stats]

X_MIL_data = df.loc[MIL1, X_stats]
y_MIL_data = df.loc[MIL1, Y_stats]

X_IND_data = df.loc[IND1, X_stats]
y_IND_data = df.loc[IND1, Y_stats]

X_CHI_data = df.loc[CHI1, X_stats]
y_CHI_data = df.loc[CHI1, Y_stats]

X_MIA_data = df.loc[MIA1, X_stats]
y_MIA_data = df.loc[MIA1, Y_stats]

X_DET_data = df.loc[DET1, X_stats]
y_DET_data = df.loc[DET1, Y_stats]

X_CHA_data = df.loc[CHA1, X_stats]
y_CHA_data = df.loc[CHA1, Y_stats]

X_NYK_data = df.loc[NYK1, X_stats]
y_NYK_data = df.loc[NYK1, Y_stats]

X_ORL_data = df.loc[ORL1, X_stats]
y_ORL_data = df.loc[ORL1, Y_stats]

X_PHI_data = df.loc[PHI1, X_stats]
y_PHI_data = df.loc[PHI1, Y_stats]

X_BKN_data = df.loc[BKN1, X_stats]
y_BKN_data = df.loc[BKN1, Y_stats]

# %%
#set the training dataset for first quarter of the season.
#this will not include the team itself

X_GSW_train = df.loc[notGSW1, X_stats]
y_GSW_train = df.loc[notGSW1, Y_stats]

X_SAS_train = df.loc[notSAS1, X_stats]
y_SAS_train = df.loc[notSAS1, Y_stats]

X_HOU_train = df.loc[notHOU1, X_stats]
y_HOU_train = df.loc[notHOU1, Y_stats]

X_LAC_train = df.loc[notLAC1, X_stats]
y_LAC_train = df.loc[notLAC1, Y_stats]

X_UTAH_train = df.loc[notUTAH1, X_stats]
y_UTAH_train = df.loc[notUTAH1, Y_stats]

X_OKC_train = df.loc[notOKC1, X_stats]
y_OKC_train = df.loc[notOKC1, Y_stats]

X_MEM_train = df.loc[notMEM1, X_stats]
y_MEM_train = df.loc[notMEM1, Y_stats]

X_POR_train = df.loc[notPOR1, X_stats]
y_POR_train = df.loc[notPOR1, Y_stats]

X_DEN_train = df.loc[notDEN1, X_stats]
y_DEN_train = df.loc[notDEN1, Y_stats]

X_NOP_train = df.loc[notNOP1, X_stats]
y_NOP_train = df.loc[notNOP1, Y_stats]

X_DAL_train = df.loc[notDAL1, X_stats]
y_DAL_train = df.loc[notDAL1, Y_stats]

X_SAC_train = df.loc[notSAC1, X_stats]
y_SAC_train = df.loc[notSAC1, Y_stats]

X_MIN_train = df.loc[notMIN1, X_stats]
y_MIN_train = df.loc[notMIN1, Y_stats]

X_LAL_train = df.loc[notLAL1, X_stats]
y_LAL_train = df.loc[notLAL1, Y_stats]

X_PHO_train = df.loc[notPHO1, X_stats]
y_PHO_train = df.loc[notPHO1, Y_stats]

X_BOS_train = df.loc[notBOS1, X_stats]
y_BOS_train = df.loc[notBOS1, Y_stats]

X_CLE_train = df.loc[notCLE1, X_stats]
y_CLE_train = df.loc[notCLE1, Y_stats]

X_TOR_train = df.loc[notTOR1, X_stats]
y_TOR_train = df.loc[notTOR1, Y_stats]

X_WAS_train = df.loc[notWAS1, X_stats]
y_WAS_train = df.loc[notWAS1, Y_stats]

X_ATL_train = df.loc[notPHO1, X_stats]
y_ATL_train = df.loc[notPHO1, Y_stats]

X_MIL_train = df.loc[notMIL1, X_stats]
y_MIL_train = df.loc[notMIL1, Y_stats]

X_IND_train = df.loc[notIND1, X_stats]
y_IND_train = df.loc[notIND1, Y_stats]

X_CHI_train = df.loc[notCHI1, X_stats]
y_CHI_train = df.loc[notCHI1, Y_stats]

X_MIA_train = df.loc[notMIA1, X_stats]
y_MIA_train = df.loc[notMIA1, Y_stats]

X_DET_train = df.loc[notDET1, X_stats]
y_DET_train = df.loc[notDET1, Y_stats]

X_CHA_train = df.loc[notCHA1, X_stats]
y_CHA_train = df.loc[notCHA1, Y_stats]

X_NYK_train = df.loc[notNYK1, X_stats]
y_NYK_train = df.loc[notNYK1, Y_stats]

X_ORL_train = df.loc[notORL1, X_stats]
y_ORL_train = df.loc[notORL1, Y_stats]

X_PHI_train = df.loc[notPHI1, X_stats]
y_PHI_train = df.loc[notPHI1, Y_stats]

X_BKN_train = df.loc[notBKN1, X_stats]
y_BKN_train = df.loc[notBKN1, Y_stats]

# %%
#implement linear regression models

from sklearn.linear_model import LinearRegression

regGSW = LinearRegression()
regGSW.fit(X_GSW_train, y_GSW_train)

regSAS = LinearRegression()
regSAS.fit(X_SAS_train, y_SAS_train)

regHOU = LinearRegression()
regHOU.fit(X_HOU_train, y_HOU_train)

regLAC = LinearRegression()
regLAC.fit(X_LAC_train, y_LAC_train)

regUTAH = LinearRegression()
regUTAH.fit(X_UTAH_train, y_UTAH_train)

regOKC = LinearRegression()
regOKC.fit(X_OKC_train, y_OKC_train)

regMEM = LinearRegression()
regMEM.fit(X_MEM_train, y_MEM_train)

regPOR = LinearRegression()
regPOR.fit(X_POR_train, y_POR_train)

regDEN = LinearRegression()
regDEN.fit(X_DEN_train, y_DEN_train)

regNOP = LinearRegression()
regNOP.fit(X_NOP_train, y_NOP_train)

regDAL = LinearRegression()
regDAL.fit(X_DAL_train, y_DAL_train)

regSAC = LinearRegression()
regSAC.fit(X_SAC_train, y_SAC_train)

regMIN = LinearRegression()
regMIN.fit(X_MIN_train, y_MIN_train)

regLAL = LinearRegression()
regLAL.fit(X_LAL_train, y_LAL_train)

regPHO = LinearRegression()
regPHO.fit(X_PHO_train, y_PHO_train)

regBOS = LinearRegression()
regBOS.fit(X_BOS_train, y_BOS_train)

regCLE = LinearRegression()
regCLE.fit(X_CLE_train, y_CLE_train)

regTOR = LinearRegression()
regTOR.fit(X_TOR_train, y_TOR_train)

regWAS = LinearRegression()
regWAS.fit(X_WAS_train, y_WAS_train)

regATL = LinearRegression()
regATL.fit(X_ATL_train, y_ATL_train)

regMIL = LinearRegression()
regMIL.fit(X_MIL_train, y_MIL_train)

regIND = LinearRegression()
regIND.fit(X_IND_train, y_IND_train)

regCHI = LinearRegression()
regCHI.fit(X_CHI_train, y_CHI_train)

regMIA = LinearRegression()
regMIA.fit(X_MIA_train, y_MIA_train)

regDET = LinearRegression()
regDET.fit(X_DET_train, y_DET_train)

regCHA = LinearRegression()
regCHA.fit(X_CHA_train, y_CHA_train)

regNYK = LinearRegression()
regNYK.fit(X_NYK_train, y_NYK_train)

regORL = LinearRegression()
regORL.fit(X_ORL_train, y_ORL_train)

regPHI = LinearRegression()
regPHI.fit(X_PHI_train, y_PHI_train)

regBKN = LinearRegression()
regBKN.fit(X_BKN_train, y_BKN_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#predict for the first quarter of the season

y_pred_GSW = regGSW.predict(X_GSW_data)

y_pred_SAS = regSAS.predict(X_SAS_data)

y_pred_HOU = regHOU.predict(X_HOU_data)

y_pred_LAC = regLAC.predict(X_LAC_data)

y_pred_UTAH = regUTAH.predict(X_UTAH_data)

y_pred_OKC = regOKC.predict(X_OKC_data)

y_pred_MEM = regMEM.predict(X_MEM_data)

y_pred_POR = regPOR.predict(X_POR_data)

y_pred_DEN = regDEN.predict(X_DEN_data)

y_pred_NOP = regNOP.predict(X_NOP_data)

y_pred_DAL = regDAL.predict(X_DAL_data)

y_pred_SAC = regSAC.predict(X_SAC_data)

y_pred_MIN = regMIN.predict(X_MIN_data)

y_pred_LAL = regLAL.predict(X_LAL_data)

y_pred_PHO = regPHO.predict(X_PHO_data)

y_pred_BOS = regBOS.predict(X_BOS_data)

y_pred_CLE = regCLE.predict(X_CLE_data)

y_pred_TOR = regTOR.predict(X_TOR_data)

y_pred_WAS = regWAS.predict(X_WAS_data)

y_pred_ATL = regATL.predict(X_ATL_data)

y_pred_MIL = regMIL.predict(X_MIL_data)

y_pred_IND = regIND.predict(X_IND_data)

y_pred_CHI = regCHI.predict(X_CHI_data)

y_pred_MIA = regMIA.predict(X_MIA_data)

y_pred_DET = regDET.predict(X_DET_data)

y_pred_CHA = regCHA.predict(X_CHA_data)

y_pred_NYK = regNYK.predict(X_NYK_data)

y_pred_ORL = regORL.predict(X_ORL_data)

y_pred_PHI = regPHI.predict(X_PHI_data)

y_pred_BKN = regBKN.predict(X_BKN_data)

# %%
#put the differences for the first quarter here

diff_GSW = y_GSW_data - y_pred_GSW

diff_SAS = y_SAS_data - y_pred_SAS

diff_HOU = y_HOU_data - y_pred_HOU

diff_LAC = y_LAC_data - y_pred_LAC

diff_UTAH = y_UTAH_data - y_pred_UTAH

diff_OKC = y_OKC_data - y_pred_OKC

diff_MEM = y_MEM_data - y_pred_MEM

diff_POR = y_POR_data - y_pred_POR

diff_DEN = y_DEN_data - y_pred_DEN

diff_NOP = y_NOP_data - y_pred_NOP

diff_DAL = y_DAL_data - y_pred_DAL

diff_SAC = y_SAC_data - y_pred_SAC

diff_MIN = y_MIN_data - y_pred_MIN

diff_LAL = y_LAL_data - y_pred_LAL

diff_PHO = y_PHO_data - y_pred_PHO

diff_BOS = y_BOS_data - y_pred_BOS

diff_CLE = y_CLE_data - y_pred_CLE

diff_TOR = y_TOR_data - y_pred_TOR

diff_WAS = y_WAS_data - y_pred_WAS

diff_ATL = y_ATL_data - y_pred_ATL

diff_MIL = y_MIL_data - y_pred_MIL

diff_IND = y_IND_data - y_pred_IND

diff_CHI = y_CHI_data - y_pred_CHI

diff_MIA = y_MIA_data - y_pred_MIA

diff_DET = y_DET_data - y_pred_DET

diff_CHA = y_CHA_data - y_pred_CHA

diff_NYK = y_NYK_data - y_pred_NYK

diff_ORL = y_ORL_data - y_pred_ORL

diff_PHI = y_PHI_data - y_pred_PHI

diff_BKN = y_BKN_data - y_pred_BKN

# %%
#get percent error for first quarter

err_GSW = round(abs(diff_GSW / y_GSW_data) * 100, 2)

err_SAS = round(abs(diff_SAS / y_SAS_data) * 100, 2)

err_HOU = round(abs(diff_HOU / y_HOU_data) * 100, 2)

err_LAC = round(abs(diff_LAC / y_LAC_data) * 100, 2)

err_UTAH = round(abs(diff_UTAH / y_UTAH_data) * 100, 2)

err_OKC = round(abs(diff_OKC / y_OKC_data) * 100, 2)

err_MEM = round(abs(diff_MEM / y_MEM_data) * 100, 2)

err_POR = round(abs(diff_POR / y_POR_data) * 100, 2)

err_DEN = round(abs(diff_DEN / y_DEN_data) * 100, 2)

err_NOP = round(abs(diff_NOP / y_NOP_data) * 100, 2)

err_DAL = round(abs(diff_DAL / y_DAL_data) * 100, 2)

err_SAC = round(abs(diff_SAC / y_SAC_data) * 100, 2)

err_MIN = round(abs(diff_MIN / y_MIN_data) * 100, 2)

err_LAL = round(abs(diff_LAL / y_LAL_data) * 100, 2)

err_PHO = round(abs(diff_PHO / y_PHO_data) * 100, 2)

err_BOS = round(abs(diff_BOS / y_BOS_data) * 100, 2)

err_CLE = round(abs(diff_CLE / y_CLE_data) * 100, 2)

err_TOR = round(abs(diff_TOR / y_TOR_data) * 100, 2)

err_WAS = round(abs(diff_WAS / y_WAS_data) * 100, 2)

err_ATL = round(abs(diff_ATL / y_ATL_data) * 100, 2)

err_MIL = round(abs(diff_MIL / y_MIL_data) * 100, 2)

err_IND = round(abs(diff_IND / y_IND_data) * 100, 2)

err_CHI = round(abs(diff_CHI / y_CHI_data) * 100, 2)

err_MIA = round(abs(diff_MIA / y_MIA_data) * 100, 2)

err_DET = round(abs(diff_DET / y_DET_data) * 100, 2)

err_CHA = round(abs(diff_CHA / y_CHA_data) * 100, 2)

err_NYK = round(abs(diff_NYK / y_NYK_data) * 100, 2)

err_ORL = round(abs(diff_ORL / y_ORL_data) * 100, 2)

err_PHI = round(abs(diff_PHI / y_PHI_data) * 100, 2)

err_BKN = round(abs(diff_BKN / y_BKN_data) * 100, 2)

# %%
pd.DataFrame(list(zip(X_GSW_train.columns, regGSW.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Defensive Rebounds
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.248336
# 1  Defensive Rebounds         -0.658186
# 2      Average Points         -0.064502
# 3           Attendees          0.002890
# 4     Team Efficiency          0.299892

# %%
pd.DataFrame(list(zip(X_SAS_train.columns, regSAS.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Defensive Rebounds
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.409129
# 1  Defensive Rebounds         -1.178692
# 2      Average Points         -0.066196
# 3           Attendees          0.004566
# 4     Team Efficiency          0.661555

# %%
pd.DataFrame(list(zip(X_HOU_train.columns, regHOU.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.513912
# 1  Defensive Rebounds         -0.867608
# 2      Average Points         -0.144978
# 3           Attendees          0.004324
# 4     Team Efficiency          0.670369

# %%
pd.DataFrame(list(zip(X_LAC_train.columns, regLAC.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.480190
# 1  Defensive Rebounds         -1.153386
# 2      Average Points          0.078769
# 3           Attendees          0.004375
# 4     Team Efficiency          0.572663

# %%
pd.DataFrame(list(zip(X_UTAH_train.columns, regUTAH.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.423220
# 1  Defensive Rebounds         -1.189511
# 2      Average Points         -0.015697
# 3           Attendees          0.004558
# 4     Team Efficiency          0.640179

# %%
pd.DataFrame(list(zip(X_OKC_train.columns, regOKC.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.417003
# 1  Defensive Rebounds         -1.189320
# 2      Average Points         -0.054602
# 3           Attendees          0.004564
# 4     Team Efficiency          0.655078

# %%
pd.DataFrame(list(zip(X_MEM_train.columns, regMEM.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.428827
# 1  Defensive Rebounds         -1.129755
# 2      Average Points         -0.136261
# 3           Attendees          0.004409
# 4     Team Efficiency          0.695449

# %%
pd.DataFrame(list(zip(X_POR_train.columns, regPOR.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.422845
# 1  Defensive Rebounds         -1.307414
# 2      Average Points         -0.096720
# 3           Attendees          0.004515
# 4     Team Efficiency          0.719575

# %%
pd.DataFrame(list(zip(X_DEN_train.columns, regDEN.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.469443
# 1  Defensive Rebounds         -0.931857
# 2      Average Points         -0.465682
# 3           Attendees          0.004522
# 4     Team Efficiency          0.967125

# %%
pd.DataFrame(list(zip(X_NOP_train.columns, regNOP.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.390676
# 1  Defensive Rebounds         -1.145021
# 2      Average Points         -0.116808
# 3           Attendees          0.004634
# 4     Team Efficiency          0.659520

# %%
pd.DataFrame(list(zip(X_DAL_train.columns, regDAL.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.355915
# 1  Defensive Rebounds         -1.388136
# 2      Average Points          0.109475
# 3           Attendees          0.005230
# 4     Team Efficiency          0.552371

# %%
pd.DataFrame(list(zip(X_SAC_train.columns, regSAC.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.455709
# 1  Defensive Rebounds         -1.181167
# 2      Average Points         -0.018944
# 3           Attendees          0.004364
# 4     Team Efficiency          0.653306

# %%
pd.DataFrame(list(zip(X_MIN_train.columns, regMIN.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.395811
# 1  Defensive Rebounds         -1.200789
# 2      Average Points         -0.004010
# 3           Attendees          0.004936
# 4     Team Efficiency          0.618804

# %%
pd.DataFrame(list(zip(X_LAL_train.columns, regLAL.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.473177
# 1  Defensive Rebounds         -1.317798
# 2      Average Points          0.045476
# 3           Attendees          0.005361
# 4     Team Efficiency          0.656715

# %%
pd.DataFrame(list(zip(X_PHO_train.columns, regPHO.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.417195
# 1  Defensive Rebounds         -1.184738
# 2      Average Points         -0.062857
# 3           Attendees          0.004580
# 4     Team Efficiency          0.663954

# %%
pd.DataFrame(list(zip(X_BOS_train.columns, regBOS.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.476360
# 1  Defensive Rebounds         -1.465649
# 2      Average Points          0.149812
# 3           Attendees          0.004579
# 4     Team Efficiency          0.599241

# %%
pd.DataFrame(list(zip(X_CLE_train.columns, regCLE.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.106854
# 1  Defensive Rebounds         -0.534729
# 2      Average Points         -0.351804
# 3           Attendees          0.003304
# 4     Team Efficiency          0.949331

# %%
pd.DataFrame(list(zip(X_TOR_train.columns, regTOR.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.407504
# 1  Defensive Rebounds         -1.171874
# 2      Average Points         -0.092604
# 3           Attendees          0.004699
# 4     Team Efficiency          0.715941

# %%
pd.DataFrame(list(zip(X_WAS_train.columns, regWAS.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.420463
# 1  Defensive Rebounds         -1.070258
# 2      Average Points         -0.117136
# 3           Attendees          0.004531
# 4     Team Efficiency          0.668317

# %%
pd.DataFrame(list(zip(X_ATL_train.columns, regATL.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.417195
# 1  Defensive Rebounds         -1.184738
# 2      Average Points         -0.062857
# 3           Attendees          0.004580
# 4     Team Efficiency          0.663954

# %%
pd.DataFrame(list(zip(X_MIL_train.columns, regMIL.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.592890
# 1  Defensive Rebounds         -1.653623
# 2      Average Points          0.009490
# 3           Attendees          0.005010
# 4     Team Efficiency          0.583862

# %%
pd.DataFrame(list(zip(X_IND_train.columns, regIND.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.414744
# 1  Defensive Rebounds         -1.185399
# 2      Average Points         -0.059060
# 3           Attendees          0.004571
# 4     Team Efficiency          0.658294

# %%
pd.DataFrame(list(zip(X_CHI_train.columns, regCHI.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.432975
# 1  Defensive Rebounds         -1.073715
# 2      Average Points         -0.097035
# 3           Attendees          0.004976
# 4     Team Efficiency          0.534890

# %%
pd.DataFrame(list(zip(X_MIA_train.columns, regMIA.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.426956
# 1  Defensive Rebounds         -1.186623
# 2      Average Points         -0.074139
# 3           Attendees          0.004492
# 4     Team Efficiency          0.681403

# %%
pd.DataFrame(list(zip(X_DET_train.columns, regDET.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.418779
# 1  Defensive Rebounds         -1.184466
# 2      Average Points         -0.070597
# 3           Attendees          0.004582
# 4     Team Efficiency          0.667767

# %%
pd.DataFrame(list(zip(X_CHA_train.columns, regCHA.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.381826
# 1  Defensive Rebounds         -1.251368
# 2      Average Points         -0.021741
# 3           Attendees          0.004486
# 4     Team Efficiency          0.686335

# %%
pd.DataFrame(list(zip(X_NYK_train.columns, regNYK.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.456544
# 1  Defensive Rebounds         -1.526545
# 2      Average Points          0.178633
# 3           Attendees          0.004977
# 4     Team Efficiency          0.517619

# %%
pd.DataFrame(list(zip(X_ORL_train.columns, regORL.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.404348
# 1  Defensive Rebounds         -1.127232
# 2      Average Points         -0.202028
# 3           Attendees          0.004484
# 4     Team Efficiency          0.730604

# %%
pd.DataFrame(list(zip(X_PHI_train.columns, regPHI.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.420781
# 1  Defensive Rebounds         -1.376933
# 2      Average Points         -0.059405
# 3           Attendees          0.004560
# 4     Team Efficiency          0.698099

# %%
pd.DataFrame(list(zip(X_BKN_train.columns, regBKN.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.411144
# 1  Defensive Rebounds         -1.197528
# 2      Average Points         -0.057324
# 3           Attendees          0.004543
# 4     Team Efficiency          0.657738

# %%
X_GSW_data2 = df.loc[GSW2, X_stats]
y_GSW_data2 = df.loc[GSW2, Y_stats]

X_SAS_data2 = df.loc[SAS2, X_stats]
y_SAS_data2 = df.loc[SAS2, Y_stats]

X_HOU_data2 = df.loc[HOU2, X_stats]
y_HOU_data2 = df.loc[HOU2, Y_stats]

X_LAC_data2 = df.loc[LAC2, X_stats]
y_LAC_data2 = df.loc[LAC2, Y_stats]

X_UTAH_data2 = df.loc[UTAH2, X_stats]
y_UTAH_data2 = df.loc[UTAH2, Y_stats]

X_OKC_data2 = df.loc[OKC2, X_stats]
y_OKC_data2 = df.loc[OKC2, Y_stats]

X_MEM_data2 = df.loc[MEM2, X_stats]
y_MEM_data2 = df.loc[MEM2, Y_stats]

X_POR_data2 = df.loc[POR2, X_stats]
y_POR_data2 = df.loc[POR2, Y_stats]

X_DEN_data2 = df.loc[DEN2, X_stats]
y_DEN_data2 = df.loc[DEN2, Y_stats]

X_NOP_data2 = df.loc[NOP2, X_stats]
y_NOP_data2 = df.loc[NOP2, Y_stats]

X_DAL_data2 = df.loc[DAL2, X_stats]
y_DAL_data2 = df.loc[DAL2, Y_stats]

X_SAC_data2 = df.loc[SAC2, X_stats]
y_SAC_data2 = df.loc[SAC2, Y_stats]

X_MIN_data2 = df.loc[MIN2, X_stats]
y_MIN_data2 = df.loc[MIN2, Y_stats]

X_LAL_data2 = df.loc[LAL2, X_stats]
y_LAL_data2 = df.loc[LAL2, Y_stats]

X_PHO_data2 = df.loc[PHO2, X_stats]
y_PHO_data2 = df.loc[PHO2, Y_stats]

X_BOS_data2 = df.loc[BOS2, X_stats]
y_BOS_data2 = df.loc[BOS2, Y_stats]

X_CLE_data2 = df.loc[CLE2, X_stats]
y_CLE_data2 = df.loc[CLE2, Y_stats]

X_TOR_data2 = df.loc[TOR2, X_stats]
y_TOR_data2 = df.loc[TOR2, Y_stats]

X_WAS_data2 = df.loc[WAS2, X_stats]
y_WAS_data2 = df.loc[WAS2, Y_stats]

X_ATL_data2 = df.loc[ATL2, X_stats]
y_ATL_data2 = df.loc[ATL2, Y_stats]

X_MIL_data2 = df.loc[MIL2, X_stats]
y_MIL_data2 = df.loc[MIL2, Y_stats]

X_IND_data2 = df.loc[IND2, X_stats]
y_IND_data2 = df.loc[IND2, Y_stats]

X_CHI_data2 = df.loc[CHI2, X_stats]
y_CHI_data2 = df.loc[CHI2, Y_stats]

X_MIA_data2 = df.loc[MIA2, X_stats]
y_MIA_data2 = df.loc[MIA2, Y_stats]

X_DET_data2 = df.loc[DET2, X_stats]
y_DET_data2 = df.loc[DET2, Y_stats]

X_CHA_data2 = df.loc[CHA2, X_stats]
y_CHA_data2 = df.loc[CHA2, Y_stats]

X_NYK_data2 = df.loc[NYK2, X_stats]
y_NYK_data2 = df.loc[NYK2, Y_stats]

X_ORL_data2 = df.loc[ORL2, X_stats]
y_ORL_data2 = df.loc[ORL2, Y_stats]

X_PHI_data2 = df.loc[PHI2, X_stats]
y_PHI_data2 = df.loc[PHI2, Y_stats]

X_BKN_data2 = df.loc[BKN2, X_stats]
y_BKN_data2 = df.loc[BKN2, Y_stats]

# %%
#set training data for second quarter of the season

X_GSW_train2 = df.loc[notGSW2, X_stats]
y_GSW_train2 = df.loc[notGSW2, Y_stats]

X_SAS_train2 = df.loc[notSAS2, X_stats]
y_SAS_train2 = df.loc[notSAS2, Y_stats]

X_HOU_train2 = df.loc[notHOU2, X_stats]
y_HOU_train2 = df.loc[notHOU2, Y_stats]

X_LAC_train2 = df.loc[notLAC2, X_stats]
y_LAC_train2 = df.loc[notLAC2, Y_stats]

X_UTAH_train2 = df.loc[notUTAH2, X_stats]
y_UTAH_train2 = df.loc[notUTAH2, Y_stats]

X_OKC_train2 = df.loc[notOKC2, X_stats]
y_OKC_train2 = df.loc[notOKC2, Y_stats]

X_MEM_train2 = df.loc[notMEM2, X_stats]
y_MEM_train2 = df.loc[notMEM2, Y_stats]

X_POR_train2 = df.loc[notPOR2, X_stats]
y_POR_train2 = df.loc[notPOR2, Y_stats]

X_DEN_train2 = df.loc[notDEN2, X_stats]
y_DEN_train2 = df.loc[notDEN2, Y_stats]

X_NOP_train2 = df.loc[notNOP2, X_stats]
y_NOP_train2 = df.loc[notNOP2, Y_stats]

X_DAL_train2 = df.loc[notDAL2, X_stats]
y_DAL_train2 = df.loc[notDAL2, Y_stats]

X_SAC_train2 = df.loc[notSAC2, X_stats]
y_SAC_train2 = df.loc[notSAC2, Y_stats]

X_MIN_train2 = df.loc[notMIN2, X_stats]
y_MIN_train2 = df.loc[notMIN2, Y_stats]

X_LAL_train2 = df.loc[notLAL2, X_stats]
y_LAL_train2 = df.loc[notLAL2, Y_stats]

X_PHO_train2 = df.loc[notPHO2, X_stats]
y_PHO_train2 = df.loc[notPHO2, Y_stats]

X_BOS_train2 = df.loc[notBOS2, X_stats]
y_BOS_train2 = df.loc[notBOS2, Y_stats]

X_CLE_train2 = df.loc[notCLE2, X_stats]
y_CLE_train2 = df.loc[notCLE2, Y_stats]

X_TOR_train2 = df.loc[notTOR2, X_stats]
y_TOR_train2 = df.loc[notTOR2, Y_stats]

X_WAS_train2 = df.loc[notWAS2, X_stats]
y_WAS_train2 = df.loc[notWAS2, Y_stats]

X_ATL_train2 = df.loc[notPHO2, X_stats]
y_ATL_train2 = df.loc[notPHO2, Y_stats]

X_MIL_train2 = df.loc[notMIL2, X_stats]
y_MIL_train2 = df.loc[notMIL2, Y_stats]

X_IND_train2 = df.loc[notIND2, X_stats]
y_IND_train2 = df.loc[notIND2, Y_stats]

X_CHI_train2 = df.loc[notCHI2, X_stats]
y_CHI_train2 = df.loc[notCHI2, Y_stats]

X_MIA_train2 = df.loc[notMIA2, X_stats]
y_MIA_train2 = df.loc[notMIA2, Y_stats]

X_DET_train2 = df.loc[notDET2, X_stats]
y_DET_train2 = df.loc[notDET2, Y_stats]

X_CHA_train2 = df.loc[notCHA2, X_stats]
y_CHA_train2 = df.loc[notCHA2, Y_stats]

X_NYK_train2 = df.loc[notNYK2, X_stats]
y_NYK_train2 = df.loc[notNYK2, Y_stats]

X_ORL_train2 = df.loc[notORL2, X_stats]
y_ORL_train2 = df.loc[notORL2, Y_stats]

X_PHI_train2 = df.loc[notPHI2, X_stats]
y_PHI_train2 = df.loc[notPHI2, Y_stats]

X_BKN_train2 = df.loc[notBKN2, X_stats]
y_BKN_train2 = df.loc[notBKN2, Y_stats]

# %%
#implement linear regression models

regGSW2 = LinearRegression()
regGSW2.fit(X_GSW_train2, y_GSW_train2)

regSAS2 = LinearRegression()
regSAS2.fit(X_SAS_train2, y_SAS_train2)

regHOU2 = LinearRegression()
regHOU2.fit(X_HOU_train2, y_HOU_train2)

regLAC2 = LinearRegression()
regLAC2.fit(X_LAC_train2, y_LAC_train2)

regUTAH2 = LinearRegression()
regUTAH2.fit(X_UTAH_train2, y_UTAH_train2)

regOKC2 = LinearRegression()
regOKC2.fit(X_OKC_train2, y_OKC_train2)

regMEM2 = LinearRegression()
regMEM2.fit(X_MEM_train2, y_MEM_train2)

regPOR2 = LinearRegression()
regPOR2.fit(X_POR_train2, y_POR_train2)

regDEN2 = LinearRegression()
regDEN2.fit(X_DEN_train2, y_DEN_train2)

regNOP2 = LinearRegression()
regNOP2.fit(X_NOP_train2, y_NOP_train2)

regDAL2 = LinearRegression()
regDAL2.fit(X_DAL_train2, y_DAL_train2)

regSAC2 = LinearRegression()
regSAC2.fit(X_SAC_train2, y_SAC_train2)

regMIN2 = LinearRegression()
regMIN2.fit(X_MIN_train2, y_MIN_train2)

regLAL2 = LinearRegression()
regLAL2.fit(X_LAL_train2, y_LAL_train2)

regPHO2 = LinearRegression()
regPHO2.fit(X_PHO_train2, y_PHO_train2)

regBOS2 = LinearRegression()
regBOS2.fit(X_BOS_train2, y_BOS_train2)

regCLE2 = LinearRegression()
regCLE2.fit(X_CLE_train2, y_CLE_train2)

regTOR2 = LinearRegression()
regTOR2.fit(X_TOR_train2, y_TOR_train2)

regWAS2 = LinearRegression()
regWAS2.fit(X_WAS_train2, y_WAS_train2)

regATL2 = LinearRegression()
regATL2.fit(X_ATL_train2, y_ATL_train2)

regMIL2 = LinearRegression()
regMIL2.fit(X_MIL_train2, y_MIL_train2)

regIND2 = LinearRegression()
regIND2.fit(X_IND_train2, y_IND_train2)

regCHI2 = LinearRegression()
regCHI2.fit(X_CHI_train2, y_CHI_train2)

regMIA2 = LinearRegression()
regMIA2.fit(X_MIA_train2, y_MIA_train2)

regDET2 = LinearRegression()
regDET2.fit(X_DET_train2, y_DET_train2)

regCHA2 = LinearRegression()
regCHA2.fit(X_CHA_train2, y_CHA_train2)

regNYK2 = LinearRegression()
regNYK2.fit(X_NYK_train2, y_NYK_train2)

regORL2 = LinearRegression()
regORL2.fit(X_ORL_train2, y_ORL_train2)

regPHI2 = LinearRegression()
regPHI2.fit(X_PHI_train2, y_PHI_train2)

regBKN2 = LinearRegression()
regBKN2.fit(X_BKN_train2, y_BKN_train2)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#predict for the second quarter of the season

y_pred_GSW2 = regGSW2.predict(X_GSW_data2)

y_pred_SAS2 = regSAS2.predict(X_SAS_data2)

y_pred_HOU2 = regHOU2.predict(X_HOU_data2)

y_pred_LAC2 = regLAC2.predict(X_LAC_data2)

y_pred_UTAH2 = regUTAH2.predict(X_UTAH_data2)

y_pred_OKC2 = regOKC2.predict(X_OKC_data2)

y_pred_MEM2 = regMEM2.predict(X_MEM_data2)

y_pred_POR2 = regPOR2.predict(X_POR_data2)

y_pred_DEN2 = regDEN2.predict(X_DEN_data2)

y_pred_NOP2 = regNOP2.predict(X_NOP_data2)

y_pred_DAL2 = regDAL2.predict(X_DAL_data2)

y_pred_SAC2 = regSAC2.predict(X_SAC_data2)

y_pred_MIN2 = regMIN2.predict(X_MIN_data2)

y_pred_LAL2 = regLAL2.predict(X_LAL_data2)

y_pred_PHO2 = regPHO2.predict(X_PHO_data2)

y_pred_BOS2 = regBOS2.predict(X_BOS_data2)

y_pred_CLE2 = regCLE2.predict(X_CLE_data2)

y_pred_TOR2 = regTOR2.predict(X_TOR_data2)

y_pred_WAS2 = regWAS2.predict(X_WAS_data2)

y_pred_ATL2 = regATL2.predict(X_ATL_data2)

y_pred_MIL2 = regMIL2.predict(X_MIL_data2)

y_pred_IND2 = regIND2.predict(X_IND_data2)

y_pred_CHI2 = regCHI2.predict(X_CHI_data2)

y_pred_MIA2 = regMIA2.predict(X_MIA_data2)

y_pred_DET2 = regDET2.predict(X_DET_data2)

y_pred_CHA2 = regCHA2.predict(X_CHA_data2)

y_pred_NYK2 = regNYK2.predict(X_NYK_data2)

y_pred_ORL2 = regORL2.predict(X_ORL_data2)

y_pred_PHI2 = regPHI2.predict(X_PHI_data2)

y_pred_BKN2 = regBKN2.predict(X_BKN_data2)

# %%
#put the differences for the second quarter here

diff_GSW2 = y_GSW_data2 - y_pred_GSW2

diff_SAS2 = y_SAS_data2 - y_pred_SAS2

diff_HOU2 = y_HOU_data2 - y_pred_HOU2

diff_LAC2 = y_LAC_data2 - y_pred_LAC2

diff_UTAH2 = y_UTAH_data2 - y_pred_UTAH2

diff_OKC2 = y_OKC_data2 - y_pred_OKC2

diff_MEM2 = y_MEM_data2 - y_pred_MEM2

diff_POR2 = y_POR_data2 - y_pred_POR2

diff_DEN2 = y_DEN_data2 - y_pred_DEN2

diff_NOP2 = y_NOP_data2 - y_pred_NOP2

diff_DAL2 = y_DAL_data2 - y_pred_DAL2

diff_SAC2 = y_SAC_data2 - y_pred_SAC2

diff_MIN2 = y_MIN_data2 - y_pred_MIN2

diff_LAL2 = y_LAL_data2 - y_pred_LAL2

diff_PHO2 = y_PHO_data2 - y_pred_PHO2

diff_BOS2 = y_BOS_data2 - y_pred_BOS2

diff_CLE2 = y_CLE_data2 - y_pred_CLE2

diff_TOR2 = y_TOR_data2 - y_pred_TOR2

diff_WAS2 = y_WAS_data2 - y_pred_WAS2

diff_ATL2 = y_ATL_data2 - y_pred_ATL2

diff_MIL2 = y_MIL_data2 - y_pred_MIL2

diff_IND2 = y_IND_data2 - y_pred_IND2

diff_CHI2 = y_CHI_data2 - y_pred_CHI2

diff_MIA2 = y_MIA_data2 - y_pred_MIA2

diff_DET2 = y_DET_data2 - y_pred_DET2

diff_CHA2 = y_CHA_data2 - y_pred_CHA2

diff_NYK2 = y_NYK_data2 - y_pred_NYK2

diff_ORL2 = y_ORL_data2 - y_pred_ORL2

diff_PHI2 = y_PHI_data2 - y_pred_PHI2

diff_BKN2 = y_BKN_data2 - y_pred_BKN2

# %%
#get percent error for second quarter

err_GSW2 = round(abs(diff_GSW2 / y_GSW_data2) * 100, 2)

err_SAS2 = round(abs(diff_SAS2 / y_SAS_data2) * 100, 2)

err_HOU2 = round(abs(diff_HOU2 / y_HOU_data2) * 100, 2)

err_LAC2 = round(abs(diff_LAC2 / y_LAC_data2) * 100, 2)

err_UTAH2 = round(abs(diff_UTAH2 / y_UTAH_data2) * 100, 2)

err_OKC2 = round(abs(diff_OKC2 / y_OKC_data2) * 100, 2)

err_MEM2 = round(abs(diff_MEM2 / y_MEM_data2) * 100, 2)

err_POR2 = round(abs(diff_POR2 / y_POR_data2) * 100, 2)

err_DEN2 = round(abs(diff_DEN2 / y_DEN_data2) * 100, 2)

err_NOP2 = round(abs(diff_NOP2 / y_NOP_data2) * 100, 2)

err_DAL2 = round(abs(diff_DAL2 / y_DAL_data2) * 100, 2)

err_SAC2 = round(abs(diff_SAC2 / y_SAC_data2) * 100, 2)

err_MIN2 = round(abs(diff_MIN2 / y_MIN_data2) * 100, 2)

err_LAL2 = round(abs(diff_LAL2 / y_LAL_data2) * 100, 2)

err_PHO2 = round(abs(diff_PHO2 / y_PHO_data2) * 100, 2)

err_BOS2 = round(abs(diff_BOS2 / y_BOS_data2) * 100, 2)

err_CLE2 = round(abs(diff_CLE2 / y_CLE_data2) * 100, 2)

err_TOR2 = round(abs(diff_TOR2 / y_TOR_data2) * 100, 2)

err_WAS2 = round(abs(diff_WAS2 / y_WAS_data2) * 100, 2)

err_ATL2 = round(abs(diff_ATL2 / y_ATL_data2) * 100, 2)

err_MIL2 = round(abs(diff_MIL2 / y_MIL_data2) * 100, 2)

err_IND2 = round(abs(diff_IND2 / y_IND_data2) * 100, 2)

err_CHI2 = round(abs(diff_CHI2 / y_CHI_data2) * 100, 2)

err_MIA2 = round(abs(diff_MIA2 / y_MIA_data2) * 100, 2)

err_DET2 = round(abs(diff_DET2 / y_DET_data2) * 100, 2)

err_CHA2 = round(abs(diff_CHA2 / y_CHA_data2) * 100, 2)

err_NYK2 = round(abs(diff_NYK2 / y_NYK_data2) * 100, 2)

err_ORL2 = round(abs(diff_ORL2 / y_ORL_data2) * 100, 2)

err_PHI2 = round(abs(diff_PHI2 / y_PHI_data2) * 100, 2)

err_BKN2 = round(abs(diff_BKN2 / y_BKN_data2) * 100, 2)

# %%
pd.DataFrame(list(zip(X_GSW_train2.columns, regGSW2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.065298
# 1  Defensive Rebounds         -0.777481
# 2      Average Points         -0.412097
# 3           Attendees          0.002673
# 4     Team Efficiency          0.549197

# %%
pd.DataFrame(list(zip(X_SAS_train2.columns, regSAS2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.020996
# 1  Defensive Rebounds         -0.824167
# 2      Average Points         -0.316300
# 3           Attendees          0.003667
# 4     Team Efficiency          0.607285

# %%
pd.DataFrame(list(zip(X_HOU_train2.columns, regHOU2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.012689
# 1  Defensive Rebounds         -0.817551
# 2      Average Points         -0.319220
# 3           Attendees          0.003672
# 4     Team Efficiency          0.618121

# %%
pd.DataFrame(list(zip(X_LAC_train2.columns, regLAC2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.076764
# 1  Defensive Rebounds         -0.849896
# 2      Average Points         -0.172553
# 3           Attendees          0.003689
# 4     Team Efficiency          0.529730

# %%
pd.DataFrame(list(zip(X_UTAH_train2.columns, regUTAH2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.007680
# 1  Defensive Rebounds         -0.831773
# 2      Average Points         -0.290368
# 3           Attendees          0.003684
# 4     Team Efficiency          0.598304

# %%
pd.DataFrame(list(zip(X_OKC_train2.columns, regOKC2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.035865
# 1  Defensive Rebounds         -0.832605
# 2      Average Points         -0.396924
# 3           Attendees          0.003612
# 4     Team Efficiency          0.661752

# %%
pd.DataFrame(list(zip(X_MEM_train2.columns, regMEM2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.001952
# 1  Defensive Rebounds         -0.777726
# 2      Average Points         -0.412145
# 3           Attendees          0.003548
# 4     Team Efficiency          0.663785

# %%
pd.DataFrame(list(zip(X_POR_train2.columns, regPOR2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.010132
# 1  Defensive Rebounds         -0.813944
# 2      Average Points         -0.338940
# 3           Attendees          0.003604
# 4     Team Efficiency          0.633098

# %%
pd.DataFrame(list(zip(X_DEN_train2.columns, regDEN2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.024210
# 1  Defensive Rebounds         -0.824346
# 2      Average Points         -0.617697
# 3           Attendees          0.003497
# 4     Team Efficiency          0.878666

# %%
pd.DataFrame(list(zip(X_NOP_train2.columns, regNOP2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.035432
# 1  Defensive Rebounds         -0.864401
# 2      Average Points         -0.332067
# 3           Attendees          0.003895
# 4     Team Efficiency          0.599024

# %%
pd.DataFrame(list(zip(X_DAL_train2.columns, regDAL2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.042556
# 1  Defensive Rebounds         -0.633252
# 2      Average Points         -0.255619
# 3           Attendees          0.003767
# 4     Team Efficiency          0.532723

# %%
pd.DataFrame(list(zip(X_SAC_train2.columns, regSAC2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.016083
# 1  Defensive Rebounds         -0.983496
# 2      Average Points         -0.229409
# 3           Attendees          0.003589
# 4     Team Efficiency          0.601069

# %%
pd.DataFrame(list(zip(X_MIN_train2.columns, regMIN2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.019257
# 1  Defensive Rebounds         -0.764753
# 2      Average Points         -0.311330
# 3           Attendees          0.003712
# 4     Team Efficiency          0.593795

# %%
pd.DataFrame(list(zip(X_LAL_train2.columns, regLAL2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.016428
# 1  Defensive Rebounds         -0.524295
# 2      Average Points         -0.194640
# 3           Attendees          0.003897
# 4     Team Efficiency          0.507010

# %%
pd.DataFrame(list(zip(X_PHO_train2.columns, regPHO2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.003410
# 1  Defensive Rebounds         -0.849377
# 2      Average Points         -0.321774
# 3           Attendees          0.003580
# 4     Team Efficiency          0.620874

# %%
pd.DataFrame(list(zip(X_BOS_train2.columns, regBOS2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.062332
# 1  Defensive Rebounds         -0.962318
# 2      Average Points         -0.387674
# 3           Attendees          0.003870
# 4     Team Efficiency          0.733869

# %%
pd.DataFrame(list(zip(X_CLE_train2.columns, regCLE2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.091686
# 1  Defensive Rebounds         -0.047814
# 2      Average Points         -0.311893
# 3           Attendees          0.002452
# 4     Team Efficiency          0.804194

# %%
pd.DataFrame(list(zip(X_TOR_train2.columns, regTOR2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.004185
# 1  Defensive Rebounds         -0.909729
# 2      Average Points         -0.303317
# 3           Attendees          0.003878
# 4     Team Efficiency          0.612392

# %%
pd.DataFrame(list(zip(X_WAS_train2.columns, regWAS2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.000999
# 1  Defensive Rebounds         -0.782821
# 2      Average Points         -0.325495
# 3           Attendees          0.003654
# 4     Team Efficiency          0.620340

# %%
pd.DataFrame(list(zip(X_ATL_train2.columns, regATL2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.003410
# 1  Defensive Rebounds         -0.849377
# 2      Average Points         -0.321774
# 3           Attendees          0.003580
# 4     Team Efficiency          0.620874

# %%
pd.DataFrame(list(zip(X_MIL_train2.columns, regMIL2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.070690
# 1  Defensive Rebounds         -1.150470
# 2      Average Points         -0.265641
# 3           Attendees          0.003929
# 4     Team Efficiency          0.593614

# %%
pd.DataFrame(list(zip(X_IND_train2.columns, regIND2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.022835
# 1  Defensive Rebounds         -0.832582
# 2      Average Points         -0.276526
# 3           Attendees          0.003707
# 4     Team Efficiency          0.579184

# %%
pd.DataFrame(list(zip(X_CHI_train2.columns, regCHI2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.138155
# 1  Defensive Rebounds         -1.015111
# 2      Average Points         -0.381151
# 3           Attendees          0.004497
# 4     Team Efficiency          0.577934

# %%
pd.DataFrame(list(zip(X_MIA_train2.columns, regMIA2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.009188
# 1  Defensive Rebounds         -0.789327
# 2      Average Points         -0.363885
# 3           Attendees          0.003671
# 4     Team Efficiency          0.646406

# %%
pd.DataFrame(list(zip(X_DET_train2.columns, regDET2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.026692
# 1  Defensive Rebounds         -0.808563
# 2      Average Points         -0.320155
# 3           Attendees          0.003789
# 4     Team Efficiency          0.639997

# %%
pd.DataFrame(list(zip(X_CHA_train2.columns, regCHA2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.000074
# 1  Defensive Rebounds         -0.804112
# 2      Average Points         -0.323368
# 3           Attendees          0.003675
# 4     Team Efficiency          0.620996

# %%
pd.DataFrame(list(zip(X_NYK_train2.columns, regNYK2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.027343
# 1  Defensive Rebounds         -0.891278
# 2      Average Points         -0.137092
# 3           Attendees          0.003989
# 4     Team Efficiency          0.452213

# %%
pd.DataFrame(list(zip(X_ORL_train2.columns, regORL2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.018072
# 1  Defensive Rebounds         -0.731698
# 2      Average Points         -0.382110
# 3           Attendees          0.003600
# 4     Team Efficiency          0.630172

# %%
pd.DataFrame(list(zip(X_PHI_train2.columns, regPHI2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.024398
# 1  Defensive Rebounds         -0.809331
# 2      Average Points         -0.294550
# 3           Attendees          0.003906
# 4     Team Efficiency          0.628478

# %%
pd.DataFrame(list(zip(X_BKN_train2.columns, regBKN2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.012378
# 1  Defensive Rebounds         -0.847675
# 2      Average Points         -0.337146
# 3           Attendees          0.003840
# 4     Team Efficiency          0.633148

# %%
#set the data to be predicted for third quarter

X_GSW_data3 = df.loc[GSW3, X_stats]
y_GSW_data3 = df.loc[GSW3, Y_stats]

X_SAS_data3 = df.loc[SAS3, X_stats]
y_SAS_data3 = df.loc[SAS3, Y_stats]

X_HOU_data3 = df.loc[HOU3, X_stats]
y_HOU_data3 = df.loc[HOU3, Y_stats]

X_LAC_data3 = df.loc[LAC3, X_stats]
y_LAC_data3 = df.loc[LAC3, Y_stats]

X_UTAH_data3 = df.loc[UTAH3, X_stats]
y_UTAH_data3 = df.loc[UTAH3, Y_stats]

X_OKC_data3 = df.loc[OKC3, X_stats]
y_OKC_data3 = df.loc[OKC3, Y_stats]

X_MEM_data3 = df.loc[MEM3, X_stats]
y_MEM_data3 = df.loc[MEM3, Y_stats]

X_POR_data3 = df.loc[POR3, X_stats]
y_POR_data3 = df.loc[POR3, Y_stats]

X_DEN_data3 = df.loc[DEN3, X_stats]
y_DEN_data3 = df.loc[DEN3, Y_stats]

X_NOP_data3 = df.loc[NOP3, X_stats]
y_NOP_data3 = df.loc[NOP3, Y_stats]

X_DAL_data3 = df.loc[DAL3, X_stats]
y_DAL_data3 = df.loc[DAL3, Y_stats]

X_SAC_data3 = df.loc[SAC3, X_stats]
y_SAC_data3 = df.loc[SAC3, Y_stats]

X_MIN_data3 = df.loc[MIN3, X_stats]
y_MIN_data3 = df.loc[MIN3, Y_stats]

X_LAL_data3 = df.loc[LAL3, X_stats]
y_LAL_data3 = df.loc[LAL3, Y_stats]

X_PHO_data3 = df.loc[PHO3, X_stats]
y_PHO_data3 = df.loc[PHO3, Y_stats]

X_BOS_data3 = df.loc[BOS3, X_stats]
y_BOS_data3 = df.loc[BOS3, Y_stats]

X_CLE_data3 = df.loc[CLE3, X_stats]
y_CLE_data3 = df.loc[CLE3, Y_stats]

X_TOR_data3 = df.loc[TOR3, X_stats]
y_TOR_data3 = df.loc[TOR3, Y_stats]

X_WAS_data3 = df.loc[WAS3, X_stats]
y_WAS_data3 = df.loc[WAS3, Y_stats]

X_ATL_data3 = df.loc[ATL3, X_stats]
y_ATL_data3 = df.loc[ATL3, Y_stats]

X_MIL_data3 = df.loc[MIL3, X_stats]
y_MIL_data3 = df.loc[MIL3, Y_stats]

X_IND_data3 = df.loc[IND3, X_stats]
y_IND_data3 = df.loc[IND3, Y_stats]

X_CHI_data3 = df.loc[CHI3, X_stats]
y_CHI_data3 = df.loc[CHI3, Y_stats]

X_MIA_data3 = df.loc[MIA3, X_stats]
y_MIA_data3 = df.loc[MIA3, Y_stats]

X_DET_data3 = df.loc[DET3, X_stats]
y_DET_data3 = df.loc[DET3, Y_stats]

X_CHA_data3 = df.loc[CHA3, X_stats]
y_CHA_data3 = df.loc[CHA3, Y_stats]

X_NYK_data3 = df.loc[NYK3, X_stats]
y_NYK_data3 = df.loc[NYK3, Y_stats]

X_ORL_data3 = df.loc[ORL3, X_stats]
y_ORL_data3 = df.loc[ORL3, Y_stats]

X_PHI_data3 = df.loc[PHI3, X_stats]
y_PHI_data3 = df.loc[PHI3, Y_stats]

X_BKN_data3 = df.loc[BKN3, X_stats]
y_BKN_data3 = df.loc[BKN3, Y_stats]

# %%
#set the training dataset for third quarter of the season.
#this will not include the team itself

X_GSW_train3 = df.loc[notGSW3, X_stats]
y_GSW_train3 = df.loc[notGSW3, Y_stats]

X_SAS_train3 = df.loc[notSAS3, X_stats]
y_SAS_train3 = df.loc[notSAS3, Y_stats]

X_HOU_train3 = df.loc[notHOU3, X_stats]
y_HOU_train3 = df.loc[notHOU3, Y_stats]

X_LAC_train3 = df.loc[notLAC3, X_stats]
y_LAC_train3 = df.loc[notLAC3, Y_stats]

X_UTAH_train3 = df.loc[notUTAH3, X_stats]
y_UTAH_train3 = df.loc[notUTAH3, Y_stats]

X_OKC_train3 = df.loc[notOKC3, X_stats]
y_OKC_train3 = df.loc[notOKC3, Y_stats]

X_MEM_train3 = df.loc[notMEM3, X_stats]
y_MEM_train3 = df.loc[notMEM3, Y_stats]

X_POR_train3 = df.loc[notPOR3, X_stats]
y_POR_train3 = df.loc[notPOR3, Y_stats]

X_DEN_train3 = df.loc[notDEN3, X_stats]
y_DEN_train3 = df.loc[notDEN3, Y_stats]

X_NOP_train3 = df.loc[notNOP3, X_stats]
y_NOP_train3 = df.loc[notNOP3, Y_stats]

X_DAL_train3 = df.loc[notDAL3, X_stats]
y_DAL_train3 = df.loc[notDAL3, Y_stats]

X_SAC_train3 = df.loc[notSAC3, X_stats]
y_SAC_train3 = df.loc[notSAC3, Y_stats]

X_MIN_train3 = df.loc[notMIN3, X_stats]
y_MIN_train3 = df.loc[notMIN3, Y_stats]

X_LAL_train3 = df.loc[notLAL3, X_stats]
y_LAL_train3 = df.loc[notLAL3, Y_stats]

X_PHO_train3 = df.loc[notPHO3, X_stats]
y_PHO_train3 = df.loc[notPHO3, Y_stats]

X_BOS_train3 = df.loc[notBOS3, X_stats]
y_BOS_train3 = df.loc[notBOS3, Y_stats]

X_CLE_train3 = df.loc[notCLE3, X_stats]
y_CLE_train3 = df.loc[notCLE3, Y_stats]

X_TOR_train3 = df.loc[notTOR3, X_stats]
y_TOR_train3 = df.loc[notTOR3, Y_stats]

X_WAS_train3 = df.loc[notWAS3, X_stats]
y_WAS_train3 = df.loc[notWAS3, Y_stats]

X_ATL_train3 = df.loc[notPHO3, X_stats]
y_ATL_train3 = df.loc[notPHO3, Y_stats]

X_MIL_train3 = df.loc[notMIL3, X_stats]
y_MIL_train3 = df.loc[notMIL3, Y_stats]

X_IND_train3 = df.loc[notIND3, X_stats]
y_IND_train3 = df.loc[notIND3, Y_stats]

X_CHI_train3 = df.loc[notCHI3, X_stats]
y_CHI_train3 = df.loc[notCHI3, Y_stats]

X_MIA_train3 = df.loc[notMIA3, X_stats]
y_MIA_train3 = df.loc[notMIA3, Y_stats]

X_DET_train3 = df.loc[notDET3, X_stats]
y_DET_train3 = df.loc[notDET3, Y_stats]

X_CHA_train3 = df.loc[notCHA3, X_stats]
y_CHA_train3 = df.loc[notCHA3, Y_stats]

X_NYK_train3 = df.loc[notNYK3, X_stats]
y_NYK_train3 = df.loc[notNYK3, Y_stats]

X_ORL_train3 = df.loc[notORL3, X_stats]
y_ORL_train3 = df.loc[notORL3, Y_stats]

X_PHI_train3 = df.loc[notPHI3, X_stats]
y_PHI_train3 = df.loc[notPHI3, Y_stats]

X_BKN_train3 = df.loc[notBKN3, X_stats]
y_BKN_train3 = df.loc[notBKN3, Y_stats]

# %%
#implement linear regression models

from sklearn.linear_model import LinearRegression

regGSW3 = LinearRegression()
regGSW3.fit(X_GSW_train3, y_GSW_train3)

regSAS3 = LinearRegression()
regSAS3.fit(X_SAS_train3, y_SAS_train3)

regHOU3 = LinearRegression()
regHOU3.fit(X_HOU_train3, y_HOU_train3)

regLAC3 = LinearRegression()
regLAC3.fit(X_LAC_train3, y_LAC_train3)

regUTAH3 = LinearRegression()
regUTAH3.fit(X_UTAH_train3, y_UTAH_train3)

regOKC3 = LinearRegression()
regOKC3.fit(X_OKC_train3, y_OKC_train3)

regMEM3 = LinearRegression()
regMEM3.fit(X_MEM_train3, y_MEM_train3)

regPOR3 = LinearRegression()
regPOR3.fit(X_POR_train3, y_POR_train3)

regDEN3 = LinearRegression()
regDEN3.fit(X_DEN_train3, y_DEN_train3)

regNOP3 = LinearRegression()
regNOP3.fit(X_NOP_train3, y_NOP_train3)

regDAL3 = LinearRegression()
regDAL3.fit(X_DAL_train3, y_DAL_train3)

regSAC3 = LinearRegression()
regSAC3.fit(X_SAC_train3, y_SAC_train3)

regMIN3 = LinearRegression()
regMIN3.fit(X_MIN_train3, y_MIN_train3)

regLAL3 = LinearRegression()
regLAL3.fit(X_LAL_train3, y_LAL_train3)

regPHO3 = LinearRegression()
regPHO3.fit(X_PHO_train3, y_PHO_train3)

regBOS3 = LinearRegression()
regBOS3.fit(X_BOS_train3, y_BOS_train3)

regCLE3 = LinearRegression()
regCLE3.fit(X_CLE_train3, y_CLE_train3)

regTOR3 = LinearRegression()
regTOR3.fit(X_TOR_train3, y_TOR_train3)

regWAS3 = LinearRegression()
regWAS3.fit(X_WAS_train3, y_WAS_train3)

regATL3 = LinearRegression()
regATL3.fit(X_ATL_train3, y_ATL_train3)

regMIL3 = LinearRegression()
regMIL3.fit(X_MIL_train3, y_MIL_train3)

regIND3 = LinearRegression()
regIND3.fit(X_IND_train3, y_IND_train3)

regCHI3 = LinearRegression()
regCHI3.fit(X_CHI_train3, y_CHI_train3)

regMIA3 = LinearRegression()
regMIA3.fit(X_MIA_train3, y_MIA_train3)

regDET3 = LinearRegression()
regDET3.fit(X_DET_train3, y_DET_train3)

regCHA3 = LinearRegression()
regCHA3.fit(X_CHA_train3, y_CHA_train3)

regNYK3 = LinearRegression()
regNYK3.fit(X_NYK_train3, y_NYK_train3)

regORL3 = LinearRegression()
regORL3.fit(X_ORL_train3, y_ORL_train3)

regPHI3 = LinearRegression()
regPHI3.fit(X_PHI_train3, y_PHI_train3)

regBKN3 = LinearRegression()
regBKN3.fit(X_BKN_train3, y_BKN_train3)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#predict for the third quarter of the season

y_pred_GSW3 = regGSW3.predict(X_GSW_data3)

y_pred_SAS3 = regSAS3.predict(X_SAS_data3)

y_pred_HOU3 = regHOU3.predict(X_HOU_data3)

y_pred_LAC3 = regLAC3.predict(X_LAC_data3)

y_pred_UTAH3 = regUTAH3.predict(X_UTAH_data3)

y_pred_OKC3 = regOKC3.predict(X_OKC_data3)

y_pred_MEM3 = regMEM3.predict(X_MEM_data3)

y_pred_POR3 = regPOR3.predict(X_POR_data3)

y_pred_DEN3 = regDEN3.predict(X_DEN_data3)

y_pred_NOP3 = regNOP3.predict(X_NOP_data3)

y_pred_DAL3 = regDAL3.predict(X_DAL_data3)

y_pred_SAC3 = regSAC3.predict(X_SAC_data3)

y_pred_MIN3 = regMIN3.predict(X_MIN_data3)

y_pred_LAL3 = regLAL3.predict(X_LAL_data3)

y_pred_PHO3 = regPHO3.predict(X_PHO_data3)

y_pred_BOS3 = regBOS3.predict(X_BOS_data3)

y_pred_CLE3 = regCLE3.predict(X_CLE_data3)

y_pred_TOR3 = regTOR3.predict(X_TOR_data3)

y_pred_WAS3 = regWAS3.predict(X_WAS_data3)

y_pred_ATL3 = regATL3.predict(X_ATL_data3)

y_pred_MIL3 = regMIL3.predict(X_MIL_data3)

y_pred_IND3 = regIND3.predict(X_IND_data3)

y_pred_CHI3 = regCHI3.predict(X_CHI_data3)

y_pred_MIA3 = regMIA3.predict(X_MIA_data3)

y_pred_DET3 = regDET3.predict(X_DET_data3)

y_pred_CHA3 = regCHA3.predict(X_CHA_data3)

y_pred_NYK3 = regNYK3.predict(X_NYK_data3)

y_pred_ORL3 = regORL3.predict(X_ORL_data3)

y_pred_PHI3 = regPHI3.predict(X_PHI_data3)

y_pred_BKN3 = regBKN3.predict(X_BKN_data3)

# %%
#put the differences for the third quarter here

diff_GSW3 = y_GSW_data3 - y_pred_GSW3

diff_SAS3 = y_SAS_data3 - y_pred_SAS3

diff_HOU3 = y_HOU_data3 - y_pred_HOU3

diff_LAC3 = y_LAC_data3 - y_pred_LAC3

diff_UTAH3 = y_UTAH_data3 - y_pred_UTAH3

diff_OKC3 = y_OKC_data3 - y_pred_OKC3

diff_MEM3 = y_MEM_data3 - y_pred_MEM3

diff_POR3 = y_POR_data3 - y_pred_POR3

diff_DEN3 = y_DEN_data3 - y_pred_DEN3

diff_NOP3 = y_NOP_data3 - y_pred_NOP3

diff_DAL3 = y_DAL_data3 - y_pred_DAL3

diff_SAC3 = y_SAC_data3 - y_pred_SAC3

diff_MIN3 = y_MIN_data3 - y_pred_MIN3

diff_LAL3 = y_LAL_data3 - y_pred_LAL3

diff_PHO3 = y_PHO_data3 - y_pred_PHO3

diff_BOS3 = y_BOS_data3 - y_pred_BOS3

diff_CLE3 = y_CLE_data3 - y_pred_CLE3

diff_TOR3 = y_TOR_data3 - y_pred_TOR3

diff_WAS3 = y_WAS_data3 - y_pred_WAS3

diff_ATL3 = y_ATL_data3 - y_pred_ATL3

diff_MIL3 = y_MIL_data3 - y_pred_MIL3

diff_IND3 = y_IND_data3 - y_pred_IND3

diff_CHI3 = y_CHI_data3 - y_pred_CHI3

diff_MIA3 = y_MIA_data3 - y_pred_MIA3

diff_DET3 = y_DET_data3 - y_pred_DET3

diff_CHA3 = y_CHA_data3 - y_pred_CHA3

diff_NYK3 = y_NYK_data3 - y_pred_NYK3

diff_ORL3 = y_ORL_data3 - y_pred_ORL3

diff_PHI3 = y_PHI_data3 - y_pred_PHI3

diff_BKN3 = y_BKN_data3 - y_pred_BKN3

# %%
#get percent error for third quarter

err_GSW3 = round(abs(diff_GSW3 / y_GSW_data3) * 100, 2)

err_SAS3 = round(abs(diff_SAS3 / y_SAS_data3) * 100, 2)

err_HOU3 = round(abs(diff_HOU3 / y_HOU_data3) * 100, 2)

err_LAC3 = round(abs(diff_LAC3 / y_LAC_data3) * 100, 2)

err_UTAH3 = round(abs(diff_UTAH3 / y_UTAH_data3) * 100, 2)

err_OKC3 = round(abs(diff_OKC3 / y_OKC_data3) * 100, 2)

err_MEM3 = round(abs(diff_MEM3 / y_MEM_data3) * 100, 2)

err_POR3 = round(abs(diff_POR3 / y_POR_data3) * 100, 2)

err_DEN3 = round(abs(diff_DEN3 / y_DEN_data3) * 100, 2)

err_NOP3 = round(abs(diff_NOP3 / y_NOP_data3) * 100, 2)

err_DAL3 = round(abs(diff_DAL3 / y_DAL_data3) * 100, 2)

err_SAC3 = round(abs(diff_SAC3 / y_SAC_data3) * 100, 2)

err_MIN3 = round(abs(diff_MIN3 / y_MIN_data3) * 100, 2)

err_LAL3 = round(abs(diff_LAL3 / y_LAL_data3) * 100, 2)

err_PHO3 = round(abs(diff_PHO3 / y_PHO_data3) * 100, 2)

err_BOS3 = round(abs(diff_BOS3 / y_BOS_data3) * 100, 2)

err_CLE3 = round(abs(diff_CLE3 / y_CLE_data3) * 100, 2)

err_TOR3 = round(abs(diff_TOR3 / y_TOR_data3) * 100, 2)

err_WAS3 = round(abs(diff_WAS3 / y_WAS_data3) * 100, 2)

err_ATL3 = round(abs(diff_ATL3 / y_ATL_data3) * 100, 2)

err_MIL3 = round(abs(diff_MIL3 / y_MIL_data3) * 100, 2)

err_IND3 = round(abs(diff_IND3 / y_IND_data3) * 100, 2)

err_CHI3 = round(abs(diff_CHI3 / y_CHI_data3) * 100, 2)

err_MIA3 = round(abs(diff_MIA3 / y_MIA_data3) * 100, 2)

err_DET3 = round(abs(diff_DET3 / y_DET_data3) * 100, 2)

err_CHA3 = round(abs(diff_CHA3 / y_CHA_data3) * 100, 2)

err_NYK3 = round(abs(diff_NYK3 / y_NYK_data3) * 100, 2)

err_ORL3 = round(abs(diff_ORL3 / y_ORL_data3) * 100, 2)

err_PHI3 = round(abs(diff_PHI3 / y_PHI_data3) * 100, 2)

err_BKN3 = round(abs(diff_BKN3 / y_BKN_data3) * 100, 2)

# %%
pd.DataFrame(list(zip(X_GSW_train3.columns, regGSW3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.033362
# 1  Defensive Rebounds         -0.325273
# 2      Average Points          0.016121
# 3           Attendees          0.002400
# 4     Team Efficiency          0.214092

# %%
pd.DataFrame(list(zip(X_SAS_train3.columns, regSAS3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.216774
# 1  Defensive Rebounds         -0.221600
# 2      Average Points         -0.447177
# 3           Attendees          0.002886
# 4     Team Efficiency          0.740695

# %%
pd.DataFrame(list(zip(X_HOU_train3.columns, regHOU3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.207934
# 1  Defensive Rebounds         -0.366010
# 2      Average Points         -0.305733
# 3           Attendees          0.002966
# 4     Team Efficiency          0.661243

# %%
pd.DataFrame(list(zip(X_LAC_train3.columns, regLAC3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.130337
# 1  Defensive Rebounds         -0.253213
# 2      Average Points         -0.301447
# 3           Attendees          0.002950
# 4     Team Efficiency          0.649415

# %%
pd.DataFrame(list(zip(X_UTAH_train3.columns, regUTAH3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.131250
# 1  Defensive Rebounds         -0.318010
# 2      Average Points         -0.334250
# 3           Attendees          0.002940
# 4     Team Efficiency          0.682544

# %%
pd.DataFrame(list(zip(X_OKC_train3.columns, regOKC3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.148008
# 1  Defensive Rebounds         -0.254413
# 2      Average Points         -0.325057
# 3           Attendees          0.002941
# 4     Team Efficiency          0.672987

# %%
pd.DataFrame(list(zip(X_MEM_train3.columns, regMEM3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.152598
# 1  Defensive Rebounds         -0.240122
# 2      Average Points         -0.306029
# 3           Attendees          0.002998
# 4     Team Efficiency          0.659291

# %%
pd.DataFrame(list(zip(X_POR_train3.columns, regPOR3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.122732
# 1  Defensive Rebounds         -0.298405
# 2      Average Points         -0.329256
# 3           Attendees          0.003067
# 4     Team Efficiency          0.698768

# %%
pd.DataFrame(list(zip(X_DEN_train3.columns, regDEN3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.107327
# 1  Defensive Rebounds         -0.444013
# 2      Average Points         -0.438496
# 3           Attendees          0.002845
# 4     Team Efficiency          0.840832

# %%
pd.DataFrame(list(zip(X_NOP_train3.columns, regNOP3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.158875
# 1  Defensive Rebounds         -0.359437
# 2      Average Points         -0.323779
# 3           Attendees          0.003129
# 4     Team Efficiency          0.662159

# %%
pd.DataFrame(list(zip(X_DAL_train3.columns, regDAL3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.284610
# 1  Defensive Rebounds         -0.179015
# 2      Average Points         -0.382698
# 3           Attendees          0.003591
# 4     Team Efficiency          0.590871

# %%
pd.DataFrame(list(zip(X_SAC_train3.columns, regSAC3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.129353
# 1  Defensive Rebounds         -0.247626
# 2      Average Points         -0.317834
# 3           Attendees          0.002855
# 4     Team Efficiency          0.666495

# %%
pd.DataFrame(list(zip(X_MIN_train3.columns, regMIN3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.229561
# 1  Defensive Rebounds         -0.141773
# 2      Average Points         -0.420780
# 3           Attendees          0.003500
# 4     Team Efficiency          0.675526

# %%
pd.DataFrame(list(zip(X_LAL_train3.columns, regLAL3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.092213
# 1  Defensive Rebounds         -0.193886
# 2      Average Points         -0.193568
# 3           Attendees          0.003223
# 4     Team Efficiency          0.557040

# %%
pd.DataFrame(list(zip(X_PHO_train3.columns, regPHO3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.145542
# 1  Defensive Rebounds         -0.296304
# 2      Average Points         -0.341084
# 3           Attendees          0.002922
# 4     Team Efficiency          0.678348

# %%
pd.DataFrame(list(zip(X_BOS_train3.columns, regBOS3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.157058
# 1  Defensive Rebounds         -0.251712
# 2      Average Points         -0.416373
# 3           Attendees          0.003012
# 4     Team Efficiency          0.738658

# %%
pd.DataFrame(list(zip(X_CLE_train3.columns, regCLE3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.134675
# 1  Defensive Rebounds         -0.044977
# 2      Average Points         -0.542373
# 3           Attendees          0.001467
# 4     Team Efficiency          1.061260

# %%
pd.DataFrame(list(zip(X_TOR_train3.columns, regTOR3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.150184
# 1  Defensive Rebounds         -0.265756
# 2      Average Points         -0.328964
# 3           Attendees          0.003078
# 4     Team Efficiency          0.675680

# %%
pd.DataFrame(list(zip(X_WAS_train3.columns, regWAS3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.151254
# 1  Defensive Rebounds         -0.226417
# 2      Average Points         -0.349125
# 3           Attendees          0.002959
# 4     Team Efficiency          0.676954

# %%
pd.DataFrame(list(zip(X_ATL_train3.columns, regATL3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.145542
# 1  Defensive Rebounds         -0.296304
# 2      Average Points         -0.341084
# 3           Attendees          0.002922
# 4     Team Efficiency          0.678348

# %%
pd.DataFrame(list(zip(X_MIL_train3.columns, regMIL3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.136352
# 1  Defensive Rebounds         -0.338860
# 2      Average Points         -0.336376
# 3           Attendees          0.002971
# 4     Team Efficiency          0.679838

# %%
pd.DataFrame(list(zip(X_IND_train3.columns, regIND3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.200578
# 1  Defensive Rebounds         -0.202370
# 2      Average Points         -0.218242
# 3           Attendees          0.003207
# 4     Team Efficiency          0.562227

# %%
pd.DataFrame(list(zip(X_CHI_train3.columns, regCHI3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.077870
# 1  Defensive Rebounds         -0.247254
# 2      Average Points         -0.265084
# 3           Attendees          0.003264
# 4     Team Efficiency          0.604801

# %%
pd.DataFrame(list(zip(X_MIA_train3.columns, regMIA3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.138896
# 1  Defensive Rebounds         -0.267404
# 2      Average Points         -0.286804
# 3           Attendees          0.002778
# 4     Team Efficiency          0.666703

# %%
pd.DataFrame(list(zip(X_DET_train3.columns, regDET3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.176265
# 1  Defensive Rebounds         -0.213661
# 2      Average Points         -0.381457
# 3           Attendees          0.002833
# 4     Team Efficiency          0.695388

# %%
pd.DataFrame(list(zip(X_CHA_train3.columns, regCHA3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.187155
# 1  Defensive Rebounds         -0.231940
# 2      Average Points         -0.425931
# 3           Attendees          0.002800
# 4     Team Efficiency          0.724471

# %%
pd.DataFrame(list(zip(X_NYK_train3.columns, regNYK3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.150831
# 1  Defensive Rebounds         -0.233788
# 2      Average Points         -0.367953
# 3           Attendees          0.002982
# 4     Team Efficiency          0.677297

# %%
pd.DataFrame(list(zip(X_ORL_train3.columns, regORL3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.184501
# 1  Defensive Rebounds         -0.075642
# 2      Average Points         -0.487426
# 3           Attendees          0.002670
# 4     Team Efficiency          0.775158

# %%
pd.DataFrame(list(zip(X_PHI_train3.columns, regPHI3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.097969
# 1  Defensive Rebounds         -0.329340
# 2      Average Points         -0.362049
# 3           Attendees          0.003289
# 4     Team Efficiency          0.735154

# %%
pd.DataFrame(list(zip(X_BKN_train3.columns, regBKN3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.153555
# 1  Defensive Rebounds         -0.242139
# 2      Average Points         -0.332566
# 3           Attendees          0.002930
# 4     Team Efficiency          0.670839

# %%
#set the data to be predicted for fourth quarter

X_GSW_data4 = df.loc[GSW4, X_stats]
y_GSW_data4 = df.loc[GSW4, Y_stats]

X_SAS_data4 = df.loc[SAS4, X_stats]
y_SAS_data4 = df.loc[SAS4, Y_stats]

X_HOU_data4 = df.loc[HOU4, X_stats]
y_HOU_data4 = df.loc[HOU4, Y_stats]

X_LAC_data4 = df.loc[LAC4, X_stats]
y_LAC_data4 = df.loc[LAC4, Y_stats]

X_UTAH_data4 = df.loc[UTAH4, X_stats]
y_UTAH_data4 = df.loc[UTAH4, Y_stats]

X_OKC_data4 = df.loc[OKC4, X_stats]
y_OKC_data4 = df.loc[OKC4, Y_stats]

X_MEM_data4 = df.loc[MEM4, X_stats]
y_MEM_data4 = df.loc[MEM4, Y_stats]

X_POR_data4 = df.loc[POR4, X_stats]
y_POR_data4 = df.loc[POR4, Y_stats]

X_DEN_data4 = df.loc[DEN4, X_stats]
y_DEN_data4 = df.loc[DEN4, Y_stats]

X_NOP_data4 = df.loc[NOP4, X_stats]
y_NOP_data4 = df.loc[NOP4, Y_stats]

X_DAL_data4 = df.loc[DAL4, X_stats]
y_DAL_data4 = df.loc[DAL4, Y_stats]

X_SAC_data4 = df.loc[SAC4, X_stats]
y_SAC_data4 = df.loc[SAC4, Y_stats]

X_MIN_data4 = df.loc[MIN4, X_stats]
y_MIN_data4 = df.loc[MIN4, Y_stats]

X_LAL_data4 = df.loc[LAL4, X_stats]
y_LAL_data4 = df.loc[LAL4, Y_stats]

X_PHO_data4 = df.loc[PHO4, X_stats]
y_PHO_data4 = df.loc[PHO4, Y_stats]

X_BOS_data4 = df.loc[BOS4, X_stats]
y_BOS_data4 = df.loc[BOS4, Y_stats]

X_CLE_data4 = df.loc[CLE4, X_stats]
y_CLE_data4 = df.loc[CLE4, Y_stats]

X_TOR_data4 = df.loc[TOR4, X_stats]
y_TOR_data4 = df.loc[TOR4, Y_stats]

X_WAS_data4 = df.loc[WAS4, X_stats]
y_WAS_data4 = df.loc[WAS4, Y_stats]

X_ATL_data4 = df.loc[ATL4, X_stats]
y_ATL_data4 = df.loc[ATL4, Y_stats]

X_MIL_data4 = df.loc[MIL4, X_stats]
y_MIL_data4 = df.loc[MIL4, Y_stats]

X_IND_data4 = df.loc[IND4, X_stats]
y_IND_data4 = df.loc[IND4, Y_stats]

X_CHI_data4 = df.loc[CHI4, X_stats]
y_CHI_data4 = df.loc[CHI4, Y_stats]

X_MIA_data4 = df.loc[MIA4, X_stats]
y_MIA_data4 = df.loc[MIA4, Y_stats]

X_DET_data4 = df.loc[DET4, X_stats]
y_DET_data4 = df.loc[DET4, Y_stats]

X_CHA_data4 = df.loc[CHA4, X_stats]
y_CHA_data4 = df.loc[CHA4, Y_stats]

X_NYK_data4 = df.loc[NYK4, X_stats]
y_NYK_data4 = df.loc[NYK4, Y_stats]

X_ORL_data4 = df.loc[ORL4, X_stats]
y_ORL_data4 = df.loc[ORL4, Y_stats]

X_PHI_data4 = df.loc[PHI4, X_stats]
y_PHI_data4 = df.loc[PHI4, Y_stats]

X_BKN_data4 = df.loc[BKN4, X_stats]
y_BKN_data4 = df.loc[BKN4, Y_stats]

# %%
#set the training dataset for fourth quarter of the season.
#this will not include the team itself

X_GSW_train4 = df.loc[notGSW4, X_stats]
y_GSW_train4 = df.loc[notGSW4, Y_stats]

X_SAS_train4 = df.loc[notSAS4, X_stats]
y_SAS_train4 = df.loc[notSAS4, Y_stats]

X_HOU_train4 = df.loc[notHOU4, X_stats]
y_HOU_train4 = df.loc[notHOU4, Y_stats]

X_LAC_train4 = df.loc[notLAC4, X_stats]
y_LAC_train4 = df.loc[notLAC4, Y_stats]

X_UTAH_train4 = df.loc[notUTAH4, X_stats]
y_UTAH_train4 = df.loc[notUTAH4, Y_stats]

X_OKC_train4 = df.loc[notOKC4, X_stats]
y_OKC_train4 = df.loc[notOKC4, Y_stats]

X_MEM_train4 = df.loc[notMEM4, X_stats]
y_MEM_train4 = df.loc[notMEM4, Y_stats]

X_POR_train4 = df.loc[notPOR4, X_stats]
y_POR_train4 = df.loc[notPOR4, Y_stats]

X_DEN_train4 = df.loc[notDEN4, X_stats]
y_DEN_train4 = df.loc[notDEN4, Y_stats]

X_NOP_train4 = df.loc[notNOP4, X_stats]
y_NOP_train4 = df.loc[notNOP4, Y_stats]

X_DAL_train4 = df.loc[notDAL4, X_stats]
y_DAL_train4 = df.loc[notDAL4, Y_stats]

X_SAC_train4 = df.loc[notSAC4, X_stats]
y_SAC_train4 = df.loc[notSAC4, Y_stats]

X_MIN_train4 = df.loc[notMIN4, X_stats]
y_MIN_train4 = df.loc[notMIN4, Y_stats]

X_LAL_train4 = df.loc[notLAL4, X_stats]
y_LAL_train4 = df.loc[notLAL4, Y_stats]

X_PHO_train4 = df.loc[notPHO4, X_stats]
y_PHO_train4 = df.loc[notPHO4, Y_stats]

X_BOS_train4 = df.loc[notBOS4, X_stats]
y_BOS_train4 = df.loc[notBOS4, Y_stats]

X_CLE_train4 = df.loc[notCLE4, X_stats]
y_CLE_train4 = df.loc[notCLE4, Y_stats]

X_TOR_train4 = df.loc[notTOR4, X_stats]
y_TOR_train4 = df.loc[notTOR4, Y_stats]

X_WAS_train4 = df.loc[notWAS4, X_stats]
y_WAS_train4 = df.loc[notWAS4, Y_stats]

X_ATL_train4 = df.loc[notPHO4, X_stats]
y_ATL_train4 = df.loc[notPHO4, Y_stats]

X_MIL_train4 = df.loc[notMIL4, X_stats]
y_MIL_train4 = df.loc[notMIL4, Y_stats]

X_IND_train4 = df.loc[notIND4, X_stats]
y_IND_train4 = df.loc[notIND4, Y_stats]

X_CHI_train4 = df.loc[notCHI4, X_stats]
y_CHI_train4 = df.loc[notCHI4, Y_stats]

X_MIA_train4 = df.loc[notMIA4, X_stats]
y_MIA_train4 = df.loc[notMIA4, Y_stats]

X_DET_train4 = df.loc[notDET4, X_stats]
y_DET_train4 = df.loc[notDET4, Y_stats]

X_CHA_train4 = df.loc[notCHA4, X_stats]
y_CHA_train4 = df.loc[notCHA4, Y_stats]

X_NYK_train4 = df.loc[notNYK4, X_stats]
y_NYK_train4 = df.loc[notNYK4, Y_stats]

X_ORL_train4 = df.loc[notORL4, X_stats]
y_ORL_train4 = df.loc[notORL4, Y_stats]

X_PHI_train4 = df.loc[notPHI4, X_stats]
y_PHI_train4 = df.loc[notPHI4, Y_stats]

X_BKN_train4 = df.loc[notBKN4, X_stats]
y_BKN_train4 = df.loc[notBKN4, Y_stats]

# %%
#implement linear regression models

from sklearn.linear_model import LinearRegression

regGSW4 = LinearRegression()
regGSW4.fit(X_GSW_train4, y_GSW_train4)

regSAS4 = LinearRegression()
regSAS4.fit(X_SAS_train4, y_SAS_train4)

regHOU4 = LinearRegression()
regHOU4.fit(X_HOU_train4, y_HOU_train4)

regLAC4 = LinearRegression()
regLAC4.fit(X_LAC_train4, y_LAC_train4)

regUTAH4 = LinearRegression()
regUTAH4.fit(X_UTAH_train4, y_UTAH_train4)

regOKC4 = LinearRegression()
regOKC4.fit(X_OKC_train4, y_OKC_train4)

regMEM4 = LinearRegression()
regMEM4.fit(X_MEM_train4, y_MEM_train4)

regPOR4 = LinearRegression()
regPOR4.fit(X_POR_train4, y_POR_train4)

regDEN4 = LinearRegression()
regDEN4.fit(X_DEN_train4, y_DEN_train4)

regNOP4 = LinearRegression()
regNOP4.fit(X_NOP_train4, y_NOP_train4)

regDAL4 = LinearRegression()
regDAL4.fit(X_DAL_train4, y_DAL_train4)

regSAC4 = LinearRegression()
regSAC4.fit(X_SAC_train4, y_SAC_train4)

regMIN4 = LinearRegression()
regMIN4.fit(X_MIN_train4, y_MIN_train4)

regLAL4 = LinearRegression()
regLAL4.fit(X_LAL_train4, y_LAL_train4)

regPHO4 = LinearRegression()
regPHO4.fit(X_PHO_train4, y_PHO_train4)

regBOS4 = LinearRegression()
regBOS4.fit(X_BOS_train4, y_BOS_train4)

regCLE4 = LinearRegression()
regCLE4.fit(X_CLE_train4, y_CLE_train4)

regTOR4 = LinearRegression()
regTOR4.fit(X_TOR_train4, y_TOR_train4)

regWAS4 = LinearRegression()
regWAS4.fit(X_WAS_train4, y_WAS_train4)

regATL4 = LinearRegression()
regATL4.fit(X_ATL_train4, y_ATL_train4)

regMIL4 = LinearRegression()
regMIL4.fit(X_MIL_train4, y_MIL_train4)

regIND4 = LinearRegression()
regIND4.fit(X_IND_train4, y_IND_train4)

regCHI4 = LinearRegression()
regCHI4.fit(X_CHI_train4, y_CHI_train4)

regMIA4 = LinearRegression()
regMIA4.fit(X_MIA_train4, y_MIA_train4)

regDET4 = LinearRegression()
regDET4.fit(X_DET_train4, y_DET_train4)

regCHA4 = LinearRegression()
regCHA4.fit(X_CHA_train4, y_CHA_train4)

regNYK4 = LinearRegression()
regNYK4.fit(X_NYK_train4, y_NYK_train4)

regORL4 = LinearRegression()
regORL4.fit(X_ORL_train4, y_ORL_train4)

regPHI4 = LinearRegression()
regPHI4.fit(X_PHI_train4, y_PHI_train4)

regBKN4 = LinearRegression()
regBKN4.fit(X_BKN_train4, y_BKN_train4)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#predict for the fourth quarter of the season

y_pred_GSW4 = regGSW4.predict(X_GSW_data4)

y_pred_SAS4 = regSAS4.predict(X_SAS_data4)

y_pred_HOU4 = regHOU4.predict(X_HOU_data4)

y_pred_LAC4 = regLAC4.predict(X_LAC_data4)

y_pred_UTAH4 = regUTAH4.predict(X_UTAH_data4)

y_pred_OKC4 = regOKC4.predict(X_OKC_data4)

y_pred_MEM4 = regMEM4.predict(X_MEM_data4)

y_pred_POR4 = regPOR4.predict(X_POR_data4)

y_pred_DEN4 = regDEN4.predict(X_DEN_data4)

y_pred_NOP4 = regNOP4.predict(X_NOP_data4)

y_pred_DAL4 = regDAL4.predict(X_DAL_data4)

y_pred_SAC4 = regSAC4.predict(X_SAC_data4)

y_pred_MIN4 = regMIN4.predict(X_MIN_data4)

y_pred_LAL4 = regLAL4.predict(X_LAL_data4)

y_pred_PHO4 = regPHO4.predict(X_PHO_data4)

y_pred_BOS4 = regBOS4.predict(X_BOS_data4)

y_pred_CLE4 = regCLE4.predict(X_CLE_data4)

y_pred_TOR4 = regTOR4.predict(X_TOR_data4)

y_pred_WAS4 = regWAS4.predict(X_WAS_data4)

y_pred_ATL4 = regATL4.predict(X_ATL_data4)

y_pred_MIL4 = regMIL4.predict(X_MIL_data4)

y_pred_IND4 = regIND4.predict(X_IND_data4)

y_pred_CHI4 = regCHI4.predict(X_CHI_data4)

y_pred_MIA4 = regMIA4.predict(X_MIA_data4)

y_pred_DET4 = regDET4.predict(X_DET_data4)

y_pred_CHA4 = regCHA4.predict(X_CHA_data4)

y_pred_NYK4 = regNYK4.predict(X_NYK_data4)

y_pred_ORL4 = regORL4.predict(X_ORL_data4)

y_pred_PHI4 = regPHI4.predict(X_PHI_data4)

y_pred_BKN4 = regBKN4.predict(X_BKN_data4)

# %%
#put the differences for the fourth quarter here

diff_GSW4 = y_GSW_data4 - y_pred_GSW4

diff_SAS4 = y_SAS_data4 - y_pred_SAS4

diff_HOU4 = y_HOU_data4 - y_pred_HOU4

diff_LAC4 = y_LAC_data4 - y_pred_LAC4

diff_UTAH4 = y_UTAH_data4 - y_pred_UTAH4

diff_OKC4 = y_OKC_data4 - y_pred_OKC4

diff_MEM4 = y_MEM_data4 - y_pred_MEM4

diff_POR4 = y_POR_data4 - y_pred_POR4

diff_DEN4 = y_DEN_data4 - y_pred_DEN4

diff_NOP4 = y_NOP_data4 - y_pred_NOP4

diff_DAL4 = y_DAL_data4 - y_pred_DAL4

diff_SAC4 = y_SAC_data4 - y_pred_SAC4

diff_MIN4 = y_MIN_data4 - y_pred_MIN4

diff_LAL4 = y_LAL_data4 - y_pred_LAL4

diff_PHO4 = y_PHO_data4 - y_pred_PHO4

diff_BOS4 = y_BOS_data4 - y_pred_BOS4

diff_CLE4 = y_CLE_data4 - y_pred_CLE4

diff_TOR4 = y_TOR_data4 - y_pred_TOR4

diff_WAS4 = y_WAS_data4 - y_pred_WAS4

diff_ATL4 = y_ATL_data4 - y_pred_ATL4

diff_MIL4 = y_MIL_data4 - y_pred_MIL4

diff_IND4 = y_IND_data4 - y_pred_IND4

diff_CHI4 = y_CHI_data4 - y_pred_CHI4

diff_MIA4 = y_MIA_data4 - y_pred_MIA4

diff_DET4 = y_DET_data4 - y_pred_DET4

diff_CHA4 = y_CHA_data4 - y_pred_CHA4

diff_NYK4 = y_NYK_data4 - y_pred_NYK4

diff_ORL4 = y_ORL_data4 - y_pred_ORL4

diff_PHI4 = y_PHI_data4 - y_pred_PHI4

diff_BKN4 = y_BKN_data4 - y_pred_BKN4

# %%
#get percent error for fourth quarter

err_GSW4 = round(abs(diff_GSW4 / y_GSW_data4) * 100, 2)

err_SAS4 = round(abs(diff_SAS4 / y_SAS_data4) * 100, 2)

err_HOU4 = round(abs(diff_HOU4 / y_HOU_data4) * 100, 2)

err_LAC4 = round(abs(diff_LAC4 / y_LAC_data4) * 100, 2)

err_UTAH4 = round(abs(diff_UTAH4 / y_UTAH_data4) * 100, 2)

err_OKC4 = round(abs(diff_OKC4 / y_OKC_data4) * 100, 2)

err_MEM4 = round(abs(diff_MEM4 / y_MEM_data4) * 100, 2)

err_POR4 = round(abs(diff_POR4 / y_POR_data4) * 100, 2)

err_DEN4 = round(abs(diff_DEN4 / y_DEN_data4) * 100, 2)

err_NOP4 = round(abs(diff_NOP4 / y_NOP_data4) * 100, 2)

err_DAL4 = round(abs(diff_DAL4 / y_DAL_data4) * 100, 2)

err_SAC4 = round(abs(diff_SAC4 / y_SAC_data4) * 100, 2)

err_MIN4 = round(abs(diff_MIN4 / y_MIN_data4) * 100, 2)

err_LAL4 = round(abs(diff_LAL4 / y_LAL_data4) * 100, 2)

err_PHO4 = round(abs(diff_PHO4 / y_PHO_data4) * 100, 2)

err_BOS4 = round(abs(diff_BOS4 / y_BOS_data4) * 100, 2)

err_CLE4 = round(abs(diff_CLE4 / y_CLE_data4) * 100, 2)

err_TOR4 = round(abs(diff_TOR4 / y_TOR_data4) * 100, 2)

err_WAS4 = round(abs(diff_WAS4 / y_WAS_data4) * 100, 2)

err_ATL4 = round(abs(diff_ATL4 / y_ATL_data4) * 100, 2)

err_MIL4 = round(abs(diff_MIL4 / y_MIL_data4) * 100, 2)

err_IND4 = round(abs(diff_IND4 / y_IND_data4) * 100, 2)

err_CHI4 = round(abs(diff_CHI4 / y_CHI_data4) * 100, 2)

err_MIA4 = round(abs(diff_MIA4 / y_MIA_data4) * 100, 2)

err_DET4 = round(abs(diff_DET4 / y_DET_data4) * 100, 2)

err_CHA4 = round(abs(diff_CHA4 / y_CHA_data4) * 100, 2)

err_NYK4 = round(abs(diff_NYK4 / y_NYK_data4) * 100, 2)

err_ORL4 = round(abs(diff_ORL4 / y_ORL_data4) * 100, 2)

err_PHI4 = round(abs(diff_PHI4 / y_PHI_data4) * 100, 2)

err_BKN4 = round(abs(diff_BKN4 / y_BKN_data4) * 100, 2)

# %%
pd.DataFrame(list(zip(X_GSW_train4.columns, regGSW4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.074232
# 1  Defensive Rebounds         -0.049853
# 2      Average Points          0.475395
# 3           Attendees          0.001418
# 4     Team Efficiency         -0.239653

# %%
pd.DataFrame(list(zip(X_SAS_train4.columns, regSAS4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.029680
# 1  Defensive Rebounds         -0.031274
# 2      Average Points          0.220037
# 3           Attendees          0.002676
# 4     Team Efficiency          0.179537

# %%
pd.DataFrame(list(zip(X_HOU_train4.columns, regHOU4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.095162
# 1  Defensive Rebounds          0.201455
# 2      Average Points          0.096765
# 3           Attendees          0.002371
# 4     Team Efficiency          0.229493

# %%
pd.DataFrame(list(zip(X_LAC_train4.columns, regLAC4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.130047
# 1  Defensive Rebounds          0.000118
# 2      Average Points          0.377480
# 3           Attendees          0.002616
# 4     Team Efficiency          0.168692

# %%
pd.DataFrame(list(zip(X_UTAH_train4.columns, regUTAH4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.017169
# 1  Defensive Rebounds          0.077994
# 2      Average Points          0.155208
# 3           Attendees          0.002528
# 4     Team Efficiency          0.191627

# %%
pd.DataFrame(list(zip(X_OKC_train4.columns, regOKC4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.035825
# 1  Defensive Rebounds          0.101183
# 2      Average Points          0.087640
# 3           Attendees          0.002430
# 4     Team Efficiency          0.278172

# %%
pd.DataFrame(list(zip(X_MEM_train4.columns, regMEM4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.008933
# 1  Defensive Rebounds          0.106801
# 2      Average Points          0.060467
# 3           Attendees          0.002071
# 4     Team Efficiency          0.263499

# %%
pd.DataFrame(list(zip(X_POR_train4.columns, regPOR4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.007981
# 1  Defensive Rebounds          0.101994
# 2      Average Points          0.094278
# 3           Attendees          0.002384
# 4     Team Efficiency          0.243058

# %%
pd.DataFrame(list(zip(X_DEN_train4.columns, regDEN4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.011810
# 1  Defensive Rebounds          0.097543
# 2      Average Points         -0.114374
# 3           Attendees          0.002232
# 4     Team Efficiency          0.369162

# %%
pd.DataFrame(list(zip(X_NOP_train4.columns, regNOP4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.002771
# 1  Defensive Rebounds         -0.027980
# 2      Average Points          0.079182
# 3           Attendees          0.002988
# 4     Team Efficiency          0.292877

# %%
pd.DataFrame(list(zip(X_DAL_train4.columns, regDAL4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.089731
# 1  Defensive Rebounds          0.045250
# 2      Average Points          0.172035
# 3           Attendees          0.003163
# 4     Team Efficiency          0.142201

# %%
pd.DataFrame(list(zip(X_SAC_train4.columns, regSAC4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.067524
# 1  Defensive Rebounds         -0.075092
# 2      Average Points          0.199377
# 3           Attendees          0.002513
# 4     Team Efficiency          0.260529

# %%
pd.DataFrame(list(zip(X_MIN_train4.columns, regMIN4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.040376
# 1  Defensive Rebounds          0.140617
# 2      Average Points          0.139221
# 3           Attendees          0.003297
# 4     Team Efficiency          0.216377

# %%
pd.DataFrame(list(zip(X_LAL_train4.columns, regLAL4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.011411
# 1  Defensive Rebounds          0.054066
# 2      Average Points          0.172600
# 3           Attendees          0.002949
# 4     Team Efficiency          0.188130

# %%
pd.DataFrame(list(zip(X_PHO_train4.columns, regPHO4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.041493
# 1  Defensive Rebounds         -0.043153
# 2      Average Points          0.150935
# 3           Attendees          0.002241
# 4     Team Efficiency          0.231263

# %%
pd.DataFrame(list(zip(X_BOS_train4.columns, regBOS4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.012371
# 1  Defensive Rebounds          0.105430
# 2      Average Points          0.107331
# 3           Attendees          0.002363
# 4     Team Efficiency          0.235331

# %%
pd.DataFrame(list(zip(X_CLE_train4.columns, regCLE4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.047106
# 1  Defensive Rebounds          0.986857
# 2      Average Points         -0.807797
# 3           Attendees          0.000508
# 4     Team Efficiency          1.087619

# %%
pd.DataFrame(list(zip(X_TOR_train4.columns, regTOR4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.009454
# 1  Defensive Rebounds          0.111774
# 2      Average Points          0.111114
# 3           Attendees          0.002542
# 4     Team Efficiency          0.249005

# %%
pd.DataFrame(list(zip(X_WAS_train4.columns, regWAS4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.008487
# 1  Defensive Rebounds          0.120467
# 2      Average Points          0.092448
# 3           Attendees          0.002454
# 4     Team Efficiency          0.238863

# %%
pd.DataFrame(list(zip(X_ATL_train4.columns, regATL4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.041493
# 1  Defensive Rebounds         -0.043153
# 2      Average Points          0.150935
# 3           Attendees          0.002241
# 4     Team Efficiency          0.231263

# %%
pd.DataFrame(list(zip(X_MIL_train4.columns, regMIL4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.013536
# 1  Defensive Rebounds          0.083172
# 2      Average Points          0.107079
# 3           Attendees          0.002418
# 4     Team Efficiency          0.241307

# %%
pd.DataFrame(list(zip(X_IND_train4.columns, regIND4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.041624
# 1  Defensive Rebounds          0.120712
# 2      Average Points          0.273763
# 3           Attendees          0.002829
# 4     Team Efficiency          0.139386

# %%
pd.DataFrame(list(zip(X_CHI_train4.columns, regCHI4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.160667
# 1  Defensive Rebounds         -0.000916
# 2      Average Points          0.442086
# 3           Attendees          0.003258
# 4     Team Efficiency         -0.014734

# %%
pd.DataFrame(list(zip(X_MIA_train4.columns, regMIA4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.017045
# 1  Defensive Rebounds          0.057564
# 2      Average Points          0.159781
# 3           Attendees          0.002368
# 4     Team Efficiency          0.219774

# %%
pd.DataFrame(list(zip(X_DET_train4.columns, regDET4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.052750
# 1  Defensive Rebounds         -0.086560
# 2      Average Points         -0.041133
# 3           Attendees          0.002519
# 4     Team Efficiency          0.334759

# %%
pd.DataFrame(list(zip(X_CHA_train4.columns, regCHA4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.019762
# 1  Defensive Rebounds         -0.088475
# 2      Average Points          0.117126
# 3           Attendees          0.002441
# 4     Team Efficiency          0.243109

# %%
pd.DataFrame(list(zip(X_NYK_train4.columns, regNYK4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.011312
# 1  Defensive Rebounds          0.266726
# 2      Average Points          0.055854
# 3           Attendees          0.002302
# 4     Team Efficiency          0.150179

# %%
pd.DataFrame(list(zip(X_ORL_train4.columns, regORL4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.004041
# 1  Defensive Rebounds          0.176317
# 2      Average Points         -0.149024
# 3           Attendees          0.002076
# 4     Team Efficiency          0.441308

# %%
pd.DataFrame(list(zip(X_PHI_train4.columns, regPHI4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.024054
# 1  Defensive Rebounds          0.108442
# 2      Average Points          0.125268
# 3           Attendees          0.002507
# 4     Team Efficiency          0.233563

# %%
pd.DataFrame(list(zip(X_BKN_train4.columns, regBKN4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.031842
# 1  Defensive Rebounds          0.255214
# 2      Average Points          0.118258
# 3           Attendees          0.002105
# 4     Team Efficiency          0.153567

# %%
#show difference for first quarter of the season

all_teams = pd.DataFrame({
    "Team Name" : ['Golden State', 'San Antonio', 'Houston', 'Los Angeles Clippers', 'Utah',
             'Oklahoma City', 'Memphis', 'Portland', 'Denver', 'New Orleans', 'Dallas',
             'Sacramento', 'Minnesota', 'Los Angeles Lakers', 'Phoenix', 'Boston',
             'Cleveland', 'Toronto', 'Washington', 'Atlanta', 'Milwaukee', 'Indiana',
             'Chicago', 'Miami', 'Detroit', 'Charlotte', 'New York', 'Orlando', 'Philadelphia', 'Brooklyn'],
    "Team Performance Difference Between Actual and Predicted": [diff_GSW["Team Performance"].mean(), diff_SAS["Team Performance"].mean(), diff_HOU["Team Performance"].mean(), diff_LAC["Team Performance"].mean(), diff_UTAH["Team Performance"].mean(),
                                               diff_OKC["Team Performance"].mean(), diff_MEM["Team Performance"].mean(), diff_POR["Team Performance"].mean(), diff_DEN["Team Performance"].mean(), diff_NOP["Team Performance"].mean(),
                                               diff_DAL["Team Performance"].mean(), diff_SAC["Team Performance"].mean(), diff_MIN["Team Performance"].mean(), diff_LAL["Team Performance"].mean(), diff_PHO["Team Performance"].mean(),
                                               diff_BOS["Team Performance"].mean(), diff_CLE["Team Performance"].mean(), diff_TOR["Team Performance"].mean(), diff_WAS["Team Performance"].mean(), diff_ATL["Team Performance"].mean(),
                                               diff_MIL["Team Performance"].mean(), diff_IND["Team Performance"].mean(), diff_CHI["Team Performance"].mean(), diff_MIA["Team Performance"].mean(), diff_DET["Team Performance"].mean(),
                                               diff_CHA["Team Performance"].mean(), diff_NYK["Team Performance"].mean(), diff_ORL["Team Performance"].mean(), diff_PHI["Team Performance"].mean(), diff_BKN["Team Performance"].mean()],
    "Team Performance Percent Error": [err_GSW["Team Performance"].mean(), err_SAS["Team Performance"].mean(), err_HOU["Team Performance"].mean(), err_LAC["Team Performance"].mean(), err_UTAH["Team Performance"].mean(),
                                               err_OKC["Team Performance"].mean(), err_MEM["Team Performance"].mean(), err_POR["Team Performance"].mean(), err_DEN["Team Performance"].mean(), err_NOP["Team Performance"].mean(),
                                               err_DAL["Team Performance"].mean(), err_SAC["Team Performance"].mean(), err_MIN["Team Performance"].mean(), err_LAL["Team Performance"].mean(), err_PHO["Team Performance"].mean(),
                                               err_BOS["Team Performance"].mean(), err_CLE["Team Performance"].mean(), err_TOR["Team Performance"].mean(), err_WAS["Team Performance"].mean(), err_ATL["Team Performance"].mean(),
                                               err_MIL["Team Performance"].mean(), err_IND["Team Performance"].mean(), err_CHI["Team Performance"].mean(), err_MIA["Team Performance"].mean(), err_DET["Team Performance"].mean(),
                                               err_CHA["Team Performance"].mean(), err_NYK["Team Performance"].mean(), err_ORL["Team Performance"].mean(), err_PHI["Team Performance"].mean(), err_BKN["Team Performance"].mean()]
  }
).sort_values(by="Team Name", ascending=True)

all_teams
# Out:
#                Team Name  \
# 19               Atlanta
# 15                Boston
# 29              Brooklyn
# 25             Charlotte
# 22               Chicago
# 16             Cleveland
# 10                Dallas
# 8                 Denver
# 24               Detroit
# 0           Golden State
# 2                Houston
# 21               Indiana
# 3   Los Angeles Clippers
# 13    Los Angeles Lakers
# 6                Memphis
# 23                 Miami
# 20             Milwaukee
# 12             Minnesota
# 9            New Orleans
# 26              New York
# 5          Oklahoma City
# 27               Orlando
# 28          Philadelphia
# 14               Phoenix
# 7               Portland
# 11            Sacramento
# 1            San Antonio
# 17               Toronto
# 4                   Utah
# 18            Washington
#
#     Team Performance Difference Between Actual and Predicted  \
# 19                                           4.528921
# ...

# %%
#show difference for second quarter of the season

all_teams = pd.DataFrame({
    "Team Name" : ['Golden State', 'San Antonio', 'Houston', 'Los Angeles Clippers', 'Utah',
             'Oklahoma City', 'Memphis', 'Portland', 'Denver', 'New Orleans', 'Dallas',
             'Sacramento', 'Minnesota', 'Los Angeles Lakers', 'Phoenix', 'Boston',
             'Cleveland', 'Toronto', 'Washington', 'Atlanta', 'Milwaukee', 'Indiana',
             'Chicago', 'Miami', 'Detroit', 'Charlotte', 'New York', 'Orlando', 'Philadelphia', 'Brooklyn'],
    "Team Performance Difference Between Actual and Predicted": [diff_GSW2["Team Performance"].mean(), diff_SAS2["Team Performance"].mean(), diff_HOU2["Team Performance"].mean(), diff_LAC2["Team Performance"].mean(), diff_UTAH2["Team Performance"].mean(),
                                               diff_OKC2["Team Performance"].mean(), diff_MEM2["Team Performance"].mean(), diff_POR2["Team Performance"].mean(), diff_DEN2["Team Performance"].mean(), diff_NOP2["Team Performance"].mean(),
                                               diff_DAL2["Team Performance"].mean(), diff_SAC2["Team Performance"].mean(), diff_MIN2["Team Performance"].mean(), diff_LAL2["Team Performance"].mean(), diff_PHO2["Team Performance"].mean(),
                                               diff_BOS2["Team Performance"].mean(), diff_CLE2["Team Performance"].mean(), diff_TOR2["Team Performance"].mean(), diff_WAS2["Team Performance"].mean(), diff_ATL2["Team Performance"].mean(),
                                               diff_MIL2["Team Performance"].mean(), diff_IND2["Team Performance"].mean(), diff_CHI2["Team Performance"].mean(), diff_MIA2["Team Performance"].mean(), diff_DET2["Team Performance"].mean(),
                                               diff_CHA2["Team Performance"].mean(), diff_NYK2["Team Performance"].mean(), diff_ORL2["Team Performance"].mean(), diff_PHI2["Team Performance"].mean(), diff_BKN2["Team Performance"].mean()],
    "Team Performance Percent Error": [err_GSW2["Team Performance"].mean(), err_SAS2["Team Performance"].mean(), err_HOU2["Team Performance"].mean(), err_LAC2["Team Performance"].mean(), err_UTAH2["Team Performance"].mean(),
                                               err_OKC2["Team Performance"].mean(), err_MEM2["Team Performance"].mean(), err_POR2["Team Performance"].mean(), err_DEN2["Team Performance"].mean(), err_NOP2["Team Performance"].mean(),
                                               err_DAL2["Team Performance"].mean(), err_SAC2["Team Performance"].mean(), err_MIN2["Team Performance"].mean(), err_LAL2["Team Performance"].mean(), err_PHO2["Team Performance"].mean(),
                                               err_BOS2["Team Performance"].mean(), err_CLE2["Team Performance"].mean(), err_TOR2["Team Performance"].mean(), err_WAS2["Team Performance"].mean(), err_ATL2["Team Performance"].mean(),
                                               err_MIL2["Team Performance"].mean(), err_IND2["Team Performance"].mean(), err_CHI2["Team Performance"].mean(), err_MIA2["Team Performance"].mean(), err_DET2["Team Performance"].mean(),
                                               err_CHA2["Team Performance"].mean(), err_NYK2["Team Performance"].mean(), err_ORL2["Team Performance"].mean(), err_PHI2["Team Performance"].mean(), err_BKN2["Team Performance"].mean()]
  }
).sort_values(by="Team Name", ascending=True)

all_teams
# Out:
#                Team Name  \
# 19               Atlanta
# 15                Boston
# 29              Brooklyn
# 25             Charlotte
# 22               Chicago
# 16             Cleveland
# 10                Dallas
# 8                 Denver
# 24               Detroit
# 0           Golden State
# 2                Houston
# 21               Indiana
# 3   Los Angeles Clippers
# 13    Los Angeles Lakers
# 6                Memphis
# 23                 Miami
# 20             Milwaukee
# 12             Minnesota
# 9            New Orleans
# 26              New York
# 5          Oklahoma City
# 27               Orlando
# 28          Philadelphia
# 14               Phoenix
# 7               Portland
# 11            Sacramento
# 1            San Antonio
# 17               Toronto
# 4                   Utah
# 18            Washington
#
#     Team Performance Difference Between Actual and Predicted  \
# 19                                          -1.491573
# ...

# %%
#show difference for third quarter of the season

all_teams = pd.DataFrame({
    "Team Name" : ['Golden State', 'San Antonio', 'Houston', 'Los Angeles Clippers', 'Utah',
             'Oklahoma City', 'Memphis', 'Portland', 'Denver', 'New Orleans', 'Dallas',
             'Sacramento', 'Minnesota', 'Los Angeles Lakers', 'Phoenix', 'Boston',
             'Cleveland', 'Toronto', 'Washington', 'Atlanta', 'Milwaukee', 'Indiana',
             'Chicago', 'Miami', 'Detroit', 'Charlotte', 'New York', 'Orlando', 'Philadelphia', 'Brooklyn'],
    "Team Performance Difference Between Actual and Predicted": [diff_GSW3["Team Performance"].mean(), diff_SAS3["Team Performance"].mean(), diff_HOU3["Team Performance"].mean(), diff_LAC3["Team Performance"].mean(), diff_UTAH3["Team Performance"].mean(),
                                               diff_OKC3["Team Performance"].mean(), diff_MEM3["Team Performance"].mean(), diff_POR3["Team Performance"].mean(), diff_DEN3["Team Performance"].mean(), diff_NOP3["Team Performance"].mean(),
                                               diff_DAL3["Team Performance"].mean(), diff_SAC3["Team Performance"].mean(), diff_MIN3["Team Performance"].mean(), diff_LAL3["Team Performance"].mean(), diff_PHO3["Team Performance"].mean(),
                                               diff_BOS3["Team Performance"].mean(), diff_CLE3["Team Performance"].mean(), diff_TOR3["Team Performance"].mean(), diff_WAS3["Team Performance"].mean(), diff_ATL3["Team Performance"].mean(),
                                               diff_MIL3["Team Performance"].mean(), diff_IND3["Team Performance"].mean(), diff_CHI3["Team Performance"].mean(), diff_MIA3["Team Performance"].mean(), diff_DET3["Team Performance"].mean(),
                                               diff_CHA3["Team Performance"].mean(), diff_NYK3["Team Performance"].mean(), diff_ORL3["Team Performance"].mean(), diff_PHI3["Team Performance"].mean(), diff_BKN3["Team Performance"].mean()],
    "Team Performance Percent Error": [err_GSW3["Team Performance"].mean(), err_SAS3["Team Performance"].mean(), err_HOU3["Team Performance"].mean(), err_LAC3["Team Performance"].mean(), err_UTAH3["Team Performance"].mean(),
                                               err_OKC3["Team Performance"].mean(), err_MEM3["Team Performance"].mean(), err_POR3["Team Performance"].mean(), err_DEN3["Team Performance"].mean(), err_NOP3["Team Performance"].mean(),
                                               err_DAL3["Team Performance"].mean(), err_SAC3["Team Performance"].mean(), err_MIN3["Team Performance"].mean(), err_LAL3["Team Performance"].mean(), err_PHO3["Team Performance"].mean(),
                                               err_BOS3["Team Performance"].mean(), err_CLE3["Team Performance"].mean(), err_TOR3["Team Performance"].mean(), err_WAS3["Team Performance"].mean(), err_ATL3["Team Performance"].mean(),
                                               err_MIL3["Team Performance"].mean(), err_IND3["Team Performance"].mean(), err_CHI3["Team Performance"].mean(), err_MIA3["Team Performance"].mean(), err_DET3["Team Performance"].mean(),
                                               err_CHA3["Team Performance"].mean(), err_NYK3["Team Performance"].mean(), err_ORL3["Team Performance"].mean(), err_PHI3["Team Performance"].mean(), err_BKN3["Team Performance"].mean()]
  }
).sort_values(by="Team Name", ascending=True)

all_teams
# Out:
#                Team Name  \
# 19               Atlanta
# 15                Boston
# 29              Brooklyn
# 25             Charlotte
# 22               Chicago
# 16             Cleveland
# 10                Dallas
# 8                 Denver
# 24               Detroit
# 0           Golden State
# 2                Houston
# 21               Indiana
# 3   Los Angeles Clippers
# 13    Los Angeles Lakers
# 6                Memphis
# 23                 Miami
# 20             Milwaukee
# 12             Minnesota
# 9            New Orleans
# 26              New York
# 5          Oklahoma City
# 27               Orlando
# 28          Philadelphia
# 14               Phoenix
# 7               Portland
# 11            Sacramento
# 1            San Antonio
# 17               Toronto
# 4                   Utah
# 18            Washington
#
#     Team Performance Difference Between Actual and Predicted  \
# 19                                          -2.388886
# ...

# %%
#show difference for fourth quarter of the season

all_teams = pd.DataFrame({
    "Team Name" : ['Golden State', 'San Antonio', 'Houston', 'Los Angeles Clippers', 'Utah',
             'Oklahoma City', 'Memphis', 'Portland', 'Denver', 'New Orleans', 'Dallas',
             'Sacramento', 'Minnesota', 'Los Angeles Lakers', 'Phoenix', 'Boston',
             'Cleveland', 'Toronto', 'Washington', 'Atlanta', 'Milwaukee', 'Indiana',
             'Chicago', 'Miami', 'Detroit', 'Charlotte', 'New York', 'Orlando', 'Philadelphia', 'Brooklyn'],
    "Team Performance Difference Between Actual and Predicted": [diff_GSW4["Team Performance"].mean(), diff_SAS4["Team Performance"].mean(), diff_HOU4["Team Performance"].mean(), diff_LAC4["Team Performance"].mean(), diff_UTAH4["Team Performance"].mean(),
                                               diff_OKC4["Team Performance"].mean(), diff_MEM4["Team Performance"].mean(), diff_POR4["Team Performance"].mean(), diff_DEN4["Team Performance"].mean(), diff_NOP4["Team Performance"].mean(),
                                               diff_DAL4["Team Performance"].mean(), diff_SAC4["Team Performance"].mean(), diff_MIN4["Team Performance"].mean(), diff_LAL4["Team Performance"].mean(), diff_PHO4["Team Performance"].mean(),
                                               diff_BOS4["Team Performance"].mean(), diff_CLE4["Team Performance"].mean(), diff_TOR4["Team Performance"].mean(), diff_WAS4["Team Performance"].mean(), diff_ATL4["Team Performance"].mean(),
                                               diff_MIL4["Team Performance"].mean(), diff_IND4["Team Performance"].mean(), diff_CHI4["Team Performance"].mean(), diff_MIA4["Team Performance"].mean(), diff_DET4["Team Performance"].mean(),
                                               diff_CHA4["Team Performance"].mean(), diff_NYK4["Team Performance"].mean(), diff_ORL4["Team Performance"].mean(), diff_PHI4["Team Performance"].mean(), diff_BKN4["Team Performance"].mean()],
    "Team Performance Percent Error": [err_GSW4["Team Performance"].mean(), err_SAS4["Team Performance"].mean(), err_HOU4["Team Performance"].mean(), err_LAC4["Team Performance"].mean(), err_UTAH4["Team Performance"].mean(),
                                               err_OKC4["Team Performance"].mean(), err_MEM4["Team Performance"].mean(), err_POR4["Team Performance"].mean(), err_DEN4["Team Performance"].mean(), err_NOP4["Team Performance"].mean(),
                                               err_DAL4["Team Performance"].mean(), err_SAC4["Team Performance"].mean(), err_MIN4["Team Performance"].mean(), err_LAL4["Team Performance"].mean(), err_PHO4["Team Performance"].mean(),
                                               err_BOS4["Team Performance"].mean(), err_CLE4["Team Performance"].mean(), err_TOR4["Team Performance"].mean(), err_WAS4["Team Performance"].mean(), err_ATL4["Team Performance"].mean(),
                                               err_MIL4["Team Performance"].mean(), err_IND4["Team Performance"].mean(), err_CHI4["Team Performance"].mean(), err_MIA4["Team Performance"].mean(), err_DET4["Team Performance"].mean(),
                                               err_CHA4["Team Performance"].mean(), err_NYK4["Team Performance"].mean(), err_ORL4["Team Performance"].mean(), err_PHI4["Team Performance"].mean(), err_BKN4["Team Performance"].mean()]
  }
).sort_values(by="Team Name", ascending=True)

all_teams
# Out:
#                Team Name  \
# 19               Atlanta
# 15                Boston
# 29              Brooklyn
# 25             Charlotte
# 22               Chicago
# 16             Cleveland
# 10                Dallas
# 8                 Denver
# 24               Detroit
# 0           Golden State
# 2                Houston
# 21               Indiana
# 3   Los Angeles Clippers
# 13    Los Angeles Lakers
# 6                Memphis
# 23                 Miami
# 20             Milwaukee
# 12             Minnesota
# 9            New Orleans
# 26              New York
# 5          Oklahoma City
# 27               Orlando
# 28          Philadelphia
# 14               Phoenix
# 7               Portland
# 11            Sacramento
# 1            San Antonio
# 17               Toronto
# 4                   Utah
# 18            Washington
#
#     Team Performance Difference Between Actual and Predicted  \
# 19                                          -5.731511
# ...

# %%
#show actual and predicted for Eastern Conference for first quarter of the season

all_east = pd.DataFrame({
    "Team Name" : ['Atlanta', 'Boston', 'Brooklyn', 'Charlotte', 'Chicago',
                  'Cleveland', 'Detroit', 'Indiana', 'Miami', 'Milwaukee',
                  'New York', 'Orlando', 'Philadelphia', 'Toronto', 'Washington'],
    "Team Performance Actual Score" : [y_ATL_data["Team Performance"].mean(), y_BOS_data["Team Performance"].mean(), y_BKN_data["Team Performance"].mean(),
                                      y_CHA_data["Team Performance"].mean(), y_CHI_data["Team Performance"].mean(), y_CLE_data["Team Performance"].mean(),
                                      y_DET_data["Team Performance"].mean(), y_IND_data["Team Performance"].mean(), y_MIA_data["Team Performance"].mean(),
                                      y_MIL_data["Team Performance"].mean(), y_NYK_data["Team Performance"].mean(), y_ORL_data["Team Performance"].mean(),
                                      y_PHI_data["Team Performance"].mean(), y_TOR_data["Team Performance"].mean(), y_WAS_data["Team Performance"].mean()],
    "Team Performance Predicted Score" : [ np.mean(y_pred_ATL),  np.mean(y_pred_BOS),
                                          np.mean(y_pred_BKN),  np.mean(y_pred_CHA),
                                          np.mean(y_pred_CHI),  np.mean(y_pred_CLE),
                                          np.mean(y_pred_DET),  np.mean(y_pred_IND),
                                          np.mean(y_pred_MIA),  np.mean(y_pred_MIL),
                                          np.mean(y_pred_NYK),  np.mean(y_pred_ORL),
                                          np.mean(y_pred_PHI),  np.mean(y_pred_TOR),
                                          np.mean(y_pred_WAS)]
  }
).sort_values(by="Team Performance Predicted Score", ascending=False)

all_east
# Out:
#        Team Name  Team Performance Actual Score  \
# 13       Toronto                           75.0
# 10      New York                           65.0
# 4        Chicago                           65.0
# 7        Indiana                           75.0
# 14    Washington                           75.0
# 8          Miami                           75.0
# 3      Charlotte                           65.0
# 11       Orlando                           65.0
# 12  Philadelphia                           75.0
# 5      Cleveland                           95.0
# 1         Boston                           75.0
# 2       Brooklyn                           65.0
# 6        Detroit                           65.0
# 9      Milwaukee                           75.0
# 0        Atlanta                           65.0
#
#     Team Performance Predicted Score
# 13                         78.972947
# 10                         75.544800
# 4                          75.343791
# 7                          74.841623
# ...

# %%
#show actual and predicted for Western Conference for first quarter of the season

all_west = pd.DataFrame({
    "Team Name" : ['Dallas', 'Denver', 'Golden State', 'Houston', 'Los Angeles Clippers',
                  'Los Angeles Lakers', 'Memphis', 'Minnesota', 'New Orleans', 'Oklahoma City',
                  'Phoenix', 'Portland', 'Sacramento', 'San Antonio', 'Utah'],
    "Team Performance Actual Score" : [y_DAL_data["Team Performance"].mean(), y_DEN_data["Team Performance"].mean(), y_GSW_data["Team Performance"].mean(),
                                      y_HOU_data["Team Performance"].mean(), y_LAC_data["Team Performance"].mean(), y_LAL_data["Team Performance"].mean(),
                                      y_MEM_data["Team Performance"].mean(), y_MIN_data["Team Performance"].mean(), y_NOP_data["Team Performance"].mean(),
                                      y_OKC_data["Team Performance"].mean(), y_PHO_data["Team Performance"].mean(), y_POR_data["Team Performance"].mean(),
                                      y_SAC_data["Team Performance"].mean(), y_SAS_data["Team Performance"].mean(), y_UTAH_data["Team Performance"].mean()],
    "Team Performance Predicted Score" : [ np.mean(y_pred_DAL), np.mean(y_pred_DEN),
                                          np.mean(y_pred_GSW), np.mean(y_pred_HOU),
                                          np.mean(y_pred_LAC), np.mean(y_pred_LAL),
                                          np.mean(y_pred_MEM), np.mean(y_pred_MIN),
                                          np.mean(y_pred_NOP), np.mean(y_pred_OKC),
                                          np.mean(y_pred_PHO), np.mean(y_pred_POR),
                                          np.mean(y_pred_SAC), np.mean(y_pred_SAS),
                                          np.mean(y_pred_UTAH)]
  }
).sort_values(by="Team Performance Predicted Score", ascending=False)

all_west
# Out:
#                Team Name  Team Performance Actual Score  \
# 5     Los Angeles Lakers                           65.0
# 2           Golden State                          100.0
# 1                 Denver                           65.0
# 0                 Dallas                           65.0
# 9          Oklahoma City                           75.0
# 13           San Antonio                           75.0
# 8            New Orleans                           75.0
# 14                  Utah                           75.0
# 11              Portland                           75.0
# 3                Houston                           75.0
# 12            Sacramento                           65.0
# 4   Los Angeles Clippers                           65.0
# 6                Memphis                           65.0
# 7              Minnesota                           75.0
# 10               Phoenix                           65.0
#
#     Team Performance Predicted Score
# ...

# %%
#show actual and predicted for Eastern Conference for second quarter of the season

all_east = pd.DataFrame({
    "Team Name" : ['Atlanta', 'Boston', 'Brooklyn', 'Charlotte', 'Chicago',
                  'Cleveland', 'Detroit', 'Indiana', 'Miami', 'Milwaukee',
                  'New York', 'Orlando', 'Philadelphia', 'Toronto', 'Washington'],
    "Team Performance Actual Score" : [y_ATL_data2["Team Performance"].mean(), y_BOS_data2["Team Performance"].mean(), y_BKN_data2["Team Performance"].mean(),
                                      y_CHA_data2["Team Performance"].mean(), y_CHI_data2["Team Performance"].mean(), y_CLE_data2["Team Performance"].mean(),
                                      y_DET_data2["Team Performance"].mean(), y_IND_data2["Team Performance"].mean(), y_MIA_data2["Team Performance"].mean(),
                                      y_MIL_data2["Team Performance"].mean(), y_NYK_data2["Team Performance"].mean(), y_ORL_data2["Team Performance"].mean(),
                                      y_PHI_data2["Team Performance"].mean(), y_TOR_data2["Team Performance"].mean(), y_WAS_data2["Team Performance"].mean()],
    "Team Performance Predicted Score" : [np.mean(y_pred_ATL2), np.mean(y_pred_BOS2),
                                         np.mean(y_pred_BKN2), np.mean(y_pred_CHA2),
                                         np.mean(y_pred_CHI2), np.mean(y_pred_CLE2),
                                         np.mean(y_pred_DET2), np.mean(y_pred_IND2),
                                         np.mean(y_pred_MIA2), np.mean(y_pred_MIL2),
                                         np.mean(y_pred_NYK2), np.mean(y_pred_ORL2),
                                         np.mean(y_pred_PHI2), np.mean(y_pred_TOR2),
                                         np.mean(y_pred_WAS2)]
  }
).sort_values(by="Team Performance Predicted Score", ascending=False)

all_east
# Out:
#        Team Name  Team Performance Actual Score  \
# 1         Boston                           75.0
# 12  Philadelphia                           75.0
# 13       Toronto                           75.0
# 4        Chicago                           65.0
# 8          Miami                           75.0
# 14    Washington                           75.0
# 7        Indiana                           75.0
# 10      New York                           65.0
# 9      Milwaukee                           75.0
# 11       Orlando                           65.0
# 0        Atlanta                           65.0
# 5      Cleveland                           95.0
# 3      Charlotte                           65.0
# 2       Brooklyn                           65.0
# 6        Detroit                           65.0
#
#     Team Performance Predicted Score
# 1                          82.725975
# 12                         79.808176
# 13                         78.419840
# 4                          77.475155
# ...

# %%
#show actual and predicted for Western Conference for second quarter of the season

all_west = pd.DataFrame({
    "Team Name" : ['Dallas', 'Denver', 'Golden State', 'Houston', 'Los Angeles Clippers',
                  'Los Angeles Lakers', 'Memphis', 'Minnesota', 'New Orleans', 'Oklahoma City',
                  'Phoenix', 'Portland', 'Sacramento', 'San Antonio', 'Utah'],
    "Team Performance Actual Score" : [y_DAL_data2["Team Performance"].mean(), y_DEN_data2["Team Performance"].mean(), y_GSW_data2["Team Performance"].mean(),
                                      y_HOU_data2["Team Performance"].mean(), y_LAC_data2["Team Performance"].mean(), y_LAL_data2["Team Performance"].mean(),
                                      y_MEM_data2["Team Performance"].mean(), y_MIN_data2["Team Performance"].mean(), y_NOP_data2["Team Performance"].mean(),
                                      y_OKC_data2["Team Performance"].mean(), y_PHO_data2["Team Performance"].mean(), y_POR_data2["Team Performance"].mean(),
                                      y_SAC_data2["Team Performance"].mean(), y_SAS_data2["Team Performance"].mean(), y_UTAH_data2["Team Performance"].mean()],
    "Team Performance Predicted Score" : [ np.mean(y_pred_DAL2), np.mean(y_pred_DEN2),
                                          np.mean(y_pred_GSW2), np.mean(y_pred_HOU2),
                                          np.mean(y_pred_LAC2), np.mean(y_pred_LAL2),
                                          np.mean(y_pred_MEM2), np.mean(y_pred_MIN2),
                                          np.mean(y_pred_NOP2), np.mean(y_pred_OKC2),
                                          np.mean(y_pred_PHO2), np.mean(y_pred_POR2),
                                          np.mean(y_pred_SAC2), np.mean(y_pred_SAS2),
                                          np.mean(y_pred_UTAH2)]
  }
).sort_values(by="Team Performance Predicted Score", ascending=False)

all_west
# Out:
#                Team Name  Team Performance Actual Score  \
# 1                 Denver                           65.0
# 3                Houston                           75.0
# 2           Golden State                          100.0
# 5     Los Angeles Lakers                           65.0
# 14                  Utah                           75.0
# 13           San Antonio                           75.0
# 12            Sacramento                           65.0
# 11              Portland                           75.0
# 7              Minnesota                           75.0
# 0                 Dallas                           65.0
# 9          Oklahoma City                           75.0
# 4   Los Angeles Clippers                           65.0
# 8            New Orleans                           75.0
# 6                Memphis                           65.0
# 10               Phoenix                           65.0
#
#     Team Performance Predicted Score
# ...

# %%
#show actual and predicted for Eastern Conference for third quarter of the season

all_east = pd.DataFrame({
    "Team Name" : ['Atlanta', 'Boston', 'Brooklyn', 'Charlotte', 'Chicago',
                  'Cleveland', 'Detroit', 'Indiana', 'Miami', 'Milwaukee',
                  'New York', 'Orlando', 'Philadelphia', 'Toronto', 'Washington'],
    "Team Performance Actual Score" : [y_ATL_data3["Team Performance"].mean(), y_BOS_data3["Team Performance"].mean(), y_BKN_data3["Team Performance"].mean(),
                                      y_CHA_data3["Team Performance"].mean(), y_CHI_data3["Team Performance"].mean(), y_CLE_data3["Team Performance"].mean(),
                                      y_DET_data3["Team Performance"].mean(), y_IND_data3["Team Performance"].mean(), y_MIA_data3["Team Performance"].mean(),
                                      y_MIL_data3["Team Performance"].mean(), y_NYK_data3["Team Performance"].mean(), y_ORL_data3["Team Performance"].mean(),
                                      y_PHI_data3["Team Performance"].mean(), y_TOR_data3["Team Performance"].mean(), y_WAS_data3["Team Performance"].mean()],
    "Team Performance Predicted Score" : [ np.mean(y_pred_ATL3),  np.mean(y_pred_BOS3),
                                          np.mean(y_pred_BKN3),  np.mean(y_pred_CHA3),
                                          np.mean(y_pred_CHI3),  np.mean(y_pred_CLE3),
                                          np.mean(y_pred_DET3),  np.mean(y_pred_IND3),
                                          np.mean(y_pred_MIA3),  np.mean(y_pred_MIL3),
                                          np.mean(y_pred_NYK3),  np.mean(y_pred_ORL3),
                                          np.mean(y_pred_PHI3),  np.mean(y_pred_TOR3),
                                          np.mean(y_pred_WAS3)]
  }
).sort_values(by="Team Performance Predicted Score", ascending=False)

all_east
# Out:
#        Team Name  Team Performance Actual Score  \
# 12  Philadelphia                           75.0
# 1         Boston                           75.0
# 13       Toronto                           75.0
# 14    Washington                           75.0
# 9      Milwaukee                           75.0
# 4        Chicago                           65.0
# 8          Miami                           75.0
# 11       Orlando                           65.0
# 3      Charlotte                           65.0
# 7        Indiana                           75.0
# 0        Atlanta                           65.0
# 6        Detroit                           65.0
# 10      New York                           65.0
# 2       Brooklyn                           65.0
# 5      Cleveland                           95.0
#
#     Team Performance Predicted Score
# 12                         81.688045
# 1                          78.245181
# 13                         78.024910
# 14                         73.927871
# ...

# %%
#show actual and predicted for Western Conference for third quarter of the season

all_west = pd.DataFrame({
    "Team Name" : ['Dallas', 'Denver', 'Golden State', 'Houston', 'Los Angeles Clippers',
                  'Los Angeles Lakers', 'Memphis', 'Minnesota', 'New Orleans', 'Oklahoma City',
                  'Phoenix', 'Portland', 'Sacramento', 'San Antonio', 'Utah'],
    "Team Performance Actual Score" : [y_DAL_data3["Team Performance"].mean(), y_DEN_data3["Team Performance"].mean(), y_GSW_data3["Team Performance"].mean(),
                                      y_HOU_data3["Team Performance"].mean(), y_LAC_data3["Team Performance"].mean(), y_LAL_data3["Team Performance"].mean(),
                                      y_MEM_data3["Team Performance"].mean(), y_MIN_data3["Team Performance"].mean(), y_NOP_data3["Team Performance"].mean(),
                                      y_OKC_data3["Team Performance"].mean(), y_PHO_data3["Team Performance"].mean(), y_POR_data3["Team Performance"].mean(),
                                      y_SAC_data3["Team Performance"].mean(), y_SAS_data3["Team Performance"].mean(), y_UTAH_data3["Team Performance"].mean()],
    "Team Performance Predicted Score" : [ np.mean(y_pred_DAL3), np.mean(y_pred_DEN3),
                                          np.mean(y_pred_GSW3), np.mean(y_pred_HOU3),
                                          np.mean(y_pred_LAC3), np.mean(y_pred_LAL3),
                                          np.mean(y_pred_MEM3), np.mean(y_pred_MIN3),
                                          np.mean(y_pred_NOP3), np.mean(y_pred_OKC3),
                                          np.mean(y_pred_PHO3), np.mean(y_pred_POR3),
                                          np.mean(y_pred_SAC3), np.mean(y_pred_SAS3),
                                          np.mean(y_pred_UTAH3)]
  }
).sort_values(by="Team Performance Predicted Score", ascending=False)

all_west
# Out:
#                Team Name  Team Performance Actual Score  \
# 11              Portland                           75.0
# 2           Golden State                          100.0
# 3                Houston                           75.0
# 1                 Denver                           65.0
# 9          Oklahoma City                           75.0
# 0                 Dallas                           65.0
# 14                  Utah                           75.0
# 5     Los Angeles Lakers                           65.0
# 13           San Antonio                           75.0
# 8            New Orleans                           75.0
# 12            Sacramento                           65.0
# 4   Los Angeles Clippers                           65.0
# 10               Phoenix                           65.0
# 7              Minnesota                           75.0
# 6                Memphis                           65.0
#
#     Team Performance Predicted Score
# ...

# %%
#show actual and predicted for Eastern Conference for fourth quarter of the season

all_east = pd.DataFrame({
    "Team Name" : ['Atlanta', 'Boston', 'Brooklyn', 'Charlotte', 'Chicago',
                  'Cleveland', 'Detroit', 'Indiana', 'Miami', 'Milwaukee',
                  'New York', 'Orlando', 'Philadelphia', 'Toronto', 'Washington'],
    "Team Performance Actual Score" : [y_ATL_data4["Team Performance"].mean(), y_BOS_data4["Team Performance"].mean(), y_BKN_data4["Team Performance"].mean(),
                                      y_CHA_data4["Team Performance"].mean(), y_CHI_data4["Team Performance"].mean(), y_CLE_data4["Team Performance"].mean(),
                                      y_DET_data4["Team Performance"].mean(), y_IND_data4["Team Performance"].mean(), y_MIA_data4["Team Performance"].mean(),
                                      y_MIL_data4["Team Performance"].mean(), y_NYK_data4["Team Performance"].mean(), y_ORL_data4["Team Performance"].mean(),
                                      y_PHI_data4["Team Performance"].mean(), y_TOR_data4["Team Performance"].mean(), y_WAS_data4["Team Performance"].mean()],
    "Team Performance Predicted Score" : [ np.mean(y_pred_ATL4),  np.mean(y_pred_BOS4),
                                          np.mean(y_pred_BKN4),  np.mean(y_pred_CHA4),
                                          np.mean(y_pred_CHI4),  np.mean(y_pred_CLE4),
                                          np.mean(y_pred_DET4),  np.mean(y_pred_IND4),
                                          np.mean(y_pred_MIA4),  np.mean(y_pred_MIL4),
                                          np.mean(y_pred_NYK4),  np.mean(y_pred_ORL4),
                                          np.mean(y_pred_PHI4),  np.mean(y_pred_TOR4),
                                          np.mean(y_pred_WAS4)]
  }
).sort_values(by="Team Performance Predicted Score", ascending=False)

all_east
# Out:
#        Team Name  Team Performance Actual Score  \
# 13       Toronto                           75.0
# 12  Philadelphia                           75.0
# 4        Chicago                           65.0
# 9      Milwaukee                           75.0
# 11       Orlando                           65.0
# 1         Boston                           75.0
# 6        Detroit                           65.0
# 8          Miami                           75.0
# 14    Washington                           75.0
# 3      Charlotte                           65.0
# 0        Atlanta                           65.0
# 2       Brooklyn                           65.0
# 10      New York                           65.0
# 7        Indiana                           75.0
# 5      Cleveland                           95.0
#
#     Team Performance Predicted Score
# 13                         76.718497
# 12                         75.990940
# 4                          74.777883
# 9                          74.727240
# ...

# %%
#show actual and predicted for Western Conference for fourth quarter of the season

all_west = pd.DataFrame({
    "Team Name" : ['Dallas', 'Denver', 'Golden State', 'Houston', 'Los Angeles Clippers',
                  'Los Angeles Lakers', 'Memphis', 'Minnesota', 'New Orleans', 'Oklahoma City',
                  'Phoenix', 'Portland', 'Sacramento', 'San Antonio', 'Utah'],
    "Team Performance Actual Score" : [y_DAL_data4["Team Performance"].mean(), y_DEN_data4["Team Performance"].mean(), y_GSW_data4["Team Performance"].mean(),
                                      y_HOU_data4["Team Performance"].mean(), y_LAC_data4["Team Performance"].mean(), y_LAL_data4["Team Performance"].mean(),
                                      y_MEM_data4["Team Performance"].mean(), y_MIN_data4["Team Performance"].mean(), y_NOP_data4["Team Performance"].mean(),
                                      y_OKC_data4["Team Performance"].mean(), y_PHO_data4["Team Performance"].mean(), y_POR_data4["Team Performance"].mean(),
                                      y_SAC_data4["Team Performance"].mean(), y_SAS_data4["Team Performance"].mean(), y_UTAH_data4["Team Performance"].mean()],
    "Team Performance Predicted Score" : [ np.mean(y_pred_DAL4), np.mean(y_pred_DEN4),
                                          np.mean(y_pred_GSW4), np.mean(y_pred_HOU4),
                                          np.mean(y_pred_LAC4), np.mean(y_pred_LAL4),
                                          np.mean(y_pred_MEM4), np.mean(y_pred_MIN4),
                                          np.mean(y_pred_NOP4), np.mean(y_pred_OKC4),
                                          np.mean(y_pred_PHO4), np.mean(y_pred_POR4),
                                          np.mean(y_pred_SAC4), np.mean(y_pred_SAS4),
                                          np.mean(y_pred_UTAH4)]
  }
).sort_values(by="Team Performance Predicted Score", ascending=False)

all_west
# Out:
#                Team Name  Team Performance Actual Score  \
# 4   Los Angeles Clippers                           65.0
# 0                 Dallas                           65.0
# 11              Portland                           75.0
# 5     Los Angeles Lakers                           65.0
# 12            Sacramento                           65.0
# 14                  Utah                           75.0
# 1                 Denver                           65.0
# 2           Golden State                          100.0
# 3                Houston                           75.0
# 13           San Antonio                           75.0
# 9          Oklahoma City                           75.0
# 10               Phoenix                           65.0
# 6                Memphis                           65.0
# 8            New Orleans                           75.0
# 7              Minnesota                           75.0
#
#     Team Performance Predicted Score
# ...
