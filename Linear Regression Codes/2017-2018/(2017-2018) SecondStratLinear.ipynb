# %% [markdown]
# Team Efficiency all-in-all uses = League Points, 3Ps Made, Assists, Turnovers, Field Goal Attempts, Field Goals Made, Free Throws Attempted, Free Throws Made, Offensive Rebounds, Total Rebounds, Steals, Blocks, and Personal Fouls thus remove these from the X set to remove redundancy
#
# Same case for factor, VOP, and DRB since they are part of getting the team efficiency engineered stat
#
# Thus, X should contain 3Ps Attempted, Defensive Rebounds, Average Points, Attendees, and Team Efficiency
#
# The data used here is from the 2017-2018 season.

# %%
import numpy as np
import pandas as pd

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/1BWHMRer0zinB6KNFmA2gJQWYZljHy3bMh375uHLwqiI/edit#gid=0'
csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

df = pd.read_csv(csv_export_url)

# %%
df.head()
# Out:
#                 Team Name and Instance  FGs Made  FGs Attempted  FG %  \
# 0   Golden State Warriors (Games 1-20)        44             86  0.51
# 1  Golden State Warriors (Games 21-41)        44             86  0.51
# 2  Golden State Warriors (Games 42-61)        43             84  0.52
# 3  Golden State Warriors (Games 62-82)        40             85  0.48
# 4       San Antonio Spurs (Games 1-20)        38             85  0.45
#
#    3Ps Made   3Ps Attempted  3Ps%  FTs Made  FTs Attempted   FT%  \
# 0         13             32  0.40        17             21  0.82
# 1         11             29  0.39        16             20  0.81
# 2         12             29  0.41        18             22  0.81
# 3         10             26  0.37        15             18  0.83
# 4          9             25  0.35        16             20  0.80
#
#        ...        League Assists  League Field Goals Made  \
# 0      ...                 672.0                   1168.0
# ...

# %%
#set the data to be predicted for first quarter

X_GSW_data = df.iloc[0:1, [5,11,18,19,20]]
y_GSW_data = df.iloc[0, 24:25]

X_SAS_data = df.iloc[4:5, [5,11,18,19,20]]
y_SAS_data = df.iloc[4, 24:25]

X_HOU_data = df.iloc[8:9, [5,11,18,19,20]]
y_HOU_data = df.iloc[8, 24:25]

X_LAC_data = df.iloc[12:13, [5,11,18,19,20]]
y_LAC_data = df.iloc[12, 24:25]

X_UTAH_data = df.iloc[16:17, [5,11,18,19,20]]
y_UTAH_data = df.iloc[16, 24:25]

X_OKC_data = df.iloc[20:21, [5,11,18,19,20]]
y_OKC_data = df.iloc[20, 24:25]

X_MEM_data = df.iloc[24:25, [5,11,18,19,20]]
y_MEM_data = df.iloc[24, 24:25]

X_POR_data = df.iloc[28:29, [5,11,18,19,20]]
y_POR_data = df.iloc[28, 24:25]

X_DEN_data = df.iloc[32:33, [5,11,18,19,20]]
y_DEN_data = df.iloc[32, 24:25]

X_NOP_data = df.iloc[36:37, [5,11,18,19,20]]
y_NOP_data = df.iloc[36, 24:25]

X_DAL_data = df.iloc[40:41, [5,11,18,19,20]]
y_DAL_data = df.iloc[40, 24:25]

X_SAC_data = df.iloc[44:45, [5,11,18,19,20]]
y_SAC_data = df.iloc[44, 24:25]

X_MIN_data = df.iloc[48:49, [5,11,18,19,20]]
y_MIN_data = df.iloc[48, 24:25]

X_LAL_data = df.iloc[52:53, [5,11,18,19,20]]
y_LAL_data = df.iloc[52, 24:25]

X_PHO_data = df.iloc[56:57, [5,11,18,19,20]]
y_PHO_data = df.iloc[56, 24:25]

X_BOS_data = df.iloc[60:61, [5,11,18,19,20]]
y_BOS_data = df.iloc[60, 24:25]

X_CLE_data = df.iloc[64:65, [5,11,18,19,20]]
y_CLE_data = df.iloc[64, 24:25]

X_TOR_data = df.iloc[68:69, [5,11,18,19,20]]
y_TOR_data = df.iloc[68, 24:25]

X_WAS_data = df.iloc[72:73, [5,11,18,19,20]]
y_WAS_data = df.iloc[72, 24:25]

X_ATL_data = df.iloc[76:77, [5,11,18,19,20]]
y_ATL_data = df.iloc[76, 24:25]

X_MIL_data = df.iloc[80:81, [5,11,18,19,20]]
y_MIL_data = df.iloc[80, 24:25]

X_IND_data = df.iloc[84:85, [5,11,18,19,20]]
y_IND_data = df.iloc[84, 24:25]

X_CHI_data = df.iloc[88:89, [5,11,18,19,20]]
y_CHI_data = df.iloc[88, 24:25]

X_MIA_data = df.iloc[92:93, [5,11,18,19,20]]
y_MIA_data = df.iloc[92, 24:25]

X_DET_data = df.iloc[96:97, [5,11,18,19,20]]
y_DET_data = df.iloc[96, 24:25]

X_CHA_data = df.iloc[100:101, [5,11,18,19,20]]
y_CHA_data = df.iloc[100, 24:25]

X_NYK_data = df.iloc[104:105, [5,11,18,19,20]]
y_NYK_data = df.iloc[104, 24:25]

X_ORL_data = df.iloc[108:109, [5,11,18,19,20]]
y_ORL_data = df.iloc[108, 24:25]

X_PHI_data = df.iloc[112:113, [5,11,18,19,20]]
y_PHI_data = df.iloc[112, 24:25]

X_BKN_data = df.iloc[116:117, [5,11,18,19,20]]
y_BKN_data = df.iloc[116, 24:25]

# %%
#set the training dataset for first quarter of the season.
#this will not include the team itself

X_GSW_train = df.iloc[[4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], [5,11,18,19,20]]
y_GSW_train = df.iloc[[4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], 24:25]

X_SAS_train = df.iloc[[0,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], [5,11,18,19,20]]
y_SAS_train = df.iloc[[0,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], 24:25]

X_HOU_train = df.iloc[[0,4,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], [5,11,18,19,20]]
y_HOU_train = df.iloc[[0,4,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], 24:25]

X_LAC_train = df.iloc[[0,4,8,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], [5,11,18,19,20]]
y_LAC_train = df.iloc[[0,4,8,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], 24]

X_UTAH_train = df.iloc[[0,4,8,12,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], [5,11,18,19,20]]
y_UTAH_train = df.iloc[[0,4,8,12,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], 24:25]

X_OKC_train = df.iloc[[0,4,8,12,16,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], [5,11,18,19,20]]
y_OKC_train = df.iloc[[0,4,8,12,16,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], 24:25]

X_MEM_train = df.iloc[[0,4,8,12,16,20,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], [5,11,18,19,20]]
y_MEM_train = df.iloc[[0,4,8,12,16,20,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], 24:25]

X_POR_train = df.iloc[[0,4,8,12,16,20,24,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], [5,11,18,19,20]]
y_POR_train = df.iloc[[0,4,8,12,16,20,24,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], 24:25]

X_DEN_train = df.iloc[[0,4,8,12,16,20,24,28,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], [5,11,18,19,20]]
y_DEN_train = df.iloc[[0,4,8,12,16,20,24,28,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], 24:25]

X_NOP_train = df.iloc[[0,4,8,12,16,20,24,28,32,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], [5,11,18,19,20]]
y_NOP_train = df.iloc[[0,4,8,12,16,20,24,28,32,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], 24:25]

X_DAL_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], [5,11,18,19,20]]
y_DAL_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], 24:25]

X_SAC_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], [5,11,18,19,20]]
y_SAC_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], 24:25]

X_MIN_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], [5,11,18,19,20]]
y_MIN_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], 24:25]

X_LAL_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], [5,11,18,19,20]]
y_LAL_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], 24:25]

X_PHO_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], [5,11,18,19,20]]
y_PHO_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116], 24:25]

X_BOS_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,64,68,72,76,80,84,88,92,96,100,104,108,112,116], [5,11,18,19,20]]
y_BOS_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,64,68,72,76,80,84,88,92,96,100,104,108,112,116], 24:25]

X_CLE_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,68,72,76,80,84,88,92,96,100,104,108,112,116], [5,11,18,19,20]]
y_CLE_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,68,72,76,80,84,88,92,96,100,104,108,112,116], 24:25]

X_TOR_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,72,76,80,84,88,92,96,100,104,108,112,116], [5,11,18,19,20]]
y_TOR_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,72,76,80,84,88,92,96,100,104,108,112,116], 24:25]

X_WAS_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,76,80,84,88,92,96,100,104,108,112,116], [5,11,18,19,20]]
y_WAS_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,76,80,84,88,92,96,100,104,108,112,116], 24:25]

X_ATL_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,80,84,88,92,96,100,104,108,112,116], [5,11,18,19,20]]
y_ATL_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,80,84,88,92,96,100,104,108,112,116], 24:25]

X_MIL_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,84,88,92,96,100,104,108,112,116], [5,11,18,19,20]]
y_MIL_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,84,88,92,96,100,104,108,112,116], 24:25]

X_IND_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,88,92,96,100,104,108,112,116], [5,11,18,19,20]]
y_IND_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,88,92,96,100,104,108,112,116], 24:25]

X_CHI_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,92,96,100,104,108,112,116], [5,11,18,19,20]]
y_CHI_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,92,96,100,104,108,112,116], 24:25]

X_MIA_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,96,100,104,108,112,116], [5,11,18,19,20]]
y_MIA_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,96,100,104,108,112,116], 24:25]

X_DET_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,100,104,108,112,116], [5,11,18,19,20]]
y_DET_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,100,104,108,112,116], 24:25]

X_CHA_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,104,108,112,116], [5,11,18,19,20]]
y_CHA_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,104,108,112,116], 24:25]

X_NYK_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,108,112,116], [5,11,18,19,20]]
y_NYK_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,108,112,116], 24:25]

X_ORL_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,112,116], [5,11,18,19,20]]
y_ORL_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,112,116], 24:25]

X_PHI_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,116], [5,11,18,19,20]]
y_PHI_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,116], 24:25]

X_BKN_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112], [5,11,18,19,20]]
y_BKN_train = df.iloc[[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112], 24:25]

# %%
#implement linear regression models

from sklearn.linear_model import LinearRegression

regGSW = LinearRegression()
regGSW.fit(X_GSW_train, y_GSW_train)

regSAS = LinearRegression()
regSAS.fit(X_SAS_train, y_SAS_train)

regHOU = LinearRegression()
regHOU.fit(X_HOU_train, y_HOU_train)

regLAC = LinearRegression()
regLAC.fit(X_LAC_train, y_LAC_train)

regUTAH = LinearRegression()
regUTAH.fit(X_UTAH_train, y_UTAH_train)

regOKC = LinearRegression()
regOKC.fit(X_OKC_train, y_OKC_train)

regMEM = LinearRegression()
regMEM.fit(X_MEM_train, y_MEM_train)

regPOR = LinearRegression()
regPOR.fit(X_POR_train, y_POR_train)

regDEN = LinearRegression()
regDEN.fit(X_DEN_train, y_DEN_train)

regNOP = LinearRegression()
regNOP.fit(X_NOP_train, y_NOP_train)

regDAL = LinearRegression()
regDAL.fit(X_DAL_train, y_DAL_train)

regSAC = LinearRegression()
regSAC.fit(X_SAC_train, y_SAC_train)

regMIN = LinearRegression()
regMIN.fit(X_MIN_train, y_MIN_train)

regLAL = LinearRegression()
regLAL.fit(X_LAL_train, y_LAL_train)

regPHO = LinearRegression()
regPHO.fit(X_PHO_train, y_PHO_train)

regBOS = LinearRegression()
regBOS.fit(X_BOS_train, y_BOS_train)

regCLE = LinearRegression()
regCLE.fit(X_CLE_train, y_CLE_train)

regTOR = LinearRegression()
regTOR.fit(X_TOR_train, y_TOR_train)

regWAS = LinearRegression()
regWAS.fit(X_WAS_train, y_WAS_train)

regATL = LinearRegression()
regATL.fit(X_ATL_train, y_ATL_train)

regMIL = LinearRegression()
regMIL.fit(X_MIL_train, y_MIL_train)

regIND = LinearRegression()
regIND.fit(X_IND_train, y_IND_train)

regCHI = LinearRegression()
regCHI.fit(X_CHI_train, y_CHI_train)

regMIA = LinearRegression()
regMIA.fit(X_MIA_train, y_MIA_train)

regDET = LinearRegression()
regDET.fit(X_DET_train, y_DET_train)

regCHA = LinearRegression()
regCHA.fit(X_CHA_train, y_CHA_train)

regNYK = LinearRegression()
regNYK.fit(X_NYK_train, y_NYK_train)

regORL = LinearRegression()
regORL.fit(X_ORL_train, y_ORL_train)

regPHI = LinearRegression()
regPHI.fit(X_PHI_train, y_PHI_train)

regBKN = LinearRegression()
regBKN.fit(X_BKN_train, y_BKN_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#predict for the first quarter of the season

y_pred_GSW = regGSW.predict(X_GSW_data)

y_pred_SAS = regSAS.predict(X_SAS_data)

y_pred_HOU = regHOU.predict(X_HOU_data)

y_pred_LAC = regLAC.predict(X_LAC_data)

y_pred_UTAH = regUTAH.predict(X_UTAH_data)

y_pred_OKC = regOKC.predict(X_OKC_data)

y_pred_MEM = regMEM.predict(X_MEM_data)

y_pred_POR = regPOR.predict(X_POR_data)

y_pred_DEN = regDEN.predict(X_DEN_data)

y_pred_NOP = regNOP.predict(X_NOP_data)

y_pred_DAL = regDAL.predict(X_DAL_data)

y_pred_SAC = regSAC.predict(X_SAC_data)

y_pred_MIN = regMIN.predict(X_MIN_data)

y_pred_LAL = regLAL.predict(X_LAL_data)

y_pred_PHO = regPHO.predict(X_PHO_data)

y_pred_BOS = regBOS.predict(X_BOS_data)

y_pred_CLE = regCLE.predict(X_CLE_data)

y_pred_TOR = regTOR.predict(X_TOR_data)

y_pred_WAS = regWAS.predict(X_WAS_data)

y_pred_ATL = regATL.predict(X_ATL_data)

y_pred_MIL = regMIL.predict(X_MIL_data)

y_pred_IND = regIND.predict(X_IND_data)

y_pred_CHI = regCHI.predict(X_CHI_data)

y_pred_MIA = regMIA.predict(X_MIA_data)

y_pred_DET = regDET.predict(X_DET_data)

y_pred_CHA = regCHA.predict(X_CHA_data)

y_pred_NYK = regNYK.predict(X_NYK_data)

y_pred_ORL = regORL.predict(X_ORL_data)

y_pred_PHI = regPHI.predict(X_PHI_data)

y_pred_BKN = regBKN.predict(X_BKN_data)

# %%
#put the differences for the first quarter here

diff_GSW = y_GSW_data[0] - y_pred_GSW.item(0)

diff_SAS = y_SAS_data[0] - y_pred_SAS.item(0)

diff_HOU = y_HOU_data[0] - y_pred_HOU.item(0)

diff_LAC = y_LAC_data[0] - y_pred_LAC.item(0)

diff_UTAH = y_UTAH_data[0] - y_pred_UTAH.item(0)

diff_OKC = y_OKC_data[0] - y_pred_OKC.item(0)

diff_MEM = y_MEM_data[0] - y_pred_MEM.item(0)

diff_POR = y_POR_data[0] - y_pred_POR.item(0)

diff_DEN = y_DEN_data[0] - y_pred_DEN.item(0)

diff_NOP = y_NOP_data[0] - y_pred_NOP.item(0)

diff_DAL = y_DAL_data[0] - y_pred_DAL.item(0)

diff_SAC = y_SAC_data[0] - y_pred_SAC.item(0)

diff_MIN = y_MIN_data[0] - y_pred_MIN.item(0)

diff_LAL = y_LAL_data[0] - y_pred_LAL.item(0)

diff_PHO = y_PHO_data[0] - y_pred_PHO.item(0)

diff_BOS = y_BOS_data[0] - y_pred_BOS.item(0)

diff_CLE = y_CLE_data[0] - y_pred_CLE.item(0)

diff_TOR = y_TOR_data[0] - y_pred_TOR.item(0)

diff_WAS = y_WAS_data[0] - y_pred_WAS.item(0)

diff_ATL = y_ATL_data[0] - y_pred_ATL.item(0)

diff_MIL = y_MIL_data[0] - y_pred_MIL.item(0)

diff_IND = y_IND_data[0] - y_pred_IND.item(0)

diff_CHI = y_CHI_data[0] - y_pred_CHI.item(0)

diff_MIA = y_MIA_data[0] - y_pred_MIA.item(0)

diff_DET = y_DET_data[0] - y_pred_DET.item(0)

diff_CHA = y_CHA_data[0] - y_pred_CHA.item(0)

diff_NYK = y_NYK_data[0] - y_pred_NYK.item(0)

diff_ORL = y_ORL_data[0] - y_pred_ORL.item(0)

diff_PHI = y_PHI_data[0] - y_pred_PHI.item(0)

diff_BKN = y_BKN_data[0] - y_pred_BKN.item(0)

# %%
#get percent error for first quarter

err_GSW = round(abs(diff_GSW / y_GSW_data[0]) * 100, 2)

err_SAS = round(abs(diff_SAS / y_SAS_data[0]) * 100, 2)

err_HOU = round(abs(diff_HOU / y_HOU_data[0]) * 100, 2)

err_LAC = round(abs(diff_LAC / y_LAC_data[0]) * 100, 2)

err_UTAH = round(abs(diff_UTAH / y_UTAH_data[0]) * 100, 2)

err_OKC = round(abs(diff_OKC / y_OKC_data[0]) * 100, 2)

err_MEM = round(abs(diff_MEM / y_MEM_data[0]) * 100, 2)

err_POR = round(abs(diff_POR / y_POR_data[0]) * 100, 2)

err_DEN = round(abs(diff_DEN / y_DEN_data[0]) * 100, 2)

err_NOP = round(abs(diff_NOP / y_NOP_data[0]) * 100, 2)

err_DAL = round(abs(diff_DAL / y_DAL_data[0]) * 100, 2)

err_SAC = round(abs(diff_SAC / y_SAC_data[0]) * 100, 2)

err_MIN = round(abs(diff_MIN / y_MIN_data[0]) * 100, 2)

err_LAL = round(abs(diff_LAL / y_LAL_data[0]) * 100, 2)

err_PHO = round(abs(diff_PHO / y_PHO_data[0]) * 100, 2)

err_BOS = round(abs(diff_BOS / y_BOS_data[0]) * 100, 2)

err_CLE = round(abs(diff_CLE / y_CLE_data[0]) * 100, 2)

err_TOR = round(abs(diff_TOR / y_TOR_data[0]) * 100, 2)

err_WAS = round(abs(diff_WAS / y_WAS_data[0]) * 100, 2)

err_ATL = round(abs(diff_ATL / y_ATL_data[0]) * 100, 2)

err_MIL = round(abs(diff_MIL / y_MIL_data[0]) * 100, 2)

err_IND = round(abs(diff_IND / y_IND_data[0]) * 100, 2)

err_CHI = round(abs(diff_CHI / y_CHI_data[0]) * 100, 2)

err_MIA = round(abs(diff_MIA / y_MIA_data[0]) * 100, 2)

err_DET = round(abs(diff_DET / y_DET_data[0]) * 100, 2)

err_CHA = round(abs(diff_CHA / y_CHA_data[0]) * 100, 2)

err_NYK = round(abs(diff_NYK / y_NYK_data[0]) * 100, 2)

err_ORL = round(abs(diff_ORL / y_ORL_data[0]) * 100, 2)

err_PHI = round(abs(diff_PHI / y_PHI_data[0]) * 100, 2)

err_BKN = round(abs(diff_BKN / y_BKN_data[0]) * 100, 2)

# %%
pd.DataFrame(list(zip(X_GSW_train.columns, regGSW.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Defensive Rebounds
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.193630
# 1  Defensive Rebounds         -1.377162
# 2      Average Points          0.186168
# 3          Attendees           0.003298
# 4     Team Efficiency          0.127336

# %%
pd.DataFrame(list(zip(X_SAS_train.columns, regSAS.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Defensive Rebounds
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.162613
# 1  Defensive Rebounds         -1.035879
# 2      Average Points         -0.104324
# 3          Attendees           0.004010
# 4     Team Efficiency          0.661474

# %%
pd.DataFrame(list(zip(X_HOU_train.columns, regHOU.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.298295
# 1  Defensive Rebounds         -0.976406
# 2      Average Points         -0.156674
# 3          Attendees           0.003793
# 4     Team Efficiency          0.707475

# %%
pd.DataFrame(list(zip(X_LAC_train.columns, regLAC.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.156808
# 1  Defensive Rebounds         -0.895568
# 2      Average Points         -0.210542
# 3          Attendees           0.003955
# 4     Team Efficiency          0.726630

# %%
pd.DataFrame(list(zip(X_UTAH_train.columns, regUTAH.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.132503
# 1  Defensive Rebounds         -0.992349
# 2      Average Points         -0.067005
# 3          Attendees           0.004068
# 4     Team Efficiency          0.647964

# %%
pd.DataFrame(list(zip(X_OKC_train.columns, regOKC.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.171676
# 1  Defensive Rebounds         -1.038589
# 2      Average Points         -0.172715
# 3          Attendees           0.004070
# 4     Team Efficiency          0.705743

# %%
pd.DataFrame(list(zip(X_MEM_train.columns, regMEM.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.111642
# 1  Defensive Rebounds         -1.033083
# 2      Average Points         -0.007765
# 3          Attendees           0.004504
# 4     Team Efficiency          0.669168

# %%
pd.DataFrame(list(zip(X_POR_train.columns, regPOR.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.244035
# 1  Defensive Rebounds         -1.164247
# 2      Average Points         -0.189763
# 3          Attendees           0.003970
# 4     Team Efficiency          0.748798

# %%
pd.DataFrame(list(zip(X_DEN_train.columns, regDEN.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.191522
# 1  Defensive Rebounds         -0.945973
# 2      Average Points         -0.268458
# 3          Attendees           0.003654
# 4     Team Efficiency          0.786925

# %%
pd.DataFrame(list(zip(X_NOP_train.columns, regNOP.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.154196
# 1  Defensive Rebounds         -0.895506
# 2      Average Points         -0.173935
# 3          Attendees           0.003796
# 4     Team Efficiency          0.725487

# %%
pd.DataFrame(list(zip(X_DAL_train.columns, regDAL.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.218359
# 1  Defensive Rebounds         -1.095418
# 2      Average Points         -0.114348
# 3          Attendees           0.004179
# 4     Team Efficiency          0.615420

# %%
pd.DataFrame(list(zip(X_SAC_train.columns, regSAC.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.130883
# 1  Defensive Rebounds         -1.085690
# 2      Average Points         -0.157789
# 3          Attendees           0.004061
# 4     Team Efficiency          0.682359

# %%
pd.DataFrame(list(zip(X_MIN_train.columns, regMIN.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.012510
# 1  Defensive Rebounds         -1.249243
# 2      Average Points         -0.025208
# 3          Attendees           0.004043
# 4     Team Efficiency          0.703135

# %%
pd.DataFrame(list(zip(X_LAL_train.columns, regLAL.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.110481
# 1  Defensive Rebounds         -0.901321
# 2      Average Points         -0.078728
# 3          Attendees           0.004113
# 4     Team Efficiency          0.636808

# %%
pd.DataFrame(list(zip(X_PHO_train.columns, regPHO.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.209016
# 1  Defensive Rebounds         -1.043545
# 2      Average Points         -0.365156
# 3          Attendees           0.004193
# 4     Team Efficiency          0.853740

# %%
pd.DataFrame(list(zip(X_BOS_train.columns, regBOS.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.102379
# 1  Defensive Rebounds         -1.382904
# 2      Average Points          0.111771
# 3          Attendees           0.004347
# 4     Team Efficiency          0.557319

# %%
pd.DataFrame(list(zip(X_CLE_train.columns, regCLE.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.275448
# 1  Defensive Rebounds          0.615874
# 2      Average Points         -1.448980
# 3          Attendees           0.000206
# 4     Team Efficiency          1.380314

# %%
pd.DataFrame(list(zip(X_TOR_train.columns, regTOR.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.169567
# 1  Defensive Rebounds         -1.134386
# 2      Average Points         -0.102311
# 3          Attendees           0.004183
# 4     Team Efficiency          0.696602

# %%
pd.DataFrame(list(zip(X_WAS_train.columns, regWAS.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.190719
# 1  Defensive Rebounds         -0.990644
# 2      Average Points         -0.183550
# 3          Attendees           0.004030
# 4     Team Efficiency          0.700463

# %%
pd.DataFrame(list(zip(X_ATL_train.columns, regATL.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.140632
# 1  Defensive Rebounds         -0.876706
# 2      Average Points         -0.130179
# 3          Attendees           0.004374
# 4     Team Efficiency          0.694595

# %%
pd.DataFrame(list(zip(X_MIL_train.columns, regMIL.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.182749
# 1  Defensive Rebounds         -0.936578
# 2      Average Points         -0.094585
# 3          Attendees           0.004160
# 4     Team Efficiency          0.641553

# %%
pd.DataFrame(list(zip(X_IND_train.columns, regIND.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.200167
# 1  Defensive Rebounds         -1.050911
# 2      Average Points         -0.133794
# 3          Attendees           0.004198
# 4     Team Efficiency          0.655076

# %%
pd.DataFrame(list(zip(X_CHI_train.columns, regCHI.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.092029
# 1  Defensive Rebounds         -1.089117
# 2      Average Points         -0.006674
# 3          Attendees           0.003645
# 4     Team Efficiency          0.693789

# %%
pd.DataFrame(list(zip(X_MIA_train.columns, regMIA.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.208474
# 1  Defensive Rebounds         -0.969524
# 2      Average Points         -0.160430
# 3          Attendees           0.004168
# 4     Team Efficiency          0.648303

# %%
pd.DataFrame(list(zip(X_DET_train.columns, regDET.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.162363
# 1  Defensive Rebounds         -1.151429
# 2      Average Points         -0.136250
# 3          Attendees           0.003926
# 4     Team Efficiency          0.711571

# %%
pd.DataFrame(list(zip(X_CHA_train.columns, regCHA.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.158273
# 1  Defensive Rebounds         -0.997423
# 2      Average Points         -0.143697
# 3          Attendees           0.003993
# 4     Team Efficiency          0.687320

# %%
pd.DataFrame(list(zip(X_NYK_train.columns, regNYK.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.028532
# 1  Defensive Rebounds         -1.194651
# 2      Average Points         -0.016271
# 3          Attendees           0.004726
# 4     Team Efficiency          0.624725

# %%
pd.DataFrame(list(zip(X_ORL_train.columns, regORL.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.165868
# 1  Defensive Rebounds         -1.029392
# 2      Average Points         -0.105334
# 3          Attendees           0.003969
# 4     Team Efficiency          0.673753

# %%
pd.DataFrame(list(zip(X_PHI_train.columns, regPHI.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.131906
# 1  Defensive Rebounds         -0.661313
# 2      Average Points         -0.166368
# 3          Attendees           0.004458
# 4     Team Efficiency          0.724653

# %%
pd.DataFrame(list(zip(X_BKN_train.columns, regBKN.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
#Team Efficiency
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.161639
# 1  Defensive Rebounds         -1.000753
# 2      Average Points         -0.135412
# 3          Attendees           0.003978
# 4     Team Efficiency          0.681686

# %%
#set the data to be predicted for second quarter

X_GSW_data2 = df.iloc[1:2, [5,11,18,19,20]]
y_GSW_data2 = df.iloc[1, 24:25]

X_SAS_data2 = df.iloc[5:6, [5,11,18,19,20]]
y_SAS_data2 = df.iloc[5, 24:25]

X_HOU_data2 = df.iloc[9:10, [5,11,18,19,20]]
y_HOU_data2 = df.iloc[9, 24:25]

X_LAC_data2 = df.iloc[13:14, [5,11,18,19,20]]
y_LAC_data2 = df.iloc[13, 24:25]

X_UTAH_data2 = df.iloc[17:18, [5,11,18,19,20]]
y_UTAH_data2 = df.iloc[17, 24:25]

X_OKC_data2 = df.iloc[21:22, [5,11,18,19,20]]
y_OKC_data2 = df.iloc[21, 24:25]

X_MEM_data2 = df.iloc[25:26, [5,11,18,19,20]]
y_MEM_data2 = df.iloc[25, 24:25]

X_POR_data2 = df.iloc[29:30, [5,11,18,19,20]]
y_POR_data2 = df.iloc[29, 24:25]

X_DEN_data2 = df.iloc[33:34, [5,11,18,19,20]]
y_DEN_data2 = df.iloc[33, 24:25]

X_NOP_data2 = df.iloc[37:38, [5,11,18,19,20]]
y_NOP_data2 = df.iloc[37, 24:25]

X_DAL_data2 = df.iloc[41:42, [5,11,18,19,20]]
y_DAL_data2 = df.iloc[41, 24:25]

X_SAC_data2 = df.iloc[45:46, [5,11,18,19,20]]
y_SAC_data2 = df.iloc[45, 24:25]

X_MIN_data2 = df.iloc[49:50, [5,11,18,19,20]]
y_MIN_data2 = df.iloc[49, 24:25]

X_LAL_data2 = df.iloc[53:54, [5,11,18,19,20]]
y_LAL_data2 = df.iloc[53, 24:25]

X_PHO_data2 = df.iloc[57:58, [5,11,18,19,20]]
y_PHO_data2 = df.iloc[57, 24:25]

X_BOS_data2 = df.iloc[61:62, [5,11,18,19,20]]
y_BOS_data2 = df.iloc[61, 24:25]

X_CLE_data2 = df.iloc[65:66, [5,11,18,19,20]]
y_CLE_data2 = df.iloc[65, 24:25]

X_TOR_data2 = df.iloc[69:70, [5,11,18,19,20]]
y_TOR_data2 = df.iloc[69, 24:25]

X_WAS_data2 = df.iloc[73:74, [5,11,18,19,20]]
y_WAS_data2 = df.iloc[73, 24:25]

X_ATL_data2 = df.iloc[77:78, [5,11,18,19,20]]
y_ATL_data2 = df.iloc[77, 24:25]

X_MIL_data2 = df.iloc[81:82, [5,11,18,19,20]]
y_MIL_data2 = df.iloc[81, 24:25]

X_IND_data2 = df.iloc[85:86, [5,11,18,19,20]]
y_IND_data2 = df.iloc[85, 24:25]

X_CHI_data2 = df.iloc[89:90, [5,11,18,19,20]]
y_CHI_data2 = df.iloc[89, 24:25]

X_MIA_data2 = df.iloc[93:94, [5,11,18,19,20]]
y_MIA_data2 = df.iloc[93, 24:25]

X_DET_data2 = df.iloc[97:98, [5,11,18,19,20]]
y_DET_data2 = df.iloc[97, 24:25]

X_CHA_data2 = df.iloc[101:102, [5,11,18,19,20]]
y_CHA_data2 = df.iloc[101, 24:25]

X_NYK_data2 = df.iloc[105:106, [5,11,18,19,20]]
y_NYK_data2 = df.iloc[105, 24:25]

X_ORL_data2 = df.iloc[109:110, [5,11,18,19,20]]
y_ORL_data2 = df.iloc[109, 24:25]

X_PHI_data2 = df.iloc[113:114, [5,11,18,19,20]]
y_PHI_data2 = df.iloc[113, 24:25]

X_BKN_data2 = df.iloc[117:118, [5,11,18,19,20]]
y_BKN_data2 = df.iloc[117, 24:25]

# %%
#set training data for second quarter of the season

X_GSW_train2 = df.iloc[[5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], [5,11,18,19,20]]
y_GSW_train2 = df.iloc[[5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], 24:25]

X_SAS_train2 = df.iloc[[1,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], [5,11,18,19,20]]
y_SAS_train2 = df.iloc[[1,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], 24:25]

X_HOU_train2 = df.iloc[[1,5,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], [5,11,18,19,20]]
y_HOU_train2 = df.iloc[[1,5,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], 24:25]

X_LAC_train2 = df.iloc[[1,5,9,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], [5,11,18,19,20]]
y_LAC_train2 = df.iloc[[1,5,9,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], 24:25]

X_UTAH_train2 = df.iloc[[1,5,9,13,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], [5,11,18,19,20]]
y_UTAH_train2 = df.iloc[[1,5,9,13,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], 24:25]

X_OKC_train2 = df.iloc[[1,5,9,13,17,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], [5,11,18,19,20]]
y_OKC_train2 = df.iloc[[1,5,9,13,17,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], 24:25]

X_MEM_train2 = df.iloc[[1,5,9,13,17,21,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], [5,11,18,19,20]]
y_MEM_train2 = df.iloc[[1,5,9,13,17,21,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], 24:25]

X_POR_train2 = df.iloc[[1,5,9,13,17,21,25,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], [5,11,18,19,20]]
y_POR_train2 = df.iloc[[1,5,9,13,17,21,25,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], 24:25]

X_DEN_train2 = df.iloc[[1,5,9,13,17,21,25,29,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], [5,11,18,19,20]]
y_DEN_train2 = df.iloc[[1,5,9,13,17,21,25,29,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], 24:25]

X_NOP_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], [5,11,18,19,20]]
y_NOP_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], 24:25]

X_DAL_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], [5,11,18,19,20]]
y_DAL_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], 24:25]

X_SAC_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], [5,11,18,19,20]]
y_SAC_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], 24:25]

X_MIN_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], [5,11,18,19,20]]
y_MIN_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], 24:25]

X_LAL_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], [5,11,18,19,20]]
y_LAL_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], 24:25]

X_PHO_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], [5,11,18,19,20]]
y_PHO_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,61,65,69,73,77,81,85,89,93,97,101,105,109,113,117], 24:25]

X_BOS_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,65,69,73,77,81,85,89,93,97,101,105,109,113,117], [5,11,18,19,20]]
y_BOS_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,65,69,73,77,81,85,89,93,97,101,105,109,113,117], 24:25]

X_CLE_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,69,73,77,81,85,89,93,97,101,105,109,113,117], [5,11,18,19,20]]
y_CLE_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,69,73,77,81,85,89,93,97,101,105,109,113,117], 24:25]

X_TOR_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,73,77,81,85,89,93,97,101,105,109,113,117], [5,11,18,19,20]]
y_TOR_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,73,77,81,85,89,93,97,101,105,109,113,117], 24:25]

X_WAS_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,77,81,85,89,93,97,101,105,109,113,117], [5,11,18,19,20]]
y_WAS_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,77,81,85,89,93,97,101,105,109,113,117], 24:25]

X_ATL_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,81,85,89,93,97,101,105,109,113,117], [5,11,18,19,20]]
y_ATL_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,81,85,89,93,97,101,105,109,113,117], 24:25]

X_MIL_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,85,89,93,97,101,105,109,113,117], [5,11,18,19,20]]
y_MIL_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,85,89,93,97,101,105,109,113,117], 24:25]

X_IND_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,89,93,97,101,105,109,113,117], [5,11,18,19,20]]
y_IND_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,89,93,97,101,105,109,113,117], 24:25]

X_CHI_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,93,97,101,105,109,113,117], [5,11,18,19,20]]
y_CHI_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,93,97,101,105,109,113,117], 24:25]

X_MIA_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,97,101,105,109,113,117], [5,11,18,19,20]]
y_MIA_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,97,101,105,109,113,117], 24:25]

X_DET_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,101,105,109,113,117], [5,11,18,19,20]]
y_DET_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,101,105,109,113,117], 24:25]

X_CHA_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,105,109,113,117], [5,11,18,19,20]]
y_CHA_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,105,109,113,117], 24:25]

X_NYK_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,109,113,117], [5,11,18,19,20]]
y_NYK_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,109,113,117], 24:25]

X_ORL_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,113,117], [5,11,18,19,20]]
y_ORL_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,113,117], 24:25]

X_PHI_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,117], [5,11,18,19,20]]
y_PHI_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,117], 24:25]

X_BKN_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113], [5,11,18,19,20]]
y_BKN_train2 = df.iloc[[1,5,9,13,17,21,25,29,33,37,41,45,49,53,57,61,65,69,73,77,81,85,89,93,97,101,105,109,113], 24:25]

# %%
#implement linear regression models

regGSW2 = LinearRegression()
regGSW2.fit(X_GSW_train2, y_GSW_train2)

regSAS2 = LinearRegression()
regSAS2.fit(X_SAS_train2, y_SAS_train2)

regHOU2 = LinearRegression()
regHOU2.fit(X_HOU_train2, y_HOU_train2)

regLAC2 = LinearRegression()
regLAC2.fit(X_LAC_train2, y_LAC_train2)

regUTAH2 = LinearRegression()
regUTAH2.fit(X_UTAH_train2, y_UTAH_train2)

regOKC2 = LinearRegression()
regOKC2.fit(X_OKC_train2, y_OKC_train2)

regMEM2 = LinearRegression()
regMEM2.fit(X_MEM_train2, y_MEM_train2)

regPOR2 = LinearRegression()
regPOR2.fit(X_POR_train2, y_POR_train2)

regDEN2 = LinearRegression()
regDEN2.fit(X_DEN_train2, y_DEN_train2)

regNOP2 = LinearRegression()
regNOP2.fit(X_NOP_train2, y_NOP_train2)

regDAL2 = LinearRegression()
regDAL2.fit(X_DAL_train2, y_DAL_train2)

regSAC2 = LinearRegression()
regSAC2.fit(X_SAC_train2, y_SAC_train2)

regMIN2 = LinearRegression()
regMIN2.fit(X_MIN_train2, y_MIN_train2)

regLAL2 = LinearRegression()
regLAL2.fit(X_LAL_train2, y_LAL_train2)

regPHO2 = LinearRegression()
regPHO2.fit(X_PHO_train2, y_PHO_train2)

regBOS2 = LinearRegression()
regBOS2.fit(X_BOS_train2, y_BOS_train2)

regCLE2 = LinearRegression()
regCLE2.fit(X_CLE_train2, y_CLE_train2)

regTOR2 = LinearRegression()
regTOR2.fit(X_TOR_train2, y_TOR_train2)

regWAS2 = LinearRegression()
regWAS2.fit(X_WAS_train2, y_WAS_train2)

regATL2 = LinearRegression()
regATL2.fit(X_ATL_train2, y_ATL_train2)

regMIL2 = LinearRegression()
regMIL2.fit(X_MIL_train2, y_MIL_train2)

regIND2 = LinearRegression()
regIND2.fit(X_IND_train2, y_IND_train2)

regCHI2 = LinearRegression()
regCHI2.fit(X_CHI_train2, y_CHI_train2)

regMIA2 = LinearRegression()
regMIA2.fit(X_MIA_train2, y_MIA_train2)

regDET2 = LinearRegression()
regDET2.fit(X_DET_train2, y_DET_train2)

regCHA2 = LinearRegression()
regCHA2.fit(X_CHA_train2, y_CHA_train2)

regNYK2 = LinearRegression()
regNYK2.fit(X_NYK_train2, y_NYK_train2)

regORL2 = LinearRegression()
regORL2.fit(X_ORL_train2, y_ORL_train2)

regPHI2 = LinearRegression()
regPHI2.fit(X_PHI_train2, y_PHI_train2)

regBKN2 = LinearRegression()
regBKN2.fit(X_BKN_train2, y_BKN_train2)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#predict for the second quarter of the season

y_pred_GSW2 = regGSW2.predict(X_GSW_data2)

y_pred_SAS2 = regSAS2.predict(X_SAS_data2)

y_pred_HOU2 = regHOU2.predict(X_HOU_data2)

y_pred_LAC2 = regLAC2.predict(X_LAC_data2)

y_pred_UTAH2 = regUTAH2.predict(X_UTAH_data2)

y_pred_OKC2 = regOKC2.predict(X_OKC_data2)

y_pred_MEM2 = regMEM2.predict(X_MEM_data2)

y_pred_POR2 = regPOR2.predict(X_POR_data2)

y_pred_DEN2 = regDEN2.predict(X_DEN_data2)

y_pred_NOP2 = regNOP2.predict(X_NOP_data2)

y_pred_DAL2 = regDAL2.predict(X_DAL_data2)

y_pred_SAC2 = regSAC2.predict(X_SAC_data2)

y_pred_MIN2 = regMIN2.predict(X_MIN_data2)

y_pred_LAL2 = regLAL2.predict(X_LAL_data2)

y_pred_PHO2 = regPHO2.predict(X_PHO_data2)

y_pred_BOS2 = regBOS2.predict(X_BOS_data2)

y_pred_CLE2 = regCLE2.predict(X_CLE_data2)

y_pred_TOR2 = regTOR2.predict(X_TOR_data2)

y_pred_WAS2 = regWAS2.predict(X_WAS_data2)

y_pred_ATL2 = regATL2.predict(X_ATL_data2)

y_pred_MIL2 = regMIL2.predict(X_MIL_data2)

y_pred_IND2 = regIND2.predict(X_IND_data2)

y_pred_CHI2 = regCHI2.predict(X_CHI_data2)

y_pred_MIA2 = regMIA2.predict(X_MIA_data2)

y_pred_DET2 = regDET2.predict(X_DET_data2)

y_pred_CHA2 = regCHA2.predict(X_CHA_data2)

y_pred_NYK2 = regNYK2.predict(X_NYK_data2)

y_pred_ORL2 = regORL2.predict(X_ORL_data2)

y_pred_PHI2 = regPHI2.predict(X_PHI_data2)

y_pred_BKN2 = regBKN2.predict(X_BKN_data2)

# %%
#put the differences for the second quarter here

diff_GSW2 = y_GSW_data2[0] - y_pred_GSW2.item(0)

diff_SAS2 = y_SAS_data2[0] - y_pred_SAS2.item(0)

diff_HOU2 = y_HOU_data2[0] - y_pred_HOU2.item(0)

diff_LAC2 = y_LAC_data2[0] - y_pred_LAC2.item(0)

diff_UTAH2 = y_UTAH_data2[0] - y_pred_UTAH2.item(0)

diff_OKC2 = y_OKC_data2[0] - y_pred_OKC2.item(0)

diff_MEM2 = y_MEM_data2[0] - y_pred_MEM2.item(0)

diff_POR2 = y_POR_data2[0] - y_pred_POR2.item(0)

diff_DEN2 = y_DEN_data2[0] - y_pred_DEN2.item(0)

diff_NOP2 = y_NOP_data2[0] - y_pred_NOP2.item(0)

diff_DAL2 = y_DAL_data2[0] - y_pred_DAL2.item(0)

diff_SAC2 = y_SAC_data2[0] - y_pred_SAC2.item(0)

diff_MIN2 = y_MIN_data2[0] - y_pred_MIN2.item(0)

diff_LAL2 = y_LAL_data2[0] - y_pred_LAL2.item(0)

diff_PHO2 = y_PHO_data2[0] - y_pred_PHO2.item(0)

diff_BOS2 = y_BOS_data2[0] - y_pred_BOS2.item(0)

diff_CLE2 = y_CLE_data2[0] - y_pred_CLE2.item(0)

diff_TOR2 = y_TOR_data2[0] - y_pred_TOR2.item(0)

diff_WAS2 = y_WAS_data2[0] - y_pred_WAS2.item(0)

diff_ATL2 = y_ATL_data2[0] - y_pred_ATL2.item(0)

diff_MIL2 = y_MIL_data2[0] - y_pred_MIL2.item(0)

diff_IND2 = y_IND_data2[0] - y_pred_IND2.item(0)

diff_CHI2 = y_CHI_data2[0] - y_pred_CHI2.item(0)

diff_MIA2 = y_MIA_data2[0] - y_pred_MIA2.item(0)

diff_DET2 = y_DET_data2[0] - y_pred_DET2.item(0)

diff_CHA2 = y_CHA_data2[0] - y_pred_CHA2.item(0)

diff_NYK2 = y_NYK_data2[0] - y_pred_NYK2.item(0)

diff_ORL2 = y_ORL_data2[0] - y_pred_ORL2.item(0)

diff_PHI2 = y_PHI_data2[0] - y_pred_PHI2.item(0)

diff_BKN2 = y_BKN_data2[0] - y_pred_BKN2.item(0)

# %%
#get percent error for second quarter

err_GSW2 = round(abs(diff_GSW2 / y_GSW_data2[0]) * 100, 2)

err_SAS2 = round(abs(diff_SAS2 / y_SAS_data2[0]) * 100, 2)

err_HOU2 = round(abs(diff_HOU2 / y_HOU_data2[0]) * 100, 2)

err_LAC2 = round(abs(diff_LAC2 / y_LAC_data2[0]) * 100, 2)

err_UTAH2 = round(abs(diff_UTAH2 / y_UTAH_data2[0]) * 100, 2)

err_OKC2 = round(abs(diff_OKC2 / y_OKC_data2[0]) * 100, 2)

err_MEM2 = round(abs(diff_MEM2 / y_MEM_data2[0]) * 100, 2)

err_POR2 = round(abs(diff_POR2 / y_POR_data2[0]) * 100, 2)

err_DEN2 = round(abs(diff_DEN2 / y_DEN_data2[0]) * 100, 2)

err_NOP2 = round(abs(diff_NOP2 / y_NOP_data2[0]) * 100, 2)

err_DAL2 = round(abs(diff_DAL2 / y_DAL_data2[0]) * 100, 2)

err_SAC2 = round(abs(diff_SAC2 / y_SAC_data2[0]) * 100, 2)

err_MIN2 = round(abs(diff_MIN2 / y_MIN_data2[0]) * 100, 2)

err_LAL2 = round(abs(diff_LAL2 / y_LAL_data2[0]) * 100, 2)

err_PHO2 = round(abs(diff_PHO2 / y_PHO_data2[0]) * 100, 2)

err_BOS2 = round(abs(diff_BOS2 / y_BOS_data2[0]) * 100, 2)

err_CLE2 = round(abs(diff_CLE2 / y_CLE_data2[0]) * 100, 2)

err_TOR2 = round(abs(diff_TOR2 / y_TOR_data2[0]) * 100, 2)

err_WAS2 = round(abs(diff_WAS2 / y_WAS_data2[0]) * 100, 2)

err_ATL2 = round(abs(diff_ATL2 / y_ATL_data2[0]) * 100, 2)

err_MIL2 = round(abs(diff_MIL2 / y_MIL_data2[0]) * 100, 2)

err_IND2 = round(abs(diff_IND2 / y_IND_data2[0]) * 100, 2)

err_CHI2 = round(abs(diff_CHI2 / y_CHI_data2[0]) * 100, 2)

err_MIA2 = round(abs(diff_MIA2 / y_MIA_data2[0]) * 100, 2)

err_DET2 = round(abs(diff_DET2 / y_DET_data2[0]) * 100, 2)

err_CHA2 = round(abs(diff_CHA2 / y_CHA_data2[0]) * 100, 2)

err_NYK2 = round(abs(diff_NYK2 / y_NYK_data2[0]) * 100, 2)

err_ORL2 = round(abs(diff_ORL2 / y_ORL_data2[0]) * 100, 2)

err_PHI2 = round(abs(diff_PHI2 / y_PHI_data2[0]) * 100, 2)

err_BKN2 = round(abs(diff_BKN2 / y_BKN_data2[0]) * 100, 2)

# %%
pd.DataFrame(list(zip(X_GSW_train2.columns, regGSW2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.295614
# 1  Defensive Rebounds         -0.564659
# 2      Average Points         -0.254509
# 3          Attendees           0.001803
# 4     Team Efficiency          0.449808

# %%
pd.DataFrame(list(zip(X_SAS_train2.columns, regSAS2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.306389
# 1  Defensive Rebounds          0.419663
# 2      Average Points         -0.995468
# 3          Attendees           0.001654
# 4     Team Efficiency          1.277615

# %%
pd.DataFrame(list(zip(X_HOU_train2.columns, regHOU2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.381299
# 1  Defensive Rebounds          0.430201
# 2      Average Points         -0.973830
# 3          Attendees           0.001686
# 4     Team Efficiency          1.269163

# %%
pd.DataFrame(list(zip(X_LAC_train2.columns, regLAC2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.330888
# 1  Defensive Rebounds          0.387926
# 2      Average Points         -1.201890
# 3          Attendees           0.001935
# 4     Team Efficiency          1.389539

# %%
pd.DataFrame(list(zip(X_UTAH_train2.columns, regUTAH2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.254073
# 1  Defensive Rebounds          0.434391
# 2      Average Points         -0.945748
# 3          Attendees           0.001751
# 4     Team Efficiency          1.250062

# %%
pd.DataFrame(list(zip(X_OKC_train2.columns, regOKC2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.289999
# 1  Defensive Rebounds          0.478961
# 2      Average Points         -1.096178
# 3          Attendees           0.001750
# 4     Team Efficiency          1.340165

# %%
pd.DataFrame(list(zip(X_MEM_train2.columns, regMEM2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.283443
# 1  Defensive Rebounds          0.743706
# 2      Average Points         -1.029952
# 3          Attendees           0.001764
# 4     Team Efficiency          1.377947

# %%
pd.DataFrame(list(zip(X_POR_train2.columns, regPOR2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.368758
# 1  Defensive Rebounds          0.564430
# 2      Average Points         -1.323925
# 3          Attendees           0.001295
# 4     Team Efficiency          1.527643

# %%
pd.DataFrame(list(zip(X_DEN_train2.columns, regDEN2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.402604
# 1  Defensive Rebounds          0.886806
# 2      Average Points         -1.381588
# 3          Attendees           0.001008
# 4     Team Efficiency          1.561334

# %%
pd.DataFrame(list(zip(X_NOP_train2.columns, regNOP2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.237126
# 1  Defensive Rebounds          0.471875
# 2      Average Points         -0.838484
# 3          Attendees           0.001271
# 4     Team Efficiency          1.268316

# %%
pd.DataFrame(list(zip(X_DAL_train2.columns, regDAL2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.412170
# 1  Defensive Rebounds          0.261424
# 2      Average Points         -1.312789
# 3          Attendees           0.002031
# 4     Team Efficiency          1.466961

# %%
pd.DataFrame(list(zip(X_SAC_train2.columns, regSAC2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.285268
# 1  Defensive Rebounds          0.483808
# 2      Average Points         -1.116755
# 3          Attendees           0.001673
# 4     Team Efficiency          1.332481

# %%
pd.DataFrame(list(zip(X_MIN_train2.columns, regMIN2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.199395
# 1  Defensive Rebounds          0.396008
# 2      Average Points         -1.112526
# 3          Attendees           0.001199
# 4     Team Efficiency          1.439939

# %%
pd.DataFrame(list(zip(X_LAL_train2.columns, regLAL2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.272106
# 1  Defensive Rebounds          0.369239
# 2      Average Points         -0.886219
# 3          Attendees           0.002196
# 4     Team Efficiency          1.178121

# %%
pd.DataFrame(list(zip(X_PHO_train2.columns, regPHO2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.289317
# 1  Defensive Rebounds          0.465144
# 2      Average Points         -1.047630
# 3          Attendees           0.001708
# 4     Team Efficiency          1.297661

# %%
pd.DataFrame(list(zip(X_BOS_train2.columns, regBOS2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.276976
# 1  Defensive Rebounds          0.458164
# 2      Average Points         -1.027187
# 3          Attendees           0.001689
# 4     Team Efficiency          1.295098

# %%
pd.DataFrame(list(zip(X_CLE_train2.columns, regCLE2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.112241
# 1  Defensive Rebounds          1.116610
# 2      Average Points         -1.115547
# 3          Attendees           0.000183
# 4     Team Efficiency          1.324750

# %%
pd.DataFrame(list(zip(X_TOR_train2.columns, regTOR2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.288243
# 1  Defensive Rebounds          0.461376
# 2      Average Points         -1.008294
# 3          Attendees           0.001748
# 4     Team Efficiency          1.289783

# %%
pd.DataFrame(list(zip(X_WAS_train2.columns, regWAS2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.304276
# 1  Defensive Rebounds          0.446240
# 2      Average Points         -1.035229
# 3          Attendees           0.001789
# 4     Team Efficiency          1.287276

# %%
pd.DataFrame(list(zip(X_ATL_train2.columns, regATL2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.237582
# 1  Defensive Rebounds          0.792821
# 2      Average Points         -1.117141
# 3          Attendees           0.002133
# 4     Team Efficiency          1.327483

# %%
pd.DataFrame(list(zip(X_MIL_train2.columns, regMIL2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.354982
# 1  Defensive Rebounds          0.750035
# 2      Average Points         -1.190824
# 3          Attendees           0.001570
# 4     Team Efficiency          1.360521

# %%
pd.DataFrame(list(zip(X_IND_train2.columns, regIND2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.314260
# 1  Defensive Rebounds          0.426676
# 2      Average Points         -1.009682
# 3          Attendees           0.002081
# 4     Team Efficiency          1.247885

# %%
pd.DataFrame(list(zip(X_CHI_train2.columns, regCHI2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.297456
# 1  Defensive Rebounds          0.472659
# 2      Average Points         -1.074899
# 3          Attendees           0.001689
# 4     Team Efficiency          1.318014

# %%
pd.DataFrame(list(zip(X_MIA_train2.columns, regMIA2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.482987
# 1  Defensive Rebounds          0.115597
# 2      Average Points         -1.505849
# 3          Attendees           0.002211
# 4     Team Efficiency          1.535593

# %%
pd.DataFrame(list(zip(X_DET_train2.columns, regDET2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.308134
# 1  Defensive Rebounds          0.459075
# 2      Average Points         -1.127793
# 3          Attendees           0.001739
# 4     Team Efficiency          1.327171

# %%
pd.DataFrame(list(zip(X_CHA_train2.columns, regCHA2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.279230
# 1  Defensive Rebounds          0.553709
# 2      Average Points         -1.054863
# 3          Attendees           0.001625
# 4     Team Efficiency          1.300437

# %%
pd.DataFrame(list(zip(X_NYK_train2.columns, regNYK2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.163362
# 1  Defensive Rebounds          0.505340
# 2      Average Points         -0.958557
# 3          Attendees           0.001932
# 4     Team Efficiency          1.236993

# %%
pd.DataFrame(list(zip(X_ORL_train2.columns, regORL2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.297677
# 1  Defensive Rebounds          0.541393
# 2      Average Points         -1.132563
# 3          Attendees           0.001680
# 4     Team Efficiency          1.368635

# %%
pd.DataFrame(list(zip(X_PHI_train2.columns, regPHI2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.237806
# 1  Defensive Rebounds          0.483855
# 2      Average Points         -0.866990
# 3          Attendees           0.002352
# 4     Team Efficiency          1.160938

# %%
pd.DataFrame(list(zip(X_BKN_train2.columns, regBKN2.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.262939
# 1  Defensive Rebounds          0.351850
# 2      Average Points         -1.043688
# 3          Attendees           0.001894
# 4     Team Efficiency          1.319183

# %%
#set the data to be predicted for third quarter

X_GSW_data3 = df.iloc[2:3, [5,11,18,19,20]]
y_GSW_data3 = df.iloc[2, 24:25]

X_SAS_data3 = df.iloc[6:7, [5,11,18,19,20]]
y_SAS_data3 = df.iloc[6, 24:25]

X_HOU_data3 = df.iloc[10:11, [5,11,18,19,20]]
y_HOU_data3 = df.iloc[10, 24:25]

X_LAC_data3 = df.iloc[14:15, [5,11,18,19,20]]
y_LAC_data3 = df.iloc[14, 24:25]

X_UTAH_data3 = df.iloc[18:19, [5,11,18,19,20]]
y_UTAH_data3 = df.iloc[18, 24:25]

X_OKC_data3 = df.iloc[22:23, [5,11,18,19,20]]
y_OKC_data3 = df.iloc[22, 24:25]

X_MEM_data3 = df.iloc[26:27, [5,11,18,19,20]]
y_MEM_data3 = df.iloc[26, 24:25]

X_POR_data3 = df.iloc[30:31, [5,11,18,19,20]]
y_POR_data3 = df.iloc[30, 24:25]

X_DEN_data3 = df.iloc[34:35, [5,11,18,19,20]]
y_DEN_data3 = df.iloc[34, 24:25]

X_NOP_data3 = df.iloc[38:39, [5,11,18,19,20]]
y_NOP_data3 = df.iloc[38, 24:25]

X_DAL_data3 = df.iloc[42:43, [5,11,18,19,20]]
y_DAL_data3 = df.iloc[42, 24:25]

X_SAC_data3 = df.iloc[46:47, [5,11,18,19,20]]
y_SAC_data3 = df.iloc[46, 24:25]

X_MIN_data3 = df.iloc[50:51, [5,11,18,19,20]]
y_MIN_data3 = df.iloc[50, 24:25]

X_LAL_data3 = df.iloc[54:55, [5,11,18,19,20]]
y_LAL_data3 = df.iloc[54, 24:25]

X_PHO_data3 = df.iloc[58:59, [5,11,18,19,20]]
y_PHO_data3 = df.iloc[58, 24:25]

X_BOS_data3 = df.iloc[62:63, [5,11,18,19,20]]
y_BOS_data3 = df.iloc[62, 24:25]

X_CLE_data3 = df.iloc[66:67, [5,11,18,19,20]]
y_CLE_data3 = df.iloc[66, 24:25]

X_TOR_data3 = df.iloc[70:71, [5,11,18,19,20]]
y_TOR_data3 = df.iloc[70, 24:25]

X_WAS_data3 = df.iloc[74:75, [5,11,18,19,20]]
y_WAS_data3 = df.iloc[74, 24:25]

X_ATL_data3 = df.iloc[78:79, [5,11,18,19,20]]
y_ATL_data3 = df.iloc[78, 24:25]

X_MIL_data3 = df.iloc[82:83, [5,11,18,19,20]]
y_MIL_data3 = df.iloc[82, 24:25]

X_IND_data3 = df.iloc[86:87, [5,11,18,19,20]]
y_IND_data3 = df.iloc[86, 24:25]

X_CHI_data3 = df.iloc[90:91, [5,11,18,19,20]]
y_CHI_data3 = df.iloc[90, 24:25]

X_MIA_data3 = df.iloc[94:95, [5,11,18,19,20]]
y_MIA_data3 = df.iloc[94, 24:25]

X_DET_data3 = df.iloc[98:99, [5,11,18,19,20]]
y_DET_data3 = df.iloc[98, 24:25]

X_CHA_data3 = df.iloc[102:103, [5,11,18,19,20]]
y_CHA_data3 = df.iloc[102, 24:25]

X_NYK_data3 = df.iloc[106:107, [5,11,18,19,20]]
y_NYK_data3 = df.iloc[106, 24:25]

X_ORL_data3 = df.iloc[110:111, [5,11,18,19,20]]
y_ORL_data3 = df.iloc[110, 24:25]

X_PHI_data3 = df.iloc[114:115, [5,11,18,19,20]]
y_PHI_data3 = df.iloc[114, 24:25]

X_BKN_data3 = df.iloc[118:119, [5,11,18,19,20]]
y_BKN_data3 = df.iloc[118, 24:25]

# %%
#set training data for third quarter of the season

X_GSW_train3 = df.iloc[[6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], [5,11,18,19,20]]
y_GSW_train3 = df.iloc[[6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], 24:25]

X_SAS_train3 = df.iloc[[2,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], [5,11,18,19,20]]
y_SAS_train3 = df.iloc[[2,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], 24:25]

X_HOU_train3 = df.iloc[[2,6,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], [5,11,18,19,20]]
y_HOU_train3 = df.iloc[[2,6,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], 24:25]

X_LAC_train3 = df.iloc[[2,6,10,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], [5,11,18,19,20]]
y_LAC_train3 = df.iloc[[2,6,10,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], 24:25]

X_UTAH_train3 = df.iloc[[2,6,10,14,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], [5,11,18,19,20]]
y_UTAH_train3 = df.iloc[[2,6,10,14,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], 24:25]

X_OKC_train3 = df.iloc[[2,6,10,14,18,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], [5,11,18,19,20]]
y_OKC_train3 = df.iloc[[2,6,10,14,18,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], 24:25]

X_MEM_train3 = df.iloc[[2,6,10,14,18,22,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], [5,11,18,19,20]]
y_MEM_train3 = df.iloc[[2,6,10,14,18,22,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], 24:25]

X_POR_train3 = df.iloc[[2,6,10,14,18,22,26,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], [5,11,18,19,20]]
y_POR_train3 = df.iloc[[2,6,10,14,18,22,26,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], 24:25]

X_DEN_train3 = df.iloc[[2,6,10,14,18,22,26,30,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], [5,11,18,19,20]]
y_DEN_train3 = df.iloc[[2,6,10,14,18,22,26,30,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], 24:25]

X_NOP_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], [5,11,18,19,20]]
y_NOP_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], 24:25]

X_DAL_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], [5,11,18,19,20]]
y_DAL_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], 24:25]

X_SAC_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], [5,11,18,19,20]]
y_SAC_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], 24:25]

X_MIN_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], [5,11,18,19,20]]
y_MIN_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], 24:25]

X_LAL_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], [5,11,18,19,20]]
y_LAL_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], 24:25]

X_PHO_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], [5,11,18,19,20]]
y_PHO_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,62,66,70,74,78,82,86,90,94,98,102,106,110,114,118], 24:25]

X_BOS_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,66,70,74,78,82,86,90,94,98,102,106,110,114,118], [5,11,18,19,20]]
y_BOS_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,66,70,74,78,82,86,90,94,98,102,106,110,114,118], 24:25]

X_CLE_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,70,74,78,82,86,90,94,98,102,106,110,114,118], [5,11,18,19,20]]
y_CLE_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,70,74,78,82,86,90,94,98,102,106,110,114,118], 24:25]

X_TOR_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,74,78,82,86,90,94,98,102,106,110,114,118], [5,11,18,19,20]]
y_TOR_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,74,78,82,86,90,94,98,102,106,110,114,118], 24:25]

X_WAS_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,78,82,86,90,94,98,102,106,110,114,118], [5,11,18,19,20]]
y_WAS_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,78,82,86,90,94,98,102,106,110,114,118], 24:25]

X_ATL_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,82,86,90,94,98,102,106,110,114,118], [5,11,18,19,20]]
y_ATL_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,82,86,90,94,98,102,106,110,114,118], 24:25]

X_MIL_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,86,90,94,98,102,106,110,114,118], [5,11,18,19,20]]
y_MIL_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,86,90,94,98,102,106,110,114,118], 24:25]

X_IND_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,90,94,98,102,106,110,114,118], [5,11,18,19,20]]
y_IND_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,90,94,98,102,106,110,114,118], 24:25]

X_CHI_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,94,98,102,106,110,114,118], [5,11,18,19,20]]
y_CHI_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,94,98,102,106,110,114,118], 24:25]

X_MIA_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,98,102,106,110,114,118], [5,11,18,19,20]]
y_MIA_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,98,102,106,110,114,118], 24:25]

X_DET_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,102,106,110,114,118], [5,11,18,19,20]]
y_DET_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,102,106,110,114,118], 24:25]

X_CHA_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,106,110,114,118], [5,11,18,19,20]]
y_CHA_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,106,110,114,118], 24:25]

X_NYK_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,110,114,118], [5,11,18,19,20]]
y_NYK_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,110,114,118], 24:25]

X_ORL_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,114,118], [5,11,18,19,20]]
y_ORL_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,114,118], 24:25]

X_PHI_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,118], [5,11,18,19,20]]
y_PHI_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,118], 24:25]

X_BKN_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114], [5,11,18,19,20]]
y_BKN_train3 = df.iloc[[2,6,10,14,18,22,26,30,34,38,42,46,50,54,58,62,66,70,74,78,82,86,90,94,98,102,106,110,114], 24:25]

# %%
#implement linear regression models

regGSW3 = LinearRegression()
regGSW3.fit(X_GSW_train3, y_GSW_train3)

regSAS3 = LinearRegression()
regSAS3.fit(X_SAS_train3, y_SAS_train3)

regHOU3 = LinearRegression()
regHOU3.fit(X_HOU_train3, y_HOU_train3)

regLAC3 = LinearRegression()
regLAC3.fit(X_LAC_train3, y_LAC_train3)

regUTAH3 = LinearRegression()
regUTAH3.fit(X_UTAH_train3, y_UTAH_train3)

regOKC3 = LinearRegression()
regOKC3.fit(X_OKC_train3, y_OKC_train3)

regMEM3 = LinearRegression()
regMEM3.fit(X_MEM_train3, y_MEM_train3)

regPOR3 = LinearRegression()
regPOR3.fit(X_POR_train3, y_POR_train3)

regDEN3 = LinearRegression()
regDEN3.fit(X_DEN_train3, y_DEN_train3)

regNOP3 = LinearRegression()
regNOP3.fit(X_NOP_train3, y_NOP_train3)

regDAL3 = LinearRegression()
regDAL3.fit(X_DAL_train3, y_DAL_train3)

regSAC3 = LinearRegression()
regSAC3.fit(X_SAC_train3, y_SAC_train3)

regMIN3 = LinearRegression()
regMIN3.fit(X_MIN_train3, y_MIN_train3)

regLAL3 = LinearRegression()
regLAL3.fit(X_LAL_train3, y_LAL_train3)

regPHO3 = LinearRegression()
regPHO3.fit(X_PHO_train3, y_PHO_train3)

regBOS3 = LinearRegression()
regBOS3.fit(X_BOS_train3, y_BOS_train3)

regCLE3 = LinearRegression()
regCLE3.fit(X_CLE_train3, y_CLE_train3)

regTOR3 = LinearRegression()
regTOR3.fit(X_TOR_train3, y_TOR_train3)

regWAS3 = LinearRegression()
regWAS3.fit(X_WAS_train3, y_WAS_train3)

regATL3 = LinearRegression()
regATL3.fit(X_ATL_train3, y_ATL_train3)

regMIL3 = LinearRegression()
regMIL3.fit(X_MIL_train3, y_MIL_train3)

regIND3 = LinearRegression()
regIND3.fit(X_IND_train3, y_IND_train3)

regCHI3 = LinearRegression()
regCHI3.fit(X_CHI_train3, y_CHI_train3)

regMIA3 = LinearRegression()
regMIA3.fit(X_MIA_train3, y_MIA_train3)

regDET3 = LinearRegression()
regDET3.fit(X_DET_train3, y_DET_train3)

regCHA3 = LinearRegression()
regCHA3.fit(X_CHA_train3, y_CHA_train3)

regNYK3 = LinearRegression()
regNYK3.fit(X_NYK_train3, y_NYK_train3)

regORL3 = LinearRegression()
regORL3.fit(X_ORL_train3, y_ORL_train3)

regPHI3 = LinearRegression()
regPHI3.fit(X_PHI_train3, y_PHI_train3)

regBKN3 = LinearRegression()
regBKN3.fit(X_BKN_train3, y_BKN_train3)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#predict for the third quarter of the season

y_pred_GSW3 = regGSW3.predict(X_GSW_data3)

y_pred_SAS3 = regSAS3.predict(X_SAS_data3)

y_pred_HOU3 = regHOU3.predict(X_HOU_data3)

y_pred_LAC3 = regLAC3.predict(X_LAC_data3)

y_pred_UTAH3 = regUTAH3.predict(X_UTAH_data3)

y_pred_OKC3 = regOKC3.predict(X_OKC_data3)

y_pred_MEM3 = regMEM3.predict(X_MEM_data3)

y_pred_POR3 = regPOR3.predict(X_POR_data3)

y_pred_DEN3 = regDEN3.predict(X_DEN_data3)

y_pred_NOP3 = regNOP3.predict(X_NOP_data3)

y_pred_DAL3 = regDAL3.predict(X_DAL_data3)

y_pred_SAC3 = regSAC3.predict(X_SAC_data3)

y_pred_MIN3 = regMIN3.predict(X_MIN_data3)

y_pred_LAL3 = regLAL3.predict(X_LAL_data3)

y_pred_PHO3 = regPHO3.predict(X_PHO_data3)

y_pred_BOS3 = regBOS3.predict(X_BOS_data3)

y_pred_CLE3 = regCLE3.predict(X_CLE_data3)

y_pred_TOR3 = regTOR3.predict(X_TOR_data3)

y_pred_WAS3 = regWAS3.predict(X_WAS_data3)

y_pred_ATL3 = regATL3.predict(X_ATL_data3)

y_pred_MIL3 = regMIL3.predict(X_MIL_data3)

y_pred_IND3 = regIND3.predict(X_IND_data3)

y_pred_CHI3 = regCHI3.predict(X_CHI_data3)

y_pred_MIA3 = regMIA3.predict(X_MIA_data3)

y_pred_DET3 = regDET3.predict(X_DET_data3)

y_pred_CHA3 = regCHA3.predict(X_CHA_data3)

y_pred_NYK3 = regNYK3.predict(X_NYK_data3)

y_pred_ORL3 = regORL3.predict(X_ORL_data3)

y_pred_PHI3 = regPHI3.predict(X_PHI_data3)

y_pred_BKN3 = regBKN3.predict(X_BKN_data3)

# %%
#put the differences for the third quarter here

diff_GSW3 = y_GSW_data3[0] - y_pred_GSW3.item(0)

diff_SAS3 = y_SAS_data3[0] - y_pred_SAS3.item(0)

diff_HOU3 = y_HOU_data3[0] - y_pred_HOU3.item(0)

diff_LAC3 = y_LAC_data3[0] - y_pred_LAC3.item(0)

diff_UTAH3 = y_UTAH_data3[0] - y_pred_UTAH3.item(0)

diff_OKC3 = y_OKC_data3[0] - y_pred_OKC3.item(0)

diff_MEM3 = y_MEM_data3[0] - y_pred_MEM3.item(0)

diff_POR3 = y_POR_data3[0] - y_pred_POR3.item(0)

diff_DEN3 = y_DEN_data3[0] - y_pred_DEN3.item(0)

diff_NOP3 = y_NOP_data3[0] - y_pred_NOP3.item(0)

diff_DAL3 = y_DAL_data3[0] - y_pred_DAL3.item(0)

diff_SAC3 = y_SAC_data3[0] - y_pred_SAC3.item(0)

diff_MIN3 = y_MIN_data3[0] - y_pred_MIN3.item(0)

diff_LAL3 = y_LAL_data3[0] - y_pred_LAL3.item(0)

diff_PHO3 = y_PHO_data3[0] - y_pred_PHO3.item(0)

diff_BOS3 = y_BOS_data3[0] - y_pred_BOS3.item(0)

diff_CLE3 = y_CLE_data3[0] - y_pred_CLE3.item(0)

diff_TOR3 = y_TOR_data3[0] - y_pred_TOR3.item(0)

diff_WAS3 = y_WAS_data3[0] - y_pred_WAS3.item(0)

diff_ATL3 = y_ATL_data3[0] - y_pred_ATL3.item(0)

diff_MIL3 = y_MIL_data3[0] - y_pred_MIL3.item(0)

diff_IND3 = y_IND_data3[0] - y_pred_IND3.item(0)

diff_CHI3 = y_CHI_data3[0] - y_pred_CHI3.item(0)

diff_MIA3 = y_MIA_data3[0] - y_pred_MIA3.item(0)

diff_DET3 = y_DET_data3[0] - y_pred_DET3.item(0)

diff_CHA3 = y_CHA_data3[0] - y_pred_CHA3.item(0)

diff_NYK3 = y_NYK_data3[0] - y_pred_NYK3.item(0)

diff_ORL3 = y_ORL_data3[0] - y_pred_ORL3.item(0)

diff_PHI3 = y_PHI_data3[0] - y_pred_PHI3.item(0)

diff_BKN3 = y_BKN_data3[0] - y_pred_BKN3.item(0)

# %%
#get percent error for third quarter

err_GSW3 = round(abs(diff_GSW3 / y_GSW_data3[0]) * 100, 2)

err_SAS3 = round(abs(diff_SAS3 / y_SAS_data3[0]) * 100, 2)

err_HOU3 = round(abs(diff_HOU3 / y_HOU_data3[0]) * 100, 2)

err_LAC3 = round(abs(diff_LAC3 / y_LAC_data3[0]) * 100, 2)

err_UTAH3 = round(abs(diff_UTAH3 / y_UTAH_data3[0]) * 100, 2)

err_OKC3 = round(abs(diff_OKC3 / y_OKC_data3[0]) * 100, 2)

err_MEM3 = round(abs(diff_MEM3 / y_MEM_data3[0]) * 100, 2)

err_POR3 = round(abs(diff_POR3 / y_POR_data3[0]) * 100, 2)

err_DEN3 = round(abs(diff_DEN3 / y_DEN_data3[0]) * 100, 2)

err_NOP3 = round(abs(diff_NOP3 / y_NOP_data3[0]) * 100, 2)

err_DAL3 = round(abs(diff_DAL3 / y_DAL_data3[0]) * 100, 2)

err_SAC3 = round(abs(diff_SAC3 / y_SAC_data3[0]) * 100, 2)

err_MIN3 = round(abs(diff_MIN3 / y_MIN_data3[0]) * 100, 2)

err_LAL3 = round(abs(diff_LAL3 / y_LAL_data3[0]) * 100, 2)

err_PHO3 = round(abs(diff_PHO3 / y_PHO_data3[0]) * 100, 2)

err_BOS3 = round(abs(diff_BOS3 / y_BOS_data3[0]) * 100, 2)

err_CLE3 = round(abs(diff_CLE3 / y_CLE_data3[0]) * 100, 2)

err_TOR3 = round(abs(diff_TOR3 / y_TOR_data3[0]) * 100, 2)

err_WAS3 = round(abs(diff_WAS3 / y_WAS_data3[0]) * 100, 2)

err_ATL3 = round(abs(diff_ATL3 / y_ATL_data3[0]) * 100, 2)

err_MIL3 = round(abs(diff_MIL3 / y_MIL_data3[0]) * 100, 2)

err_IND3 = round(abs(diff_IND3 / y_IND_data3[0]) * 100, 2)

err_CHI3 = round(abs(diff_CHI3 / y_CHI_data3[0]) * 100, 2)

err_MIA3 = round(abs(diff_MIA3 / y_MIA_data3[0]) * 100, 2)

err_DET3 = round(abs(diff_DET3 / y_DET_data3[0]) * 100, 2)

err_CHA3 = round(abs(diff_CHA3 / y_CHA_data3[0]) * 100, 2)

err_NYK3 = round(abs(diff_NYK3 / y_NYK_data3[0]) * 100, 2)

err_ORL3 = round(abs(diff_ORL3 / y_ORL_data3[0]) * 100, 2)

err_PHI3 = round(abs(diff_PHI3 / y_PHI_data3[0]) * 100, 2)

err_BKN3 = round(abs(diff_BKN3 / y_BKN_data3[0]) * 100, 2)

# %%
pd.DataFrame(list(zip(X_GSW_train3.columns, regGSW3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.090703
# 1  Defensive Rebounds          0.381295
# 2      Average Points          0.590008
# 3          Attendees           0.001286
# 4     Team Efficiency         -0.426488

# %%
pd.DataFrame(list(zip(X_SAS_train3.columns, regSAS3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.120499
# 1  Defensive Rebounds         -0.399738
# 2      Average Points          1.414303
# 3          Attendees           0.002157
# 4     Team Efficiency         -0.623677

# %%
pd.DataFrame(list(zip(X_HOU_train3.columns, regHOU3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.202033
# 1  Defensive Rebounds         -0.052508
# 2      Average Points          0.712348
# 3          Attendees           0.002048
# 4     Team Efficiency         -0.166706

# %%
pd.DataFrame(list(zip(X_LAC_train3.columns, regLAC3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.155685
# 1  Defensive Rebounds         -0.080022
# 2      Average Points          0.703853
# 3          Attendees           0.002111
# 4     Team Efficiency         -0.188917

# %%
pd.DataFrame(list(zip(X_UTAH_train3.columns, regUTAH3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.146479
# 1  Defensive Rebounds         -0.374865
# 2      Average Points          0.959415
# 3          Attendees           0.002272
# 4     Team Efficiency         -0.332010

# %%
pd.DataFrame(list(zip(X_OKC_train3.columns, regOKC3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.129877
# 1  Defensive Rebounds         -0.014529
# 2      Average Points          0.748663
# 3          Attendees           0.002038
# 4     Team Efficiency         -0.209447

# %%
pd.DataFrame(list(zip(X_MEM_train3.columns, regMEM3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.302403
# 1  Defensive Rebounds          0.287521
# 2      Average Points          0.392814
# 3          Attendees           0.002302
# 4     Team Efficiency          0.133773

# %%
pd.DataFrame(list(zip(X_POR_train3.columns, regPOR3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.137573
# 1  Defensive Rebounds         -0.053227
# 2      Average Points          0.722341
# 3          Attendees           0.002046
# 4     Team Efficiency         -0.188140

# %%
pd.DataFrame(list(zip(X_DEN_train3.columns, regDEN3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.177242
# 1  Defensive Rebounds         -0.282484
# 2      Average Points          0.769881
# 3          Attendees           0.001862
# 4     Team Efficiency         -0.156374

# %%
pd.DataFrame(list(zip(X_NOP_train3.columns, regNOP3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.044091
# 1  Defensive Rebounds          0.377979
# 2      Average Points          1.067546
# 3          Attendees           0.001517
# 4     Team Efficiency         -0.339300

# %%
pd.DataFrame(list(zip(X_DAL_train3.columns, regDAL3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.239365
# 1  Defensive Rebounds         -0.063059
# 2      Average Points          0.560995
# 3          Attendees           0.002175
# 4     Team Efficiency         -0.121870

# %%
pd.DataFrame(list(zip(X_SAC_train3.columns, regSAC3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.102168
# 1  Defensive Rebounds         -0.155429
# 2      Average Points          0.779956
# 3          Attendees           0.002089
# 4     Team Efficiency         -0.242230

# %%
pd.DataFrame(list(zip(X_MIN_train3.columns, regMIN3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.059895
# 1  Defensive Rebounds         -0.411845
# 2      Average Points          0.962933
# 3          Attendees           0.002115
# 4     Team Efficiency         -0.242941

# %%
pd.DataFrame(list(zip(X_LAL_train3.columns, regLAL3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.045209
# 1  Defensive Rebounds          0.095645
# 2      Average Points          1.321882
# 3          Attendees           0.002376
# 4     Team Efficiency         -0.573766

# %%
pd.DataFrame(list(zip(X_PHO_train3.columns, regPHO3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.125955
# 1  Defensive Rebounds         -0.135146
# 2      Average Points          0.845637
# 3          Attendees           0.002043
# 4     Team Efficiency         -0.295103

# %%
pd.DataFrame(list(zip(X_BOS_train3.columns, regBOS3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.133146
# 1  Defensive Rebounds         -0.012143
# 2      Average Points          0.719117
# 3          Attendees           0.001976
# 4     Team Efficiency         -0.176653

# %%
pd.DataFrame(list(zip(X_CLE_train3.columns, regCLE3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.149404
# 1  Defensive Rebounds          0.189808
# 2      Average Points         -0.023650
# 3          Attendees           0.000916
# 4     Team Efficiency          0.326816

# %%
pd.DataFrame(list(zip(X_TOR_train3.columns, regTOR3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.161392
# 1  Defensive Rebounds         -0.011057
# 2      Average Points          0.726744
# 3          Attendees           0.002090
# 4     Team Efficiency         -0.182175

# %%
pd.DataFrame(list(zip(X_WAS_train3.columns, regWAS3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.136373
# 1  Defensive Rebounds          0.060168
# 2      Average Points          0.750839
# 3          Attendees           0.002058
# 4     Team Efficiency         -0.228249

# %%
pd.DataFrame(list(zip(X_ATL_train3.columns, regATL3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.010322
# 1  Defensive Rebounds         -0.019431
# 2      Average Points          0.873101
# 3          Attendees           0.003100
# 4     Team Efficiency         -0.261533

# %%
pd.DataFrame(list(zip(X_MIL_train3.columns, regMIL3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.181283
# 1  Defensive Rebounds         -0.032872
# 2      Average Points          0.840235
# 3          Attendees           0.002035
# 4     Team Efficiency         -0.239771

# %%
pd.DataFrame(list(zip(X_IND_train3.columns, regIND3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.199230
# 1  Defensive Rebounds         -0.156921
# 2      Average Points          0.858081
# 3          Attendees           0.002254
# 4     Team Efficiency         -0.277174

# %%
pd.DataFrame(list(zip(X_CHI_train3.columns, regCHI3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.131097
# 1  Defensive Rebounds         -0.018027
# 2      Average Points          0.765818
# 3          Attendees           0.002086
# 4     Team Efficiency         -0.223731

# %%
pd.DataFrame(list(zip(X_MIA_train3.columns, regMIA3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.178040
# 1  Defensive Rebounds          0.289139
# 2      Average Points          0.344929
# 3          Attendees           0.002320
# 4     Team Efficiency         -0.006661

# %%
pd.DataFrame(list(zip(X_DET_train3.columns, regDET3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.142721
# 1  Defensive Rebounds          0.119906
# 2      Average Points          0.636532
# 3          Attendees           0.001945
# 4     Team Efficiency         -0.147173

# %%
pd.DataFrame(list(zip(X_CHA_train3.columns, regCHA3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.163792
# 1  Defensive Rebounds          0.011563
# 2      Average Points          0.697962
# 3          Attendees           0.001697
# 4     Team Efficiency         -0.132444

# %%
pd.DataFrame(list(zip(X_NYK_train3.columns, regNYK3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.021407
# 1  Defensive Rebounds         -0.212279
# 2      Average Points          1.039984
# 3          Attendees           0.002376
# 4     Team Efficiency         -0.438810

# %%
pd.DataFrame(list(zip(X_ORL_train3.columns, regORL3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.172326
# 1  Defensive Rebounds         -0.401300
# 2      Average Points          0.703414
# 3          Attendees           0.002216
# 4     Team Efficiency         -0.151020

# %%
pd.DataFrame(list(zip(X_PHI_train3.columns, regPHI3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.166494
# 1  Defensive Rebounds          0.273477
# 2      Average Points          0.363063
# 3          Attendees           0.002239
# 4     Team Efficiency          0.028647

# %%
pd.DataFrame(list(zip(X_BKN_train3.columns, regBKN3.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.210362
# 1  Defensive Rebounds         -0.007062
# 2      Average Points          0.717891
# 3          Attendees           0.001856
# 4     Team Efficiency         -0.200759

# %%
#set the data to be predicted for fourth quarter

X_GSW_data4 = df.iloc[3:4, [5,11,18,19,20]]
y_GSW_data4 = df.iloc[3, 24:25]

X_SAS_data4 = df.iloc[7:8, [5,11,18,19,20]]
y_SAS_data4 = df.iloc[7, 24:25]

X_HOU_data4 = df.iloc[11:12, [5,11,18,19,20]]
y_HOU_data4 = df.iloc[11, 24:25]

X_LAC_data4 = df.iloc[15:16, [5,11,18,19,20]]
y_LAC_data4 = df.iloc[15, 24:25]

X_UTAH_data4 = df.iloc[19:20, [5,11,18,19,20]]
y_UTAH_data4 = df.iloc[19, 24:25]

X_OKC_data4 = df.iloc[23:24, [5,11,18,19,20]]
y_OKC_data4 = df.iloc[23, 24:25]

X_MEM_data4 = df.iloc[27:28, [5,11,18,19,20]]
y_MEM_data4 = df.iloc[27, 24:25]

X_POR_data4 = df.iloc[31:32, [5,11,18,19,20]]
y_POR_data4 = df.iloc[31, 24:25]

X_DEN_data4 = df.iloc[35:36, [5,11,18,19,20]]
y_DEN_data4 = df.iloc[35, 24:25]

X_NOP_data4 = df.iloc[39:40, [5,11,18,19,20]]
y_NOP_data4 = df.iloc[39, 24:25]

X_DAL_data4 = df.iloc[43:44, [5,11,18,19,20]]
y_DAL_data4 = df.iloc[43, 24:25]

X_SAC_data4 = df.iloc[47:48, [5,11,18,19,20]]
y_SAC_data4 = df.iloc[47, 24:25]

X_MIN_data4 = df.iloc[51:52, [5,11,18,19,20]]
y_MIN_data4 = df.iloc[51, 24:25]

X_LAL_data4 = df.iloc[55:56, [5,11,18,19,20]]
y_LAL_data4 = df.iloc[55, 24:25]

X_PHO_data4 = df.iloc[59:60, [5,11,18,19,20]]
y_PHO_data4 = df.iloc[59, 24:25]

X_BOS_data4 = df.iloc[63:64, [5,11,18,19,20]]
y_BOS_data4 = df.iloc[63, 24:25]

X_CLE_data4 = df.iloc[67:68, [5,11,18,19,20]]
y_CLE_data4 = df.iloc[67, 24:25]

X_TOR_data4 = df.iloc[71:72, [5,11,18,19,20]]
y_TOR_data4 = df.iloc[71, 24:25]

X_WAS_data4 = df.iloc[75:76, [5,11,18,19,20]]
y_WAS_data4 = df.iloc[75, 24:25]

X_ATL_data4 = df.iloc[79:80, [5,11,18,19,20]]
y_ATL_data4 = df.iloc[79, 24:25]

X_MIL_data4 = df.iloc[83:84, [5,11,18,19,20]]
y_MIL_data4 = df.iloc[83, 24:25]

X_IND_data4 = df.iloc[87:88, [5,11,18,19,20]]
y_IND_data4 = df.iloc[87, 24:25]

X_CHI_data4 = df.iloc[91:92, [5,11,18,19,20]]
y_CHI_data4 = df.iloc[91, 24:25]

X_MIA_data4 = df.iloc[95:96, [5,11,18,19,20]]
y_MIA_data4 = df.iloc[95, 24:25]

X_DET_data4 = df.iloc[99:100, [5,11,18,19,20]]
y_DET_data4 = df.iloc[99, 24:25]

X_CHA_data4 = df.iloc[103:104, [5,11,18,19,20]]
y_CHA_data4 = df.iloc[103, 24:25]

X_NYK_data4 = df.iloc[107:108, [5,11,18,19,20]]
y_NYK_data4 = df.iloc[107, 24:25]

X_ORL_data4 = df.iloc[111:112, [5,11,18,19,20]]
y_ORL_data4 = df.iloc[111, 24:25]

X_PHI_data4 = df.iloc[115:116, [5,11,18,19,20]]
y_PHI_data4 = df.iloc[115, 24:25]

X_BKN_data4 = df.iloc[119:120, [5,11,18,19,20]]
y_BKN_data4 = df.iloc[119, 24:25]

# %%
#set training data for fourth quarter of the season

X_GSW_train4 = df.iloc[[7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], [5,11,18,19,20]]
y_GSW_train4 = df.iloc[[7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], 24:25]

X_SAS_train4 = df.iloc[[3,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], [5,11,18,19,20]]
y_SAS_train4 = df.iloc[[3,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], 24:25]

X_HOU_train4 = df.iloc[[3,7,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], [5,11,18,19,20]]
y_HOU_train4 = df.iloc[[3,7,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], 24:25]

X_LAC_train4 = df.iloc[[3,7,11,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], [5,11,18,19,20]]
y_LAC_train4 = df.iloc[[3,7,11,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], 24:25]

X_UTAH_train4 = df.iloc[[3,7,11,15,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], [5,11,18,19,20]]
y_UTAH_train4 = df.iloc[[3,7,11,15,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], 24:25]

X_OKC_train4 = df.iloc[[3,7,11,15,19,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], [5,11,18,19,20]]
y_OKC_train4 = df.iloc[[3,7,11,15,19,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], 24:25]

X_MEM_train4 = df.iloc[[3,7,11,15,19,23,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], [5,11,18,19,20]]
y_MEM_train4 = df.iloc[[3,7,11,15,19,23,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], 24:25]

X_POR_train4 = df.iloc[[3,7,11,15,19,23,27,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], [5,11,18,19,20]]
y_POR_train4 = df.iloc[[3,7,11,15,19,23,27,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], 24:25]

X_DEN_train4 = df.iloc[[3,7,11,15,19,23,27,31,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], [5,11,18,19,20]]
y_DEN_train4 = df.iloc[[3,7,11,15,19,23,27,31,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], 24:25]

X_NOP_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], [5,11,18,19,20]]
y_NOP_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], 24:25]

X_DAL_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], [5,11,18,19,20]]
y_DAL_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], 24:25]

X_SAC_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], [5,11,18,19,20]]
y_SAC_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], 24:25]

X_MIN_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], [5,11,18,19,20]]
y_MIN_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], 24:25]

X_LAL_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], [5,11,18,19,20]]
y_LAL_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], 24:25]

X_PHO_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], [5,11,18,19,20]]
y_PHO_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,63,67,71,75,79,83,87,91,95,99,103,107,111,115,119], 24:25]

X_BOS_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,67,71,75,79,83,87,91,95,99,103,107,111,115,119], [5,11,18,19,20]]
y_BOS_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,67,71,75,79,83,87,91,95,99,103,107,111,115,119], 24:25]

X_CLE_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,71,75,79,83,87,91,95,99,103,107,111,115,119], [5,11,18,19,20]]
y_CLE_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,71,75,79,83,87,91,95,99,103,107,111,115,119], 24:25]

X_TOR_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,75,79,83,87,91,95,99,103,107,111,115,119], [5,11,18,19,20]]
y_TOR_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,75,79,83,87,91,95,99,103,107,111,115,119], 24:25]

X_WAS_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,79,83,87,91,95,99,103,107,111,115,119], [5,11,18,19,20]]
y_WAS_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,79,83,87,91,95,99,103,107,111,115,119], 24:25]

X_ATL_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,83,87,91,95,99,103,107,111,115,119], [5,11,18,19,20]]
y_ATL_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,83,87,91,95,99,103,107,111,115,119], 24:25]

X_MIL_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,87,91,95,99,103,107,111,115,119], [5,11,18,19,20]]
y_MIL_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,87,91,95,99,103,107,111,115,119], 24:25]

X_IND_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,91,95,99,103,107,111,115,119], [5,11,18,19,20]]
y_IND_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,91,95,99,103,107,111,115,119], 24:25]

X_CHI_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,95,99,103,107,111,115,119], [5,11,18,19,20]]
y_CHI_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,95,99,103,107,111,115,119], 24:25]

X_MIA_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,99,103,107,111,115,119], [5,11,18,19,20]]
y_MIA_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,99,103,107,111,115,119], 24:25]

X_DET_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,103,107,111,115,119], [5,11,18,19,20]]
y_DET_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,103,107,111,115,119], 24:25]

X_CHA_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,107,111,115,119], [5,11,18,19,20]]
y_CHA_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,107,111,115,119], 24:25]

X_NYK_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,111,115,119], [5,11,18,19,20]]
y_NYK_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,111,115,119], 24:25]

X_ORL_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,115,119], [5,11,18,19,20]]
y_ORL_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,115,119], 24:25]

X_PHI_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,119], [5,11,18,19,20]]
y_PHI_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,119], 24:25]

X_BKN_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115], [5,11,18,19,20]]
y_BKN_train4 = df.iloc[[3,7,11,15,19,23,27,31,35,39,43,47,51,55,59,63,67,71,75,79,83,87,91,95,99,103,107,111,115], 24:25]

# %%
#implement linear regression models

regGSW4 = LinearRegression()
regGSW4.fit(X_GSW_train4, y_GSW_train4)

regSAS4 = LinearRegression()
regSAS4.fit(X_SAS_train4, y_SAS_train4)

regHOU4 = LinearRegression()
regHOU4.fit(X_HOU_train4, y_HOU_train4)

regLAC4 = LinearRegression()
regLAC4.fit(X_LAC_train4, y_LAC_train4)

regUTAH4 = LinearRegression()
regUTAH4.fit(X_UTAH_train4, y_UTAH_train4)

regOKC4 = LinearRegression()
regOKC4.fit(X_OKC_train4, y_OKC_train4)

regMEM4 = LinearRegression()
regMEM4.fit(X_MEM_train4, y_MEM_train4)

regPOR4 = LinearRegression()
regPOR4.fit(X_POR_train4, y_POR_train4)

regDEN4 = LinearRegression()
regDEN4.fit(X_DEN_train4, y_DEN_train4)

regNOP4 = LinearRegression()
regNOP4.fit(X_NOP_train4, y_NOP_train4)

regDAL4 = LinearRegression()
regDAL4.fit(X_DAL_train4, y_DAL_train4)

regSAC4 = LinearRegression()
regSAC4.fit(X_SAC_train4, y_SAC_train4)

regMIN4 = LinearRegression()
regMIN4.fit(X_MIN_train4, y_MIN_train4)

regLAL4 = LinearRegression()
regLAL4.fit(X_LAL_train4, y_LAL_train4)

regPHO4 = LinearRegression()
regPHO4.fit(X_PHO_train4, y_PHO_train4)

regBOS4 = LinearRegression()
regBOS4.fit(X_BOS_train4, y_BOS_train4)

regCLE4 = LinearRegression()
regCLE4.fit(X_CLE_train4, y_CLE_train4)

regTOR4 = LinearRegression()
regTOR4.fit(X_TOR_train4, y_TOR_train4)

regWAS4 = LinearRegression()
regWAS4.fit(X_WAS_train4, y_WAS_train4)

regATL4 = LinearRegression()
regATL4.fit(X_ATL_train4, y_ATL_train4)

regMIL4 = LinearRegression()
regMIL4.fit(X_MIL_train4, y_MIL_train4)

regIND4 = LinearRegression()
regIND4.fit(X_IND_train4, y_IND_train4)

regCHI4 = LinearRegression()
regCHI4.fit(X_CHI_train4, y_CHI_train4)

regMIA4 = LinearRegression()
regMIA4.fit(X_MIA_train4, y_MIA_train4)

regDET4 = LinearRegression()
regDET4.fit(X_DET_train4, y_DET_train4)

regCHA4 = LinearRegression()
regCHA4.fit(X_CHA_train4, y_CHA_train4)

regNYK4 = LinearRegression()
regNYK4.fit(X_NYK_train4, y_NYK_train4)

regORL4 = LinearRegression()
regORL4.fit(X_ORL_train4, y_ORL_train4)

regPHI4 = LinearRegression()
regPHI4.fit(X_PHI_train4, y_PHI_train4)

regBKN4 = LinearRegression()
regBKN4.fit(X_BKN_train4, y_BKN_train4)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#predict for the fourth quarter of the season

y_pred_GSW4 = regGSW4.predict(X_GSW_data4)

y_pred_SAS4 = regSAS4.predict(X_SAS_data4)

y_pred_HOU4 = regHOU4.predict(X_HOU_data4)

y_pred_LAC4 = regLAC4.predict(X_LAC_data4)

y_pred_UTAH4 = regUTAH4.predict(X_UTAH_data4)

y_pred_OKC4 = regOKC4.predict(X_OKC_data4)

y_pred_MEM4 = regMEM4.predict(X_MEM_data4)

y_pred_POR4 = regPOR4.predict(X_POR_data4)

y_pred_DEN4 = regDEN4.predict(X_DEN_data4)

y_pred_NOP4 = regNOP4.predict(X_NOP_data4)

y_pred_DAL4 = regDAL4.predict(X_DAL_data4)

y_pred_SAC4 = regSAC4.predict(X_SAC_data4)

y_pred_MIN4 = regMIN4.predict(X_MIN_data4)

y_pred_LAL4 = regLAL4.predict(X_LAL_data4)

y_pred_PHO4 = regPHO4.predict(X_PHO_data4)

y_pred_BOS4 = regBOS4.predict(X_BOS_data4)

y_pred_CLE4 = regCLE4.predict(X_CLE_data4)

y_pred_TOR4 = regTOR4.predict(X_TOR_data4)

y_pred_WAS4 = regWAS4.predict(X_WAS_data4)

y_pred_ATL4 = regATL4.predict(X_ATL_data4)

y_pred_MIL4 = regMIL4.predict(X_MIL_data4)

y_pred_IND4 = regIND4.predict(X_IND_data4)

y_pred_CHI4 = regCHI4.predict(X_CHI_data4)

y_pred_MIA4 = regMIA4.predict(X_MIA_data4)

y_pred_DET4 = regDET4.predict(X_DET_data4)

y_pred_CHA4 = regCHA4.predict(X_CHA_data4)

y_pred_NYK4 = regNYK4.predict(X_NYK_data4)

y_pred_ORL4 = regORL4.predict(X_ORL_data4)

y_pred_PHI4 = regPHI4.predict(X_PHI_data4)

y_pred_BKN4 = regBKN4.predict(X_BKN_data4)

# %%
#put the differences for the fourth quarter here

diff_GSW4 = y_GSW_data4[0] - y_pred_GSW4.item(0)

diff_SAS4 = y_SAS_data4[0] - y_pred_SAS4.item(0)

diff_HOU4 = y_HOU_data4[0] - y_pred_HOU4.item(0)

diff_LAC4 = y_LAC_data4[0] - y_pred_LAC4.item(0)

diff_UTAH4 = y_UTAH_data4[0] - y_pred_UTAH4.item(0)

diff_OKC4 = y_OKC_data4[0] - y_pred_OKC4.item(0)

diff_MEM4 = y_MEM_data4[0] - y_pred_MEM4.item(0)

diff_POR4 = y_POR_data4[0] - y_pred_POR4.item(0)

diff_DEN4 = y_DEN_data4[0] - y_pred_DEN4.item(0)

diff_NOP4 = y_NOP_data4[0] - y_pred_NOP4.item(0)

diff_DAL4 = y_DAL_data4[0] - y_pred_DAL4.item(0)

diff_SAC4 = y_SAC_data4[0] - y_pred_SAC4.item(0)

diff_MIN4 = y_MIN_data4[0] - y_pred_MIN4.item(0)

diff_LAL4 = y_LAL_data4[0] - y_pred_LAL4.item(0)

diff_PHO4 = y_PHO_data4[0] - y_pred_PHO4.item(0)

diff_BOS4 = y_BOS_data4[0] - y_pred_BOS4.item(0)

diff_CLE4 = y_CLE_data4[0] - y_pred_CLE4.item(0)

diff_TOR4 = y_TOR_data4[0] - y_pred_TOR4.item(0)

diff_WAS4 = y_WAS_data4[0] - y_pred_WAS4.item(0)

diff_ATL4 = y_ATL_data4[0] - y_pred_ATL4.item(0)

diff_MIL4 = y_MIL_data4[0] - y_pred_MIL4.item(0)

diff_IND4 = y_IND_data4[0] - y_pred_IND4.item(0)

diff_CHI4 = y_CHI_data4[0] - y_pred_CHI4.item(0)

diff_MIA4 = y_MIA_data4[0] - y_pred_MIA4.item(0)

diff_DET4 = y_DET_data4[0] - y_pred_DET4.item(0)

diff_CHA4 = y_CHA_data4[0] - y_pred_CHA4.item(0)

diff_NYK4 = y_NYK_data4[0] - y_pred_NYK4.item(0)

diff_ORL4 = y_ORL_data4[0] - y_pred_ORL4.item(0)

diff_PHI4 = y_PHI_data4[0] - y_pred_PHI4.item(0)

diff_BKN4 = y_BKN_data4[0] - y_pred_BKN4.item(0)

# %%
#get percent error for fourth quarter

err_GSW4 = round(abs(diff_GSW4 / y_GSW_data4[0]) * 100, 2)

err_SAS4 = round(abs(diff_SAS4 / y_SAS_data4[0]) * 100, 2)

err_HOU4 = round(abs(diff_HOU4 / y_HOU_data4[0]) * 100, 2)

err_LAC4 = round(abs(diff_LAC4 / y_LAC_data4[0]) * 100, 2)

err_UTAH4 = round(abs(diff_UTAH4 / y_UTAH_data4[0]) * 100, 2)

err_OKC4 = round(abs(diff_OKC4 / y_OKC_data4[0]) * 100, 2)

err_MEM4 = round(abs(diff_MEM4 / y_MEM_data4[0]) * 100, 2)

err_POR4 = round(abs(diff_POR4 / y_POR_data4[0]) * 100, 2)

err_DEN4 = round(abs(diff_DEN4 / y_DEN_data4[0]) * 100, 2)

err_NOP4 = round(abs(diff_NOP4 / y_NOP_data4[0]) * 100, 2)

err_DAL4 = round(abs(diff_DAL4 / y_DAL_data4[0]) * 100, 2)

err_SAC4 = round(abs(diff_SAC4 / y_SAC_data4[0]) * 100, 2)

err_MIN4 = round(abs(diff_MIN4 / y_MIN_data4[0]) * 100, 2)

err_LAL4 = round(abs(diff_LAL4 / y_LAL_data4[0]) * 100, 2)

err_PHO4 = round(abs(diff_PHO4 / y_PHO_data4[0]) * 100, 2)

err_BOS4 = round(abs(diff_BOS4 / y_BOS_data4[0]) * 100, 2)

err_CLE4 = round(abs(diff_CLE4 / y_CLE_data4[0]) * 100, 2)

err_TOR4 = round(abs(diff_TOR4 / y_TOR_data4[0]) * 100, 2)

err_WAS4 = round(abs(diff_WAS4 / y_WAS_data4[0]) * 100, 2)

err_ATL4 = round(abs(diff_ATL4 / y_ATL_data4[0]) * 100, 2)

err_MIL4 = round(abs(diff_MIL4 / y_MIL_data4[0]) * 100, 2)

err_IND4 = round(abs(diff_IND4 / y_IND_data4[0]) * 100, 2)

err_CHI4 = round(abs(diff_CHI4 / y_CHI_data4[0]) * 100, 2)

err_MIA4 = round(abs(diff_MIA4 / y_MIA_data4[0]) * 100, 2)

err_DET4 = round(abs(diff_DET4 / y_DET_data4[0]) * 100, 2)

err_CHA4 = round(abs(diff_CHA4 / y_CHA_data4[0]) * 100, 2)

err_NYK4 = round(abs(diff_NYK4 / y_NYK_data4[0]) * 100, 2)

err_ORL4 = round(abs(diff_ORL4 / y_ORL_data4[0]) * 100, 2)

err_PHI4 = round(abs(diff_PHI4 / y_PHI_data4[0]) * 100, 2)

err_BKN4 = round(abs(diff_BKN4 / y_BKN_data4[0]) * 100, 2)

# %%
pd.DataFrame(list(zip(X_GSW_train4.columns, regGSW4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.132818
# 1  Defensive Rebounds         -1.426021
# 2      Average Points          0.100711
# 3          Attendees           0.002404
# 4     Team Efficiency          0.062344

# %%
pd.DataFrame(list(zip(X_SAS_train4.columns, regSAS4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.048252
# 1  Defensive Rebounds         -1.566425
# 2      Average Points         -0.539160
# 3          Attendees           0.003368
# 4     Team Efficiency          0.511427

# %%
pd.DataFrame(list(zip(X_HOU_train4.columns, regHOU4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.088068
# 1  Defensive Rebounds         -1.464834
# 2      Average Points         -0.460621
# 3          Attendees           0.003517
# 4     Team Efficiency          0.449395

# %%
pd.DataFrame(list(zip(X_LAC_train4.columns, regLAC4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.140693
# 1  Defensive Rebounds         -1.548616
# 2      Average Points         -0.678184
# 3          Attendees           0.003401
# 4     Team Efficiency          0.596758

# %%
pd.DataFrame(list(zip(X_UTAH_train4.columns, regUTAH4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.038149
# 1  Defensive Rebounds         -1.733762
# 2      Average Points         -0.306236
# 3          Attendees           0.003448
# 4     Team Efficiency          0.335654

# %%
pd.DataFrame(list(zip(X_OKC_train4.columns, regOKC4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.049944
# 1  Defensive Rebounds         -1.533566
# 2      Average Points         -0.545876
# 3          Attendees           0.003363
# 4     Team Efficiency          0.507432

# %%
pd.DataFrame(list(zip(X_MEM_train4.columns, regMEM4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.029851
# 1  Defensive Rebounds         -1.351472
# 2      Average Points         -0.534738
# 3          Attendees           0.003813
# 4     Team Efficiency          0.509099

# %%
pd.DataFrame(list(zip(X_POR_train4.columns, regPOR4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.069275
# 1  Defensive Rebounds         -1.658266
# 2      Average Points         -0.532612
# 3          Attendees           0.003157
# 4     Team Efficiency          0.523650

# %%
pd.DataFrame(list(zip(X_DEN_train4.columns, regDEN4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.079416
# 1  Defensive Rebounds         -1.625225
# 2      Average Points         -0.403518
# 3          Attendees           0.003299
# 4     Team Efficiency          0.485057

# %%
pd.DataFrame(list(zip(X_NOP_train4.columns, regNOP4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.033063
# 1  Defensive Rebounds         -1.489837
# 2      Average Points         -0.556814
# 3          Attendees           0.003228
# 4     Team Efficiency          0.537728

# %%
pd.DataFrame(list(zip(X_DAL_train4.columns, regDAL4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.116515
# 1  Defensive Rebounds         -1.583395
# 2      Average Points         -0.569837
# 3          Attendees           0.003925
# 4     Team Efficiency          0.457773

# %%
pd.DataFrame(list(zip(X_SAC_train4.columns, regSAC4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.042656
# 1  Defensive Rebounds         -1.554939
# 2      Average Points         -0.613208
# 3          Attendees           0.003216
# 4     Team Efficiency          0.510246

# %%
pd.DataFrame(list(zip(X_MIN_train4.columns, regMIN4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.075448
# 1  Defensive Rebounds         -1.604687
# 2      Average Points         -0.309255
# 3          Attendees           0.003492
# 4     Team Efficiency          0.367967

# %%
pd.DataFrame(list(zip(X_LAL_train4.columns, regLAL4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.040109
# 1  Defensive Rebounds         -1.454882
# 2      Average Points         -0.466441
# 3          Attendees           0.003506
# 4     Team Efficiency          0.437806

# %%
pd.DataFrame(list(zip(X_PHO_train4.columns, regPHO4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.044235
# 1  Defensive Rebounds         -1.539984
# 2      Average Points         -0.480702
# 3          Attendees           0.003356
# 4     Team Efficiency          0.457665

# %%
pd.DataFrame(list(zip(X_BOS_train4.columns, regBOS4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.081807
# 1  Defensive Rebounds         -1.625645
# 2      Average Points         -0.502212
# 3          Attendees           0.003232
# 4     Team Efficiency          0.498205

# %%
pd.DataFrame(list(zip(X_CLE_train4.columns, regCLE4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.113952
# 1  Defensive Rebounds         -1.079293
# 2      Average Points         -1.258854
# 3          Attendees           0.001137
# 4     Team Efficiency          0.924197

# %%
pd.DataFrame(list(zip(X_TOR_train4.columns, regTOR4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.057069
# 1  Defensive Rebounds         -1.566101
# 2      Average Points         -0.520629
# 3          Attendees           0.003353
# 4     Team Efficiency          0.498032

# %%
pd.DataFrame(list(zip(X_WAS_train4.columns, regWAS4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.055338
# 1  Defensive Rebounds         -1.569813
# 2      Average Points         -0.529441
# 3          Attendees           0.003367
# 4     Team Efficiency          0.502746

# %%
pd.DataFrame(list(zip(X_ATL_train4.columns, regATL4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.019089
# 1  Defensive Rebounds         -2.133072
# 2      Average Points         -0.849008
# 3          Attendees           0.004517
# 4     Team Efficiency          0.900353

# %%
pd.DataFrame(list(zip(X_MIL_train4.columns, regMIL4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.059283
# 1  Defensive Rebounds         -1.763667
# 2      Average Points         -0.567179
# 3          Attendees           0.003230
# 4     Team Efficiency          0.585669

# %%
pd.DataFrame(list(zip(X_IND_train4.columns, regIND4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.054991
# 1  Defensive Rebounds         -1.509717
# 2      Average Points         -0.422032
# 3          Attendees           0.003601
# 4     Team Efficiency          0.423708

# %%
pd.DataFrame(list(zip(X_CHI_train4.columns, regCHI4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.077193
# 1  Defensive Rebounds         -1.600264
# 2      Average Points         -0.539584
# 3          Attendees           0.003603
# 4     Team Efficiency          0.485960

# %%
pd.DataFrame(list(zip(X_MIA_train4.columns, regMIA4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.059327
# 1  Defensive Rebounds         -1.532219
# 2      Average Points         -0.524645
# 3          Attendees           0.003692
# 4     Team Efficiency          0.517092

# %%
pd.DataFrame(list(zip(X_DET_train4.columns, regDET4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.058015
# 1  Defensive Rebounds         -1.508512
# 2      Average Points         -0.565257
# 3          Attendees           0.003387
# 4     Team Efficiency          0.517780

# %%
pd.DataFrame(list(zip(X_CHA_train4.columns, regCHA4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.067760
# 1  Defensive Rebounds         -1.583794
# 2      Average Points         -0.569866
# 3          Attendees           0.003423
# 4     Team Efficiency          0.526596

# %%
pd.DataFrame(list(zip(X_NYK_train4.columns, regNYK4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.021149
# 1  Defensive Rebounds         -1.628227
# 2      Average Points         -0.352037
# 3          Attendees           0.003942
# 4     Team Efficiency          0.345231

# %%
pd.DataFrame(list(zip(X_ORL_train4.columns, regORL4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.085631
# 1  Defensive Rebounds         -1.520370
# 2      Average Points         -0.666018
# 3          Attendees           0.003263
# 4     Team Efficiency          0.537516

# %%
pd.DataFrame(list(zip(X_PHI_train4.columns, regPHI4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.061033
# 1  Defensive Rebounds         -1.423415
# 2      Average Points         -0.574951
# 3          Attendees           0.003263
# 4     Team Efficiency          0.576422

# %%
pd.DataFrame(list(zip(X_BKN_train4.columns, regBKN4.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.197616
# 1  Defensive Rebounds         -1.759987
# 2      Average Points         -0.499402
# 3          Attendees           0.002738
# 4     Team Efficiency          0.530823

# %%
#show difference for first quarter of the season

all_teams = pd.DataFrame({
    "Team Name" : ['Golden State', 'San Antonio', 'Houston', 'Los Angeles Clippers', 'Utah',
             'Oklahoma City', 'Memphis', 'Portland', 'Denver', 'New Orleans', 'Dallas',
             'Sacramento', 'Minnesota', 'Los Angeles Lakers', 'Phoenix', 'Boston',
             'Cleveland', 'Toronto', 'Washington', 'Atlanta', 'Milwaukee', 'Indiana',
             'Chicago', 'Miami', 'Detroit', 'Charlotte', 'New York', 'Orlando', 'Philadelphia', 'Brooklyn'],
    "Team Performance Difference Between Actual and Predicted": [diff_GSW, diff_SAS, diff_HOU, diff_LAC, diff_UTAH,
                                               diff_OKC, diff_MEM, diff_POR, diff_DEN, diff_NOP,
                                               diff_DAL, diff_SAC, diff_MIN, diff_LAL, diff_PHO,
                                               diff_BOS, diff_CLE, diff_TOR, diff_WAS, diff_ATL,
                                               diff_MIL, diff_IND, diff_CHI, diff_MIA, diff_DET,
                                               diff_CHA, diff_NYK, diff_ORL, diff_PHI, diff_BKN],
    "Team Performance Percent Error": [err_GSW, err_SAS, err_HOU, err_LAC, err_UTAH,
                                               err_OKC, err_MEM, err_POR, err_DEN, err_NOP,
                                               err_DAL, err_SAC, err_MIN, err_LAL, err_PHO,
                                               err_BOS, err_CLE, err_TOR, err_WAS, err_ATL,
                                               err_MIL, err_IND, err_CHI, err_MIA, err_DET,
                                               err_CHA, err_NYK, err_ORL, err_PHI, err_BKN]
  }
).sort_values(by="Team Name", ascending=True)

all_teams
# Out:
#                Team Name  \
# 19               Atlanta
# 15                Boston
# 29              Brooklyn
# 25             Charlotte
# 22               Chicago
# 16             Cleveland
# 10                Dallas
# 8                 Denver
# 24               Detroit
# 0           Golden State
# 2                Houston
# 21               Indiana
# 3   Los Angeles Clippers
# 13    Los Angeles Lakers
# 6                Memphis
# 23                 Miami
# 20             Milwaukee
# 12             Minnesota
# 9            New Orleans
# 26              New York
# 5          Oklahoma City
# 27               Orlando
# 28          Philadelphia
# 14               Phoenix
# 7               Portland
# 11            Sacramento
# 1            San Antonio
# 17               Toronto
# 4                   Utah
# 18            Washington
#
#     Team Performance Difference Between Actual and Predicted  \
# 19                                           9.102605
# ...

# %%
#show difference for second quarter of the season

all_teams = pd.DataFrame({
    "Team Name" : ['Golden State', 'San Antonio', 'Houston', 'Los Angeles Clippers', 'Utah',
             'Oklahoma City', 'Memphis', 'Portland', 'Denver', 'New Orleans', 'Dallas',
             'Sacramento', 'Minnesota', 'Los Angeles Lakers', 'Phoenix', 'Boston',
             'Cleveland', 'Toronto', 'Washington', 'Atlanta', 'Milwaukee', 'Indiana',
             'Chicago', 'Miami', 'Detroit', 'Charlotte', 'New York', 'Orlando', 'Philadelphia', 'Brooklyn'],
    "Team Performance Difference Between Actual and Predicted": [diff_GSW2, diff_SAS2, diff_HOU2, diff_LAC2, diff_UTAH2,
                                               diff_OKC2, diff_MEM2, diff_POR2, diff_DEN2, diff_NOP2,
                                               diff_DAL2, diff_SAC2, diff_MIN2, diff_LAL2, diff_PHO2,
                                               diff_BOS2, diff_CLE2, diff_TOR2, diff_WAS2, diff_ATL2,
                                               diff_MIL2, diff_IND2, diff_CHI2, diff_MIA2, diff_DET2,
                                               diff_CHA2, diff_NYK2, diff_ORL2, diff_PHI2, diff_BKN2],
    "Team Performance Percent Error": [err_GSW2, err_SAS2, err_HOU2, err_LAC2, err_UTAH2,
                                               err_OKC2, err_MEM2, err_POR2, err_DEN2, err_NOP2,
                                               err_DAL2, err_SAC2, err_MIN2, err_LAL2, err_PHO2,
                                               err_BOS2, err_CLE2, err_TOR2, err_WAS2, err_ATL2,
                                               err_MIL2, err_IND2, err_CHI2, err_MIA2, err_DET2,
                                               err_CHA2, err_NYK2, err_ORL2, err_PHI2, err_BKN2]
  }
).sort_values(by="Team Name", ascending=True)

all_teams
# Out:
#                Team Name  \
# 19               Atlanta
# 15                Boston
# 29              Brooklyn
# 25             Charlotte
# 22               Chicago
# 16             Cleveland
# 10                Dallas
# 8                 Denver
# 24               Detroit
# 0           Golden State
# 2                Houston
# 21               Indiana
# 3   Los Angeles Clippers
# 13    Los Angeles Lakers
# 6                Memphis
# 23                 Miami
# 20             Milwaukee
# 12             Minnesota
# 9            New Orleans
# 26              New York
# 5          Oklahoma City
# 27               Orlando
# 28          Philadelphia
# 14               Phoenix
# 7               Portland
# 11            Sacramento
# 1            San Antonio
# 17               Toronto
# 4                   Utah
# 18            Washington
#
#     Team Performance Difference Between Actual and Predicted  \
# 19                                           9.421040
# ...

# %%
#show difference for third quarter of the season

all_teams = pd.DataFrame({
    "Team Name" : ['Golden State', 'San Antonio', 'Houston', 'Los Angeles Clippers', 'Utah',
             'Oklahoma City', 'Memphis', 'Portland', 'Denver', 'New Orleans', 'Dallas',
             'Sacramento', 'Minnesota', 'Los Angeles Lakers', 'Phoenix', 'Boston',
             'Cleveland', 'Toronto', 'Washington', 'Atlanta', 'Milwaukee', 'Indiana',
             'Chicago', 'Miami', 'Detroit', 'Charlotte', 'New York', 'Orlando', 'Philadelphia', 'Brooklyn'],
    "Team Performance Difference Between Actual and Predicted": [diff_GSW3, diff_SAS3, diff_HOU3, diff_LAC3, diff_UTAH3,
                                               diff_OKC3, diff_MEM3, diff_POR3, diff_DEN3, diff_NOP3,
                                               diff_DAL3, diff_SAC3, diff_MIN3, diff_LAL3, diff_PHO3,
                                               diff_BOS3, diff_CLE3, diff_TOR3, diff_WAS3, diff_ATL3,
                                               diff_MIL3, diff_IND3, diff_CHI3, diff_MIA3, diff_DET3,
                                               diff_CHA3, diff_NYK3, diff_ORL3, diff_PHI3, diff_BKN3],
    "Team Performance Percent Error": [err_GSW3, err_SAS3, err_HOU3, err_LAC3, err_UTAH3,
                                               err_OKC3, err_MEM3, err_POR3, err_DEN3, err_NOP3,
                                               err_DAL3, err_SAC3, err_MIN3, err_LAL3, err_PHO3,
                                               err_BOS3, err_CLE3, err_TOR3, err_WAS3, err_ATL3,
                                               err_MIL3, err_IND3, err_CHI3, err_MIA3, err_DET3,
                                               err_CHA3, err_NYK3, err_ORL3, err_PHI3, err_BKN3]
  }
).sort_values(by="Team Name", ascending=True)

all_teams
# Out:
#                Team Name  \
# 19               Atlanta
# 15                Boston
# 29              Brooklyn
# 25             Charlotte
# 22               Chicago
# 16             Cleveland
# 10                Dallas
# 8                 Denver
# 24               Detroit
# 0           Golden State
# 2                Houston
# 21               Indiana
# 3   Los Angeles Clippers
# 13    Los Angeles Lakers
# 6                Memphis
# 23                 Miami
# 20             Milwaukee
# 12             Minnesota
# 9            New Orleans
# 26              New York
# 5          Oklahoma City
# 27               Orlando
# 28          Philadelphia
# 14               Phoenix
# 7               Portland
# 11            Sacramento
# 1            San Antonio
# 17               Toronto
# 4                   Utah
# 18            Washington
#
#     Team Performance Difference Between Actual and Predicted  \
# 19                                          14.480416
# ...

# %%
#show difference for fourth quarter of the season

all_teams = pd.DataFrame({
    "Team Name" : ['Golden State', 'San Antonio', 'Houston', 'Los Angeles Clippers', 'Utah',
             'Oklahoma City', 'Memphis', 'Portland', 'Denver', 'New Orleans', 'Dallas',
             'Sacramento', 'Minnesota', 'Los Angeles Lakers', 'Phoenix', 'Boston',
             'Cleveland', 'Toronto', 'Washington', 'Atlanta', 'Milwaukee', 'Indiana',
             'Chicago', 'Miami', 'Detroit', 'Charlotte', 'New York', 'Orlando', 'Philadelphia', 'Brooklyn'],
    "Team Performance Difference Between Actual and Predicted": [diff_GSW4, diff_SAS4, diff_HOU4, diff_LAC4, diff_UTAH4,
                                               diff_OKC4, diff_MEM4, diff_POR4, diff_DEN4, diff_NOP4,
                                               diff_DAL4, diff_SAC4, diff_MIN4, diff_LAL4, diff_PHO4,
                                               diff_BOS4, diff_CLE4, diff_TOR4, diff_WAS4, diff_ATL4,
                                               diff_MIL4, diff_IND4, diff_CHI4, diff_MIA4, diff_DET4,
                                               diff_CHA4, diff_NYK4, diff_ORL4, diff_PHI4, diff_BKN4],
    "Team Performance Percent Error": [err_GSW4, err_SAS4, err_HOU4, err_LAC4, err_UTAH4,
                                               err_OKC4, err_MEM4, err_POR4, err_DEN4, err_NOP4,
                                               err_DAL4, err_SAC4, err_MIN4, err_LAL4, err_PHO4,
                                               err_BOS4, err_CLE4, err_TOR4, err_WAS4, err_ATL4,
                                               err_MIL4, err_IND4, err_CHI4, err_MIA4, err_DET4,
                                               err_CHA4, err_NYK4, err_ORL4, err_PHI4, err_BKN4]
  }
).sort_values(by="Team Name", ascending=True)

all_teams
# Out:
#                Team Name  \
# 19               Atlanta
# 15                Boston
# 29              Brooklyn
# 25             Charlotte
# 22               Chicago
# 16             Cleveland
# 10                Dallas
# 8                 Denver
# 24               Detroit
# 0           Golden State
# 2                Houston
# 21               Indiana
# 3   Los Angeles Clippers
# 13    Los Angeles Lakers
# 6                Memphis
# 23                 Miami
# 20             Milwaukee
# 12             Minnesota
# 9            New Orleans
# 26              New York
# 5          Oklahoma City
# 27               Orlando
# 28          Philadelphia
# 14               Phoenix
# 7               Portland
# 11            Sacramento
# 1            San Antonio
# 17               Toronto
# 4                   Utah
# 18            Washington
#
#     Team Performance Difference Between Actual and Predicted  \
# 19                                          20.837330
# ...

# %%
#show actual and predicted for Eastern Conference for first quarter of the season

all_east = pd.DataFrame({
    "Team Name" : ['Atlanta', 'Boston', 'Brooklyn', 'Charlotte', 'Chicago',
                  'Cleveland', 'Detroit', 'Indiana', 'Miami', 'Milwaukee',
                  'New York', 'Orlando', 'Philadelphia', 'Toronto', 'Washington'],
    "Team Performance Actual Score" : [y_ATL_data[0], y_BOS_data[0], y_BKN_data[0],
                                      y_CHA_data[0], y_CHI_data[0], y_CLE_data[0],
                                      y_DET_data[0], y_IND_data[0], y_MIA_data[0],
                                      y_MIL_data[0], y_NYK_data[0], y_ORL_data[0],
                                      y_PHI_data[0], y_TOR_data[0], y_WAS_data[0]],
    "Team Performance Predicted Score" : [y_pred_ATL.item(0), y_pred_BOS.item(0),
                                         y_pred_BKN.item(0), y_pred_CHA.item(0),
                                         y_pred_CHI.item(0), y_pred_CLE.item(0),
                                         y_pred_DET.item(0), y_pred_IND.item(0),
                                         y_pred_MIA.item(0), y_pred_MIL.item(0),
                                         y_pred_NYK.item(0), y_pred_ORL.item(0),
                                         y_pred_PHI.item(0), y_pred_TOR.item(0),
                                         y_pred_WAS.item(0)]
  }
).sort_values(by="Team Performance Predicted Score", ascending=False)

all_east
# Out:
#        Team Name  Team Performance Actual Score  \
# 13       Toronto                             75
# 12  Philadelphia                             65
# 10      New York                             65
# 6        Detroit                             65
# 11       Orlando                             65
# 8          Miami                             65
# 14    Washington                             75
# 7        Indiana                             75
# 9      Milwaukee                             75
# 5      Cleveland                             95
# 1         Boston                             75
# 4        Chicago                             75
# 0        Atlanta                             75
# 2       Brooklyn                             65
# 3      Charlotte                             65
#
#     Team Performance Predicted Score
# 13                         80.121166
# 12                         78.801567
# 10                         76.235235
# 6                          73.818645
# ...

# %%
#show actual and predicted for Western Conference for first quarter of the season

all_west = pd.DataFrame({
    "Team Name" : ['Dallas', 'Denver', 'Golden State', 'Houston', 'Los Angeles Clippers',
                  'Los Angeles Lakers', 'Memphis', 'Minnesota', 'New Orleans', 'Oklahoma City',
                  'Phoenix', 'Portland', 'Sacramento', 'San Antonio', 'Utah'],
    "Team Performance Actual Score" : [y_DAL_data[0], y_DEN_data[0], y_GSW_data[0],
                                      y_HOU_data[0], y_LAC_data[0], y_LAL_data[0],
                                      y_MEM_data[0], y_MIN_data[0], y_NOP_data[0],
                                      y_OKC_data[0], y_PHO_data[0], y_POR_data[0],
                                      y_SAC_data[0], y_SAS_data[0], y_UTAH_data[0]],
    "Team Performance Predicted Score" : [y_pred_DAL.item(0), y_pred_DEN.item(0),
                                         y_pred_GSW.item(0), y_pred_HOU.item(0),
                                         y_pred_LAC.item(0), y_pred_LAL.item(0),
                                         y_pred_MEM.item(0), y_pred_MIN.item(0),
                                         y_pred_NOP.item(0), y_pred_OKC.item(0),
                                         y_pred_PHO.item(0), y_pred_POR.item(0),
                                         y_pred_SAC.item(0), y_pred_SAS.item(0),
                                         y_pred_UTAH.item(0)]
  }
).sort_values(by="Team Performance Predicted Score", ascending=False)

all_west
# Out:
#                Team Name  Team Performance Actual Score  \
# 3                Houston                             75
# 9          Oklahoma City                             75
# 2           Golden State                            100
# 7              Minnesota                             65
# 13           San Antonio                             75
# 1                 Denver                             65
# 8            New Orleans                             65
# 4   Los Angeles Clippers                             75
# 14                  Utah                             75
# 5     Los Angeles Lakers                             65
# 0                 Dallas                             65
# 12            Sacramento                             65
# 11              Portland                             75
# 6                Memphis                             75
# 10               Phoenix                             65
#
#     Team Performance Predicted Score
# ...

# %%
#show actual and predicted for Eastern Conference for second quarter of the season

all_east = pd.DataFrame({
    "Team Name" : ['Atlanta', 'Boston', 'Brooklyn', 'Charlotte', 'Chicago',
                  'Cleveland', 'Detroit', 'Indiana', 'Miami', 'Milwaukee',
                  'New York', 'Orlando', 'Philadelphia', 'Toronto', 'Washington'],
    "Team Performance Actual Score" : [y_ATL_data2[0], y_BOS_data2[0], y_BKN_data2[0],
                                      y_CHA_data2[0], y_CHI_data2[0], y_CLE_data2[0],
                                      y_DET_data2[0], y_IND_data2[0], y_MIA_data2[0],
                                      y_MIL_data2[0], y_NYK_data2[0], y_ORL_data2[0],
                                      y_PHI_data2[0], y_TOR_data2[0], y_WAS_data2[0]],
    "Team Performance Predicted Score" : [y_pred_ATL2.item(0), y_pred_BOS2.item(0),
                                         y_pred_BKN2.item(0), y_pred_CHA2.item(0),
                                         y_pred_CHI2.item(0), y_pred_CLE2.item(0),
                                         y_pred_DET2.item(0), y_pred_IND2.item(0),
                                         y_pred_MIA2.item(0), y_pred_MIL2.item(0),
                                         y_pred_NYK2.item(0), y_pred_ORL2.item(0),
                                         y_pred_PHI2.item(0), y_pred_TOR2.item(0),
                                         y_pred_WAS2.item(0)]
  }
).sort_values(by="Team Performance Predicted Score", ascending=False)

all_east
# Out:
#        Team Name  Team Performance Actual Score  \
# 8          Miami                             65
# 13       Toronto                             75
# 12  Philadelphia                             65
# 4        Chicago                             75
# 5      Cleveland                             95
# 1         Boston                             75
# 14    Washington                             75
# 10      New York                             65
# 9      Milwaukee                             75
# 7        Indiana                             75
# 6        Detroit                             65
# 3      Charlotte                             65
# 0        Atlanta                             75
# 11       Orlando                             65
# 2       Brooklyn                             65
#
#     Team Performance Predicted Score
# 8                          77.681556
# 13                         77.015900
# 12                         75.369009
# 4                          74.510991
# ...

# %%
#show actual and predicted for Western Conference for second quarter of the season

all_west = pd.DataFrame({
    "Team Name" : ['Dallas', 'Denver', 'Golden State', 'Houston', 'Los Angeles Clippers',
                  'Los Angeles Lakers', 'Memphis', 'Minnesota', 'New Orleans', 'Oklahoma City',
                  'Phoenix', 'Portland', 'Sacramento', 'San Antonio', 'Utah'],
    "Team Performance Actual Score" : [y_DAL_data2[0], y_DEN_data2[0], y_GSW_data2[0],
                                      y_HOU_data2[0], y_LAC_data2[0], y_LAL_data2[0],
                                      y_MEM_data2[0], y_MIN_data2[0], y_NOP_data2[0],
                                      y_OKC_data2[0], y_PHO_data2[0], y_POR_data2[0],
                                      y_SAC_data2[0], y_SAS_data2[0], y_UTAH_data2[0]],
    "Team Performance Predicted Score" : [y_pred_DAL2.item(0), y_pred_DEN2.item(0),
                                         y_pred_GSW2.item(0), y_pred_HOU2.item(0),
                                         y_pred_LAC2.item(0), y_pred_LAL2.item(0),
                                         y_pred_MEM2.item(0), y_pred_MIN2.item(0),
                                         y_pred_NOP2.item(0), y_pred_OKC2.item(0),
                                         y_pred_PHO2.item(0), y_pred_POR2.item(0),
                                         y_pred_SAC2.item(0), y_pred_SAS2.item(0),
                                         y_pred_UTAH2.item(0)]
  }
).sort_values(by="Team Performance Predicted Score", ascending=False)

all_west
# Out:
#                Team Name  Team Performance Actual Score  \
# 3                Houston                             75
# 2           Golden State                            100
# 1                 Denver                             65
# 9          Oklahoma City                             75
# 0                 Dallas                             65
# 8            New Orleans                             65
# 7              Minnesota                             65
# 5     Los Angeles Lakers                             65
# 13           San Antonio                             75
# 14                  Utah                             75
# 4   Los Angeles Clippers                             75
# 12            Sacramento                             65
# 11              Portland                             75
# 10               Phoenix                             65
# 6                Memphis                             75
#
#     Team Performance Predicted Score
# ...

# %%
#show actual and predicted for Eastern Conference for third quarter of the season

all_east = pd.DataFrame({
    "Team Name" : ['Atlanta', 'Boston', 'Brooklyn', 'Charlotte', 'Chicago',
                  'Cleveland', 'Detroit', 'Indiana', 'Miami', 'Milwaukee',
                  'New York', 'Orlando', 'Philadelphia', 'Toronto', 'Washington'],
    "Team Performance Actual Score" : [y_ATL_data3[0], y_BOS_data3[0], y_BKN_data3[0],
                                      y_CHA_data3[0], y_CHI_data3[0], y_CLE_data3[0],
                                      y_DET_data3[0], y_IND_data3[0], y_MIA_data3[0],
                                      y_MIL_data3[0], y_NYK_data3[0], y_ORL_data3[0],
                                      y_PHI_data3[0], y_TOR_data3[0], y_WAS_data3[0]],
    "Team Performance Predicted Score" : [y_pred_ATL3.item(0), y_pred_BOS3.item(0),
                                         y_pred_BKN3.item(0), y_pred_CHA3.item(0),
                                         y_pred_CHI3.item(0), y_pred_CLE3.item(0),
                                         y_pred_DET3.item(0), y_pred_IND3.item(0),
                                         y_pred_MIA3.item(0), y_pred_MIL3.item(0),
                                         y_pred_NYK3.item(0), y_pred_ORL3.item(0),
                                         y_pred_PHI3.item(0), y_pred_TOR3.item(0),
                                         y_pred_WAS3.item(0)]
  }
).sort_values(by="Team Performance Predicted Score", ascending=False)

all_east
# Out:
#        Team Name  Team Performance Actual Score  \
# 13       Toronto                             75
# 4        Chicago                             75
# 12  Philadelphia                             65
# 8          Miami                             65
# 11       Orlando                             65
# 5      Cleveland                             95
# 10      New York                             65
# 1         Boston                             75
# 14    Washington                             75
# 3      Charlotte                             65
# 6        Detroit                             65
# 2       Brooklyn                             65
# 9      Milwaukee                             75
# 7        Indiana                             75
# 0        Atlanta                             75
#
#     Team Performance Predicted Score
# 13                         77.305932
# 4                          75.675437
# 12                         74.648295
# 8                          73.966148
# ...

# %%
#show actual and predicted for Western Conference for third quarter of the season

all_west = pd.DataFrame({
    "Team Name" : ['Dallas', 'Denver', 'Golden State', 'Houston', 'Los Angeles Clippers',
                  'Los Angeles Lakers', 'Memphis', 'Minnesota', 'New Orleans', 'Oklahoma City',
                  'Phoenix', 'Portland', 'Sacramento', 'San Antonio', 'Utah'],
    "Team Performance Actual Score" : [y_DAL_data3[0], y_DEN_data3[0], y_GSW_data3[0],
                                      y_HOU_data3[0], y_LAC_data3[0], y_LAL_data3[0],
                                      y_MEM_data3[0], y_MIN_data3[0], y_NOP_data3[0],
                                      y_OKC_data3[0], y_PHO_data3[0], y_POR_data3[0],
                                      y_SAC_data3[0], y_SAS_data3[0], y_UTAH_data3[0]],
    "Team Performance Predicted Score" : [y_pred_DAL3.item(0), y_pred_DEN3.item(0),
                                         y_pred_GSW3.item(0), y_pred_HOU3.item(0),
                                         y_pred_LAC3.item(0), y_pred_LAL3.item(0),
                                         y_pred_MEM3.item(0), y_pred_MIN3.item(0),
                                         y_pred_NOP3.item(0), y_pred_OKC3.item(0),
                                         y_pred_PHO3.item(0), y_pred_POR3.item(0),
                                         y_pred_SAC3.item(0), y_pred_SAS3.item(0),
                                         y_pred_UTAH3.item(0)]
  }
).sort_values(by="Team Performance Predicted Score", ascending=False)

all_west
# Out:
#                Team Name  Team Performance Actual Score  \
# 5     Los Angeles Lakers                             65
# 3                Houston                             75
# 8            New Orleans                             65
# 7              Minnesota                             65
# 9          Oklahoma City                             75
# 11              Portland                             75
# 1                 Denver                             65
# 4   Los Angeles Clippers                             75
# 0                 Dallas                             65
# 2           Golden State                            100
# 12            Sacramento                             65
# 10               Phoenix                             65
# 14                  Utah                             75
# 13           San Antonio                             75
# 6                Memphis                             75
#
#     Team Performance Predicted Score
# ...

# %%
#show actual and predicted for Eastern Conference for fourth quarter of the season

all_east = pd.DataFrame({
    "Team Name" : ['Atlanta', 'Boston', 'Brooklyn', 'Charlotte', 'Chicago',
                  'Cleveland', 'Detroit', 'Indiana', 'Miami', 'Milwaukee',
                  'New York', 'Orlando', 'Philadelphia', 'Toronto', 'Washington'],
    "Team Performance Actual Score" : [y_ATL_data4[0], y_BOS_data4[0], y_BKN_data4[0],
                                      y_CHA_data4[0], y_CHI_data4[0], y_CLE_data4[0],
                                      y_DET_data4[0], y_IND_data4[0], y_MIA_data4[0],
                                      y_MIL_data4[0], y_NYK_data4[0], y_ORL_data4[0],
                                      y_PHI_data4[0], y_TOR_data4[0], y_WAS_data4[0]],
    "Team Performance Predicted Score" : [y_pred_ATL4.item(0), y_pred_BOS4.item(0),
                                         y_pred_BKN4.item(0), y_pred_CHA4.item(0),
                                         y_pred_CHI4.item(0), y_pred_CLE4.item(0),
                                         y_pred_CLE4.item(0), y_pred_IND4.item(0),
                                         y_pred_MIA4.item(0), y_pred_MIL4.item(0),
                                         y_pred_NYK4.item(0), y_pred_ORL4.item(0),
                                         y_pred_PHI4.item(0), y_pred_TOR4.item(0),
                                         y_pred_WAS4.item(0)]
  }
).sort_values(by="Team Performance Predicted Score", ascending=False)

all_east
# Out:
#        Team Name  Team Performance Actual Score  \
# 9      Milwaukee                             75
# 4        Chicago                             75
# 10      New York                             65
# 14    Washington                             75
# 13       Toronto                             75
# 8          Miami                             65
# 5      Cleveland                             95
# 6        Detroit                             65
# 1         Boston                             75
# 7        Indiana                             75
# 2       Brooklyn                             65
# 11       Orlando                             65
# 12  Philadelphia                             65
# 3      Charlotte                             65
# 0        Atlanta                             75
#
#     Team Performance Predicted Score
# 9                          80.130098
# 4                          78.200400
# 10                         76.249068
# 14                         75.663799
# ...

# %%
#show actual and predicted for Western Conference for fourth quarter of the season

all_west = pd.DataFrame({
    "Team Name" : ['Dallas', 'Denver', 'Golden State', 'Houston', 'Los Angeles Clippers',
                  'Los Angeles Lakers', 'Memphis', 'Minnesota', 'New Orleans', 'Oklahoma City',
                  'Phoenix', 'Portland', 'Sacramento', 'San Antonio', 'Utah'],
    "Team Performance Actual Score" : [y_DAL_data4[0], y_DEN_data4[0], y_GSW_data4[0],
                                      y_HOU_data4[0], y_LAC_data4[0], y_LAL_data4[0],
                                      y_MEM_data4[0], y_MIN_data4[0], y_NOP_data4[0],
                                      y_OKC_data4[0], y_PHO_data4[0], y_POR_data4[0],
                                      y_SAC_data4[0], y_SAS_data4[0], y_UTAH_data4[0]],
    "Team Performance Predicted Score" : [y_pred_DAL4.item(0), y_pred_DEN4.item(0),
                                         y_pred_GSW4.item(0), y_pred_HOU4.item(0),
                                         y_pred_LAC4.item(0), y_pred_LAL4.item(0),
                                         y_pred_MEM4.item(0), y_pred_MIN4.item(0),
                                         y_pred_NOP4.item(0), y_pred_OKC4.item(0),
                                         y_pred_PHO4.item(0), y_pred_POR4.item(0),
                                         y_pred_SAC4.item(0), y_pred_SAS4.item(0),
                                         y_pred_UTAH4.item(0)]
  }
).sort_values(by="Team Performance Predicted Score", ascending=False)

all_west
# Out:
#                Team Name  Team Performance Actual Score  \
# 13           San Antonio                             75
# 0                 Dallas                             65
# 7              Minnesota                             65
# 9          Oklahoma City                             75
# 2           Golden State                            100
# 1                 Denver                             65
# 12            Sacramento                             65
# 11              Portland                             75
# 6                Memphis                             75
# 4   Los Angeles Clippers                             75
# 3                Houston                             75
# 5     Los Angeles Lakers                             65
# 14                  Utah                             75
# 8            New Orleans                             65
# 10               Phoenix                             65
#
#     Team Performance Predicted Score
# ...
