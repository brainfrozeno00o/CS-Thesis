# %% [markdown]
# Team Efficiency all-in-all uses = League Points, 3Ps Made, Assists, Turnovers, Field Goal Attempts, Field Goals Made, Free Throws Attempted, Free Throws Made, Offensive Rebounds, Total Rebounds, Steals, Blocks, and Personal Fouls thus remove these from the X set to remove redundancy
#
# Same case for factor, VOP, and DRB since they are part of getting the team efficiency engineered stat
#
# Thus, X should contain 3Ps Attempted, Defensive Rebounds, Average Points, Attendees, and Team Efficiency

# %%
# %matplotlib inline

import matplotlib.pylab as plt
import numpy as np
import pandas as pd

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/14pMDUP0sqKl9bg8ZxL2D5QKbjZcWdC4nsSG-u_6nXxY/edit#gid=812816002'
csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

df = pd.read_csv(csv_export_url)
df.describe() #describes the dataset
# Out:
#          FGs Made  FGs Attempted    3Ps Made  3Ps Attempted    FTs Made  \
# count  660.000000     660.000000  660.000000     660.000000  660.000000
# mean    38.371212      84.707576    8.654545      24.266667   17.719697
# std      2.987087       4.177867    2.346093       5.221798    3.477468
# min     30.000000      72.000000    3.000000      10.000000    8.000000
# 25%     36.000000      82.000000    7.000000      20.750000   15.000000
# 50%     38.000000      85.000000    8.000000      24.000000   18.000000
# 75%     40.000000      88.000000   10.000000      28.000000   20.000000
# max     50.000000      99.000000   17.000000      40.000000   30.000000
#
#        FTs Attempted  Offensive Rebounds  Defensive Rebounds  Total Rebounds  \
# count     660.000000          660.000000          660.000000      660.000000
# mean       23.383333           10.512121           33.422727       43.825758
# std         4.453097            2.299602            3.106374        3.831616
# ...

# %%
df.shape #print how many columns and rows
# Out:
# (660, 36)

# %%
df.dtypes #check types per column
# Out:
# TEAM NAME                     object
# FGs Made                       int64
# FGs Attempted                  int64
# FG %                          object
# 3Ps Made                       int64
# 3Ps Attempted                  int64
# 3Ps %                         object
# FTs Made                       int64
# FTs Attempted                  int64
# FT%                           object
# Offensive Rebounds             int64
# Defensive Rebounds             int64
# Total Rebounds                 int64
# Assists                        int64
# Steals                         int64
# Blocks                         int64
# Turnovers                      int64
# Personal Fouls                 int64
# Average Points                 int64
# Attendees                      int64
# TEAM EFFICIENCY                int64
# Factor                       float64
# VOP                          float64
# DRB%                         float64
# Team Performance               int64
# ...

# %%
#remove '%' in percentages
df["FG %"] = df["FG %"].str.rstrip('%')
df["3Ps %"] = df["3Ps %"].str.rstrip('%')
df["FT%"] = df["FT%"].str.rstrip('%')

# %%
#change object types to numeric
df["FG %"] = pd.to_numeric(df["FG %"], downcast='float', errors='coerce')
df["3Ps %"] = pd.to_numeric(df["3Ps %"], downcast='float', errors='coerce')
df["FT%"] = pd.to_numeric(df["FT%"], downcast='float', errors='coerce')

# %%
#get the real percentage of stats that involve percentages
df["FG %"] = df["FG %"] / 100
df["3Ps %"] = df["3Ps %"] / 100
df["FT%"] = df["FT%"] / 100

#df["FT%"] #check the percentages

# %%
#set the dataset per team

# df.columns.get_loc("3Ps Attempted") #5
# df.columns.get_loc("Defensive Rebounds") #11
# df.columns.get_loc("Attendees") #19
# df.columns.get_loc("Average Points") #18
# df.columns.get_loc("TEAM EFFICIENCY") #20

#for Houston
X_Houston = df.iloc[0:22, [5,11,18,19,20]]
y_Houston = df.iloc[0:22, 24]

#for Golden State
X_GoldenState = df.iloc[22:44, [5,11,18,19,20]]
y_GoldenState = df.iloc[22:44, 24]

#for Portland
X_Portland = df.iloc[44:66, [5,11,18,19,20]]
y_Portland = df.iloc[44:66, 24]

#for Oklahoma City
X_OklahomaCity = df.iloc[66:88, [5,11,18,19,20]]
y_OklahomaCity = df.iloc[66:88, 24]

#for Utah
X_Utah = df.iloc[88:110, [5,11,18,19,20]]
y_Utah = df.iloc[88:110, 24]

#for New Orleans
X_NewOrleans = df.iloc[110:132, [5,11,18,19,20]]
y_NewOrleans = df.iloc[110:132, 24]

#for San Antonio
X_SanAntonio = df.iloc[132:154, [5,11,18,19,20]]
y_SanAntonio = df.iloc[132:154, 24]

#for Minnesota
X_Minnesota = df.iloc[154:176, [5,11,18,19,20]]
y_Minnesota = df.iloc[154:176, 24]

#for Denver
X_Denver = df.iloc[176:198, [5,11,18,19,20]]
y_Denver = df.iloc[176:198, 24]

#for Los Angeles Clippers
X_LosAngelesClippers = df.iloc[198:220, [5,11,18,19,20]]
y_LosAngelesClippers = df.iloc[198:220, 24]

#for Toronto
X_Toronto = df.iloc[220:242, [5,11,18,19,20]]
y_Toronto = df.iloc[220:242, 24]

#for Boston
X_Boston = df.iloc[242:264, [5,11,18,19,20]]
y_Boston = df.iloc[242:264, 24]

#for Philadelphia 
X_Philadelphia = df.iloc[264:286, [5,11,18,19,20]]
y_Philadelphia = df.iloc[264:286, 24]

#for Cleveland
X_Cleveland = df.iloc[286:308, [5,11,18,19,20]]
y_Cleveland = df.iloc[286:308, 24]

#for Indiana
X_Indiana = df.iloc[308:330, [5,11,18,19,20]]
y_Indiana = df.iloc[308:330, 24]

#for Los Angeles Lakers
X_LosAngelesLakers = df.iloc[330:352, [5,11,18,19,20]]
y_LosAngelesLakers = df.iloc[330:352, 24]

#for Sacramento
X_Sacramento = df.iloc[352:374, [5,11,18,19,20]]
y_Sacramento = df.iloc[352:374, 24]

#for Dallas
X_Dallas = df.iloc[374:396, [5,11,18,19,20]]
y_Dallas = df.iloc[374:396, 24]

#for Memphis
X_Memphis = df.iloc[396:418, [5,11,18,19,20]]
y_Memphis = df.iloc[396:418, 24]

#for Phoenix
X_Phoenix = df.iloc[418:440, [5,11,18,19,20]]
y_Phoenix = df.iloc[418:440, 24]

#for Miami
X_Miami = df.iloc[440:462, [5,11,18,19,20]]
y_Miami = df.iloc[440:462, 24]

#for Milwaukee
X_Milwaukee = df.iloc[462:484, [5,11,18,19,20]]
y_Milwaukee = df.iloc[462:484, 24]

#for Washington
X_Washington = df.iloc[484:506, [5,11,18,19,20]]
y_Washington = df.iloc[484:506, 24]

#for Detroit
X_Detroit = df.iloc[506:528, [5,11,18,19,20]]
y_Detroit = df.iloc[506:528, 24]

#for Charlotte
X_Charlotte = df.iloc[528:550, [5,11,18,19,20]]
y_Charlotte = df.iloc[528:550, 24]

#for New York
X_NewYork = df.iloc[550:572, [5,11,18,19,20]]
y_NewYork = df.iloc[550:572, 24]

#for Brooklyn
X_Brooklyn = df.iloc[572:594, [5,11,18,19,20]]
y_Brooklyn = df.iloc[572:594, 24]

#for Chicago
X_Chicago = df.iloc[594:616, [5,11,18,19,20]]
y_Chicago = df.iloc[594:616, 24]

#for Orlando
X_Orlando = df.iloc[616:638, [5,11,18,19,20]]
y_Orlando = df.iloc[616:638, 24]

#for Atlanta
X_Atlanta = df.iloc[638:660, [5,11,18,19,20]]
y_Atlanta = df.iloc[638:660, 24]

# %%
#from sklearn.model_selection import train_test_split

#80% will be for training, 20% will be for testing, original plan
#X_train_Houston, X_test_Houston, y_train_Houston, y_test_Houston = train_test_split(X_Houston, y_Houston, test_size=0.2, random_state=0)

#setting training and testing data based on instances
#4-game period instances are part of the training dataset
#3-game period instances are part of the testing dataset

#for Houston
X_train_Houston = X_Houston[:16]
X_test_Houston = X_Houston[16:22]
y_train_Houston = y_Houston[:16]
y_test_Houston = y_Houston[16:22]

#for Golden State
X_train_GoldenState = X_GoldenState[:16]
X_test_GoldenState = X_GoldenState[16:22]
y_train_GoldenState = y_GoldenState[:16]
y_test_GoldenState = y_GoldenState[16:22]

#for Portland
X_train_Portland = X_Portland[:16]
X_test_Portland = X_Portland[16:22]
y_train_Portland = y_Portland[:16]
y_test_Portland = y_Portland[16:22]

#for Oklahoma City
X_train_OklahomaCity = X_OklahomaCity[:16]
X_test_OklahomaCity = X_OklahomaCity[16:22]
y_train_OklahomaCity = y_OklahomaCity[:16]
y_test_OklahomaCity = y_OklahomaCity[16:22]

#for Utah
X_train_Utah = X_Utah[:16]
X_test_Utah = X_Utah[16:22]
y_train_Utah = y_Utah[:16]
y_test_Utah = y_Utah[16:22]

#for New Orleans
X_train_NewOrleans = X_NewOrleans[:16]
X_test_NewOrleans = X_NewOrleans[16:22]
y_train_NewOrleans = y_NewOrleans[:16]
y_test_NewOrleans = y_NewOrleans[16:22]

#for San Antonio
X_train_SanAntonio = X_SanAntonio[:16]
X_test_SanAntonio = X_SanAntonio[16:22]
y_train_SanAntonio = y_SanAntonio[:16]
y_test_SanAntonio = y_SanAntonio[16:22]

#for Minnesota
X_train_Minnesota = X_Minnesota[:16]
X_test_Minnesota = X_Minnesota[16:22]
y_train_Minnesota = y_Minnesota[:16]
y_test_Minnesota = y_Minnesota[16:22]

#for Denver
X_train_Denver = X_Denver[:16]
X_test_Denver = X_Denver[16:22]
y_train_Denver = y_Denver[:16]
y_test_Denver = y_Denver[16:22]

#for Los Angeles Clippers
X_train_LosAngelesClippers = X_LosAngelesClippers[:16]
X_test_LosAngelesClippers = X_LosAngelesClippers[16:22]
y_train_LosAngelesClippers = y_LosAngelesClippers[:16]
y_test_LosAngelesClippers = y_LosAngelesClippers[16:22]

#for Toronto
X_train_Toronto = X_Toronto[:16]
X_test_Toronto = X_Toronto[16:22]
y_train_Toronto = y_Toronto[:16]
y_test_Toronto = y_Toronto[16:22]

#for Boston
X_train_Boston = X_Boston[:16]
X_test_Boston = X_Boston[16:22]
y_train_Boston = y_Boston[:16]
y_test_Boston = y_Boston[16:22]

#for Philadelphia
X_train_Philadelphia = X_Philadelphia[:16]
X_test_Philadelphia = X_Philadelphia[16:22]
y_train_Philadelphia = y_Philadelphia[:16]
y_test_Philadelphia = y_Philadelphia[16:22]

#for Cleveland
X_train_Cleveland = X_Cleveland[:16]
X_test_Cleveland = X_Cleveland[16:22]
y_train_Cleveland = y_Cleveland[:16]
y_test_Cleveland = y_Cleveland[16:22]

#for Indiana
X_train_Indiana = X_Indiana[:16]
X_test_Indiana = X_Indiana[16:22]
y_train_Indiana = y_Indiana[:16]
y_test_Indiana = y_Indiana[16:22]

#for Los Angeles Lakers
X_train_LosAngelesLakers = X_LosAngelesLakers[:16]
X_test_LosAngelesLakers = X_LosAngelesLakers[16:22]
y_train_LosAngelesLakers = y_LosAngelesLakers[:16]
y_test_LosAngelesLakers = y_LosAngelesLakers[16:22]

#for Sacramento
X_train_Sacramento = X_Sacramento[:16]
X_test_Sacramento = X_Sacramento[16:22]
y_train_Sacramento = y_Sacramento[:16]
y_test_Sacramento = y_Sacramento[16:22]

#for Dallas
X_train_Dallas = X_Dallas[:16]
X_test_Dallas = X_Dallas[16:22]
y_train_Dallas = y_Dallas[:16]
y_test_Dallas = y_Dallas[16:22]

#for Memphis
X_train_Memphis = X_Memphis[:16]
X_test_Memphis = X_Memphis[16:22]
y_train_Memphis = y_Memphis[:16]
y_test_Memphis = y_Memphis[16:22]

#for Phoenix
X_train_Phoenix = X_Phoenix[:16]
X_test_Phoenix = X_Phoenix[16:22]
y_train_Phoenix = y_Phoenix[:16]
y_test_Phoenix = y_Phoenix[16:22]

#for Miami
X_train_Miami = X_Miami[:16]
X_test_Miami = X_Miami[16:22]
y_train_Miami = y_Miami[:16]
y_test_Miami = y_Miami[16:22]

#for Milwaukee
X_train_Milwaukee = X_Milwaukee[:16]
X_test_Milwaukee = X_Milwaukee[16:22]
y_train_Milwaukee = y_Milwaukee[:16]
y_test_Milwaukee = y_Milwaukee[16:22]

#for Washington
X_train_Washington = X_Washington[:16]
X_test_Washington = X_Washington[16:22]
y_train_Washington = y_Washington[:16]
y_test_Washington = y_Washington[16:22]

#for Detroit
X_train_Detroit = X_Detroit[:16]
X_test_Detroit = X_Detroit[16:22]
y_train_Detroit = y_Detroit[:16]
y_test_Detroit = y_Detroit[16:22]

#for Charlotte
X_train_Charlotte = X_Charlotte[:16]
X_test_Charlotte = X_Charlotte[16:22]
y_train_Charlotte = y_Charlotte[:16]
y_test_Charlotte = y_Charlotte[16:22]

#for New York
X_train_NewYork = X_NewYork[:16]
X_test_NewYork = X_NewYork[16:22]
y_train_NewYork = y_NewYork[:16]
y_test_NewYork = y_NewYork[16:22]

#for Brooklyn
X_train_Brooklyn = X_Brooklyn[:16]
X_test_Brooklyn = X_Brooklyn[16:22]
y_train_Brooklyn = y_Brooklyn[:16]
y_test_Brooklyn = y_Brooklyn[16:22]

#for Chicago
X_train_Chicago = X_Chicago[:16]
X_test_Chicago = X_Chicago[16:22]
y_train_Chicago = y_Chicago[:16]
y_test_Chicago = y_Chicago[16:22]

#for Orlando
X_train_Orlando = X_Orlando[:16]
X_test_Orlando = X_Orlando[16:22]
y_train_Orlando = y_Orlando[:16]
y_test_Orlando = y_Orlando[16:22]

#for Atlanta
X_train_Atlanta = X_Atlanta[:16]
X_test_Atlanta = X_Atlanta[16:22]
y_train_Atlanta = y_Atlanta[:16]
y_test_Atlanta = y_Atlanta[16:22]

# %%
from sklearn.linear_model import LinearRegression

#Houston, Golden State, Portland, Oklahoma City, Utah

#training data for Houston for Team Performance 1
regressorHouston = LinearRegression()
regressorHouston.fit(X_train_Houston, y_train_Houston)

#training data for Golden State
regressorGoldenState = LinearRegression()
regressorGoldenState.fit(X_train_GoldenState, y_train_GoldenState)

#training data for Portland
regressorPortland = LinearRegression()
regressorPortland.fit(X_train_Portland, y_train_Portland)

#training data for Oklahoma City
regressorOklahomaCity = LinearRegression()
regressorOklahomaCity.fit(X_train_OklahomaCity, y_train_OklahomaCity)

#training data for Utah
regressorUtah = LinearRegression()
regressorUtah.fit(X_train_Utah, y_train_Utah)

#New Orleans, San Antonio, Minnesota, Denver, Los Angeles Clippers

#training data for New Orleans
regressorNewOrleans = LinearRegression()
regressorNewOrleans.fit(X_train_NewOrleans, y_train_NewOrleans)

#training data for San Antonio
regressorSanAntonio = LinearRegression()
regressorSanAntonio.fit(X_train_SanAntonio, y_train_SanAntonio)

#training data for Minnesota
regressorMinnesota = LinearRegression()
regressorMinnesota.fit(X_train_Minnesota, y_train_Minnesota)

#training data for Denver
regressorDenver = LinearRegression()
regressorDenver.fit(X_train_Denver, y_train_Denver)

#training data for Los Angeles Clippers
regressorLosAngelesClippers = LinearRegression()
regressorLosAngelesClippers.fit(X_train_LosAngelesClippers, y_train_LosAngelesClippers)

#Toronto, Boston, Philadelphia, Cleveland, Indiana

#training data for Toronto
regressorToronto = LinearRegression()
regressorToronto.fit(X_train_Toronto, y_train_Toronto)

#training data for Boston
regressorBoston = LinearRegression()
regressorBoston.fit(X_train_Boston, y_train_Boston)

#training data for Philadelphia
regressorPhiladelphia = LinearRegression()
regressorPhiladelphia.fit(X_train_Philadelphia, y_train_Philadelphia)

#training data for Cleveland
regressorCleveland = LinearRegression()
regressorCleveland.fit(X_train_Cleveland, y_train_Cleveland)

#training data for Indiana
regressorIndiana = LinearRegression()
regressorIndiana.fit(X_train_Indiana, y_train_Indiana)

#Los Angeles Lakers, Sacramento, Dallas, Memphis, Phoenix

#training data for Los Angeles Lakers
regressorLosAngelesLakers = LinearRegression()
regressorLosAngelesLakers.fit(X_train_LosAngelesLakers, y_train_LosAngelesLakers)

#training data for Sacramento
regressorSacramento = LinearRegression()
regressorSacramento.fit(X_train_Sacramento, y_train_Sacramento)

#training data for Dallas
regressorDallas = LinearRegression()
regressorDallas.fit(X_train_Dallas, y_train_Dallas)

#training data for Memphis
regressorMemphis = LinearRegression()
regressorMemphis.fit(X_train_Memphis, y_train_Memphis)

#training data for Phoenix
regressorPhoenix = LinearRegression()
regressorPhoenix.fit(X_train_Phoenix, y_train_Phoenix)

#Miami, Milwaukee, Washington, Detroit, Charlotte

#training data for Miami
regressorMiami = LinearRegression()
regressorMiami.fit(X_train_Miami, y_train_Miami)

#training data for Milwaukee
regressorMilwaukee = LinearRegression()
regressorMilwaukee.fit(X_train_Milwaukee, y_train_Milwaukee)

#training data for Washington
regressorWashington = LinearRegression()
regressorWashington.fit(X_train_Washington, y_train_Washington)

#training data for Detroit
regressorDetroit = LinearRegression()
regressorDetroit.fit(X_train_Detroit, y_train_Detroit)

#training data for Charlotte
regressorCharlotte = LinearRegression()
regressorCharlotte.fit(X_train_Charlotte, y_train_Charlotte)

#New York, Brooklyn, Chicago, Orlando, Atlanta

#training data for New York
regressorNewYork = LinearRegression()
regressorNewYork.fit(X_train_NewYork, y_train_NewYork)

#training data for Brooklyn
regressorBrooklyn = LinearRegression()
regressorBrooklyn.fit(X_train_Brooklyn, y_train_Brooklyn)

#training data for Chicago
regressorChicago = LinearRegression()
regressorChicago.fit(X_train_Chicago, y_train_Chicago)

#training data for Orlando
regressorOrlando = LinearRegression()
regressorOrlando.fit(X_train_Orlando, y_train_Orlando)

#training data for Atlanta
regressorAtlanta = LinearRegression()
regressorAtlanta.fit(X_train_Atlanta, y_train_Atlanta)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pd.DataFrame(list(zip(X_train_Houston, regressorHouston.coef_)), columns=['Features', 'Beta Coefficient'])
#based on team performance per instance
# Out:
#              Features  Beta Coefficient
# 0       3Ps Attempted          0.068786
# 1  Defensive Rebounds          0.200508
# 2      Average Points          0.967141
# 3           Attendees          0.000514
# 4     TEAM EFFICIENCY         -0.062356

# %%
pd.DataFrame(list(zip(X_train_GoldenState.columns, regressorGoldenState.coef_)), columns=['Features', 'Beta Coefficient'])
#stat with the highest factor in terms of magnitude is field goals for Golden State
# Out:
#              Features  Beta Coefficient
# 0       3Ps Attempted          0.124593
# 1  Defensive Rebounds          0.052901
# 2      Average Points         -0.718884
# 3           Attendees         -0.003926
# 4     TEAM EFFICIENCY          0.688746

# %%
pd.DataFrame(list(zip(X_train_Portland.columns, regressorPortland.coef_)))
#stat with the highest factor in terms of magnitude is field goals made for Portland
# Out:
#                     0         1
# 0       3Ps Attempted  0.081802
# 1  Defensive Rebounds -0.040904
# 2      Average Points  1.243061
# 3           Attendees  0.000021
# 4     TEAM EFFICIENCY -0.531238

# %%
pd.DataFrame(list(zip(X_train_OklahomaCity.columns, regressorOklahomaCity.coef_)))
#stat with the highest factor in terms of magnitude is the field goals made for Oklahoma City
# Out:
#                     0         1
# 0       3Ps Attempted  0.224288
# 1  Defensive Rebounds  0.603104
# 2      Average Points  0.199976
# 3           Attendees -0.003254
# 4     TEAM EFFICIENCY  0.273228

# %%
pd.DataFrame(list(zip(X_train_Utah.columns, regressorUtah.coef_)))
#stat with the highest factor in terms of magnitude is steals for Utah
# Out:
#                     0         1
# 0       3Ps Attempted -0.378951
# 1  Defensive Rebounds  0.339187
# 2      Average Points -0.259775
# 3           Attendees -0.001152
# 4     TEAM EFFICIENCY  0.460774

# %%
pd.DataFrame(list(zip(X_train_NewOrleans.columns, regressorNewOrleans.coef_)))
#stat with the highest factor in terms of magnitude is field goals made for New Orleans
# Out:
#                     0         1
# 0       3Ps Attempted -0.861316
# 1  Defensive Rebounds  1.274293
# 2      Average Points -0.847389
# 3           Attendees -0.014079
# 4     TEAM EFFICIENCY -0.091083

# %%
pd.DataFrame(list(zip(X_train_SanAntonio.columns, regressorSanAntonio.coef_)))
#stat with the highest factor in terms of magnitude is free throws made for San Antonio
# Out:
#                     0         1
# 0       3Ps Attempted  0.188975
# 1  Defensive Rebounds -0.455127
# 2      Average Points  0.330829
# 3           Attendees -0.001106
# 4     TEAM EFFICIENCY -0.183452

# %%
pd.DataFrame(list(zip(X_train_Minnesota.columns, regressorMinnesota.coef_)))
#stat with the highest factor in terms of magnitude is field goals made for Minnesota
# Out:
#                     0         1
# 0       3Ps Attempted -1.292422
# 1  Defensive Rebounds  1.527880
# 2      Average Points  0.704914
# 3           Attendees  0.000162
# 4     TEAM EFFICIENCY -0.843285

# %%
pd.DataFrame(list(zip(X_train_Denver.columns, regressorDenver.coef_)))
#stat with the highest factor in terms of magnitude is field goals made for Denver
# Out:
#                     0         1
# 0       3Ps Attempted -0.121272
# 1  Defensive Rebounds  0.187993
# 2      Average Points -0.675098
# 3           Attendees -0.000229
# 4     TEAM EFFICIENCY  0.694855

# %%
pd.DataFrame(list(zip(X_train_LosAngelesClippers.columns, regressorLosAngelesClippers.coef_)))
#stat with the highest factor in terms of magnitude is field goals made for Los Angeles Clippers
# Out:
#                     0         1
# 0       3Ps Attempted  0.018582
# 1  Defensive Rebounds  2.683284
# 2      Average Points  1.766506
# 3           Attendees  0.000515
# 4     TEAM EFFICIENCY -1.446433

# %%
pd.DataFrame(list(zip(X_train_Toronto.columns, regressorToronto.coef_)))
#stat with the highest factor in terms of magnitude is 3 pointers made for Toronto
# Out:
#                     0         1
# 0       3Ps Attempted -0.119708
# 1  Defensive Rebounds  0.790874
# 2      Average Points  4.217604
# 3           Attendees  0.000900
# 4     TEAM EFFICIENCY -3.605355

# %%
pd.DataFrame(list(zip(X_train_Boston.columns, regressorBoston.coef_)))
#stat with the highest factor in terms of magnitude is field goals made for Boston
# Out:
#                     0         1
# 0       3Ps Attempted  0.699023
# 1  Defensive Rebounds  1.895562
# 2      Average Points -0.015105
# 3           Attendees  0.002263
# 4     TEAM EFFICIENCY  0.585551

# %%
pd.DataFrame(list(zip(X_train_Philadelphia.columns, regressorPhiladelphia.coef_)))
#stat with the highest factor in terms of magnitude is offensive rebounds for Philadelphia
# Out:
#                     0         1
# 0       3Ps Attempted -0.045295
# 1  Defensive Rebounds  0.043268
# 2      Average Points  0.621480
# 3           Attendees -0.001045
# 4     TEAM EFFICIENCY -0.013198

# %%
pd.DataFrame(list(zip(X_train_Cleveland.columns, regressorCleveland.coef_)))
#stat with the highest factor in terms of magnitude is field goals made for Cleveland
# Out:
#                     0         1
# 0       3Ps Attempted -0.607877
# 1  Defensive Rebounds  0.860089
# 2      Average Points  0.064416
# 3           Attendees  0.001448
# 4     TEAM EFFICIENCY  0.081611

# %%
pd.DataFrame(list(zip(X_train_Indiana.columns, regressorIndiana.coef_)))
#stat with the highest factor in terms of magnitude is average points for Indiana
# Out:
#                     0         1
# 0       3Ps Attempted  0.780876
# 1  Defensive Rebounds  1.810784
# 2      Average Points  0.007065
# 3           Attendees  0.001652
# 4     TEAM EFFICIENCY  0.774803

# %%
pd.DataFrame(list(zip(X_train_LosAngelesLakers.columns, regressorLosAngelesLakers.coef_)))
#stat with the highest factor in terms of magnitude is total rebounds for Los Angeles Lakers
# Out:
#                     0         1
# 0       3Ps Attempted -1.461887
# 1  Defensive Rebounds -0.481987
# 2      Average Points -0.451458
# 3           Attendees  0.001462
# 4     TEAM EFFICIENCY  0.841165

# %%
pd.DataFrame(list(zip(X_train_Sacramento.columns, regressorSacramento.coef_)))
#stat with the highest factor in terms of magnitude is field goals made for Sacramento
# Out:
#                     0         1
# 0       3Ps Attempted  0.680539
# 1  Defensive Rebounds  0.749895
# 2      Average Points  0.369164
# 3           Attendees -0.000317
# 4     TEAM EFFICIENCY  0.120596

# %%
pd.DataFrame(list(zip(X_train_Dallas.columns, regressorDallas.coef_)))
#stat with the highest factor in terms of magnitude is offensive rebounds for Dallas
# Out:
#                     0         1
# 0       3Ps Attempted -0.345338
# 1  Defensive Rebounds  0.025482
# 2      Average Points -0.185438
# 3           Attendees -0.002767
# 4     TEAM EFFICIENCY  0.272401

# %%
pd.DataFrame(list(zip(X_train_Memphis.columns, regressorMemphis.coef_)))
#stat with the highest factor in terms of magnitude is field goals made for Memphis
# Out:
#                     0         1
# 0       3Ps Attempted  0.336768
# 1  Defensive Rebounds  0.718532
# 2      Average Points  0.219971
# 3           Attendees -0.002153
# 4     TEAM EFFICIENCY  0.214812

# %%
pd.DataFrame(list(zip(X_train_Phoenix.columns, regressorPhoenix.coef_)))
#stat with the highest factor in terms of magnitude is field goals made for Phoenix
# Out:
#                     0         1
# 0       3Ps Attempted  0.984797
# 1  Defensive Rebounds  0.944870
# 2      Average Points  0.199716
# 3           Attendees  0.001446
# 4     TEAM EFFICIENCY  0.764600

# %%
pd.DataFrame(list(zip(X_train_Miami.columns, regressorMiami.coef_)))
#stat with the highest factor in terms of magnitude is field goals made for Miami
# Out:
#                     0         1
# 0       3Ps Attempted  0.148479
# 1  Defensive Rebounds  0.678028
# 2      Average Points -1.214594
# 3           Attendees -0.001578
# 4     TEAM EFFICIENCY  0.951501

# %%
pd.DataFrame(list(zip(X_train_Milwaukee.columns, regressorMilwaukee.coef_)))
#stat with the highest factor in terms of magnitude is offensive rebounds for Milwaukee
# Out:
#                     0         1
# 0       3Ps Attempted -0.613307
# 1  Defensive Rebounds  0.006932
# 2      Average Points -0.473221
# 3           Attendees -0.001925
# 4     TEAM EFFICIENCY  0.470094

# %%
pd.DataFrame(list(zip(X_train_Washington.columns, regressorWashington.coef_)))
#stat with the highest factor in terms of magnitude is offensive rebounds for Washington
# Out:
#                     0         1
# 0       3Ps Attempted  0.701548
# 1  Defensive Rebounds -0.223105
# 2      Average Points  1.030226
# 3           Attendees -0.000848
# 4     TEAM EFFICIENCY -0.722679

# %%
pd.DataFrame(list(zip(X_train_Detroit.columns, regressorDetroit.coef_)))
#stat with the highest factor in terms of magnitude is defensive rebounds for Detroit
# Out:
#                     0         1
# 0       3Ps Attempted -1.551304
# 1  Defensive Rebounds  1.290316
# 2      Average Points -0.329869
# 3           Attendees -0.001082
# 4     TEAM EFFICIENCY -0.079486

# %%
pd.DataFrame(list(zip(X_train_Charlotte.columns, regressorCharlotte.coef_)))
#stat with the highest factor in terms of magnitude is field goals made for Charlotte
# Out:
#                     0         1
# 0       3Ps Attempted  0.124562
# 1  Defensive Rebounds -0.411696
# 2      Average Points  0.361486
# 3           Attendees  0.000064
# 4     TEAM EFFICIENCY -0.075279

# %%
pd.DataFrame(list(zip(X_train_NewYork.columns, regressorNewYork.coef_)))
#stat with the highest factor in terms of magnitude is field goals made for New York
# Out:
#                     0         1
# 0       3Ps Attempted  0.307305
# 1  Defensive Rebounds -0.462834
# 2      Average Points  0.023921
# 3           Attendees  0.002683
# 4     TEAM EFFICIENCY  0.239291

# %%
pd.DataFrame(list(zip(X_train_Brooklyn.columns, regressorBrooklyn.coef_)))
#stat with the highest factor in terms of magnitude is average points for Brooklyn
# Out:
#                     0         1
# 0       3Ps Attempted  1.015471
# 1  Defensive Rebounds  0.153816
# 2      Average Points  0.005600
# 3           Attendees  0.000078
# 4     TEAM EFFICIENCY  0.156607

# %%
pd.DataFrame(list(zip(X_train_Chicago.columns, regressorChicago.coef_)))
#stat with the highest factor in terms of magnitude is personal fouls for Chicago
# Out:
#                     0         1
# 0       3Ps Attempted  0.077115
# 1  Defensive Rebounds  1.673764
# 2      Average Points -0.420451
# 3           Attendees -0.001655
# 4     TEAM EFFICIENCY  0.330138

# %%
pd.DataFrame(list(zip(X_train_Orlando.columns, regressorOrlando.coef_)))
#stat with the highest factor in terms of magnitude is steals for Orlando
# Out:
#                     0         1
# 0       3Ps Attempted -0.506599
# 1  Defensive Rebounds -1.846854
# 2      Average Points -0.753332
# 3           Attendees -0.001307
# 4     TEAM EFFICIENCY  0.611242

# %%
pd.DataFrame(list(zip(X_train_Atlanta.columns, regressorAtlanta.coef_)))
#stat with the highest factor in terms of magnitude is defensive rebounds for Atlanta
# Out:
#                     0         1
# 0       3Ps Attempted -0.805503
# 1  Defensive Rebounds -0.332645
# 2      Average Points -0.818255
# 3           Attendees  0.000999
# 4     TEAM EFFICIENCY  1.059661

# %%
#making predictions for all teams

#making predictions for Houston
y_pred_Houston = regressorHouston.predict(X_test_Houston)

#making predictions for Golden State
y_pred_GoldenState = regressorGoldenState.predict(X_test_GoldenState)

#making predictions for Portland
y_pred_Portland = regressorPortland.predict(X_test_Portland)

#making predictions for Oklahoma City
y_pred_OklahomaCity = regressorOklahomaCity.predict(X_test_OklahomaCity)

#making predictions for Utah
y_pred_Utah = regressorUtah.predict(X_test_Utah)

#making predictions for New Orleans
y_pred_NewOrleans = regressorNewOrleans.predict(X_test_NewOrleans)

#making predictions for San Antonio
y_pred_SanAntonio = regressorSanAntonio.predict(X_test_SanAntonio)

#making predictions for Minnesota
y_pred_Minnesota = regressorMinnesota.predict(X_test_Minnesota)

#making predictions for Denver
y_pred_Denver = regressorDenver.predict(X_test_Denver)

#making predictions for Los Angeles Clippers
y_pred_LosAngelesClippers = regressorLosAngelesClippers.predict(X_test_LosAngelesClippers)

#making predictions for Toronto
y_pred_Toronto = regressorToronto.predict(X_test_Toronto)

#making predictions for Boston
y_pred_Boston = regressorBoston.predict(X_test_Boston)

#making predictions for Philadelphia
y_pred_Philadelphia = regressorPhiladelphia.predict(X_test_Philadelphia)

#making predictions for Cleveland
y_pred_Cleveland = regressorCleveland.predict(X_test_Cleveland)

#making predictions for Indiana
y_pred_Indiana = regressorIndiana.predict(X_test_Indiana)

#making predictions for Los Angeles Lakers
y_pred_LosAngelesLakers = regressorLosAngelesLakers.predict(X_test_LosAngelesLakers)

#making predictions for Sacramento
y_pred_Sacramento = regressorSacramento.predict(X_test_Sacramento)

#making predictions for Dallas
y_pred_Dallas = regressorDallas.predict(X_test_Dallas)

#making predictions for Memphis
y_pred_Memphis = regressorMemphis.predict(X_test_Memphis)

#making predictions for Phoenix
y_pred_Phoenix = regressorPhoenix.predict(X_test_Phoenix)

#making predictions for Miami
y_pred_Miami = regressorMiami.predict(X_test_Miami)

#making predictions for Milwaukee
y_pred_Milwaukee = regressorMilwaukee.predict(X_test_Milwaukee)

#making predictions for Washington
y_pred_Washington = regressorWashington.predict(X_test_Washington)

#making predictions for Detroit
y_pred_Detroit = regressorDetroit.predict(X_test_Detroit)

#making predictions for Charlotte
y_pred_Charlotte = regressorCharlotte.predict(X_test_Charlotte)

#making predictions for New York
y_pred_NewYork = regressorNewYork.predict(X_test_NewYork)

#making predictions for Brooklyn
y_pred_Brooklyn = regressorBrooklyn.predict(X_test_Brooklyn)

#making predictions for Chicago
y_pred_Chicago = regressorChicago.predict(X_test_Chicago)

#making predictions for Orlando
y_pred_Orlando = regressorOrlando.predict(X_test_Orlando)

#making predictions for Atlanta
y_pred_Atlanta = regressorAtlanta.predict(X_test_Atlanta)

# %%
#see data frame for actual vs predicted for Houston for Team Performance 1
actual_predicted_Houston = pd.DataFrame({'Actual Team Efficiency': y_test_Houston, 'Predicted Team Efficiency': y_pred_Houston})

print(((y_pred_Houston- y_test_Houston) / y_test_Houston) * 100)
print()
print(np.mean(((y_pred_Houston- y_test_Houston) / y_test_Houston) * 100))
print()
print(actual_predicted_Houston)
# Out:
# 16     9.588724
# 17    -7.481214
# 18   -12.249615
# 19    -7.880493
# 20    -5.107039
# 21    28.719473
# Name: Team Performance, dtype: float64
#
# 0.9316395161512337
#
#     Actual Team Efficiency  Predicted Team Efficiency
# 16                      50                  54.794362
# 17                      50                  46.259393
# 18                      49                  42.997689
# 19                      48                  44.217364
# 20                      48                  45.548621
# 21                      50                  64.359737

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_Houston)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_Houston)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                    49.166667                       49.696194
#
#    Difference Between Target and Predicted
# 0                                 0.529528

# %%
#see data frame for actual vs predicted for Golden State
actual_predicted_GoldenState = pd.DataFrame({'Actual Team Efficiency': y_test_GoldenState, 'Predicted Team Efficiency': y_pred_GoldenState})

print(((y_pred_GoldenState- y_test_GoldenState) / y_test_GoldenState) * 100)
print()
print(np.mean(((y_pred_GoldenState- y_test_GoldenState) / y_test_GoldenState) * 100))
print()
print(actual_predicted_GoldenState)
# Out:
# 38    4.454492
# 39    7.555098
# 40    6.290182
# 41   -1.191131
# 42    4.455515
# 43    9.425403
# Name: Team Performance, dtype: float64
#
# 5.164926643079769
#
#     Actual Team Efficiency  Predicted Team Efficiency
# 38                      91                  95.053588
# 39                      90                  96.799589
# 40                      90                  95.661164
# 41                      89                  87.939893
# 42                      88                  91.920853
# 43                      89                  97.388609

# %%
difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_GoldenState)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_GoldenState)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                         89.5                       94.127283
#
#    Difference Between Target and Predicted
# 0                                 4.627283

# %%
#see data frame for actual vs predicted for Portland
actual_predicted_Portland = pd.DataFrame({'Actual Team Efficiency': y_test_Portland, 'Predicted Team Efficiency': y_pred_Portland})

print(((y_pred_Portland- y_test_Portland) / y_test_Portland) * 100)
print()
print(np.mean(((y_pred_Portland- y_test_Portland) / y_test_Portland) * 100))
print()
print(actual_predicted_Portland)
# Out:
# 60     5.664082
# 61    -1.442204
# 62    -7.367583
# 63   -10.253083
# 64   -11.596220
# 65   -10.519982
# Name: Team Performance, dtype: float64
#
# -5.919164913490152
#
#     Actual Team Efficiency  Predicted Team Efficiency
# 60                      52                  54.945322
# 61                      51                  50.264476
# 62                      50                  46.316209
# 63                      52                  46.668397
# 64                      53                  46.854003
# 65                      53                  47.424410

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_Portland)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_Portland)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                    51.833333                        48.74547
#
#    Difference Between Target and Predicted
# 0                                -3.087864

# %%
#see data frame for actual vs predicted for Oklahoma City
actual_predicted_OklahomaCity = pd.DataFrame({'Actual Team Efficiency': y_test_OklahomaCity, 'Predicted Team Efficiency': y_pred_OklahomaCity})

actual_predicted_OklahomaCity

print(((y_pred_OklahomaCity- y_test_OklahomaCity) / y_test_OklahomaCity) * 100)
print()
print(np.mean(((y_pred_OklahomaCity- y_test_OklahomaCity) / y_test_OklahomaCity) * 100))
print()
print(actual_predicted_OklahomaCity)
# Out:
# 82    -3.335829
# 83     5.562687
# 84    -0.951193
# 85    -5.537209
# 86    11.766628
# 87     1.910839
# Name: Team Performance, dtype: float64
#
# 1.5693204815266188
#
#     Actual Team Efficiency  Predicted Team Efficiency
# 82                      67                  64.764995
# 83                      68                  71.782627
# 84                      69                  68.343676
# 85                      69                  65.179326
# 86                      68                  76.001307
# 87                      67                  68.280262

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_OklahomaCity)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_OklahomaCity)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                         68.0                       69.058699
#
#    Difference Between Target and Predicted
# 0                                 1.058699

# %%
#see data frame for actual vs predicted for Utah
actual_predicted_Utah = pd.DataFrame({'Actual Team Efficiency': y_test_Utah, 'Predicted Team Efficiency': y_pred_Utah})

print(((y_pred_Utah- y_test_Utah) / y_test_Utah) * 100)
print()
print(np.mean(((y_pred_Utah- y_test_Utah) / y_test_Utah) * 100))
print()
print(actual_predicted_Utah)
# Out:
# 104    2.516381
# 105   -3.659029
# 106   -4.251677
# 107   -3.520223
# 108   -8.902257
# 109   -3.156454
# Name: Team Performance, dtype: float64
#
# -3.4955430313927507
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 104                      47                  48.182699
# 105                      48                  46.243666
# 106                      49                  46.916678
# 107                      50                  48.239889
# 108                      49                  44.637894
# 109                      48                  46.484902

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_Utah)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_Utah)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                         48.5                       46.784288
#
#    Difference Between Target and Predicted
# 0                                -1.715712

# %%
#see data frame for actual vs predicted for New Orleans
actual_predicted_NewOrleans = pd.DataFrame({'Actual Team Efficiency': y_test_NewOrleans, 'Predicted Team Efficiency': y_pred_NewOrleans})

print(((y_pred_NewOrleans- y_test_NewOrleans) / y_test_NewOrleans) * 100)
print()
print(np.mean(((y_pred_NewOrleans- y_test_NewOrleans) / y_test_NewOrleans) * 100))
print()
print(actual_predicted_NewOrleans)
# Out:
# 126   -55.514883
# 127    -4.229945
# 128    43.310651
# 129    -6.457204
# 130    56.724067
# 131   -21.446633
# Name: Team Performance, dtype: float64
#
# 2.0643422636510134
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 126                      37                  16.459493
# 127                      37                  35.434920
# 128                      36                  51.591834
# 129                      38                  35.546262
# 130                      37                  57.987905
# 131                      36                  28.279212

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_NewOrleans)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_NewOrleans)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                    36.833333                       37.549938
#
#    Difference Between Target and Predicted
# 0                                 0.716605

# %%
#see data frame for actual vs predicted for San Antonio
actual_predicted_SanAntonio = pd.DataFrame({'Actual Team Efficiency': y_test_SanAntonio, 'Predicted Team Efficiency': y_pred_SanAntonio})

# actual_predicted_SanAntonio

print(((y_pred_SanAntonio- y_test_SanAntonio) / y_test_SanAntonio) * 100)
print()
print(np.mean(((y_pred_SanAntonio- y_test_SanAntonio) / y_test_SanAntonio) * 100))
print()
print(actual_predicted_SanAntonio)
# Out:
# 148   -2.961639
# 149   -5.401786
# 150    1.225067
# 151   -2.790957
# 152   -0.503783
# 153   -1.000558
# Name: Team Performance, dtype: float64
#
# -1.9056092648445553
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 148                      85                  82.482606
# 149                      84                  79.462500
# 150                      83                  84.016806
# 151                      84                  81.655596
# 152                      82                  81.586898
# 153                      81                  80.189548

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_SanAntonio)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_SanAntonio)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                    83.166667                       81.565659
#
#    Difference Between Target and Predicted
# 0                                -1.601008

# %%
#see data frame for actual vs predicted for Minnesota
actual_predicted_Minnesota = pd.DataFrame({'Actual Team Efficiency': y_test_Minnesota, 'Predicted Team Efficiency': y_pred_Minnesota})

print(((y_pred_Minnesota- y_test_Minnesota) / y_test_Minnesota) * 100)
print()
print(np.mean(((y_pred_Minnesota- y_test_Minnesota) / y_test_Minnesota) * 100))
print()
print(actual_predicted_Minnesota)
# Out:
# 170    18.194954
# 171   -49.811950
# 172     4.756204
# 173   -16.693543
# 174   -13.590919
# 175   -54.610983
# Name: Team Performance, dtype: float64
#
# -18.626039466652475
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 170                      31                  36.640436
# 171                      31                  15.558295
# 172                      32                  33.521985
# 173                      32                  26.658066
# 174                      34                  29.379088
# 175                      35                  15.886156

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_Minnesota)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_Minnesota)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                         32.5                       26.274004
#
#    Difference Between Target and Predicted
# 0                                -6.225996

# %%
#see data frame for actual vs predicted for Denver
actual_predicted_Denver = pd.DataFrame({'Actual Team Efficiency': y_test_Denver, 'Predicted Team Efficiency': y_pred_Denver})

print(((y_pred_Denver- y_test_Denver) / y_test_Denver) * 100)
print()
print(np.mean(((y_pred_Denver- y_test_Denver) / y_test_Denver) * 100))
print()
print(actual_predicted_Denver)
# Out:
# 192    4.793349
# 193   -8.450650
# 194   -3.734427
# 195   -8.114987
# 196    9.858128
# 197    2.520320
# Name: Team Performance, dtype: float64
#
# -0.5213778761951081
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 192                      41                  42.965273
# 193                      41                  37.535233
# 194                      42                  40.431541
# 195                      42                  38.591705
# 196                      40                  43.943251
# 197                      40                  41.008128

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_Denver)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_Denver)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                         41.0                       40.745855
#
#    Difference Between Target and Predicted
# 0                                -0.254145

# %%
#see data frame for actual vs predicted for Los Angeles Clippers 
actual_predicted_LosAngelesClippers = pd.DataFrame({'Actual Team Efficiency': y_test_LosAngelesClippers, 'Predicted Team Efficiency': y_pred_LosAngelesClippers})

print(((y_pred_LosAngelesClippers- y_test_LosAngelesClippers) / y_test_LosAngelesClippers) * 100)
print()
print(np.mean(((y_pred_LosAngelesClippers- y_test_LosAngelesClippers) / y_test_LosAngelesClippers) * 100))
print()
print(actual_predicted_LosAngelesClippers)
# Out:
# 214   -36.974558
# 215     3.283253
# 216   -21.636101
# 217   -29.444904
# 218     4.376986
# 219   -14.968618
# Name: Team Performance, dtype: float64
#
# -15.89399036937293
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 214                      64                  40.336283
# 215                      61                  63.002784
# 216                      63                  49.369257
# 217                      63                  44.449710
# 218                      64                  66.801271
# 219                      64                  54.420084

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_LosAngelesClippers)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_LosAngelesClippers)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                    63.166667                       53.063232
#
#    Difference Between Target and Predicted
# 0                               -10.103435

# %%
#see data frame for actual vs predicted for Toronto
actual_predicted_Toronto = pd.DataFrame({'Actual Team Efficiency': y_test_Toronto, 'Predicted Team Efficiency': y_pred_Toronto})

print(((y_pred_Toronto- y_test_Toronto) / y_test_Toronto) * 100)
print()
print(np.mean(((y_pred_Toronto- y_test_Toronto) / y_test_Toronto) * 100))
print()
print(actual_predicted_Toronto)
# Out:
# 236    10.900790
# 237   -10.938082
# 238    -2.142744
# 239   -26.948571
# 240    10.561998
# 241   -43.651789
# Name: Team Performance, dtype: float64
#
# -10.369733093287056
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 236                      68                  75.412537
# 237                      68                  60.562104
# 238                      67                  65.564362
# 239                      67                  48.944457
# 240                      67                  74.076539
# 241                      68                  38.316783

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_Toronto)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_Toronto)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                         67.5                       60.479464
#
#    Difference Between Target and Predicted
# 0                                -7.020536

# %%
#see data frame for actual vs predicted for Boston
actual_predicted_Boston = pd.DataFrame({'Actual Team Efficiency': y_test_Boston, 'Predicted Team Efficiency': y_pred_Boston})

print(((y_pred_Boston- y_test_Boston) / y_test_Boston) * 100)
print()
print(np.mean(((y_pred_Boston- y_test_Boston) / y_test_Boston) * 100))
print()
print(actual_predicted_Boston)
# Out:
# 258   -11.711232
# 259   -21.286957
# 260    -5.438809
# 261   -15.959322
# 262     4.686417
# 263   -25.946032
# Name: Team Performance, dtype: float64
#
# -12.609322443200726
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 258                      58                  51.207485
# 259                      57                  44.866434
# 260                      58                  54.845491
# 261                      57                  47.903187
# 262                      59                  61.764986
# 263                      58                  42.951302

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_Boston)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_Boston)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                    57.833333                       50.589814
#
#    Difference Between Target and Predicted
# 0                                -7.243519

# %%
#see data frame for actual vs predicted for Philadelphia
actual_predicted_Philadelphia = pd.DataFrame({'Actual Team Efficiency': y_test_Philadelphia, 'Predicted Team Efficiency': y_pred_Philadelphia})

print(((y_pred_Philadelphia- y_test_Philadelphia) / y_test_Philadelphia) * 100)
print()
print(np.mean(((y_pred_Philadelphia- y_test_Philadelphia) / y_test_Philadelphia) * 100))
print()
print(actual_predicted_Philadelphia)
# Out:
# 280    13.048773
# 281   -22.830116
# 282   -46.258859
# 283   -68.526541
# 284    -0.884006
# 285   -36.659315
# Name: Team Performance, dtype: float64
#
# -27.018344250190466
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 280                      13                  14.696340
# 281                      12                   9.260386
# 282                      12                   6.448937
# 283                      11                   3.462081
# 284                      12                  11.893919
# 285                      12                   7.600882

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_Philadelphia)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_Philadelphia)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                         12.0                        8.893758
#
#    Difference Between Target and Predicted
# 0                                -3.106242

# %%
#see data frame for actual vs predicted for Cleveland
actual_predicted_Cleveland= pd.DataFrame({'Actual Team Efficiency': y_test_Cleveland, 'Predicted Team Efficiency': y_pred_Cleveland})

print(((y_pred_Cleveland- y_test_Cleveland) / y_test_Cleveland) * 100)
print()
print(np.mean(((y_pred_Cleveland- y_test_Cleveland) / y_test_Cleveland) * 100))
print()
print(actual_predicted_Cleveland)
# Out:
# 302    -9.735975
# 303    -1.249291
# 304    -5.575363
# 305     6.393378
# 306    -5.090469
# 307    14.857553
# Name: Team Performance, dtype: float64
#
# -0.0666944508531051
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 302                      72                  64.990098
# 303                      71                  70.113003
# 304                      70                  66.097246
# 305                      71                  75.539298
# 306                      70                  66.436672
# 307                      70                  80.400287

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_Cleveland)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_Cleveland)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                    70.666667                       70.596101
#
#    Difference Between Target and Predicted
# 0                                -0.070566

# %%
#see data frame for actual vs predicted for Indiana
actual_predicted_Indiana = pd.DataFrame({'Actual Team Efficiency': y_test_Indiana, 'Predicted Team Efficiency': y_pred_Indiana})

print(((y_pred_Indiana - y_test_Indiana) / y_test_Indiana) * 100)
print()
print(np.mean(((y_pred_Indiana- y_test_Indiana) / y_test_Indiana) * 100))
print()
print(actual_predicted_Indiana)
# Out:
# 324    -8.573281
# 325    -2.822626
# 326    10.471958
# 327     9.422388
# 328    12.388177
# 329    36.205496
# Name: Team Performance, dtype: float64
#
# 9.515351916937183
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 324                      53                  48.456161
# 325                      52                  50.532235
# 326                      53                  58.550138
# 327                      52                  56.899642
# 328                      53                  59.565734
# 329                      54                  73.550968

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_Indiana)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_Indiana)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                    52.833333                       57.925813
#
#    Difference Between Target and Predicted
# 0                                 5.092479

# %%
#see data frame for actual vs predicted for Los Angeles Lakers
actual_predicted_LosAngelesLakers = pd.DataFrame({'Actual Team Efficiency': y_test_LosAngelesLakers, 'Predicted Team Efficiency': y_pred_LosAngelesLakers})

print(((y_pred_LosAngelesLakers- y_test_LosAngelesLakers) / y_test_LosAngelesLakers) * 100)
print()
print(np.mean(((y_pred_LosAngelesLakers- y_test_LosAngelesLakers) / y_test_LosAngelesLakers) * 100))
print()
print(actual_predicted_LosAngelesLakers)
# Out:
# 346     5.614736
# 347   -20.539058
# 348   -35.336144
# 349    -5.785429
# 350   -15.018923
# 351   -71.583768
# Name: Team Performance, dtype: float64
#
# -23.774764133512928
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 346                      20                  21.122947
# 347                      21                  16.686798
# 348                      20                  12.932771
# 349                      21                  19.785060
# 350                      20                  16.996215
# 351                      20                   5.683246

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_LosAngelesLakers)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_LosAngelesLakers)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                    20.333333                       15.534506
#
#    Difference Between Target and Predicted
# 0                                -4.798827

# %%
#see data frame for actual vs predicted for Sacramento
actual_predicted_Sacramento = pd.DataFrame({'Actual Team Efficiency': y_test_Sacramento, 'Predicted Team Efficiency': y_pred_Sacramento})

print(((y_pred_Sacramento- y_test_Sacramento) / y_test_Sacramento) * 100)
print()
print(np.mean(((y_pred_Sacramento- y_test_Sacramento) / y_test_Sacramento) * 100))
print()
print(actual_predicted_Sacramento)
# Out:
# 368   -17.059415
# 369   -14.834610
# 370     7.488097
# 371   -22.787913
# 372   -13.777211
# 373   -11.819879
# Name: Team Performance, dtype: float64
#
# -12.131821835077266
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 368                      38                  31.517422
# 369                      38                  32.362848
# 370                      39                  41.920358
# 371                      39                  30.112714
# 372                      39                  33.626888
# 373                      40                  35.272048

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_Sacramento)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_Sacramento)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                    38.833333                        34.13538
#
#    Difference Between Target and Predicted
# 0                                -4.697954

# %%
#see data frame for actual vs predicted for Dallas
actual_predicted_Dallas = pd.DataFrame({'Actual Team Efficiency': y_test_Dallas, 'Predicted Team Efficiency': y_pred_Dallas})


print(((y_pred_Dallas- y_test_Dallas) / y_test_Dallas) * 100)
print()
print(np.mean(((y_pred_Dallas- y_test_Dallas) / y_test_Dallas) * 100))
print()
print(actual_predicted_Dallas)
# Out:
# 390    11.975824
# 391     6.580201
# 392    16.910315
# 393    16.456813
# 394     4.468713
# 395    -3.481857
# Name: Team Performance, dtype: float64
#
# 8.818334779904903
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 390                      50                  55.987912
# 391                      50                  53.290101
# 392                      47                  54.947848
# 393                      50                  58.228406
# 394                      51                  53.279044
# 395                      51                  49.224253

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_Dallas)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_Dallas)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                    49.833333                       54.159594
#
#    Difference Between Target and Predicted
# 0                                 4.326261

# %%
#see data frame for actual vs predicted for Memphis
actual_predicted_Memphis = pd.DataFrame({'Actual Team Efficiency': y_test_Memphis, 'Predicted Team Efficiency': y_pred_Memphis})


print(((y_pred_Memphis- y_test_Memphis) / y_test_Memphis) * 100)
print()
print(np.mean(((y_pred_Memphis- y_test_Memphis) / y_test_Memphis) * 100))
print()
print(actual_predicted_Memphis)
# Out:
# 412   -14.523732
# 413    -1.829871
# 414   -18.732758
# 415     0.008109
# 416    -1.848576
# 417   -16.198039
# Name: Team Performance, dtype: float64
#
# -8.85414442266749
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 412                      57                  48.721473
# 413                      57                  55.956974
# 414                      55                  44.696983
# 415                      53                  53.004298
# 416                      52                  51.038740
# 417                      51                  42.739000

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_Memphis)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_Memphis)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                    54.166667                       49.359578
#
#    Difference Between Target and Predicted
# 0                                -4.807089

# %%
#see data frame for actual vs predicted for Phoenix
actual_predicted_Phoenix = pd.DataFrame({'Actual Team Efficiency': y_test_Phoenix, 'Predicted Team Efficiency': y_pred_Phoenix})

print(((y_pred_Phoenix- y_test_Phoenix) / y_test_Phoenix) * 100)
print()
print(np.mean(((y_pred_Phoenix- y_test_Phoenix) / y_test_Phoenix) * 100))
print()
print(actual_predicted_Phoenix)
# Out:
# 434    79.773571
# 435    10.312370
# 436    72.504335
# 437    33.601352
# 438    53.944402
# 439    94.354558
# Name: Team Performance, dtype: float64
#
# 57.415097876606275
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 434                      26                  46.741128
# 435                      27                  29.784340
# 436                      27                  46.576170
# 437                      26                  34.736351
# 438                      26                  40.025545
# 439                      28                  54.419276

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_Phoenix)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_Phoenix)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                    26.666667                       42.047135
#
#    Difference Between Target and Predicted
# 0                                15.380468

# %%
#see data frame for actual vs predicted for Miami
actual_predicted_Miami = pd.DataFrame({'Actual Team Efficiency': y_test_Miami, 'Predicted Team Efficiency': y_pred_Miami})


print(((y_pred_Miami- y_test_Miami) / y_test_Miami) * 100)
print()
print(np.mean(((y_pred_Miami- y_test_Miami) / y_test_Miami) * 100))
print()
print(actual_predicted_Miami)
# Out:
# 456   -12.603590
# 457    -2.835613
# 458     2.486196
# 459    -6.551777
# 460    -8.166104
# 461    -3.569342
# Name: Team Performance, dtype: float64
#
# -5.206705216172789
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 456                      58                  50.689918
# 457                      58                  56.355344
# 458                      58                  59.441993
# 459                      57                  53.265487
# 460                      58                  53.263659
# 461                      58                  55.929782

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_Miami)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_Miami)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                    57.833333                       54.824364
#
#    Difference Between Target and Predicted
# 0                                -3.008969

# %%
#see data frame for actual vs predicted for Milwaukee
actual_predicted_Milwaukee = pd.DataFrame({'Actual Team Efficiency': y_test_Milwaukee, 'Predicted Team Efficiency': y_pred_Milwaukee})

print(((y_pred_Milwaukee - y_test_Milwaukee) / y_test_Milwaukee) * 100)
print()
print(np.mean(((y_pred_Milwaukee- y_test_Milwaukee) / y_test_Milwaukee) * 100))
print()
print(actual_predicted_Milwaukee)
# Out:
# 478     6.566439
# 479    24.670755
# 480    -1.136533
# 481     4.370495
# 482     1.797530
# 483   -18.700147
# Name: Team Performance, dtype: float64
#
# 2.9280898171039844
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 478                      43                  45.823569
# 479                      42                  52.361717
# 480                      41                  40.534022
# 481                      42                  43.835608
# 482                      40                  40.719012
# 483                      40                  32.519941

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_Milwaukee)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_Milwaukee)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                    41.333333                       42.632311
#
#    Difference Between Target and Predicted
# 0                                 1.298978

# %%
#see data frame for actual vs predicted for Washington
actual_predicted_Washington = pd.DataFrame({'Actual Team Efficiency': y_test_Washington, 'Predicted Team Efficiency': y_pred_Washington})

print(((y_pred_Washington - y_test_Washington) / y_test_Washington) * 100)
print()
print(np.mean(((y_pred_Washington- y_test_Washington) / y_test_Washington) * 100))
print()
print(actual_predicted_Washington)
# Out:
# 500    2.702854
# 501    1.973646
# 502    2.842842
# 503    7.149637
# 504    2.277181
# 505    1.189182
# Name: Team Performance, dtype: float64
#
# 3.0225569796508647
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 500                      47                  48.270342
# 501                      50                  50.986823
# 502                      49                  50.392993
# 503                      48                  51.431826
# 504                      48                  49.093047
# 505                      50                  50.594591

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_Washington)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_Washington)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                    48.666667                        50.12827
#
#    Difference Between Target and Predicted
# 0                                 1.461603

# %%
#see data frame for actual vs predicted for Detroit
actual_predicted_Detroit = pd.DataFrame({'Actual Team Efficiency': y_test_Detroit, 'Predicted Team Efficiency': y_pred_Detroit})

print(((y_pred_Detroit - y_test_Detroit) / y_test_Detroit) * 100)
print()
print(np.mean(((y_pred_Detroit- y_test_Detroit) / y_test_Detroit) * 100))
print()
print(actual_predicted_Detroit)
# Out:
# 522    15.072031
# 523     5.029303
# 524     3.022281
# 525    18.534645
# 526    13.535065
# 527    -4.618561
# Name: Team Performance, dtype: float64
#
# 8.429127339212968
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 522                      50                  57.536015
# 523                      51                  53.564945
# 524                      53                  54.601809
# 525                      52                  61.638016
# 526                      53                  60.173585
# 527                      53                  50.552162

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_Detroit)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_Detroit)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                         52.0                       56.344422
#
#    Difference Between Target and Predicted
# 0                                 4.344422

# %%
#see data frame for actual vs predicted for Charlotte
actual_predicted_Charlotte = pd.DataFrame({'Actual Team Efficiency': y_test_Charlotte, 'Predicted Team Efficiency': y_pred_Charlotte})

print(((y_pred_Charlotte - y_test_Charlotte) / y_test_Charlotte) * 100)
print()
print(np.mean(((y_pred_Charlotte- y_test_Charlotte) / y_test_Charlotte) * 100))
print()
print(actual_predicted_Charlotte)
# Out:
# 544    -8.409146
# 545   -13.090620
# 546    -9.263120
# 547   -19.847720
# 548    -9.099312
# 549   -11.933905
# Name: Team Performance, dtype: float64
#
# -11.940637177213098
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 544                      56                  51.290878
# 545                      57                  49.538347
# 546                      57                  51.720021
# 547                      57                  45.686799
# 548                      58                  52.722399
# 549                      58                  51.078335

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_Charlotte)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_Charlotte)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                    57.166667                       50.339463
#
#    Difference Between Target and Predicted
# 0                                -6.827203

# %%
#see data frame for actual vs predicted for New York
actual_predicted_NewYork = pd.DataFrame({'Actual Team Efficiency': y_test_NewYork, 'Predicted Team Efficiency': y_pred_NewYork})

print(((y_pred_NewYork - y_test_NewYork) / y_test_NewYork) * 100)
print()
print(np.mean(((y_pred_NewYork- y_test_NewYork) / y_test_NewYork) * 100))
print()
print(actual_predicted_NewYork)
# Out:
# 566     1.477610
# 567    12.736344
# 568    23.500285
# 569    13.255402
# 570    24.934033
# 571     4.628975
# Name: Team Performance, dtype: float64
#
# 13.422108059597006
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 566                      40                  40.591044
# 567                      40                  45.094538
# 568                      41                  50.635117
# 569                      39                  44.169607
# 570                      39                  48.724273
# 571                      39                  40.805300

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_NewYork)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_NewYork)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                    39.666667                       45.003313
#
#    Difference Between Target and Predicted
# 0                                 5.336646

# %%
#see data frame for actual vs predicted for Brooklyn
actual_predicted_Brooklyn = pd.DataFrame({'Actual Team Efficiency': y_test_Brooklyn, 'Predicted Team Efficiency': y_pred_Brooklyn})

print(((y_pred_Brooklyn - y_test_Brooklyn) / y_test_Brooklyn) * 100)
print()
print(np.mean(((y_pred_Brooklyn- y_test_Brooklyn) / y_test_Brooklyn) * 100))
print()
print(actual_predicted_Brooklyn)
# Out:
# 588     5.838811
# 589   -11.590055
# 590   -19.946404
# 591    -7.414967
# 592     1.605868
# 593    49.674014
# Name: Team Performance, dtype: float64
#
# 3.027877705752536
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 588                      28                  29.634867
# 589                      27                  23.870685
# 590                      28                  22.415007
# 591                      27                  24.997959
# 592                      26                  26.417526
# 593                      25                  37.418504

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_Brooklyn)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_Brooklyn)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                    26.833333                       27.459091
#
#    Difference Between Target and Predicted
# 0                                 0.625758

# %%
#see data frame for actual vs predicted for Chicago
actual_predicted_Chicago = pd.DataFrame({'Actual Team Efficiency': y_test_Chicago, 'Predicted Team Efficiency': y_pred_Chicago})


      
print(((y_pred_Chicago - y_test_Chicago) / y_test_Chicago) * 100)
print()
print(np.mean(((y_pred_Chicago- y_test_Chicago) / y_test_Chicago) * 100))
print()
print(actual_predicted_Chicago)
# Out:
# 610     3.510335
# 611    -4.064679
# 612     5.498305
# 613    15.566573
# 614    11.504551
# 615     7.130124
# Name: Team Performance, dtype: float64
#
# 6.524201553491558
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 610                      50                  51.755168
# 611                      51                  48.927014
# 612                      49                  51.694169
# 613                      50                  57.783287
# 614                      49                  54.637230
# 615                      51                  54.636363

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_Chicago)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_Chicago)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                         50.0                       53.238872
#
#    Difference Between Target and Predicted
# 0                                 3.238872

# %%
#see data frame for actual vs predicted for Orlando
actual_predicted_Orlando = pd.DataFrame({'Actual Team Efficiency': y_test_Orlando, 'Predicted Team Efficiency': y_pred_Orlando})

print(((y_pred_Orlando - y_test_Orlando) / y_test_Orlando) * 100)
print()
print(np.mean(((y_pred_Orlando -  y_test_Orlando) / y_test_Orlando) * 100))
print()
print(actual_predicted_Orlando)
# Out:
# 632     7.395214
# 633    25.443369
# 634    31.498206
# 635    31.388246
# 636    22.948283
# 637    31.881552
# Name: Team Performance, dtype: float64
#
# 25.092478433607443
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 632                      43                  46.179942
# 633                      41                  51.431781
# 634                      41                  53.914264
# 635                      42                  55.183063
# 636                      43                  52.867762
# 637                      42                  55.390252

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_Orlando)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_Orlando)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                         42.0                       52.494511
#
#    Difference Between Target and Predicted
# 0                                10.494511

# %%
#see data frame for actual vs predicted for Atlanta
actual_predicted_Atlanta = pd.DataFrame({'Actual Team Efficiency': y_test_Atlanta, 'Predicted Team Efficiency': y_pred_Atlanta})

print(((y_pred_Atlanta- y_test_Atlanta) / y_test_Atlanta) * 100)
print()
print(np.mean(((y_pred_Atlanta- y_test_Atlanta) / y_test_Atlanta) * 100))
print()
print(actual_predicted_Atlanta)
# Out:
# 654     9.805395
# 655     1.958258
# 656     1.733396
# 657     4.563659
# 658   -18.969492
# 659    -2.182525
# Name: Team Performance, dtype: float64
#
# -0.515218093341823
#
#      Actual Team Efficiency  Predicted Team Efficiency
# 654                      56                  61.491021
# 655                      58                  59.135790
# 656                      58                  59.005370
# 657                      59                  61.692559
# 658                      59                  47.808000
# 659                      58                  56.734136

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Formula Used" : ["Cumulative Wins over Cumulative Games Played Per Instance"],
       "Target Team Efficiency Mean" : [np.mean(y_test_Atlanta)],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_Atlanta)]
    }
)

difference.insert(3, "Difference Between Target and Predicted", difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean'])

difference
# Out:
#                                         Formula Used  \
# 0  Cumulative Wins over Cumulative Games Played P...
#
#    Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0                         58.0                       57.644479
#
#    Difference Between Target and Predicted
# 0                                -0.355521

# %%
east_seeding = ['E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8', 'E9', 'E10', 'E11', 'E12', 'E13', 'E14', 'E15']
west_seeding = ['W1', 'W2', 'W3', 'W4', 'W5', 'W6', 'W7', 'W8', 'W9', 'W10', 'W11', 'W12', 'W13', 'W14', 'W15']
classification = ['Finalist', 'Semi-Finalist', 'Playoffs Maker', 'Playoffs Maker', 'Playoffs Maker', 'Playoffs Maker', 'Playoffs Maker', 'Playoffs Maker',
                 'Did not make Playoffs', 'Did not make Playoffs', 'Did not make Playoffs', 'Did not make Playoffs', 'Did not make Playoffs', 'Did not make Playoffs'
                 , 'Did not make Playoffs']
class_dict = {'Finalist': 1, 'Semi-Finalist': 2, 'Playoffs Maker': 3, 'Did not make Playoffs' : 4}

# %%
#get Eastern Conference Seedings based on average predicted team efficiency

ECF = pd.DataFrame(
  {
      "Team": ['Atlanta', 'Boston', 'Brooklyn', 'Charlotte', 'Chicago', 
               'Cleveland', 'Detroit', 'Indiana','Miami', 'Milwaukee', 'New York',
              'Orlando', 'Philadelphia', 'Toronto', 'Washington'],
      "Team Efficiency (Predicted Average)": [np.mean(y_pred_Atlanta),
                                           np.mean(y_pred_Boston), np.mean(y_pred_Brooklyn),
                                           np.mean(y_pred_Charlotte), np.mean(y_pred_Chicago),
                                           np.mean(y_pred_Cleveland), np.mean(y_pred_Detroit),
                                           np.mean(y_pred_Indiana), np.mean(y_pred_Miami),
                                           np.mean(y_pred_Milwaukee), np.mean(y_pred_NewYork),
                                           np.mean(y_pred_Orlando), np.mean(y_pred_Philadelphia),
                                           np.mean(y_pred_Toronto), np.mean(y_pred_Washington)],
  }
).sort_values(by='Team Efficiency (Predicted Average)', ascending=False)

ECF.insert(0, 'Seeding', east_seeding)
ECF.insert(3, 'Classification', classification)

ECF[:8]
# Out:
#    Seeding       Team  Team Efficiency (Predicted Average)  Classification
# 5       E1  Cleveland                            70.596101        Finalist
# 13      E2    Toronto                            60.479464   Semi-Finalist
# 7       E3    Indiana                            57.925813  Playoffs Maker
# 0       E4    Atlanta                            57.644479  Playoffs Maker
# 6       E5    Detroit                            56.344422  Playoffs Maker
# 8       E6      Miami                            54.824364  Playoffs Maker
# 4       E7    Chicago                            53.238872  Playoffs Maker
# 11      E8    Orlando                            52.494511  Playoffs Maker

# %%
WCF = pd.DataFrame(
  {
      "Team": ['Dallas', 'Denver', 'Golden State', 'Houston', 'Los Angeles Clippers', 
               'Los Angeles Lakers', 'Memphis', 'Minnesota','New Orleans', 'Oklahoma City', 'Phoenix',
              'Portland', 'Sacramento', 'San Antonio', 'Utah'],
      "Team Efficiency (Predicted Average)": [np.mean(y_pred_Dallas),
                                           np.mean(y_pred_Denver), np.mean(y_pred_GoldenState),
                                           np.mean(y_pred_Houston), np.mean(y_pred_LosAngelesClippers),
                                           np.mean(y_pred_LosAngelesLakers), np.mean(y_pred_Memphis),
                                           np.mean(y_pred_Minnesota), np.mean(y_pred_NewOrleans),
                                           np.mean(y_pred_OklahomaCity), np.mean(y_pred_Phoenix),
                                           np.mean(y_pred_Portland), np.mean(y_pred_Sacramento),
                                           np.mean(y_pred_SanAntonio), np.mean(y_pred_Utah)],
  }
).sort_values(by='Team Efficiency (Predicted Average)', ascending=False)

WCF.insert(0, 'Seeding', west_seeding)
WCF.insert(3, 'Classification', classification)

WCF[:8]
# Out:
#    Seeding                  Team  Team Efficiency (Predicted Average)  \
# 2       W1          Golden State                            94.127283
# 13      W2           San Antonio                            81.565659
# 9       W3         Oklahoma City                            69.058699
# 0       W4                Dallas                            54.159594
# 4       W5  Los Angeles Clippers                            53.063232
# 3       W6               Houston                            49.696194
# 6       W7               Memphis                            49.359578
# 11      W8              Portland                            48.745470
#
#     Classification
# 2         Finalist
# 13   Semi-Finalist
# 9   Playoffs Maker
# 0   Playoffs Maker
# 4   Playoffs Maker
# 3   Playoffs Maker
# 6   Playoffs Maker
# 11  Playoffs Maker

# %%
overall = pd.concat([ECF,WCF], axis=0, join='outer', ignore_index=True)

overall['Rank'] = overall['Classification'].map(class_dict)

overall.sort_values(by='Rank')

#overall.style.hide_index() #pandas version 0.23
#overall.style.hide_columns('Rank') #pandas version 0.23
# Out:
#    Seeding                  Team  Team Efficiency (Predicted Average)  \
# 0       E1             Cleveland                            70.596101
# 15      W1          Golden State                            94.127283
# 1       E2               Toronto                            60.479464
# 16      W2           San Antonio                            81.565659
# 18      W4                Dallas                            54.159594
# 17      W3         Oklahoma City                            69.058699
# 21      W7               Memphis                            49.359578
# 22      W8              Portland                            48.745470
# 19      W5  Los Angeles Clippers                            53.063232
# 20      W6               Houston                            49.696194
# 7       E8               Orlando                            52.494511
# 6       E7               Chicago                            53.238872
# ...
