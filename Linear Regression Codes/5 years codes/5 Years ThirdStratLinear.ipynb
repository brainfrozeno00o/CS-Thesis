# %% [markdown]
# Team Efficiency all-in-all uses = League Points, 3Ps Made, Assists, Turnovers, Field Goal Attempts, Field Goals Made, Free Throws Attempted, Free Throws Made, Offensive Rebounds, Total Rebounds, Steals, Blocks, and Personal Fouls thus remove these from the X set to remove redundancy
#
# Same case for factor, VOP, and DRB since they are part of getting the team efficiency engineered stat
#
# Thus, X should contain 3Ps Attempted, Defensive Rebounds, Average Points, Attendees, and Team Efficiency
#
# The data used here is a consolidated dataset from the 2013-2014 season up to 2017-2018 season.

# %%
import numpy as np
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/1d7M7hZwCRQbDGAY3zp6jZ1uFUZ4yf41wUR06CbVpSx4/edit#gid=0'
csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

df = pd.read_csv(csv_export_url)

X_guide = ['Team Name and Instance', '3Ps Attempted', 'Defensive Rebounds', 'Average Points', 'Attendees', 'Team Efficiency']
Y_guide = ['Team Name and Instance', 'Team Performance']

X_stats = ['3Ps Attempted', 'Defensive Rebounds', 'Average Points', 'Attendees', 'Team Efficiency']
Y_stats = ['Team Performance']

#get rows that contain the data for each team

conGSW = df['Team Name and Instance'].str.contains('Golden State Warriors')
conSAS = df['Team Name and Instance'].str.contains('San Antonio Spurs')
conHOU = df['Team Name and Instance'].str.contains('Houston Rockets')
conLAC = df['Team Name and Instance'].str.contains('Los Angeles Clippers')
conUTAH = df['Team Name and Instance'].str.contains('Utah Jazz')
conOKC = df['Team Name and Instance'].str.contains('Oklahoma City Thunder')
conMEM = df['Team Name and Instance'].str.contains('Memphis Grizzlies')
conPOR = df['Team Name and Instance'].str.contains('Portland Trailblazers')
conDEN = df['Team Name and Instance'].str.contains('Denver Nuggets')
conNOP = df['Team Name and Instance'].str.contains('New Orleans Pelicans')
conDAL = df['Team Name and Instance'].str.contains('Dallas Mavericks')
conSAC = df['Team Name and Instance'].str.contains('Sacramento Kings')
conMIN = df['Team Name and Instance'].str.contains('Minnesota Timberwolves')
conLAL = df['Team Name and Instance'].str.contains('Los Angeles Lakers')
conPHO = df['Team Name and Instance'].str.contains('Phoenix Suns')
conBOS = df['Team Name and Instance'].str.contains('Boston Celtics')
conCLE = df['Team Name and Instance'].str.contains('Cleveland Cavaliers')
conTOR = df['Team Name and Instance'].str.contains('Toronto Raptors')
conWAS = df['Team Name and Instance'].str.contains('Washington Wizards')
conATL = df['Team Name and Instance'].str.contains('Atlanta Hawks')
conMIL = df['Team Name and Instance'].str.contains('Milwaukee Bucks')
conIND = df['Team Name and Instance'].str.contains('Indiana Pacers')
conCHI = df['Team Name and Instance'].str.contains('Chicago Bulls')
conMIA = df['Team Name and Instance'].str.contains('Miami Heat')
conDET = df['Team Name and Instance'].str.contains('Detroit Pistons')
conCHA = df['Team Name and Instance'].str.contains('Charlotte Hornets')
conNYK = df['Team Name and Instance'].str.contains('New York Knicks')
conORL = df['Team Name and Instance'].str.contains('Orlando Magic')
conPHI = df['Team Name and Instance'].str.contains('Philadelphia 76ers')
conBKN = df['Team Name and Instance'].str.contains('Brooklyn Nets')

# %%
#remove '%' in percentages
df["FG %"] = df["FG %"].str.rstrip('%')
df["3Ps %"] = df["3Ps %"].str.rstrip('%')
df["FT%"] = df["FT%"].str.rstrip('%')

# %%
#change object types to numeric
df["FG %"] = pd.to_numeric(df["FG %"], downcast='float', errors='coerce')
df["3Ps %"] = pd.to_numeric(df["3Ps %"], downcast='float', errors='coerce')
df["FT%"] = pd.to_numeric(df["FT%"], downcast='float', errors='coerce')

# %%
#get the real percentage of stats that involve percentages
df["FG %"] = df["FG %"] / 100
df["3Ps %"] = df["3Ps %"] / 100
df["FT%"] = df["FT%"] / 100

# %%
#setting consolidated dataset per team

X_GSW = df.loc[conGSW, X_guide]
y_GSW = df.loc[conGSW, Y_guide]

X_SAS = df.loc[conSAS, X_guide]
y_SAS = df.loc[conSAS, Y_guide]

X_HOU = df.loc[conHOU, X_guide]
y_HOU = df.loc[conHOU, Y_guide]

X_LAC = df.loc[conLAC, X_guide]
y_LAC = df.loc[conLAC, Y_guide]

X_UTAH = df.loc[conUTAH, X_guide]
y_UTAH = df.loc[conUTAH, Y_guide]

X_OKC = df.loc[conOKC, X_guide]
y_OKC = df.loc[conOKC, Y_guide]

X_MEM = df.loc[conMEM, X_guide]
y_MEM = df.loc[conMEM, Y_guide]

X_POR = df.loc[conPOR, X_guide]
y_POR = df.loc[conPOR, Y_guide]

X_DEN = df.loc[conDEN, X_guide]
y_DEN = df.loc[conDEN, Y_guide]

X_NOP = df.loc[conNOP, X_guide]
y_NOP = df.loc[conNOP, Y_guide]

X_DAL = df.loc[conDAL, X_guide]
y_DAL = df.loc[conDAL, Y_guide]

X_SAC = df.loc[conSAC, X_guide]
y_SAC = df.loc[conSAC, Y_guide]

X_MIN = df.loc[conMIN, X_guide]
y_MIN = df.loc[conMIN, Y_guide]

X_LAL = df.loc[conLAL, X_guide]
y_LAL = df.loc[conLAL, Y_guide]

X_PHO = df.loc[conPHO, X_guide]
y_PHO = df.loc[conPHO, Y_guide]

X_BOS = df.loc[conBOS, X_guide]
y_BOS = df.loc[conBOS, Y_guide]

X_CLE = df.loc[conCLE, X_guide]
y_CLE = df.loc[conCLE, Y_guide]

X_TOR = df.loc[conTOR, X_guide]
y_TOR = df.loc[conTOR, Y_guide]

X_WAS = df.loc[conWAS, X_guide]
y_WAS = df.loc[conWAS, Y_guide]

X_ATL = df.loc[conATL, X_guide]
y_ATL = df.loc[conATL, Y_guide]

X_MIL = df.loc[conMIL, X_guide]
y_MIL = df.loc[conMIL, Y_guide]

X_IND = df.loc[conIND, X_guide]
y_IND = df.loc[conIND, Y_guide]

X_CHI = df.loc[conCHI, X_guide]
y_CHI = df.loc[conCHI, Y_guide]

X_MIA = df.loc[conMIA, X_guide]
y_MIA = df.loc[conMIA, Y_guide]

X_DET = df.loc[conDET, X_guide]
y_DET = df.loc[conDET, Y_guide]

X_CHA = df.loc[conCHA, X_guide]
y_CHA = df.loc[conCHA, Y_guide]

X_NYK = df.loc[conNYK, X_guide]
y_NYK = df.loc[conNYK, Y_guide]

X_ORL = df.loc[conORL, X_guide]
y_ORL = df.loc[conORL, Y_guide]

X_PHI = df.loc[conPHI, X_guide]
y_PHI = df.loc[conPHI, Y_guide]

X_BKN = df.loc[conBKN, X_guide]
y_BKN = df.loc[conBKN, Y_guide]

# %%
#trim the dataset in such a way that the testing set contains instances that
#have 4 games and the training set contains instances that have 3 games

#set the conditions first

condGSW1 = X_GSW['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condGSW2 = X_GSW['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condGSW3 = y_GSW['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condGSW4 = y_GSW['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condSAS1 = X_SAS['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condSAS2 = X_SAS['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condSAS3 = y_SAS['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condSAS4 = y_SAS['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condHOU1 = X_HOU['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condHOU2 = X_HOU['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condHOU3 = y_HOU['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condHOU4 = y_HOU['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condLAC1 = X_LAC['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condLAC2 = X_LAC['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condLAC3 = y_LAC['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condLAC4 = y_LAC['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condUTAH1 = X_UTAH['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condUTAH2 = X_UTAH['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condUTAH3 = y_UTAH['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condUTAH4 = y_UTAH['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condOKC1 = X_OKC['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condOKC2 = X_OKC['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condOKC3 = y_OKC['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condOKC4 = y_OKC['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condMEM1 = X_MEM['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condMEM2 = X_MEM['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condMEM3 = y_MEM['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condMEM4 = y_MEM['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condPOR1 = X_POR['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condPOR2 = X_POR['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condPOR3 = y_POR['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condPOR4 = y_POR['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condDEN1 = X_DEN['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condDEN2 = X_DEN['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condDEN3 = y_DEN['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condDEN4 = y_DEN['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condNOP1 = X_NOP['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condNOP2 = X_NOP['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condNOP3 = y_NOP['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condNOP4 = y_NOP['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condDAL1 = X_DAL['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condDAL2 = X_DAL['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condDAL3 = y_DAL['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condDAL4 = y_DAL['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condSAC1 = X_SAC['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condSAC2 = X_SAC['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condSAC3 = y_SAC['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condSAC4 = y_SAC['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condMIN1 = X_MIN['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condMIN2 = X_MIN['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condMIN3 = y_MIN['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condMIN4 = y_MIN['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condLAL1 = X_LAL['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condLAL2 = X_LAL['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condLAL3 = y_LAL['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condLAL4 = y_LAL['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condPHO1 = X_PHO['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condPHO2 = X_PHO['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condPHO3 = y_PHO['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condPHO4 = y_PHO['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condBOS1 = X_BOS['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condBOS2 = X_BOS['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condBOS3 = y_BOS['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condBOS4 = y_BOS['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condCLE1 = X_CLE['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condCLE2 = X_CLE['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condCLE3 = y_CLE['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condCLE4 = y_CLE['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condTOR1 = X_TOR['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condTOR2 = X_TOR['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condTOR3 = y_TOR['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condTOR4 = y_TOR['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condWAS1 = X_WAS['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condWAS2 = X_WAS['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condWAS3 = y_WAS['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condWAS4 = y_WAS['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condATL1 = X_ATL['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condATL2 = X_ATL['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condATL3 = y_ATL['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condATL4 = y_ATL['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condMIL1 = X_MIL['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condMIL2 = X_MIL['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condMIL3 = y_MIL['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condMIL4 = y_MIL['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condIND1 = X_IND['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condIND2 = X_IND['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condIND3 = y_IND['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condIND4 = y_IND['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condCHI1 = X_CHI['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condCHI2 = X_CHI['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condCHI3 = y_CHI['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condCHI4 = y_CHI['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condMIA1 = X_MIA['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condMIA2 = X_MIA['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condMIA3 = y_MIA['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condMIA4 = y_MIA['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condDET1 = X_DET['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condDET2 = X_DET['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condDET3 = y_DET['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condDET4 = y_DET['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condCHA1 = X_CHA['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condCHA2 = X_CHA['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condCHA3 = y_CHA['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condCHA4 = y_CHA['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condNYK1 = X_NYK['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condNYK2 = X_NYK['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condNYK3 = y_NYK['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condNYK4 = y_NYK['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condORL1 = X_ORL['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condORL2 = X_ORL['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condORL3 = y_ORL['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condORL4 = y_ORL['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condPHI1 = X_PHI['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condPHI2 = X_PHI['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condPHI3 = y_PHI['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condPHI4 = y_PHI['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

condBKN1 = X_BKN['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condBKN2 = X_BKN['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)
condBKN3 = y_BKN['Team Name and Instance'].str.contains('(Games ([1-9]|[1-5][0-9]|6[01234])-([1-9]|[1-5][0-9]|6[01234]))', regex=True)
condBKN4 = y_BKN['Team Name and Instance'].str.contains('(Games (6[5-9]|7[0-9]|8[012])-(6[5-9]|7[0-9]|8[012]))', regex=True)

X_train_GSW = X_GSW.loc[condGSW1, X_stats]
X_test_GSW = X_GSW.loc[condGSW2, X_stats]
y_train_GSW = y_GSW.loc[condGSW3, Y_stats]
y_test_GSW = y_GSW.loc[condGSW4, Y_stats]

X_train_SAS = X_SAS.loc[condSAS1, X_stats]
X_test_SAS = X_SAS.loc[condSAS2, X_stats]
y_train_SAS = y_SAS.loc[condSAS3, Y_stats]
y_test_SAS = y_SAS.loc[condSAS4, Y_stats]

X_train_HOU = X_HOU.loc[condHOU1, X_stats]
X_test_HOU = X_HOU.loc[condHOU2, X_stats]
y_train_HOU = y_HOU.loc[condHOU3, Y_stats]
y_test_HOU = y_HOU.loc[condHOU4, Y_stats]

X_train_LAC = X_LAC.loc[condLAC1, X_stats]
X_test_LAC = X_LAC.loc[condLAC2, X_stats]
y_train_LAC = y_LAC.loc[condLAC3, Y_stats]
y_test_LAC = y_LAC.loc[condLAC4, Y_stats]

X_train_UTAH = X_UTAH.loc[condUTAH1, X_stats]
X_test_UTAH = X_UTAH.loc[condUTAH2, X_stats]
y_train_UTAH = y_UTAH.loc[condUTAH3, Y_stats]
y_test_UTAH = y_UTAH.loc[condUTAH4, Y_stats]

X_train_OKC = X_OKC.loc[condOKC1, X_stats]
X_test_OKC = X_OKC.loc[condOKC2, X_stats]
y_train_OKC = y_OKC.loc[condOKC3, Y_stats]
y_test_OKC = y_OKC.loc[condOKC4, Y_stats]

X_train_MEM = X_MEM.loc[condMEM1, X_stats]
X_test_MEM = X_MEM.loc[condMEM2, X_stats]
y_train_MEM = y_MEM.loc[condMEM3, Y_stats]
y_test_MEM = y_MEM.loc[condMEM4, Y_stats]

X_train_POR = X_POR.loc[condPOR1, X_stats]
X_test_POR = X_POR.loc[condPOR2, X_stats]
y_train_POR = y_POR.loc[condPOR3, Y_stats]
y_test_POR = y_POR.loc[condPOR4, Y_stats]

X_train_DEN = X_DEN.loc[condDEN1, X_stats]
X_test_DEN = X_DEN.loc[condDEN2, X_stats]
y_train_DEN = y_DEN.loc[condDEN3, Y_stats]
y_test_DEN = y_DEN.loc[condDEN4, Y_stats]

X_train_NOP = X_NOP.loc[condNOP1, X_stats]
X_test_NOP = X_NOP.loc[condNOP2, X_stats]
y_train_NOP = y_NOP.loc[condNOP3, Y_stats]
y_test_NOP = y_NOP.loc[condNOP4, Y_stats]

X_train_DAL = X_DAL.loc[condDAL1, X_stats]
X_test_DAL = X_DAL.loc[condDAL2, X_stats]
y_train_DAL = y_DAL.loc[condDAL3, Y_stats]
y_test_DAL = y_DAL.loc[condDAL4, Y_stats]

X_train_SAC = X_SAC.loc[condSAC1, X_stats]
X_test_SAC = X_SAC.loc[condSAC2, X_stats]
y_train_SAC = y_SAC.loc[condSAC3, Y_stats]
y_test_SAC = y_SAC.loc[condSAC4, Y_stats]

X_train_MIN = X_MIN.loc[condMIN1, X_stats]
X_test_MIN = X_MIN.loc[condMIN2, X_stats]
y_train_MIN = y_MIN.loc[condMIN3, Y_stats]
y_test_MIN = y_MIN.loc[condMIN4, Y_stats]

X_train_LAL = X_LAL.loc[condLAL1, X_stats]
X_test_LAL = X_LAL.loc[condLAL2, X_stats]
y_train_LAL = y_LAL.loc[condLAL3, Y_stats]
y_test_LAL = y_LAL.loc[condLAL4, Y_stats]

X_train_PHO = X_PHO.loc[condPHO1, X_stats]
X_test_PHO = X_PHO.loc[condPHO2, X_stats]
y_train_PHO = y_PHO.loc[condPHO3, Y_stats]
y_test_PHO = y_PHO.loc[condPHO4, Y_stats]

X_train_BOS = X_BOS.loc[condBOS1, X_stats]
X_test_BOS = X_BOS.loc[condBOS2, X_stats]
y_train_BOS = y_BOS.loc[condBOS3, Y_stats]
y_test_BOS = y_BOS.loc[condBOS4, Y_stats]

X_train_CLE = X_CLE.loc[condCLE1, X_stats]
X_test_CLE = X_CLE.loc[condCLE2, X_stats]
y_train_CLE = y_CLE.loc[condCLE3, Y_stats]
y_test_CLE = y_CLE.loc[condCLE4, Y_stats]

X_train_TOR = X_TOR.loc[condTOR1, X_stats]
X_test_TOR = X_TOR.loc[condTOR2, X_stats]
y_train_TOR = y_TOR.loc[condTOR3, Y_stats]
y_test_TOR = y_TOR.loc[condTOR4, Y_stats]

X_train_WAS = X_WAS.loc[condWAS1, X_stats]
X_test_WAS = X_WAS.loc[condWAS2, X_stats]
y_train_WAS = y_WAS.loc[condWAS3, Y_stats]
y_test_WAS = y_WAS.loc[condWAS4, Y_stats]

X_train_ATL = X_ATL.loc[condATL1, X_stats]
X_test_ATL = X_ATL.loc[condATL2, X_stats]
y_train_ATL = y_ATL.loc[condATL3, Y_stats]
y_test_ATL = y_ATL.loc[condATL4, Y_stats]

X_train_MIL = X_MIL.loc[condMIL1, X_stats]
X_test_MIL = X_MIL.loc[condMIL2, X_stats]
y_train_MIL = y_MIL.loc[condMIL3, Y_stats]
y_test_MIL = y_MIL.loc[condMIL4, Y_stats]

X_train_IND = X_IND.loc[condIND1, X_stats]
X_test_IND = X_IND.loc[condIND2, X_stats]
y_train_IND = y_IND.loc[condIND3, Y_stats]
y_test_IND = y_IND.loc[condIND4, Y_stats]

X_train_CHI = X_CHI.loc[condCHI1, X_stats]
X_test_CHI = X_CHI.loc[condCHI2, X_stats]
y_train_CHI = y_CHI.loc[condCHI3, Y_stats]
y_test_CHI = y_CHI.loc[condCHI4, Y_stats]

X_train_MIA = X_MIA.loc[condMIA1, X_stats]
X_test_MIA = X_MIA.loc[condMIA2, X_stats]
y_train_MIA = y_MIA.loc[condMIA3, Y_stats]
y_test_MIA = y_MIA.loc[condMIA4, Y_stats]

X_train_DET = X_DET.loc[condDET1, X_stats]
X_test_DET = X_DET.loc[condDET2, X_stats]
y_train_DET = y_DET.loc[condDET3, Y_stats]
y_test_DET = y_DET.loc[condDET4, Y_stats]

X_train_CHA = X_CHA.loc[condCHA1, X_stats]
X_test_CHA = X_CHA.loc[condCHA2, X_stats]
y_train_CHA = y_CHA.loc[condCHA3, Y_stats]
y_test_CHA = y_CHA.loc[condCHA4, Y_stats]

X_train_NYK = X_NYK.loc[condNYK1, X_stats]
X_test_NYK = X_NYK.loc[condNYK2, X_stats]
y_train_NYK = y_NYK.loc[condNYK3, Y_stats]
y_test_NYK = y_NYK.loc[condNYK4, Y_stats]

X_train_ORL = X_ORL.loc[condORL1, X_stats]
X_test_ORL = X_ORL.loc[condORL2, X_stats]
y_train_ORL = y_ORL.loc[condORL3, Y_stats]
y_test_ORL = y_ORL.loc[condORL4, Y_stats]

X_train_PHI = X_PHI.loc[condPHI1, X_stats]
X_test_PHI = X_PHI.loc[condPHI2, X_stats]
y_train_PHI = y_PHI.loc[condPHI3, Y_stats]
y_test_PHI = y_PHI.loc[condPHI4, Y_stats]

X_train_BKN = X_BKN.loc[condBKN1, X_stats]
X_test_BKN = X_BKN.loc[condBKN2, X_stats]
y_train_BKN = y_BKN.loc[condBKN3, Y_stats]
y_test_BKN = y_BKN.loc[condBKN4, Y_stats]

# %%
from sklearn.linear_model import LinearRegression

regressorGSW = LinearRegression()
regressorGSW.fit(X_train_GSW, y_train_GSW)

regressorSAS = LinearRegression()
regressorSAS.fit(X_train_SAS, y_train_SAS)

regressorHOU = LinearRegression()
regressorHOU.fit(X_train_HOU, y_train_HOU)

regressorLAC = LinearRegression()
regressorLAC.fit(X_train_LAC, y_train_LAC)

regressorUTAH = LinearRegression()
regressorUTAH.fit(X_train_UTAH, y_train_UTAH)

regressorOKC = LinearRegression()
regressorOKC.fit(X_train_OKC, y_train_OKC)

regressorMEM = LinearRegression()
regressorMEM.fit(X_train_MEM, y_train_MEM)

regressorPOR = LinearRegression()
regressorPOR.fit(X_train_POR, y_train_POR)

regressorDEN = LinearRegression()
regressorDEN.fit(X_train_DEN, y_train_DEN)

regressorNOP = LinearRegression()
regressorNOP.fit(X_train_NOP, y_train_NOP)

regressorDAL = LinearRegression()
regressorDAL.fit(X_train_DAL, y_train_DAL)

regressorSAC = LinearRegression()
regressorSAC.fit(X_train_SAC, y_train_SAC)

regressorMIN = LinearRegression()
regressorMIN.fit(X_train_MIN, y_train_MIN)

regressorLAL = LinearRegression()
regressorLAL.fit(X_train_LAL, y_train_LAL)

regressorPHO = LinearRegression()
regressorPHO.fit(X_train_PHO, y_train_PHO)

regressorBOS = LinearRegression()
regressorBOS.fit(X_train_BOS, y_train_BOS)

regressorCLE = LinearRegression()
regressorCLE.fit(X_train_CLE, y_train_CLE)

regressorTOR = LinearRegression()
regressorTOR.fit(X_train_TOR, y_train_TOR)

regressorWAS = LinearRegression()
regressorWAS.fit(X_train_WAS, y_train_WAS)

regressorATL = LinearRegression()
regressorATL.fit(X_train_ATL, y_train_ATL)

regressorMIL = LinearRegression()
regressorMIL.fit(X_train_MIL, y_train_MIL)

regressorIND = LinearRegression()
regressorIND.fit(X_train_IND, y_train_IND)

regressorCHI = LinearRegression()
regressorCHI.fit(X_train_CHI, y_train_CHI)

regressorMIA = LinearRegression()
regressorMIA.fit(X_train_MIA, y_train_MIA)

regressorDET = LinearRegression()
regressorDET.fit(X_train_DET, y_train_DET)

regressorCHA = LinearRegression()
regressorCHA.fit(X_train_CHA, y_train_CHA)

regressorNYK = LinearRegression()
regressorNYK.fit(X_train_NYK, y_train_NYK)

regressorORL = LinearRegression()
regressorORL.fit(X_train_ORL, y_train_ORL)

regressorPHI = LinearRegression()
regressorPHI.fit(X_train_PHI, y_train_PHI)

regressorBKN = LinearRegression()
regressorBKN.fit(X_train_BKN, y_train_BKN)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pd.DataFrame(list(zip(X_train_GSW, regressorGSW.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.635859
# 1  Defensive Rebounds          0.583630
# 2      Average Points         -0.019142
# 3           Attendees          0.002970
# 4     Team Efficiency          0.360917

# %%
pd.DataFrame(list(zip(X_train_SAS, regressorSAS.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -1.331421
# 1  Defensive Rebounds          0.935039
# 2      Average Points         -0.293375
# 3           Attendees         -0.000480
# 4     Team Efficiency          0.737908

# %%
pd.DataFrame(list(zip(X_train_HOU, regressorHOU.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.539286
# 1  Defensive Rebounds          1.349681
# 2      Average Points         -0.255225
# 3           Attendees          0.001283
# 4     Team Efficiency          0.389012

# %%
pd.DataFrame(list(zip(X_train_LAC, regressorLAC.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.486645
# 1  Defensive Rebounds          0.602524
# 2      Average Points         -0.540037
# 3           Attendees          0.002886
# 4     Team Efficiency          0.670393

# %%
pd.DataFrame(list(zip(X_train_UTAH, regressorUTAH.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          1.054803
# 1  Defensive Rebounds          1.775039
# 2      Average Points          0.618998
# 3           Attendees          0.003146
# 4     Team Efficiency         -0.226341

# %%
pd.DataFrame(list(zip(X_train_OKC, regressorOKC.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -1.195213
# 1  Defensive Rebounds          0.056783
# 2      Average Points          0.993403
# 3           Attendees          0.002680
# 4     Team Efficiency         -0.164175

# %%
pd.DataFrame(list(zip(X_train_MEM, regressorMEM.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -1.035312
# 1  Defensive Rebounds          1.331704
# 2      Average Points          0.609476
# 3           Attendees          0.000884
# 4     Team Efficiency          0.142876

# %%
pd.DataFrame(list(zip(X_train_POR, regressorPOR.coef_)), columns=['Feature', 'Beta Coefficient'])
# Out:
#          Feature                                   Beta Coefficient
# 0  3Ps Attempted  [-0.6691711566067, 1.1842071094551858, -1.1848...

# %%
pd.DataFrame(list(zip(X_train_DEN, regressorDEN.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.116742
# 1  Defensive Rebounds          0.181297
# 2      Average Points         -0.610038
# 3           Attendees          0.001457
# 4     Team Efficiency          0.722657

# %%
pd.DataFrame(list(zip(X_train_NOP, regressorNOP.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.527418
# 1  Defensive Rebounds          0.517170
# 2      Average Points         -0.569858
# 3           Attendees          0.000017
# 4     Team Efficiency          1.111122

# %%
pd.DataFrame(list(zip(X_train_DAL, regressorDAL.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -2.334277
# 1  Defensive Rebounds          1.474070
# 2      Average Points         -0.479408
# 3           Attendees          0.001126
# 4     Team Efficiency          1.189215

# %%
pd.DataFrame(list(zip(X_train_SAC, regressorSAC.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.587348
# 1  Defensive Rebounds          0.775719
# 2      Average Points          0.452237
# 3           Attendees         -0.000151
# 4     Team Efficiency         -0.056867

# %%
pd.DataFrame(list(zip(X_train_MIN, regressorMIN.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          1.113868
# 1  Defensive Rebounds          1.240748
# 2      Average Points          0.172606
# 3           Attendees          0.001409
# 4     Team Efficiency          0.404858

# %%
pd.DataFrame(list(zip(X_train_LAL, regressorLAL.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.310992
# 1  Defensive Rebounds          1.125091
# 2      Average Points         -0.022009
# 3           Attendees         -0.004202
# 4     Team Efficiency          0.438638

# %%
pd.DataFrame(list(zip(X_train_PHO, regressorPHO.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.255423
# 1  Defensive Rebounds          0.580967
# 2      Average Points         -2.155115
# 3           Attendees         -0.003918
# 4     Team Efficiency          2.079339

# %%
pd.DataFrame(list(zip(X_train_BOS, regressorBOS.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          1.553031
# 1  Defensive Rebounds          1.921402
# 2      Average Points          0.279507
# 3           Attendees          0.002681
# 4     Team Efficiency          0.127590

# %%
pd.DataFrame(list(zip(X_train_CLE, regressorCLE.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          1.314678
# 1  Defensive Rebounds          1.017339
# 2      Average Points         -0.791540
# 3           Attendees          0.004495
# 4     Team Efficiency          0.700681

# %%
pd.DataFrame(list(zip(X_train_TOR, regressorTOR.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.157925
# 1  Defensive Rebounds          0.529124
# 2      Average Points          0.612948
# 3           Attendees          0.002763
# 4     Team Efficiency         -0.034284

# %%
pd.DataFrame(list(zip(X_train_WAS, regressorWAS.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.832110
# 1  Defensive Rebounds          1.080985
# 2      Average Points         -0.356048
# 3           Attendees          0.002798
# 4     Team Efficiency          0.711561

# %%
pd.DataFrame(list(zip(X_train_ATL, regressorATL.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.759321
# 1  Defensive Rebounds          1.565955
# 2      Average Points         -2.243895
# 3           Attendees          0.003064
# 4     Team Efficiency          2.011691

# %%
pd.DataFrame(list(zip(X_train_MIL, regressorMIL.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.361824
# 1  Defensive Rebounds          0.843889
# 2      Average Points          0.008194
# 3           Attendees          0.003528
# 4     Team Efficiency          0.411404

# %%
pd.DataFrame(list(zip(X_train_IND, regressorIND.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -1.043337
# 1  Defensive Rebounds          1.083265
# 2      Average Points         -0.988574
# 3           Attendees          0.001173
# 4     Team Efficiency          1.218661

# %%
pd.DataFrame(list(zip(X_train_CHI, regressorCHI.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -1.572678
# 1  Defensive Rebounds          0.874584
# 2      Average Points          0.029782
# 3           Attendees          0.001632
# 4     Team Efficiency          0.538341

# %%
pd.DataFrame(list(zip(X_train_MIA, regressorMIA.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.617221
# 1  Defensive Rebounds         -0.373976
# 2      Average Points         -0.508166
# 3           Attendees          0.004565
# 4     Team Efficiency          0.924753

# %%
pd.DataFrame(list(zip(X_train_DET, regressorDET.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.142750
# 1  Defensive Rebounds          0.321217
# 2      Average Points          1.309050
# 3           Attendees          0.002190
# 4     Team Efficiency         -0.609249

# %%
pd.DataFrame(list(zip(X_train_CHA, regressorCHA.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.483307
# 1  Defensive Rebounds          0.695372
# 2      Average Points         -0.233937
# 3           Attendees         -0.000394
# 4     Team Efficiency          0.388240

# %%
pd.DataFrame(list(zip(X_train_NYK, regressorNYK.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.256827
# 1  Defensive Rebounds          1.428291
# 2      Average Points          1.015090
# 3           Attendees          0.001933
# 4     Team Efficiency         -0.126108

# %%
pd.DataFrame(list(zip(X_train_ORL, regressorORL.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.715089
# 1  Defensive Rebounds          1.235384
# 2      Average Points         -0.617088
# 3           Attendees         -0.000261
# 4     Team Efficiency          0.866704

# %%
pd.DataFrame(list(zip(X_train_PHI, regressorPHI.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted         -0.809295
# 1  Defensive Rebounds          1.117287
# 2      Average Points          0.997792
# 3           Attendees          0.001636
# 4     Team Efficiency          0.350584

# %%
pd.DataFrame(list(zip(X_train_BKN, regressorBKN.coef_.ravel())), columns=['Feature', 'Beta Coefficient'])
# Out:
#               Feature  Beta Coefficient
# 0       3Ps Attempted          0.303018
# 1  Defensive Rebounds          0.293907
# 2      Average Points         -0.681544
# 3           Attendees          0.002150
# 4     Team Efficiency          0.599451

# %%
#make the predictions for each team

y_pred_GSW = regressorGSW.predict(X_test_GSW)

y_pred_SAS = regressorSAS.predict(X_test_SAS)

y_pred_HOU = regressorHOU.predict(X_test_HOU)

y_pred_LAC = regressorLAC.predict(X_test_LAC)

y_pred_UTAH = regressorUTAH.predict(X_test_UTAH)

y_pred_OKC = regressorOKC.predict(X_test_OKC)

y_pred_MEM = regressorMEM.predict(X_test_MEM)

y_pred_POR = regressorPOR.predict(X_test_POR)

y_pred_DEN = regressorDEN.predict(X_test_DEN)

y_pred_NOP = regressorNOP.predict(X_test_NOP)

y_pred_DAL = regressorDAL.predict(X_test_DAL)

y_pred_SAC = regressorSAC.predict(X_test_SAC)

y_pred_MIN = regressorMIN.predict(X_test_MIN)

y_pred_LAL = regressorLAL.predict(X_test_LAL)

y_pred_PHO = regressorPHO.predict(X_test_PHO)

y_pred_BOS = regressorBOS.predict(X_test_BOS)

y_pred_CLE = regressorCLE.predict(X_test_CLE)

y_pred_TOR = regressorTOR.predict(X_test_TOR)

y_pred_WAS = regressorWAS.predict(X_test_WAS)

y_pred_ATL = regressorATL.predict(X_test_ATL)

y_pred_MIL = regressorMIL.predict(X_test_MIL)

y_pred_IND = regressorIND.predict(X_test_IND)

y_pred_CHI = regressorCHI.predict(X_test_CHI)

y_pred_MIA = regressorMIA.predict(X_test_MIA)

y_pred_DET = regressorDET.predict(X_test_DET)

y_pred_CHA = regressorCHA.predict(X_test_CHA)

y_pred_NYK = regressorNYK.predict(X_test_NYK)

y_pred_ORL = regressorORL.predict(X_test_ORL)

y_pred_PHI = regressorPHI.predict(X_test_PHI)

y_pred_BKN = regressorBKN.predict(X_test_BKN)

# %%
actual_predicted_GSW = pd.DataFrame({'Actual Team Performance': y_test_GSW.squeeze(), 'Predicted Team Performance': y_pred_GSW.flatten()})

print(((y_pred_GSW.flatten() - y_test_GSW.squeeze()) / y_test_GSW.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_GSW.flatten() - y_test_GSW.squeeze()) / y_test_GSW.squeeze()) * 100)))
print()
print(actual_predicted_GSW)
# Out:
# 38      21.349304
# 39      24.990613
# 40      13.842751
# 41      26.062065
# 42      34.772503
# 43      34.766808
# 698      5.646276
# 699     -4.699260
# 700     -3.365771
# 701     -1.284235
# 702    -10.985492
# 703      0.667452
# 1358    -2.667151
# 1359    -9.771964
# 1360    -0.489328
# 1361    -9.801892
# 1362    -4.812681
# 1363    -6.027691
# 2018   -13.786582
# 2019     5.162733
# 2020     6.998751
# 2021    -3.100968
# 2022     5.477854
# 2023     3.078959
# 2678     2.119332
# 2679     2.209241
# 2680   -11.109941
# 2681    -5.438199
# 2682     5.901678
# 2683    -0.766597
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: 3.497952
#
#       Actual Team Performance  Predicted Team Performance
# 38                         59                   71.596090
# 39                         61                   76.244274
# 40                         60                   68.305650
# 41                         60                   75.637239
# ...

# %%
actual_predicted_SAS = pd.DataFrame({'Actual Team Performance': y_test_SAS.squeeze(), 'Predicted Team Performance': y_pred_SAS.flatten()})

print(((y_pred_SAS.flatten() - y_test_SAS.squeeze()) / y_test_SAS.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_SAS.flatten() - y_test_SAS.squeeze()) / y_test_SAS.squeeze()) * 100)))
print()
print(actual_predicted_SAS)
# Out:
# 148     20.259478
# 149    -12.118118
# 150      6.018792
# 151     -7.412087
# 152    -13.034967
# 153    -13.236300
# 808     33.869616
# 809     17.886134
# 810     34.420711
# 811      9.203713
# 812     23.275903
# 813     18.327059
# 1468   -10.573279
# 1469    -6.745539
# 1470    -6.935931
# 1471    -6.574010
# 1472    -9.114530
# 1473   -10.913931
# 2128   -16.129887
# 2129   -18.418205
# 2130    -7.618309
# 2131   -10.388977
# 2132   -16.441161
# 2133   -15.988512
# 2788     3.612999
# 2789    34.127578
# 2790    24.525531
# 2791    16.612165
# 2792    32.079370
# 2793    14.356172
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: 3.564383
#
#       Actual Team Performance  Predicted Team Performance
# 148                        76                   91.397203
# 149                        77                   67.669049
# 150                        78                   82.694658
# 151                        77                   71.292693
# ...

# %%
actual_predicted_HOU = pd.DataFrame({'Actual Team Performance': y_test_HOU.squeeze(), 'Predicted Team Performance': y_pred_HOU.flatten()})

print(((y_pred_HOU.flatten() - y_test_HOU.squeeze()) / y_test_HOU.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_HOU.flatten() - y_test_HOU.squeeze()) / y_test_HOU.squeeze()) * 100)))
print()
print(actual_predicted_HOU)
# Out:
# 16      -9.091578
# 17      -2.119316
# 18      -4.304648
# 19       0.843128
# 20      11.575199
# 21      -7.520310
# 676     -6.964757
# 677     -7.088611
# 678     -2.430103
# 679     -0.491482
# 680    -13.867625
# 681      5.440605
# 1336    36.894271
# 1337    16.139928
# 1338    25.678128
# 1339    35.038243
# 1340    16.935651
# 1341    50.196981
# 1996     5.467535
# 1997     5.358104
# 1998     7.367169
# 1999   -13.075291
# 2000    10.850306
# 2001     9.085922
# 2656    -7.608829
# 2657   -14.930258
# 2658    -5.414245
# 2659     0.375746
# 2660   -17.038580
# 2661   -16.928904
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: 3.612413
#
#       Actual Team Performance  Predicted Team Performance
# 16                         67                   60.908643
# 17                         68                   66.558865
# 18                         67                   64.115886
# 19                         67                   67.564895
# ...

# %%
actual_predicted_LAC = pd.DataFrame({'Actual Team Performance': y_test_LAC.squeeze(), 'Predicted Team Performance': y_pred_LAC.flatten()})

print(((y_pred_LAC.flatten() - y_test_LAC.squeeze()) / y_test_LAC.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_LAC.flatten() - y_test_LAC.squeeze()) / y_test_LAC.squeeze()) * 100)))
print()
print(actual_predicted_LAC)
# Out:
# 214      2.852244
# 215     -4.137204
# 216     -7.651120
# 217    -26.852054
# 218      4.688500
# 219     -1.790588
# 874      0.727289
# 875      1.656297
# 876      9.662458
# 877      7.519540
# 878      1.797438
# 879     -0.690021
# 1534    -7.536781
# 1535    -9.691871
# 1536    14.955134
# 1537    -3.017956
# 1538    12.848201
# 1539     9.079688
# 2194     4.910679
# 2195     5.501967
# 2196     9.742556
# 2197    10.144921
# 2198     2.523133
# 2199    18.043983
# 2854    11.750195
# 2855    11.552637
# 2856    32.439784
# 2857    25.065140
# 2858    10.269204
# 2859    22.895467
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: 5.641962
#
#       Actual Team Performance  Predicted Team Performance
# 214                        70                   71.996571
# 215                        70                   67.103957
# 216                        69                   63.720728
# 217                        71                   51.935042
# ...

# %%
actual_predicted_UTAH = pd.DataFrame({'Actual Team Performance': y_test_UTAH.squeeze(), 'Predicted Team Performance': y_pred_UTAH.flatten()})

print(((y_pred_UTAH.flatten() - y_test_UTAH.squeeze()) / y_test_UTAH.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_UTAH.flatten() - y_test_UTAH.squeeze()) / y_test_UTAH.squeeze()) * 100)))
print()
print(actual_predicted_UTAH)
# Out:
# 104    -12.650012
# 105     -4.491761
# 106    -25.353759
# 107      2.978665
# 108     -2.612673
# 109     34.247016
# 764     -9.451698
# 765    -16.148352
# 766    -21.902808
# 767     -6.402432
# 768     -4.890129
# 769      6.880316
# 1424    12.029892
# 1425    -4.582463
# 1426   -23.410118
# 1427    31.539797
# 1428    -1.686420
# 1429     3.637260
# 2084   -20.496572
# 2085   -22.762456
# 2086   -26.326973
# 2087    -7.514707
# 2088   -26.053385
# 2089   -15.082700
# 2744     6.283890
# 2745    18.815477
# 2746     2.856824
# 2747    -2.638120
# 2748    -2.833030
# 2749    22.012386
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: -3.866968
#
#       Actual Team Performance  Predicted Team Performance
# 104                        32                   27.951996
# 105                        32                   30.562637
# 106                        31                   23.140335
# 107                        31                   31.923386
# ...

# %%
actual_predicted_OKC = pd.DataFrame({'Actual Team Performance': y_test_OKC.squeeze(), 'Predicted Team Performance': y_pred_OKC.flatten()})

print(((y_pred_OKC.flatten() - y_test_OKC.squeeze()) / y_test_OKC.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_OKC.flatten() - y_test_OKC.squeeze()) / y_test_OKC.squeeze()) * 100)))
print()
print(actual_predicted_OKC)
# Out:
# 82     -19.055505
# 83     -17.709839
# 84     -13.149206
# 85     -17.026851
# 86      -6.623978
# 87     -33.304457
# 742     23.474352
# 743     17.756754
# 744     19.257200
# 745     14.683686
# 746      3.379360
# 747     18.317129
# 1402    -7.240141
# 1403     5.051117
# 1404   -10.533005
# 1405   -14.072737
# 1406    -9.999610
# 1407   -21.018140
# 2062    11.630739
# 2063    11.984595
# 2064    18.686505
# 2065    -2.321146
# 2066    -9.673709
# 2067     7.740797
# 2722     1.021587
# 2723   -12.244952
# 2724    15.286279
# 2725    -6.530279
# 2726    -8.117971
# 2727    -1.359611
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: -1.390368
#
#       Actual Team Performance  Predicted Team Performance
# 82                         73                   59.089481
# 83                         74                   60.894719
# 84                         73                   63.401079
# 85                         72                   59.740667
# ...

# %%
actual_predicted_MEM = pd.DataFrame({'Actual Team Performance': y_test_MEM.squeeze(), 'Predicted Team Performance': y_pred_MEM.flatten()})

print(((y_pred_MEM.flatten() - y_test_MEM.squeeze()) / y_test_MEM.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_MEM.flatten() - y_test_MEM.squeeze()) / y_test_MEM.squeeze()) * 100)))
print()
print(actual_predicted_MEM)
# Out:
# 412       4.271080
# 413       4.807136
# 414       0.120244
# 415      -9.011580
# 416      11.458922
# 417       5.906579
# 1072    -19.631930
# 1073    -13.863128
# 1074    -21.156352
# 1075    -16.371192
# 1076    -12.233576
# 1077     -6.425391
# 1732    -14.577973
# 1733      0.385519
# 1734    -13.719100
# 1735      0.406712
# 1736      7.526466
# 1737    -14.153415
# 2392    -17.186922
# 2393    -10.001329
# 2394    -32.273533
# 2395     -9.413901
# 2396     -8.370087
# 2397    -13.092691
# 3052     42.727124
# 3053     76.613393
# 3054     58.116868
# 3055     83.326511
# 3056     57.689653
# 3057    133.986636
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: 8.528691
#
#       Actual Team Performance  Predicted Team Performance
# 412                        59                   61.519937
# 413                        60                   62.884282
# 414                        58                   58.069742
# ...

# %%
actual_predicted_POR = pd.DataFrame({'Actual Team Performance': y_test_POR.squeeze(), 'Predicted Team Performance': y_pred_POR.flatten()})

print(((y_pred_POR.flatten() - y_test_POR.squeeze()) / y_test_POR.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_POR.flatten() - y_test_POR.squeeze()) / y_test_POR.squeeze()) * 100)))
print()
print(actual_predicted_POR)
# Out:
# 60     -18.961440
# 61     -22.580437
# 62     -12.309192
# 63      15.082859
# 64      -2.081811
# 65       6.502944
# 720    -16.813530
# 721    -20.243882
# 722      8.970003
# 723     16.044270
# 724      0.655488
# 725    -21.403372
# 1380     2.890894
# 1381    -9.800294
# 1382     6.022589
# 1383    25.344505
# 1384    18.904264
# 1385     0.870702
# 2040    16.412692
# 2041    43.703705
# 2042    50.072416
# 2043    16.993371
# 2044     0.152749
# 2045     9.252349
# 2700   -55.836648
# 2701    -1.700713
# 2702    -2.138824
# 2703     0.190160
# 2704   -12.199041
# 2705   -13.966825
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: 0.934332
#
#       Actual Team Performance  Predicted Team Performance
# 60                         64                   51.864678
# 61                         64                   49.548520
# 62                         63                   55.245209
# 63                         64                   73.653030
# ...

# %%
actual_predicted_DEN = pd.DataFrame({'Actual Team Performance': y_test_DEN.squeeze(), 'Predicted Team Performance': y_pred_DEN.flatten()})

print(((y_pred_DEN.flatten() - y_test_DEN.squeeze()) / y_test_DEN.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_DEN.flatten() - y_test_DEN.squeeze()) / y_test_DEN.squeeze()) * 100)))
print()
print(actual_predicted_DEN)
# Out:
# 192      6.826412
# 193     12.871608
# 194     -1.675458
# 195      0.139716
# 196     13.586264
# 197     -6.208035
# 852     23.450946
# 853     19.049912
# 854     14.504585
# 855     23.938089
# 856     17.341965
# 857     34.211772
# 1512     9.859069
# 1513    -0.388480
# 1514     4.638587
# 1515     1.368711
# 1516    14.464819
# 1517    13.618883
# 2172    14.063987
# 2173     0.517450
# 2174     5.544073
# 2175     8.058962
# 2176     0.089075
# 2177     3.154012
# 2832     2.457005
# 2833    -8.717460
# 2834     1.901014
# 2835    -4.854026
# 2836   -12.680119
# 2837   -12.484383
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: 6.621632
#
#       Actual Team Performance  Predicted Team Performance
# 192                        44                   47.003621
# 193                        45                   50.792224
# 194                        43                   42.279553
# 195                        43                   43.060078
# ...

# %%
actual_predicted_NOP = pd.DataFrame({'Actual Team Performance': y_test_NOP.squeeze(), 'Predicted Team Performance': y_pred_NOP.flatten()})

print(((y_pred_NOP.flatten() - y_test_NOP.squeeze()) / y_test_NOP.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_NOP.flatten() - y_test_NOP.squeeze()) / y_test_NOP.squeeze()) * 100)))
print()
print(actual_predicted_NOP)
# Out:
# 126     16.519320
# 127     23.039287
# 128      5.056640
# 129     -6.924227
# 130     -8.796495
# 131     13.281461
# 786    -12.026022
# 787    -40.463073
# 788      3.184982
# 789     -9.209609
# 790    -20.192120
# 791    -16.146065
# 1446     3.057003
# 1447   -12.854488
# 1448    -9.954893
# 1449    17.871342
# 1450    -8.184729
# 1451    -5.817326
# 2106     4.628152
# 2107    18.073963
# 2108    -1.652717
# 2109    16.972212
# 2110    -6.764479
# 2111   -12.312789
# 2766   -19.222322
# 2767   -24.929158
# 2768   -12.881904
# 2769   -39.102269
# 2770   -13.336246
# 2771    13.883524
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: -4.840102
#
#       Actual Team Performance  Predicted Team Performance
# 126                        40                   46.607728
# 127                        42                   51.676500
# 128                        43                   45.174355
# 129                        42                   39.091825
# ...

# %%
actual_predicted_DAL = pd.DataFrame({'Actual Team Performance': y_test_DAL.squeeze(), 'Predicted Team Performance': y_pred_DAL.flatten()})

print(((y_pred_DAL.flatten() - y_test_DAL.squeeze()) / y_test_DAL.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_DAL.flatten() - y_test_DAL.squeeze()) / y_test_DAL.squeeze()) * 100)))
print()
print(actual_predicted_DAL)
# Out:
# 390      0.840467
# 391     14.012281
# 392     -8.835764
# 393     13.084030
# 394      2.795243
# 395      2.601508
# 1050     1.105296
# 1051   -20.641485
# 1052   -16.942246
# 1053    19.379601
# 1054    20.409185
# 1055    19.647136
# 1710     4.932270
# 1711    38.991140
# 1712     3.885944
# 1713    -7.320727
# 1714   -52.752699
# 1715   -40.672561
# 2370   -34.018820
# 2371   -30.855880
# 2372     4.903136
# 2373   -24.907010
# 2374   -31.904716
# 2375   -67.585953
# 3030    83.357723
# 3031    68.795289
# 3032    -0.015477
# 3033   -11.185347
# 3034   -33.018771
# 3035   -27.128967
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: -3.634873
#
#       Actual Team Performance  Predicted Team Performance
# 390                        59                   59.495876
# 391                        60                   68.407368
# 392                        58                   52.875257
# 393                        59                   66.719577
# ...

# %%
actual_predicted_SAC = pd.DataFrame({'Actual Team Performance': y_test_SAC.squeeze(), 'Predicted Team Performance': y_pred_SAC.flatten()})

print(((y_pred_SAC.flatten() - y_test_SAC.squeeze()) / y_test_SAC.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_SAC.flatten() - y_test_SAC.squeeze()) / y_test_SAC.squeeze()) * 100)))
print()
print(actual_predicted_SAC)
# Out:
# 368     22.112710
# 369     29.338071
# 370      0.095809
# 371     14.549093
# 372      7.591401
# 373     22.736296
# 1028    15.693532
# 1029    10.316267
# 1030    -5.575356
# 1031    16.815180
# 1032     5.354223
# 1033    21.871959
# 1688    -1.574932
# 1689    -8.837171
# 1690    11.898010
# 1691    -4.499154
# 1692    -0.489279
# 1693   -26.622602
# 2348     1.601919
# 2349     2.290057
# 2350   -13.530266
# 2351   -19.234211
# 2352     0.090335
# 2353    16.254296
# 3008    -2.978443
# 3009    12.280892
# 3010     5.979753
# 3011    -6.947356
# 3012    -5.088073
# 3013     5.743057
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: 4.241201
#
#       Actual Team Performance  Predicted Team Performance
# 368                        34                   41.518322
# 369                        35                   45.268325
# 370                        34                   34.032575
# 371                        35                   40.092182
# ...

# %%
actual_predicted_MIN = pd.DataFrame({'Actual Team Performance': y_test_MIN.squeeze(), 'Predicted Team Performance': y_pred_MIN.flatten()})

print(((y_pred_MIN.flatten() - y_test_MIN.squeeze()) / y_test_MIN.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_MIN.flatten() - y_test_MIN.squeeze()) / y_test_MIN.squeeze()) * 100)))
print()
print(actual_predicted_MIN)
# Out:
# 170     -2.767638
# 171    -17.834363
# 172     -9.266219
# 173    -13.317780
# 174    -39.435064
# 175     -2.102280
# 830     61.091216
# 831     42.502502
# 832    -10.592902
# 833     18.605915
# 834     68.890437
# 835     71.538815
# 1490    -1.303874
# 1491    35.879834
# 1492    33.977731
# 1493    12.740843
# 1494    32.769833
# 1495    56.124470
# 2150     5.798626
# 2151   -31.666736
# 2152    -3.445956
# 2153    18.105248
# 2154     8.356601
# 2155    31.480831
# 2810   -15.829781
# 2811   -25.669602
# 2812    -0.343821
# 2813    -8.819597
# 2814   -22.307957
# 2815     0.241234
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: 9.780019
#
#       Actual Team Performance  Predicted Team Performance
# 170                        53                   51.533152
# 171                        52                   42.726131
# 172                        52                   47.181566
# 173                        52                   45.074755
# ...

# %%
actual_predicted_LAL = pd.DataFrame({'Actual Team Performance': y_test_LAL.squeeze(), 'Predicted Team Performance': y_pred_LAL.flatten()})

print(((y_pred_LAL.flatten() - y_test_LAL.squeeze()) / y_test_LAL.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_LAL.flatten() - y_test_LAL.squeeze()) / y_test_LAL.squeeze()) * 100)))
print()
print(actual_predicted_LAL)
# Out:
# 346    -19.756448
# 347      2.428104
# 348      0.182338
# 349     20.517867
# 350      4.630389
# 351     11.931092
# 1006    11.802864
# 1007    50.642558
# 1008    30.283112
# 1009   -30.822389
# 1010    44.445054
# 1011    12.813984
# 1666    37.540149
# 1667    35.146082
# 1668    29.497618
# 1669    -5.464263
# 1670   -21.227510
# 1671    63.913337
# 2326    21.473086
# 2327    -1.848418
# 2328     9.811245
# 2329     5.734002
# 2330     4.299012
# 2331    -3.667881
# 2986    -7.401212
# 2987   -24.456732
# 2988    -7.664315
# 2989    -6.205204
# 2990   -16.453783
# 2991   -15.587482
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: 7.884542
#
#       Actual Team Performance  Predicted Team Performance
# 346                        32                   25.677937
# 347                        34                   34.825555
# 348                        34                   34.061995
# 349                        32                   38.565717
# ...

# %%
actual_predicted_PHO = pd.DataFrame({'Actual Team Performance': y_test_PHO.squeeze(), 'Predicted Team Performance': y_pred_PHO.flatten()})

print(((y_pred_PHO.flatten() - y_test_PHO.squeeze()) / y_test_PHO.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_PHO.flatten() - y_test_PHO.squeeze()) / y_test_PHO.squeeze()) * 100)))
print()
print(actual_predicted_PHO)
# Out:
# 434    -42.790377
# 435    -25.724025
# 436      3.897552
# 437    -38.054556
# 438    -28.792620
# 439    -21.984132
# 1094   -11.152297
# 1095     5.595603
# 1096   -15.498638
# 1097   -16.431146
# 1098   -24.031885
# 1099    11.160583
# 1754    38.024738
# 1755    47.894843
# 1756    30.034138
# 1757    58.843151
# 1758    59.959680
# 1759    67.110576
# 2414    -5.669179
# 2415    17.105121
# 2416   -41.328432
# 2417    76.125886
# 2418    30.719662
# 2419    40.022698
# 3074     6.983334
# 3075   -44.465594
# 3076     1.067688
# 3077    92.031180
# 3078    73.438900
# 3079    64.334778
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: 13.614241
#
#       Actual Team Performance  Predicted Team Performance
# 434                        58                   33.181581
# 435                        60                   44.565585
# 436                        61                   63.377507
# 437                        60                   37.167266
# ...

# %%
actual_predicted_BOS = pd.DataFrame({'Actual Team Performance': y_test_BOS.squeeze(), 'Predicted Team Performance': y_pred_BOS.flatten()})

print(((y_pred_BOS.flatten() - y_test_BOS.squeeze()) / y_test_BOS.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_BOS.flatten() - y_test_BOS.squeeze()) / y_test_BOS.squeeze()) * 100)))
print()
print(actual_predicted_BOS)
# Out:
# 258     22.201992
# 259     30.040494
# 260     11.063764
# 261     13.955237
# 262     30.498102
# 263     71.230445
# 918     22.815940
# 919     20.178476
# 920      2.926545
# 921     13.261049
# 922      0.629825
# 923      9.496944
# 1578    -4.524950
# 1579   -25.909819
# 1580    -6.784952
# 1581   -20.691761
# 1582     0.741953
# 1583   -29.199394
# 2238    -2.389276
# 2239     2.930864
# 2240    13.910570
# 2241    -9.194557
# 2242     7.679919
# 2243    34.514375
# 2898    10.606667
# 2899   -16.502885
# 2900   -20.727465
# 2901   -35.510853
# 2902   -26.892003
# 2903   -12.187376
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: 3.605596
#
#       Actual Team Performance  Predicted Team Performance
# 258                        32                   39.104637
# 259                        32                   41.612958
# 260                        31                   34.429767
# 261                        30                   34.186571
# ...

# %%
actual_predicted_CLE = pd.DataFrame({'Actual Team Performance': y_test_CLE.squeeze(), 'Predicted Team Performance': y_pred_CLE.flatten()})

print(((y_pred_CLE.flatten() - y_test_CLE.squeeze()) / y_test_CLE.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_CLE.flatten() - y_test_CLE.squeeze()) / y_test_CLE.squeeze()) * 100)))
print()
print(actual_predicted_CLE)
# Out:
# 302     35.145612
# 303     36.843635
# 304      8.944750
# 305    -10.398540
# 306      9.189800
# 307      3.157929
# 962     -4.502354
# 963      0.472308
# 964     -2.384571
# 965      2.744493
# 966      3.315499
# 967      0.091864
# 1622    -3.501465
# 1623    -5.644094
# 1624    -0.231621
# 1625    14.173241
# 1626    -6.981560
# 1627   -13.342102
# 2282    12.215266
# 2283    -2.903027
# 2284   -10.304139
# 2285    26.153715
# 2286    18.990466
# 2287    16.543503
# 2942     6.987358
# 2943    24.293353
# 2944    -1.430813
# 2945    -3.712129
# 2946     8.581617
# 2947    12.907410
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: 5.847180
#
#       Actual Team Performance  Predicted Team Performance
# 302                        38                   51.355332
# 303                        37                   50.632145
# 304                        39                   42.488453
# 305                        40                   35.840584
# ...

# %%
actual_predicted_TOR = pd.DataFrame({'Actual Team Performance': y_test_TOR.squeeze(), 'Predicted Team Performance': y_pred_TOR.flatten()})

print(((y_pred_TOR.flatten() - y_test_TOR.squeeze()) / y_test_TOR.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_TOR.flatten() - y_test_TOR.squeeze()) / y_test_TOR.squeeze()) * 100)))
print()
print(actual_predicted_TOR)
# Out:
# 236      2.585146
# 237     13.531416
# 238      2.784495
# 239      6.013514
# 240      7.352401
# 241     10.968831
# 896     14.304458
# 897     10.510078
# 898      0.471337
# 899     -0.839029
# 900      2.029465
# 901      3.089200
# 1556   -12.574939
# 1557    -8.437283
# 1558    -3.054780
# 1559   -10.163953
# 1560    -4.418058
# 1561    -2.539980
# 2216     5.433891
# 2217    11.604755
# 2218    16.771323
# 2219    24.544845
# 2220     0.095064
# 2221     8.187084
# 2876    -1.076896
# 2877    -3.648639
# 2878    -6.184127
# 2879    -9.653921
# 2880    -8.188354
# 2881     1.479553
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: 2.365897
#
#       Actual Team Performance  Predicted Team Performance
# 236                        56                   57.447682
# 237                        55                   62.442279
# 238                        57                   58.587162
# 239                        57                   60.427703
# ...

# %%
actual_predicted_WAS = pd.DataFrame({'Actual Team Performance': y_test_WAS.squeeze(), 'Predicted Team Performance': y_pred_WAS.flatten()})

print(((y_pred_WAS.flatten() - y_test_WAS.squeeze()) / y_test_WAS.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_WAS.flatten() - y_test_WAS.squeeze()) / y_test_WAS.squeeze()) * 100)))
print()
print(actual_predicted_WAS)
# Out:
# 500     -6.072209
# 501      5.979920
# 502      6.200104
# 503      4.670047
# 504      7.120564
# 505     14.251572
# 1160    16.536791
# 1161    -9.402171
# 1162     8.936583
# 1163    27.699020
# 1164     2.258277
# 1165    12.328992
# 1820    21.879297
# 1821     0.220223
# 1822    17.106287
# 1823     7.569203
# 1824    13.107384
# 1825    22.918371
# 2480   -19.136363
# 2481   -25.906470
# 2482     4.796998
# 2483   -15.840841
# 2484   -17.141893
# 2485     1.250239
# 3140     0.072768
# 3141     2.269803
# 3142    -3.104232
# 3143     0.952174
# 3144     2.658062
# 3145   -11.424014
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: 3.091816
#
#       Actual Team Performance  Predicted Team Performance
# 500                        52                   48.842451
# 501                        51                   54.049759
# 502                        52                   55.224054
# 503                        52                   54.428424
# ...

# %%
actual_predicted_ATL = pd.DataFrame({'Actual Team Performance': y_test_ATL.squeeze(), 'Predicted Team Performance': y_pred_ATL.flatten()})

print(((y_pred_ATL.flatten() - y_test_ATL.squeeze()) / y_test_ATL.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_ATL.flatten() - y_test_ATL.squeeze()) / y_test_ATL.squeeze()) * 100)))
print()
print(actual_predicted_ATL)
# Out:
# 654    -40.264881
# 655    -38.294183
# 656    -11.615034
# 657     12.043598
# 658     24.229836
# 659     20.555694
# 1314   -17.975303
# 1315   -27.593004
# 1316    -3.352480
# 1317    -5.567246
# 1318     8.271070
# 1319   -19.304344
# 1974    23.596010
# 1975   -14.928884
# 1976   -12.220296
# 1977    15.564081
# 1978   -17.571331
# 1979     2.369795
# 2634     2.501958
# 2635   -19.311473
# 2636   -12.315747
# 2637   -12.118138
# 2638     4.894033
# 2639    -5.969148
# 3294    48.295830
# 3295    61.180933
# 3296    65.947313
# 3297    45.601662
# 3298    86.877654
# 3299    30.585257
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: 6.470441
#
#       Actual Team Performance  Predicted Team Performance
# 654                        46                   27.478155
# 655                        44                   27.150560
# 656                        43                   38.005535
# 657                        44                   49.299183
# ...

# %%
actual_predicted_MIL = pd.DataFrame({'Actual Team Performance': y_test_MIL.squeeze(), 'Predicted Team Performance': y_pred_MIL.flatten()})

print(((y_pred_MIL.flatten() - y_test_MIL.squeeze()) / y_test_MIL.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_MIL.flatten() - y_test_MIL.squeeze()) / y_test_MIL.squeeze()) * 100)))
print()
print(actual_predicted_MIL)
# Out:
# 478      63.974404
# 479     188.510719
# 480      91.111807
# 481     139.075084
# 482      94.738735
# 483     101.686082
# 1138    -17.825812
# 1139     -3.590758
# 1140    -26.496087
# 1141     -6.180134
# 1142    -19.724610
# 1143    -17.544941
# 1798     -4.877019
# 1799    -34.478488
# 1800     -0.828542
# 1801      0.991532
# 1802     -4.525118
# 1803     21.877340
# 2458     -5.243655
# 2459      4.156196
# 2460     -0.056763
# 2461     13.133448
# 2462    -16.088675
# 2463     -2.837725
# 3118      3.809811
# 3119     19.540906
# 3120     16.144416
# 3121     18.300609
# 3122      4.179230
# 3123     18.589392
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: 21.317379
#
#       Actual Team Performance  Predicted Team Performance
# 478                        19                   31.155137
# 479                        18                   51.931929
# 480                        19                   36.311243
# ...

# %%
actual_predicted_IND = pd.DataFrame({'Actual Team Performance': y_test_IND.squeeze(), 'Predicted Team Performance': y_pred_IND.flatten()})

print(((y_pred_IND.flatten() - y_test_IND.squeeze()) / y_test_IND.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_IND.flatten() - y_test_IND.squeeze()) / y_test_IND.squeeze()) * 100)))
print()
print(actual_predicted_IND)
# Out:
# 324    -13.512534
# 325    -21.377232
# 326    -23.501826
# 327    -23.369515
# 328    -19.824627
# 329    -13.939556
# 984      7.917771
# 985     19.965104
# 986     13.608026
# 987     36.248595
# 988     51.196677
# 989     20.756611
# 1644     4.269682
# 1645    -7.390924
# 1646    15.883215
# 1647    20.829467
# 1648    -4.490325
# 1649    30.223818
# 2304    -7.395145
# 2305     6.562090
# 2306    17.994656
# 2307     1.806218
# 2308    -1.321772
# 2309    36.129888
# 2964    -7.370343
# 2965   -21.063467
# 2966    -4.983388
# 2967     4.311020
# 2968    -3.711435
# 2969   -18.463127
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: 3.199587
#
#       Actual Team Performance  Predicted Team Performance
# 324                        74                   64.000725
# 325                        72                   56.608393
# 326                        71                   54.313703
# 327                        69                   52.875035
# ...

# %%
actual_predicted_CHI = pd.DataFrame({'Actual Team Performance': y_test_CHI.squeeze(), 'Predicted Team Performance': y_pred_CHI.flatten()})

print(((y_pred_CHI.flatten() - y_test_CHI.squeeze()) / y_test_CHI.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_CHI.flatten() - y_test_CHI.squeeze()) / y_test_CHI.squeeze()) * 100)))
print()
print(actual_predicted_CHI)
# Out:
# 610     -1.996153
# 611      2.889684
# 612      1.241399
# 613     -5.761779
# 614    -10.729091
# 615    -12.022151
# 1270   -33.440812
# 1271   -21.002545
# 1272    -2.337662
# 1273   -11.462370
# 1274   -24.401829
# 1275   -12.177013
# 1930     5.093388
# 1931     3.409624
# 1932   -18.196338
# 1933   -14.949523
# 1934   -10.673685
# 1935    13.583980
# 2590   -45.065211
# 2591     5.966703
# 2592     7.555417
# 2593    12.390820
# 2594    -9.183960
# 2595    23.548690
# 3250    -1.092373
# 3251    -9.728541
# 3252    -5.109970
# 3253   -29.884483
# 3254    19.080129
# 3255    -9.479975
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: -6.464521
#
#       Actual Team Performance  Predicted Team Performance
# 610                        55                   53.902116
# 611                        55                   56.589326
# 612                        56                   56.695183
# 613                        57                   53.715786
# ...

# %%
actual_predicted_MIA = pd.DataFrame({'Actual Team Performance': y_test_MIA.squeeze(), 'Predicted Team Performance': y_pred_MIA.flatten()})

print(((y_pred_MIA.flatten() - y_test_MIA.squeeze()) / y_test_MIA.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_MIA.flatten() - y_test_MIA.squeeze()) / y_test_MIA.squeeze()) * 100)))
print()
print(actual_predicted_MIA)
# Out:
# 456     -6.825252
# 457    -22.341958
# 458     -5.760239
# 459    -15.273125
# 460     -9.429666
# 461    -27.031571
# 1116    34.209569
# 1117    -4.385846
# 1118     6.793851
# 1119    16.319492
# 1120    10.836027
# 1121    10.666360
# 1776    23.375571
# 1777    10.907557
# 1778    21.627834
# 1779    -9.701960
# 1780     6.315362
# 1781    -2.246646
# 2436     5.605496
# 2437    31.129269
# 2438    15.483029
# 2439    -0.839409
# 2440     5.809580
# 2441    17.033191
# 3096     0.865412
# 3097   -22.852133
# 3098     4.902159
# 3099    -5.171198
# 3100   -17.498178
# 3101    -8.414736
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: 2.136928
#
#       Actual Team Performance  Predicted Team Performance
# 456                        70                   65.222324
# 457                        68                   52.807468
# 458                        69                   65.025435
# 459                        69                   58.461544
# ...

# %%
actual_predicted_DET = pd.DataFrame({'Actual Team Performance': y_test_DET.squeeze(), 'Predicted Team Performance': y_pred_DET.flatten()})

print(((y_pred_DET.flatten() - y_test_DET.squeeze()) / y_test_DET.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_DET.flatten() - y_test_DET.squeeze()) / y_test_DET.squeeze()) * 100)))
print()
print(actual_predicted_DET)
# Out:
# 522     30.572319
# 523     33.477226
# 524     14.273113
# 525     19.667543
# 526     28.549908
# 527     52.856796
# 1182    14.000938
# 1183    18.604002
# 1184     9.758138
# 1185   -14.294140
# 1186    13.561458
# 1187    30.984064
# 1842     5.058938
# 1843     6.543492
# 1844    -5.512170
# 1845   -12.632235
# 1846    -7.033237
# 1847     7.689035
# 2502     8.457811
# 2503    -9.594476
# 2504    -0.971001
# 2505     0.366710
# 2506    22.971968
# 2507    22.996236
# 3162    12.909192
# 3163    19.425900
# 3164    21.984317
# 3165    24.027847
# 3166    25.678952
# 3167    16.033402
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: 13.680401
#
#       Actual Team Performance  Predicted Team Performance
# 522                        37                   48.311758
# 523                        37                   49.386574
# 524                        35                   39.995590
# 525                        35                   41.883640
# ...

# %%
actual_predicted_CHA = pd.DataFrame({'Actual Team Performance': y_test_CHA.squeeze(), 'Predicted Team Performance': y_pred_CHA.flatten()})

print(((y_pred_CHA.flatten() - y_test_CHA.squeeze()) / y_test_CHA.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_CHA.flatten() - y_test_CHA.squeeze()) / y_test_CHA.squeeze()) * 100)))
print()
print(actual_predicted_CHA)
# Out:
# 544     -4.772319
# 545      1.487233
# 546    -12.135342
# 547     -5.753810
# 548     -8.542521
# 549     -6.501158
# 1204   -21.196412
# 1205     0.390033
# 1206    21.196794
# 1207    -3.683839
# 1208    -4.961861
# 1209     2.528173
# 1864    -5.870185
# 1865   -24.654788
# 1866   -12.047829
# 1867    -6.163313
# 1868   -16.099937
# 1869   -10.903678
# 2524    26.929033
# 2525     1.728016
# 2526    11.297183
# 2527     9.380766
# 2528     1.572846
# 2529    -5.537043
# 3184     6.752888
# 3185    23.502266
# 3186    19.746377
# 3187     9.418304
# 3188     5.546604
# 3189    32.565801
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: 0.840609
#
#       Actual Team Performance  Predicted Team Performance
# 544                        49                   46.661564
# 545                        48                   48.713872
# 546                        47                   41.296389
# 547                        50                   47.123095
# ...

# %%
actual_predicted_NYK = pd.DataFrame({'Actual Team Performance': y_test_NYK.squeeze(), 'Predicted Team Performance': y_pred_NYK.flatten()})

print(((y_pred_NYK.flatten() - y_test_NYK.squeeze()) / y_test_NYK.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_NYK.flatten() - y_test_NYK.squeeze()) / y_test_NYK.squeeze()) * 100)))
print()
print(actual_predicted_NYK)
# Out:
# 566      23.793672
# 567     -21.634900
# 568     -45.586095
# 569     -18.887136
# 570     -38.472418
# 571     -26.934545
# 1226     75.745162
# 1227      9.257886
# 1228     16.051430
# 1229     55.895957
# 1230    100.959745
# 1231     53.277438
# 1886      9.755999
# 1887    -22.375604
# 1888     18.677292
# 1889    -14.041070
# 1890      2.038565
# 1891      3.642692
# 2546     -4.154025
# 2547     15.524581
# 2548     -1.699525
# 2549      3.895673
# 2550     -2.810015
# 2551    -18.210052
# 3206      4.934418
# 3207     55.610862
# 3208     27.934220
# 3209     32.539989
# 3210     27.071737
# 3211     20.853856
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: 11.421860
#
#       Actual Team Performance  Predicted Team Performance
# 566                        40                   49.517469
# 567                        41                   32.129691
# 568                        41                   22.309701
# ...

# %%
actual_predicted_ORL = pd.DataFrame({'Actual Team Performance': y_test_ORL.squeeze(), 'Predicted Team Performance': y_pred_ORL.flatten()})

print(((y_pred_ORL.flatten() - y_test_ORL.squeeze()) / y_test_ORL.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_ORL.flatten() - y_test_ORL.squeeze()) / y_test_ORL.squeeze()) * 100)))
print()
print(actual_predicted_ORL)
# Out:
# 632     35.024947
# 633     -4.428715
# 634     42.582401
# 635     -6.165558
# 636     41.573151
# 637     -7.960599
# 1292    -1.712336
# 1293    25.355298
# 1294     0.869833
# 1295    28.629444
# 1296    36.804585
# 1297    10.005650
# 1952   -17.706569
# 1953   -23.291181
# 1954    -3.421773
# 1955    15.831743
# 1956    -9.906846
# 1957   -12.979394
# 2612    -3.737770
# 2613     7.580544
# 2614    35.267869
# 2615    22.568123
# 2616    22.678274
# 2617    10.442950
# 3272    16.995184
# 3273    11.941599
# 3274    61.170151
# 3275    64.429463
# 3276    53.207289
# 3277    33.643957
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: 16.176390
#
#       Actual Team Performance  Predicted Team Performance
# 632                        28                   37.806985
# 633                        27                   25.804247
# 634                        27                   38.497248
# 635                        26                   24.396955
# ...

# %%
actual_predicted_PHI = pd.DataFrame({'Actual Team Performance': y_test_PHI.squeeze(), 'Predicted Team Performance': y_pred_PHI.flatten()})

print(((y_pred_PHI.flatten() - y_test_PHI.squeeze()) / y_test_PHI.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_PHI.flatten() - y_test_PHI.squeeze()) / y_test_PHI.squeeze()) * 100)))
print()
print(actual_predicted_PHI)
# Out:
# 280     -76.788560
# 281     -55.086309
# 282      35.974847
# 283      -5.494391
# 284      54.770930
# 285      85.189803
# 940     -26.902387
# 941     -56.082191
# 942       4.202032
# 943     -27.928746
# 944     -88.944185
# 945     -13.990193
# 1600    127.823336
# 1601     55.599975
# 1602     44.044772
# 1603     15.564073
# 1604     68.299180
# 1605     90.834745
# 2260     18.584406
# 2261     25.801951
# 2262    -19.853274
# 2263    -34.876336
# 2264    -43.365648
# 2265    -36.619233
# 2920     -9.102353
# 2921    -15.355791
# 2922     12.555966
# 2923     -8.270383
# 2924     12.318451
# 2925      3.816959
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: 4.557382
#
#       Actual Team Performance  Predicted Team Performance
# 280                        22                    5.106517
# 281                        21                    9.431875
# 282                        21                   28.554718
# ...

# %%
actual_predicted_BKN = pd.DataFrame({'Actual Team Performance': y_test_BKN.squeeze(), 'Predicted Team Performance': y_pred_BKN.flatten()})

print(((y_pred_BKN.flatten() - y_test_BKN.squeeze()) / y_test_BKN.squeeze()) * 100)
print()
print('Team Performance Mean Error: %f' % (np.mean(((y_pred_BKN.flatten() - y_test_BKN.squeeze()) / y_test_BKN.squeeze()) * 100)))
print()
print(actual_predicted_BKN)
# Out:
# 588    -21.818197
# 589    -27.909562
# 590    -18.843862
# 591    -30.572402
# 592    -24.884168
# 593    -22.467650
# 1248   -21.654838
# 1249   -27.337789
# 1250   -17.745335
# 1251   -13.669836
# 1252   -12.508418
# 1253   -30.837469
# 1908     0.644321
# 1909    25.809073
# 1910    24.813218
# 1911    43.151743
# 1912    27.075823
# 1913    41.344095
# 2568    66.957407
# 2569    41.632463
# 2570    44.317786
# 2571    46.829521
# 2572    27.908282
# 2573    56.062532
# 3228     4.411767
# 3229    18.349445
# 3230    -8.868694
# 3231    24.035871
# 3232    22.857853
# 3233    44.430251
# Name: Team Performance, dtype: float64
#
# Team Performance Mean Error: 9.383774
#
#       Actual Team Performance  Predicted Team Performance
# 588                        47                   36.745447
# 589                        47                   33.882506
# 590                        49                   39.766508
# 591                        50                   34.713799
# ...

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_GSW.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_GSW.flatten())]
    }
)

difference.insert(0, "Team", "Golden State Warriors")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#                     Team  Target Team Efficiency Mean  \
# 0  Golden State Warriors                    76.833333
#
#    Team Efficiency Predicted Mean  Difference Between Target and Predicted
# 0                       78.510911                                 1.677578

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_SAS.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_SAS.flatten())]
    }
)

difference.insert(0, "Team", "San Antonio Spurs")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#                 Team  Target Team Efficiency Mean  \
# 0  San Antonio Spurs                    71.533333
#
#    Team Efficiency Predicted Mean  Difference Between Target and Predicted
# 0                       72.768767                                 1.235433

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_HOU.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_HOU.flatten())]
    }
)

difference.insert(0, "Team", "Houston Rockets")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#               Team  Target Team Efficiency Mean  \
# 0  Houston Rockets                    66.166667
#
#    Team Efficiency Predicted Mean  Difference Between Target and Predicted
# 0                       67.260649                                 1.093983

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_LAC.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_LAC.flatten())]
    }
)

difference.insert(0, "Team", "Los Angeles Clippers")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#                    Team  Target Team Efficiency Mean  \
# 0  Los Angeles Clippers                    62.033333
#
#    Team Efficiency Predicted Mean  Difference Between Target and Predicted
# 0                        65.08272                                 3.049387

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_UTAH.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_UTAH.flatten())]
    }
)

difference.insert(0, "Team", "Utah Jazz")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#         Team  Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0  Utah Jazz                    48.366667                       46.238555
#
#    Difference Between Target and Predicted
# 0                                 2.128112

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_OKC.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_OKC.flatten())]
    }
)

difference.insert(0, "Team", "Oklahoma City Thunder")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#                     Team  Target Team Efficiency Mean  \
# 0  Oklahoma City Thunder                         61.9
#
#    Team Efficiency Predicted Mean  Difference Between Target and Predicted
# 0                       60.298225                                 1.601775

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_MEM.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_MEM.flatten())]
    }
)

difference.insert(0, "Team", "Memphis Grizzlies")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#                 Team  Target Team Efficiency Mean  \
# 0  Memphis Grizzlies                         52.5
#
#    Team Efficiency Predicted Mean  Difference Between Target and Predicted
# 0                       52.512813                                 0.012813

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_POR.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_POR.flatten())]
    }
)

difference.insert(0, "Team", "Portland Trailblazers")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#                     Team  Target Team Efficiency Mean  \
# 0  Portland Trailblazers                    57.633333
#
#    Team Efficiency Predicted Mean  Difference Between Target and Predicted
# 0                       57.388759                                 0.244575

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_DEN.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_DEN.flatten())]
    }
)

difference.insert(0, "Team", "Denver Nuggets")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#              Team  Target Team Efficiency Mean  \
# 0  Denver Nuggets                    44.666667
#
#    Team Efficiency Predicted Mean  Difference Between Target and Predicted
# 0                       47.122266                                   2.4556

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_NOP.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_NOP.flatten())]
    }
)

difference.insert(0, "Team", "New Orleans Pelicans")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#                    Team  Target Team Efficiency Mean  \
# 0  New Orleans Pelicans                    46.033333
#
#    Team Efficiency Predicted Mean  Difference Between Target and Predicted
# 0                       43.212225                                 2.821109

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_DAL.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_DAL.flatten())]
    }
)

difference.insert(0, "Team", "Dallas Mavericks")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#                Team  Target Team Efficiency Mean  \
# 0  Dallas Mavericks                         48.3
#
#    Team Efficiency Predicted Mean  Difference Between Target and Predicted
# 0                       46.655134                                 1.644866

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_SAC.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_SAC.flatten())]
    }
)

difference.insert(0, "Team", "Sacramento Kings")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#                Team  Target Team Efficiency Mean  \
# 0  Sacramento Kings                    35.433333
#
#    Team Efficiency Predicted Mean  Difference Between Target and Predicted
# 0                       36.820523                                  1.38719

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_MIN.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_MIN.flatten())]
    }
)

difference.insert(0, "Team", "Minnesota Timberwolves")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#                      Team  Target Team Efficiency Mean  \
# 0  Minnesota Timberwolves                    40.166667
#
#    Team Efficiency Predicted Mean  Difference Between Target and Predicted
# 0                       41.245712                                 1.079046

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_LAL.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_LAL.flatten())]
    }
)

difference.insert(0, "Team", "Los Angeles Lakers")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#                  Team  Target Team Efficiency Mean  \
# 0  Los Angeles Lakers                    30.233333
#
#    Team Efficiency Predicted Mean  Difference Between Target and Predicted
# 0                       31.650495                                 1.417162

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_PHO.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_PHO.flatten())]
    }
)

difference.insert(0, "Team", "Phoenix Suns")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#            Team  Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0  Phoenix Suns                    38.366667                       39.838858
#
#    Difference Between Target and Predicted
# 0                                 1.472191

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_BOS.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_BOS.flatten())]
    }
)

difference.insert(0, "Team", "Boston Celtics")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#              Team  Target Team Efficiency Mean  \
# 0  Boston Celtics                         52.9
#
#    Team Efficiency Predicted Mean  Difference Between Target and Predicted
# 0                       52.815965                                 0.084035

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_CLE.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_CLE.flatten())]
    }
)

difference.insert(0, "Team", "Toronto Raptors")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#               Team  Target Team Efficiency Mean  \
# 0  Toronto Raptors                         59.4
#
#    Team Efficiency Predicted Mean  Difference Between Target and Predicted
# 0                       62.309598                                 2.909598

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_TOR.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_TOR.flatten())]
    }
)

difference.insert(0, "Team", "Toronto Raptors")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#               Team  Target Team Efficiency Mean  \
# 0  Toronto Raptors                    63.133333
#
#    Team Efficiency Predicted Mean  Difference Between Target and Predicted
# 0                       64.274697                                 1.141364

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_WAS.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_WAS.flatten())]
    }
)

difference.insert(0, "Team", "Washington Wizards")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#                  Team  Target Team Efficiency Mean  \
# 0  Washington Wizards                    54.333333
#
#    Team Efficiency Predicted Mean  Difference Between Target and Predicted
# 0                       55.737106                                 1.403772

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_ATL.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_ATL.flatten())]
    }
)

difference.insert(0, "Team", "Atlanta Hawks")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#             Team  Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0  Atlanta Hawks                    51.566667                       51.770161
#
#    Difference Between Target and Predicted
# 0                                 0.203495

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_MIL.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_MIL.flatten())]
    }
)

difference.insert(0, "Team", "Milwaukee Bucks")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#               Team  Target Team Efficiency Mean  \
# 0  Milwaukee Bucks                    42.433333
#
#    Team Efficiency Predicted Mean  Difference Between Target and Predicted
# 0                       46.046751                                 3.613418

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_IND.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_IND.flatten())]
    }
)

difference.insert(0, "Team", "Indiana Pacers")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#              Team  Target Team Efficiency Mean  \
# 0  Indiana Pacers                         55.0
#
#    Team Efficiency Predicted Mean  Difference Between Target and Predicted
# 0                       55.467285                                 0.467285

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_CHI.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_CHI.flatten())]
    }
)

difference.insert(0, "Team", "Chicago Bulls")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#             Team  Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0  Chicago Bulls                    49.433333                       46.059138
#
#    Difference Between Target and Predicted
# 0                                 3.374195

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_MIA.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_MIA.flatten())]
    }
)

difference.insert(0, "Team", "Miami Heat")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#          Team  Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0  Miami Heat                         54.4                       54.890283
#
#    Difference Between Target and Predicted
# 0                                 0.490283

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_DET.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_DET.flatten())]
    }
)

difference.insert(0, "Team", "Detroit Pistons")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#               Team  Target Team Efficiency Mean  \
# 0  Detroit Pistons                         43.5
#
#    Team Efficiency Predicted Mean  Difference Between Target and Predicted
# 0                       48.948761                                 5.448761

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_CHA.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_CHA.flatten())]
    }
)

difference.insert(0, "Team", "Charlotte Hornets")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#                 Team  Target Team Efficiency Mean  \
# 0  Charlotte Hornets                         47.1
#
#    Team Efficiency Predicted Mean  Difference Between Target and Predicted
# 0                       47.034451                                 0.065549

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_NYK.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_NYK.flatten())]
    }
)

difference.insert(0, "Team", "New York Knicks")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#               Team  Target Team Efficiency Mean  \
# 0  New York Knicks                    34.666667
#
#    Team Efficiency Predicted Mean  Difference Between Target and Predicted
# 0                       36.666794                                 2.000127

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_ORL.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_ORL.flatten())]
    }
)

difference.insert(0, "Team", "Orlando Magic")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#             Team  Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0  Orlando Magic                    32.766667                       37.461981
#
#    Difference Between Target and Predicted
# 0                                 4.695314

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_PHI.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_PHI.flatten())]
    }
)

difference.insert(0, "Team", "Philadelphia 76ers")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#                  Team  Target Team Efficiency Mean  \
# 0  Philadelphia 76ers                         30.2
#
#    Team Efficiency Predicted Mean  Difference Between Target and Predicted
# 0                       29.479558                                 0.720442

# %%
#check differences, not R^2

difference = pd.DataFrame(
    {
       "Target Team Efficiency Mean" : [np.mean(y_test_BKN.squeeze())],
       "Team Efficiency Predicted Mean" : [np.mean(y_pred_BKN.flatten())]
    }
)

difference.insert(0, "Team", "Brooklyn Nets")
difference.insert(3, "Difference Between Target and Predicted", abs(difference['Team Efficiency Predicted Mean'] - difference['Target Team Efficiency Mean']))

difference
# Out:
#             Team  Target Team Efficiency Mean  Team Efficiency Predicted Mean  \
# 0  Brooklyn Nets                         34.6                       35.030347
#
#    Difference Between Target and Predicted
# 0                                 0.430347

# %%
east_seeding = ['E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8', 'E9', 'E10', 'E11', 'E12', 'E13', 'E14', 'E15']
west_seeding = ['W1', 'W2', 'W3', 'W4', 'W5', 'W6', 'W7', 'W8', 'W9', 'W10', 'W11', 'W12', 'W13', 'W14', 'W15']
classification = ['Finalist', 'Semi-Finalist', 'Playoffs Maker', 'Playoffs Maker', 'Playoffs Maker', 'Playoffs Maker', 'Playoffs Maker', 'Playoffs Maker',
                 'Did not make Playoffs', 'Did not make Playoffs', 'Did not make Playoffs', 'Did not make Playoffs', 'Did not make Playoffs', 'Did not make Playoffs'
                 , 'Did not make Playoffs']
class_dict = {'Finalist': 1, 'Semi-Finalist': 2, 'Playoffs Maker': 3, 'Did not make Playoffs' : 4}

# %%
ECF = pd.DataFrame(
  {
      "Team": ['Atlanta', 'Boston', 'Brooklyn', 'Charlotte', 'Chicago', 
               'Cleveland', 'Detroit', 'Indiana','Miami', 'Milwaukee', 'New York',
              'Orlando', 'Philadelphia', 'Toronto', 'Washington'],
      "Team Efficiency (Predicted Average)": [np.mean(y_pred_ATL.flatten()),
                                           np.mean(y_pred_BOS.flatten()), np.mean(y_pred_BKN.flatten()),
                                           np.mean(y_pred_CHA.flatten()), np.mean(y_pred_CHI.flatten()),
                                           np.mean(y_pred_CLE.flatten()), np.mean(y_pred_DET.flatten()),
                                           np.mean(y_pred_IND.flatten()), np.mean(y_pred_MIA.flatten()),
                                           np.mean(y_pred_MIL.flatten()), np.mean(y_pred_NYK.flatten()),
                                           np.mean(y_pred_ORL.flatten()), np.mean(y_pred_PHI.flatten()),
                                           np.mean(y_pred_TOR.flatten()), np.mean(y_pred_WAS.flatten())],
  }
).sort_values(by='Team Efficiency (Predicted Average)', ascending=False)

ECF.insert(0, 'Seeding', east_seeding)
ECF.insert(3, 'Classification', classification)

ECF[:8]
# Out:
#    Seeding        Team  Team Efficiency (Predicted Average)  Classification
# 13      E1     Toronto                            64.274697        Finalist
# 5       E2   Cleveland                            62.309598   Semi-Finalist
# 14      E3  Washington                            55.737106  Playoffs Maker
# 7       E4     Indiana                            55.467285  Playoffs Maker
# 8       E5       Miami                            54.890283  Playoffs Maker
# 1       E6      Boston                            52.815965  Playoffs Maker
# 0       E7     Atlanta                            51.770161  Playoffs Maker
# 6       E8     Detroit                            48.948761  Playoffs Maker

# %%
WCF = pd.DataFrame(
  {
      "Team": ['Dallas', 'Denver', 'Golden State', 'Houston', 'Los Angeles Clippers', 
               'Los Angeles Lakers', 'Memphis', 'Minnesota','New Orleans', 'Oklahoma City', 'Phoenix',
              'Portland', 'Sacramento', 'San Antonio', 'Utah'],
      "Team Efficiency (Predicted Average)": [np.mean(y_pred_DAL.flatten()),
                                           np.mean(y_pred_DEN.flatten()), np.mean(y_pred_GSW.flatten()),
                                           np.mean(y_pred_HOU.flatten()), np.mean(y_pred_LAC.flatten()),
                                           np.mean(y_pred_LAL.flatten()), np.mean(y_pred_MEM.flatten()),
                                           np.mean(y_pred_MIN.flatten()), np.mean(y_pred_NOP.flatten()),
                                           np.mean(y_pred_OKC.flatten()), np.mean(y_pred_PHO.flatten()),
                                           np.mean(y_pred_POR.flatten()), np.mean(y_pred_SAC.flatten()),
                                           np.mean(y_pred_SAS.flatten()), np.mean(y_pred_UTAH.flatten())],
  }
).sort_values(by='Team Efficiency (Predicted Average)', ascending=False)

WCF.insert(0, 'Seeding', west_seeding)
WCF.insert(3, 'Classification', classification)

WCF[:8]
# Out:
#    Seeding                  Team  Team Efficiency (Predicted Average)  \
# 2       W1          Golden State                            78.510911
# 13      W2           San Antonio                            72.768767
# 3       W3               Houston                            67.260649
# 4       W4  Los Angeles Clippers                            65.082720
# 9       W5         Oklahoma City                            60.298225
# 11      W6              Portland                            57.388759
# 6       W7               Memphis                            52.512813
# 1       W8                Denver                            47.122266
#
#     Classification
# 2         Finalist
# 13   Semi-Finalist
# 3   Playoffs Maker
# 4   Playoffs Maker
# 9   Playoffs Maker
# 11  Playoffs Maker
# 6   Playoffs Maker
# 1   Playoffs Maker

# %%
overall = pd.concat([ECF,WCF], axis=0, join='outer', ignore_index=True)

overall['Rank'] = overall['Classification'].map(class_dict)

overall.sort_values(by='Rank')
# Out:
#    Seeding                  Team  Team Efficiency (Predicted Average)  \
# 0       E1               Toronto                            64.274697
# 15      W1          Golden State                            78.510911
# 1       E2             Cleveland                            62.309598
# 16      W2           San Antonio                            72.768767
# 18      W4  Los Angeles Clippers                            65.082720
# 17      W3               Houston                            67.260649
# 21      W7               Memphis                            52.512813
# 22      W8                Denver                            47.122266
# 19      W5         Oklahoma City                            60.298225
# 20      W6              Portland                            57.388759
# 7       E8               Detroit                            48.948761
# 6       E7               Atlanta                            51.770161
# ...
