# %%
# %matplotlib inline

import matplotlib.pylab as plt
import numpy as np
import pandas as pd

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/1Lx7AOozLSxBx_v7rm_BDbQtu0_URkZdwgPQgv1MebCg/edit#gid=812816002'
csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

df = pd.read_csv(csv_export_url)
#df.describe() #describes the dataset

# %%
#df.shape #print how many columns and rows

# %%
#df.dtypes #check types per column

# %%
#remove '%' in percentages
df["FG %"] = df["FG %"].str.rstrip('%')
df["3Ps %"] = df["3Ps %"].str.rstrip('%')
df["FT%"] = df["FT%"].str.rstrip('%')

#change object types to numeric
df["FG %"] = pd.to_numeric(df["FG %"], downcast='float', errors='coerce')
df["3Ps %"] = pd.to_numeric(df["3Ps %"], downcast='float', errors='coerce')
df["FT%"] = pd.to_numeric(df["FT%"], downcast='float', errors='coerce')

#get the real percentage of stats that involve percentages
df["FG %"] = df["FG %"] / 100
df["3Ps %"] = df["3Ps %"] / 100
df["FT%"] = df["FT%"] / 100

# %%
#set the dataset per team

# df.columns.get_loc("3Ps Attempted") #5
# df.columns.get_loc("Defensive Rebounds") #11
# df.columns.get_loc("Attendees") #19
# df.columns.get_loc("Average Points") #18
# df.columns.get_loc("TEAM EFFICIENCY") #20

#for Houston
X_Houston = df.iloc[0:22, [5,11,18,19,20]]
y_Houston = df.iloc[0:22, 24]

#for Golden State
X_GoldenState = df.iloc[22:44, [5,11,18,19,20]]
y_GoldenState = df.iloc[22:44, 24]

#for Portland
X_Portland = df.iloc[44:66, [5,11,18,19,20]]
y_Portland = df.iloc[44:66, 24]

#for Oklahoma City
X_OklahomaCity = df.iloc[66:88, [5,11,18,19,20]]
y_OklahomaCity = df.iloc[66:88, 24]

#for Utah
X_Utah = df.iloc[88:110, [5,11,18,19,20]]
y_Utah = df.iloc[88:110, 24]

#for New Orleans
X_NewOrleans = df.iloc[110:132, [5,11,18,19,20]]
y_NewOrleans = df.iloc[110:132, 24]

#for San Antonio
X_SanAntonio = df.iloc[132:154, [5,11,18,19,20]]
y_SanAntonio = df.iloc[132:154, 24]

#for Minnesota
X_Minnesota = df.iloc[154:176, [5,11,18,19,20]]
y_Minnesota = df.iloc[154:176, 24]

#for Denver
X_Denver = df.iloc[176:198, [5,11,18,19,20]]
y_Denver = df.iloc[176:198, 24]

#for Los Angeles Clippers
X_LosAngelesClippers = df.iloc[198:220, [5,11,18,19,20]]
y_LosAngelesClippers = df.iloc[198:220, 24]

#for Toronto
X_Toronto = df.iloc[220:242, [5,11,18,19,20]]
y_Toronto = df.iloc[220:242, 24]

#for Boston
X_Boston = df.iloc[242:264, [5,11,18,19,20]]
y_Boston = df.iloc[242:264, 24]

#for Philadelphia 
X_Philadelphia = df.iloc[264:286, [5,11,18,19,20]]
y_Philadelphia = df.iloc[264:286, 24]

#for Cleveland
X_Cleveland = df.iloc[286:308, [5,11,18,19,20]]
y_Cleveland = df.iloc[286:308, 24]

#for Indiana
X_Indiana = df.iloc[308:330, [5,11,18,19,20]]
y_Indiana = df.iloc[308:330, 24]

#for Los Angeles Lakers
X_LosAngelesLakers = df.iloc[330:352, [5,11,18,19,20]]
y_LosAngelesLakers = df.iloc[330:352, 24]

#for Sacramento
X_Sacramento = df.iloc[352:374, [5,11,18,19,20]]
y_Sacramento = df.iloc[352:374, 24]

#for Dallas
X_Dallas = df.iloc[374:396, [5,11,18,19,20]]
y_Dallas = df.iloc[374:396, 24]

#for Memphis
X_Memphis = df.iloc[396:418, [5,11,18,19,20]]
y_Memphis = df.iloc[396:418, 24]

#for Phoenix
X_Phoenix = df.iloc[418:440, [5,11,18,19,20]]
y_Phoenix = df.iloc[418:440, 24]

#for Miami
X_Miami = df.iloc[440:462, [5,11,18,19,20]]
y_Miami = df.iloc[440:462, 24]

#for Milwaukee
X_Milwaukee = df.iloc[462:484, [5,11,18,19,20]]
y_Milwaukee = df.iloc[462:484, 24]

#for Washington
X_Washington = df.iloc[484:506, [5,11,18,19,20]]
y_Washington = df.iloc[484:506, 24]

#for Detroit
X_Detroit = df.iloc[506:528, [5,11,18,19,20]]
y_Detroit = df.iloc[506:528, 24]

#for Charlotte
X_Charlotte = df.iloc[528:550, [5,11,18,19,20]]
y_Charlotte = df.iloc[528:550, 24]

#for New York
X_NewYork = df.iloc[550:572, [5,11,18,19,20]]
y_NewYork = df.iloc[550:572, 24]

#for Brooklyn
X_Brooklyn = df.iloc[572:594, [5,11,18,19,20]]
y_Brooklyn = df.iloc[572:594, 24]

#for Chicago
X_Chicago = df.iloc[594:616, [5,11,18,19,20]]
y_Chicago = df.iloc[594:616, 24]

#for Orlando
X_Orlando = df.iloc[616:638, [5,11,18,19,20]]
y_Orlando = df.iloc[616:638, 24]

#for Atlanta
X_Atlanta = df.iloc[638:660, [5,11,18,19,20]]
y_Atlanta = df.iloc[638:660, 24]

# %%
X_train1_Houston = X_Houston[0:1]
y_train1_Houston = y_Houston[0:1]
X_train2_Houston = X_Houston[1:2]
y_train2_Houston = y_Houston[1:2]
X_train3_Houston = X_Houston[2:3]
y_train3_Houston = y_Houston[2:3]
X_train4_Houston = X_Houston[3:4]
y_train4_Houston = y_Houston[3:4]
X_train5_Houston = X_Houston[4:5]
y_train5_Houston = y_Houston[4:5]
X_train6_Houston = X_Houston[5:6]
y_train6_Houston = y_Houston[5:6]
X_train7_Houston = X_Houston[7:8]
y_train7_Houston = y_Houston[7:8]
X_train8_Houston = X_Houston[8:9]
y_train8_Houston = y_Houston[8:9]
X_train9_Houston = X_Houston[9:10]
y_train9_Houston = y_Houston[9:10]
X_train10_Houston = X_Houston[10:11]
y_train10_Houston = y_Houston[10:11]
X_train11_Houston = X_Houston[11:12]
y_train11_Houston = y_Houston[11:12]
X_train12_Houston = X_Houston[12:13]
y_train12_Houston = y_Houston[12:13]
X_train13_Houston = X_Houston[13:14]
y_train13_Houston = y_Houston[13:14]
X_train14_Houston = X_Houston[14:15]
y_train14_Houston = y_Houston[14:15]
X_train15_Houston = X_Houston[15:16]
y_train15_Houston = y_Houston[15:16]
X_train16_Houston = X_Houston[16:17]
y_train16_Houston = y_Houston[16:17]
X_train17_Houston = X_Houston[17:18]
y_train17_Houston = y_Houston[17:18]
X_train18_Houston = X_Houston[18:19]
y_train18_Houston = y_Houston[18:19]
X_train19_Houston = X_Houston[19:20]
y_train19_Houston = y_Houston[19:20]
X_train20_Houston = X_Houston[20:21]
y_train20_Houston = y_Houston[20:21]
X_train21_Houston = X_Houston[21:22]
y_train21_Houston = y_Houston[21:22]
X_train22_Houston = X_Houston[22:23]
y_train22_Houston = y_Houston[22:23]

X_train1_all = df.iloc[[22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],[5,11,18,19,20]]
y_train1_all = df.iloc[[22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],24:25]

X_train2_all = df.iloc[[0,23,45 ,67 ,89,111, 133,155,177,199,221 ,243 ,265 ,287 ,309 ,331 ,353 ,375 ,397 ,419 ,441 ,463 ,485 ,507 ,529 ,551 ,573 ,595 ,617 ,639],[5,11,18,19,20]]
y_train2_all = df.iloc[[23,45 ,67,89,111, 133,155,177,199,221 ,243 ,265 ,287 ,309 ,331 ,353 ,375 ,397 ,419 ,441 ,463 ,485 ,507 ,529 ,551 ,573 ,595 ,617 ,639],24:25]

X_train3_all = df.iloc[[0,24,46,68,90,112 ,134 ,156 ,178 ,200 ,222 ,244 ,266 ,288 ,310 ,332 ,354 ,376 ,398 ,420 ,442 ,464 ,486 ,508 ,530 ,552 ,574 ,596 ,618 ,640],[5,11,18,19,20]]
y_train3_all = df.iloc[[24,46,68,90,112 ,134 ,156 ,178 ,200 ,222 ,244 ,266 ,288 ,310 ,332 ,354 ,376 ,398 ,420 ,442 ,464 ,486 ,508 ,530 ,552 ,574 ,596 ,618 ,640],24:25]

X_train4_all = df.iloc[[0,25,47,69,91,113 ,135 ,157 ,179 ,201 ,223 ,245 ,267 ,289 ,311 ,333 ,355 ,377 ,399 ,421 ,443 ,465 ,487 ,509 ,531 ,553 ,575 ,597 ,619 ,641],[5,11,18,19,20]]
y_train4_all = df.iloc[[25,47,69,91,113 ,135 ,157 ,179 ,201 ,223 ,245 ,267 ,289 ,311 ,333 ,355 ,377 ,399 ,421 ,443 ,465 ,487 ,509 ,531 ,553 ,575 ,597 ,619 ,641],24:25]

X_train5_all = df.iloc[[0,26,48,70,92,114 ,136 ,158 ,180 ,202 ,224 ,246 ,268 ,290 ,312 ,334 ,356 ,378 ,400 ,422 ,444 ,466 ,488 ,510 ,532 ,554 ,576 ,598 ,620 ,642],[5,11,18,19,20]]
y_train5_all = df.iloc[[26,48,70,92,114 ,136 ,158 ,180 ,202 ,224 ,246 ,268 ,290 ,312 ,334 ,356 ,378 ,400 ,422 ,444 ,466 ,488 ,510 ,532 ,554 ,576 ,598 ,620 ,642],24:25]

X_train6_all = df.iloc[[0,27,49,71,93,115 ,137 ,159 ,181 ,203 ,225 ,247 ,269 ,291 ,313 ,335 ,357 ,379 ,401 ,423 ,445 ,467 ,489 ,511 ,533 ,555 ,577 ,599 ,621 ,643],[5,11,18,19,20]]
y_train6_all = df.iloc[[27,49,71,93,115 ,137 ,159 ,181 ,203 ,225 ,247 ,269 ,291 ,313 ,335 ,357 ,379 ,401 ,423 ,445 ,467 ,489 ,511 ,533 ,555 ,577 ,599 ,621 ,643],24:25]

X_train7_all = df.iloc[[0,28,50,72,94,116 ,138 ,160 ,182 ,204 ,226 ,248 ,270 ,292 ,314 ,336 ,358 ,380 ,402 ,424 ,446 ,468 ,490 ,512 ,534 ,556 ,578 ,600 ,622 ,644],[5,11,18,19,20]]
y_train7_all = df.iloc[[28,50,72,94,116 ,138 ,160 ,182 ,204 ,226 ,248 ,270 ,292 ,314 ,336 ,358 ,380 ,402 ,424 ,446 ,468 ,490 ,512 ,534 ,556 ,578 ,600 ,622 ,644],24:25]

X_train8_all = df.iloc[[0,29,51,73,95,117 ,139 ,161 ,183 ,205 ,227 ,249 ,271 ,293 ,315 ,337 ,359 ,381 ,403 ,425 ,447 ,469 ,491 ,513 ,535 ,557 ,579 ,601 ,623 ,645],[5,11,18,19,20]]
y_train8_all = df.iloc[[29,51,73,95,117 ,139 ,161 ,183 ,205 ,227 ,249 ,271 ,293 ,315 ,337 ,359 ,381 ,403 ,425 ,447 ,469 ,491 ,513 ,535 ,557 ,579 ,601 ,623 ,645],24:25]

X_train9_all = df.iloc[[0,30,52,74,96,118 ,140 ,162 ,184 ,206 ,228 ,250 ,272 ,294 ,316 ,338 ,360 ,382 ,404 ,426 ,448 ,470 ,492 ,514 ,536 ,558 ,580 ,602 ,624 ,646],[5,11,18,19,20]]
y_train9_all = df.iloc[[30,52,74,96,118 ,140 ,162 ,184 ,206 ,228 ,250 ,272 ,294 ,316 ,338 ,360 ,382 ,404 ,426 ,448 ,470 ,492 ,514 ,536 ,558 ,580 ,602 ,624 ,646],24:25]

X_train10_all = df.iloc[[0,31,53,75,97,119 ,141 ,163 ,185 ,207 ,229 ,251 ,273 ,295 ,317 ,339 ,361 ,383 ,405 ,427 ,449 ,471 ,493 ,515 ,537 ,559 ,581 ,603 ,625 ,647],[5,11,18,19,20]]
y_train10_all = df.iloc[[31,53,75,97,119 ,141 ,163 ,185 ,207 ,229 ,251 ,273 ,295 ,317 ,339 ,361 ,383 ,405 ,427 ,449 ,471 ,493 ,515 ,537 ,559 ,581 ,603 ,625 ,647],24:25]

X_train11_all = df.iloc[[0,32,54,76,98,120 ,142 ,164 ,186 ,208 ,230 ,252 ,274 ,296 ,318 ,340 ,362 ,384 ,406 ,428 ,450 ,472 ,494 ,516 ,538 ,560 ,582 ,604 ,626 ,648],[5,11,18,19,20]]
y_train11_all = df.iloc[[32,54,76,98,120 ,142 ,164 ,186 ,208 ,230 ,252 ,274 ,296 ,318 ,340 ,362 ,384 ,406 ,428 ,450 ,472 ,494 ,516 ,538 ,560 ,582 ,604 ,626 ,648],24:25]

X_train12_all = df.iloc[[0,33,55,77,99,121 ,143 ,165 ,187 ,209 ,231 ,253 ,275 ,297 ,319 ,341 ,363 ,385 ,407 ,429 ,451 ,473 ,495 ,517 ,539 ,561 ,583 ,605 ,627 ,649],[5,11,18,19,20]]
y_train12_all = df.iloc[[33,55,77,99,121 ,143 ,165 ,187 ,209 ,231 ,253 ,275 ,297 ,319 ,341 ,363 ,385 ,407 ,429 ,451 ,473 ,495 ,517 ,539 ,561 ,583 ,605 ,627 ,649],24:25]

X_train13_all = df.iloc[[0,34,56,78,10, 122, 144, 166, 188, 210, 232, 254, 276, 298, 320, 342, 364, 386, 408, 430, 452, 474, 496, 518, 540, 562, 584, 606, 628, 650],[5,11,18,19,20]]
y_train13_all = df.iloc[[34,56,78,10, 122, 144, 166, 188, 210, 232, 254, 276, 298, 320, 342, 364, 386, 408, 430, 452, 474, 496, 518, 540, 562, 584, 606, 628, 650],24:25]

X_train14_all = df.iloc[[0,35,57,79,10, 123, 145, 167, 189, 211, 233, 255, 277, 299, 321, 343, 365, 387, 409, 431, 453, 475, 497, 519, 541, 563, 585, 607, 629, 651],[5,11,18,19,20]]
y_train14_all = df.iloc[[35,57,79,10, 123, 145, 167, 189, 211, 233, 255, 277, 299, 321, 343, 365, 387, 409, 431, 453, 475, 497, 519, 541, 563, 585, 607, 629, 651],24:25]

X_train15_all = df.iloc[[0,36,58,80,10, 124, 146, 168, 190, 212, 234, 256, 278, 300, 322, 344, 366, 388, 410, 432, 454, 476, 498, 520, 542, 564, 586, 608, 630, 652],[5,11,18,19,20]]
y_train15_all = df.iloc[[36,58,80,10, 124, 146, 168, 190, 212, 234, 256, 278, 300, 322, 344, 366, 388, 410, 432, 454, 476, 498, 520, 542, 564, 586, 608, 630, 652],24:25]

X_train16_all = df.iloc[[0,37,59,81,10, 125, 147, 169, 191, 213, 235, 257, 279, 301, 323, 345, 367, 389, 411, 433, 455, 477, 499, 521, 543, 565, 587, 609, 631, 653],[5,11,18,19,20]]
y_train16_all = df.iloc[[37,59,81,10, 125, 147, 169, 191, 213, 235, 257, 279, 301, 323, 345, 367, 389, 411, 433, 455, 477, 499, 521, 543, 565, 587, 609, 631, 653],24:25]

X_train17_all = df.iloc[[0,38,60,82,10, 126, 148, 170, 192, 214, 236, 258, 280, 302, 324, 346, 368, 390, 412, 434, 456, 478, 500, 522, 544, 566, 588, 610, 632, 654],[5,11,18,19,20]]
y_train17_all = df.iloc[[38,60,82,10, 126, 148, 170, 192, 214, 236, 258, 280, 302, 324, 346, 368, 390, 412, 434, 456, 478, 500, 522, 544, 566, 588, 610, 632, 654],24:25]

X_train18_all = df.iloc[[0,39,61,83,10, 127, 149, 171, 193, 215, 237, 259, 281, 303, 325, 347, 369, 391, 413, 435, 457, 479, 501, 523, 545, 567, 589, 611, 633, 655],[5,11,18,19,20]]
y_train18_all = df.iloc[[39,61,83,10, 127, 149, 171, 193, 215, 237, 259, 281, 303, 325, 347, 369, 391, 413, 435, 457, 479, 501, 523, 545, 567, 589, 611, 633, 655],24:25]

X_train19_all = df.iloc[[0,40,62,84,10, 128, 150, 172, 194, 216, 238, 260, 282, 304, 326, 348, 370, 392, 414, 436, 458, 480, 502, 524, 546, 568, 590, 612, 634, 656],[5,11,18,19,20]]
y_train19_all = df.iloc[[40,62,84,10, 128, 150, 172, 194, 216, 238, 260, 282, 304, 326, 348, 370, 392, 414, 436, 458, 480, 502, 524, 546, 568, 590, 612, 634, 656],24:25]

X_train20_all = df.iloc[[0,41,63,85,10, 129, 151, 173, 195, 217, 239, 261, 283, 305, 327, 349, 371, 393, 415, 437, 459, 481, 503, 525, 547, 569, 591, 613, 635, 657],[5,11,18,19,20]]
y_train20_all = df.iloc[[41,63,85,10, 129, 151, 173, 195, 217, 239, 261, 283, 305, 327, 349, 371, 393, 415, 437, 459, 481, 503, 525, 547, 569, 591, 613, 635, 657],24:25]

X_train21_all = df.iloc[[0,42,64,86,10, 130, 152, 174, 196, 218, 240, 262, 284, 306, 328, 350, 372, 394, 416, 438, 460, 482, 504, 526, 548, 570, 592, 614, 636, 658],[5,11,18,19,20]]
y_train21_all = df.iloc[[42,64,86,10, 130, 152, 174, 196, 218, 240, 262, 284, 306, 328, 350, 372, 394, 416, 438, 460, 482, 504, 526, 548, 570, 592, 614, 636, 658],24:25]

X_train22_all = df.iloc[[0,43,65,87,10, 131, 153, 175, 197, 219, 241, 263, 285, 307, 329, 351, 373, 395, 417, 439, 461, 483, 505, 527, 549, 571, 593, 615, 637, 659],[5,11,18,19,20]]
y_train22_all = df.iloc[[43,65,87,10, 131, 153, 175, 197, 219, 241, 263, 285, 307, 329, 351, 373, 395, 417, 439, 461, 483, 505, 527, 549, 571, 593, 615, 637, 659],24:25]

# %%
from sklearn.linear_model import LinearRegression
regressorHouston1 = LinearRegression()
regressorHouston1.fit(X_train1_all, y_train1_all)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pd.DataFrame(list(zip(X_train1_all, regressorHouston1.coef_)), columns=['Features', 'Beta Coefficient'])
# Out:
#         Features                                   Beta Coefficient
# 0  3Ps Attempted  [-0.34824932546527265, 3.902760326962351, -0.2...

# %%
y_pred1_Houston = regressorHouston1.predict(X_train1_Houston)

# %%
#y_train1_all.insert(0, 1, y_pred1_Houston[0])

y_train2_all.loc[-1] = y_pred1_Houston.item(0)  # adding a row
y_train2_all.index = y_train2_all.index + 1  # shifting index
y_train2_all = y_train2_all.sort_index()
regressorHouston2 = LinearRegression()
regressorHouston2.fit(X_train2_all, y_train2_all)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pd.DataFrame(list(zip(X_train2_all, regressorHouston2.coef_)), columns=['Features', 'Beta Coefficient'])
# Out:
#         Features                                   Beta Coefficient
# 0  3Ps Attempted  [0.6961861526975305, 1.1634925272237313, -1.43...

# %%
y_pred2_Houston = regressorHouston2.predict(X_train2_Houston)

# %%
y_train3_all.loc[-1] = y_pred2_Houston.item(0)  # adding a row
y_train3_all.index = y_train3_all.index + 1  # shifting index
y_train3_all = y_train3_all.sort_index()
regressorHouston3 = LinearRegression()
regressorHouston3.fit(X_train3_all, y_train3_all)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pd.DataFrame(list(zip(X_train3_all, regressorHouston3.coef_)), columns=['Features', 'Beta Coefficient'])
# Out:
#         Features                                   Beta Coefficient
# 0  3Ps Attempted  [0.5484896134169344, 3.3961806534567147, -1.00...

# %%
y_pred3_Houston = regressorHouston3.predict(X_train3_Houston)

# %%
y_train4_all.loc[-1] = y_pred3_Houston.item(0)  # adding a row
y_train4_all.index = y_train4_all.index + 1  # shifting index
y_train4_all = y_train4_all.sort_index()
regressorHouston4 = LinearRegression()
regressorHouston4.fit(X_train4_all, y_train4_all)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pd.DataFrame(list(zip(X_train4_all, regressorHouston4.coef_)), columns=['Features', 'Beta Coefficient'])
# Out:
#         Features                                   Beta Coefficient
# 0  3Ps Attempted  [-0.4007593272910754, -0.19236165111564452, -0...

# %%
y_pred4_Houston = regressorHouston4.predict(X_train4_Houston)

# %%
y_train5_all.loc[-1] = y_pred4_Houston.item(0)  # adding a row
y_train5_all.index = y_train5_all.index + 1  # shifting index
y_train5_all = y_train5_all.sort_index()
regressorHouston5 = LinearRegression()
regressorHouston5.fit(X_train5_all, y_train5_all)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pd.DataFrame(list(zip(X_train5_all, regressorHouston5.coef_)), columns=['Features', 'Beta Coefficient'])
# Out:
#         Features                                   Beta Coefficient
# 0  3Ps Attempted  [-0.5532199168628578, 2.163095750273006, 0.031...

# %%
y_pred5_Houston = regressorHouston5.predict(X_train5_Houston)

# %%
y_train6_all.loc[-1] = y_pred5_Houston.item(0)  # adding a row
y_train6_all.index = y_train6_all.index + 1  # shifting index
y_train6_all = y_train6_all.sort_index()
regressorHouston6 = LinearRegression()
regressorHouston6.fit(X_train6_all, y_train6_all)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pd.DataFrame(list(zip(X_train6_all, regressorHouston6.coef_)), columns=['Features', 'Beta Coefficient'])
# Out:
#         Features                                   Beta Coefficient
# 0  3Ps Attempted  [-0.016975768915853746, 2.4122485325610183, -0...

# %%
y_pred6_Houston = regressorHouston6.predict(X_train6_Houston)

# %%
y_train7_all.loc[-1] = y_pred6_Houston.item(0)  # adding a row
y_train7_all.index = y_train7_all.index + 1  # shifting index
y_train7_all = y_train7_all.sort_index()
regressorHouston7 = LinearRegression()
regressorHouston7.fit(X_train7_all, y_train7_all)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pd.DataFrame(list(zip(X_train7_all, regressorHouston7.coef_)), columns=['Features', 'Beta Coefficient'])
# Out:
#         Features                                   Beta Coefficient
# 0  3Ps Attempted  [-0.8290775763333486, 0.7826371556446734, -0.5...

# %%
y_pred7_Houston = regressorHouston7.predict(X_train7_Houston)

# %%
y_train8_all.loc[-1] = y_pred7_Houston.item(0)  # adding a row
y_train8_all.index = y_train8_all.index + 1  # shifting index
y_train8_all = y_train8_all.sort_index()
regressorHouston8 = LinearRegression()
regressorHouston8.fit(X_train8_all, y_train8_all)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pd.DataFrame(list(zip(X_train8_all, regressorHouston8.coef_)), columns=['Features', 'Beta Coefficient'])
# Out:
#         Features                                   Beta Coefficient
# 0  3Ps Attempted  [0.31388669775320427, 2.0970175046195143, -1.8...

# %%
y_pred8_Houston = regressorHouston8.predict(X_train8_Houston)

# %%
y_train9_all.loc[-1] = y_pred8_Houston.item(0)  # adding a row
y_train9_all.index = y_train9_all.index + 1  # shifting index
y_train9_all = y_train9_all.sort_index()
regressorHouston9 = LinearRegression()
regressorHouston9.fit(X_train9_all, y_train9_all)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pd.DataFrame(list(zip(X_train9_all, regressorHouston9.coef_)), columns=['Features', 'Beta Coefficient'])
# Out:
#         Features                                   Beta Coefficient
# 0  3Ps Attempted  [-0.022628638483028783, 1.2809927810010986, 2....

# %%
y_pred9_Houston = regressorHouston9.predict(X_train9_Houston)

# %%
y_train10_all.loc[-1] = y_pred9_Houston.item(0)  # adding a row
y_train10_all.index = y_train10_all.index + 1  # shifting index
y_train10_all = y_train10_all.sort_index()
regressorHouston10 = LinearRegression()
regressorHouston10.fit(X_train10_all, y_train10_all)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pd.DataFrame(list(zip(X_train10_all, regressorHouston10.coef_)), columns=['Features', 'Beta Coefficient'])
# Out:
#         Features                                   Beta Coefficient
# 0  3Ps Attempted  [0.12019668678431611, 0.39120239381927896, -1....

# %%
y_pred10_Houston = regressorHouston10.predict(X_train10_Houston)

# %%
y_train11_all.loc[-1] = y_pred10_Houston.item(0)  # adding a row
y_train11_all.index = y_train11_all.index + 1  # shifting index
y_train11_all = y_train11_all.sort_index()
regressorHouston11 = LinearRegression()
regressorHouston11.fit(X_train11_all, y_train11_all)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pd.DataFrame(list(zip(X_train11_all, regressorHouston11.coef_)), columns=['Features', 'Beta Coefficient'])
# Out:
#         Features                                   Beta Coefficient
# 0  3Ps Attempted  [-0.0510208490186359, -1.5935860473025898, -0....

# %%
y_pred11_Houston = regressorHouston11.predict(X_train11_Houston)

# %%
y_train12_all.loc[-1] = y_pred11_Houston.item(0)  # adding a row
y_train12_all.index = y_train12_all.index + 1  # shifting index
y_train12_all = y_train12_all.sort_index()
regressorHouston12 = LinearRegression()
regressorHouston12.fit(X_train12_all, y_train12_all)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pd.DataFrame(list(zip(X_train12_all, regressorHouston12.coef_)), columns=['Features', 'Beta Coefficient'])
# Out:
#         Features                                   Beta Coefficient
# 0  3Ps Attempted  [0.2596346928289568, 1.6768634486350702, -0.31...

# %%
y_pred12_Houston = regressorHouston12.predict(X_train12_Houston)

# %%
y_train13_all.loc[-1] = y_pred12_Houston.item(0)  # adding a row
y_train13_all.index = y_train13_all.index + 1  # shifting index
y_train13_all = y_train13_all.sort_index()
regressorHouston13 = LinearRegression()
regressorHouston13.fit(X_train13_all, y_train13_all)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pd.DataFrame(list(zip(X_train13_all, regressorHouston13.coef_)), columns=['Features', 'Beta Coefficient'])
# Out:
#         Features                                   Beta Coefficient
# 0  3Ps Attempted  [0.44084121647405444, 1.1732941721010963, -1.1...

# %%
y_pred13_Houston = regressorHouston13.predict(X_train13_Houston)

# %%
y_train14_all.loc[-1] = y_pred13_Houston.item(0)  # adding a row
y_train14_all.index = y_train14_all.index + 1  # shifting index
y_train14_all = y_train14_all.sort_index()
regressorHouston14 = LinearRegression()
regressorHouston14.fit(X_train14_all, y_train14_all)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pd.DataFrame(list(zip(X_train14_all, regressorHouston14.coef_)), columns=['Features', 'Beta Coefficient'])
# Out:
#         Features                                   Beta Coefficient
# 0  3Ps Attempted  [-0.7787862148860909, 2.659364056521107, -0.56...

# %%
y_pred14_Houston = regressorHouston14.predict(X_train14_Houston)

# %%
y_train15_all.loc[-1] = y_pred14_Houston.item(0)  # adding a row
y_train15_all.index = y_train15_all.index + 1  # shifting index
y_train15_all = y_train15_all.sort_index()
regressorHouston15 = LinearRegression()
regressorHouston15.fit(X_train15_all, y_train15_all)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pd.DataFrame(list(zip(X_train15_all, regressorHouston15.coef_)), columns=['Features', 'Beta Coefficient'])
# Out:
#         Features                                   Beta Coefficient
# 0  3Ps Attempted  [0.5445704324636773, 0.5997853775163211, -1.14...

# %%
y_pred15_Houston = regressorHouston15.predict(X_train15_Houston)

# %%
y_train16_all.loc[-1] = y_pred15_Houston.item(0)  # adding a row
y_train16_all.index = y_train16_all.index + 1  # shifting index
y_train16_all = y_train16_all.sort_index()
regressorHouston16 = LinearRegression()
regressorHouston16.fit(X_train16_all, y_train16_all)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pd.DataFrame(list(zip(X_train16_all, regressorHouston16.coef_)), columns=['Features', 'Beta Coefficient'])
# Out:
#         Features                                   Beta Coefficient
# 0  3Ps Attempted  [0.11870799981896123, -0.02959369670142322, -0...

# %%
y_pred16_Houston = regressorHouston16.predict(X_train16_Houston)

# %%
y_train17_all.loc[-1] = y_pred16_Houston.item(0)  # adding a row
y_train17_all.index = y_train17_all.index + 1  # shifting index
y_train17_all = y_train17_all.sort_index()
regressorHouston17 = LinearRegression()
regressorHouston17.fit(X_train17_all, y_train17_all)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pd.DataFrame(list(zip(X_train17_all, regressorHouston17.coef_)), columns=['Features', 'Beta Coefficient'])
# Out:
#         Features                                   Beta Coefficient
# 0  3Ps Attempted  [0.5466507112457138, 0.8469580066662034, -0.78...

# %%
y_pred17_Houston = regressorHouston17.predict(X_train17_Houston)

# %%
y_train18_all.loc[-1] = y_pred17_Houston.item(0)  # adding a row
y_train18_all.index = y_train18_all.index + 1  # shifting index
y_train18_all = y_train18_all.sort_index()
regressorHouston18 = LinearRegression()
regressorHouston18.fit(X_train18_all, y_train18_all)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pd.DataFrame(list(zip(X_train18_all, regressorHouston18.coef_)), columns=['Features', 'Beta Coefficient'])
# Out:
#         Features                                   Beta Coefficient
# 0  3Ps Attempted  [0.496735718088216, 0.5465738183675587, -1.379...

# %%
y_pred18_Houston = regressorHouston18.predict(X_train18_Houston)

# %%
y_train19_all.loc[-1] = y_pred18_Houston.item(0)  # adding a row
y_train19_all.index = y_train19_all.index + 1  # shifting index
y_train19_all = y_train19_all.sort_index()
regressorHouston19 = LinearRegression()
regressorHouston19.fit(X_train19_all, y_train19_all)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pd.DataFrame(list(zip(X_train19_all, regressorHouston19.coef_)), columns=['Features', 'Beta Coefficient'])
# Out:
#         Features                                   Beta Coefficient
# 0  3Ps Attempted  [0.7797877234524645, 1.3729132924540004, -1.34...

# %%
y_pred19_Houston = regressorHouston19.predict(X_train19_Houston)

# %%
y_train20_all.loc[-1] = y_pred19_Houston.item(0)  # adding a row
y_train20_all.index = y_train20_all.index + 1  # shifting index
y_train20_all = y_train20_all.sort_index()
regressorHouston20 = LinearRegression()
regressorHouston20.fit(X_train20_all, y_train20_all)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pd.DataFrame(list(zip(X_train20_all, regressorHouston20.coef_)), columns=['Features', 'Beta Coefficient'])
# Out:
#         Features                                   Beta Coefficient
# 0  3Ps Attempted  [0.42917002099379925, -0.6162017872189757, -0....

# %%
y_pred20_Houston = regressorHouston20.predict(X_train20_Houston)

# %%
y_train21_all.loc[-1] = y_pred20_Houston.item(0)  # adding a row
y_train21_all.index = y_train21_all.index + 1  # shifting index
y_train21_all = y_train21_all.sort_index()
regressorHouston21 = LinearRegression()
regressorHouston21.fit(X_train21_all, y_train21_all)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pd.DataFrame(list(zip(X_train21_all, regressorHouston21.coef_)), columns=['Features', 'Beta Coefficient'])
# Out:
#         Features                                   Beta Coefficient
# 0  3Ps Attempted  [1.1514925862528427, -0.1855073054992084, -2.2...

# %%
y_pred21_Houston = regressorHouston21.predict(X_train21_Houston)

# %%
#y_train22_all.loc[-21] = y_pred21_Houston.item(0)  # adding a row
#y_train22_all.index = y_train22_all.index + 21  # shifting index
#y_train22_all = y_train21_all.sort_index()
#regressorHouston22 = LinearRegression()
#regressorHouston22.fit(X_train22_all, y_train22_all)

#pd.DataFrame(list(zip(X_train22_all, regressorHouston22.coef_)), columns=['Features', 'Beta Coefficient'])

#y_pred22_Houston = regressorHouston22.predict(X_train22_Houston)

# %%
X_train1_GoldenState = X_GoldenState[0:1]
y_train1_GoldenState = y_GoldenState[0:1]
X_train2_GoldenState = X_GoldenState[1:2]
y_train2_GoldenState = y_GoldenState[1:2]
X_train3_GoldenState = X_GoldenState[2:3]
y_train3_GoldenState = y_GoldenState[2:3]
X_train4_GoldenState = X_GoldenState[3:4]
y_train4_GoldenState = y_GoldenState[3:4]
X_train5_GoldenState = X_GoldenState[4:5]
y_train5_GoldenState = y_GoldenState[4:5]
X_train6_GoldenState = X_GoldenState[5:6]
y_train6_GoldenState = y_GoldenState[5:6]
X_train7_GoldenState = X_GoldenState[7:8]
y_train7_GoldenState = y_GoldenState[7:8]
X_train8_GoldenState = X_GoldenState[8:9]
y_train8_GoldenState = y_GoldenState[8:9]
X_train9_GoldenState = X_GoldenState[9:10]
y_train9_GoldenState = y_GoldenState[9:10]
X_train10_GoldenState = X_GoldenState[10:11]
y_train10_GoldenState = y_GoldenState[10:11]
X_train11_GoldenState = X_GoldenState[11:12]
y_train11_GoldenState = y_GoldenState[11:12]
X_train12_GoldenState = X_GoldenState[12:13]
y_train12_GoldenState = y_GoldenState[12:13]
X_train13_GoldenState = X_GoldenState[13:14]
y_train13_GoldenState = y_GoldenState[13:14]
X_train14_GoldenState = X_GoldenState[14:15]
y_train14_GoldenState = y_GoldenState[14:15]
X_train15_GoldenState = X_GoldenState[15:16]
y_train15_GoldenState = y_GoldenState[15:16]
X_train16_GoldenState = X_GoldenState[16:17]
y_train16_GoldenState = y_GoldenState[16:17]
X_train17_GoldenState = X_GoldenState[17:18]
y_train17_GoldenState = y_GoldenState[17:18]
X_train18_GoldenState = X_GoldenState[18:19]
y_train18_GoldenState = y_GoldenState[18:19]
X_train19_GoldenState = X_GoldenState[19:20]
y_train19_GoldenState = y_GoldenState[19:20]
X_train20_GoldenState = X_GoldenState[20:21]
y_train20_GoldenState = y_GoldenState[20:21]
X_train21_GoldenState = X_GoldenState[21:22]
y_train21_GoldenState = y_GoldenState[21:22]
X_train22_GoldenState = X_GoldenState[22:23]
y_train22_GoldenState = y_GoldenState[22:23]

X_train1_GoldenStateAll = df.iloc[[0,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],[5,11,18,19,20]]
y_train1_GoldenStateAll = df.iloc[[0,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],24:25]

X_train2_GoldenStateAll = df.iloc[[0,1,45 ,67 ,89,111, 133,155,177,199,221 ,243 ,265 ,287 ,309 ,331 ,353 ,375 ,397 ,419 ,441 ,463 ,485 ,507 ,529 ,551 ,573 ,595 ,617 ,639],[5,11,18,19,20]]
y_train2_GoldenStateAll = df.iloc[[1, 45 ,67,89,111, 133,155,177,199,221 ,243 ,265 ,287 ,309 ,331 ,353 ,375 ,397 ,419 ,441 ,463 ,485 ,507 ,529 ,551 ,573 ,595 ,617 ,639],24:25]

X_train3_GoldenStateAll = df.iloc[[0,2,46,68,90,112 ,134 ,156 ,178 ,200 ,222 ,244 ,266 ,288 ,310 ,332 ,354 ,376 ,398 ,420 ,442 ,464 ,486 ,508 ,530 ,552 ,574 ,596 ,618 ,640],[5,11,18,19,20]]
y_train3_GoldenStateAll = df.iloc[[2,46,68,90,112 ,134 ,156 ,178 ,200 ,222 ,244 ,266 ,288 ,310 ,332 ,354 ,376 ,398 ,420 ,442 ,464 ,486 ,508 ,530 ,552 ,574 ,596 ,618 ,640],24:25]

X_train4_GoldenStateAll = df.iloc[[0,3,47,69,91,113 ,135 ,157 ,179 ,201 ,223 ,245 ,267 ,289 ,311 ,333 ,355 ,377 ,399 ,421 ,443 ,465 ,487 ,509 ,531 ,553 ,575 ,597 ,619 ,641],[5,11,18,19,20]]
y_train4_GoldenStateAll = df.iloc[[3,47,69,91,113 ,135 ,157 ,179 ,201 ,223 ,245 ,267 ,289 ,311 ,333 ,355 ,377 ,399 ,421 ,443 ,465 ,487 ,509 ,531 ,553 ,575 ,597 ,619 ,641],24:25]

X_train5_GoldenStateAll = df.iloc[[0,4,48,70,92,114 ,136 ,158 ,180 ,202 ,224 ,246 ,268 ,290 ,312 ,334 ,356 ,378 ,400 ,422 ,444 ,466 ,488 ,510 ,532 ,554 ,576 ,598 ,620 ,642],[5,11,18,19,20]]
y_train5_GoldenStateAll = df.iloc[[4,48,70,92,114 ,136 ,158 ,180 ,202 ,224 ,246 ,268 ,290 ,312 ,334 ,356 ,378 ,400 ,422 ,444 ,466 ,488 ,510 ,532 ,554 ,576 ,598 ,620 ,642],24:25]

X_train6_GoldenStateAll = df.iloc[[0,5,49,71,93,115 ,137 ,159 ,181 ,203 ,225 ,247 ,269 ,291 ,313 ,335 ,357 ,379 ,401 ,423 ,445 ,467 ,489 ,511 ,533 ,555 ,577 ,599 ,621 ,643],[5,11,18,19,20]]
y_train6_GoldenStateAll = df.iloc[[5,49,71,93,115 ,137 ,159 ,181 ,203 ,225 ,247 ,269 ,291 ,313 ,335 ,357 ,379 ,401 ,423 ,445 ,467 ,489 ,511 ,533 ,555 ,577 ,599 ,621 ,643],24:25]

X_train7_GoldenStateAll = df.iloc[[0,6,50,72,94,116 ,138 ,160 ,182 ,204 ,226 ,248 ,270 ,292 ,314 ,336 ,358 ,380 ,402 ,424 ,446 ,468 ,490 ,512 ,534 ,556 ,578 ,600 ,622 ,644],[5,11,18,19,20]]
y_train7_GoldenStateAll = df.iloc[[6,50,72,94,116 ,138 ,160 ,182 ,204 ,226 ,248 ,270 ,292 ,314 ,336 ,358 ,380 ,402 ,424 ,446 ,468 ,490 ,512 ,534 ,556 ,578 ,600 ,622 ,644],24:25]

X_train8_GoldenStateAll = df.iloc[[0,7,51,73,95,117 ,139 ,161 ,183 ,205 ,227 ,249 ,271 ,293 ,315 ,337 ,359 ,381 ,403 ,425 ,447 ,469 ,491 ,513 ,535 ,557 ,579 ,601 ,623 ,645],[5,11,18,19,20]]
y_train8_GoldenStateAll = df.iloc[[7,51,73,95,117 ,139 ,161 ,183 ,205 ,227 ,249 ,271 ,293 ,315 ,337 ,359 ,381 ,403 ,425 ,447 ,469 ,491 ,513 ,535 ,557 ,579 ,601 ,623 ,645],24:25]

X_train9_GoldenStateAll = df.iloc[[0,8,52,74,96,118 ,140 ,162 ,184 ,206 ,228 ,250 ,272 ,294 ,316 ,338 ,360 ,382 ,404 ,426 ,448 ,470 ,492 ,514 ,536 ,558 ,580 ,602 ,624 ,646],[5,11,18,19,20]]
y_train9_GoldenStateAll = df.iloc[[8,52,74,96,118 ,140 ,162 ,184 ,206 ,228 ,250 ,272 ,294 ,316 ,338 ,360 ,382 ,404 ,426 ,448 ,470 ,492 ,514 ,536 ,558 ,580 ,602 ,624 ,646],24:25]

X_train10_GoldenStateAll = df.iloc[[0,9,53,75,97,119 ,141 ,163 ,185 ,207 ,229 ,251 ,273 ,295 ,317 ,339 ,361 ,383 ,405 ,427 ,449 ,471 ,493 ,515 ,537 ,559 ,581 ,603 ,625 ,647],[5,11,18,19,20]]
y_train10_GoldenStateAll = df.iloc[[9,53,75,97,119 ,141 ,163 ,185 ,207 ,229 ,251 ,273 ,295 ,317 ,339 ,361 ,383 ,405 ,427 ,449 ,471 ,493 ,515 ,537 ,559 ,581 ,603 ,625 ,647],24:25]

X_train11_GoldenStateAll = df.iloc[[0,10,54,76,98,120 ,142 ,164 ,186 ,208 ,230 ,252 ,274 ,296 ,318 ,340 ,362 ,384 ,406 ,428 ,450 ,472 ,494 ,516 ,538 ,560 ,582 ,604 ,626 ,648],[5,11,18,19,20]]
y_train11_GoldenStateAll = df.iloc[[10,54,76,98,120 ,142 ,164 ,186 ,208 ,230 ,252 ,274 ,296 ,318 ,340 ,362 ,384 ,406 ,428 ,450 ,472 ,494 ,516 ,538 ,560 ,582 ,604 ,626 ,648],24:25]

X_train12_GoldenStateAll = df.iloc[[0,11,55,77,99,121 ,143 ,165 ,187 ,209 ,231 ,253 ,275 ,297 ,319 ,341 ,363 ,385 ,407 ,429 ,451 ,473 ,495 ,517 ,539 ,561 ,583 ,605 ,627 ,649],[5,11,18,19,20]]
y_train12_GoldenStateAll = df.iloc[[11,55,77,99,121 ,143 ,165 ,187 ,209 ,231 ,253 ,275 ,297 ,319 ,341 ,363 ,385 ,407 ,429 ,451 ,473 ,495 ,517 ,539 ,561 ,583 ,605 ,627 ,649],24:25]

X_train13_GoldenStateAll = df.iloc[[0,12,56,78,100, 122, 144, 166, 188, 210, 232, 254, 276, 298, 320, 342, 364, 386, 408, 430, 452, 474, 496, 518, 540, 562, 584, 606, 628, 650],[5,11,18,19,20]]
y_train13_GoldenStateAll = df.iloc[[12,56,78,100, 122, 144, 166, 188, 210, 232, 254, 276, 298, 320, 342, 364, 386, 408, 430, 452, 474, 496, 518, 540, 562, 584, 606, 628, 650],24:25]

X_train14_GoldenStateAll = df.iloc[[0,13,57,79,101, 123, 145, 167, 189, 211, 233, 255, 277, 299, 321, 343, 365, 387, 409, 431, 453, 475, 497, 519, 541, 563, 585, 607, 629, 651],[5,11,18,19,20]]
y_train14_GoldenStateAll = df.iloc[[13,57,79,101, 123, 145, 167, 189, 211, 233, 255, 277, 299, 321, 343, 365, 387, 409, 431, 453, 475, 497, 519, 541, 563, 585, 607, 629, 651],24:25]

X_train15_GoldenStateAll = df.iloc[[0,14,58,80,102, 124, 146, 168, 190, 212, 234, 256, 278, 300, 322, 344, 366, 388, 410, 432, 454, 476, 498, 520, 542, 564, 586, 608, 630, 652],[5,11,18,19,20]]
y_train15_GoldenStateAll = df.iloc[[14,58,80,102, 124, 146, 168, 190, 212, 234, 256, 278, 300, 322, 344, 366, 388, 410, 432, 454, 476, 498, 520, 542, 564, 586, 608, 630, 652],24:25]

X_train16_GoldenStateAll = df.iloc[[0,15,59,81,103, 125, 147, 169, 191, 213, 235, 257, 279, 301, 323, 345, 367, 389, 411, 433, 455, 477, 499, 521, 543, 565, 587, 609, 631, 653],[5,11,18,19,20]]
y_train16_GoldenStateAll = df.iloc[[15,59,81,103, 125, 147, 169, 191, 213, 235, 257, 279, 301, 323, 345, 367, 389, 411, 433, 455, 477, 499, 521, 543, 565, 587, 609, 631, 653],24:25]

X_train17_GoldenStateAll = df.iloc[[0,16,60,82,104, 126, 148, 170, 192, 214, 236, 258, 280, 302, 324, 346, 368, 390, 412, 434, 456, 478, 500, 522, 544, 566, 588, 610, 632, 654],[5,11,18,19,20]]
y_train17_GoldenStateAll = df.iloc[[16,60,82,104, 126, 148, 170, 192, 214, 236, 258, 280, 302, 324, 346, 368, 390, 412, 434, 456, 478, 500, 522, 544, 566, 588, 610, 632, 654],24:25]

X_train18_GoldenStateAll = df.iloc[[0,17,61,83,105, 127, 149, 171, 193, 215, 237, 259, 281, 303, 325, 347, 369, 391, 413, 435, 457, 479, 501, 523, 545, 567, 589, 611, 633, 655],[5,11,18,19,20]]
y_train18_GoldenStateAll = df.iloc[[17,61,83,105, 127, 149, 171, 193, 215, 237, 259, 281, 303, 325, 347, 369, 391, 413, 435, 457, 479, 501, 523, 545, 567, 589, 611, 633, 655],24:25]

X_train19_GoldenStateAll = df.iloc[[0,18,62,84,106, 128, 150, 172, 194, 216, 238, 260, 282, 304, 326, 348, 370, 392, 414, 436, 458, 480, 502, 524, 546, 568, 590, 612, 634, 656],[5,11,18,19,20]]
y_train19_GoldenStateAll = df.iloc[[18,62,84,106, 128, 150, 172, 194, 216, 238, 260, 282, 304, 326, 348, 370, 392, 414, 436, 458, 480, 502, 524, 546, 568, 590, 612, 634, 656],24:25]

X_train20_GoldenStateAll = df.iloc[[0,19,63,85,107, 129, 151, 173, 195, 217, 239, 261, 283, 305, 327, 349, 371, 393, 415, 437, 459, 481, 503, 525, 547, 569, 591, 613, 635, 657],[5,11,18,19,20]]
y_train20_GoldenStateAll = df.iloc[[19,63,85,107, 129, 151, 173, 195, 217, 239, 261, 283, 305, 327, 349, 371, 393, 415, 437, 459, 481, 503, 525, 547, 569, 591, 613, 635, 657],24:25]

X_train21_GoldenStateAll = df.iloc[[0,20,64,86,108, 130, 152, 174, 196, 218, 240, 262, 284, 306, 328, 350, 372, 394, 416, 438, 460, 482, 504, 526, 548, 570, 592, 614, 636, 658],[5,11,18,19,20]]
y_train21_GoldenStateAll = df.iloc[[20,64,86,108, 130, 152, 174, 196, 218, 240, 262, 284, 306, 328, 350, 372, 394, 416, 438, 460, 482, 504, 526, 548, 570, 592, 614, 636, 658],24:25]

X_train22_GoldenStateAll = df.iloc[[0,21,65,87,109, 131, 153, 175, 197, 219, 241, 263, 285, 307, 329, 351, 373, 395, 417, 439, 461, 483, 505, 527, 549, 571, 593, 615, 637, 659],[5,11,18,19,20]]
y_train22_GoldenStateAll = df.iloc[[21,65,87,109, 131, 153, 175, 197, 219, 241, 263, 285, 307, 329, 351, 373, 395, 417, 439, 461, 483, 505, 527, 549, 571, 593, 615, 637, 659],24:25]

# %%
regressorGoldenState1 = LinearRegression()
regressorGoldenState1.fit(X_train1_GoldenStateAll, y_train1_GoldenStateAll)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pd.DataFrame(list(zip(X_train1_GoldenStateAll, regressorHouston1.coef_)), columns=['Features', 'Beta Coefficient'])
# Out:
#         Features                                   Beta Coefficient
# 0  3Ps Attempted  [-0.34824932546527265, 3.902760326962351, -0.2...

# %%
y_pred1_GoldenState = regressorGoldenState1.predict(X_train1_GoldenState)

# %%
y_train2_GoldenStateAll.loc[-1] = y_pred1_GoldenState.item(0)  # adding a row
y_train2_GoldenStateAll.index = y_train2_GoldenStateAll.index + 1  # shifting index
y_train2_GoldenStateAll = y_train2_GoldenStateAll.sort_index()
regressorGoldenState2 = LinearRegression()
regressorGoldenState2.fit(X_train2_GoldenStateAll, y_train2_GoldenStateAll)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
pd.DataFrame(list(zip(X_train2_GoldenStateAll, regressorGoldenState2.coef_)), columns=['Features', 'Beta Coefficient'])
# Out:
#         Features                                   Beta Coefficient
# 0  3Ps Attempted  [1.3218750238951475, 0.47583201051313745, -1.5...

# %%
y_pred2_GoldenState = regressorGoldenState2.predict(X_train2_GoldenState)

# %%
y_train3_GoldenStateAll.loc[-1] = y_pred2_GoldenState.item(0)  # adding a row
y_train3_GoldenStateAll.index = y_train3_GoldenStateAll.index + 1  # shifting index
y_train3_GoldenStateAll = y_train3_GoldenStateAll.sort_index()
regressorGoldenState3 = LinearRegression()
regressorGoldenState3.fit(X_train3_GoldenStateAll, y_train3_GoldenStateAll)

pd.DataFrame(list(zip(X_train3_GoldenStateAll, regressorGoldenState3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred3_GoldenState = regressorGoldenState3.predict(X_train3_GoldenState)

# %%
y_train4_GoldenStateAll.loc[-1] = y_pred3_GoldenState.item(0)  # adding a row
y_train4_GoldenStateAll.index = y_train4_GoldenStateAll.index + 1  # shifting index
y_train4_GoldenStateAll = y_train4_GoldenStateAll.sort_index()
regressorGoldenState4 = LinearRegression()
regressorGoldenState4.fit(X_train4_GoldenStateAll, y_train4_GoldenStateAll)

pd.DataFrame(list(zip(X_train4_GoldenStateAll, regressorGoldenState4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred4_GoldenState = regressorGoldenState4.predict(X_train4_GoldenState)

# %%
y_train5_GoldenStateAll.loc[-1] = y_pred4_GoldenState.item(0)  # adding a row
y_train5_GoldenStateAll.index = y_train5_GoldenStateAll.index + 1  # shifting index
y_train5_GoldenStateAll = y_train5_GoldenStateAll.sort_index()
regressorGoldenState5 = LinearRegression()
regressorGoldenState5.fit(X_train5_GoldenStateAll, y_train5_GoldenStateAll)

pd.DataFrame(list(zip(X_train5_GoldenStateAll, regressorGoldenState5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred5_GoldenState = regressorGoldenState5.predict(X_train5_GoldenState)

# %%
y_train6_GoldenStateAll.loc[-1] = y_pred5_GoldenState.item(0)  # adding a row
y_train6_GoldenStateAll.index = y_train6_GoldenStateAll.index + 1  # shifting index
y_train6_GoldenStateAll = y_train6_GoldenStateAll.sort_index()
regressorGoldenState6 = LinearRegression()
regressorGoldenState6.fit(X_train6_GoldenStateAll, y_train6_GoldenStateAll)

pd.DataFrame(list(zip(X_train6_GoldenStateAll, regressorGoldenState6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred6_GoldenState = regressorGoldenState6.predict(X_train6_GoldenState)

# %%
y_train7_GoldenStateAll.loc[-1] = y_pred6_GoldenState.item(0)  # adding a row
y_train7_GoldenStateAll.index = y_train7_GoldenStateAll.index + 1  # shifting index
y_train7_GoldenStateAll = y_train7_GoldenStateAll.sort_index()
regressorGoldenState7 = LinearRegression()
regressorGoldenState7.fit(X_train7_GoldenStateAll, y_train7_GoldenStateAll)

pd.DataFrame(list(zip(X_train7_GoldenStateAll, regressorGoldenState7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred7_GoldenState = regressorGoldenState7.predict(X_train7_GoldenState)

# %%
y_train8_GoldenStateAll.loc[-1] = y_pred7_GoldenState.item(0)  # adding a row
y_train8_GoldenStateAll.index = y_train8_GoldenStateAll.index + 1  # shifting index
y_train8_GoldenStateAll = y_train8_GoldenStateAll.sort_index()
regressorGoldenState8 = LinearRegression()
regressorGoldenState8.fit(X_train8_GoldenStateAll, y_train8_GoldenStateAll)

pd.DataFrame(list(zip(X_train8_GoldenStateAll, regressorGoldenState8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred8_GoldenState = regressorGoldenState8.predict(X_train8_GoldenState)

# %%
y_train9_GoldenStateAll.loc[-1] = y_pred8_GoldenState.item(0)  # adding a row
y_train9_GoldenStateAll.index = y_train9_GoldenStateAll.index + 1  # shifting index
y_train9_GoldenStateAll = y_train9_GoldenStateAll.sort_index()
regressorGoldenState9 = LinearRegression()
regressorGoldenState9.fit(X_train9_GoldenStateAll, y_train9_GoldenStateAll)

pd.DataFrame(list(zip(X_train9_GoldenStateAll, regressorGoldenState9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred9_GoldenState = regressorGoldenState9.predict(X_train9_GoldenState)

# %%
y_train10_GoldenStateAll.loc[-1] = y_pred9_GoldenState.item(0)  # adding a row
y_train10_GoldenStateAll.index = y_train10_GoldenStateAll.index + 1  # shifting index
y_train10_GoldenStateAll = y_train10_GoldenStateAll.sort_index()
regressorGoldenState10 = LinearRegression()
regressorGoldenState10.fit(X_train10_GoldenStateAll, y_train10_GoldenStateAll)

pd.DataFrame(list(zip(X_train10_GoldenStateAll, regressorGoldenState10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred10_GoldenState = regressorGoldenState10.predict(X_train10_GoldenState)

# %%
y_train11_GoldenStateAll.loc[-1] = y_pred10_GoldenState.item(0)  # adding a row
y_train11_GoldenStateAll.index = y_train11_GoldenStateAll.index + 1  # shifting index
y_train11_GoldenStateAll = y_train11_GoldenStateAll.sort_index()
regressorGoldenState11 = LinearRegression()
regressorGoldenState11.fit(X_train11_GoldenStateAll, y_train11_GoldenStateAll)

pd.DataFrame(list(zip(X_train11_GoldenStateAll, regressorGoldenState11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred11_GoldenState = regressorGoldenState11.predict(X_train11_GoldenState)

# %%
y_train12_GoldenStateAll.loc[-1] = y_pred11_GoldenState.item(0)  # adding a row
y_train12_GoldenStateAll.index = y_train12_GoldenStateAll.index + 1  # shifting index
y_train12_GoldenStateAll = y_train12_GoldenStateAll.sort_index()
regressorGoldenState12 = LinearRegression()
regressorGoldenState12.fit(X_train12_GoldenStateAll, y_train12_GoldenStateAll)

pd.DataFrame(list(zip(X_train12_GoldenStateAll, regressorGoldenState12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred12_GoldenState = regressorGoldenState12.predict(X_train12_GoldenState)

# %%
y_train13_GoldenStateAll.loc[-1] = y_pred12_GoldenState.item(0)  # adding a row
y_train13_GoldenStateAll.index = y_train13_GoldenStateAll.index + 1  # shifting index
y_train13_GoldenStateAll = y_train13_GoldenStateAll.sort_index()
regressorGoldenState13 = LinearRegression()
regressorGoldenState13.fit(X_train13_GoldenStateAll, y_train13_GoldenStateAll)

pd.DataFrame(list(zip(X_train13_GoldenStateAll, regressorGoldenState13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred13_GoldenState = regressorGoldenState13.predict(X_train13_GoldenState)

# %%
y_train14_GoldenStateAll.loc[-1] = y_pred13_GoldenState.item(0)  # adding a row
y_train14_GoldenStateAll.index = y_train14_GoldenStateAll.index + 1  # shifting index
y_train14_GoldenStateAll = y_train14_GoldenStateAll.sort_index()
regressorGoldenState14 = LinearRegression()
regressorGoldenState14.fit(X_train14_GoldenStateAll, y_train14_GoldenStateAll)

pd.DataFrame(list(zip(X_train14_GoldenStateAll, regressorGoldenState14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred14_GoldenState = regressorGoldenState14.predict(X_train14_GoldenState)

# %%
y_train15_GoldenStateAll.loc[-1] = y_pred14_GoldenState.item(0)  # adding a row
y_train15_GoldenStateAll.index = y_train15_GoldenStateAll.index + 1  # shifting index
y_train15_GoldenStateAll = y_train15_GoldenStateAll.sort_index()
regressorGoldenState15 = LinearRegression()
regressorGoldenState15.fit(X_train15_GoldenStateAll, y_train15_GoldenStateAll)

pd.DataFrame(list(zip(X_train15_GoldenStateAll, regressorGoldenState15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred15_GoldenState = regressorGoldenState15.predict(X_train15_GoldenState)

# %%
y_train16_GoldenStateAll.loc[-1] = y_pred15_GoldenState.item(0)  # adding a row
y_train16_GoldenStateAll.index = y_train16_GoldenStateAll.index + 1  # shifting index
y_train16_GoldenStateAll = y_train16_GoldenStateAll.sort_index()
regressorGoldenState16 = LinearRegression()
regressorGoldenState16.fit(X_train16_GoldenStateAll, y_train16_GoldenStateAll)

pd.DataFrame(list(zip(X_train16_GoldenStateAll, regressorGoldenState16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred16_GoldenState = regressorGoldenState16.predict(X_train16_GoldenState)

# %%
y_train17_GoldenStateAll.loc[-1] = y_pred16_GoldenState.item(0)  # adding a row
y_train17_GoldenStateAll.index = y_train17_GoldenStateAll.index + 1  # shifting index
y_train17_GoldenStateAll = y_train17_GoldenStateAll.sort_index()
regressorGoldenState17 = LinearRegression()
regressorGoldenState17.fit(X_train17_GoldenStateAll, y_train17_GoldenStateAll)

pd.DataFrame(list(zip(X_train17_GoldenStateAll, regressorGoldenState17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred17_GoldenState = regressorGoldenState17.predict(X_train17_GoldenState)

# %%
y_train18_GoldenStateAll.loc[-1] = y_pred17_GoldenState.item(0)  # adding a row
y_train18_GoldenStateAll.index = y_train18_GoldenStateAll.index + 1  # shifting index
y_train18_GoldenStateAll = y_train18_GoldenStateAll.sort_index()
regressorGoldenState18 = LinearRegression()
regressorGoldenState18.fit(X_train18_GoldenStateAll, y_train18_GoldenStateAll)

pd.DataFrame(list(zip(X_train18_GoldenStateAll, regressorGoldenState18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred18_GoldenState = regressorGoldenState18.predict(X_train18_GoldenState)

# %%
y_train19_GoldenStateAll.loc[-1] = y_pred18_GoldenState.item(0)  # adding a row
y_train19_GoldenStateAll.index = y_train19_GoldenStateAll.index + 1  # shifting index
y_train19_GoldenStateAll = y_train19_GoldenStateAll.sort_index()
regressorGoldenState19 = LinearRegression()
regressorGoldenState19.fit(X_train19_GoldenStateAll, y_train19_GoldenStateAll)

pd.DataFrame(list(zip(X_train19_GoldenStateAll, regressorGoldenState19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred19_GoldenState = regressorGoldenState19.predict(X_train19_GoldenState)

# %%
y_train20_GoldenStateAll.loc[-1] = y_pred19_GoldenState.item(0)  # adding a row
y_train20_GoldenStateAll.index = y_train20_GoldenStateAll.index + 1  # shifting index
y_train20_GoldenStateAll = y_train20_GoldenStateAll.sort_index()
regressorGoldenState20 = LinearRegression()
regressorGoldenState20.fit(X_train20_GoldenStateAll, y_train20_GoldenStateAll)

pd.DataFrame(list(zip(X_train20_GoldenStateAll, regressorGoldenState20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred20_GoldenState = regressorGoldenState20.predict(X_train20_GoldenState)

# %%
y_train21_GoldenStateAll.loc[-1] = y_pred20_GoldenState.item(0)  # adding a row
y_train21_GoldenStateAll.index = y_train21_GoldenStateAll.index + 1  # shifting index
y_train21_GoldenStateAll = y_train21_GoldenStateAll.sort_index()
regressorGoldenState21 = LinearRegression()
regressorGoldenState21.fit(X_train21_GoldenStateAll, y_train21_GoldenStateAll)

pd.DataFrame(list(zip(X_train21_GoldenStateAll, regressorGoldenState21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred21_GoldenState = regressorGoldenState21.predict(X_train21_GoldenState)

# %%
#y_train22_GoldenStateAll.loc[-1] = y_pred21_GoldenState.item(0)  # adding a row
#y_train22_GoldenStateAll.index = y_train22_GoldenStateAll.index + 1  # shifting index
#y_train22_GoldenStateAll = y_train22_GoldenStateAll.sort_index()
#regressorGoldenState22 = LinearRegression()
#regressorGoldenState22.fit(X_train22_GoldenStateAll, y_train22_GoldenStateAll)

#pd.DataFrame(list(zip(X_train22_GoldenStateAll, regressorGoldenState22.coef_)), columns=['Features', 'Beta Coefficient'])

#y_pred22_GoldenState = regressorGoldenState22.predict(X_train22_GoldenState)

# %%
X_train1_Portland = X_Portland[0:1]
y_train1_Portland = y_Portland[0:1]
X_train2_Portland = X_Portland[1:2]
y_train2_Portland = y_Portland[1:2]
X_train3_Portland = X_Portland[2:3]
y_train3_Portland = y_Portland[2:3]
X_train4_Portland = X_Portland[3:4]
y_train4_Portland = y_Portland[3:4]
X_train5_Portland = X_Portland[4:5]
y_train5_Portland = y_Portland[4:5]
X_train6_Portland = X_Portland[5:6]
y_train6_Portland = y_Portland[5:6]
X_train7_Portland = X_Portland[7:8]
y_train7_Portland = y_Portland[7:8]
X_train8_Portland = X_Portland[8:9]
y_train8_Portland = y_Portland[8:9]
X_train9_Portland = X_Portland[9:10]
y_train9_Portland = y_Portland[9:10]
X_train10_Portland = X_Portland[10:11]
y_train10_Portland = y_Portland[10:11]
X_train11_Portland = X_Portland[11:12]
y_train11_Portland = y_Portland[11:12]
X_train12_Portland = X_Portland[12:13]
y_train12_Portland = y_Portland[12:13]
X_train13_Portland = X_Portland[13:14]
y_train13_Portland = y_Portland[13:14]
X_train14_Portland = X_Portland[14:15]
y_train14_Portland = y_Portland[14:15]
X_train15_Portland = X_Portland[15:16]
y_train15_Portland = y_Portland[15:16]
X_train16_Portland = X_Portland[16:17]
y_train16_Portland = y_Portland[16:17]
X_train17_Portland = X_Portland[17:18]
y_train17_Portland = y_Portland[17:18]
X_train18_Portland = X_Portland[18:19]
y_train18_Portland = y_Portland[18:19]
X_train19_Portland = X_Portland[19:20]
y_train19_Portland = y_Portland[19:20]
X_train20_Portland = X_Portland[20:21]
y_train20_Portland = y_Portland[20:21]
X_train21_Portland = X_Portland[21:22]
y_train21_Portland = y_Portland[21:22]
X_train22_Portland = X_Portland[22:23]
y_train22_Portland = y_Portland[22:23]

X_train1_PortlandAll = df.iloc[[0,22,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],[5,11,18,19,20]]
y_train1_PortlandAll = df.iloc[[0,22,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],24:25]

X_train2_PortlandAll = df.iloc[[0,1,23 ,67 ,89,111, 133,155,177,199,221 ,243 ,265 ,287 ,309 ,331 ,353 ,375 ,397 ,419 ,441 ,463 ,485 ,507 ,529 ,551 ,573 ,595 ,617 ,639],[5,11,18,19,20]]
y_train2_PortlandAll = df.iloc[[1, 23 ,67,89,111, 133,155,177,199,221 ,243 ,265 ,287 ,309 ,331 ,353 ,375 ,397 ,419 ,441 ,463 ,485 ,507 ,529 ,551 ,573 ,595 ,617 ,639],24:25]

X_train3_PortlandAll = df.iloc[[0,2,24,68,90,112 ,134 ,156 ,178 ,200 ,222 ,244 ,266 ,288 ,310 ,332 ,354 ,376 ,398 ,420 ,442 ,464 ,486 ,508 ,530 ,552 ,574 ,596 ,618 ,640],[5,11,18,19,20]]
y_train3_PortlandAll = df.iloc[[2,24,68,90,112 ,134 ,156 ,178 ,200 ,222 ,244 ,266 ,288 ,310 ,332 ,354 ,376 ,398 ,420 ,442 ,464 ,486 ,508 ,530 ,552 ,574 ,596 ,618 ,640],24:25]

X_train4_PortlandAll = df.iloc[[0,3,25,69,91,113 ,135 ,157 ,179 ,201 ,223 ,245 ,267 ,289 ,311 ,333 ,355 ,377 ,399 ,421 ,443 ,465 ,487 ,509 ,531 ,553 ,575 ,597 ,619 ,641],[5,11,18,19,20]]
y_train4_PortlandAll = df.iloc[[3,25,69,91,113 ,135 ,157 ,179 ,201 ,223 ,245 ,267 ,289 ,311 ,333 ,355 ,377 ,399 ,421 ,443 ,465 ,487 ,509 ,531 ,553 ,575 ,597 ,619 ,641],24:25]

X_train5_PortlandAll = df.iloc[[0,4,26,70,92,114 ,136 ,158 ,180 ,202 ,224 ,246 ,268 ,290 ,312 ,334 ,356 ,378 ,400 ,422 ,444 ,466 ,488 ,510 ,532 ,554 ,576 ,598 ,620 ,642],[5,11,18,19,20]]
y_train5_PortlandAll = df.iloc[[4,26,70,92,114 ,136 ,158 ,180 ,202 ,224 ,246 ,268 ,290 ,312 ,334 ,356 ,378 ,400 ,422 ,444 ,466 ,488 ,510 ,532 ,554 ,576 ,598 ,620 ,642],24:25]

X_train6_PortlandAll = df.iloc[[0,5,27,71,93,115 ,137 ,159 ,181 ,203 ,225 ,247 ,269 ,291 ,313 ,335 ,357 ,379 ,401 ,423 ,445 ,467 ,489 ,511 ,533 ,555 ,577 ,599 ,621 ,643],[5,11,18,19,20]]
y_train6_PortlandAll = df.iloc[[5,27,71,93,115 ,137 ,159 ,181 ,203 ,225 ,247 ,269 ,291 ,313 ,335 ,357 ,379 ,401 ,423 ,445 ,467 ,489 ,511 ,533 ,555 ,577 ,599 ,621 ,643],24:25]

X_train7_PortlandAll = df.iloc[[0,6,28,72,94,116 ,138 ,160 ,182 ,204 ,226 ,248 ,270 ,292 ,314 ,336 ,358 ,380 ,402 ,424 ,446 ,468 ,490 ,512 ,534 ,556 ,578 ,600 ,622 ,644],[5,11,18,19,20]]
y_train7_PortlandAll = df.iloc[[6,28,72,94,116 ,138 ,160 ,182 ,204 ,226 ,248 ,270 ,292 ,314 ,336 ,358 ,380 ,402 ,424 ,446 ,468 ,490 ,512 ,534 ,556 ,578 ,600 ,622 ,644],24:25]

X_train8_PortlandAll = df.iloc[[0,7,29,73,95,117 ,139 ,161 ,183 ,205 ,227 ,249 ,271 ,293 ,315 ,337 ,359 ,381 ,403 ,425 ,447 ,469 ,491 ,513 ,535 ,557 ,579 ,601 ,623 ,645],[5,11,18,19,20]]
y_train8_PortlandAll = df.iloc[[7,29,73,95,117 ,139 ,161 ,183 ,205 ,227 ,249 ,271 ,293 ,315 ,337 ,359 ,381 ,403 ,425 ,447 ,469 ,491 ,513 ,535 ,557 ,579 ,601 ,623 ,645],24:25]

X_train9_PortlandAll = df.iloc[[0,8,30,74,96,118 ,140 ,162 ,184 ,206 ,228 ,250 ,272 ,294 ,316 ,338 ,360 ,382 ,404 ,426 ,448 ,470 ,492 ,514 ,536 ,558 ,580 ,602 ,624 ,646],[5,11,18,19,20]]
y_train9_PortlandAll = df.iloc[[8,30,74,96,118 ,140 ,162 ,184 ,206 ,228 ,250 ,272 ,294 ,316 ,338 ,360 ,382 ,404 ,426 ,448 ,470 ,492 ,514 ,536 ,558 ,580 ,602 ,624 ,646],24:25]

X_train10_PortlandAll = df.iloc[[0,9,31,75,97,119 ,141 ,163 ,185 ,207 ,229 ,251 ,273 ,295 ,317 ,339 ,361 ,383 ,405 ,427 ,449 ,471 ,493 ,515 ,537 ,559 ,581 ,603 ,625 ,647],[5,11,18,19,20]]
y_train10_PortlandAll = df.iloc[[9,31,75,97,119 ,141 ,163 ,185 ,207 ,229 ,251 ,273 ,295 ,317 ,339 ,361 ,383 ,405 ,427 ,449 ,471 ,493 ,515 ,537 ,559 ,581 ,603 ,625 ,647],24:25]

X_train11_PortlandAll = df.iloc[[0,10,32,76,98,120 ,142 ,164 ,186 ,208 ,230 ,252 ,274 ,296 ,318 ,340 ,362 ,384 ,406 ,428 ,450 ,472 ,494 ,516 ,538 ,560 ,582 ,604 ,626 ,648],[5,11,18,19,20]]
y_train11_PortlandAll = df.iloc[[10,32,76,98,120 ,142 ,164 ,186 ,208 ,230 ,252 ,274 ,296 ,318 ,340 ,362 ,384 ,406 ,428 ,450 ,472 ,494 ,516 ,538 ,560 ,582 ,604 ,626 ,648],24:25]

X_train12_PortlandAll = df.iloc[[0,11,33,77,99,121 ,143 ,165 ,187 ,209 ,231 ,253 ,275 ,297 ,319 ,341 ,363 ,385 ,407 ,429 ,451 ,473 ,495 ,517 ,539 ,561 ,583 ,605 ,627 ,649],[5,11,18,19,20]]
y_train12_PortlandAll = df.iloc[[11,33,77,99,121 ,143 ,165 ,187 ,209 ,231 ,253 ,275 ,297 ,319 ,341 ,363 ,385 ,407 ,429 ,451 ,473 ,495 ,517 ,539 ,561 ,583 ,605 ,627 ,649],24:25]

X_train13_PortlandAll = df.iloc[[0,12,34,78,110, 122, 144, 166, 188, 210, 232, 254, 276, 298, 320, 342, 364, 386, 408, 430, 452, 474, 496, 518, 540, 562, 584, 606, 628, 650],[5,11,18,19,20]]
y_train13_PortlandAll = df.iloc[[12,34,78,110, 122, 144, 166, 188, 210, 232, 254, 276, 298, 320, 342, 364, 386, 408, 430, 452, 474, 496, 518, 540, 562, 584, 606, 628, 650],24:25]

X_train14_PortlandAll = df.iloc[[0,13,35,79,111, 123, 145, 167, 189, 211, 233, 255, 277, 299, 321, 343, 365, 387, 409, 431, 453, 475, 497, 519, 541, 563, 585, 607, 629, 651],[5,11,18,19,20]]
y_train14_PortlandAll = df.iloc[[13,35,79,110, 123, 145, 167, 189, 211, 233, 255, 277, 299, 321, 343, 365, 387, 409, 431, 453, 475, 497, 519, 541, 563, 585, 607, 629, 651],24:25]

X_train15_PortlandAll = df.iloc[[0,14,36,80,112, 124, 146, 168, 190, 212, 234, 256, 278, 300, 322, 344, 366, 388, 410, 432, 454, 476, 498, 520, 542, 564, 586, 608, 630, 652],[5,11,18,19,20]]
y_train15_PortlandAll = df.iloc[[14,36,80,112, 124, 146, 168, 190, 212, 234, 256, 278, 300, 322, 344, 366, 388, 410, 432, 454, 476, 498, 520, 542, 564, 586, 608, 630, 652],24:25]

X_train16_PortlandAll = df.iloc[[0,15,37,81,113, 125, 147, 169, 191, 213, 235, 257, 279, 301, 323, 345, 367, 389, 411, 433, 455, 477, 499, 521, 543, 565, 587, 609, 631, 653],[5,11,18,19,20]]
y_train16_PortlandAll = df.iloc[[15,37,81,113, 125, 147, 169, 191, 213, 235, 257, 279, 301, 323, 345, 367, 389, 411, 433, 455, 477, 499, 521, 543, 565, 587, 609, 631, 653],24:25]

X_train17_PortlandAll = df.iloc[[0,16,38,82,114, 126, 148, 170, 192, 214, 236, 258, 280, 302, 324, 346, 368, 390, 412, 434, 456, 478, 500, 522, 544, 566, 588, 610, 632, 654],[5,11,18,19,20]]
y_train17_PortlandAll = df.iloc[[16,38,82,114, 126, 148, 170, 192, 214, 236, 258, 280, 302, 324, 346, 368, 390, 412, 434, 456, 478, 500, 522, 544, 566, 588, 610, 632, 654],24:25]

X_train18_PortlandAll = df.iloc[[0,17,39,83,115, 127, 149, 171, 193, 215, 237, 259, 281, 303, 325, 347, 369, 391, 413, 435, 457, 479, 501, 523, 545, 567, 589, 611, 633, 655],[5,11,18,19,20]]
y_train18_PortlandAll = df.iloc[[17,39,83,115, 127, 149, 171, 193, 215, 237, 259, 281, 303, 325, 347, 369, 391, 413, 435, 457, 479, 501, 523, 545, 567, 589, 611, 633, 655],24:25]

X_train19_PortlandAll = df.iloc[[0,18,40,84,116, 128, 150, 172, 194, 216, 238, 260, 282, 304, 326, 348, 370, 392, 414, 436, 458, 480, 502, 524, 546, 568, 590, 612, 634, 656],[5,11,18,19,20]]
y_train19_PortlandAll = df.iloc[[18,40,84,116, 128, 150, 172, 194, 216, 238, 260, 282, 304, 326, 348, 370, 392, 414, 436, 458, 480, 502, 524, 546, 568, 590, 612, 634, 656],24:25]

X_train20_PortlandAll = df.iloc[[0,19,41,85,117, 129, 151, 173, 195, 217, 239, 261, 283, 305, 327, 349, 371, 393, 415, 437, 459, 481, 503, 525, 547, 569, 591, 613, 635, 657],[5,11,18,19,20]]
y_train20_PortlandAll = df.iloc[[19,41,85,117, 129, 151, 173, 195, 217, 239, 261, 283, 305, 327, 349, 371, 393, 415, 437, 459, 481, 503, 525, 547, 569, 591, 613, 635, 657],24:25]

X_train21_PortlandAll = df.iloc[[0,20,42,86,118, 130, 152, 174, 196, 218, 240, 262, 284, 306, 328, 350, 372, 394, 416, 438, 460, 482, 504, 526, 548, 570, 592, 614, 636, 658],[5,11,18,19,20]]
y_train21_PortlandAll = df.iloc[[20,42,86,118, 130, 152, 174, 196, 218, 240, 262, 284, 306, 328, 350, 372, 394, 416, 438, 460, 482, 504, 526, 548, 570, 592, 614, 636, 658],24:25]

X_train22_PortlandAll = df.iloc[[0,21,43,87,119, 131, 153, 175, 197, 219, 241, 263, 285, 307, 329, 351, 373, 395, 417, 439, 461, 483, 505, 527, 549, 571, 593, 615, 637, 659],[5,11,18,19,20]]
y_train22_PortlandAll = df.iloc[[21,43,87,119, 131, 153, 175, 197, 219, 241, 263, 285, 307, 329, 351, 373, 395, 417, 439, 461, 483, 505, 527, 549, 571, 593, 615, 637, 659],24:25]

# %%
regressorPortland1 = LinearRegression()
regressorPortland1.fit(X_train1_PortlandAll, y_train1_PortlandAll)
pd.DataFrame(list(zip(X_train1_PortlandAll, regressorPortland1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred1_Portland = regressorPortland1.predict(X_train1_Portland)

# %%
y_train2_PortlandAll.loc[-1] = y_pred1_Portland.item(0)  # adding a row
y_train2_PortlandAll.index = y_train2_PortlandAll.index + 1  # shifting index
y_train2_PortlandAll = y_train2_PortlandAll.sort_index()
regressorPortland2 = LinearRegression()
regressorPortland2.fit(X_train2_PortlandAll, y_train2_PortlandAll)

pd.DataFrame(list(zip(X_train2_PortlandAll, regressorPortland2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred2_Portland = regressorPortland2.predict(X_train2_Portland)

# %%
y_train3_PortlandAll.loc[-1] = y_pred2_Portland.item(0)  # adding a row
y_train3_PortlandAll.index = y_train3_PortlandAll.index + 1  # shifting index
y_train3_PortlandAll = y_train3_PortlandAll.sort_index()
regressorPortland3 = LinearRegression()
regressorPortland3.fit(X_train3_PortlandAll, y_train3_PortlandAll)

pd.DataFrame(list(zip(X_train3_PortlandAll, regressorPortland3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred3_Portland = regressorPortland3.predict(X_train3_Portland)

# %%
y_train4_PortlandAll.loc[-1] = y_pred3_Portland.item(0)  # adding a row
y_train4_PortlandAll.index = y_train4_PortlandAll.index + 1  # shifting index
y_train4_PortlandAll = y_train4_PortlandAll.sort_index()
regressorPortland4 = LinearRegression()
regressorPortland4.fit(X_train4_PortlandAll, y_train4_PortlandAll)

pd.DataFrame(list(zip(X_train4_PortlandAll, regressorPortland4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred4_Portland = regressorPortland4.predict(X_train4_Portland)

# %%
y_train5_PortlandAll.loc[-1] = y_pred4_Portland.item(0)  # adding a row
y_train5_PortlandAll.index = y_train5_PortlandAll.index + 1  # shifting index
y_train5_PortlandAll = y_train5_PortlandAll.sort_index()
regressorPortland5 = LinearRegression()
regressorPortland5.fit(X_train5_PortlandAll, y_train5_PortlandAll)

pd.DataFrame(list(zip(X_train5_PortlandAll, regressorPortland5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred5_Portland = regressorPortland5.predict(X_train5_Portland)

# %%
y_train6_PortlandAll.loc[-1] = y_pred5_Portland.item(0)  # adding a row
y_train6_PortlandAll.index = y_train6_PortlandAll.index + 1  # shifting index
y_train6_PortlandAll = y_train6_PortlandAll.sort_index()
regressorPortland6 = LinearRegression()
regressorPortland6.fit(X_train6_PortlandAll, y_train6_PortlandAll)

pd.DataFrame(list(zip(X_train6_PortlandAll, regressorPortland6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred6_Portland = regressorPortland6.predict(X_train6_Portland)

# %%
y_train7_PortlandAll.loc[-1] = y_pred6_Portland.item(0)  # adding a row
y_train7_PortlandAll.index = y_train7_PortlandAll.index + 1  # shifting index
y_train7_PortlandAll = y_train7_PortlandAll.sort_index()
regressorPortland7 = LinearRegression()
regressorPortland7.fit(X_train7_PortlandAll, y_train7_PortlandAll)

pd.DataFrame(list(zip(X_train7_PortlandAll, regressorPortland7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred7_Portland = regressorPortland7.predict(X_train7_Portland)

# %%
y_train8_PortlandAll.loc[-1] = y_pred7_Portland.item(0)  # adding a row
y_train8_PortlandAll.index = y_train8_PortlandAll.index + 1  # shifting index
y_train8_PortlandAll = y_train8_PortlandAll.sort_index()
regressorPortland8 = LinearRegression()
regressorPortland8.fit(X_train8_PortlandAll, y_train8_PortlandAll)

pd.DataFrame(list(zip(X_train8_PortlandAll, regressorPortland8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred8_Portland = regressorPortland8.predict(X_train8_Portland)

# %%
y_train9_PortlandAll.loc[-1] = y_pred8_Portland.item(0)  # adding a row
y_train9_PortlandAll.index = y_train9_PortlandAll.index + 1  # shifting index
y_train9_PortlandAll = y_train9_PortlandAll.sort_index()
regressorPortland9 = LinearRegression()
regressorPortland9.fit(X_train9_PortlandAll, y_train9_PortlandAll)

pd.DataFrame(list(zip(X_train9_PortlandAll, regressorPortland9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred9_Portland = regressorPortland9.predict(X_train9_Portland)

# %%
y_train10_PortlandAll.loc[-1] = y_pred9_Portland.item(0)  # adding a row
y_train10_PortlandAll.index = y_train10_PortlandAll.index + 1  # shifting index
y_train10_PortlandAll = y_train10_PortlandAll.sort_index()
regressorPortland10 = LinearRegression()
regressorPortland10.fit(X_train10_PortlandAll, y_train10_PortlandAll)

pd.DataFrame(list(zip(X_train10_PortlandAll, regressorPortland10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred10_Portland = regressorPortland10.predict(X_train10_Portland)

# %%
y_train11_PortlandAll.loc[-1] = y_pred10_Portland.item(0)  # adding a row
y_train11_PortlandAll.index = y_train11_PortlandAll.index + 1  # shifting index
y_train11_PortlandAll = y_train11_PortlandAll.sort_index()
regressorPortland11 = LinearRegression()
regressorPortland11.fit(X_train11_PortlandAll, y_train11_PortlandAll)

pd.DataFrame(list(zip(X_train11_PortlandAll, regressorPortland11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred11_Portland = regressorPortland11.predict(X_train11_Portland)

# %%
y_train12_PortlandAll.loc[-1] = y_pred11_Portland.item(0)  # adding a row
y_train12_PortlandAll.index = y_train12_PortlandAll.index + 1  # shifting index
y_train12_PortlandAll = y_train12_PortlandAll.sort_index()
regressorPortland12 = LinearRegression()
regressorPortland12.fit(X_train12_PortlandAll, y_train12_PortlandAll)

pd.DataFrame(list(zip(X_train12_PortlandAll, regressorPortland12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred12_Portland = regressorPortland12.predict(X_train12_Portland)

# %%
y_train13_PortlandAll.loc[-1] = y_pred12_Portland.item(0)  # adding a row
y_train13_PortlandAll.index = y_train13_PortlandAll.index + 1  # shifting index
y_train13_PortlandAll = y_train13_PortlandAll.sort_index()
regressorPortland13 = LinearRegression()
regressorPortland13.fit(X_train13_PortlandAll, y_train13_PortlandAll)

pd.DataFrame(list(zip(X_train13_PortlandAll, regressorPortland13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred13_Portland = regressorPortland13.predict(X_train13_Portland)

# %%
y_train14_PortlandAll.loc[-1] = y_pred13_Portland.item(0)  # adding a row
y_train14_PortlandAll.index = y_train14_PortlandAll.index + 1  # shifting index
y_train14_PortlandAll = y_train14_PortlandAll.sort_index()
regressorPortland14 = LinearRegression()
regressorPortland14.fit(X_train14_PortlandAll, y_train14_PortlandAll)

pd.DataFrame(list(zip(X_train14_PortlandAll, regressorPortland14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred14_Portland = regressorPortland14.predict(X_train14_Portland)

# %%
y_train15_PortlandAll.loc[-1] = y_pred14_Portland.item(0)  # adding a row
y_train15_PortlandAll.index = y_train15_PortlandAll.index + 1  # shifting index
y_train15_PortlandAll = y_train15_PortlandAll.sort_index()
regressorPortland15 = LinearRegression()
regressorPortland15.fit(X_train15_PortlandAll, y_train15_PortlandAll)

pd.DataFrame(list(zip(X_train15_PortlandAll, regressorPortland15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred15_Portland = regressorPortland15.predict(X_train15_Portland)

# %%
y_train16_PortlandAll.loc[-1] = y_pred15_Portland.item(0)  # adding a row
y_train16_PortlandAll.index = y_train16_PortlandAll.index + 1  # shifting index
y_train16_PortlandAll = y_train16_PortlandAll.sort_index()
regressorPortland16 = LinearRegression()
regressorPortland16.fit(X_train16_PortlandAll, y_train16_PortlandAll)

pd.DataFrame(list(zip(X_train16_PortlandAll, regressorPortland16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred16_Portland = regressorPortland16.predict(X_train16_Portland)

# %%
y_train17_PortlandAll.loc[-1] = y_pred16_Portland.item(0)  # adding a row
y_train17_PortlandAll.index = y_train17_PortlandAll.index + 1  # shifting index
y_train17_PortlandAll = y_train17_PortlandAll.sort_index()
regressorPortland17 = LinearRegression()
regressorPortland17.fit(X_train17_PortlandAll, y_train17_PortlandAll)

pd.DataFrame(list(zip(X_train17_PortlandAll, regressorPortland17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred17_Portland = regressorPortland17.predict(X_train17_Portland)

# %%
y_train18_PortlandAll.loc[-1] = y_pred17_Portland.item(0)  # adding a row
y_train18_PortlandAll.index = y_train18_PortlandAll.index + 1  # shifting index
y_train18_PortlandAll = y_train18_PortlandAll.sort_index()
regressorPortland18 = LinearRegression()
regressorPortland18.fit(X_train18_PortlandAll, y_train18_PortlandAll)

pd.DataFrame(list(zip(X_train18_PortlandAll, regressorPortland18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred18_Portland = regressorPortland18.predict(X_train18_Portland)

# %%
y_train19_PortlandAll.loc[-1] = y_pred18_Portland.item(0)  # adding a row
y_train19_PortlandAll.index = y_train19_PortlandAll.index + 1  # shifting index
y_train19_PortlandAll = y_train19_PortlandAll.sort_index()
regressorPortland19 = LinearRegression()
regressorPortland19.fit(X_train19_PortlandAll, y_train19_PortlandAll)

pd.DataFrame(list(zip(X_train19_PortlandAll, regressorPortland19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred19_Portland = regressorPortland19.predict(X_train19_Portland)

# %%
y_train20_PortlandAll.loc[-1] = y_pred19_Portland.item(0)  # adding a row
y_train20_PortlandAll.index = y_train20_PortlandAll.index + 1  # shifting index
y_train20_PortlandAll = y_train20_PortlandAll.sort_index()
regressorPortland20 = LinearRegression()
regressorPortland20.fit(X_train20_PortlandAll, y_train20_PortlandAll)

pd.DataFrame(list(zip(X_train20_PortlandAll, regressorPortland20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred20_Portland = regressorPortland20.predict(X_train20_Portland)

# %%
y_train21_PortlandAll.loc[-1] = y_pred20_Portland.item(0)  # adding a row
y_train21_PortlandAll.index = y_train21_PortlandAll.index + 1  # shifting index
y_train21_PortlandAll = y_train21_PortlandAll.sort_index()
regressorPortland21 = LinearRegression()
regressorPortland21.fit(X_train21_PortlandAll, y_train21_PortlandAll)

pd.DataFrame(list(zip(X_train21_PortlandAll, regressorPortland21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred21_Portland = regressorPortland21.predict(X_train21_Portland)

# %%
X_train_OklahomaCity1= X_OklahomaCity[0:1]
y_train_OklahomaCity1= y_OklahomaCity[0:1]
X_train_OklahomaCity2= X_OklahomaCity[1:2]
y_train_OklahomaCity2= y_OklahomaCity[1:2]
X_train_OklahomaCity3= X_OklahomaCity[2:3]
y_train_OklahomaCity3= y_OklahomaCity[2:3]
X_train_OklahomaCity4= X_OklahomaCity[3:4]
y_train_OklahomaCity4= y_OklahomaCity[3:4]
X_train_OklahomaCity5= X_OklahomaCity[4:5]
y_train_OklahomaCity5= y_OklahomaCity[4:5]
y_train_OklahomaCity6= y_OklahomaCity[5:6]
X_train_OklahomaCity7= X_OklahomaCity[7:8]
X_train_OklahomaCity6= X_OklahomaCity[5:6]
y_train_OklahomaCity7= y_OklahomaCity[7:8]
X_train_OklahomaCity8= X_OklahomaCity[8:9]
y_train_OklahomaCity8= y_OklahomaCity[8:9]
X_train_OklahomaCity9= X_OklahomaCity[9:10]
y_train_OklahomaCity9= y_OklahomaCity[9:10]
X_train_OklahomaCity10 = X_OklahomaCity[10:11]
y_train_OklahomaCity10 = y_OklahomaCity[10:11]
X_train_OklahomaCity11 = X_OklahomaCity[11:12]
y_train_OklahomaCity11 = y_OklahomaCity[11:12]
X_train_OklahomaCity12 = X_OklahomaCity[12:13]
y_train_OklahomaCity12 = y_OklahomaCity[12:13]
X_train_OklahomaCity13 = X_OklahomaCity[13:14]
y_train_OklahomaCity13 = y_OklahomaCity[13:14]
X_train_OklahomaCity14 = X_OklahomaCity[14:15]
y_train_OklahomaCity14 = y_OklahomaCity[14:15]
X_train_OklahomaCity15 = X_OklahomaCity[15:16]
y_train_OklahomaCity15 = y_OklahomaCity[15:16]
X_train_OklahomaCity16 = X_OklahomaCity[16:17]
y_train_OklahomaCity16 = y_OklahomaCity[16:17]
X_train_OklahomaCity17 = X_OklahomaCity[17:18]
y_train_OklahomaCity17 = y_OklahomaCity[17:18]
X_train_OklahomaCity18 = X_OklahomaCity[18:19]
y_train_OklahomaCity18 = y_OklahomaCity[18:19]
X_train_OklahomaCity19 = X_OklahomaCity[19:20]
y_train_OklahomaCity19 = y_OklahomaCity[19:20]
X_train_OklahomaCity20 = X_OklahomaCity[20:21]
y_train_OklahomaCity20 = y_OklahomaCity[20:21]
X_train_OklahomaCity21 = X_OklahomaCity[21:22]
y_train_OklahomaCity21 = y_OklahomaCity[21:22]
X_train_OklahomaCity22 = X_OklahomaCity[22:23]
y_train_OklahomaCity22 = y_OklahomaCity[22:23]

X_train_OklahomaCityAll1 = df.iloc[[0,22,44,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],[5,11,18,19,20]]
y_train_OklahomaCityAll1 = df.iloc[[0,22,44,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],24:25]

X_train_OklahomaCityAll2 = df.iloc[[0,1,23 ,45 ,89,111, 133,155,177,199,221 ,243 ,265 ,287 ,309 ,331 ,353 ,375 ,397 ,419 ,441 ,463 ,485 ,507 ,529 ,551 ,573 ,595 ,617 ,639],[5,11,18,19,20]]
y_train_OklahomaCityAll2 = df.iloc[[1, 23 ,45,89,111, 133,155,177,199,221 ,243 ,265 ,287 ,309 ,331 ,353 ,375 ,397 ,419 ,441 ,463 ,485 ,507 ,529 ,551 ,573 ,595 ,617 ,639],24:25]

X_train_OklahomaCityAll3 = df.iloc[[0,2,24,46,90,112 ,134 ,156 ,178 ,200 ,222 ,244 ,266 ,288 ,310 ,332 ,354 ,376 ,398 ,420 ,442 ,464 ,486 ,508 ,530 ,552 ,574 ,596 ,618 ,640],[5,11,18,19,20]]
y_train_OklahomaCityAll3 = df.iloc[[2,24,46,90,112 ,134 ,156 ,178 ,200 ,222 ,244 ,266 ,288 ,310 ,332 ,354 ,376 ,398 ,420 ,442 ,464 ,486 ,508 ,530 ,552 ,574 ,596 ,618 ,640],24:25]

X_train_OklahomaCityAll4 = df.iloc[[0,3,25,47,91,113 ,135 ,157 ,179 ,201 ,223 ,245 ,267 ,289 ,311 ,333 ,355 ,377 ,399 ,421 ,443 ,465 ,487 ,509 ,531 ,553 ,575 ,597 ,619 ,641],[5,11,18,19,20]]
y_train_OklahomaCityAll4 = df.iloc[[3,25,47,91,113 ,135 ,157 ,179 ,201 ,223 ,245 ,267 ,289 ,311 ,333 ,355 ,377 ,399 ,421 ,443 ,465 ,487 ,509 ,531 ,553 ,575 ,597 ,619 ,641],24:25]

X_train_OklahomaCityAll5 = df.iloc[[0,4,26,48,92,114 ,136 ,158 ,180 ,202 ,224 ,246 ,268 ,290 ,312 ,334 ,356 ,378 ,400 ,422 ,444 ,466 ,488 ,510 ,532 ,554 ,576 ,598 ,620 ,642],[5,11,18,19,20]]
y_train_OklahomaCityAll5 = df.iloc[[4,26,48,92,114 ,136 ,158 ,180 ,202 ,224 ,246 ,268 ,290 ,312 ,334 ,356 ,378 ,400 ,422 ,444 ,466 ,488 ,510 ,532 ,554 ,576 ,598 ,620 ,642],24:25]

X_train_OklahomaCityAll6 = df.iloc[[0,5,27,49,93,115 ,137 ,159 ,181 ,203 ,225 ,247 ,269 ,291 ,313 ,335 ,357 ,379 ,401 ,423 ,445 ,467 ,489 ,511 ,533 ,555 ,577 ,599 ,621 ,643],[5,11,18,19,20]]
y_train_OklahomaCityAll6 = df.iloc[[5,27,49,93,115 ,137 ,159 ,181 ,203 ,225 ,247 ,269 ,291 ,313 ,335 ,357 ,379 ,401 ,423 ,445 ,467 ,489 ,511 ,533 ,555 ,577 ,599 ,621 ,643],24:25]

X_train_OklahomaCityAll7 = df.iloc[[0,6,28,50,94,116 ,138 ,160 ,182 ,204 ,226 ,248 ,270 ,292 ,314 ,336 ,358 ,380 ,402 ,424 ,446 ,468 ,490 ,512 ,534 ,556 ,578 ,600 ,622 ,644],[5,11,18,19,20]]
y_train_OklahomaCityAll7 = df.iloc[[6,28,50,94,116 ,138 ,160 ,182 ,204 ,226 ,248 ,270 ,292 ,314 ,336 ,358 ,380 ,402 ,424 ,446 ,468 ,490 ,512 ,534 ,556 ,578 ,600 ,622 ,644],24:25]

X_train_OklahomaCityAll8 = df.iloc[[0,7,29,51,95,117 ,139 ,161 ,183 ,205 ,227 ,249 ,271 ,293 ,315 ,337 ,359 ,381 ,403 ,425 ,447 ,469 ,491 ,513 ,535 ,557 ,579 ,601 ,623 ,645],[5,11,18,19,20]]
y_train_OklahomaCityAll8 = df.iloc[[7,29,51,95,117 ,139 ,161 ,183 ,205 ,227 ,249 ,271 ,293 ,315 ,337 ,359 ,381 ,403 ,425 ,447 ,469 ,491 ,513 ,535 ,557 ,579 ,601 ,623 ,645],24:25]

X_train_OklahomaCityAll9 = df.iloc[[0,8,30,52,96,118 ,140 ,162 ,184 ,206 ,228 ,250 ,272 ,294 ,316 ,338 ,360 ,382 ,404 ,426 ,448 ,470 ,492 ,514 ,536 ,558 ,580 ,602 ,624 ,646],[5,11,18,19,20]]
y_train_OklahomaCityAll9 = df.iloc[[8,30,52,96,118 ,140 ,162 ,184 ,206 ,228 ,250 ,272 ,294 ,316 ,338 ,360 ,382 ,404 ,426 ,448 ,470 ,492 ,514 ,536 ,558 ,580 ,602 ,624 ,646],24:25]

X_train_OklahomaCityAll10 = df.iloc[[0,9,31,53,97,119 ,141 ,163 ,185 ,207 ,229 ,251 ,273 ,295 ,317 ,339 ,361 ,383 ,405 ,427 ,449 ,471 ,493 ,515 ,537 ,559 ,581 ,603 ,625 ,647],[5,11,18,19,20]]
y_train_OklahomaCityAll10 = df.iloc[[9,31,53,97,119 ,141 ,163 ,185 ,207 ,229 ,251 ,273 ,295 ,317 ,339 ,361 ,383 ,405 ,427 ,449 ,471 ,493 ,515 ,537 ,559 ,581 ,603 ,625 ,647],24:25]

X_train_OklahomaCityAll11 = df.iloc[[0,10,32,54,98,120 ,142 ,164 ,186 ,208 ,230 ,252 ,274 ,296 ,318 ,340 ,362 ,384 ,406 ,428 ,450 ,472 ,494 ,516 ,538 ,560 ,582 ,604 ,626 ,648],[5,11,18,19,20]]
y_train_OklahomaCityAll11= df.iloc[[10,32,54,98,120 ,142 ,164 ,186 ,208 ,230 ,252 ,274 ,296 ,318 ,340 ,362 ,384 ,406 ,428 ,450 ,472 ,494 ,516 ,538 ,560 ,582 ,604 ,626 ,648],24:25]

X_train_OklahomaCityAll12 = df.iloc[[0,11,33,55,99,121 ,143 ,165 ,187 ,209 ,231 ,253 ,275 ,297 ,319 ,341 ,363 ,385 ,407 ,429 ,451 ,473 ,495 ,517 ,539 ,561 ,583 ,605 ,627 ,649],[5,11,18,19,20]]
y_train_OklahomaCityAll12 = df.iloc[[11,33,55,99,121 ,143 ,165 ,187 ,209 ,231 ,253 ,275 ,297 ,319 ,341 ,363 ,385 ,407 ,429 ,451 ,473 ,495 ,517 ,539 ,561 ,583 ,605 ,627 ,649],24:25]

X_train_OklahomaCityAll13 = df.iloc[[0,12,34,56,100, 122, 144, 166, 188, 210, 232, 254, 276, 298, 320, 342, 364, 386, 408, 430, 452, 474, 496, 518, 540, 562, 584, 606, 628, 650],[5,11,18,19,20]]
y_train_OklahomaCityAll13 = df.iloc[[12,34,56,100, 122, 144, 166, 188, 210, 232, 254, 276, 298, 320, 342, 364, 386, 408, 430, 452, 474, 496, 518, 540, 562, 584, 606, 628, 650],24:25]

X_train_OklahomaCityAll14 = df.iloc[[0,13,35,57,101, 123, 145, 167, 189, 211, 233, 255, 277, 299, 321, 343, 365, 387, 409, 431, 453, 475, 497, 519, 541, 563, 585, 607, 629, 651],[5,11,18,19,20]]
y_train_OklahomaCityAll14 = df.iloc[[13,35,57,101, 123, 145, 167, 189, 211, 233, 255, 277, 299, 321, 343, 365, 387, 409, 431, 453, 475, 497, 519, 541, 563, 585, 607, 629, 651],24:25]

X_train_OklahomaCityAll15 = df.iloc[[0,14,36,58,102, 124, 146, 168, 190, 212, 234, 256, 278, 300, 322, 344, 366, 388, 410, 432, 454, 476, 498, 520, 542, 564, 586, 608, 630, 652],[5,11,18,19,20]]
y_train_OklahomaCityAll15 = df.iloc[[14,36,58,102, 124, 146, 168, 190, 212, 234, 256, 278, 300, 322, 344, 366, 388, 410, 432, 454, 476, 498, 520, 542, 564, 586, 608, 630, 652],24:25]

X_train_OklahomaCityAll16 = df.iloc[[0,15,37,59,103, 125, 147, 169, 191, 213, 235, 257, 279, 301, 323, 345, 367, 389, 411, 433, 455, 477, 499, 521, 543, 565, 587, 609, 631, 653],[5,11,18,19,20]]
y_train_OklahomaCityAll16 = df.iloc[[15,37,59,103, 125, 147, 169, 191, 213, 235, 257, 279, 301, 323, 345, 367, 389, 411, 433, 455, 477, 499, 521, 543, 565, 587, 609, 631, 653],24:25]

X_train_OklahomaCityAll17 = df.iloc[[0,16,38,60,104, 126, 148, 170, 192, 214, 236, 258, 280, 302, 324, 346, 368, 390, 412, 434, 456, 478, 500, 522, 544, 566, 588, 610, 632, 654],[5,11,18,19,20]]
y_train_OklahomaCityAll17 = df.iloc[[16,38,60,104, 126, 148, 170, 192, 214, 236, 258, 280, 302, 324, 346, 368, 390, 412, 434, 456, 478, 500, 522, 544, 566, 588, 610, 632, 654],24:25]

X_train_OklahomaCityAll18 = df.iloc[[0,17,39,61,105, 127, 149, 171, 193, 215, 237, 259, 281, 303, 325, 347, 369, 391, 413, 435, 457, 479, 501, 523, 545, 567, 589, 611, 633, 655],[5,11,18,19,20]]
y_train_OklahomaCityAll18 = df.iloc[[17,39,61,105, 127, 149, 171, 193, 215, 237, 259, 281, 303, 325, 347, 369, 391, 413, 435, 457, 479, 501, 523, 545, 567, 589, 611, 633, 655],24:25]

X_train_OklahomaCityAll19 = df.iloc[[0,18,40,62,106, 128, 150, 172, 194, 216, 238, 260, 282, 304, 326, 348, 370, 392, 414, 436, 458, 480, 502, 524, 546, 568, 590, 612, 634, 656],[5,11,18,19,20]]
y_train_OklahomaCityAll19 = df.iloc[[18,40,62,106, 128, 150, 172, 194, 216, 238, 260, 282, 304, 326, 348, 370, 392, 414, 436, 458, 480, 502, 524, 546, 568, 590, 612, 634, 656],24:25]

X_train_OklahomaCityAll20 = df.iloc[[0,19,41,63,107, 129, 151, 173, 195, 217, 239, 261, 283, 305, 327, 349, 371, 393, 415, 437, 459, 481, 503, 525, 547, 569, 591, 613, 635, 657],[5,11,18,19,20]]
y_train_OklahomaCityAll20 = df.iloc[[19,41,63,107, 129, 151, 173, 195, 217, 239, 261, 283, 305, 327, 349, 371, 393, 415, 437, 459, 481, 503, 525, 547, 569, 591, 613, 635, 657],24:25]

X_train_OklahomaCityAll21 = df.iloc[[0,20,42,64,108, 130, 152, 174, 196, 218, 240, 262, 284, 306, 328, 350, 372, 394, 416, 438, 460, 482, 504, 526, 548, 570, 592, 614, 636, 658],[5,11,18,19,20]]
y_train_OklahomaCityAll21 = df.iloc[[20,42,64,108, 130, 152, 174, 196, 218, 240, 262, 284, 306, 328, 350, 372, 394, 416, 438, 460, 482, 504, 526, 548, 570, 592, 614, 636, 658],24:25]

X_train_OklahomaCityAll22 = df.iloc[[0,21,43,65,109, 131, 153, 175, 197, 219, 241, 263, 285, 307, 329, 351, 373, 395, 417, 439, 461, 483, 505, 527, 549, 571, 593, 615, 637, 659],[5,11,18,19,20]]
y_train_OklahomaCityAll22 = df.iloc[[21,43,65,109, 131, 153, 175, 197, 219, 241, 263, 285, 307, 329, 351, 373, 395, 417, 439, 461, 483, 505, 527, 549, 571, 593, 615, 637, 659],24:25]

regressorOklahomaCity1 = LinearRegression()
regressorOklahomaCity1.fit(X_train_OklahomaCityAll1, y_train_OklahomaCityAll1)
pd.DataFrame(list(zip(X_train_OklahomaCityAll1, regressorOklahomaCity1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_OklahomaCity1 = regressorOklahomaCity1.predict(X_train_OklahomaCity1)

# %%
y_train_OklahomaCityAll2.loc[-1] = y_pred_OklahomaCity1.item(0)  # adding a row
y_train_OklahomaCityAll2.index = y_train_OklahomaCityAll2.index + 1  # shifting index
y_train_OklahomaCityAll2 = y_train_OklahomaCityAll2.sort_index()
regressorOklahomaCity2 = LinearRegression()
regressorOklahomaCity2.fit(X_train_OklahomaCityAll2, y_train_OklahomaCityAll2)

pd.DataFrame(list(zip(X_train_OklahomaCityAll2, regressorOklahomaCity2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_OklahomaCity2 = regressorOklahomaCity2.predict(X_train_OklahomaCity2)

# %%
y_train_OklahomaCityAll3.loc[-1] = y_pred_OklahomaCity2.item(0)  # adding a row
y_train_OklahomaCityAll3.index = y_train_OklahomaCityAll3.index + 1  # shifting index
y_train_OklahomaCityAll3 = y_train_OklahomaCityAll3.sort_index()
regressorOklahomaCity3 = LinearRegression()
regressorOklahomaCity3.fit(X_train_OklahomaCityAll3, y_train_OklahomaCityAll3)

pd.DataFrame(list(zip(X_train_OklahomaCityAll3, regressorOklahomaCity3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_OklahomaCity3 = regressorOklahomaCity3.predict(X_train_OklahomaCity3)

# %%
y_train_OklahomaCityAll4.loc[-1] = y_pred_OklahomaCity3.item(0)  # adding a row
y_train_OklahomaCityAll4.index = y_train_OklahomaCityAll4.index + 1  # shifting index
y_train_OklahomaCityAll4 = y_train_OklahomaCityAll4.sort_index()
regressorOklahomaCity4 = LinearRegression()
regressorOklahomaCity4.fit(X_train_OklahomaCityAll4, y_train_OklahomaCityAll4)

pd.DataFrame(list(zip(X_train_OklahomaCityAll4, regressorOklahomaCity4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_OklahomaCity4 = regressorOklahomaCity4.predict(X_train_OklahomaCity4)

# %%
y_train_OklahomaCityAll5.loc[-1] = y_pred_OklahomaCity4.item(0)  # adding a row
y_train_OklahomaCityAll5.index = y_train_OklahomaCityAll5.index + 1  # shifting index
y_train_OklahomaCityAll5 = y_train_OklahomaCityAll5.sort_index()
regressorOklahomaCity5 = LinearRegression()
regressorOklahomaCity5.fit(X_train_OklahomaCityAll5, y_train_OklahomaCityAll5)

pd.DataFrame(list(zip(X_train_OklahomaCityAll5, regressorOklahomaCity5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_OklahomaCity5 = regressorOklahomaCity5.predict(X_train_OklahomaCity5)

# %%
y_train_OklahomaCityAll6.loc[-1] = y_pred_OklahomaCity5.item(0)  # adding a row
y_train_OklahomaCityAll6.index = y_train_OklahomaCityAll6.index + 1  # shifting index
y_train_OklahomaCityAll6 = y_train_OklahomaCityAll6.sort_index()
regressorOklahomaCity6 = LinearRegression()
regressorOklahomaCity6.fit(X_train_OklahomaCityAll6, y_train_OklahomaCityAll6)

pd.DataFrame(list(zip(X_train_OklahomaCityAll6, regressorOklahomaCity6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_OklahomaCity6 = regressorOklahomaCity6.predict(X_train_OklahomaCity6)

# %%
y_train_OklahomaCityAll7.loc[-1] = y_pred_OklahomaCity6.item(0)  # adding a row
y_train_OklahomaCityAll7.index = y_train_OklahomaCityAll7.index + 1  # shifting index
y_train_OklahomaCityAll7 = y_train_OklahomaCityAll7.sort_index()
regressorOklahomaCity7 = LinearRegression()
regressorOklahomaCity7.fit(X_train_OklahomaCityAll7, y_train_OklahomaCityAll7)

pd.DataFrame(list(zip(X_train_OklahomaCityAll7, regressorOklahomaCity7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_OklahomaCity7 = regressorOklahomaCity7.predict(X_train_OklahomaCity7)

# %%
y_train_OklahomaCityAll8.loc[-1] = y_pred_OklahomaCity7.item(0)  # adding a row
y_train_OklahomaCityAll8.index = y_train_OklahomaCityAll8.index + 1  # shifting index
y_train_OklahomaCityAll8 = y_train_OklahomaCityAll8.sort_index()
regressorOklahomaCity8 = LinearRegression()
regressorOklahomaCity8.fit(X_train_OklahomaCityAll8, y_train_OklahomaCityAll8)

pd.DataFrame(list(zip(X_train_OklahomaCityAll8, regressorOklahomaCity8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_OklahomaCity8 = regressorOklahomaCity8.predict(X_train_OklahomaCity8)

# %%
y_train_OklahomaCityAll9.loc[-1] = y_pred_OklahomaCity8.item(0)  # adding a row
y_train_OklahomaCityAll9.index = y_train_OklahomaCityAll9.index + 1  # shifting index
y_train_OklahomaCityAll9 = y_train_OklahomaCityAll9.sort_index()
regressorOklahomaCity9 = LinearRegression()
regressorOklahomaCity9.fit(X_train_OklahomaCityAll9, y_train_OklahomaCityAll9)

pd.DataFrame(list(zip(X_train_OklahomaCityAll9, regressorOklahomaCity9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_OklahomaCity9 = regressorOklahomaCity9.predict(X_train_OklahomaCity9)

# %%
y_train_OklahomaCityAll10.loc[-1] = y_pred_OklahomaCity9.item(0)  # adding a row
y_train_OklahomaCityAll10.index = y_train_OklahomaCityAll10.index + 1  # shifting index
y_train_OklahomaCityAll10 = y_train_OklahomaCityAll10.sort_index()
regressorOklahomaCity10 = LinearRegression()
regressorOklahomaCity10.fit(X_train_OklahomaCityAll10, y_train_OklahomaCityAll10)

pd.DataFrame(list(zip(X_train_OklahomaCityAll10, regressorOklahomaCity10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_OklahomaCity10 = regressorOklahomaCity10.predict(X_train_OklahomaCity10)

# %%
y_train_OklahomaCityAll11.loc[-1] = y_pred_OklahomaCity10.item(0)  # adding a row
y_train_OklahomaCityAll11.index = y_train_OklahomaCityAll11.index + 1  # shifting index
y_train_OklahomaCityAll11 = y_train_OklahomaCityAll11.sort_index()
regressorOklahomaCity11 = LinearRegression()
regressorOklahomaCity11.fit(X_train_OklahomaCityAll11, y_train_OklahomaCityAll11)

pd.DataFrame(list(zip(X_train_OklahomaCityAll11, regressorOklahomaCity11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_OklahomaCity11 = regressorOklahomaCity11.predict(X_train_OklahomaCity11)

# %%
y_train_OklahomaCityAll12.loc[-1] = y_pred_OklahomaCity11.item(0)  # adding a row
y_train_OklahomaCityAll12.index = y_train_OklahomaCityAll12.index + 1  # shifting index
y_train_OklahomaCityAll12 = y_train_OklahomaCityAll12.sort_index()
regressorOklahomaCity12 = LinearRegression()
regressorOklahomaCity12.fit(X_train_OklahomaCityAll12, y_train_OklahomaCityAll12)

pd.DataFrame(list(zip(X_train_OklahomaCityAll12, regressorOklahomaCity12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_OklahomaCity12 = regressorOklahomaCity12.predict(X_train_OklahomaCity12)

# %%
y_train_OklahomaCityAll13.loc[-1] = y_pred_OklahomaCity12.item(0)  # adding a row
y_train_OklahomaCityAll13.index = y_train_OklahomaCityAll13.index + 1  # shifting index
y_train_OklahomaCityAll13 = y_train_OklahomaCityAll13.sort_index()
regressorOklahomaCity13 = LinearRegression()
regressorOklahomaCity13.fit(X_train_OklahomaCityAll13, y_train_OklahomaCityAll13)

pd.DataFrame(list(zip(X_train_OklahomaCityAll13, regressorOklahomaCity13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_OklahomaCity13 = regressorOklahomaCity13.predict(X_train_OklahomaCity13)

# %%
y_train_OklahomaCityAll14.loc[-1] = y_pred_OklahomaCity13.item(0)  # adding a row
y_train_OklahomaCityAll14.index = y_train_OklahomaCityAll14.index + 1  # shifting index
y_train_OklahomaCityAll14 = y_train_OklahomaCityAll14.sort_index()
regressorOklahomaCity14 = LinearRegression()
regressorOklahomaCity14.fit(X_train_OklahomaCityAll14, y_train_OklahomaCityAll14)

pd.DataFrame(list(zip(X_train_OklahomaCityAll14, regressorOklahomaCity14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_OklahomaCity14 = regressorOklahomaCity14.predict(X_train_OklahomaCity14)

# %%
y_train_OklahomaCityAll15.loc[-1] = y_pred_OklahomaCity14.item(0)  # adding a row
y_train_OklahomaCityAll15.index = y_train_OklahomaCityAll15.index + 1  # shifting index
y_train_OklahomaCityAll15 = y_train_OklahomaCityAll15.sort_index()
regressorOklahomaCity15 = LinearRegression()
regressorOklahomaCity15.fit(X_train_OklahomaCityAll15, y_train_OklahomaCityAll15)

pd.DataFrame(list(zip(X_train_OklahomaCityAll15, regressorOklahomaCity15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_OklahomaCity15 = regressorOklahomaCity15.predict(X_train_OklahomaCity15)

# %%
y_train_OklahomaCityAll16.loc[-1] = y_pred_OklahomaCity15.item(0)  # adding a row
y_train_OklahomaCityAll16.index = y_train_OklahomaCityAll16.index + 1  # shifting index
y_train_OklahomaCityAll16 = y_train_OklahomaCityAll16.sort_index()
regressorOklahomaCity16 = LinearRegression()
regressorOklahomaCity16.fit(X_train_OklahomaCityAll16, y_train_OklahomaCityAll16)

pd.DataFrame(list(zip(X_train_OklahomaCityAll16, regressorOklahomaCity16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_OklahomaCity16 = regressorOklahomaCity16.predict(X_train_OklahomaCity16)

# %%
y_train_OklahomaCityAll17.loc[-1] = y_pred_OklahomaCity16.item(0)  # adding a row
y_train_OklahomaCityAll17.index = y_train_OklahomaCityAll17.index + 1  # shifting index
y_train_OklahomaCityAll17 = y_train_OklahomaCityAll17.sort_index()
regressorOklahomaCity17 = LinearRegression()
regressorOklahomaCity17.fit(X_train_OklahomaCityAll17, y_train_OklahomaCityAll17)

pd.DataFrame(list(zip(X_train_OklahomaCityAll17, regressorOklahomaCity17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_OklahomaCity17 = regressorOklahomaCity17.predict(X_train_OklahomaCity17)

# %%
y_train_OklahomaCityAll18.loc[-1] = y_pred_OklahomaCity17.item(0)  # adding a row
y_train_OklahomaCityAll18.index = y_train_OklahomaCityAll18.index + 1  # shifting index
y_train_OklahomaCityAll18 = y_train_OklahomaCityAll18.sort_index()
regressorOklahomaCity18 = LinearRegression()
regressorOklahomaCity18.fit(X_train_OklahomaCityAll18, y_train_OklahomaCityAll18)

pd.DataFrame(list(zip(X_train_OklahomaCityAll18, regressorOklahomaCity18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_OklahomaCity18 = regressorOklahomaCity18.predict(X_train_OklahomaCity18)

# %%
y_train_OklahomaCityAll19.loc[-1] = y_pred_OklahomaCity18.item(0)  # adding a row
y_train_OklahomaCityAll19.index = y_train_OklahomaCityAll19.index + 1  # shifting index
y_train_OklahomaCityAll19 = y_train_OklahomaCityAll19.sort_index()
regressorOklahomaCity19 = LinearRegression()
regressorOklahomaCity19.fit(X_train_OklahomaCityAll19, y_train_OklahomaCityAll19)

pd.DataFrame(list(zip(X_train_OklahomaCityAll19, regressorOklahomaCity19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_OklahomaCity19 = regressorOklahomaCity19.predict(X_train_OklahomaCity19)

# %%
y_train_OklahomaCityAll20.loc[-1] = y_pred_OklahomaCity19.item(0)  # adding a row
y_train_OklahomaCityAll20.index = y_train_OklahomaCityAll20.index + 1  # shifting index
y_train_OklahomaCityAll20 = y_train_OklahomaCityAll20.sort_index()
regressorOklahomaCity20 = LinearRegression()
regressorOklahomaCity20.fit(X_train_OklahomaCityAll20, y_train_OklahomaCityAll20)

pd.DataFrame(list(zip(X_train_OklahomaCityAll20, regressorOklahomaCity20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_OklahomaCity20 = regressorOklahomaCity20.predict(X_train_OklahomaCity20)

# %%
y_train_OklahomaCityAll21.loc[-1] = y_pred_OklahomaCity20.item(0)  # adding a row
y_train_OklahomaCityAll21.index = y_train_OklahomaCityAll21.index + 1  # shifting index
y_train_OklahomaCityAll21 = y_train_OklahomaCityAll21.sort_index()
regressorOklahomaCity21 = LinearRegression()
regressorOklahomaCity21.fit(X_train_OklahomaCityAll21, y_train_OklahomaCityAll21)

pd.DataFrame(list(zip(X_train_OklahomaCityAll21, regressorOklahomaCity21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_OklahomaCity21 = regressorOklahomaCity21.predict(X_train_OklahomaCity21)

# %%
#Utah
X_train_Utah1= X_Utah[0:1]
y_train_Utah1= y_Utah[0:1]
X_train_Utah2= X_Utah[1:2]
y_train_Utah2= y_Utah[1:2]
X_train_Utah3= X_Utah[2:3]
y_train_Utah3= y_Utah[2:3]
X_train_Utah4= X_Utah[3:4]
y_train_Utah4= y_Utah[3:4]
X_train_Utah5= X_Utah[4:5]
y_train_Utah5= y_Utah[4:5]
y_train_Utah6= y_Utah[5:6]
X_train_Utah7= X_Utah[7:8]
X_train_Utah6= X_Utah[5:6]
y_train_Utah7= y_Utah[7:8]
X_train_Utah8= X_Utah[8:9]
y_train_Utah8= y_Utah[8:9]
X_train_Utah9= X_Utah[9:10]
y_train_Utah9= y_Utah[9:10]
X_train_Utah10 = X_Utah[10:11]
y_train_Utah10 = y_Utah[10:11]
X_train_Utah11 = X_Utah[11:12]
y_train_Utah11 = y_Utah[11:12]
X_train_Utah12 = X_Utah[12:13]
y_train_Utah12 = y_Utah[12:13]
X_train_Utah13 = X_Utah[13:14]
y_train_Utah13 = y_Utah[13:14]
X_train_Utah14 = X_Utah[14:15]
y_train_Utah14 = y_Utah[14:15]
X_train_Utah15 = X_Utah[15:16]
y_train_Utah15 = y_Utah[15:16]
X_train_Utah16 = X_Utah[16:17]
y_train_Utah16 = y_Utah[16:17]
X_train_Utah17 = X_Utah[17:18]
y_train_Utah17 = y_Utah[17:18]
X_train_Utah18 = X_Utah[18:19]
y_train_Utah18 = y_Utah[18:19]
X_train_Utah19 = X_Utah[19:20]
y_train_Utah19 = y_Utah[19:20]
X_train_Utah20 = X_Utah[20:21]
y_train_Utah20 = y_Utah[20:21]
X_train_Utah21 = X_Utah[21:22]
y_train_Utah21 = y_Utah[21:22]
X_train_Utah22 = X_Utah[22:23]
y_train_Utah22 = y_Utah[22:23]

X_train_UtahAll1 = df.iloc[[0,22,44,66,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],[5,11,18,19,20]]
y_train_UtahAll1 = df.iloc[[0,22,44,66,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],24:25]

X_train_UtahAll2 = df.iloc[[0,1,23 ,45 ,67,111, 133,155,177,199,221 ,243 ,265 ,287 ,309 ,331 ,353 ,375 ,397 ,419 ,441 ,463 ,485 ,507 ,529 ,551 ,573 ,595 ,617 ,639],[5,11,18,19,20]]
y_train_UtahAll2 = df.iloc[[1, 23 ,45,67,111, 133,155,177,199,221 ,243 ,265 ,287 ,309 ,331 ,353 ,375 ,397 ,419 ,441 ,463 ,485 ,507 ,529 ,551 ,573 ,595 ,617 ,639],24:25]

X_train_UtahAll3 = df.iloc[[0,2,24,46,68,112 ,134 ,156 ,178 ,200 ,222 ,244 ,266 ,288 ,310 ,332 ,354 ,376 ,398 ,420 ,442 ,464 ,486 ,508 ,530 ,552 ,574 ,596 ,618 ,640],[5,11,18,19,20]]
y_train_UtahAll3 = df.iloc[[2,24,46,68,112 ,134 ,156 ,178 ,200 ,222 ,244 ,266 ,288 ,310 ,332 ,354 ,376 ,398 ,420 ,442 ,464 ,486 ,508 ,530 ,552 ,574 ,596 ,618 ,640],24:25]

X_train_UtahAll4 = df.iloc[[0,3,25,47,69,113 ,135 ,157 ,179 ,201 ,223 ,245 ,267 ,289 ,311 ,333 ,355 ,377 ,399 ,421 ,443 ,465 ,487 ,509 ,531 ,553 ,575 ,597 ,619 ,641],[5,11,18,19,20]]
y_train_UtahAll4 = df.iloc[[3,25,47,69,113 ,135 ,157 ,179 ,201 ,223 ,245 ,267 ,289 ,311 ,333 ,355 ,377 ,399 ,421 ,443 ,465 ,487 ,509 ,531 ,553 ,575 ,597 ,619 ,641],24:25]

X_train_UtahAll5 = df.iloc[[0,4,26,48,70,114 ,136 ,158 ,180 ,202 ,224 ,246 ,268 ,290 ,312 ,334 ,356 ,378 ,400 ,422 ,444 ,466 ,488 ,510 ,532 ,554 ,576 ,598 ,620 ,642],[5,11,18,19,20]]
y_train_UtahAll5 = df.iloc[[4,26,48,70,114 ,136 ,158 ,180 ,202 ,224 ,246 ,268 ,290 ,312 ,334 ,356 ,378 ,400 ,422 ,444 ,466 ,488 ,510 ,532 ,554 ,576 ,598 ,620 ,642],24:25]

X_train_UtahAll6 = df.iloc[[0,5,27,49,71,115 ,137 ,159 ,181 ,203 ,225 ,247 ,269 ,291 ,313 ,335 ,357 ,379 ,401 ,423 ,445 ,467 ,489 ,511 ,533 ,555 ,577 ,599 ,621 ,643],[5,11,18,19,20]]
y_train_UtahAll6 = df.iloc[[5,27,49,71,115 ,137 ,159 ,181 ,203 ,225 ,247 ,269 ,291 ,313 ,335 ,357 ,379 ,401 ,423 ,445 ,467 ,489 ,511 ,533 ,555 ,577 ,599 ,621 ,643],24:25]

X_train_UtahAll7 = df.iloc[[0,6,28,50,72,116 ,138 ,160 ,182 ,204 ,226 ,248 ,270 ,292 ,314 ,336 ,358 ,380 ,402 ,424 ,446 ,468 ,490 ,512 ,534 ,556 ,578 ,600 ,622 ,644],[5,11,18,19,20]]
y_train_UtahAll7 = df.iloc[[6,28,50,72,116 ,138 ,160 ,182 ,204 ,226 ,248 ,270 ,292 ,314 ,336 ,358 ,380 ,402 ,424 ,446 ,468 ,490 ,512 ,534 ,556 ,578 ,600 ,622 ,644],24:25]

X_train_UtahAll8 = df.iloc[[0,7,29,51,73,117 ,139 ,161 ,183 ,205 ,227 ,249 ,271 ,293 ,315 ,337 ,359 ,381 ,403 ,425 ,447 ,469 ,491 ,513 ,535 ,557 ,579 ,601 ,623 ,645],[5,11,18,19,20]]
y_train_UtahAll8 = df.iloc[[7,29,51,73,117 ,139 ,161 ,183 ,205 ,227 ,249 ,271 ,293 ,315 ,337 ,359 ,381 ,403 ,425 ,447 ,469 ,491 ,513 ,535 ,557 ,579 ,601 ,623 ,645],24:25]

X_train_UtahAll9 = df.iloc[[0,8,30,52,74,118 ,140 ,162 ,184 ,206 ,228 ,250 ,272 ,294 ,316 ,338 ,360 ,382 ,404 ,426 ,448 ,470 ,492 ,514 ,536 ,558 ,580 ,602 ,624 ,646],[5,11,18,19,20]]
y_train_UtahAll9 = df.iloc[[8,30,52,74,118 ,140 ,162 ,184 ,206 ,228 ,250 ,272 ,294 ,316 ,338 ,360 ,382 ,404 ,426 ,448 ,470 ,492 ,514 ,536 ,558 ,580 ,602 ,624 ,646],24:25]

X_train_UtahAll10 = df.iloc[[0,9,31,53,75,119 ,141 ,163 ,185 ,207 ,229 ,251 ,273 ,295 ,317 ,339 ,361 ,383 ,405 ,427 ,449 ,471 ,493 ,515 ,537 ,559 ,581 ,603 ,625 ,647],[5,11,18,19,20]]
y_train_UtahAll10 = df.iloc[[9,31,53,75,119 ,141 ,163 ,185 ,207 ,229 ,251 ,273 ,295 ,317 ,339 ,361 ,383 ,405 ,427 ,449 ,471 ,493 ,515 ,537 ,559 ,581 ,603 ,625 ,647],24:25]

X_train_UtahAll11 = df.iloc[[0,10,32,54,76,120 ,142 ,164 ,186 ,208 ,230 ,252 ,274 ,296 ,318 ,340 ,362 ,384 ,406 ,428 ,450 ,472 ,494 ,516 ,538 ,560 ,582 ,604 ,626 ,648],[5,11,18,19,20]]
y_train_UtahAll11= df.iloc[[10,32,54,76,120 ,142 ,164 ,186 ,208 ,230 ,252 ,274 ,296 ,318 ,340 ,362 ,384 ,406 ,428 ,450 ,472 ,494 ,516 ,538 ,560 ,582 ,604 ,626 ,648],24:25]

X_train_UtahAll12 = df.iloc[[0,11,33,55,77,121 ,143 ,165 ,187 ,209 ,231 ,253 ,275 ,297 ,319 ,341 ,363 ,385 ,407 ,429 ,451 ,473 ,495 ,517 ,539 ,561 ,583 ,605 ,627 ,649],[5,11,18,19,20]]
y_train_UtahAll12 = df.iloc[[11,33,55,77,121 ,143 ,165 ,187 ,209 ,231 ,253 ,275 ,297 ,319 ,341 ,363 ,385 ,407 ,429 ,451 ,473 ,495 ,517 ,539 ,561 ,583 ,605 ,627 ,649],24:25]

X_train_UtahAll13 = df.iloc[[0,12,34,56,78, 122, 144, 166, 188, 210, 232, 254, 276, 298, 320, 342, 364, 386, 408, 430, 452, 474, 496, 518, 540, 562, 584, 606, 628, 650],[5,11,18,19,20]]
y_train_UtahAll13 = df.iloc[[12,34,56,78, 122, 144, 166, 188, 210, 232, 254, 276, 298, 320, 342, 364, 386, 408, 430, 452, 474, 496, 518, 540, 562, 584, 606, 628, 650],24:25]

X_train_UtahAll14 = df.iloc[[0,13,35,57,79, 123, 145, 167, 189, 211, 233, 255, 277, 299, 321, 343, 365, 387, 409, 431, 453, 475, 497, 519, 541, 563, 585, 607, 629, 651],[5,11,18,19,20]]
y_train_UtahAll14 = df.iloc[[13,35,57,79, 123, 145, 167, 189, 211, 233, 255, 277, 299, 321, 343, 365, 387, 409, 431, 453, 475, 497, 519, 541, 563, 585, 607, 629, 651],24:25]

X_train_UtahAll15 = df.iloc[[0,14,36,58,80, 124, 146, 168, 190, 212, 234, 256, 278, 300, 322, 344, 366, 388, 410, 432, 454, 476, 498, 520, 542, 564, 586, 608, 630, 652],[5,11,18,19,20]]
y_train_UtahAll15 = df.iloc[[14,36,58,80, 124, 146, 168, 190, 212, 234, 256, 278, 300, 322, 344, 366, 388, 410, 432, 454, 476, 498, 520, 542, 564, 586, 608, 630, 652],24:25]

X_train_UtahAll16 = df.iloc[[0,15,37,59,81, 125, 147, 169, 191, 213, 235, 257, 279, 301, 323, 345, 367, 389, 411, 433, 455, 477, 499, 521, 543, 565, 587, 609, 631, 653],[5,11,18,19,20]]
y_train_UtahAll16 = df.iloc[[15,37,59,81, 125, 147, 169, 191, 213, 235, 257, 279, 301, 323, 345, 367, 389, 411, 433, 455, 477, 499, 521, 543, 565, 587, 609, 631, 653],24:25]

X_train_UtahAll17 = df.iloc[[0,16,38,60,82, 126, 148, 170, 192, 214, 236, 258, 280, 302, 324, 346, 368, 390, 412, 434, 456, 478, 500, 522, 544, 566, 588, 610, 632, 654],[5,11,18,19,20]]
y_train_UtahAll17 = df.iloc[[16,38,60,82, 126, 148, 170, 192, 214, 236, 258, 280, 302, 324, 346, 368, 390, 412, 434, 456, 478, 500, 522, 544, 566, 588, 610, 632, 654],24:25]

X_train_UtahAll18 = df.iloc[[0,17,39,61,83, 127, 149, 171, 193, 215, 237, 259, 281, 303, 325, 347, 369, 391, 413, 435, 457, 479, 501, 523, 545, 567, 589, 611, 633, 655],[5,11,18,19,20]]
y_train_UtahAll18 = df.iloc[[17,39,61,83, 127, 149, 171, 193, 215, 237, 259, 281, 303, 325, 347, 369, 391, 413, 435, 457, 479, 501, 523, 545, 567, 589, 611, 633, 655],24:25]

X_train_UtahAll19 = df.iloc[[0,18,40,62,84, 128, 150, 172, 194, 216, 238, 260, 282, 304, 326, 348, 370, 392, 414, 436, 458, 480, 502, 524, 546, 568, 590, 612, 634, 656],[5,11,18,19,20]]
y_train_UtahAll19 = df.iloc[[18,40,62,84, 128, 150, 172, 194, 216, 238, 260, 282, 304, 326, 348, 370, 392, 414, 436, 458, 480, 502, 524, 546, 568, 590, 612, 634, 656],24:25]

X_train_UtahAll20 = df.iloc[[0,19,41,63,85, 129, 151, 173, 195, 217, 239, 261, 283, 305, 327, 349, 371, 393, 415, 437, 459, 481, 503, 525, 547, 569, 591, 613, 635, 657],[5,11,18,19,20]]
y_train_UtahAll20 = df.iloc[[19,41,63,85, 129, 151, 173, 195, 217, 239, 261, 283, 305, 327, 349, 371, 393, 415, 437, 459, 481, 503, 525, 547, 569, 591, 613, 635, 657],24:25]

X_train_UtahAll21 = df.iloc[[0,20,42,64,86, 130, 152, 174, 196, 218, 240, 262, 284, 306, 328, 350, 372, 394, 416, 438, 460, 482, 504, 526, 548, 570, 592, 614, 636, 658],[5,11,18,19,20]]
y_train_UtahAll21 = df.iloc[[20,42,64,86, 130, 152, 174, 196, 218, 240, 262, 284, 306, 328, 350, 372, 394, 416, 438, 460, 482, 504, 526, 548, 570, 592, 614, 636, 658],24:25]

X_train_UtahAll22 = df.iloc[[0,21,43,65,87, 131, 153, 175, 197, 219, 241, 263, 285, 307, 329, 351, 373, 395, 417, 439, 461, 483, 505, 527, 549, 571, 593, 615, 637, 659],[5,11,18,19,20]]
y_train_UtahAll22 = df.iloc[[21,43,65,87, 131, 153, 175, 197, 219, 241, 263, 285, 307, 329, 351, 373, 395, 417, 439, 461, 483, 505, 527, 549, 571, 593, 615, 637, 659],24:25]

# %%
regressorUtah1 = LinearRegression()
regressorUtah1.fit(X_train_UtahAll1, y_train_UtahAll1)
pd.DataFrame(list(zip(X_train_UtahAll1, regressorUtah1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_Utah1 = regressorUtah1.predict(X_train_Utah1)

# %%
y_train_UtahAll2.loc[-1] = y_pred_Utah1.item(0)  # adding a row
y_train_UtahAll2.index = y_train_UtahAll2.index + 1  # shifting index
y_train_UtahAll2 = y_train_UtahAll2.sort_index()
regressorUtah2 = LinearRegression()
regressorUtah2.fit(X_train_UtahAll2, y_train_UtahAll2)

pd.DataFrame(list(zip(X_train_UtahAll2, regressorUtah2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Utah2 = regressorUtah2.predict(X_train_Utah2)

# %%
y_train_UtahAll3.loc[-1] = y_pred_Utah2.item(0)  # adding a row
y_train_UtahAll3.index = y_train_UtahAll3.index + 1  # shifting index
y_train_UtahAll3 = y_train_UtahAll3.sort_index()
regressorUtah3 = LinearRegression()
regressorUtah3.fit(X_train_UtahAll3, y_train_UtahAll3)

pd.DataFrame(list(zip(X_train_UtahAll3, regressorUtah3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Utah3 = regressorUtah3.predict(X_train_Utah3)

# %%
y_train_UtahAll4.loc[-1] = y_pred_Utah3.item(0)  # adding a row
y_train_UtahAll4.index = y_train_UtahAll4.index + 1  # shifting index
y_train_UtahAll4 = y_train_UtahAll4.sort_index()
regressorUtah4 = LinearRegression()
regressorUtah4.fit(X_train_UtahAll4, y_train_UtahAll4)

pd.DataFrame(list(zip(X_train_UtahAll4, regressorUtah4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Utah4 = regressorUtah4.predict(X_train_Utah4)

# %%
y_train_UtahAll5.loc[-1] = y_pred_Utah4.item(0)  # adding a row
y_train_UtahAll5.index = y_train_UtahAll5.index + 1  # shifting index
y_train_UtahAll5 = y_train_UtahAll5.sort_index()
regressorUtah5 = LinearRegression()
regressorUtah5.fit(X_train_UtahAll5, y_train_UtahAll5)

pd.DataFrame(list(zip(X_train_UtahAll5, regressorUtah5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Utah5 = regressorUtah5.predict(X_train_Utah5)

# %%
y_train_UtahAll6.loc[-1] = y_pred_Utah5.item(0)  # adding a row
y_train_UtahAll6.index = y_train_UtahAll6.index + 1  # shifting index
y_train_UtahAll6 = y_train_UtahAll6.sort_index()
regressorUtah6 = LinearRegression()
regressorUtah6.fit(X_train_UtahAll6, y_train_UtahAll6)

pd.DataFrame(list(zip(X_train_UtahAll6, regressorUtah6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Utah6 = regressorUtah6.predict(X_train_Utah6)

# %%
y_train_UtahAll7.loc[-1] = y_pred_Utah6.item(0)  # adding a row
y_train_UtahAll7.index = y_train_UtahAll7.index + 1  # shifting index
y_train_UtahAll7 = y_train_UtahAll7.sort_index()
regressorUtah7 = LinearRegression()
regressorUtah7.fit(X_train_UtahAll7, y_train_UtahAll7)

pd.DataFrame(list(zip(X_train_UtahAll7, regressorUtah7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Utah7 = regressorUtah7.predict(X_train_Utah7)

# %%
y_train_UtahAll8.loc[-1] = y_pred_Utah7.item(0)  # adding a row
y_train_UtahAll8.index = y_train_UtahAll8.index + 1  # shifting index
y_train_UtahAll8 = y_train_UtahAll8.sort_index()
regressorUtah8 = LinearRegression()
regressorUtah8.fit(X_train_UtahAll8, y_train_UtahAll8)

pd.DataFrame(list(zip(X_train_UtahAll8, regressorUtah8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Utah8 = regressorUtah8.predict(X_train_Utah8)

# %%
y_train_UtahAll9.loc[-1] = y_pred_Utah8.item(0)  # adding a row
y_train_UtahAll9.index = y_train_UtahAll9.index + 1  # shifting index
y_train_UtahAll9 = y_train_UtahAll9.sort_index()
regressorUtah9 = LinearRegression()
regressorUtah9.fit(X_train_UtahAll9, y_train_UtahAll9)

pd.DataFrame(list(zip(X_train_UtahAll9, regressorUtah9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Utah9 = regressorUtah9.predict(X_train_Utah9)

# %%
y_train_UtahAll10.loc[-1] = y_pred_Utah9.item(0)  # adding a row
y_train_UtahAll10.index = y_train_UtahAll10.index + 1  # shifting index
y_train_UtahAll10 = y_train_UtahAll10.sort_index()
regressorUtah10 = LinearRegression()
regressorUtah10.fit(X_train_UtahAll10, y_train_UtahAll10)

pd.DataFrame(list(zip(X_train_UtahAll10, regressorUtah10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Utah10 = regressorUtah10.predict(X_train_Utah10)

# %%
y_train_UtahAll11.loc[-1] = y_pred_Utah10.item(0)  # adding a row
y_train_UtahAll11.index = y_train_UtahAll11.index + 1  # shifting index
y_train_UtahAll11 = y_train_UtahAll11.sort_index()
regressorUtah11 = LinearRegression()
regressorUtah11.fit(X_train_UtahAll11, y_train_UtahAll11)

pd.DataFrame(list(zip(X_train_UtahAll11, regressorUtah11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Utah11 = regressorUtah11.predict(X_train_Utah11)

# %%
y_train_UtahAll12.loc[-1] = y_pred_Utah11.item(0)  # adding a row
y_train_UtahAll12.index = y_train_UtahAll12.index + 1  # shifting index
y_train_UtahAll12 = y_train_UtahAll12.sort_index()
regressorUtah12 = LinearRegression()
regressorUtah12.fit(X_train_UtahAll12, y_train_UtahAll12)

pd.DataFrame(list(zip(X_train_UtahAll12, regressorUtah12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Utah12 = regressorUtah12.predict(X_train_Utah12)

# %%
y_train_UtahAll13.loc[-1] = y_pred_Utah12.item(0)  # adding a row
y_train_UtahAll13.index = y_train_UtahAll13.index + 1  # shifting index
y_train_UtahAll13 = y_train_UtahAll13.sort_index()
regressorUtah13 = LinearRegression()
regressorUtah13.fit(X_train_UtahAll13, y_train_UtahAll13)

pd.DataFrame(list(zip(X_train_UtahAll13, regressorUtah13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Utah13 = regressorUtah13.predict(X_train_Utah13)

# %%
y_train_UtahAll14.loc[-1] = y_pred_Utah13.item(0)  # adding a row
y_train_UtahAll14.index = y_train_UtahAll14.index + 1  # shifting index
y_train_UtahAll14 = y_train_UtahAll14.sort_index()
regressorUtah14 = LinearRegression()
regressorUtah14.fit(X_train_UtahAll14, y_train_UtahAll14)

pd.DataFrame(list(zip(X_train_UtahAll14, regressorUtah14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Utah14 = regressorUtah14.predict(X_train_Utah14)

# %%
y_train_UtahAll15.loc[-1] = y_pred_Utah14.item(0)  # adding a row
y_train_UtahAll15.index = y_train_UtahAll15.index + 1  # shifting index
y_train_UtahAll15 = y_train_UtahAll15.sort_index()
regressorUtah15 = LinearRegression()
regressorUtah15.fit(X_train_UtahAll15, y_train_UtahAll15)

pd.DataFrame(list(zip(X_train_UtahAll15, regressorUtah15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Utah15 = regressorUtah15.predict(X_train_Utah15)

# %%
y_train_UtahAll16.loc[-1] = y_pred_Utah15.item(0)  # adding a row
y_train_UtahAll16.index = y_train_UtahAll16.index + 1  # shifting index
y_train_UtahAll16 = y_train_UtahAll16.sort_index()
regressorUtah16 = LinearRegression()
regressorUtah16.fit(X_train_UtahAll16, y_train_UtahAll16)

pd.DataFrame(list(zip(X_train_UtahAll16, regressorUtah16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Utah16 = regressorUtah16.predict(X_train_Utah16)

# %%
y_train_UtahAll17.loc[-1] = y_pred_Utah16.item(0)  # adding a row
y_train_UtahAll17.index = y_train_UtahAll17.index + 1  # shifting index
y_train_UtahAll17 = y_train_UtahAll17.sort_index()
regressorUtah17 = LinearRegression()
regressorUtah17.fit(X_train_UtahAll17, y_train_UtahAll17)

pd.DataFrame(list(zip(X_train_UtahAll17, regressorUtah17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Utah17 = regressorUtah17.predict(X_train_Utah17)

# %%
y_train_UtahAll18.loc[-1] = y_pred_Utah1.item(0)  # adding a row
y_train_UtahAll18.index = y_train_UtahAll18.index + 1  # shifting index
y_train_UtahAll18 = y_train_UtahAll18.sort_index()
regressorUtah18 = LinearRegression()
regressorUtah18.fit(X_train_UtahAll18, y_train_UtahAll18)

pd.DataFrame(list(zip(X_train_UtahAll18, regressorUtah18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Utah18 = regressorUtah18.predict(X_train_Utah18)

# %%
y_train_UtahAll19.loc[-1] = y_pred_Utah1.item(0)  # adding a row
y_train_UtahAll19.index = y_train_UtahAll19.index + 1  # shifting index
y_train_UtahAll19 = y_train_UtahAll19.sort_index()
regressorUtah19 = LinearRegression()
regressorUtah19.fit(X_train_UtahAll19, y_train_UtahAll19)

pd.DataFrame(list(zip(X_train_UtahAll19, regressorUtah19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Utah19 = regressorUtah19.predict(X_train_Utah19)

# %%
y_train_UtahAll20.loc[-1] = y_pred_Utah1.item(0)  # adding a row
y_train_UtahAll20.index = y_train_UtahAll20.index + 1  # shifting index
y_train_UtahAll20 = y_train_UtahAll20.sort_index()
regressorUtah20 = LinearRegression()
regressorUtah20.fit(X_train_UtahAll20, y_train_UtahAll20)

pd.DataFrame(list(zip(X_train_UtahAll20, regressorUtah20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Utah20 = regressorUtah20.predict(X_train_Utah20)

# %%
y_train_UtahAll21.loc[-1] = y_pred_Utah1.item(0)  # adding a row
y_train_UtahAll21.index = y_train_UtahAll21.index + 1  # shifting index
y_train_UtahAll21 = y_train_UtahAll21.sort_index()
regressorUtah21 = LinearRegression()
regressorUtah21.fit(X_train_UtahAll21, y_train_UtahAll21)

pd.DataFrame(list(zip(X_train_UtahAll21, regressorUtah21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Utah21 = regressorUtah21.predict(X_train_Utah21)

# %%
#New Orleans
X_train_NewOrleans1= X_NewOrleans[0:1]
y_train_NewOrleans1= y_NewOrleans[0:1]
X_train_NewOrleans2= X_NewOrleans[1:2]
y_train_NewOrleans2= y_NewOrleans[1:2]
X_train_NewOrleans3= X_NewOrleans[2:3]
y_train_NewOrleans3= y_NewOrleans[2:3]
X_train_NewOrleans4= X_NewOrleans[3:4]
y_train_NewOrleans4= y_NewOrleans[3:4]
X_train_NewOrleans5= X_NewOrleans[4:5]
y_train_NewOrleans5= y_NewOrleans[4:5]
y_train_NewOrleans6= y_NewOrleans[5:6]
X_train_NewOrleans7= X_NewOrleans[7:8]
X_train_NewOrleans6= X_NewOrleans[5:6]
y_train_NewOrleans7= y_NewOrleans[7:8]
X_train_NewOrleans8= X_NewOrleans[8:9]
y_train_NewOrleans8= y_NewOrleans[8:9]
X_train_NewOrleans9= X_NewOrleans[9:10]
y_train_NewOrleans9= y_NewOrleans[9:10]
X_train_NewOrleans10 = X_NewOrleans[10:11]
y_train_NewOrleans10 = y_NewOrleans[10:11]
X_train_NewOrleans11 = X_NewOrleans[11:12]
y_train_NewOrleans11 = y_NewOrleans[11:12]
X_train_NewOrleans12 = X_NewOrleans[12:13]
y_train_NewOrleans12 = y_NewOrleans[12:13]
X_train_NewOrleans13 = X_NewOrleans[13:14]
y_train_NewOrleans13 = y_NewOrleans[13:14]
X_train_NewOrleans14 = X_NewOrleans[14:15]
y_train_NewOrleans14 = y_NewOrleans[14:15]
X_train_NewOrleans15 = X_NewOrleans[15:16]
y_train_NewOrleans15 = y_NewOrleans[15:16]
X_train_NewOrleans16 = X_NewOrleans[16:17]
y_train_NewOrleans16 = y_NewOrleans[16:17]
X_train_NewOrleans17 = X_NewOrleans[17:18]
y_train_NewOrleans17 = y_NewOrleans[17:18]
X_train_NewOrleans18 = X_NewOrleans[18:19]
y_train_NewOrleans18 = y_NewOrleans[18:19]
X_train_NewOrleans19 = X_NewOrleans[19:20]
y_train_NewOrleans19 = y_NewOrleans[19:20]
X_train_NewOrleans20 = X_NewOrleans[20:21]
y_train_NewOrleans20 = y_NewOrleans[20:21]
X_train_NewOrleans21 = X_NewOrleans[21:22]
y_train_NewOrleans21 = y_NewOrleans[21:22]
X_train_NewOrleans22 = X_NewOrleans[22:23]
y_train_NewOrleans22 = y_NewOrleans[22:23]

X_train_NewOrleansAll1 = df.iloc[[0,22,44,66,88,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],[5,11,18,19,20]]
y_train_NewOrleansAll1 = df.iloc[[0,22,44,66,88,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],24:25]

X_train_NewOrleansAll2 = df.iloc[[0,1,23 ,45 ,67,89, 133,155,177,199,221 ,243 ,265 ,287 ,309 ,331 ,353 ,375 ,397 ,419 ,441 ,463 ,485 ,507 ,529 ,551 ,573 ,595 ,617 ,639],[5,11,18,19,20]]
y_train_NewOrleansAll2 = df.iloc[[1, 23 ,45,67,89, 133,155,177,199,221 ,243 ,265 ,287 ,309 ,331 ,353 ,375 ,397 ,419 ,441 ,463 ,485 ,507 ,529 ,551 ,573 ,595 ,617 ,639],24:25]

X_train_NewOrleansAll3 = df.iloc[[0,2,24,46,68,90 ,134 ,156 ,178 ,200 ,222 ,244 ,266 ,288 ,310 ,332 ,354 ,376 ,398 ,420 ,442 ,464 ,486 ,508 ,530 ,552 ,574 ,596 ,618 ,640],[5,11,18,19,20]]
y_train_NewOrleansAll3 = df.iloc[[2,24,46,68,90 ,134 ,156 ,178 ,200 ,222 ,244 ,266 ,288 ,310 ,332 ,354 ,376 ,398 ,420 ,442 ,464 ,486 ,508 ,530 ,552 ,574 ,596 ,618 ,640],24:25]

X_train_NewOrleansAll4 = df.iloc[[0,3,25,47,69,91 ,135 ,157 ,179 ,201 ,223 ,245 ,267 ,289 ,311 ,333 ,355 ,377 ,399 ,421 ,443 ,465 ,487 ,509 ,531 ,553 ,575 ,597 ,619 ,641],[5,11,18,19,20]]
y_train_NewOrleansAll4 = df.iloc[[3,25,47,69,91 ,135 ,157 ,179 ,201 ,223 ,245 ,267 ,289 ,311 ,333 ,355 ,377 ,399 ,421 ,443 ,465 ,487 ,509 ,531 ,553 ,575 ,597 ,619 ,641],24:25]

X_train_NewOrleansAll5 = df.iloc[[0,4,26,48,70,92 ,136 ,158 ,180 ,202 ,224 ,246 ,268 ,290 ,312 ,334 ,356 ,378 ,400 ,422 ,444 ,466 ,488 ,510 ,532 ,554 ,576 ,598 ,620 ,642],[5,11,18,19,20]]
y_train_NewOrleansAll5 = df.iloc[[4,26,48,70,92 ,136 ,158 ,180 ,202 ,224 ,246 ,268 ,290 ,312 ,334 ,356 ,378 ,400 ,422 ,444 ,466 ,488 ,510 ,532 ,554 ,576 ,598 ,620 ,642],24:25]

X_train_NewOrleansAll6 = df.iloc[[0,5,27,49,71,93 ,137 ,159 ,181 ,203 ,225 ,247 ,269 ,291 ,313 ,335 ,357 ,379 ,401 ,423 ,445 ,467 ,489 ,511 ,533 ,555 ,577 ,599 ,621 ,643],[5,11,18,19,20]]
y_train_NewOrleansAll6 = df.iloc[[5,27,49,71,93 ,137 ,159 ,181 ,203 ,225 ,247 ,269 ,291 ,313 ,335 ,357 ,379 ,401 ,423 ,445 ,467 ,489 ,511 ,533 ,555 ,577 ,599 ,621 ,643],24:25]

X_train_NewOrleansAll7 = df.iloc[[0,6,28,50,72,94 ,138 ,160 ,182 ,204 ,226 ,248 ,270 ,292 ,314 ,336 ,358 ,380 ,402 ,424 ,446 ,468 ,490 ,512 ,534 ,556 ,578 ,600 ,622 ,644],[5,11,18,19,20]]
y_train_NewOrleansAll7 = df.iloc[[6,28,50,72,94 ,138 ,160 ,182 ,204 ,226 ,248 ,270 ,292 ,314 ,336 ,358 ,380 ,402 ,424 ,446 ,468 ,490 ,512 ,534 ,556 ,578 ,600 ,622 ,644],24:25]

X_train_NewOrleansAll8 = df.iloc[[0,7,29,51,73,95 ,139 ,161 ,183 ,205 ,227 ,249 ,271 ,293 ,315 ,337 ,359 ,381 ,403 ,425 ,447 ,469 ,491 ,513 ,535 ,557 ,579 ,601 ,623 ,645],[5,11,18,19,20]]
y_train_NewOrleansAll8 = df.iloc[[7,29,51,73,95 ,139 ,161 ,183 ,205 ,227 ,249 ,271 ,293 ,315 ,337 ,359 ,381 ,403 ,425 ,447 ,469 ,491 ,513 ,535 ,557 ,579 ,601 ,623 ,645],24:25]

X_train_NewOrleansAll9 = df.iloc[[0,8,30,52,74,96 ,140 ,162 ,184 ,206 ,228 ,250 ,272 ,294 ,316 ,338 ,360 ,382 ,404 ,426 ,448 ,470 ,492 ,514 ,536 ,558 ,580 ,602 ,624 ,646],[5,11,18,19,20]]
y_train_NewOrleansAll9 = df.iloc[[8,30,52,74,96 ,140 ,162 ,184 ,206 ,228 ,250 ,272 ,294 ,316 ,338 ,360 ,382 ,404 ,426 ,448 ,470 ,492 ,514 ,536 ,558 ,580 ,602 ,624 ,646],24:25]

X_train_NewOrleansAll10 = df.iloc[[0,9,31,53,75,97 ,141 ,163 ,185 ,207 ,229 ,251 ,273 ,295 ,317 ,339 ,361 ,383 ,405 ,427 ,449 ,471 ,493 ,515 ,537 ,559 ,581 ,603 ,625 ,647],[5,11,18,19,20]]
y_train_NewOrleansAll10 = df.iloc[[9,31,53,75,97 ,141 ,163 ,185 ,207 ,229 ,251 ,273 ,295 ,317 ,339 ,361 ,383 ,405 ,427 ,449 ,471 ,493 ,515 ,537 ,559 ,581 ,603 ,625 ,647],24:25]

X_train_NewOrleansAll11 = df.iloc[[0,10,32,54,76,98 ,142 ,164 ,186 ,208 ,230 ,252 ,274 ,296 ,318 ,340 ,362 ,384 ,406 ,428 ,450 ,472 ,494 ,516 ,538 ,560 ,582 ,604 ,626 ,648],[5,11,18,19,20]]
y_train_NewOrleansAll11= df.iloc[[10,32,54,76,98 ,142 ,164 ,186 ,208 ,230 ,252 ,274 ,296 ,318 ,340 ,362 ,384 ,406 ,428 ,450 ,472 ,494 ,516 ,538 ,560 ,582 ,604 ,626 ,648],24:25]

X_train_NewOrleansAll12 = df.iloc[[0,11,33,55,77,99 ,143 ,165 ,187 ,209 ,231 ,253 ,275 ,297 ,319 ,341 ,363 ,385 ,407 ,429 ,451 ,473 ,495 ,517 ,539 ,561 ,583 ,605 ,627 ,649],[5,11,18,19,20]]
y_train_NewOrleansAll12 = df.iloc[[11,33,55,77,99 ,143 ,165 ,187 ,209 ,231 ,253 ,275 ,297 ,319 ,341 ,363 ,385 ,407 ,429 ,451 ,473 ,495 ,517 ,539 ,561 ,583 ,605 ,627 ,649],24:25]

X_train_NewOrleansAll13 = df.iloc[[0,12,34,56,78, 100, 144, 166, 188, 210, 232, 254, 276, 298, 320, 342, 364, 386, 408, 430, 452, 474, 496, 518, 540, 562, 584, 606, 628, 650],[5,11,18,19,20]]
y_train_NewOrleansAll13 = df.iloc[[12,34,56,78, 100, 144, 166, 188, 210, 232, 254, 276, 298, 320, 342, 364, 386, 408, 430, 452, 474, 496, 518, 540, 562, 584, 606, 628, 650],24:25]

X_train_NewOrleansAll14 = df.iloc[[0,13,35,57,79, 101, 145, 167, 189, 211, 233, 255, 277, 299, 321, 343, 365, 387, 409, 431, 453, 475, 497, 519, 541, 563, 585, 607, 629, 651],[5,11,18,19,20]]
y_train_NewOrleansAll14 = df.iloc[[13,35,57,79, 101, 145, 167, 189, 211, 233, 255, 277, 299, 321, 343, 365, 387, 409, 431, 453, 475, 497, 519, 541, 563, 585, 607, 629, 651],24:25]

X_train_NewOrleansAll15 = df.iloc[[0,14,36,58,80, 102, 146, 168, 190, 212, 234, 256, 278, 300, 322, 344, 366, 388, 410, 432, 454, 476, 498, 520, 542, 564, 586, 608, 630, 652],[5,11,18,19,20]]
y_train_NewOrleansAll15 = df.iloc[[14,36,58,80, 102, 146, 168, 190, 212, 234, 256, 278, 300, 322, 344, 366, 388, 410, 432, 454, 476, 498, 520, 542, 564, 586, 608, 630, 652],24:25]

X_train_NewOrleansAll16 = df.iloc[[0,15,37,59,81, 103, 147, 169, 191, 213, 235, 257, 279, 301, 323, 345, 367, 389, 411, 433, 455, 477, 499, 521, 543, 565, 587, 609, 631, 653],[5,11,18,19,20]]
y_train_NewOrleansAll16 = df.iloc[[15,37,59,81, 103, 147, 169, 191, 213, 235, 257, 279, 301, 323, 345, 367, 389, 411, 433, 455, 477, 499, 521, 543, 565, 587, 609, 631, 653],24:25]

X_train_NewOrleansAll17 = df.iloc[[0,16,38,60,82, 104, 148, 170, 192, 214, 236, 258, 280, 302, 324, 346, 368, 390, 412, 434, 456, 478, 500, 522, 544, 566, 588, 610, 632, 654],[5,11,18,19,20]]
y_train_NewOrleansAll17 = df.iloc[[16,38,60,82, 104, 148, 170, 192, 214, 236, 258, 280, 302, 324, 346, 368, 390, 412, 434, 456, 478, 500, 522, 544, 566, 588, 610, 632, 654],24:25]

X_train_NewOrleansAll18 = df.iloc[[0,17,39,61,83, 105, 149, 171, 193, 215, 237, 259, 281, 303, 325, 347, 369, 391, 413, 435, 457, 479, 501, 523, 545, 567, 589, 611, 633, 655],[5,11,18,19,20]]
y_train_NewOrleansAll18 = df.iloc[[17,39,61,83, 105, 149, 171, 193, 215, 237, 259, 281, 303, 325, 347, 369, 391, 413, 435, 457, 479, 501, 523, 545, 567, 589, 611, 633, 655],24:25]

X_train_NewOrleansAll19 = df.iloc[[0,18,40,62,84, 106, 150, 172, 194, 216, 238, 260, 282, 304, 326, 348, 370, 392, 414, 436, 458, 480, 502, 524, 546, 568, 590, 612, 634, 656],[5,11,18,19,20]]
y_train_NewOrleansAll19 = df.iloc[[18,40,62,84, 106, 150, 172, 194, 216, 238, 260, 282, 304, 326, 348, 370, 392, 414, 436, 458, 480, 502, 524, 546, 568, 590, 612, 634, 656],24:25]

X_train_NewOrleansAll20 = df.iloc[[0,19,41,63,85, 107, 151, 173, 195, 217, 239, 261, 283, 305, 327, 349, 371, 393, 415, 437, 459, 481, 503, 525, 547, 569, 591, 613, 635, 657],[5,11,18,19,20]]
y_train_NewOrleansAll20 = df.iloc[[19,41,63,85, 107, 151, 173, 195, 217, 239, 261, 283, 305, 327, 349, 371, 393, 415, 437, 459, 481, 503, 525, 547, 569, 591, 613, 635, 657],24:25]

X_train_NewOrleansAll21 = df.iloc[[0,20,42,64,86, 108, 152, 174, 196, 218, 240, 262, 284, 306, 328, 350, 372, 394, 416, 438, 460, 482, 504, 526, 548, 570, 592, 614, 636, 658],[5,11,18,19,20]]
y_train_NewOrleansAll21 = df.iloc[[20,42,64,86, 108, 152, 174, 196, 218, 240, 262, 284, 306, 328, 350, 372, 394, 416, 438, 460, 482, 504, 526, 548, 570, 592, 614, 636, 658],24:25]

X_train_NewOrleansAll22 = df.iloc[[0,21,43,65,87, 109, 153, 175, 197, 219, 241, 263, 285, 307, 329, 351, 373, 395, 417, 439, 461, 483, 505, 527, 549, 571, 593, 615, 637, 659],[5,11,18,19,20]]
y_train_NewOrleansAll22 = df.iloc[[21,43,65,87, 109, 153, 175, 197, 219, 241, 263, 285, 307, 329, 351, 373, 395, 417, 439, 461, 483, 505, 527, 549, 571, 593, 615, 637, 659],24:25]

# %%
regressorNewOrleans1 = LinearRegression()
regressorNewOrleans1.fit(X_train_NewOrleansAll1, y_train_NewOrleansAll1)
pd.DataFrame(list(zip(X_train_NewOrleansAll1, regressorNewOrleans1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_NewOrleans1 = regressorNewOrleans1.predict(X_train_NewOrleans1)

# %%
y_train_NewOrleansAll2.loc[-1] = y_pred_NewOrleans1.item(0)  # adding a row
y_train_NewOrleansAll2.index = y_train_NewOrleansAll2.index + 1  # shifting index
y_train_NewOrleansAll2 = y_train_NewOrleansAll2.sort_index()
regressorNewOrleans2 = LinearRegression()
regressorNewOrleans2.fit(X_train_NewOrleansAll2, y_train_NewOrleansAll2)

pd.DataFrame(list(zip(X_train_NewOrleansAll2, regressorNewOrleans2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewOrleans2 = regressorNewOrleans2.predict(X_train_NewOrleans2)

y_train_NewOrleansAll3.loc[-1] = y_pred_NewOrleans2.item(0)  # adding a row
y_train_NewOrleansAll3.index = y_train_NewOrleansAll3.index + 1  # shifting index
y_train_NewOrleansAll3 = y_train_NewOrleansAll3.sort_index()
regressorNewOrleans3 = LinearRegression()
regressorNewOrleans3.fit(X_train_NewOrleansAll3, y_train_NewOrleansAll3)

pd.DataFrame(list(zip(X_train_NewOrleansAll3, regressorNewOrleans3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewOrleans3 = regressorNewOrleans3.predict(X_train_NewOrleans3)

y_train_NewOrleansAll4.loc[-1] = y_pred_NewOrleans3.item(0)  # adding a row
y_train_NewOrleansAll4.index = y_train_NewOrleansAll4.index + 1  # shifting index
y_train_NewOrleansAll4 = y_train_NewOrleansAll4.sort_index()
regressorNewOrleans4 = LinearRegression()
regressorNewOrleans4.fit(X_train_NewOrleansAll4, y_train_NewOrleansAll4)

pd.DataFrame(list(zip(X_train_NewOrleansAll4, regressorNewOrleans4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewOrleans4 = regressorNewOrleans4.predict(X_train_NewOrleans4)

y_train_NewOrleansAll5.loc[-1] = y_pred_NewOrleans4.item(0)  # adding a row
y_train_NewOrleansAll5.index = y_train_NewOrleansAll5.index + 1  # shifting index
y_train_NewOrleansAll5 = y_train_NewOrleansAll5.sort_index()
regressorNewOrleans5 = LinearRegression()
regressorNewOrleans5.fit(X_train_NewOrleansAll5, y_train_NewOrleansAll5)

pd.DataFrame(list(zip(X_train_NewOrleansAll5, regressorNewOrleans5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewOrleans5 = regressorNewOrleans5.predict(X_train_NewOrleans5)

y_train_NewOrleansAll6.loc[-1] = y_pred_NewOrleans5.item(0)  # adding a row
y_train_NewOrleansAll6.index = y_train_NewOrleansAll6.index + 1  # shifting index
y_train_NewOrleansAll6 = y_train_NewOrleansAll6.sort_index()
regressorNewOrleans6 = LinearRegression()
regressorNewOrleans6.fit(X_train_NewOrleansAll6, y_train_NewOrleansAll6)

pd.DataFrame(list(zip(X_train_NewOrleansAll6, regressorNewOrleans6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewOrleans6 = regressorNewOrleans6.predict(X_train_NewOrleans6)

y_train_NewOrleansAll7.loc[-1] = y_pred_NewOrleans6.item(0)  # adding a row
y_train_NewOrleansAll7.index = y_train_NewOrleansAll7.index + 1  # shifting index
y_train_NewOrleansAll7 = y_train_NewOrleansAll7.sort_index()
regressorNewOrleans7 = LinearRegression()
regressorNewOrleans7.fit(X_train_NewOrleansAll7, y_train_NewOrleansAll7)

pd.DataFrame(list(zip(X_train_NewOrleansAll7, regressorNewOrleans7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewOrleans7 = regressorNewOrleans7.predict(X_train_NewOrleans7)

y_train_NewOrleansAll8.loc[-1] = y_pred_NewOrleans7.item(0)  # adding a row
y_train_NewOrleansAll8.index = y_train_NewOrleansAll8.index + 1  # shifting index
y_train_NewOrleansAll8 = y_train_NewOrleansAll8.sort_index()
regressorNewOrleans8 = LinearRegression()
regressorNewOrleans8.fit(X_train_NewOrleansAll8, y_train_NewOrleansAll8)

pd.DataFrame(list(zip(X_train_NewOrleansAll8, regressorNewOrleans8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewOrleans8 = regressorNewOrleans8.predict(X_train_NewOrleans8)

y_train_NewOrleansAll9.loc[-1] = y_pred_NewOrleans8.item(0)  # adding a row
y_train_NewOrleansAll9.index = y_train_NewOrleansAll9.index + 1  # shifting index
y_train_NewOrleansAll9 = y_train_NewOrleansAll9.sort_index()
regressorNewOrleans9 = LinearRegression()
regressorNewOrleans9.fit(X_train_NewOrleansAll9, y_train_NewOrleansAll9)

pd.DataFrame(list(zip(X_train_NewOrleansAll9, regressorNewOrleans9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewOrleans9 = regressorNewOrleans9.predict(X_train_NewOrleans9)

y_train_NewOrleansAll10.loc[-1] = y_pred_NewOrleans9.item(0)  # adding a row
y_train_NewOrleansAll10.index = y_train_NewOrleansAll10.index + 1  # shifting index
y_train_NewOrleansAll10 = y_train_NewOrleansAll10.sort_index()
regressorNewOrleans10 = LinearRegression()
regressorNewOrleans10.fit(X_train_NewOrleansAll10, y_train_NewOrleansAll10)

pd.DataFrame(list(zip(X_train_NewOrleansAll10, regressorNewOrleans10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewOrleans10 = regressorNewOrleans10.predict(X_train_NewOrleans10)

y_train_NewOrleansAll11.loc[-1] = y_pred_NewOrleans10.item(0)  # adding a row
y_train_NewOrleansAll11.index = y_train_NewOrleansAll11.index + 1  # shifting index
y_train_NewOrleansAll11 = y_train_NewOrleansAll11.sort_index()
regressorNewOrleans11 = LinearRegression()
regressorNewOrleans11.fit(X_train_NewOrleansAll11, y_train_NewOrleansAll11)

pd.DataFrame(list(zip(X_train_NewOrleansAll11, regressorNewOrleans11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewOrleans11 = regressorNewOrleans11.predict(X_train_NewOrleans11)

y_train_NewOrleansAll12.loc[-1] = y_pred_NewOrleans11.item(0)  # adding a row
y_train_NewOrleansAll12.index = y_train_NewOrleansAll12.index + 1  # shifting index
y_train_NewOrleansAll12 = y_train_NewOrleansAll12.sort_index()
regressorNewOrleans12 = LinearRegression()
regressorNewOrleans12.fit(X_train_NewOrleansAll12, y_train_NewOrleansAll12)

pd.DataFrame(list(zip(X_train_NewOrleansAll12, regressorNewOrleans12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewOrleans12 = regressorNewOrleans12.predict(X_train_NewOrleans12)

y_train_NewOrleansAll13.loc[-1] = y_pred_NewOrleans12.item(0)  # adding a row
y_train_NewOrleansAll13.index = y_train_NewOrleansAll13.index + 1  # shifting index
y_train_NewOrleansAll13 = y_train_NewOrleansAll13.sort_index()
regressorNewOrleans13 = LinearRegression()
regressorNewOrleans13.fit(X_train_NewOrleansAll13, y_train_NewOrleansAll13)

pd.DataFrame(list(zip(X_train_NewOrleansAll13, regressorNewOrleans13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewOrleans13 = regressorNewOrleans13.predict(X_train_NewOrleans13)

y_train_NewOrleansAll14.loc[-1] = y_pred_NewOrleans13.item(0)  # adding a row
y_train_NewOrleansAll14.index = y_train_NewOrleansAll14.index + 1  # shifting index
y_train_NewOrleansAll14 = y_train_NewOrleansAll14.sort_index()
regressorNewOrleans14 = LinearRegression()
regressorNewOrleans14.fit(X_train_NewOrleansAll14, y_train_NewOrleansAll14)

pd.DataFrame(list(zip(X_train_NewOrleansAll14, regressorNewOrleans14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewOrleans14 = regressorNewOrleans14.predict(X_train_NewOrleans14)

y_train_NewOrleansAll15.loc[-1] = y_pred_NewOrleans14.item(0)  # adding a row
y_train_NewOrleansAll15.index = y_train_NewOrleansAll15.index + 1  # shifting index
y_train_NewOrleansAll15 = y_train_NewOrleansAll15.sort_index()
regressorNewOrleans15 = LinearRegression()
regressorNewOrleans15.fit(X_train_NewOrleansAll15, y_train_NewOrleansAll15)

pd.DataFrame(list(zip(X_train_NewOrleansAll15, regressorNewOrleans15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewOrleans15 = regressorNewOrleans15.predict(X_train_NewOrleans15)

y_train_NewOrleansAll16.loc[-1] = y_pred_NewOrleans15.item(0)  # adding a row
y_train_NewOrleansAll16.index = y_train_NewOrleansAll16.index + 1  # shifting index
y_train_NewOrleansAll16 = y_train_NewOrleansAll16.sort_index()
regressorNewOrleans16 = LinearRegression()
regressorNewOrleans16.fit(X_train_NewOrleansAll16, y_train_NewOrleansAll16)

pd.DataFrame(list(zip(X_train_NewOrleansAll16, regressorNewOrleans16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewOrleans16 = regressorNewOrleans16.predict(X_train_NewOrleans16)

y_train_NewOrleansAll17.loc[-1] = y_pred_NewOrleans16.item(0)  # adding a row
y_train_NewOrleansAll17.index = y_train_NewOrleansAll17.index + 1  # shifting index
y_train_NewOrleansAll17 = y_train_NewOrleansAll17.sort_index()
regressorNewOrleans17 = LinearRegression()
regressorNewOrleans17.fit(X_train_NewOrleansAll17, y_train_NewOrleansAll17)

pd.DataFrame(list(zip(X_train_NewOrleansAll17, regressorNewOrleans17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewOrleans17 = regressorNewOrleans17.predict(X_train_NewOrleans17)

y_train_NewOrleansAll18.loc[-1] = y_pred_NewOrleans17.item(0)  # adding a row
y_train_NewOrleansAll18.index = y_train_NewOrleansAll18.index + 1  # shifting index
y_train_NewOrleansAll18 = y_train_NewOrleansAll18.sort_index()
regressorNewOrleans18 = LinearRegression()
regressorNewOrleans18.fit(X_train_NewOrleansAll18, y_train_NewOrleansAll18)

pd.DataFrame(list(zip(X_train_NewOrleansAll18, regressorNewOrleans18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewOrleans18 = regressorNewOrleans18.predict(X_train_NewOrleans18)

y_train_NewOrleansAll19.loc[-1] = y_pred_NewOrleans18.item(0)  # adding a row
y_train_NewOrleansAll19.index = y_train_NewOrleansAll19.index + 1  # shifting index
y_train_NewOrleansAll19 = y_train_NewOrleansAll19.sort_index()
regressorNewOrleans19 = LinearRegression()
regressorNewOrleans19.fit(X_train_NewOrleansAll19, y_train_NewOrleansAll19)

pd.DataFrame(list(zip(X_train_NewOrleansAll19, regressorNewOrleans19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewOrleans19 = regressorNewOrleans19.predict(X_train_NewOrleans19)

y_train_NewOrleansAll20.loc[-1] = y_pred_NewOrleans19.item(0)  # adding a row
y_train_NewOrleansAll20.index = y_train_NewOrleansAll20.index + 1  # shifting index
y_train_NewOrleansAll20 = y_train_NewOrleansAll20.sort_index()
regressorNewOrleans20 = LinearRegression()
regressorNewOrleans20.fit(X_train_NewOrleansAll20, y_train_NewOrleansAll20)

pd.DataFrame(list(zip(X_train_NewOrleansAll20, regressorNewOrleans20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewOrleans20 = regressorNewOrleans20.predict(X_train_NewOrleans20)

y_train_NewOrleansAll21.loc[-1] = y_pred_NewOrleans20.item(0)  # adding a row
y_train_NewOrleansAll21.index = y_train_NewOrleansAll21.index + 1  # shifting index
y_train_NewOrleansAll21 = y_train_NewOrleansAll21.sort_index()
regressorNewOrleans21 = LinearRegression()
regressorNewOrleans21.fit(X_train_NewOrleansAll21, y_train_NewOrleansAll21)

pd.DataFrame(list(zip(X_train_NewOrleansAll21, regressorNewOrleans21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewOrleans21 = regressorNewOrleans21.predict(X_train_NewOrleans21)

# %%
X_train_SanAntonio1= X_SanAntonio[0:1]
y_train_SanAntonio1= y_SanAntonio[0:1]
X_train_SanAntonio2= X_SanAntonio[1:2]
y_train_SanAntonio2= y_SanAntonio[1:2]
X_train_SanAntonio3= X_SanAntonio[2:3]
y_train_SanAntonio3= y_SanAntonio[2:3]
X_train_SanAntonio4= X_SanAntonio[3:4]
y_train_SanAntonio4= y_SanAntonio[3:4]
X_train_SanAntonio5= X_SanAntonio[4:5]
y_train_SanAntonio5= y_SanAntonio[4:5]
y_train_SanAntonio6= y_SanAntonio[5:6]
X_train_SanAntonio7= X_SanAntonio[7:8]
X_train_SanAntonio6= X_SanAntonio[5:6]
y_train_SanAntonio7= y_SanAntonio[7:8]
X_train_SanAntonio8= X_SanAntonio[8:9]
y_train_SanAntonio8= y_SanAntonio[8:9]
X_train_SanAntonio9= X_SanAntonio[9:10]
y_train_SanAntonio9= y_SanAntonio[9:10]
X_train_SanAntonio10 = X_SanAntonio[10:11]
y_train_SanAntonio10 = y_SanAntonio[10:11]
X_train_SanAntonio11 = X_SanAntonio[11:12]
y_train_SanAntonio11 = y_SanAntonio[11:12]
X_train_SanAntonio12 = X_SanAntonio[12:13]
y_train_SanAntonio12 = y_SanAntonio[12:13]
X_train_SanAntonio13 = X_SanAntonio[13:14]
y_train_SanAntonio13 = y_SanAntonio[13:14]
X_train_SanAntonio14 = X_SanAntonio[14:15]
y_train_SanAntonio14 = y_SanAntonio[14:15]
X_train_SanAntonio15 = X_SanAntonio[15:16]
y_train_SanAntonio15 = y_SanAntonio[15:16]
X_train_SanAntonio16 = X_SanAntonio[16:17]
y_train_SanAntonio16 = y_SanAntonio[16:17]
X_train_SanAntonio17 = X_SanAntonio[17:18]
y_train_SanAntonio17 = y_SanAntonio[17:18]
X_train_SanAntonio18 = X_SanAntonio[18:19]
y_train_SanAntonio18 = y_SanAntonio[18:19]
X_train_SanAntonio19 = X_SanAntonio[19:20]
y_train_SanAntonio19 = y_SanAntonio[19:20]
X_train_SanAntonio20 = X_SanAntonio[20:21]
y_train_SanAntonio20 = y_SanAntonio[20:21]
X_train_SanAntonio21 = X_SanAntonio[21:22]
y_train_SanAntonio21 = y_SanAntonio[21:22]
X_train_SanAntonio22 = X_SanAntonio[22:23]
y_train_SanAntonio22 = y_SanAntonio[22:23]

X_train_SanAntonioAll1 = df.iloc[[0,22,44,66,88,110,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],[5,11,18,19,20]]
y_train_SanAntonioAll1 = df.iloc[[0,22,44,66,88,110,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],24:25]

X_train_SanAntonioAll2 = df.iloc[[0,1,23 ,45 ,67,89,111,155,177,199,221 ,243 ,265 ,287 ,309 ,331 ,353 ,375 ,397 ,419 ,441 ,463 ,485 ,507 ,529 ,551 ,573 ,595 ,617 ,639],[5,11,18,19,20]]
y_train_SanAntonioAll2 = df.iloc[[1, 23 ,45,67,89, 111,155,177,199,221 ,243 ,265 ,287 ,309 ,331 ,353 ,375 ,397 ,419 ,441 ,463 ,485 ,507 ,529 ,551 ,573 ,595 ,617 ,639],24:25]

X_train_SanAntonioAll3 = df.iloc[[0,2,24,46,68,90,112,156 ,178 ,200 ,222 ,244 ,266 ,288 ,310 ,332 ,354 ,376 ,398 ,420 ,442 ,464 ,486 ,508 ,530 ,552 ,574 ,596 ,618 ,640],[5,11,18,19,20]]
y_train_SanAntonioAll3 = df.iloc[[2,24,46,68,90,112 ,156 ,178 ,200 ,222 ,244 ,266 ,288 ,310 ,332 ,354 ,376 ,398 ,420 ,442 ,464 ,486 ,508 ,530 ,552 ,574 ,596 ,618 ,640],24:25]

X_train_SanAntonioAll4 = df.iloc[[0,3,25,47,69,91,113,157 ,179 ,201 ,223 ,245 ,267 ,289 ,311 ,333 ,355 ,377 ,399 ,421 ,443 ,465 ,487 ,509 ,531 ,553 ,575 ,597 ,619 ,641],[5,11,18,19,20]]
y_train_SanAntonioAll4 = df.iloc[[3,25,47,69,91,113,157 ,179 ,201 ,223 ,245 ,267 ,289 ,311 ,333 ,355 ,377 ,399 ,421 ,443 ,465 ,487 ,509 ,531 ,553 ,575 ,597 ,619 ,641],24:25]

X_train_SanAntonioAll5 = df.iloc[[0,4,26,48,70,92,114,158 ,180 ,202 ,224 ,246 ,268 ,290 ,312 ,334 ,356 ,378 ,400 ,422 ,444 ,466 ,488 ,510 ,532 ,554 ,576 ,598 ,620 ,642],[5,11,18,19,20]]
y_train_SanAntonioAll5 = df.iloc[[4,26,48,70,92,114,158 ,180 ,202 ,224 ,246 ,268 ,290 ,312 ,334 ,356 ,378 ,400 ,422 ,444 ,466 ,488 ,510 ,532 ,554 ,576 ,598 ,620 ,642],24:25]

X_train_SanAntonioAll6 = df.iloc[[0,5,27,49,71,93,115,159 ,181 ,203 ,225 ,247 ,269 ,291 ,313 ,335 ,357 ,379 ,401 ,423 ,445 ,467 ,489 ,511 ,533 ,555 ,577 ,599 ,621 ,643],[5,11,18,19,20]]
y_train_SanAntonioAll6 = df.iloc[[5,27,49,71,93,115,159 ,181 ,203 ,225 ,247 ,269 ,291 ,313 ,335 ,357 ,379 ,401 ,423 ,445 ,467 ,489 ,511 ,533 ,555 ,577 ,599 ,621 ,643],24:25]

X_train_SanAntonioAll7 = df.iloc[[0,6,28,50,72,94,116,160 ,182 ,204 ,226 ,248 ,270 ,292 ,314 ,336 ,358 ,380 ,402 ,424 ,446 ,468 ,490 ,512 ,534 ,556 ,578 ,600 ,622 ,644],[5,11,18,19,20]]
y_train_SanAntonioAll7 = df.iloc[[6,28,50,72,94,116,160 ,182 ,204 ,226 ,248 ,270 ,292 ,314 ,336 ,358 ,380 ,402 ,424 ,446 ,468 ,490 ,512 ,534 ,556 ,578 ,600 ,622 ,644],24:25]

X_train_SanAntonioAll8 = df.iloc[[0,7,29,51,73,95,117 ,161 ,183 ,205 ,227 ,249 ,271 ,293 ,315 ,337 ,359 ,381 ,403 ,425 ,447 ,469 ,491 ,513 ,535 ,557 ,579 ,601 ,623 ,645],[5,11,18,19,20]]
y_train_SanAntonioAll8 = df.iloc[[7,29,51,73,95,117 ,161 ,183 ,205 ,227 ,249 ,271 ,293 ,315 ,337 ,359 ,381 ,403 ,425 ,447 ,469 ,491 ,513 ,535 ,557 ,579 ,601 ,623 ,645],24:25]

X_train_SanAntonioAll9 = df.iloc[[0,8,30,52,74,96,118,162 ,184 ,206 ,228 ,250 ,272 ,294 ,316 ,338 ,360 ,382 ,404 ,426 ,448 ,470 ,492 ,514 ,536 ,558 ,580 ,602 ,624 ,646],[5,11,18,19,20]]
y_train_SanAntonioAll9 = df.iloc[[8,30,52,74,96,118,162 ,184 ,206 ,228 ,250 ,272 ,294 ,316 ,338 ,360 ,382 ,404 ,426 ,448 ,470 ,492 ,514 ,536 ,558 ,580 ,602 ,624 ,646],24:25]

X_train_SanAntonioAll10 = df.iloc[[0,9,31,53,75,97,119 ,141 ,163 ,185 ,207 ,229 ,251 ,273 ,295 ,317 ,339 ,361 ,383 ,405 ,427 ,449 ,471 ,493 ,515 ,537 ,559 ,581 ,603 ,625 ,647],[5,11,18,19,20]]
y_train_SanAntonioAll10 = df.iloc[[9,31,53,75,97, 119 ,141 ,163 ,185 ,207 ,229 ,251 ,273 ,295 ,317 ,339 ,361 ,383 ,405 ,427 ,449 ,471 ,493 ,515 ,537 ,559 ,581 ,603 ,625 ,647],24:25]

X_train_SanAntonioAll11 = df.iloc[[0,10,32,54,76,98,120 ,142 ,164 ,186 ,208 ,230 ,252 ,274 ,296 ,318 ,340 ,362 ,384 ,406 ,428 ,450 ,472 ,494 ,516 ,538 ,560 ,582 ,604 ,626 ,648],[5,11,18,19,20]]
y_train_SanAntonioAll11 = df.iloc[[10,32,54,76,98,120 ,142 ,164 ,186 ,208 ,230 ,252 ,274 ,296 ,318 ,340 ,362 ,384 ,406 ,428 ,450 ,472 ,494 ,516 ,538 ,560 ,582 ,604 ,626 ,648],24:25]

X_train_SanAntonioAll12 = df.iloc[[0,11,33,55,77,99,121 ,143 ,165 ,187 ,209 ,231 ,253 ,275 ,297 ,319 ,341 ,363 ,385 ,407 ,429 ,451 ,473 ,495 ,517 ,539 ,561 ,583 ,605 ,627 ,649],[5,11,18,19,20]]
y_train_SanAntonioAll12 = df.iloc[[11,33,55,77,99,121 ,143 ,165 ,187 ,209 ,231 ,253 ,275 ,297 ,319 ,341 ,363 ,385 ,407 ,429 ,451 ,473 ,495 ,517 ,539 ,561 ,583 ,605 ,627 ,649],24:25]

X_train_SanAntonioAll13 = df.iloc[[0,12,34,56,78,100,122, 144, 166, 188, 210, 232, 254, 276, 298, 320, 342, 364, 386, 408, 430, 452, 474, 496, 518, 540, 562, 584, 606, 628, 650],[5,11,18,19,20]]
y_train_SanAntonioAll13 = df.iloc[[12,34,56,78,100, 122, 144, 166, 188, 210, 232, 254, 276, 298, 320, 342, 364, 386, 408, 430, 452, 474, 496, 518, 540, 562, 584, 606, 628, 650],24:25]

X_train_SanAntonioAll14 = df.iloc[[0,13,35,57,79,101,123, 145, 167, 189, 211, 233, 255, 277, 299, 321, 343, 365, 387, 409, 431, 453, 475, 497, 519, 541, 563, 585, 607, 629, 651],[5,11,18,19,20]]
y_train_SanAntonioAll14 = df.iloc[[13,35,57,79, 101,123, 145, 167, 189, 211, 233, 255, 277, 299, 321, 343, 365, 387, 409, 431, 453, 475, 497, 519, 541, 563, 585, 607, 629, 651],24:25]

X_train_SanAntonioAll15 = df.iloc[[0,14,36,58,80,102,124, 146, 168, 190, 212, 234, 256, 278, 300, 322, 344, 366, 388, 410, 432, 454, 476, 498, 520, 542, 564, 586, 608, 630, 652],[5,11,18,19,20]]
y_train_SanAntonioAll15 = df.iloc[[14,36,58,80, 102,124, 146, 168, 190, 212, 234, 256, 278, 300, 322, 344, 366, 388, 410, 432, 454, 476, 498, 520, 542, 564, 586, 608, 630, 652],24:25]

X_train_SanAntonioAll16 = df.iloc[[0,15,37,59,81, 103,125, 147, 169, 191, 213, 235, 257, 279, 301, 323, 345, 367, 389, 411, 433, 455, 477, 499, 521, 543, 565, 587, 609, 631, 653],[5,11,18,19,20]]
y_train_SanAntonioAll16 = df.iloc[[15,37,59,81, 103, 125, 147, 169, 191, 213, 235, 257, 279, 301, 323, 345, 367, 389, 411, 433, 455, 477, 499, 521, 543, 565, 587, 609, 631, 653],24:25]

X_train_SanAntonioAll17 = df.iloc[[0,16,38,60,82, 104,126, 148, 170, 192, 214, 236, 258, 280, 302, 324, 346, 368, 390, 412, 434, 456, 478, 500, 522, 544, 566, 588, 610, 632, 654],[5,11,18,19,20]]
y_train_SanAntonioAll17 = df.iloc[[16,38,60,82, 104,126, 148, 170, 192, 214, 236, 258, 280, 302, 324, 346, 368, 390, 412, 434, 456, 478, 500, 522, 544, 566, 588, 610, 632, 654],24:25]

X_train_SanAntonioAll18 = df.iloc[[0,17,39,61,83, 105,127, 149, 171, 193, 215, 237, 259, 281, 303, 325, 347, 369, 391, 413, 435, 457, 479, 501, 523, 545, 567, 589, 611, 633, 655],[5,11,18,19,20]]
y_train_SanAntonioAll18 = df.iloc[[17,39,61,83,105, 127, 149, 171, 193, 215, 237, 259, 281, 303, 325, 347, 369, 391, 413, 435, 457, 479, 501, 523, 545, 567, 589, 611, 633, 655],24:25]

X_train_SanAntonioAll19 = df.iloc[[0,18,40,62,84, 106,128, 150, 172, 194, 216, 238, 260, 282, 304, 326, 348, 370, 392, 414, 436, 458, 480, 502, 524, 546, 568, 590, 612, 634, 656],[5,11,18,19,20]]
y_train_SanAntonioAll19 = df.iloc[[18,40,62,84, 106,128, 150, 172, 194, 216, 238, 260, 282, 304, 326, 348, 370, 392, 414, 436, 458, 480, 502, 524, 546, 568, 590, 612, 634, 656],24:25]

X_train_SanAntonioAll20 = df.iloc[[0,19,41,63,85, 107, 129, 151, 173, 195, 217, 239, 261, 283, 305, 327, 349, 371, 393, 415, 437, 459, 481, 503, 525, 547, 569, 591, 613, 635, 657],[5,11,18,19,20]]
y_train_SanAntonioAll20 = df.iloc[[19,41,63,85, 107, 129, 151, 173, 195, 217, 239, 261, 283, 305, 327, 349, 371, 393, 415, 437, 459, 481, 503, 525, 547, 569, 591, 613, 635, 657],24:25]

X_train_SanAntonioAll21 = df.iloc[[0,20,42,64,86, 108, 130, 152, 174, 196, 218, 240, 262, 284, 306, 328, 350, 372, 394, 416, 438, 460, 482, 504, 526, 548, 570, 592, 614, 636, 658],[5,11,18,19,20]]
y_train_SanAntonioAll21 = df.iloc[[20,42,64,86,108, 130, 152, 174, 196, 218, 240, 262, 284, 306, 328, 350, 372, 394, 416, 438, 460, 482, 504, 526, 548, 570, 592, 614, 636, 658],24:25]

X_train_SanAntonioAll22 = df.iloc[[0,21,43,65,87, 109,131, 153, 175, 197, 219, 241, 263, 285, 307, 329, 351, 373, 395, 417, 439, 461, 483, 505, 527, 549, 571, 593, 615, 637, 659],[5,11,18,19,20]]
y_train_SanAntonioAll22 = df.iloc[[21,43,65,87,109,131, 153, 175, 197, 219, 241, 263, 285, 307, 329, 351, 373, 395, 417, 439, 461, 483, 505, 527, 549, 571, 593, 615, 637, 659],24:25]

# %%
regressorSanAntonio1 = LinearRegression()
regressorSanAntonio1.fit(X_train_SanAntonioAll1, y_train_SanAntonioAll1)
pd.DataFrame(list(zip(X_train_SanAntonioAll1, regressorSanAntonio1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_SanAntonio1 = regressorSanAntonio1.predict(X_train_SanAntonio1)

# %%
y_train_SanAntonioAll2.loc[-1] = y_pred_SanAntonio1.item(0)  # adding a row
y_train_SanAntonioAll2.index = y_train_SanAntonioAll2.index + 1  # shifting index
y_train_SanAntonioAll2 = y_train_SanAntonioAll2.sort_index()
regressorSanAntonio2 = LinearRegression()
regressorSanAntonio2.fit(X_train_SanAntonioAll2, y_train_SanAntonioAll2)

pd.DataFrame(list(zip(X_train_SanAntonioAll2, regressorSanAntonio2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_SanAntonio2 = regressorSanAntonio2.predict(X_train_SanAntonio2)

y_train_SanAntonioAll3.loc[-1] = y_pred_SanAntonio2.item(0)  # adding a row
y_train_SanAntonioAll3.index = y_train_SanAntonioAll3.index + 1  # shifting index
y_train_SanAntonioAll3 = y_train_SanAntonioAll3.sort_index()
regressorSanAntonio3 = LinearRegression()
regressorSanAntonio3.fit(X_train_SanAntonioAll3, y_train_SanAntonioAll3)

pd.DataFrame(list(zip(X_train_SanAntonioAll3, regressorSanAntonio3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_SanAntonio3 = regressorSanAntonio3.predict(X_train_SanAntonio3)

y_train_SanAntonioAll4.loc[-1] = y_pred_SanAntonio3.item(0)  # adding a row
y_train_SanAntonioAll4.index = y_train_SanAntonioAll4.index + 1  # shifting index
y_train_SanAntonioAll4 = y_train_SanAntonioAll4.sort_index()
regressorSanAntonio4 = LinearRegression()
regressorSanAntonio4.fit(X_train_SanAntonioAll4, y_train_SanAntonioAll4)

pd.DataFrame(list(zip(X_train_SanAntonioAll4, regressorSanAntonio4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_SanAntonio4 = regressorSanAntonio4.predict(X_train_SanAntonio4)

y_train_SanAntonioAll5.loc[-1] = y_pred_SanAntonio4.item(0)  # adding a row
y_train_SanAntonioAll5.index = y_train_SanAntonioAll5.index + 1  # shifting index
y_train_SanAntonioAll5 = y_train_SanAntonioAll5.sort_index()
regressorSanAntonio5 = LinearRegression()
regressorSanAntonio5.fit(X_train_SanAntonioAll5, y_train_SanAntonioAll5)

pd.DataFrame(list(zip(X_train_SanAntonioAll5, regressorSanAntonio5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_SanAntonio5 = regressorSanAntonio5.predict(X_train_SanAntonio5)

y_train_SanAntonioAll6.loc[-1] = y_pred_SanAntonio5.item(0)  # adding a row
y_train_SanAntonioAll6.index = y_train_SanAntonioAll6.index + 1  # shifting index
y_train_SanAntonioAll6 = y_train_SanAntonioAll6.sort_index()
regressorSanAntonio6 = LinearRegression()
regressorSanAntonio6.fit(X_train_SanAntonioAll6, y_train_SanAntonioAll6)

pd.DataFrame(list(zip(X_train_SanAntonioAll6, regressorSanAntonio6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_SanAntonio6 = regressorSanAntonio6.predict(X_train_SanAntonio6)

y_train_SanAntonioAll7.loc[-1] = y_pred_SanAntonio6.item(0)  # adding a row
y_train_SanAntonioAll7.index = y_train_SanAntonioAll7.index + 1  # shifting index
y_train_SanAntonioAll7 = y_train_SanAntonioAll7.sort_index()
regressorSanAntonio7 = LinearRegression()
regressorSanAntonio7.fit(X_train_SanAntonioAll7, y_train_SanAntonioAll7)

pd.DataFrame(list(zip(X_train_SanAntonioAll7, regressorSanAntonio7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_SanAntonio7 = regressorSanAntonio7.predict(X_train_SanAntonio7)

y_train_SanAntonioAll8.loc[-1] = y_pred_SanAntonio7.item(0)  # adding a row
y_train_SanAntonioAll8.index = y_train_SanAntonioAll8.index + 1  # shifting index
y_train_SanAntonioAll8 = y_train_SanAntonioAll8.sort_index()
regressorSanAntonio8 = LinearRegression()
regressorSanAntonio8.fit(X_train_SanAntonioAll8, y_train_SanAntonioAll8)

pd.DataFrame(list(zip(X_train_SanAntonioAll8, regressorSanAntonio8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_SanAntonio8 = regressorSanAntonio8.predict(X_train_SanAntonio8)

y_train_SanAntonioAll9.loc[-1] = y_pred_SanAntonio8.item(0)  # adding a row
y_train_SanAntonioAll9.index = y_train_SanAntonioAll9.index + 1  # shifting index
y_train_SanAntonioAll9 = y_train_SanAntonioAll9.sort_index()
regressorSanAntonio9 = LinearRegression()
regressorSanAntonio9.fit(X_train_SanAntonioAll9, y_train_SanAntonioAll9)

pd.DataFrame(list(zip(X_train_SanAntonioAll9, regressorSanAntonio9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_SanAntonio9 = regressorSanAntonio9.predict(X_train_SanAntonio9)

y_train_SanAntonioAll10.loc[-1] = y_pred_SanAntonio9.item(0)  # adding a row
y_train_SanAntonioAll10.index = y_train_SanAntonioAll10.index + 1  # shifting index
y_train_SanAntonioAll10 = y_train_SanAntonioAll10.sort_index()
regressorSanAntonio10 = LinearRegression()
regressorSanAntonio10.fit(X_train_SanAntonioAll10, y_train_SanAntonioAll10)

pd.DataFrame(list(zip(X_train_SanAntonioAll10, regressorSanAntonio10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_SanAntonio10 = regressorSanAntonio10.predict(X_train_SanAntonio10)

y_train_SanAntonioAll11.loc[-1] = y_pred_SanAntonio10.item(0)  # adding a row
y_train_SanAntonioAll11.index = y_train_SanAntonioAll11.index + 1  # shifting index
y_train_SanAntonioAll11 = y_train_SanAntonioAll11.sort_index()
regressorSanAntonio11 = LinearRegression()
regressorSanAntonio11.fit(X_train_SanAntonioAll11, y_train_SanAntonioAll11)

pd.DataFrame(list(zip(X_train_SanAntonioAll11, regressorSanAntonio11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_SanAntonio11 = regressorSanAntonio11.predict(X_train_SanAntonio11)

y_train_SanAntonioAll12.loc[-1] = y_pred_SanAntonio11.item(0)  # adding a row
y_train_SanAntonioAll12.index = y_train_SanAntonioAll12.index + 1  # shifting index
y_train_SanAntonioAll12 = y_train_SanAntonioAll12.sort_index()
regressorSanAntonio12 = LinearRegression()
regressorSanAntonio12.fit(X_train_SanAntonioAll12, y_train_SanAntonioAll12)

pd.DataFrame(list(zip(X_train_SanAntonioAll12, regressorSanAntonio12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_SanAntonio12 = regressorSanAntonio12.predict(X_train_SanAntonio12)

y_train_SanAntonioAll13.loc[-1] = y_pred_SanAntonio12.item(0)  # adding a row
y_train_SanAntonioAll13.index = y_train_SanAntonioAll13.index + 1  # shifting index
y_train_SanAntonioAll13 = y_train_SanAntonioAll13.sort_index()
regressorSanAntonio13 = LinearRegression()
regressorSanAntonio13.fit(X_train_SanAntonioAll13, y_train_SanAntonioAll13)

pd.DataFrame(list(zip(X_train_SanAntonioAll13, regressorSanAntonio13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_SanAntonio13 = regressorSanAntonio13.predict(X_train_SanAntonio13)

y_train_SanAntonioAll14.loc[-1] = y_pred_SanAntonio13.item(0)  # adding a row
y_train_SanAntonioAll14.index = y_train_SanAntonioAll14.index + 1  # shifting index
y_train_SanAntonioAll14 = y_train_SanAntonioAll14.sort_index()
regressorSanAntonio14 = LinearRegression()
regressorSanAntonio14.fit(X_train_SanAntonioAll14, y_train_SanAntonioAll14)

pd.DataFrame(list(zip(X_train_SanAntonioAll14, regressorSanAntonio14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_SanAntonio14 = regressorSanAntonio14.predict(X_train_SanAntonio14)

y_train_SanAntonioAll15.loc[-1] = y_pred_SanAntonio14.item(0)  # adding a row
y_train_SanAntonioAll15.index = y_train_SanAntonioAll15.index + 1  # shifting index
y_train_SanAntonioAll15 = y_train_SanAntonioAll15.sort_index()
regressorSanAntonio15 = LinearRegression()
regressorSanAntonio15.fit(X_train_SanAntonioAll15, y_train_SanAntonioAll15)

pd.DataFrame(list(zip(X_train_SanAntonioAll15, regressorSanAntonio15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_SanAntonio15 = regressorSanAntonio15.predict(X_train_SanAntonio15)

y_train_SanAntonioAll16.loc[-1] = y_pred_SanAntonio15.item(0)  # adding a row
y_train_SanAntonioAll16.index = y_train_SanAntonioAll16.index + 1  # shifting index
y_train_SanAntonioAll16 = y_train_SanAntonioAll16.sort_index()
regressorSanAntonio16 = LinearRegression()
regressorSanAntonio16.fit(X_train_SanAntonioAll16, y_train_SanAntonioAll16)

pd.DataFrame(list(zip(X_train_SanAntonioAll16, regressorSanAntonio16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_SanAntonio16 = regressorSanAntonio16.predict(X_train_SanAntonio16)

y_train_SanAntonioAll17.loc[-1] = y_pred_SanAntonio16.item(0)  # adding a row
y_train_SanAntonioAll17.index = y_train_SanAntonioAll17.index + 1  # shifting index
y_train_SanAntonioAll17 = y_train_SanAntonioAll17.sort_index()
regressorSanAntonio17 = LinearRegression()
regressorSanAntonio17.fit(X_train_SanAntonioAll17, y_train_SanAntonioAll17)

pd.DataFrame(list(zip(X_train_SanAntonioAll17, regressorSanAntonio17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_SanAntonio17 = regressorSanAntonio17.predict(X_train_SanAntonio17)

y_train_SanAntonioAll18.loc[-1] = y_pred_SanAntonio17.item(0)  # adding a row
y_train_SanAntonioAll18.index = y_train_SanAntonioAll18.index + 1  # shifting index
y_train_SanAntonioAll18 = y_train_SanAntonioAll18.sort_index()
regressorSanAntonio18 = LinearRegression()
regressorSanAntonio18.fit(X_train_SanAntonioAll18, y_train_SanAntonioAll18)

pd.DataFrame(list(zip(X_train_SanAntonioAll18, regressorSanAntonio18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_SanAntonio18 = regressorSanAntonio18.predict(X_train_SanAntonio18)

y_train_SanAntonioAll19.loc[-1] = y_pred_SanAntonio18.item(0)  # adding a row
y_train_SanAntonioAll19.index = y_train_SanAntonioAll19.index + 1  # shifting index
y_train_SanAntonioAll19 = y_train_SanAntonioAll19.sort_index()
regressorSanAntonio19 = LinearRegression()
regressorSanAntonio19.fit(X_train_SanAntonioAll19, y_train_SanAntonioAll19)

pd.DataFrame(list(zip(X_train_SanAntonioAll19, regressorSanAntonio19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_SanAntonio19 = regressorSanAntonio19.predict(X_train_SanAntonio19)

y_train_SanAntonioAll20.loc[-1] = y_pred_SanAntonio19.item(0)  # adding a row
y_train_SanAntonioAll20.index = y_train_SanAntonioAll20.index + 1  # shifting index
y_train_SanAntonioAll20 = y_train_SanAntonioAll20.sort_index()
regressorSanAntonio20 = LinearRegression()
regressorSanAntonio20.fit(X_train_SanAntonioAll20, y_train_SanAntonioAll20)

pd.DataFrame(list(zip(X_train_SanAntonioAll20, regressorSanAntonio20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_SanAntonio20 = regressorSanAntonio20.predict(X_train_SanAntonio20)

y_train_SanAntonioAll21.loc[-1] = y_pred_SanAntonio20.item(0)  # adding a row
y_train_SanAntonioAll21.index = y_train_SanAntonioAll21.index + 1  # shifting index
y_train_SanAntonioAll21 = y_train_SanAntonioAll21.sort_index()
regressorSanAntonio21 = LinearRegression()
regressorSanAntonio21.fit(X_train_SanAntonioAll21, y_train_SanAntonioAll21)

pd.DataFrame(list(zip(X_train_SanAntonioAll21, regressorSanAntonio21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_SanAntonio21 = regressorSanAntonio21.predict(X_train_SanAntonio21)

# %%
X_train_Minnesota1= X_Minnesota[0:1]
y_train_Minnesota1= y_Minnesota[0:1]
X_train_Minnesota2= X_Minnesota[1:2]
y_train_Minnesota2= y_Minnesota[1:2]
X_train_Minnesota3= X_Minnesota[2:3]
y_train_Minnesota3= y_Minnesota[2:3]
X_train_Minnesota4= X_Minnesota[3:4]
y_train_Minnesota4= y_Minnesota[3:4]
X_train_Minnesota5= X_Minnesota[4:5]
y_train_Minnesota5= y_Minnesota[4:5]
y_train_Minnesota6= y_Minnesota[5:6]
X_train_Minnesota7= X_Minnesota[7:8]
X_train_Minnesota6= X_Minnesota[5:6]
y_train_Minnesota7= y_Minnesota[7:8]
X_train_Minnesota8= X_Minnesota[8:9]
y_train_Minnesota8= y_Minnesota[8:9]
X_train_Minnesota9= X_Minnesota[9:10]
y_train_Minnesota9= y_Minnesota[9:10]
X_train_Minnesota10 = X_Minnesota[10:11]
y_train_Minnesota10 = y_Minnesota[10:11]
X_train_Minnesota11 = X_Minnesota[11:12]
y_train_Minnesota11 = y_Minnesota[11:12]
X_train_Minnesota12 = X_Minnesota[12:13]
y_train_Minnesota12 = y_Minnesota[12:13]
X_train_Minnesota13 = X_Minnesota[13:14]
y_train_Minnesota13 = y_Minnesota[13:14]
X_train_Minnesota14 = X_Minnesota[14:15]
y_train_Minnesota14 = y_Minnesota[14:15]
X_train_Minnesota15 = X_Minnesota[15:16]
y_train_Minnesota15 = y_Minnesota[15:16]
X_train_Minnesota16 = X_Minnesota[16:17]
y_train_Minnesota16 = y_Minnesota[16:17]
X_train_Minnesota17 = X_Minnesota[17:18]
y_train_Minnesota17 = y_Minnesota[17:18]
X_train_Minnesota18 = X_Minnesota[18:19]
y_train_Minnesota18 = y_Minnesota[18:19]
X_train_Minnesota19 = X_Minnesota[19:20]
y_train_Minnesota19 = y_Minnesota[19:20]
X_train_Minnesota20 = X_Minnesota[20:21]
y_train_Minnesota20 = y_Minnesota[20:21]
X_train_Minnesota21 = X_Minnesota[21:22]
y_train_Minnesota21 = y_Minnesota[21:22]
X_train_Minnesota22 = X_Minnesota[22:23]
y_train_Minnesota22 = y_Minnesota[22:23]

X_train_MinnesotaAll1 = df.iloc[[0,22,44,66,88,110,132,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],[5,11,18,19,20]]
y_train_MinnesotaAll1 = df.iloc[[0,22,44,66,88,110,132,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],24:25]

X_train_MinnesotaAll2 = df.iloc[[0,1,23 ,45 ,67,89,111, 133,177,199,221 ,243 ,265 ,287 ,309 ,331 ,353 ,375 ,397 ,419 ,441 ,463 ,485 ,507 ,529 ,551 ,573 ,595 ,617 ,639],[5,11,18,19,20]]
y_train_MinnesotaAll2 = df.iloc[[1, 23 ,45,67,89, 111, 133,177,199,221 ,243 ,265 ,287 ,309 ,331 ,353 ,375 ,397 ,419 ,441 ,463 ,485 ,507 ,529 ,551 ,573 ,595 ,617 ,639],24:25]

X_train_MinnesotaAll3 = df.iloc[[0,2,24,46,68,90,112 ,134 ,178 ,200 ,222 ,244 ,266 ,288 ,310 ,332 ,354 ,376 ,398 ,420 ,442 ,464 ,486 ,508 ,530 ,552 ,574 ,596 ,618 ,640],[5,11,18,19,20]]
y_train_MinnesotaAll3 = df.iloc[[2,24,46,68,90,112 ,134,178 ,200 ,222 ,244 ,266 ,288 ,310 ,332 ,354 ,376 ,398 ,420 ,442 ,464 ,486 ,508 ,530 ,552 ,574 ,596 ,618 ,640],24:25]

X_train_MinnesotaAll4 = df.iloc[[0,3,25,47,69,91,113,135,179 ,201 ,223 ,245 ,267 ,289 ,311 ,333 ,355 ,377 ,399 ,421 ,443 ,465 ,487 ,509 ,531 ,553 ,575 ,597 ,619 ,641],[5,11,18,19,20]]
y_train_MinnesotaAll4 = df.iloc[[3,25,47,69,91,113,135,179 ,201 ,223 ,245 ,267 ,289 ,311 ,333 ,355 ,377 ,399 ,421 ,443 ,465 ,487 ,509 ,531 ,553 ,575 ,597 ,619 ,641],24:25]

X_train_MinnesotaAll5 = df.iloc[[0,4,26,48,70,92, 114,136  ,180 ,202 ,224 ,246 ,268 ,290 ,312 ,334 ,356 ,378 ,400 ,422 ,444 ,466 ,488 ,510 ,532 ,554 ,576 ,598 ,620 ,642],[5,11,18,19,20]]
y_train_MinnesotaAll5 = df.iloc[[4,26,48,70,92,114,136  ,180 ,202 ,224 ,246 ,268 ,290 ,312 ,334 ,356 ,378 ,400 ,422 ,444 ,466 ,488 ,510 ,532 ,554 ,576 ,598 ,620 ,642],24:25]

X_train_MinnesotaAll6 = df.iloc[[0,5,27,49,71,93,115 ,137,181 ,203 ,225 ,247 ,269 ,291 ,313 ,335 ,357 ,379 ,401 ,423 ,445 ,467 ,489 ,511 ,533 ,555 ,577 ,599 ,621 ,643],[5,11,18,19,20]]
y_train_MinnesotaAll6 = df.iloc[[5,27,49,71,93,115 ,137 ,181 ,203 ,225 ,247 ,269 ,291 ,313 ,335 ,357 ,379 ,401 ,423 ,445 ,467 ,489 ,511 ,533 ,555 ,577 ,599 ,621 ,643],24:25]

X_train_MinnesotaAll7 = df.iloc[[0,6,28,50,72,94,116,138  ,182 ,204 ,226 ,248 ,270 ,292 ,314 ,336 ,358 ,380 ,402 ,424 ,446 ,468 ,490 ,512 ,534 ,556 ,578 ,600 ,622 ,644],[5,11,18,19,20]]
y_train_MinnesotaAll7 = df.iloc[[6,28,50,72,94,116 ,138  ,182 ,204 ,226 ,248 ,270 ,292 ,314 ,336 ,358 ,380 ,402 ,424 ,446 ,468 ,490 ,512 ,534 ,556 ,578 ,600 ,622 ,644],24:25]

X_train_MinnesotaAll8 = df.iloc[[0,7,29,51,73,95,117,139 ,183 ,205 ,227 ,249 ,271 ,293 ,315 ,337 ,359 ,381 ,403 ,425 ,447 ,469 ,491 ,513 ,535 ,557 ,579 ,601 ,623 ,645],[5,11,18,19,20]]
y_train_MinnesotaAll8 = df.iloc[[7,29,51,73,95,117 ,139 ,183 ,205 ,227 ,249 ,271 ,293 ,315 ,337 ,359 ,381 ,403 ,425 ,447 ,469 ,491 ,513 ,535 ,557 ,579 ,601 ,623 ,645],24:25]

X_train_MinnesotaAll9 = df.iloc[[0,8,30,52,74,96,118 ,140 ,184 ,206 ,228 ,250 ,272 ,294 ,316 ,338 ,360 ,382 ,404 ,426 ,448 ,470 ,492 ,514 ,536 ,558 ,580 ,602 ,624 ,646],[5,11,18,19,20]]
y_train_MinnesotaAll9 = df.iloc[[8,30,52,74,96,118 ,140 ,184 ,206 ,228 ,250 ,272 ,294 ,316 ,338 ,360 ,382 ,404 ,426 ,448 ,470 ,492 ,514 ,536 ,558 ,580 ,602 ,624 ,646],24:25]

X_train_MinnesotaAll10 = df.iloc[[0,9,31,53,75,97, 119,141 ,185 ,207 ,229 ,251 ,273 ,295 ,317 ,339 ,361 ,383 ,405 ,427 ,449 ,471 ,493 ,515 ,537 ,559 ,581 ,603 ,625 ,647],[5,11,18,19,20]]
y_train_MinnesotaAll10 = df.iloc[[9,31,53,75,97, 119,141,185 ,207 ,229 ,251 ,273 ,295 ,317 ,339 ,361 ,383 ,405 ,427 ,449 ,471 ,493 ,515 ,537 ,559 ,581 ,603 ,625 ,647],24:25]

X_train_MinnesotaAll11 = df.iloc[[0,10,32,54,76,98,120,142 ,186 ,208 ,230 ,252 ,274 ,296 ,318 ,340 ,362 ,384 ,406 ,428 ,450 ,472 ,494 ,516 ,538 ,560 ,582 ,604 ,626 ,648],[5,11,18,19,20]]
y_train_MinnesotaAll11= df.iloc[[10,32,54,76,98,120 ,142,186 ,208 ,230 ,252 ,274 ,296 ,318 ,340 ,362 ,384 ,406 ,428 ,450 ,472 ,494 ,516 ,538 ,560 ,582 ,604 ,626 ,648],24:25]

X_train_MinnesotaAll12 = df.iloc[[0,11,33,55,77,99,121 ,143 ,187 ,209 ,231 ,253 ,275 ,297 ,319 ,341 ,363 ,385 ,407 ,429 ,451 ,473 ,495 ,517 ,539 ,561 ,583 ,605 ,627 ,649],[5,11,18,19,20]]
y_train_MinnesotaAll12 = df.iloc[[11,33,55,77,99,121 ,143,187 ,209 ,231 ,253 ,275 ,297 ,319 ,341 ,363 ,385 ,407 ,429 ,451 ,473 ,495 ,517 ,539 ,561 ,583 ,605 ,627 ,649],24:25]

X_train_MinnesotaAll13 = df.iloc[[0,12,34,56,78, 100, 122, 144, 188, 210, 232, 254, 276, 298, 320, 342, 364, 386, 408, 430, 452, 474, 496, 518, 540, 562, 584, 606, 628, 650],[5,11,18,19,20]]
y_train_MinnesotaAll13 = df.iloc[[12,34,56,78, 100, 122, 144, 188, 210, 232, 254, 276, 298, 320, 342, 364, 386, 408, 430, 452, 474, 496, 518, 540, 562, 584, 606, 628, 650],24:25]

X_train_MinnesotaAll14 = df.iloc[[0,13,35,57,79, 101,123, 145, 189, 211, 233, 255, 277, 299, 321, 343, 365, 387, 409, 431, 453, 475, 497, 519, 541, 563, 585, 607, 629, 651],[5,11,18,19,20]]
y_train_MinnesotaAll14 = df.iloc[[13,35,57,79, 101,123, 145, 189, 211, 233, 255, 277, 299, 321, 343, 365, 387, 409, 431, 453, 475, 497, 519, 541, 563, 585, 607, 629, 651],24:25]

X_train_MinnesotaAll15 = df.iloc[[0,14,36,58,80, 102,124, 146, 190, 212, 234, 256, 278, 300, 322, 344, 366, 388, 410, 432, 454, 476, 498, 520, 542, 564, 586, 608, 630, 652],[5,11,18,19,20]]
y_train_MinnesotaAll15 = df.iloc[[14,36,58,80, 102,124, 146, 190, 212, 234, 256, 278, 300, 322, 344, 366, 388, 410, 432, 454, 476, 498, 520, 542, 564, 586, 608, 630, 652],24:25]

X_train_MinnesotaAll16 = df.iloc[[0,15,37,59,81, 103,125, 147, 191, 213, 235, 257, 279, 301, 323, 345, 367, 389, 411, 433, 455, 477, 499, 521, 543, 565, 587, 609, 631, 653],[5,11,18,19,20]]
y_train_MinnesotaAll16 = df.iloc[[15,37,59,81, 103,125,147,191, 213, 235, 257, 279, 301, 323, 345, 367, 389, 411, 433, 455, 477, 499, 521, 543, 565, 587, 609, 631, 653],24:25]

X_train_MinnesotaAll17 = df.iloc[[0,16,38,60,82, 104,126, 148, 192, 214, 236, 258, 280, 302, 324, 346, 368, 390, 412, 434, 456, 478, 500, 522, 544, 566, 588, 610, 632, 654],[5,11,18,19,20]]
y_train_MinnesotaAll17 = df.iloc[[16,38,60,82, 104,126,148, 192, 214, 236, 258, 280, 302, 324, 346, 368, 390, 412, 434, 456, 478, 500, 522, 544, 566, 588, 610, 632, 654],24:25]

X_train_MinnesotaAll18 = df.iloc[[0,17,39,61,83, 105,127, 149, 193, 215, 237, 259, 281, 303, 325, 347, 369, 391, 413, 435, 457, 479, 501, 523, 545, 567, 589, 611, 633, 655],[5,11,18,19,20]]
y_train_MinnesotaAll18 = df.iloc[[17,39,61,83, 105,127, 149, 193, 215, 237, 259, 281, 303, 325, 347, 369, 391, 413, 435, 457, 479, 501, 523, 545, 567, 589, 611, 633, 655],24:25]

X_train_MinnesotaAll19 = df.iloc[[0,18,40,62,84, 106,128, 150, 194, 216, 238, 260, 282, 304, 326, 348, 370, 392, 414, 436, 458, 480, 502, 524, 546, 568, 590, 612, 634, 656],[5,11,18,19,20]]
y_train_MinnesotaAll19 = df.iloc[[18,40,62,84, 106,128, 150, 194, 216, 238, 260, 282, 304, 326, 348, 370, 392, 414, 436, 458, 480, 502, 524, 546, 568, 590, 612, 634, 656],24:25]

X_train_MinnesotaAll20 = df.iloc[[0,19,41,63,85, 107,129, 151,195, 217, 239, 261, 283, 305, 327, 349, 371, 393, 415, 437, 459, 481, 503, 525, 547, 569, 591, 613, 635, 657],[5,11,18,19,20]]
y_train_MinnesotaAll20 = df.iloc[[19,41,63,85, 107, 129, 151, 195, 217, 239, 261, 283, 305, 327, 349, 371, 393, 415, 437, 459, 481, 503, 525, 547, 569, 591, 613, 635, 657],24:25]

X_train_MinnesotaAll21 = df.iloc[[0,20,42,64,86, 108,130, 152,196, 218, 240, 262, 284, 306, 328, 350, 372, 394, 416, 438, 460, 482, 504, 526, 548, 570, 592, 614, 636, 658],[5,11,18,19,20]]
y_train_MinnesotaAll21 = df.iloc[[20,42,64,86, 108,130, 152, 196, 218, 240, 262, 284, 306, 328, 350, 372, 394, 416, 438, 460, 482, 504, 526, 548, 570, 592, 614, 636, 658],24:25]

X_train_MinnesotaAll22 = df.iloc[[0,21,43,65,87, 109,131, 153, 197, 219, 241, 263, 285, 307, 329, 351, 373, 395, 417, 439, 461, 483, 505, 527, 549, 571, 593, 615, 637, 659],[5,11,18,19,20]]
y_train_MinnesotaAll22 = df.iloc[[21,43,65,87, 109,131, 153, 197, 219, 241, 263, 285, 307, 329, 351, 373, 395, 417, 439, 461, 483, 505, 527, 549, 571, 593, 615, 637, 659],24:25]

# %%
regressorMinnesota1 = LinearRegression()
regressorMinnesota1.fit(X_train_MinnesotaAll1, y_train_MinnesotaAll1)
pd.DataFrame(list(zip(X_train_MinnesotaAll1, regressorMinnesota1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_Minnesota1 = regressorMinnesota1.predict(X_train_Minnesota1)

# %%
y_train_MinnesotaAll2.loc[-1] = y_pred_Minnesota1.item(0)  # adding a row
y_train_MinnesotaAll2.index = y_train_MinnesotaAll2.index + 1  # shifting index
y_train_MinnesotaAll2 = y_train_MinnesotaAll2.sort_index()
regressorMinnesota2 = LinearRegression()
regressorMinnesota2.fit(X_train_MinnesotaAll2, y_train_MinnesotaAll2)

pd.DataFrame(list(zip(X_train_MinnesotaAll2, regressorMinnesota2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Minnesota2 = regressorMinnesota2.predict(X_train_Minnesota2)

y_train_MinnesotaAll3.loc[-1] = y_pred_Minnesota2.item(0)  # adding a row
y_train_MinnesotaAll3.index = y_train_MinnesotaAll3.index + 1  # shifting index
y_train_MinnesotaAll3 = y_train_MinnesotaAll3.sort_index()
regressorMinnesota3 = LinearRegression()
regressorMinnesota3.fit(X_train_MinnesotaAll3, y_train_MinnesotaAll3)

pd.DataFrame(list(zip(X_train_MinnesotaAll3, regressorMinnesota3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Minnesota3 = regressorMinnesota3.predict(X_train_Minnesota3)

y_train_MinnesotaAll4.loc[-1] = y_pred_Minnesota3.item(0)  # adding a row
y_train_MinnesotaAll4.index = y_train_MinnesotaAll4.index + 1  # shifting index
y_train_MinnesotaAll4 = y_train_MinnesotaAll4.sort_index()
regressorMinnesota4 = LinearRegression()
regressorMinnesota4.fit(X_train_MinnesotaAll4, y_train_MinnesotaAll4)

pd.DataFrame(list(zip(X_train_MinnesotaAll4, regressorMinnesota4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Minnesota4 = regressorMinnesota4.predict(X_train_Minnesota4)

y_train_MinnesotaAll5.loc[-1] = y_pred_Minnesota4.item(0)  # adding a row
y_train_MinnesotaAll5.index = y_train_MinnesotaAll5.index + 1  # shifting index
y_train_MinnesotaAll5 = y_train_MinnesotaAll5.sort_index()
regressorMinnesota5 = LinearRegression()
regressorMinnesota5.fit(X_train_MinnesotaAll5, y_train_MinnesotaAll5)

pd.DataFrame(list(zip(X_train_MinnesotaAll5, regressorMinnesota5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Minnesota5 = regressorMinnesota5.predict(X_train_Minnesota5)

y_train_MinnesotaAll6.loc[-1] = y_pred_Minnesota5.item(0)  # adding a row
y_train_MinnesotaAll6.index = y_train_MinnesotaAll6.index + 1  # shifting index
y_train_MinnesotaAll6 = y_train_MinnesotaAll6.sort_index()
regressorMinnesota6 = LinearRegression()
regressorMinnesota6.fit(X_train_MinnesotaAll6, y_train_MinnesotaAll6)

pd.DataFrame(list(zip(X_train_MinnesotaAll6, regressorMinnesota6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Minnesota6 = regressorMinnesota6.predict(X_train_Minnesota6)

y_train_MinnesotaAll7.loc[-1] = y_pred_Minnesota6.item(0)  # adding a row
y_train_MinnesotaAll7.index = y_train_MinnesotaAll7.index + 1  # shifting index
y_train_MinnesotaAll7 = y_train_MinnesotaAll7.sort_index()
regressorMinnesota7 = LinearRegression()
regressorMinnesota7.fit(X_train_MinnesotaAll7, y_train_MinnesotaAll7)

pd.DataFrame(list(zip(X_train_MinnesotaAll7, regressorMinnesota7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Minnesota7 = regressorMinnesota7.predict(X_train_Minnesota7)

y_train_MinnesotaAll8.loc[-1] = y_pred_Minnesota7.item(0)  # adding a row
y_train_MinnesotaAll8.index = y_train_MinnesotaAll8.index + 1  # shifting index
y_train_MinnesotaAll8 = y_train_MinnesotaAll8.sort_index()
regressorMinnesota8 = LinearRegression()
regressorMinnesota8.fit(X_train_MinnesotaAll8, y_train_MinnesotaAll8)

pd.DataFrame(list(zip(X_train_MinnesotaAll8, regressorMinnesota8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Minnesota8 = regressorMinnesota8.predict(X_train_Minnesota8)

y_train_MinnesotaAll9.loc[-1] = y_pred_Minnesota8.item(0)  # adding a row
y_train_MinnesotaAll9.index = y_train_MinnesotaAll9.index + 1  # shifting index
y_train_MinnesotaAll9 = y_train_MinnesotaAll9.sort_index()
regressorMinnesota9 = LinearRegression()
regressorMinnesota9.fit(X_train_MinnesotaAll9, y_train_MinnesotaAll9)

pd.DataFrame(list(zip(X_train_MinnesotaAll9, regressorMinnesota9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Minnesota9 = regressorMinnesota9.predict(X_train_Minnesota9)

y_train_MinnesotaAll10.loc[-1] = y_pred_Minnesota9.item(0)  # adding a row
y_train_MinnesotaAll10.index = y_train_MinnesotaAll10.index + 1  # shifting index
y_train_MinnesotaAll10 = y_train_MinnesotaAll10.sort_index()
regressorMinnesota10 = LinearRegression()
regressorMinnesota10.fit(X_train_MinnesotaAll10, y_train_MinnesotaAll10)

pd.DataFrame(list(zip(X_train_MinnesotaAll10, regressorMinnesota10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Minnesota10 = regressorMinnesota10.predict(X_train_Minnesota10)

y_train_MinnesotaAll11.loc[-1] = y_pred_Minnesota10.item(0)  # adding a row
y_train_MinnesotaAll11.index = y_train_MinnesotaAll11.index + 1  # shifting index
y_train_MinnesotaAll11 = y_train_MinnesotaAll11.sort_index()
regressorMinnesota11 = LinearRegression()
regressorMinnesota11.fit(X_train_MinnesotaAll11, y_train_MinnesotaAll11)

pd.DataFrame(list(zip(X_train_MinnesotaAll11, regressorMinnesota11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Minnesota11 = regressorMinnesota11.predict(X_train_Minnesota11)

y_train_MinnesotaAll12.loc[-1] = y_pred_Minnesota11.item(0)  # adding a row
y_train_MinnesotaAll12.index = y_train_MinnesotaAll12.index + 1  # shifting index
y_train_MinnesotaAll12 = y_train_MinnesotaAll12.sort_index()
regressorMinnesota12 = LinearRegression()
regressorMinnesota12.fit(X_train_MinnesotaAll12, y_train_MinnesotaAll12)

pd.DataFrame(list(zip(X_train_MinnesotaAll12, regressorMinnesota12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Minnesota12 = regressorMinnesota12.predict(X_train_Minnesota12)

y_train_MinnesotaAll13.loc[-1] = y_pred_Minnesota12.item(0)  # adding a row
y_train_MinnesotaAll13.index = y_train_MinnesotaAll13.index + 1  # shifting index
y_train_MinnesotaAll13 = y_train_MinnesotaAll13.sort_index()
regressorMinnesota13 = LinearRegression()
regressorMinnesota13.fit(X_train_MinnesotaAll13, y_train_MinnesotaAll13)

pd.DataFrame(list(zip(X_train_MinnesotaAll13, regressorMinnesota13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Minnesota13 = regressorMinnesota13.predict(X_train_Minnesota13)

y_train_MinnesotaAll14.loc[-1] = y_pred_Minnesota13.item(0)  # adding a row
y_train_MinnesotaAll14.index = y_train_MinnesotaAll14.index + 1  # shifting index
y_train_MinnesotaAll14 = y_train_MinnesotaAll14.sort_index()
regressorMinnesota14 = LinearRegression()
regressorMinnesota14.fit(X_train_MinnesotaAll14, y_train_MinnesotaAll14)

pd.DataFrame(list(zip(X_train_MinnesotaAll14, regressorMinnesota14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Minnesota14 = regressorMinnesota14.predict(X_train_Minnesota14)

y_train_MinnesotaAll15.loc[-1] = y_pred_Minnesota14.item(0)  # adding a row
y_train_MinnesotaAll15.index = y_train_MinnesotaAll15.index + 1  # shifting index
y_train_MinnesotaAll15 = y_train_MinnesotaAll15.sort_index()
regressorMinnesota15 = LinearRegression()
regressorMinnesota15.fit(X_train_MinnesotaAll15, y_train_MinnesotaAll15)

pd.DataFrame(list(zip(X_train_MinnesotaAll15, regressorMinnesota15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Minnesota15 = regressorMinnesota15.predict(X_train_Minnesota15)

y_train_MinnesotaAll16.loc[-1] = y_pred_Minnesota15.item(0)  # adding a row
y_train_MinnesotaAll16.index = y_train_MinnesotaAll16.index + 1  # shifting index
y_train_MinnesotaAll16 = y_train_MinnesotaAll16.sort_index()
regressorMinnesota16 = LinearRegression()
regressorMinnesota16.fit(X_train_MinnesotaAll16, y_train_MinnesotaAll16)

pd.DataFrame(list(zip(X_train_MinnesotaAll16, regressorMinnesota16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Minnesota16 = regressorMinnesota16.predict(X_train_Minnesota16)

y_train_MinnesotaAll17.loc[-1] = y_pred_Minnesota16.item(0)  # adding a row
y_train_MinnesotaAll17.index = y_train_MinnesotaAll17.index + 1  # shifting index
y_train_MinnesotaAll17 = y_train_MinnesotaAll17.sort_index()
regressorMinnesota17 = LinearRegression()
regressorMinnesota17.fit(X_train_MinnesotaAll17, y_train_MinnesotaAll17)

pd.DataFrame(list(zip(X_train_MinnesotaAll17, regressorMinnesota17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Minnesota17 = regressorMinnesota17.predict(X_train_Minnesota17)

y_train_MinnesotaAll18.loc[-1] = y_pred_Minnesota17.item(0)  # adding a row
y_train_MinnesotaAll18.index = y_train_MinnesotaAll18.index + 1  # shifting index
y_train_MinnesotaAll18 = y_train_MinnesotaAll18.sort_index()
regressorMinnesota18 = LinearRegression()
regressorMinnesota18.fit(X_train_MinnesotaAll18, y_train_MinnesotaAll18)

pd.DataFrame(list(zip(X_train_MinnesotaAll18, regressorMinnesota18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Minnesota18 = regressorMinnesota18.predict(X_train_Minnesota18)

y_train_MinnesotaAll19.loc[-1] = y_pred_Minnesota18.item(0)  # adding a row
y_train_MinnesotaAll19.index = y_train_MinnesotaAll19.index + 1  # shifting index
y_train_MinnesotaAll19 = y_train_MinnesotaAll19.sort_index()
regressorMinnesota19 = LinearRegression()
regressorMinnesota19.fit(X_train_MinnesotaAll19, y_train_MinnesotaAll19)

pd.DataFrame(list(zip(X_train_MinnesotaAll19, regressorMinnesota19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Minnesota19 = regressorMinnesota19.predict(X_train_Minnesota19)

y_train_MinnesotaAll20.loc[-1] = y_pred_Minnesota19.item(0)  # adding a row
y_train_MinnesotaAll20.index = y_train_MinnesotaAll20.index + 1  # shifting index
y_train_MinnesotaAll20 = y_train_MinnesotaAll20.sort_index()
regressorMinnesota20 = LinearRegression()
regressorMinnesota20.fit(X_train_MinnesotaAll20, y_train_MinnesotaAll20)

pd.DataFrame(list(zip(X_train_MinnesotaAll20, regressorMinnesota20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Minnesota20 = regressorMinnesota20.predict(X_train_Minnesota20)

y_train_MinnesotaAll21.loc[-1] = y_pred_Minnesota20.item(0)  # adding a row
y_train_MinnesotaAll21.index = y_train_MinnesotaAll21.index + 1  # shifting index
y_train_MinnesotaAll21 = y_train_MinnesotaAll21.sort_index()
regressorMinnesota21 = LinearRegression()
regressorMinnesota21.fit(X_train_MinnesotaAll21, y_train_MinnesotaAll21)

pd.DataFrame(list(zip(X_train_MinnesotaAll21, regressorMinnesota21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Minnesota21 = regressorMinnesota21.predict(X_train_Minnesota21)

# %%
X_train_Denver1= X_Denver[0:1]
y_train_Denver1= y_Denver[0:1]
X_train_Denver2= X_Denver[1:2]
y_train_Denver2= y_Denver[1:2]
X_train_Denver3= X_Denver[2:3]
y_train_Denver3= y_Denver[2:3]
X_train_Denver4= X_Denver[3:4]
y_train_Denver4= y_Denver[3:4]
X_train_Denver5= X_Denver[4:5]
y_train_Denver5= y_Denver[4:5]
y_train_Denver6= y_Denver[5:6]
X_train_Denver7= X_Denver[7:8]
X_train_Denver6= X_Denver[5:6]
y_train_Denver7= y_Denver[7:8]
X_train_Denver8= X_Denver[8:9]
y_train_Denver8= y_Denver[8:9]
X_train_Denver9= X_Denver[9:10]
y_train_Denver9= y_Denver[9:10]
X_train_Denver10 = X_Denver[10:11]
y_train_Denver10 = y_Denver[10:11]
X_train_Denver11 = X_Denver[11:12]
y_train_Denver11 = y_Denver[11:12]
X_train_Denver12 = X_Denver[12:13]
y_train_Denver12 = y_Denver[12:13]
X_train_Denver13 = X_Denver[13:14]
y_train_Denver13 = y_Denver[13:14]
X_train_Denver14 = X_Denver[14:15]
y_train_Denver14 = y_Denver[14:15]
X_train_Denver15 = X_Denver[15:16]
y_train_Denver15 = y_Denver[15:16]
X_train_Denver16 = X_Denver[16:17]
y_train_Denver16 = y_Denver[16:17]
X_train_Denver17 = X_Denver[17:18]
y_train_Denver17 = y_Denver[17:18]
X_train_Denver18 = X_Denver[18:19]
y_train_Denver18 = y_Denver[18:19]
X_train_Denver19 = X_Denver[19:20]
y_train_Denver19 = y_Denver[19:20]
X_train_Denver20 = X_Denver[20:21]
y_train_Denver20 = y_Denver[20:21]
X_train_Denver21 = X_Denver[21:22]
y_train_Denver21 = y_Denver[21:22]
X_train_Denver22 = X_Denver[22:23]
y_train_Denver22 = y_Denver[22:23]

X_train_DenverAll1 = df.iloc[[0,22,44,66,88,110,132,154,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],[5,11,18,19,20]]
y_train_DenverAll1 = df.iloc[[0,22,44,66,88,110,132,154,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],24:25]

X_train_DenverAll2 = df.iloc[[0,1,23 ,45 ,67,89,111, 133,155,199,221 ,243 ,265 ,287 ,309 ,331 ,353 ,375 ,397 ,419 ,441 ,463 ,485 ,507 ,529 ,551 ,573 ,595 ,617 ,639],[5,11,18,19,20]]
y_train_DenverAll2 = df.iloc[[1, 23 ,45,67,89, 111, 133,155,199,221 ,243 ,265 ,287 ,309 ,331 ,353 ,375 ,397 ,419 ,441 ,463 ,485 ,507 ,529 ,551 ,573 ,595 ,617 ,639],24:25]

X_train_DenverAll3 = df.iloc[[0,2,24,46,68,90,112 ,134 ,156 ,200 ,222 ,244 ,266 ,288 ,310 ,332 ,354 ,376 ,398 ,420 ,442 ,464 ,486 ,508 ,530 ,552 ,574 ,596 ,618 ,640],[5,11,18,19,20]]
y_train_DenverAll3 = df.iloc[[2,24,46,68,90,112 ,134,156 ,200 ,222 ,244 ,266 ,288 ,310 ,332 ,354 ,376 ,398 ,420 ,442 ,464 ,486 ,508 ,530 ,552 ,574 ,596 ,618 ,640],24:25]

X_train_DenverAll4 = df.iloc[[0,3,25,47,69,91,113,135,157 ,201 ,223 ,245 ,267 ,289 ,311 ,333 ,355 ,377 ,399 ,421 ,443 ,465 ,487 ,509 ,531 ,553 ,575 ,597 ,619 ,641],[5,11,18,19,20]]
y_train_DenverAll4 = df.iloc[[3,25,47,69,91,113,135,157 ,201 ,223 ,245 ,267 ,289 ,311 ,333 ,355 ,377 ,399 ,421 ,443 ,465 ,487 ,509 ,531 ,553 ,575 ,597 ,619 ,641],24:25]

X_train_DenverAll5 = df.iloc[[0,4,26,48,70,92, 114,136  ,158 ,202 ,224 ,246 ,268 ,290 ,312 ,334 ,356 ,378 ,400 ,422 ,444 ,466 ,488 ,510 ,532 ,554 ,576 ,598 ,620 ,642],[5,11,18,19,20]]
y_train_DenverAll5 = df.iloc[[4,26,48,70,92,114,136  ,158 ,202 ,224 ,246 ,268 ,290 ,312 ,334 ,356 ,378 ,400 ,422 ,444 ,466 ,488 ,510 ,532 ,554 ,576 ,598 ,620 ,642],24:25]

X_train_DenverAll6 = df.iloc[[0,5,27,49,71,93,115 ,137,159 ,203 ,225 ,247 ,269 ,291 ,313 ,335 ,357 ,379 ,401 ,423 ,445 ,467 ,489 ,511 ,533 ,555 ,577 ,599 ,621 ,643],[5,11,18,19,20]]
y_train_DenverAll6 = df.iloc[[5,27,49,71,93,115 ,137 ,159 ,203 ,225 ,247 ,269 ,291 ,313 ,335 ,357 ,379 ,401 ,423 ,445 ,467 ,489 ,511 ,533 ,555 ,577 ,599 ,621 ,643],24:25]

X_train_DenverAll7 = df.iloc[[0,6,28,50,72,94,116,138  ,160 ,204 ,226 ,248 ,270 ,292 ,314 ,336 ,358 ,380 ,402 ,424 ,446 ,468 ,490 ,512 ,534 ,556 ,578 ,600 ,622 ,644],[5,11,18,19,20]]
y_train_DenverAll7 = df.iloc[[6,28,50,72,94,116 ,138  ,160 ,204 ,226 ,248 ,270 ,292 ,314 ,336 ,358 ,380 ,402 ,424 ,446 ,468 ,490 ,512 ,534 ,556 ,578 ,600 ,622 ,644],24:25]

X_train_DenverAll8 = df.iloc[[0,7,29,51,73,95,117,139 ,161 ,205 ,227 ,249 ,271 ,293 ,315 ,337 ,359 ,381 ,403 ,425 ,447 ,469 ,491 ,513 ,535 ,557 ,579 ,601 ,623 ,645],[5,11,18,19,20]]
y_train_DenverAll8 = df.iloc[[7,29,51,73,95,117 ,139 ,161 ,205 ,227 ,249 ,271 ,293 ,315 ,337 ,359 ,381 ,403 ,425 ,447 ,469 ,491 ,513 ,535 ,557 ,579 ,601 ,623 ,645],24:25]

X_train_DenverAll9 = df.iloc[[0,8,30,52,74,96,118 ,140 ,162 ,206 ,228 ,250 ,272 ,294 ,316 ,338 ,360 ,382 ,404 ,426 ,448 ,470 ,492 ,514 ,536 ,558 ,580 ,602 ,624 ,646],[5,11,18,19,20]]
y_train_DenverAll9 = df.iloc[[8,30,52,74,96,118 ,140 ,162 ,206 ,228 ,250 ,272 ,294 ,316 ,338 ,360 ,382 ,404 ,426 ,448 ,470 ,492 ,514 ,536 ,558 ,580 ,602 ,624 ,646],24:25]

X_train_DenverAll10 = df.iloc[[0,9,31,53,75,97, 119,141 ,163 ,207 ,229 ,251 ,273 ,295 ,317 ,339 ,361 ,383 ,405 ,427 ,449 ,471 ,493 ,515 ,537 ,559 ,581 ,603 ,625 ,647],[5,11,18,19,20]]
y_train_DenverAll10 = df.iloc[[9,31,53,75,97, 119,141,163 ,207 ,229 ,251 ,273 ,295 ,317 ,339 ,361 ,383 ,405 ,427 ,449 ,471 ,493 ,515 ,537 ,559 ,581 ,603 ,625 ,647],24:25]

X_train_DenverAll11 = df.iloc[[0,10,32,54,76,98,120,142 ,164 ,208 ,230 ,252 ,274 ,296 ,318 ,340 ,362 ,384 ,406 ,428 ,450 ,472 ,494 ,516 ,538 ,560 ,582 ,604 ,626 ,648],[5,11,18,19,20]]
y_train_DenverAll11= df.iloc[[10,32,54,76,98,120 ,142,164 ,208 ,230 ,252 ,274 ,296 ,318 ,340 ,362 ,384 ,406 ,428 ,450 ,472 ,494 ,516 ,538 ,560 ,582 ,604 ,626 ,648],24:25]

X_train_DenverAll12 = df.iloc[[0,11,33,55,77,99,121 ,143 ,165 ,209 ,231 ,253 ,275 ,297 ,319 ,341 ,363 ,385 ,407 ,429 ,451 ,473 ,495 ,517 ,539 ,561 ,583 ,605 ,627 ,649],[5,11,18,19,20]]
y_train_DenverAll12 = df.iloc[[11,33,55,77,99,121 ,143,165 ,209 ,231 ,253 ,275 ,297 ,319 ,341 ,363 ,385 ,407 ,429 ,451 ,473 ,495 ,517 ,539 ,561 ,583 ,605 ,627 ,649],24:25]

X_train_DenverAll13 = df.iloc[[0,12,34,56,78, 100, 122, 144,166, 210, 232, 254, 276, 298, 320, 342, 364, 386, 408, 430, 452, 474, 496, 518, 540, 562, 584, 606, 628, 650],[5,11,18,19,20]]
y_train_DenverAll13 = df.iloc[[12,34,56,78, 100, 122, 144,166, 210, 232, 254, 276, 298, 320, 342, 364, 386, 408, 430, 452, 474, 496, 518, 540, 562, 584, 606, 628, 650],24:25]

X_train_DenverAll14 = df.iloc[[0,13,35,57,79, 101,123, 145,167, 211, 233, 255, 277, 299, 321, 343, 365, 387, 409, 431, 453, 475, 497, 519, 541, 563, 585, 607, 629, 651],[5,11,18,19,20]]
y_train_DenverAll14 = df.iloc[[13,35,57,79, 101,123, 145, 167, 211, 233, 255, 277, 299, 321, 343, 365, 387, 409, 431, 453, 475, 497, 519, 541, 563, 585, 607, 629, 651],24:25]

X_train_DenverAll15 = df.iloc[[0,14,36,58,80, 102,124, 146, 168, 212, 234, 256, 278, 300, 322, 344, 366, 388, 410, 432, 454, 476, 498, 520, 542, 564, 586, 608, 630, 652],[5,11,18,19,20]]
y_train_DenverAll15 = df.iloc[[14,36,58,80, 102,124, 146, 168, 212, 234, 256, 278, 300, 322, 344, 366, 388, 410, 432, 454, 476, 498, 520, 542, 564, 586, 608, 630, 652],24:25]

X_train_DenverAll16 = df.iloc[[0,15,37,59,81, 103,125, 147, 169, 213, 235, 257, 279, 301, 323, 345, 367, 389, 411, 433, 455, 477, 499, 521, 543, 565, 587, 609, 631, 653],[5,11,18,19,20]]
y_train_DenverAll16 = df.iloc[[15,37,59,81, 103,125,147,169, 213,235, 257, 279, 301, 323, 345, 367, 389, 411, 433, 455, 477, 499, 521, 543, 565, 587, 609, 631, 653],24:25]

X_train_DenverAll17 = df.iloc[[0,16,38,60,82, 104,126, 148, 170, 214, 236, 258, 280, 302, 324, 346, 368, 390, 412, 434, 456, 478, 500, 522, 544, 566, 588, 610, 632, 654],[5,11,18,19,20]]
y_train_DenverAll17 = df.iloc[[16,38,60,82, 104,126,148, 170, 214, 236, 258, 280, 302, 324, 346, 368, 390, 412, 434, 456, 478, 500, 522, 544, 566, 588, 610, 632, 654],24:25]

X_train_DenverAll18 = df.iloc[[0,17,39,61,83, 105,127, 149, 171, 215, 237, 259, 281, 303, 325, 347, 369, 391, 413, 435, 457, 479, 501, 523, 545, 567, 589, 611, 633, 655],[5,11,18,19,20]]
y_train_DenverAll18 = df.iloc[[17,39,61,83, 105,127, 149, 171, 215, 237, 259, 281, 303, 325, 347, 369, 391, 413, 435, 457, 479, 501, 523, 545, 567, 589, 611, 633, 655],24:25]

X_train_DenverAll19 = df.iloc[[0,18,40,62,84, 106,128, 150,172, 216, 238, 260, 282, 304, 326, 348, 370, 392, 414, 436, 458, 480, 502, 524, 546, 568, 590, 612, 634, 656],[5,11,18,19,20]]
y_train_DenverAll19 = df.iloc[[18,40,62,84, 106,128, 150,172, 216, 238, 260, 282, 304, 326, 348, 370, 392, 414, 436, 458, 480, 502, 524, 546, 568, 590, 612, 634, 656],24:25]

X_train_DenverAll20 = df.iloc[[0,19,41,63,85, 107,129, 151,173, 217, 239, 261, 283, 305, 327, 349, 371, 393, 415, 437, 459, 481, 503, 525, 547, 569, 591, 613, 635, 657],[5,11,18,19,20]]
y_train_DenverAll20 = df.iloc[[19,41,63,85, 107, 129, 151,173, 217, 239, 261, 283, 305, 327, 349, 371, 393, 415, 437, 459, 481, 503, 525, 547, 569, 591, 613, 635, 657],24:25]

X_train_DenverAll21 = df.iloc[[0,20,42,64,86, 108,130, 152,174, 218, 240, 262, 284, 306, 328, 350, 372, 394, 416, 438, 460, 482, 504, 526, 548, 570, 592, 614, 636, 658],[5,11,18,19,20]]
y_train_DenverAll21 = df.iloc[[20,42,64,86, 108,130, 152,174, 218, 240, 262, 284, 306, 328, 350, 372, 394, 416, 438, 460, 482, 504, 526, 548, 570, 592, 614, 636, 658],24:25]

X_train_DenverAll22 = df.iloc[[0,21,43,65,87, 109,131, 153,175, 219, 241, 263, 285, 307, 329, 351, 373, 395, 417, 439, 461, 483, 505, 527, 549, 571, 593, 615, 637, 659],[5,11,18,19,20]]
y_train_DenverAll22 = df.iloc[[21,43,65,87, 109,131, 153,175, 219, 241, 263, 285, 307, 329, 351, 373, 395, 417, 439, 461, 483, 505, 527, 549, 571, 593, 615, 637, 659],24:25]

# %%
regressorDenver1 = LinearRegression()
regressorDenver1.fit(X_train_DenverAll1, y_train_DenverAll1)
pd.DataFrame(list(zip(X_train_DenverAll1, regressorDenver1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_Denver1 = regressorDenver1.predict(X_train_Denver1)

# %%
y_train_DenverAll2.loc[-1] = y_pred_Denver1.item(0)  # adding a row
y_train_DenverAll2.index = y_train_DenverAll2.index + 1  # shifting index
y_train_DenverAll2 = y_train_DenverAll2.sort_index()
regressorDenver2 = LinearRegression()
regressorDenver2.fit(X_train_DenverAll2, y_train_DenverAll2)

pd.DataFrame(list(zip(X_train_DenverAll2, regressorDenver2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Denver2 = regressorDenver2.predict(X_train_Denver2)

y_train_DenverAll3.loc[-1] = y_pred_Denver2.item(0)  # adding a row
y_train_DenverAll3.index = y_train_DenverAll3.index + 1  # shifting index
y_train_DenverAll3 = y_train_DenverAll3.sort_index()
regressorDenver3 = LinearRegression()
regressorDenver3.fit(X_train_DenverAll3, y_train_DenverAll3)

pd.DataFrame(list(zip(X_train_DenverAll3, regressorDenver3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Denver3 = regressorDenver3.predict(X_train_Denver3)

y_train_DenverAll4.loc[-1] = y_pred_Denver3.item(0)  # adding a row
y_train_DenverAll4.index = y_train_DenverAll4.index + 1  # shifting index
y_train_DenverAll4 = y_train_DenverAll4.sort_index()
regressorDenver4 = LinearRegression()
regressorDenver4.fit(X_train_DenverAll4, y_train_DenverAll4)

pd.DataFrame(list(zip(X_train_DenverAll4, regressorDenver4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Denver4 = regressorDenver4.predict(X_train_Denver4)

y_train_DenverAll5.loc[-1] = y_pred_Denver4.item(0)  # adding a row
y_train_DenverAll5.index = y_train_DenverAll5.index + 1  # shifting index
y_train_DenverAll5 = y_train_DenverAll5.sort_index()
regressorDenver5 = LinearRegression()
regressorDenver5.fit(X_train_DenverAll5, y_train_DenverAll5)

pd.DataFrame(list(zip(X_train_DenverAll5, regressorDenver5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Denver5 = regressorDenver5.predict(X_train_Denver5)

y_train_DenverAll6.loc[-1] = y_pred_Denver5.item(0)  # adding a row
y_train_DenverAll6.index = y_train_DenverAll6.index + 1  # shifting index
y_train_DenverAll6 = y_train_DenverAll6.sort_index()
regressorDenver6 = LinearRegression()
regressorDenver6.fit(X_train_DenverAll6, y_train_DenverAll6)

pd.DataFrame(list(zip(X_train_DenverAll6, regressorDenver6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Denver6 = regressorDenver6.predict(X_train_Denver6)

y_train_DenverAll7.loc[-1] = y_pred_Denver6.item(0)  # adding a row
y_train_DenverAll7.index = y_train_DenverAll7.index + 1  # shifting index
y_train_DenverAll7 = y_train_DenverAll7.sort_index()
regressorDenver7 = LinearRegression()
regressorDenver7.fit(X_train_DenverAll7, y_train_DenverAll7)

pd.DataFrame(list(zip(X_train_DenverAll7, regressorDenver7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Denver7 = regressorDenver7.predict(X_train_Denver7)

y_train_DenverAll8.loc[-1] = y_pred_Denver7.item(0)  # adding a row
y_train_DenverAll8.index = y_train_DenverAll8.index + 1  # shifting index
y_train_DenverAll8 = y_train_DenverAll8.sort_index()
regressorDenver8 = LinearRegression()
regressorDenver8.fit(X_train_DenverAll8, y_train_DenverAll8)

pd.DataFrame(list(zip(X_train_DenverAll8, regressorDenver8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Denver8 = regressorDenver8.predict(X_train_Denver8)

y_train_DenverAll9.loc[-1] = y_pred_Denver8.item(0)  # adding a row
y_train_DenverAll9.index = y_train_DenverAll9.index + 1  # shifting index
y_train_DenverAll9 = y_train_DenverAll9.sort_index()
regressorDenver9 = LinearRegression()
regressorDenver9.fit(X_train_DenverAll9, y_train_DenverAll9)

pd.DataFrame(list(zip(X_train_DenverAll9, regressorDenver9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Denver9 = regressorDenver9.predict(X_train_Denver9)

y_train_DenverAll10.loc[-1] = y_pred_Denver9.item(0)  # adding a row
y_train_DenverAll10.index = y_train_DenverAll10.index + 1  # shifting index
y_train_DenverAll10 = y_train_DenverAll10.sort_index()
regressorDenver10 = LinearRegression()
regressorDenver10.fit(X_train_DenverAll10, y_train_DenverAll10)

pd.DataFrame(list(zip(X_train_DenverAll10, regressorDenver10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Denver10 = regressorDenver10.predict(X_train_Denver10)

y_train_DenverAll11.loc[-1] = y_pred_Denver10.item(0)  # adding a row
y_train_DenverAll11.index = y_train_DenverAll11.index + 1  # shifting index
y_train_DenverAll11 = y_train_DenverAll11.sort_index()
regressorDenver11 = LinearRegression()
regressorDenver11.fit(X_train_DenverAll11, y_train_DenverAll11)

pd.DataFrame(list(zip(X_train_DenverAll11, regressorDenver11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Denver11 = regressorDenver11.predict(X_train_Denver11)

y_train_DenverAll12.loc[-1] = y_pred_Denver11.item(0)  # adding a row
y_train_DenverAll12.index = y_train_DenverAll12.index + 1  # shifting index
y_train_DenverAll12 = y_train_DenverAll12.sort_index()
regressorDenver12 = LinearRegression()
regressorDenver12.fit(X_train_DenverAll12, y_train_DenverAll12)

pd.DataFrame(list(zip(X_train_DenverAll12, regressorDenver12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Denver12 = regressorDenver12.predict(X_train_Denver12)

y_train_DenverAll13.loc[-1] = y_pred_Denver12.item(0)  # adding a row
y_train_DenverAll13.index = y_train_DenverAll13.index + 1  # shifting index
y_train_DenverAll13 = y_train_DenverAll13.sort_index()
regressorDenver13 = LinearRegression()
regressorDenver13.fit(X_train_DenverAll13, y_train_DenverAll13)

pd.DataFrame(list(zip(X_train_DenverAll13, regressorDenver13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Denver13 = regressorDenver13.predict(X_train_Denver13)

y_train_DenverAll14.loc[-1] = y_pred_Denver13.item(0)  # adding a row
y_train_DenverAll14.index = y_train_DenverAll14.index + 1  # shifting index
y_train_DenverAll14 = y_train_DenverAll14.sort_index()
regressorDenver14 = LinearRegression()
regressorDenver14.fit(X_train_DenverAll14, y_train_DenverAll14)

pd.DataFrame(list(zip(X_train_DenverAll14, regressorDenver14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Denver14 = regressorDenver14.predict(X_train_Denver14)

y_train_DenverAll15.loc[-1] = y_pred_Denver14.item(0)  # adding a row
y_train_DenverAll15.index = y_train_DenverAll15.index + 1  # shifting index
y_train_DenverAll15 = y_train_DenverAll15.sort_index()
regressorDenver15 = LinearRegression()
regressorDenver15.fit(X_train_DenverAll15, y_train_DenverAll15)

pd.DataFrame(list(zip(X_train_DenverAll15, regressorDenver15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Denver15 = regressorDenver15.predict(X_train_Denver15)

y_train_DenverAll16.loc[-1] = y_pred_Denver15.item(0)  # adding a row
y_train_DenverAll16.index = y_train_DenverAll16.index + 1  # shifting index
y_train_DenverAll16 = y_train_DenverAll16.sort_index()
regressorDenver16 = LinearRegression()
regressorDenver16.fit(X_train_DenverAll16, y_train_DenverAll16)

pd.DataFrame(list(zip(X_train_DenverAll16, regressorDenver16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Denver16 = regressorDenver16.predict(X_train_Denver16)

y_train_DenverAll17.loc[-1] = y_pred_Denver16.item(0)  # adding a row
y_train_DenverAll17.index = y_train_DenverAll17.index + 1  # shifting index
y_train_DenverAll17 = y_train_DenverAll17.sort_index()
regressorDenver17 = LinearRegression()
regressorDenver17.fit(X_train_DenverAll17, y_train_DenverAll17)

pd.DataFrame(list(zip(X_train_DenverAll17, regressorDenver17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Denver17 = regressorDenver17.predict(X_train_Denver17)

y_train_DenverAll18.loc[-1] = y_pred_Denver17.item(0)  # adding a row
y_train_DenverAll18.index = y_train_DenverAll18.index + 1  # shifting index
y_train_DenverAll18 = y_train_DenverAll18.sort_index()
regressorDenver18 = LinearRegression()
regressorDenver18.fit(X_train_DenverAll18, y_train_DenverAll18)

pd.DataFrame(list(zip(X_train_DenverAll18, regressorDenver18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Denver18 = regressorDenver18.predict(X_train_Denver18)

y_train_DenverAll19.loc[-1] = y_pred_Denver18.item(0)  # adding a row
y_train_DenverAll19.index = y_train_DenverAll19.index + 1  # shifting index
y_train_DenverAll19 = y_train_DenverAll19.sort_index()
regressorDenver19 = LinearRegression()
regressorDenver19.fit(X_train_DenverAll19, y_train_DenverAll19)

pd.DataFrame(list(zip(X_train_DenverAll19, regressorDenver19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Denver19 = regressorDenver19.predict(X_train_Denver19)

y_train_DenverAll20.loc[-1] = y_pred_Denver19.item(0)  # adding a row
y_train_DenverAll20.index = y_train_DenverAll20.index + 1  # shifting index
y_train_DenverAll20 = y_train_DenverAll20.sort_index()
regressorDenver20 = LinearRegression()
regressorDenver20.fit(X_train_DenverAll20, y_train_DenverAll20)

pd.DataFrame(list(zip(X_train_DenverAll20, regressorDenver20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Denver20 = regressorDenver20.predict(X_train_Denver20)

y_train_DenverAll21.loc[-1] = y_pred_Denver20.item(0)  # adding a row
y_train_DenverAll21.index = y_train_DenverAll21.index + 1  # shifting index
y_train_DenverAll21 = y_train_DenverAll21.sort_index()
regressorDenver21 = LinearRegression()
regressorDenver21.fit(X_train_DenverAll21, y_train_DenverAll21)

pd.DataFrame(list(zip(X_train_DenverAll21, regressorDenver21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Denver21 = regressorDenver21.predict(X_train_Denver21)

# %%
X_train_LosAngelesClippers1= X_LosAngelesClippers[0:1]
y_train_LosAngelesClippers1= y_LosAngelesClippers[0:1]
X_train_LosAngelesClippers2= X_LosAngelesClippers[1:2]
y_train_LosAngelesClippers2= y_LosAngelesClippers[1:2]
X_train_LosAngelesClippers3= X_LosAngelesClippers[2:3]
y_train_LosAngelesClippers3= y_LosAngelesClippers[2:3]
X_train_LosAngelesClippers4= X_LosAngelesClippers[3:4]
y_train_LosAngelesClippers4= y_LosAngelesClippers[3:4]
X_train_LosAngelesClippers5= X_LosAngelesClippers[4:5]
y_train_LosAngelesClippers5= y_LosAngelesClippers[4:5]
y_train_LosAngelesClippers6= y_LosAngelesClippers[5:6]
X_train_LosAngelesClippers7= X_LosAngelesClippers[7:8]
X_train_LosAngelesClippers6= X_LosAngelesClippers[5:6]
y_train_LosAngelesClippers7= y_LosAngelesClippers[7:8]
X_train_LosAngelesClippers8= X_LosAngelesClippers[8:9]
y_train_LosAngelesClippers8= y_LosAngelesClippers[8:9]
X_train_LosAngelesClippers9= X_LosAngelesClippers[9:10]
y_train_LosAngelesClippers9= y_LosAngelesClippers[9:10]
X_train_LosAngelesClippers10 = X_LosAngelesClippers[10:11]
y_train_LosAngelesClippers10 = y_LosAngelesClippers[10:11]
X_train_LosAngelesClippers11 = X_LosAngelesClippers[11:12]
y_train_LosAngelesClippers11 = y_LosAngelesClippers[11:12]
X_train_LosAngelesClippers12 = X_LosAngelesClippers[12:13]
y_train_LosAngelesClippers12 = y_LosAngelesClippers[12:13]
X_train_LosAngelesClippers13 = X_LosAngelesClippers[13:14]
y_train_LosAngelesClippers13 = y_LosAngelesClippers[13:14]
X_train_LosAngelesClippers14 = X_LosAngelesClippers[14:15]
y_train_LosAngelesClippers14 = y_LosAngelesClippers[14:15]
X_train_LosAngelesClippers15 = X_LosAngelesClippers[15:16]
y_train_LosAngelesClippers15 = y_LosAngelesClippers[15:16]
X_train_LosAngelesClippers16 = X_LosAngelesClippers[16:17]
y_train_LosAngelesClippers16 = y_LosAngelesClippers[16:17]
X_train_LosAngelesClippers17 = X_LosAngelesClippers[17:18]
y_train_LosAngelesClippers17 = y_LosAngelesClippers[17:18]
X_train_LosAngelesClippers18 = X_LosAngelesClippers[18:19]
y_train_LosAngelesClippers18 = y_LosAngelesClippers[18:19]
X_train_LosAngelesClippers19 = X_LosAngelesClippers[19:20]
y_train_LosAngelesClippers19 = y_LosAngelesClippers[19:20]
X_train_LosAngelesClippers20 = X_LosAngelesClippers[20:21]
y_train_LosAngelesClippers20 = y_LosAngelesClippers[20:21]
X_train_LosAngelesClippers21 = X_LosAngelesClippers[21:22]
y_train_LosAngelesClippers21 = y_LosAngelesClippers[21:22]
X_train_LosAngelesClippers22 = X_LosAngelesClippers[22:23]
y_train_LosAngelesClippers22 = y_LosAngelesClippers[22:23]

X_train_LosAngelesClippersAll1 = df.iloc[[0,22,44,66,88,110,132,154,176,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],[5,11,18,19,20]]
y_train_LosAngelesClippersAll1 = df.iloc[[0,22,44,66,88,110,132,154,176,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],24:25]

X_train_LosAngelesClippersAll2 = df.iloc[[0,1,23 ,45 ,67,89,111, 133,155,177,221 ,243 ,265 ,287 ,309 ,331 ,353 ,375 ,397 ,419 ,441 ,463 ,485 ,507 ,529 ,551 ,573 ,595 ,617 ,639],[5,11,18,19,20]]
y_train_LosAngelesClippersAll2 = df.iloc[[1, 23 ,45,67,89, 111, 133,155,177,221 ,243 ,265 ,287 ,309 ,331 ,353 ,375 ,397 ,419 ,441 ,463 ,485 ,507 ,529 ,551 ,573 ,595 ,617 ,639],24:25]

X_train_LosAngelesClippersAll3 = df.iloc[[0,2,24,46,68,90,112 ,134 ,156,178 ,222 ,244 ,266 ,288 ,310 ,332 ,354 ,376 ,398 ,420 ,442 ,464 ,486 ,508 ,530 ,552 ,574 ,596 ,618 ,640],[5,11,18,19,20]]
y_train_LosAngelesClippersAll3 = df.iloc[[2,24,46,68,90,112 ,134,156,178,222 ,244 ,266 ,288 ,310 ,332 ,354 ,376 ,398 ,420 ,442 ,464 ,486 ,508 ,530 ,552 ,574 ,596 ,618 ,640],24:25]

X_train_LosAngelesClippersAll4 = df.iloc[[0,3,25,47,69,91,113,135,157,179,223 ,245 ,267 ,289 ,311 ,333 ,355 ,377 ,399 ,421 ,443 ,465 ,487 ,509 ,531 ,553 ,575 ,597 ,619 ,641],[5,11,18,19,20]]
y_train_LosAngelesClippersAll4 = df.iloc[[3,25,47,69,91,113,135,158,179,223 ,245 ,267 ,289 ,311 ,333 ,355 ,377 ,399 ,421 ,443 ,465 ,487 ,509 ,531 ,553 ,575 ,597 ,619 ,641],24:25]

X_train_LosAngelesClippersAll5 = df.iloc[[0,4,26,48,70,92,114,136,158 ,180,224 ,246 ,268 ,290 ,312 ,334 ,356 ,378 ,400 ,422 ,444 ,466 ,488 ,510 ,532 ,554 ,576 ,598 ,620 ,642],[5,11,18,19,20]]
y_train_LosAngelesClippersAll5 = df.iloc[[4,26,48,70,92,114,136,158,180,224 ,246 ,268 ,290 ,312 ,334 ,356 ,378 ,400 ,422 ,444 ,466 ,488 ,510 ,532 ,554 ,576 ,598 ,620 ,642],24:25]

X_train_LosAngelesClippersAll6 = df.iloc[[0,5,27,49,71,93,115 ,137,159,181,225 ,247 ,269 ,291 ,313 ,335 ,357 ,379 ,401 ,423 ,445 ,467 ,489 ,511 ,533 ,555 ,577 ,599 ,621 ,643],[5,11,18,19,20]]
y_train_LosAngelesClippersAll6 = df.iloc[[5,27,49,71,93,115 ,137,159,181,225 ,247 ,269 ,291 ,313 ,335 ,357 ,379 ,401 ,423 ,445 ,467 ,489 ,511 ,533 ,555 ,577 ,599 ,621 ,643],24:25]

X_train_LosAngelesClippersAll7 = df.iloc[[0,6,28,50,72,94,116,138,160,182,226 ,248 ,270 ,292 ,314 ,336 ,358 ,380 ,402 ,424 ,446 ,468 ,490 ,512 ,534 ,556 ,578 ,600 ,622 ,644],[5,11,18,19,20]]
y_train_LosAngelesClippersAll7 = df.iloc[[6,28,50,72,94,116 ,138,160,182,226 ,248 ,270 ,292 ,314 ,336 ,358 ,380 ,402 ,424 ,446 ,468 ,490 ,512 ,534 ,556 ,578 ,600 ,622 ,644],24:25]

X_train_LosAngelesClippersAll8 = df.iloc[[0,7,29,51,73,95,117,139,161 ,183,227 ,249 ,271 ,293 ,315 ,337 ,359 ,381 ,403 ,425 ,447 ,469 ,491 ,513 ,535 ,557 ,579 ,601 ,623 ,645],[5,11,18,19,20]]
y_train_LosAngelesClippersAll8 = df.iloc[[7,29,51,73,95,117 ,139,161 ,183,227 ,249 ,271 ,293 ,315 ,337 ,359 ,381 ,403 ,425 ,447 ,469 ,491 ,513 ,535 ,557 ,579 ,601 ,623 ,645],24:25]

X_train_LosAngelesClippersAll9 = df.iloc[[0,8,30,52,74,96,118 ,140,162 ,184,228 ,250 ,272 ,294 ,316 ,338 ,360 ,382 ,404 ,426 ,448 ,470 ,492 ,514 ,536 ,558 ,580 ,602 ,624 ,646],[5,11,18,19,20]]
y_train_LosAngelesClippersAll9 = df.iloc[[8,30,52,74,96,118 ,140,162 ,184,228 ,250 ,272 ,294 ,316 ,338 ,360 ,382 ,404 ,426 ,448 ,470 ,492 ,514 ,536 ,558 ,580 ,602 ,624 ,646],24:25]

X_train_LosAngelesClippersAll10 = df.iloc[[0,9,31,53,75,97, 119,141,163 ,185 ,229 ,251 ,273 ,295 ,317 ,339 ,361 ,383 ,405 ,427 ,449 ,471 ,493 ,515 ,537 ,559 ,581 ,603 ,625 ,647],[5,11,18,19,20]]
y_train_LosAngelesClippersAll10 = df.iloc[[9,31,53,75,97, 119,141,163,185 ,229 ,251 ,273 ,295 ,317 ,339 ,361 ,383 ,405 ,427 ,449 ,471 ,493 ,515 ,537 ,559 ,581 ,603 ,625 ,647],24:25]

X_train_LosAngelesClippersAll11 = df.iloc[[0,10,32,54,76,98,120,142,164 ,186 ,230 ,252 ,274 ,296 ,318 ,340 ,362 ,384 ,406 ,428 ,450 ,472 ,494 ,516 ,538 ,560 ,582 ,604 ,626 ,648],[5,11,18,19,20]]
y_train_LosAngelesClippersAll11= df.iloc[[10,32,54,76,98,120 ,142,164,186 ,230 ,252 ,274 ,296 ,318 ,340 ,362 ,384 ,406 ,428 ,450 ,472 ,494 ,516 ,538 ,560 ,582 ,604 ,626 ,648],24:25]

X_train_LosAngelesClippersAll12 = df.iloc[[0,11,33,55,77,99,121 ,143,165,187 ,231 ,253 ,275 ,297 ,319 ,341 ,363 ,385 ,407 ,429 ,451 ,473 ,495 ,517 ,539 ,561 ,583 ,605 ,627 ,649],[5,11,18,19,20]]
y_train_LosAngelesClippersAll12 = df.iloc[[11,33,55,77,99,121 ,143,165,187 ,231 ,253 ,275 ,297 ,319 ,341 ,363 ,385 ,407 ,429 ,451 ,473 ,495 ,517 ,539 ,561 ,583 ,605 ,627 ,649],24:25]

X_train_LosAngelesClippersAll13 = df.iloc[[0,12,34,56,78, 100, 122, 144,166,188, 232, 254, 276, 298, 320, 342, 364, 386, 408, 430, 452, 474, 496, 518, 540, 562, 584, 606, 628, 650],[5,11,18,19,20]]
y_train_LosAngelesClippersAll13 = df.iloc[[12,34,56,78, 100, 122, 144,166, 188, 232, 254, 276, 298, 320, 342, 364, 386, 408, 430, 452, 474, 496, 518, 540, 562, 584, 606, 628, 650],24:25]

X_train_LosAngelesClippersAll14 = df.iloc[[0,13,35,57,79, 101,123, 145,167,189, 233, 255, 277, 299, 321, 343, 365, 387, 409, 431, 453, 475, 497, 519, 541, 563, 585, 607, 629, 651],[5,11,18,19,20]]
y_train_LosAngelesClippersAll14 = df.iloc[[13,35,57,79, 101,123, 145,167,189, 233, 255, 277, 299, 321, 343, 365, 387, 409, 431, 453, 475, 497, 519, 541, 563, 585, 607, 629, 651],24:25]

X_train_LosAngelesClippersAll15 = df.iloc[[0,14,36,58,80, 102,124, 146,168,190, 234, 256, 278, 300, 322, 344, 366, 388, 410, 432, 454, 476, 498, 520, 542, 564, 586, 608, 630, 652],[5,11,18,19,20]]
y_train_LosAngelesClippersAll15 = df.iloc[[14,36,58,80, 102,124, 146,168, 190, 234, 256, 278, 300, 322, 344, 366, 388, 410, 432, 454, 476, 498, 520, 542, 564, 586, 608, 630, 652],24:25]

X_train_LosAngelesClippersAll16 = df.iloc[[0,15,37,59,81, 103,125, 147, 169,191, 235, 257, 279, 301, 323, 345, 367, 389, 411, 433, 455, 477, 499, 521, 543, 565, 587, 609, 631, 653],[5,11,18,19,20]]
y_train_LosAngelesClippersAll16 = df.iloc[[15,37,59,81, 103,125,147,169,191, 235, 257, 279, 301, 323, 345, 367, 389, 411, 433, 455, 477, 499, 521, 543, 565, 587, 609, 631, 653],24:25]

X_train_LosAngelesClippersAll17 = df.iloc[[0,16,38,60,82, 104,126, 148, 170,192, 236, 258, 280, 302, 324, 346, 368, 390, 412, 434, 456, 478, 500, 522, 544, 566, 588, 610, 632, 654],[5,11,18,19,20]]
y_train_LosAngelesClippersAll17 = df.iloc[[16,38,60,82, 104,126,148, 170,192, 236, 258, 280, 302, 324, 346, 368, 390, 412, 434, 456, 478, 500, 522, 544, 566, 588, 610, 632, 654],24:25]

X_train_LosAngelesClippersAll18 = df.iloc[[0,17,39,61,83, 105,127, 149, 171,193, 237, 259, 281, 303, 325, 347, 369, 391, 413, 435, 457, 479, 501, 523, 545, 567, 589, 611, 633, 655],[5,11,18,19,20]]
y_train_LosAngelesClippersAll18 = df.iloc[[17,39,61,83, 105,127, 149, 171,193, 237, 259, 281, 303, 325, 347, 369, 391, 413, 435, 457, 479, 501, 523, 545, 567, 589, 611, 633, 655],24:25]

X_train_LosAngelesClippersAll19 = df.iloc[[0,18,40,62,84, 106,128, 150, 172,194, 238, 260, 282, 304, 326, 348, 370, 392, 414, 436, 458, 480, 502, 524, 546, 568, 590, 612, 634, 656],[5,11,18,19,20]]
y_train_LosAngelesClippersAll19 = df.iloc[[18,40,62,84, 106,128, 150, 172,194, 238, 260, 282, 304, 326, 348, 370, 392, 414, 436, 458, 480, 502, 524, 546, 568, 590, 612, 634, 656],24:25]

X_train_LosAngelesClippersAll20 = df.iloc[[0,19,41,63,85, 107,129, 151,173,195, 239, 261, 283, 305, 327, 349, 371, 393, 415, 437, 459, 481, 503, 525, 547, 569, 591, 613, 635, 657],[5,11,18,19,20]]
y_train_LosAngelesClippersAll20 = df.iloc[[19,41,63,85, 107, 129, 151,173, 195, 239, 261, 283, 305, 327, 349, 371, 393, 415, 437, 459, 481, 503, 525, 547, 569, 591, 613, 635, 657],24:25]

X_train_LosAngelesClippersAll21 = df.iloc[[0,20,42,64,86, 108,130, 152,174,196, 240, 262, 284, 306, 328, 350, 372, 394, 416, 438, 460, 482, 504, 526, 548, 570, 592, 614, 636, 658],[5,11,18,19,20]]
y_train_LosAngelesClippersAll21 = df.iloc[[20,42,64,86, 108,130, 152,174, 196, 240, 262, 284, 306, 328, 350, 372, 394, 416, 438, 460, 482, 504, 526, 548, 570, 592, 614, 636, 658],24:25]

X_train_LosAngelesClippersAll22 = df.iloc[[0,21,43,65,87, 109,131, 153, 175,197, 241, 263, 285, 307, 329, 351, 373, 395, 417, 439, 461, 483, 505, 527, 549, 571, 593, 615, 637, 659],[5,11,18,19,20]]
y_train_LosAngelesClippersAll22 = df.iloc[[21,43,65,87, 109,131, 153, 175,197, 241, 263, 285, 307, 329, 351, 373, 395, 417, 439, 461, 483, 505, 527, 549, 571, 593, 615, 637, 659],24:25]

# %%
regressorLosAngelesClippers1 = LinearRegression()
regressorLosAngelesClippers1.fit(X_train_LosAngelesClippersAll1, y_train_LosAngelesClippersAll1)
pd.DataFrame(list(zip(X_train_LosAngelesClippersAll1, regressorLosAngelesClippers1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_LosAngelesClippers1 = regressorLosAngelesClippers1.predict(X_train_LosAngelesClippers1)

# %%
y_train_LosAngelesClippersAll2.loc[-1] = y_pred_LosAngelesClippers1.item(0)  # adding a row
y_train_LosAngelesClippersAll2.index = y_train_LosAngelesClippersAll2.index + 1  # shifting index
y_train_LosAngelesClippersAll2 = y_train_LosAngelesClippersAll2.sort_index()
regressorLosAngelesClippers2 = LinearRegression()
regressorLosAngelesClippers2.fit(X_train_LosAngelesClippersAll2, y_train_LosAngelesClippersAll2)

pd.DataFrame(list(zip(X_train_LosAngelesClippersAll2, regressorLosAngelesClippers2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesClippers2 = regressorLosAngelesClippers2.predict(X_train_LosAngelesClippers2)

y_train_LosAngelesClippersAll3.loc[-1] = y_pred_LosAngelesClippers2.item(0)  # adding a row
y_train_LosAngelesClippersAll3.index = y_train_LosAngelesClippersAll3.index + 1  # shifting index
y_train_LosAngelesClippersAll3 = y_train_LosAngelesClippersAll3.sort_index()
regressorLosAngelesClippers3 = LinearRegression()
regressorLosAngelesClippers3.fit(X_train_LosAngelesClippersAll3, y_train_LosAngelesClippersAll3)

pd.DataFrame(list(zip(X_train_LosAngelesClippersAll3, regressorLosAngelesClippers3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesClippers3 = regressorLosAngelesClippers3.predict(X_train_LosAngelesClippers3)

y_train_LosAngelesClippersAll4.loc[-1] = y_pred_LosAngelesClippers3.item(0)  # adding a row
y_train_LosAngelesClippersAll4.index = y_train_LosAngelesClippersAll4.index + 1  # shifting index
y_train_LosAngelesClippersAll4 = y_train_LosAngelesClippersAll4.sort_index()
regressorLosAngelesClippers4 = LinearRegression()
regressorLosAngelesClippers4.fit(X_train_LosAngelesClippersAll4, y_train_LosAngelesClippersAll4)

pd.DataFrame(list(zip(X_train_LosAngelesClippersAll4, regressorLosAngelesClippers4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesClippers4 = regressorLosAngelesClippers4.predict(X_train_LosAngelesClippers4)

y_train_LosAngelesClippersAll5.loc[-1] = y_pred_LosAngelesClippers4.item(0)  # adding a row
y_train_LosAngelesClippersAll5.index = y_train_LosAngelesClippersAll5.index + 1  # shifting index
y_train_LosAngelesClippersAll5 = y_train_LosAngelesClippersAll5.sort_index()
regressorLosAngelesClippers5 = LinearRegression()
regressorLosAngelesClippers5.fit(X_train_LosAngelesClippersAll5, y_train_LosAngelesClippersAll5)

pd.DataFrame(list(zip(X_train_LosAngelesClippersAll5, regressorLosAngelesClippers5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesClippers5 = regressorLosAngelesClippers5.predict(X_train_LosAngelesClippers5)

y_train_LosAngelesClippersAll6.loc[-1] = y_pred_LosAngelesClippers5.item(0)  # adding a row
y_train_LosAngelesClippersAll6.index = y_train_LosAngelesClippersAll6.index + 1  # shifting index
y_train_LosAngelesClippersAll6 = y_train_LosAngelesClippersAll6.sort_index()
regressorLosAngelesClippers6 = LinearRegression()
regressorLosAngelesClippers6.fit(X_train_LosAngelesClippersAll6, y_train_LosAngelesClippersAll6)

pd.DataFrame(list(zip(X_train_LosAngelesClippersAll6, regressorLosAngelesClippers6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesClippers6 = regressorLosAngelesClippers6.predict(X_train_LosAngelesClippers6)

y_train_LosAngelesClippersAll7.loc[-1] = y_pred_LosAngelesClippers6.item(0)  # adding a row
y_train_LosAngelesClippersAll7.index = y_train_LosAngelesClippersAll7.index + 1  # shifting index
y_train_LosAngelesClippersAll7 = y_train_LosAngelesClippersAll7.sort_index()
regressorLosAngelesClippers7 = LinearRegression()
regressorLosAngelesClippers7.fit(X_train_LosAngelesClippersAll7, y_train_LosAngelesClippersAll7)

pd.DataFrame(list(zip(X_train_LosAngelesClippersAll7, regressorLosAngelesClippers7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesClippers7 = regressorLosAngelesClippers7.predict(X_train_LosAngelesClippers7)

y_train_LosAngelesClippersAll8.loc[-1] = y_pred_LosAngelesClippers7.item(0)  # adding a row
y_train_LosAngelesClippersAll8.index = y_train_LosAngelesClippersAll8.index + 1  # shifting index
y_train_LosAngelesClippersAll8 = y_train_LosAngelesClippersAll8.sort_index()
regressorLosAngelesClippers8 = LinearRegression()
regressorLosAngelesClippers8.fit(X_train_LosAngelesClippersAll8, y_train_LosAngelesClippersAll8)

pd.DataFrame(list(zip(X_train_LosAngelesClippersAll8, regressorLosAngelesClippers8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesClippers8 = regressorLosAngelesClippers8.predict(X_train_LosAngelesClippers8)

y_train_LosAngelesClippersAll9.loc[-1] = y_pred_LosAngelesClippers8.item(0)  # adding a row
y_train_LosAngelesClippersAll9.index = y_train_LosAngelesClippersAll9.index + 1  # shifting index
y_train_LosAngelesClippersAll9 = y_train_LosAngelesClippersAll9.sort_index()
regressorLosAngelesClippers9 = LinearRegression()
regressorLosAngelesClippers9.fit(X_train_LosAngelesClippersAll9, y_train_LosAngelesClippersAll9)

pd.DataFrame(list(zip(X_train_LosAngelesClippersAll9, regressorLosAngelesClippers9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesClippers9 = regressorLosAngelesClippers9.predict(X_train_LosAngelesClippers9)

y_train_LosAngelesClippersAll10.loc[-1] = y_pred_LosAngelesClippers9.item(0)  # adding a row
y_train_LosAngelesClippersAll10.index = y_train_LosAngelesClippersAll10.index + 1  # shifting index
y_train_LosAngelesClippersAll10 = y_train_LosAngelesClippersAll10.sort_index()
regressorLosAngelesClippers10 = LinearRegression()
regressorLosAngelesClippers10.fit(X_train_LosAngelesClippersAll10, y_train_LosAngelesClippersAll10)

pd.DataFrame(list(zip(X_train_LosAngelesClippersAll10, regressorLosAngelesClippers10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesClippers10 = regressorLosAngelesClippers10.predict(X_train_LosAngelesClippers10)

y_train_LosAngelesClippersAll11.loc[-1] = y_pred_LosAngelesClippers10.item(0)  # adding a row
y_train_LosAngelesClippersAll11.index = y_train_LosAngelesClippersAll11.index + 1  # shifting index
y_train_LosAngelesClippersAll11 = y_train_LosAngelesClippersAll11.sort_index()
regressorLosAngelesClippers11 = LinearRegression()
regressorLosAngelesClippers11.fit(X_train_LosAngelesClippersAll11, y_train_LosAngelesClippersAll11)

pd.DataFrame(list(zip(X_train_LosAngelesClippersAll11, regressorLosAngelesClippers11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesClippers11 = regressorLosAngelesClippers11.predict(X_train_LosAngelesClippers11)

y_train_LosAngelesClippersAll12.loc[-1] = y_pred_LosAngelesClippers11.item(0)  # adding a row
y_train_LosAngelesClippersAll12.index = y_train_LosAngelesClippersAll12.index + 1  # shifting index
y_train_LosAngelesClippersAll12 = y_train_LosAngelesClippersAll12.sort_index()
regressorLosAngelesClippers12 = LinearRegression()
regressorLosAngelesClippers12.fit(X_train_LosAngelesClippersAll12, y_train_LosAngelesClippersAll12)

pd.DataFrame(list(zip(X_train_LosAngelesClippersAll12, regressorLosAngelesClippers12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesClippers12 = regressorLosAngelesClippers12.predict(X_train_LosAngelesClippers12)

y_train_LosAngelesClippersAll13.loc[-1] = y_pred_LosAngelesClippers12.item(0)  # adding a row
y_train_LosAngelesClippersAll13.index = y_train_LosAngelesClippersAll13.index + 1  # shifting index
y_train_LosAngelesClippersAll13 = y_train_LosAngelesClippersAll13.sort_index()
regressorLosAngelesClippers13 = LinearRegression()
regressorLosAngelesClippers13.fit(X_train_LosAngelesClippersAll13, y_train_LosAngelesClippersAll13)

pd.DataFrame(list(zip(X_train_LosAngelesClippersAll13, regressorLosAngelesClippers13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesClippers13 = regressorLosAngelesClippers13.predict(X_train_LosAngelesClippers13)

y_train_LosAngelesClippersAll14.loc[-1] = y_pred_LosAngelesClippers13.item(0)  # adding a row
y_train_LosAngelesClippersAll14.index = y_train_LosAngelesClippersAll14.index + 1  # shifting index
y_train_LosAngelesClippersAll14 = y_train_LosAngelesClippersAll14.sort_index()
regressorLosAngelesClippers14 = LinearRegression()
regressorLosAngelesClippers14.fit(X_train_LosAngelesClippersAll14, y_train_LosAngelesClippersAll14)

pd.DataFrame(list(zip(X_train_LosAngelesClippersAll14, regressorLosAngelesClippers14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesClippers14 = regressorLosAngelesClippers14.predict(X_train_LosAngelesClippers14)

y_train_LosAngelesClippersAll15.loc[-1] = y_pred_LosAngelesClippers14.item(0)  # adding a row
y_train_LosAngelesClippersAll15.index = y_train_LosAngelesClippersAll15.index + 1  # shifting index
y_train_LosAngelesClippersAll15 = y_train_LosAngelesClippersAll15.sort_index()
regressorLosAngelesClippers15 = LinearRegression()
regressorLosAngelesClippers15.fit(X_train_LosAngelesClippersAll15, y_train_LosAngelesClippersAll15)

pd.DataFrame(list(zip(X_train_LosAngelesClippersAll15, regressorLosAngelesClippers15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesClippers15 = regressorLosAngelesClippers15.predict(X_train_LosAngelesClippers15)

y_train_LosAngelesClippersAll16.loc[-1] = y_pred_LosAngelesClippers15.item(0)  # adding a row
y_train_LosAngelesClippersAll16.index = y_train_LosAngelesClippersAll16.index + 1  # shifting index
y_train_LosAngelesClippersAll16 = y_train_LosAngelesClippersAll16.sort_index()
regressorLosAngelesClippers16 = LinearRegression()
regressorLosAngelesClippers16.fit(X_train_LosAngelesClippersAll16, y_train_LosAngelesClippersAll16)

pd.DataFrame(list(zip(X_train_LosAngelesClippersAll16, regressorLosAngelesClippers16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesClippers16 = regressorLosAngelesClippers16.predict(X_train_LosAngelesClippers16)

y_train_LosAngelesClippersAll17.loc[-1] = y_pred_LosAngelesClippers16.item(0)  # adding a row
y_train_LosAngelesClippersAll17.index = y_train_LosAngelesClippersAll17.index + 1  # shifting index
y_train_LosAngelesClippersAll17 = y_train_LosAngelesClippersAll17.sort_index()
regressorLosAngelesClippers17 = LinearRegression()
regressorLosAngelesClippers17.fit(X_train_LosAngelesClippersAll17, y_train_LosAngelesClippersAll17)

pd.DataFrame(list(zip(X_train_LosAngelesClippersAll17, regressorLosAngelesClippers17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesClippers17 = regressorLosAngelesClippers17.predict(X_train_LosAngelesClippers17)

y_train_LosAngelesClippersAll18.loc[-1] = y_pred_LosAngelesClippers17.item(0)  # adding a row
y_train_LosAngelesClippersAll18.index = y_train_LosAngelesClippersAll18.index + 1  # shifting index
y_train_LosAngelesClippersAll18 = y_train_LosAngelesClippersAll18.sort_index()
regressorLosAngelesClippers18 = LinearRegression()
regressorLosAngelesClippers18.fit(X_train_LosAngelesClippersAll18, y_train_LosAngelesClippersAll18)

pd.DataFrame(list(zip(X_train_LosAngelesClippersAll18, regressorLosAngelesClippers18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesClippers18 = regressorLosAngelesClippers18.predict(X_train_LosAngelesClippers18)

y_train_LosAngelesClippersAll19.loc[-1] = y_pred_LosAngelesClippers18.item(0)  # adding a row
y_train_LosAngelesClippersAll19.index = y_train_LosAngelesClippersAll19.index + 1  # shifting index
y_train_LosAngelesClippersAll19 = y_train_LosAngelesClippersAll19.sort_index()
regressorLosAngelesClippers19 = LinearRegression()
regressorLosAngelesClippers19.fit(X_train_LosAngelesClippersAll19, y_train_LosAngelesClippersAll19)

pd.DataFrame(list(zip(X_train_LosAngelesClippersAll19, regressorLosAngelesClippers19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesClippers19 = regressorLosAngelesClippers19.predict(X_train_LosAngelesClippers19)

y_train_LosAngelesClippersAll20.loc[-1] = y_pred_LosAngelesClippers19.item(0)  # adding a row
y_train_LosAngelesClippersAll20.index = y_train_LosAngelesClippersAll20.index + 1  # shifting index
y_train_LosAngelesClippersAll20 = y_train_LosAngelesClippersAll20.sort_index()
regressorLosAngelesClippers20 = LinearRegression()
regressorLosAngelesClippers20.fit(X_train_LosAngelesClippersAll20, y_train_LosAngelesClippersAll20)

pd.DataFrame(list(zip(X_train_LosAngelesClippersAll20, regressorLosAngelesClippers20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesClippers20 = regressorLosAngelesClippers20.predict(X_train_LosAngelesClippers20)

y_train_LosAngelesClippersAll21.loc[-1] = y_pred_LosAngelesClippers20.item(0)  # adding a row
y_train_LosAngelesClippersAll21.index = y_train_LosAngelesClippersAll21.index + 1  # shifting index
y_train_LosAngelesClippersAll21 = y_train_LosAngelesClippersAll21.sort_index()
regressorLosAngelesClippers21 = LinearRegression()
regressorLosAngelesClippers21.fit(X_train_LosAngelesClippersAll21, y_train_LosAngelesClippersAll21)

pd.DataFrame(list(zip(X_train_LosAngelesClippersAll21, regressorLosAngelesClippers21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesClippers21 = regressorLosAngelesClippers21.predict(X_train_LosAngelesClippers21)

# %%
X_train_Toronto1= X_Toronto[0:1]
y_train_Toronto1= y_Toronto[0:1]
X_train_Toronto2= X_Toronto[1:2]
y_train_Toronto2= y_Toronto[1:2]
X_train_Toronto3= X_Toronto[2:3]
y_train_Toronto3= y_Toronto[2:3]
X_train_Toronto4= X_Toronto[3:4]
y_train_Toronto4= y_Toronto[3:4]
X_train_Toronto5= X_Toronto[4:5]
y_train_Toronto5= y_Toronto[4:5]
y_train_Toronto6= y_Toronto[5:6]
X_train_Toronto7= X_Toronto[7:8]
X_train_Toronto6= X_Toronto[5:6]
y_train_Toronto7= y_Toronto[7:8]
X_train_Toronto8= X_Toronto[8:9]
y_train_Toronto8= y_Toronto[8:9]
X_train_Toronto9= X_Toronto[9:10]
y_train_Toronto9= y_Toronto[9:10]
X_train_Toronto10 = X_Toronto[10:11]
y_train_Toronto10 = y_Toronto[10:11]
X_train_Toronto11 = X_Toronto[11:12]
y_train_Toronto11 = y_Toronto[11:12]
X_train_Toronto12 = X_Toronto[12:13]
y_train_Toronto12 = y_Toronto[12:13]
X_train_Toronto13 = X_Toronto[13:14]
y_train_Toronto13 = y_Toronto[13:14]
X_train_Toronto14 = X_Toronto[14:15]
y_train_Toronto14 = y_Toronto[14:15]
X_train_Toronto15 = X_Toronto[15:16]
y_train_Toronto15 = y_Toronto[15:16]
X_train_Toronto16 = X_Toronto[16:17]
y_train_Toronto16 = y_Toronto[16:17]
X_train_Toronto17 = X_Toronto[17:18]
y_train_Toronto17 = y_Toronto[17:18]
X_train_Toronto18 = X_Toronto[18:19]
y_train_Toronto18 = y_Toronto[18:19]
X_train_Toronto19 = X_Toronto[19:20]
y_train_Toronto19 = y_Toronto[19:20]
X_train_Toronto20 = X_Toronto[20:21]
y_train_Toronto20 = y_Toronto[20:21]
X_train_Toronto21 = X_Toronto[21:22]
y_train_Toronto21 = y_Toronto[21:22]
X_train_Toronto22 = X_Toronto[22:23]
y_train_Toronto22 = y_Toronto[22:23]

X_train_TorontoAll1 = df.iloc[[0,22,44,66,88,110,132,154,176,198,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],[5,11,18,19,20]]
y_train_TorontoAll1 = df.iloc[[0,22,44,66,88,110,132,154,176,198,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],24:25]

X_train_TorontoAll2 = df.iloc[[0,1,23 ,45 ,67,89,111, 133,155,177,199 ,243 ,265 ,287 ,309 ,331 ,353 ,375 ,397 ,419 ,441 ,463 ,485 ,507 ,529 ,551 ,573 ,595 ,617 ,639],[5,11,18,19,20]]
y_train_TorontoAll2 = df.iloc[[1, 23 ,45,67,89, 111, 133,155,177,199,243 ,265 ,287 ,309 ,331 ,353 ,375 ,397 ,419 ,441 ,463 ,485 ,507 ,529 ,551 ,573 ,595 ,617 ,639],24:25]

X_train_TorontoAll3 = df.iloc[[0,2,24,46,68,90,112 ,134 ,156,178 ,200 ,244 ,266 ,288 ,310 ,332 ,354 ,376 ,398 ,420 ,442 ,464 ,486 ,508 ,530 ,552 ,574 ,596 ,618 ,640],[5,11,18,19,20]]
y_train_TorontoAll3 = df.iloc[[2,24,46,68,90,112 ,134,156,178,200 ,244 ,266 ,288 ,310 ,332 ,354 ,376 ,398 ,420 ,442 ,464 ,486 ,508 ,530 ,552 ,574 ,596 ,618 ,640],24:25]

X_train_TorontoAll4 = df.iloc[[0,3,25,47,69,91,113,135,157,179,201 ,245 ,267 ,289 ,311 ,333 ,355 ,377 ,399 ,421 ,443 ,465 ,487 ,509 ,531 ,553 ,575 ,597 ,619 ,641],[5,11,18,19,20]]
y_train_TorontoAll4 = df.iloc[[3,25,47,69,91,113,135,158,179,201 ,245 ,267 ,289 ,311 ,333 ,355 ,377 ,399 ,421 ,443 ,465 ,487 ,509 ,531 ,553 ,575 ,597 ,619 ,641],24:25]

X_train_TorontoAll5 = df.iloc[[0,4,26,48,70,92,114,136,158 ,180,202 ,246 ,268 ,290 ,312 ,334 ,356 ,378 ,400 ,422 ,444 ,466 ,488 ,510 ,532 ,554 ,576 ,598 ,620 ,642],[5,11,18,19,20]]
y_train_TorontoAll5 = df.iloc[[4,26,48,70,92,114,136,158,180,202 ,246 ,268 ,290 ,312 ,334 ,356 ,378 ,400 ,422 ,444 ,466 ,488 ,510 ,532 ,554 ,576 ,598 ,620 ,642],24:25]

X_train_TorontoAll6 = df.iloc[[0,5,27,49,71,93,115 ,137,159,181,203 ,247 ,269 ,291 ,313 ,335 ,357 ,379 ,401 ,423 ,445 ,467 ,489 ,511 ,533 ,555 ,577 ,599 ,621 ,643],[5,11,18,19,20]]
y_train_TorontoAll6 = df.iloc[[5,27,49,71,93,115 ,137,159,181,203 ,247 ,269 ,291 ,313 ,335 ,357 ,379 ,401 ,423 ,445 ,467 ,489 ,511 ,533 ,555 ,577 ,599 ,621 ,643],24:25]

X_train_TorontoAll7 = df.iloc[[0,6,28,50,72,94,116,138,160,182,204 ,248 ,270 ,292 ,314 ,336 ,358 ,380 ,402 ,424 ,446 ,468 ,490 ,512 ,534 ,556 ,578 ,600 ,622 ,644],[5,11,18,19,20]]
y_train_TorontoAll7 = df.iloc[[6,28,50,72,94,116 ,138,160,182,204 ,248 ,270 ,292 ,314 ,336 ,358 ,380 ,402 ,424 ,446 ,468 ,490 ,512 ,534 ,556 ,578 ,600 ,622 ,644],24:25]

X_train_TorontoAll8 = df.iloc[[0,7,29,51,73,95,117,139,161 ,183,205 ,249 ,271 ,293 ,315 ,337 ,359 ,381 ,403 ,425 ,447 ,469 ,491 ,513 ,535 ,557 ,579 ,601 ,623 ,645],[5,11,18,19,20]]
y_train_TorontoAll8 = df.iloc[[7,29,51,73,95,117 ,139,161 ,183,205 ,249 ,271 ,293 ,315 ,337 ,359 ,381 ,403 ,425 ,447 ,469 ,491 ,513 ,535 ,557 ,579 ,601 ,623 ,645],24:25]

X_train_TorontoAll9 = df.iloc[[0,8,30,52,74,96,118 ,140,162 ,184,206 ,250 ,272 ,294 ,316 ,338 ,360 ,382 ,404 ,426 ,448 ,470 ,492 ,514 ,536 ,558 ,580 ,602 ,624 ,646],[5,11,18,19,20]]
y_train_TorontoAll9 = df.iloc[[8,30,52,74,96,118 ,140,162 ,184,206 ,250 ,272 ,294 ,316 ,338 ,360 ,382 ,404 ,426 ,448 ,470 ,492 ,514 ,536 ,558 ,580 ,602 ,624 ,646],24:25]

X_train_TorontoAll10 = df.iloc[[0,9,31,53,75,97, 119,141,163 ,185 ,207 ,251 ,273 ,295 ,317 ,339 ,361 ,383 ,405 ,427 ,449 ,471 ,493 ,515 ,537 ,559 ,581 ,603 ,625 ,647],[5,11,18,19,20]]
y_train_TorontoAll10 = df.iloc[[9,31,53,75,97, 119,141,163,185 ,207 ,251 ,273 ,295 ,317 ,339 ,361 ,383 ,405 ,427 ,449 ,471 ,493 ,515 ,537 ,559 ,581 ,603 ,625 ,647],24:25]

X_train_TorontoAll11 = df.iloc[[0,10,32,54,76,98,120,142,164 ,186 ,208 ,252 ,274 ,296 ,318 ,340 ,362 ,384 ,406 ,428 ,450 ,472 ,494 ,516 ,538 ,560 ,582 ,604 ,626 ,648],[5,11,18,19,20]]
y_train_TorontoAll11= df.iloc[[10,32,54,76,98,120 ,142,164,186 ,208 ,252 ,274 ,296 ,318 ,340 ,362 ,384 ,406 ,428 ,450 ,472 ,494 ,516 ,538 ,560 ,582 ,604 ,626 ,648],24:25]

X_train_TorontoAll12 = df.iloc[[0,11,33,55,77,99,121 ,143,165,187 ,209 ,253 ,275 ,297 ,319 ,341 ,363 ,385 ,407 ,429 ,451 ,473 ,495 ,517 ,539 ,561 ,583 ,605 ,627 ,649],[5,11,18,19,20]]
y_train_TorontoAll12 = df.iloc[[11,33,55,77,99,121 ,143,165,187 ,209 ,253 ,275 ,297 ,319 ,341 ,363 ,385 ,407 ,429 ,451 ,473 ,495 ,517 ,539 ,561 ,583 ,605 ,627 ,649],24:25]

X_train_TorontoAll13 = df.iloc[[0,12,34,56,78, 100, 122, 144,166,188, 210, 254, 276, 298, 320, 342, 364, 386, 408, 430, 452, 474, 496, 518, 540, 562, 584, 606, 628, 650],[5,11,18,19,20]]
y_train_TorontoAll13 = df.iloc[[12,34,56,78, 100, 122, 144,166, 188, 210, 254, 276, 298, 320, 342, 364, 386, 408, 430, 452, 474, 496, 518, 540, 562, 584, 606, 628, 650],24:25]

X_train_TorontoAll14 = df.iloc[[0,13,35,57,79, 101,123, 145,167,189, 211, 255, 277, 299, 321, 343, 365, 387, 409, 431, 453, 475, 497, 519, 541, 563, 585, 607, 629, 651],[5,11,18,19,20]]
y_train_TorontoAll14 = df.iloc[[13,35,57,79, 101,123, 145,167,189, 211, 255, 277, 299, 321, 343, 365, 387, 409, 431, 453, 475, 497, 519, 541, 563, 585, 607, 629, 651],24:25]

X_train_TorontoAll15 = df.iloc[[0,14,36,58,80, 102,124, 146,168,190, 212, 256, 278, 300, 322, 344, 366, 388, 410, 432, 454, 476, 498, 520, 542, 564, 586, 608, 630, 652],[5,11,18,19,20]]
y_train_TorontoAll15 = df.iloc[[14,36,58,80, 102,124, 146,168, 190, 212, 256, 278, 300, 322, 344, 366, 388, 410, 432, 454, 476, 498, 520, 542, 564, 586, 608, 630, 652],24:25]

X_train_TorontoAll16 = df.iloc[[0,15,37,59,81, 103,125, 147, 169,191, 213, 257, 279, 301, 323, 345, 367, 389, 411, 433, 455, 477, 499, 521, 543, 565, 587, 609, 631, 653],[5,11,18,19,20]]
y_train_TorontoAll16 = df.iloc[[15,37,59,81, 103,125,147,169,191, 213, 257, 279, 301, 323, 345, 367, 389, 411, 433, 455, 477, 499, 521, 543, 565, 587, 609, 631, 653],24:25]

X_train_TorontoAll17 = df.iloc[[0,16,38,60,82, 104,126, 148, 170,192, 214, 258, 280, 302, 324, 346, 368, 390, 412, 434, 456, 478, 500, 522, 544, 566, 588, 610, 632, 654],[5,11,18,19,20]]
y_train_TorontoAll17 = df.iloc[[16,38,60,82, 104,126,148, 170,192, 214, 258, 280, 302, 324, 346, 368, 390, 412, 434, 456, 478, 500, 522, 544, 566, 588, 610, 632, 654],24:25]

X_train_TorontoAll18 = df.iloc[[0,17,39,61,83, 105,127, 149, 171,193, 215, 259, 281, 303, 325, 347, 369, 391, 413, 435, 457, 479, 501, 523, 545, 567, 589, 611, 633, 655],[5,11,18,19,20]]
y_train_TorontoAll18 = df.iloc[[17,39,61,83, 105,127, 149, 171,193, 215, 259, 281, 303, 325, 347, 369, 391, 413, 435, 457, 479, 501, 523, 545, 567, 589, 611, 633, 655],24:25]

X_train_TorontoAll19 = df.iloc[[0,18,40,62,84, 106,128, 150, 172,194, 216, 260, 282, 304, 326, 348, 370, 392, 414, 436, 458, 480, 502, 524, 546, 568, 590, 612, 634, 656],[5,11,18,19,20]]
y_train_TorontoAll19 = df.iloc[[18,40,62,84, 106,128, 150, 172,194, 216, 260, 282, 304, 326, 348, 370, 392, 414, 436, 458, 480, 502, 524, 546, 568, 590, 612, 634, 656],24:25]

X_train_TorontoAll20 = df.iloc[[0,19,41,63,85, 107,129, 151,173,195, 217, 261, 283, 305, 327, 349, 371, 393, 415, 437, 459, 481, 503, 525, 547, 569, 591, 613, 635, 657],[5,11,18,19,20]]
y_train_TorontoAll20 = df.iloc[[19,41,63,85, 107, 129, 151,173, 195, 217, 261, 283, 305, 327, 349, 371, 393, 415, 437, 459, 481, 503, 525, 547, 569, 591, 613, 635, 657],24:25]

X_train_TorontoAll21 = df.iloc[[0,20,42,64,86, 108,130, 152,174,196, 218, 262, 284, 306, 328, 350, 372, 394, 416, 438, 460, 482, 504, 526, 548, 570, 592, 614, 636, 658],[5,11,18,19,20]]
y_train_TorontoAll21 = df.iloc[[20,42,64,86, 108,130, 152,174, 196, 218, 262, 284, 306, 328, 350, 372, 394, 416, 438, 460, 482, 504, 526, 548, 570, 592, 614, 636, 658],24:25]

X_train_TorontoAll22 = df.iloc[[0,21,43,65,87, 109,131, 153, 175,197, 219, 263, 285, 307, 329, 351, 373, 395, 417, 439, 461, 483, 505, 527, 549, 571, 593, 615, 637, 659],[5,11,18,19,20]]
y_train_TorontoAll22 = df.iloc[[21,43,65,87, 109,131, 153, 175,197, 219, 263, 285, 307, 329, 351, 373, 395, 417, 439, 461, 483, 505, 527, 549, 571, 593, 615, 637, 659],24:25]

# %%
regressorToronto1 = LinearRegression()
regressorToronto1.fit(X_train_TorontoAll1, y_train_TorontoAll1)
pd.DataFrame(list(zip(X_train_TorontoAll1, regressorToronto1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_Toronto1 = regressorToronto1.predict(X_train_Toronto1)

# %%
y_train_TorontoAll2.loc[-1] = y_pred_Toronto1.item(0)  # adding a row
y_train_TorontoAll2.index = y_train_TorontoAll2.index + 1  # shifting index
y_train_TorontoAll2 = y_train_TorontoAll2.sort_index()
regressorToronto2 = LinearRegression()
regressorToronto2.fit(X_train_TorontoAll2, y_train_TorontoAll2)

pd.DataFrame(list(zip(X_train_TorontoAll2, regressorToronto2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Toronto2 = regressorToronto2.predict(X_train_Toronto2)

y_train_TorontoAll3.loc[-1] = y_pred_Toronto2.item(0)  # adding a row
y_train_TorontoAll3.index = y_train_TorontoAll3.index + 1  # shifting index
y_train_TorontoAll3 = y_train_TorontoAll3.sort_index()
regressorToronto3 = LinearRegression()
regressorToronto3.fit(X_train_TorontoAll3, y_train_TorontoAll3)

pd.DataFrame(list(zip(X_train_TorontoAll3, regressorToronto3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Toronto3 = regressorToronto3.predict(X_train_Toronto3)

y_train_TorontoAll4.loc[-1] = y_pred_Toronto3.item(0)  # adding a row
y_train_TorontoAll4.index = y_train_TorontoAll4.index + 1  # shifting index
y_train_TorontoAll4 = y_train_TorontoAll4.sort_index()
regressorToronto4 = LinearRegression()
regressorToronto4.fit(X_train_TorontoAll4, y_train_TorontoAll4)

pd.DataFrame(list(zip(X_train_TorontoAll4, regressorToronto4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Toronto4 = regressorToronto4.predict(X_train_Toronto4)

y_train_TorontoAll5.loc[-1] = y_pred_Toronto4.item(0)  # adding a row
y_train_TorontoAll5.index = y_train_TorontoAll5.index + 1  # shifting index
y_train_TorontoAll5 = y_train_TorontoAll5.sort_index()
regressorToronto5 = LinearRegression()
regressorToronto5.fit(X_train_TorontoAll5, y_train_TorontoAll5)

pd.DataFrame(list(zip(X_train_TorontoAll5, regressorToronto5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Toronto5 = regressorToronto5.predict(X_train_Toronto5)

y_train_TorontoAll6.loc[-1] = y_pred_Toronto5.item(0)  # adding a row
y_train_TorontoAll6.index = y_train_TorontoAll6.index + 1  # shifting index
y_train_TorontoAll6 = y_train_TorontoAll6.sort_index()
regressorToronto6 = LinearRegression()
regressorToronto6.fit(X_train_TorontoAll6, y_train_TorontoAll6)

pd.DataFrame(list(zip(X_train_TorontoAll6, regressorToronto6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Toronto6 = regressorToronto6.predict(X_train_Toronto6)

y_train_TorontoAll7.loc[-1] = y_pred_Toronto6.item(0)  # adding a row
y_train_TorontoAll7.index = y_train_TorontoAll7.index + 1  # shifting index
y_train_TorontoAll7 = y_train_TorontoAll7.sort_index()
regressorToronto7 = LinearRegression()
regressorToronto7.fit(X_train_TorontoAll7, y_train_TorontoAll7)

pd.DataFrame(list(zip(X_train_TorontoAll7, regressorToronto7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Toronto7 = regressorToronto7.predict(X_train_Toronto7)

y_train_TorontoAll8.loc[-1] = y_pred_Toronto7.item(0)  # adding a row
y_train_TorontoAll8.index = y_train_TorontoAll8.index + 1  # shifting index
y_train_TorontoAll8 = y_train_TorontoAll8.sort_index()
regressorToronto8 = LinearRegression()
regressorToronto8.fit(X_train_TorontoAll8, y_train_TorontoAll8)

pd.DataFrame(list(zip(X_train_TorontoAll8, regressorToronto8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Toronto8 = regressorToronto8.predict(X_train_Toronto8)

y_train_TorontoAll9.loc[-1] = y_pred_Toronto8.item(0)  # adding a row
y_train_TorontoAll9.index = y_train_TorontoAll9.index + 1  # shifting index
y_train_TorontoAll9 = y_train_TorontoAll9.sort_index()
regressorToronto9 = LinearRegression()
regressorToronto9.fit(X_train_TorontoAll9, y_train_TorontoAll9)

pd.DataFrame(list(zip(X_train_TorontoAll9, regressorToronto9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Toronto9 = regressorToronto9.predict(X_train_Toronto9)

y_train_TorontoAll10.loc[-1] = y_pred_Toronto9.item(0)  # adding a row
y_train_TorontoAll10.index = y_train_TorontoAll10.index + 1  # shifting index
y_train_TorontoAll10 = y_train_TorontoAll10.sort_index()
regressorToronto10 = LinearRegression()
regressorToronto10.fit(X_train_TorontoAll10, y_train_TorontoAll10)

pd.DataFrame(list(zip(X_train_TorontoAll10, regressorToronto10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Toronto10 = regressorToronto10.predict(X_train_Toronto10)

y_train_TorontoAll11.loc[-1] = y_pred_Toronto10.item(0)  # adding a row
y_train_TorontoAll11.index = y_train_TorontoAll11.index + 1  # shifting index
y_train_TorontoAll11 = y_train_TorontoAll11.sort_index()
regressorToronto11 = LinearRegression()
regressorToronto11.fit(X_train_TorontoAll11, y_train_TorontoAll11)

pd.DataFrame(list(zip(X_train_TorontoAll11, regressorToronto11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Toronto11 = regressorToronto11.predict(X_train_Toronto11)

y_train_TorontoAll12.loc[-1] = y_pred_Toronto11.item(0)  # adding a row
y_train_TorontoAll12.index = y_train_TorontoAll12.index + 1  # shifting index
y_train_TorontoAll12 = y_train_TorontoAll12.sort_index()
regressorToronto12 = LinearRegression()
regressorToronto12.fit(X_train_TorontoAll12, y_train_TorontoAll12)

pd.DataFrame(list(zip(X_train_TorontoAll12, regressorToronto12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Toronto12 = regressorToronto12.predict(X_train_Toronto12)

y_train_TorontoAll13.loc[-1] = y_pred_Toronto12.item(0)  # adding a row
y_train_TorontoAll13.index = y_train_TorontoAll13.index + 1  # shifting index
y_train_TorontoAll13 = y_train_TorontoAll13.sort_index()
regressorToronto13 = LinearRegression()
regressorToronto13.fit(X_train_TorontoAll13, y_train_TorontoAll13)

pd.DataFrame(list(zip(X_train_TorontoAll13, regressorToronto13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Toronto13 = regressorToronto13.predict(X_train_Toronto13)

y_train_TorontoAll14.loc[-1] = y_pred_Toronto13.item(0)  # adding a row
y_train_TorontoAll14.index = y_train_TorontoAll14.index + 1  # shifting index
y_train_TorontoAll14 = y_train_TorontoAll14.sort_index()
regressorToronto14 = LinearRegression()
regressorToronto14.fit(X_train_TorontoAll14, y_train_TorontoAll14)

pd.DataFrame(list(zip(X_train_TorontoAll14, regressorToronto14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Toronto14 = regressorToronto14.predict(X_train_Toronto14)

y_train_TorontoAll15.loc[-1] = y_pred_Toronto14.item(0)  # adding a row
y_train_TorontoAll15.index = y_train_TorontoAll15.index + 1  # shifting index
y_train_TorontoAll15 = y_train_TorontoAll15.sort_index()
regressorToronto15 = LinearRegression()
regressorToronto15.fit(X_train_TorontoAll15, y_train_TorontoAll15)

pd.DataFrame(list(zip(X_train_TorontoAll15, regressorToronto15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Toronto15 = regressorToronto15.predict(X_train_Toronto15)

y_train_TorontoAll16.loc[-1] = y_pred_Toronto15.item(0)  # adding a row
y_train_TorontoAll16.index = y_train_TorontoAll16.index + 1  # shifting index
y_train_TorontoAll16 = y_train_TorontoAll16.sort_index()
regressorToronto16 = LinearRegression()
regressorToronto16.fit(X_train_TorontoAll16, y_train_TorontoAll16)

pd.DataFrame(list(zip(X_train_TorontoAll16, regressorToronto16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Toronto16 = regressorToronto16.predict(X_train_Toronto16)

y_train_TorontoAll17.loc[-1] = y_pred_Toronto16.item(0)  # adding a row
y_train_TorontoAll17.index = y_train_TorontoAll17.index + 1  # shifting index
y_train_TorontoAll17 = y_train_TorontoAll17.sort_index()
regressorToronto17 = LinearRegression()
regressorToronto17.fit(X_train_TorontoAll17, y_train_TorontoAll17)

pd.DataFrame(list(zip(X_train_TorontoAll17, regressorToronto17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Toronto17 = regressorToronto17.predict(X_train_Toronto17)

y_train_TorontoAll18.loc[-1] = y_pred_Toronto17.item(0)  # adding a row
y_train_TorontoAll18.index = y_train_TorontoAll18.index + 1  # shifting index
y_train_TorontoAll18 = y_train_TorontoAll18.sort_index()
regressorToronto18 = LinearRegression()
regressorToronto18.fit(X_train_TorontoAll18, y_train_TorontoAll18)

pd.DataFrame(list(zip(X_train_TorontoAll18, regressorToronto18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Toronto18 = regressorToronto18.predict(X_train_Toronto18)

y_train_TorontoAll19.loc[-1] = y_pred_Toronto18.item(0)  # adding a row
y_train_TorontoAll19.index = y_train_TorontoAll19.index + 1  # shifting index
y_train_TorontoAll19 = y_train_TorontoAll19.sort_index()
regressorToronto19 = LinearRegression()
regressorToronto19.fit(X_train_TorontoAll19, y_train_TorontoAll19)

pd.DataFrame(list(zip(X_train_TorontoAll19, regressorToronto19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Toronto19 = regressorToronto19.predict(X_train_Toronto19)

y_train_TorontoAll20.loc[-1] = y_pred_Toronto19.item(0)  # adding a row
y_train_TorontoAll20.index = y_train_TorontoAll20.index + 1  # shifting index
y_train_TorontoAll20 = y_train_TorontoAll20.sort_index()
regressorToronto20 = LinearRegression()
regressorToronto20.fit(X_train_TorontoAll20, y_train_TorontoAll20)

pd.DataFrame(list(zip(X_train_TorontoAll20, regressorToronto20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Toronto20 = regressorToronto20.predict(X_train_Toronto20)

y_train_TorontoAll21.loc[-1] = y_pred_Toronto20.item(0)  # adding a row
y_train_TorontoAll21.index = y_train_TorontoAll21.index + 1  # shifting index
y_train_TorontoAll21 = y_train_TorontoAll21.sort_index()
regressorToronto21 = LinearRegression()
regressorToronto21.fit(X_train_TorontoAll21, y_train_TorontoAll21)

pd.DataFrame(list(zip(X_train_TorontoAll21, regressorToronto21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Toronto21 = regressorToronto21.predict(X_train_Toronto21)

# %%
	X_train_Boston1=X_Boston[0:1]
	y_train_Boston1=y_Boston[0:1]
	X_train_Boston2=X_Boston[1:2]
	y_train_Boston2=y_Boston[1:2]
	X_train_Boston3=X_Boston[2:3]
	y_train_Boston3=y_Boston[2:3]
	X_train_Boston4=X_Boston[3:4]
	y_train_Boston4=y_Boston[3:4]
	X_train_Boston5=X_Boston[4:5]
	y_train_Boston5=y_Boston[4:5]
	y_train_Boston6=y_Boston[5:6]
	X_train_Boston7=X_Boston[7:8]
	X_train_Boston6=X_Boston[5:6]
	y_train_Boston7=y_Boston[7:8]
	X_train_Boston8=X_Boston[8:9]
	y_train_Boston8=y_Boston[8:9]
	X_train_Boston9=X_Boston[9:10]
	y_train_Boston9=y_Boston[9:10]
	X_train_Boston10=X_Boston[10:11]
	y_train_Boston10=y_Boston[10:11]
	X_train_Boston11=X_Boston[11:12]
	y_train_Boston11=y_Boston[11:12]
	X_train_Boston12=X_Boston[12:13]
	y_train_Boston12=y_Boston[12:13]
	X_train_Boston13=X_Boston[13:14]
	y_train_Boston13=y_Boston[13:14]
	X_train_Boston14=X_Boston[14:15]
	y_train_Boston14=y_Boston[14:15]
	X_train_Boston15=X_Boston[15:16]
	y_train_Boston15=y_Boston[15:16]
	X_train_Boston16=X_Boston[16:17]
	y_train_Boston16=y_Boston[16:17]
	X_train_Boston17=X_Boston[17:18]
	y_train_Boston17=y_Boston[17:18]
	X_train_Boston18=X_Boston[18:19]
	y_train_Boston18=y_Boston[18:19]
	X_train_Boston19=X_Boston[19:20]
	y_train_Boston19=y_Boston[19:20]
	X_train_Boston20=X_Boston[20:21]
	y_train_Boston20=y_Boston[20:21]
	X_train_Boston21=X_Boston[21:22]
	y_train_Boston21=y_Boston[21:22]
	X_train_Boston22=X_Boston[22:23]
	y_train_Boston22=y_Boston[22:23]
	
	X_train_BostonAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],[5,11,18,19,20]]
	y_train_BostonAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],24:25]
	
	X_train_BostonAll2=df.iloc[[0,1,23,45,67,89,111,133,155,177,199,221,265,287,309,331,353,375,397,419,441,463,485,507,529,551,573,595,617,639],[5,11,18,19,20]]
	y_train_BostonAll2=df.iloc[[1,23,45,67,89,111,133,155,177,199,221,265,287,309,331,353,375,397,419,441,463,485,507,529,551,573,595,617,639],24:25]
	
	X_train_BostonAll3=df.iloc[[0,2,24,46,68,90,112,134,156,178,200,222,266,288,310,332,354,376,398,420,442,464,486,508,530,552,574,596,618,640],[5,11,18,19,20]]
	y_train_BostonAll3=df.iloc[[2,24,46,68,90,112,134,156,178,200,222,266,288,310,332,354,376,398,420,442,464,486,508,530,552,574,596,618,640],24:25]
	
	X_train_BostonAll4=df.iloc[[0,3,25,47,69,91,113,135,157,179,201,223,267,289,311,333,355,377,399,421,443,465,487,509,531,553,575,597,619,641],[5,11,18,19,20]]
	y_train_BostonAll4=df.iloc[[3,25,47,69,91,113,135,158,179,201,223,267,289,311,333,355,377,399,421,443,465,487,509,531,553,575,597,619,641],24:25]
	
	X_train_BostonAll5=df.iloc[[0,4,26,48,70,92,114,136,158,180,202,224,268,290,312,334,356,378,400,422,444,466,488,510,532,554,576,598,620,642],[5,11,18,19,20]]
	y_train_BostonAll5=df.iloc[[4,26,48,70,92,114,136,158,180,202,224,268,290,312,334,356,378,400,422,444,466,488,510,532,554,576,598,620,642],24:25]
	
	X_train_BostonAll6=df.iloc[[0,5,27,49,71,93,115,137,159,181,203,225,269,291,313,335,357,379,401,423,445,467,489,511,533,555,577,599,621,643],[5,11,18,19,20]]
	y_train_BostonAll6=df.iloc[[5,27,49,71,93,115,137,159,181,203,225,269,291,313,335,357,379,401,423,445,467,489,511,533,555,577,599,621,643],24:25]
	
	X_train_BostonAll7=df.iloc[[0,6,28,50,72,94,116,138,160,182,204,226,270,292,314,336,358,380,402,424,446,468,490,512,534,556,578,600,622,644],[5,11,18,19,20]]
	y_train_BostonAll7=df.iloc[[6,28,50,72,94,116,138,160,182,204,226,270,292,314,336,358,380,402,424,446,468,490,512,534,556,578,600,622,644],24:25]
	
	X_train_BostonAll8=df.iloc[[0,7,29,51,73,95,117,139,161,183,205,227,271,293,315,337,359,381,403,425,447,469,491,513,535,557,579,601,623,645],[5,11,18,19,20]]
	y_train_BostonAll8=df.iloc[[7,29,51,73,95,117,139,161,183,205,227,271,293,315,337,359,381,403,425,447,469,491,513,535,557,579,601,623,645],24:25]
	
	X_train_BostonAll9=df.iloc[[0,8,30,52,74,96,118,140,162,184,206,228,272,294,316,338,360,382,404,426,448,470,492,514,536,558,580,602,624,646],[5,11,18,19,20]]
	y_train_BostonAll9=df.iloc[[8,30,52,74,96,118,140,162,184,206,228,272,294,316,338,360,382,404,426,448,470,492,514,536,558,580,602,624,646],24:25]
	
	X_train_BostonAll10=df.iloc[[0,9,31,53,75,97,119,141,163,185,207,229,273,295,317,339,361,383,405,427,449,471,493,515,537,559,581,603,625,647],[5,11,18,19,20]]
	y_train_BostonAll10=df.iloc[[9,31,53,75,97,119,141,163,185,207,229,273,295,317,339,361,383,405,427,449,471,493,515,537,559,581,603,625,647],24:25]
	
	X_train_BostonAll11=df.iloc[[0,10,32,54,76,98,120,142,164,186,208,230,274,296,318,340,362,384,406,428,450,472,494,516,538,560,582,604,626,648],[5,11,18,19,20]]
	y_train_BostonAll11=df.iloc[[10,32,54,76,98,120,142,164,186,208,230,274,296,318,340,362,384,406,428,450,472,494,516,538,560,582,604,626,648],24:25]
	
	X_train_BostonAll12=df.iloc[[0,11,33,55,77,99,121,143,165,187,209,231,275,297,319,341,363,385,407,429,451,473,495,517,539,561,583,605,627,649],[5,11,18,19,20]]
	y_train_BostonAll12=df.iloc[[11,33,55,77,99,121,143,165,187,209,231,275,297,319,341,363,385,407,429,451,473,495,517,539,561,583,605,627,649],24:25]
	
	X_train_BostonAll13=df.iloc[[0,12,34,56,78,100,122,144,166,188,210,232,276,298,320,342,364,386,408,430,452,474,496,518,540,562,584,606,628,650],[5,11,18,19,20]]
	y_train_BostonAll13=df.iloc[[12,34,56,78,100,122,144,166,188,210,232,276,298,320,342,364,386,408,430,452,474,496,518,540,562,584,606,628,650],24:25]
	
	X_train_BostonAll14=df.iloc[[0,13,35,57,79,101,123,145,167,189,211,233,277,299,321,343,365,387,409,431,453,475,497,519,541,563,585,607,629,651],[5,11,18,19,20]]
	y_train_BostonAll14=df.iloc[[13,35,57,79,101,123,145,167,189,211,233,277,299,321,343,365,387,409,431,453,475,497,519,541,563,585,607,629,651],24:25]
	
	X_train_BostonAll15=df.iloc[[0,14,36,58,80,102,124,146,168,190,212,234,278,300,322,344,366,388,410,432,454,476,498,520,542,564,586,608,630,652],[5,11,18,19,20]]
	y_train_BostonAll15=df.iloc[[14,36,58,80,102,124,146,168,190,212,234,278,300,322,344,366,388,410,432,454,476,498,520,542,564,586,608,630,652],24:25]
	
	X_train_BostonAll16=df.iloc[[0,15,37,59,81,103,125,147,169,191,213,235,279,301,323,345,367,389,411,433,455,477,499,521,543,565,587,609,631,653],[5,11,18,19,20]]
	y_train_BostonAll16=df.iloc[[15,37,59,81,103,125,147,169,191,213,235,279,301,323,345,367,389,411,433,455,477,499,521,543,565,587,609,631,653],24:25]
	
	X_train_BostonAll17=df.iloc[[0,16,38,60,82,104,126,148,170,192,214,236,280,302,324,346,368,390,412,434,456,478,500,522,544,566,588,610,632,654],[5,11,18,19,20]]
	y_train_BostonAll17=df.iloc[[16,38,60,82,104,126,148,170,192,214,236,280,302,324,346,368,390,412,434,456,478,500,522,544,566,588,610,632,654],24:25]
	
	X_train_BostonAll18=df.iloc[[0,17,39,61,83,105,127,149,171,193,215,237,281,303,325,347,369,391,413,435,457,479,501,523,545,567,589,611,633,655],[5,11,18,19,20]]
	y_train_BostonAll18=df.iloc[[17,39,61,83,105,127,149,171,193,215,237,281,303,325,347,369,391,413,435,457,479,501,523,545,567,589,611,633,655],24:25]
	
	X_train_BostonAll19=df.iloc[[0,18,40,62,84,106,128,150,172,194,216,238,282,304,326,348,370,392,414,436,458,480,502,524,546,568,590,612,634,656],[5,11,18,19,20]]
	y_train_BostonAll19=df.iloc[[18,40,62,84,106,128,150,172,194,216,238,282,304,326,348,370,392,414,436,458,480,502,524,546,568,590,612,634,656],24:25]
	
	X_train_BostonAll20=df.iloc[[0,19,41,63,85,107,129,151,173,195,217,239,283,305,327,349,371,393,415,437,459,481,503,525,547,569,591,613,635,657],[5,11,18,19,20]]
	y_train_BostonAll20=df.iloc[[19,41,63,85,107,129,151,173,195,217,239,283,305,327,349,371,393,415,437,459,481,503,525,547,569,591,613,635,657],24:25]
	
	X_train_BostonAll21=df.iloc[[0,20,42,64,86,108,130,152,174,196,218,240,284,306,328,350,372,394,416,438,460,482,504,526,548,570,592,614,636,658],[5,11,18,19,20]]
	y_train_BostonAll21=df.iloc[[20,42,64,86,108,130,152,174,196,218,240,284,306,328,350,372,394,416,438,460,482,504,526,548,570,592,614,636,658],24:25]
	
	X_train_BostonAll22=df.iloc[[0,21,43,65,87,109,131,153,175,197,219,241,285,307,329,351,373,395,417,439,461,483,505,527,549,571,593,615,637,659],[5,11,18,19,20]]
	y_train_BostonAll22=df.iloc[[21,43,65,87,109,131,153,175,197,219,241,285,307,329,351,373,395,417,439,461,483,505,527,549,571,593,615,637,659],24:25]

# %%
regressorBoston1 = LinearRegression()
regressorBoston1.fit(X_train_BostonAll1, y_train_BostonAll1)
pd.DataFrame(list(zip(X_train_BostonAll1, regressorBoston1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_Boston1 = regressorBoston1.predict(X_train_Boston1)

# %%
y_train_BostonAll2.loc[-1] = y_pred_Boston1.item(0)  # adding a row
y_train_BostonAll2.index = y_train_BostonAll2.index + 1  # shifting index
y_train_BostonAll2 = y_train_BostonAll2.sort_index()
regressorBoston2 = LinearRegression()
regressorBoston2.fit(X_train_BostonAll2, y_train_BostonAll2)

pd.DataFrame(list(zip(X_train_BostonAll2, regressorBoston2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Boston2 = regressorBoston2.predict(X_train_Boston2)

y_train_BostonAll3.loc[-1] = y_pred_Boston2.item(0)  # adding a row
y_train_BostonAll3.index = y_train_BostonAll3.index + 1  # shifting index
y_train_BostonAll3 = y_train_BostonAll3.sort_index()
regressorBoston3 = LinearRegression()
regressorBoston3.fit(X_train_BostonAll3, y_train_BostonAll3)

pd.DataFrame(list(zip(X_train_BostonAll3, regressorBoston3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Boston3 = regressorBoston3.predict(X_train_Boston3)

y_train_BostonAll4.loc[-1] = y_pred_Boston3.item(0)  # adding a row
y_train_BostonAll4.index = y_train_BostonAll4.index + 1  # shifting index
y_train_BostonAll4 = y_train_BostonAll4.sort_index()
regressorBoston4 = LinearRegression()
regressorBoston4.fit(X_train_BostonAll4, y_train_BostonAll4)

pd.DataFrame(list(zip(X_train_BostonAll4, regressorBoston4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Boston4 = regressorBoston4.predict(X_train_Boston4)

y_train_BostonAll5.loc[-1] = y_pred_Boston4.item(0)  # adding a row
y_train_BostonAll5.index = y_train_BostonAll5.index + 1  # shifting index
y_train_BostonAll5 = y_train_BostonAll5.sort_index()
regressorBoston5 = LinearRegression()
regressorBoston5.fit(X_train_BostonAll5, y_train_BostonAll5)

pd.DataFrame(list(zip(X_train_BostonAll5, regressorBoston5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Boston5 = regressorBoston5.predict(X_train_Boston5)

y_train_BostonAll6.loc[-1] = y_pred_Boston5.item(0)  # adding a row
y_train_BostonAll6.index = y_train_BostonAll6.index + 1  # shifting index
y_train_BostonAll6 = y_train_BostonAll6.sort_index()
regressorBoston6 = LinearRegression()
regressorBoston6.fit(X_train_BostonAll6, y_train_BostonAll6)

pd.DataFrame(list(zip(X_train_BostonAll6, regressorBoston6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Boston6 = regressorBoston6.predict(X_train_Boston6)

y_train_BostonAll7.loc[-1] = y_pred_Boston6.item(0)  # adding a row
y_train_BostonAll7.index = y_train_BostonAll7.index + 1  # shifting index
y_train_BostonAll7 = y_train_BostonAll7.sort_index()
regressorBoston7 = LinearRegression()
regressorBoston7.fit(X_train_BostonAll7, y_train_BostonAll7)

pd.DataFrame(list(zip(X_train_BostonAll7, regressorBoston7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Boston7 = regressorBoston7.predict(X_train_Boston7)

y_train_BostonAll8.loc[-1] = y_pred_Boston7.item(0)  # adding a row
y_train_BostonAll8.index = y_train_BostonAll8.index + 1  # shifting index
y_train_BostonAll8 = y_train_BostonAll8.sort_index()
regressorBoston8 = LinearRegression()
regressorBoston8.fit(X_train_BostonAll8, y_train_BostonAll8)

pd.DataFrame(list(zip(X_train_BostonAll8, regressorBoston8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Boston8 = regressorBoston8.predict(X_train_Boston8)

y_train_BostonAll9.loc[-1] = y_pred_Boston8.item(0)  # adding a row
y_train_BostonAll9.index = y_train_BostonAll9.index + 1  # shifting index
y_train_BostonAll9 = y_train_BostonAll9.sort_index()
regressorBoston9 = LinearRegression()
regressorBoston9.fit(X_train_BostonAll9, y_train_BostonAll9)

pd.DataFrame(list(zip(X_train_BostonAll9, regressorBoston9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Boston9 = regressorBoston9.predict(X_train_Boston9)

y_train_BostonAll10.loc[-1] = y_pred_Boston9.item(0)  # adding a row
y_train_BostonAll10.index = y_train_BostonAll10.index + 1  # shifting index
y_train_BostonAll10 = y_train_BostonAll10.sort_index()
regressorBoston10 = LinearRegression()
regressorBoston10.fit(X_train_BostonAll10, y_train_BostonAll10)

pd.DataFrame(list(zip(X_train_BostonAll10, regressorBoston10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Boston10 = regressorBoston10.predict(X_train_Boston10)

y_train_BostonAll11.loc[-1] = y_pred_Boston10.item(0)  # adding a row
y_train_BostonAll11.index = y_train_BostonAll11.index + 1  # shifting index
y_train_BostonAll11 = y_train_BostonAll11.sort_index()
regressorBoston11 = LinearRegression()
regressorBoston11.fit(X_train_BostonAll11, y_train_BostonAll11)

pd.DataFrame(list(zip(X_train_BostonAll11, regressorBoston11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Boston11 = regressorBoston11.predict(X_train_Boston11)

y_train_BostonAll12.loc[-1] = y_pred_Boston11.item(0)  # adding a row
y_train_BostonAll12.index = y_train_BostonAll12.index + 1  # shifting index
y_train_BostonAll12 = y_train_BostonAll12.sort_index()
regressorBoston12 = LinearRegression()
regressorBoston12.fit(X_train_BostonAll12, y_train_BostonAll12)

pd.DataFrame(list(zip(X_train_BostonAll12, regressorBoston12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Boston12 = regressorBoston12.predict(X_train_Boston12)

y_train_BostonAll13.loc[-1] = y_pred_Boston12.item(0)  # adding a row
y_train_BostonAll13.index = y_train_BostonAll13.index + 1  # shifting index
y_train_BostonAll13 = y_train_BostonAll13.sort_index()
regressorBoston13 = LinearRegression()
regressorBoston13.fit(X_train_BostonAll13, y_train_BostonAll13)

pd.DataFrame(list(zip(X_train_BostonAll13, regressorBoston13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Boston13 = regressorBoston13.predict(X_train_Boston13)

y_train_BostonAll14.loc[-1] = y_pred_Boston13.item(0)  # adding a row
y_train_BostonAll14.index = y_train_BostonAll14.index + 1  # shifting index
y_train_BostonAll14 = y_train_BostonAll14.sort_index()
regressorBoston14 = LinearRegression()
regressorBoston14.fit(X_train_BostonAll14, y_train_BostonAll14)

pd.DataFrame(list(zip(X_train_BostonAll14, regressorBoston14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Boston14 = regressorBoston14.predict(X_train_Boston14)

y_train_BostonAll15.loc[-1] = y_pred_Boston14.item(0)  # adding a row
y_train_BostonAll15.index = y_train_BostonAll15.index + 1  # shifting index
y_train_BostonAll15 = y_train_BostonAll15.sort_index()
regressorBoston15 = LinearRegression()
regressorBoston15.fit(X_train_BostonAll15, y_train_BostonAll15)

pd.DataFrame(list(zip(X_train_BostonAll15, regressorBoston15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Boston15 = regressorBoston15.predict(X_train_Boston15)

y_train_BostonAll16.loc[-1] = y_pred_Boston15.item(0)  # adding a row
y_train_BostonAll16.index = y_train_BostonAll16.index + 1  # shifting index
y_train_BostonAll16 = y_train_BostonAll16.sort_index()
regressorBoston16 = LinearRegression()
regressorBoston16.fit(X_train_BostonAll16, y_train_BostonAll16)

pd.DataFrame(list(zip(X_train_BostonAll16, regressorBoston16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Boston16 = regressorBoston16.predict(X_train_Boston16)

y_train_BostonAll17.loc[-1] = y_pred_Boston16.item(0)  # adding a row
y_train_BostonAll17.index = y_train_BostonAll17.index + 1  # shifting index
y_train_BostonAll17 = y_train_BostonAll17.sort_index()
regressorBoston17 = LinearRegression()
regressorBoston17.fit(X_train_BostonAll17, y_train_BostonAll17)

pd.DataFrame(list(zip(X_train_BostonAll17, regressorBoston17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Boston17 = regressorBoston17.predict(X_train_Boston17)

y_train_BostonAll18.loc[-1] = y_pred_Boston17.item(0)  # adding a row
y_train_BostonAll18.index = y_train_BostonAll18.index + 1  # shifting index
y_train_BostonAll18 = y_train_BostonAll18.sort_index()
regressorBoston18 = LinearRegression()
regressorBoston18.fit(X_train_BostonAll18, y_train_BostonAll18)

pd.DataFrame(list(zip(X_train_BostonAll18, regressorBoston18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Boston18 = regressorBoston18.predict(X_train_Boston18)

y_train_BostonAll19.loc[-1] = y_pred_Boston18.item(0)  # adding a row
y_train_BostonAll19.index = y_train_BostonAll19.index + 1  # shifting index
y_train_BostonAll19 = y_train_BostonAll19.sort_index()
regressorBoston19 = LinearRegression()
regressorBoston19.fit(X_train_BostonAll19, y_train_BostonAll19)

pd.DataFrame(list(zip(X_train_BostonAll19, regressorBoston19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Boston19 = regressorBoston19.predict(X_train_Boston19)

y_train_BostonAll20.loc[-1] = y_pred_Boston19.item(0)  # adding a row
y_train_BostonAll20.index = y_train_BostonAll20.index + 1  # shifting index
y_train_BostonAll20 = y_train_BostonAll20.sort_index()
regressorBoston20 = LinearRegression()
regressorBoston20.fit(X_train_BostonAll20, y_train_BostonAll20)

pd.DataFrame(list(zip(X_train_BostonAll20, regressorBoston20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Boston20 = regressorBoston20.predict(X_train_Boston20)

y_train_BostonAll21.loc[-1] = y_pred_Boston20.item(0)  # adding a row
y_train_BostonAll21.index = y_train_BostonAll21.index + 1  # shifting index
y_train_BostonAll21 = y_train_BostonAll21.sort_index()
regressorBoston21 = LinearRegression()
regressorBoston21.fit(X_train_BostonAll21, y_train_BostonAll21)

pd.DataFrame(list(zip(X_train_BostonAll21, regressorBoston21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Boston21 = regressorBoston21.predict(X_train_Boston21)

# %%
	X_train_Philadelphia1=X_Philadelphia[0:1]
	y_train_Philadelphia1=y_Philadelphia[0:1]
	X_train_Philadelphia2=X_Philadelphia[1:2]
	y_train_Philadelphia2=y_Philadelphia[1:2]
	X_train_Philadelphia3=X_Philadelphia[2:3]
	y_train_Philadelphia3=y_Philadelphia[2:3]
	X_train_Philadelphia4=X_Philadelphia[3:4]
	y_train_Philadelphia4=y_Philadelphia[3:4]
	X_train_Philadelphia5=X_Philadelphia[4:5]
	y_train_Philadelphia5=y_Philadelphia[4:5]
	y_train_Philadelphia6=y_Philadelphia[5:6]
	X_train_Philadelphia7=X_Philadelphia[7:8]
	X_train_Philadelphia6=X_Philadelphia[5:6]
	y_train_Philadelphia7=y_Philadelphia[7:8]
	X_train_Philadelphia8=X_Philadelphia[8:9]
	y_train_Philadelphia8=y_Philadelphia[8:9]
	X_train_Philadelphia9=X_Philadelphia[9:10]
	y_train_Philadelphia9=y_Philadelphia[9:10]
	X_train_Philadelphia10=X_Philadelphia[10:11]
	y_train_Philadelphia10=y_Philadelphia[10:11]
	X_train_Philadelphia11=X_Philadelphia[11:12]
	y_train_Philadelphia11=y_Philadelphia[11:12]
	X_train_Philadelphia12=X_Philadelphia[12:13]
	y_train_Philadelphia12=y_Philadelphia[12:13]
	X_train_Philadelphia13=X_Philadelphia[13:14]
	y_train_Philadelphia13=y_Philadelphia[13:14]
	X_train_Philadelphia14=X_Philadelphia[14:15]
	y_train_Philadelphia14=y_Philadelphia[14:15]
	X_train_Philadelphia15=X_Philadelphia[15:16]
	y_train_Philadelphia15=y_Philadelphia[15:16]
	X_train_Philadelphia16=X_Philadelphia[16:17]
	y_train_Philadelphia16=y_Philadelphia[16:17]
	X_train_Philadelphia17=X_Philadelphia[17:18]
	y_train_Philadelphia17=y_Philadelphia[17:18]
	X_train_Philadelphia18=X_Philadelphia[18:19]
	y_train_Philadelphia18=y_Philadelphia[18:19]
	X_train_Philadelphia19=X_Philadelphia[19:20]
	y_train_Philadelphia19=y_Philadelphia[19:20]
	X_train_Philadelphia20=X_Philadelphia[20:21]
	y_train_Philadelphia20=y_Philadelphia[20:21]
	X_train_Philadelphia21=X_Philadelphia[21:22]
	y_train_Philadelphia21=y_Philadelphia[21:22]
	X_train_Philadelphia22=X_Philadelphia[22:23]
	y_train_Philadelphia22=y_Philadelphia[22:23]
	
	X_train_PhiladelphiaAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],[5,11,18,19,20]]
	y_train_PhiladelphiaAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],24:25]
	
	X_train_PhiladelphiaAll2=df.iloc[[0,1,23,45,67,89,111,133,155,177,199,221,243,287,309,331,353,375,397,419,441,463,485,507,529,551,573,595,617,639],[5,11,18,19,20]]
	y_train_PhiladelphiaAll2=df.iloc[[1,23,45,67,89,111,133,155,177,199,221,243,287,309,331,353,375,397,419,441,463,485,507,529,551,573,595,617,639],24:25]
	
	X_train_PhiladelphiaAll3=df.iloc[[0,2,24,46,68,90,112,134,156,178,200,222,244,288,310,332,354,376,398,420,442,464,486,508,530,552,574,596,618,640],[5,11,18,19,20]]
	y_train_PhiladelphiaAll3=df.iloc[[2,24,46,68,90,112,134,156,178,200,222,244,288,310,332,354,376,398,420,442,464,486,508,530,552,574,596,618,640],24:25]
	
	X_train_PhiladelphiaAll4=df.iloc[[0,3,25,47,69,91,113,135,157,179,201,223,245,289,311,333,355,377,399,421,443,465,487,509,531,553,575,597,619,641],[5,11,18,19,20]]
	y_train_PhiladelphiaAll4=df.iloc[[3,25,47,69,91,113,135,158,179,201,223,245,289,311,333,355,377,399,421,443,465,487,509,531,553,575,597,619,641],24:25]
	
	X_train_PhiladelphiaAll5=df.iloc[[0,4,26,48,70,92,114,136,158,180,202,224,246,290,312,334,356,378,400,422,444,466,488,510,532,554,576,598,620,642],[5,11,18,19,20]]
	y_train_PhiladelphiaAll5=df.iloc[[4,26,48,70,92,114,136,158,180,202,224,246,290,312,334,356,378,400,422,444,466,488,510,532,554,576,598,620,642],24:25]
	
	X_train_PhiladelphiaAll6=df.iloc[[0,5,27,49,71,93,115,137,159,181,203,225,247,291,313,335,357,379,401,423,445,467,489,511,533,555,577,599,621,643],[5,11,18,19,20]]
	y_train_PhiladelphiaAll6=df.iloc[[5,27,49,71,93,115,137,159,181,203,225,247,291,313,335,357,379,401,423,445,467,489,511,533,555,577,599,621,643],24:25]
	
	X_train_PhiladelphiaAll7=df.iloc[[0,6,28,50,72,94,116,138,160,182,204,226,248,292,314,336,358,380,402,424,446,468,490,512,534,556,578,600,622,644],[5,11,18,19,20]]
	y_train_PhiladelphiaAll7=df.iloc[[6,28,50,72,94,116,138,160,182,204,226,248,292,314,336,358,380,402,424,446,468,490,512,534,556,578,600,622,644],24:25]
	
	X_train_PhiladelphiaAll8=df.iloc[[0,7,29,51,73,95,117,139,161,183,205,227,249,293,315,337,359,381,403,425,447,469,491,513,535,557,579,601,623,645],[5,11,18,19,20]]
	y_train_PhiladelphiaAll8=df.iloc[[7,29,51,73,95,117,139,161,183,205,227,249,293,315,337,359,381,403,425,447,469,491,513,535,557,579,601,623,645],24:25]
	
	X_train_PhiladelphiaAll9=df.iloc[[0,8,30,52,74,96,118,140,162,184,206,228,250,294,316,338,360,382,404,426,448,470,492,514,536,558,580,602,624,646],[5,11,18,19,20]]
	y_train_PhiladelphiaAll9=df.iloc[[8,30,52,74,96,118,140,162,184,206,228,250,294,316,338,360,382,404,426,448,470,492,514,536,558,580,602,624,646],24:25]
	
	X_train_PhiladelphiaAll10=df.iloc[[0,9,31,53,75,97,119,141,163,185,207,229,251,295,317,339,361,383,405,427,449,471,493,515,537,559,581,603,625,647],[5,11,18,19,20]]
	y_train_PhiladelphiaAll10=df.iloc[[9,31,53,75,97,119,141,163,185,207,229,251,295,317,339,361,383,405,427,449,471,493,515,537,559,581,603,625,647],24:25]
	
	X_train_PhiladelphiaAll11=df.iloc[[0,10,32,54,76,98,120,142,164,186,208,230,252,296,318,340,362,384,406,428,450,472,494,516,538,560,582,604,626,648],[5,11,18,19,20]]
	y_train_PhiladelphiaAll11=df.iloc[[10,32,54,76,98,120,142,164,186,208,230,252,296,318,340,362,384,406,428,450,472,494,516,538,560,582,604,626,648],24:25]
	
	X_train_PhiladelphiaAll12=df.iloc[[0,11,33,55,77,99,121,143,165,187,209,231,253,297,319,341,363,385,407,429,451,473,495,517,539,561,583,605,627,649],[5,11,18,19,20]]
	y_train_PhiladelphiaAll12=df.iloc[[11,33,55,77,99,121,143,165,187,209,231,253,297,319,341,363,385,407,429,451,473,495,517,539,561,583,605,627,649],24:25]
	
	X_train_PhiladelphiaAll13=df.iloc[[0,12,34,56,78,100,122,144,166,188,210,232,254,298,320,342,364,386,408,430,452,474,496,518,540,562,584,606,628,650],[5,11,18,19,20]]
	y_train_PhiladelphiaAll13=df.iloc[[12,34,56,78,100,122,144,166,188,210,232,254,298,320,342,364,386,408,430,452,474,496,518,540,562,584,606,628,650],24:25]
	
	X_train_PhiladelphiaAll14=df.iloc[[0,13,35,57,79,101,123,145,167,189,211,233,255,299,321,343,365,387,409,431,453,475,497,519,541,563,585,607,629,651],[5,11,18,19,20]]
	y_train_PhiladelphiaAll14=df.iloc[[13,35,57,79,101,123,145,167,189,211,233,255,299,321,343,365,387,409,431,453,475,497,519,541,563,585,607,629,651],24:25]
	
	X_train_PhiladelphiaAll15=df.iloc[[0,14,36,58,80,102,124,146,168,190,212,234,256,300,322,344,366,388,410,432,454,476,498,520,542,564,586,608,630,652],[5,11,18,19,20]]
	y_train_PhiladelphiaAll15=df.iloc[[14,36,58,80,102,124,146,168,190,212,234,256,300,322,344,366,388,410,432,454,476,498,520,542,564,586,608,630,652],24:25]
	
	X_train_PhiladelphiaAll16=df.iloc[[0,15,37,59,81,103,125,147,169,191,213,235,257,301,323,345,367,389,411,433,455,477,499,521,543,565,587,609,631,653],[5,11,18,19,20]]
	y_train_PhiladelphiaAll16=df.iloc[[15,37,59,81,103,125,147,169,191,213,235,257,301,323,345,367,389,411,433,455,477,499,521,543,565,587,609,631,653],24:25]
	
	X_train_PhiladelphiaAll17=df.iloc[[0,16,38,60,82,104,126,148,170,192,214,236,258,302,324,346,368,390,412,434,456,478,500,522,544,566,588,610,632,654],[5,11,18,19,20]]
	y_train_PhiladelphiaAll17=df.iloc[[16,38,60,82,104,126,148,170,192,214,236,258,302,324,346,368,390,412,434,456,478,500,522,544,566,588,610,632,654],24:25]
	
	X_train_PhiladelphiaAll18=df.iloc[[0,17,39,61,83,105,127,149,171,193,215,237,259,303,325,347,369,391,413,435,457,479,501,523,545,567,589,611,633,655],[5,11,18,19,20]]
	y_train_PhiladelphiaAll18=df.iloc[[17,39,61,83,105,127,149,171,193,215,237,259,303,325,347,369,391,413,435,457,479,501,523,545,567,589,611,633,655],24:25]
	
	X_train_PhiladelphiaAll19=df.iloc[[0,18,40,62,84,106,128,150,172,194,216,238,260,304,326,348,370,392,414,436,458,480,502,524,546,568,590,612,634,656],[5,11,18,19,20]]
	y_train_PhiladelphiaAll19=df.iloc[[18,40,62,84,106,128,150,172,194,216,238,260,304,326,348,370,392,414,436,458,480,502,524,546,568,590,612,634,656],24:25]
	
	X_train_PhiladelphiaAll20=df.iloc[[0,19,41,63,85,107,129,151,173,195,217,239,261,305,327,349,371,393,415,437,459,481,503,525,547,569,591,613,635,657],[5,11,18,19,20]]
	y_train_PhiladelphiaAll20=df.iloc[[19,41,63,85,107,129,151,173,195,217,239,261,305,327,349,371,393,415,437,459,481,503,525,547,569,591,613,635,657],24:25]
	
	X_train_PhiladelphiaAll21=df.iloc[[0,20,42,64,86,108,130,152,174,196,218,240,262,306,328,350,372,394,416,438,460,482,504,526,548,570,592,614,636,658],[5,11,18,19,20]]
	y_train_PhiladelphiaAll21=df.iloc[[20,42,64,86,108,130,152,174,196,218,240,262,306,328,350,372,394,416,438,460,482,504,526,548,570,592,614,636,658],24:25]
	
	X_train_PhiladelphiaAll22=df.iloc[[0,21,43,65,87,109,131,153,175,197,219,241,263,307,329,351,373,395,417,439,461,483,505,527,549,571,593,615,637,659],[5,11,18,19,20]]
	y_train_PhiladelphiaAll22=df.iloc[[21,43,65,87,109,131,153,175,197,219,241,263,307,329,351,373,395,417,439,461,483,505,527,549,571,593,615,637,659],24:25]

# %%
regressorPhiladelphia1 = LinearRegression()
regressorPhiladelphia1.fit(X_train_PhiladelphiaAll1, y_train_PhiladelphiaAll1)
pd.DataFrame(list(zip(X_train_PhiladelphiaAll1, regressorPhiladelphia1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_Philadelphia1 = regressorPhiladelphia1.predict(X_train_Philadelphia1)

# %%
y_train_PhiladelphiaAll2.loc[-1] = y_pred_Philadelphia1.item(0)  # adding a row
y_train_PhiladelphiaAll2.index = y_train_PhiladelphiaAll2.index + 1  # shifting index
y_train_PhiladelphiaAll2 = y_train_PhiladelphiaAll2.sort_index()
regressorPhiladelphia2 = LinearRegression()
regressorPhiladelphia2.fit(X_train_PhiladelphiaAll2, y_train_PhiladelphiaAll2)

pd.DataFrame(list(zip(X_train_PhiladelphiaAll2, regressorPhiladelphia2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Philadelphia2 = regressorPhiladelphia2.predict(X_train_Philadelphia2)

y_train_PhiladelphiaAll3.loc[-1] = y_pred_Philadelphia2.item(0)  # adding a row
y_train_PhiladelphiaAll3.index = y_train_PhiladelphiaAll3.index + 1  # shifting index
y_train_PhiladelphiaAll3 = y_train_PhiladelphiaAll3.sort_index()
regressorPhiladelphia3 = LinearRegression()
regressorPhiladelphia3.fit(X_train_PhiladelphiaAll3, y_train_PhiladelphiaAll3)

pd.DataFrame(list(zip(X_train_PhiladelphiaAll3, regressorPhiladelphia3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Philadelphia3 = regressorPhiladelphia3.predict(X_train_Philadelphia3)

y_train_PhiladelphiaAll4.loc[-1] = y_pred_Philadelphia3.item(0)  # adding a row
y_train_PhiladelphiaAll4.index = y_train_PhiladelphiaAll4.index + 1  # shifting index
y_train_PhiladelphiaAll4 = y_train_PhiladelphiaAll4.sort_index()
regressorPhiladelphia4 = LinearRegression()
regressorPhiladelphia4.fit(X_train_PhiladelphiaAll4, y_train_PhiladelphiaAll4)

pd.DataFrame(list(zip(X_train_PhiladelphiaAll4, regressorPhiladelphia4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Philadelphia4 = regressorPhiladelphia4.predict(X_train_Philadelphia4)

y_train_PhiladelphiaAll5.loc[-1] = y_pred_Philadelphia4.item(0)  # adding a row
y_train_PhiladelphiaAll5.index = y_train_PhiladelphiaAll5.index + 1  # shifting index
y_train_PhiladelphiaAll5 = y_train_PhiladelphiaAll5.sort_index()
regressorPhiladelphia5 = LinearRegression()
regressorPhiladelphia5.fit(X_train_PhiladelphiaAll5, y_train_PhiladelphiaAll5)

pd.DataFrame(list(zip(X_train_PhiladelphiaAll5, regressorPhiladelphia5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Philadelphia5 = regressorPhiladelphia5.predict(X_train_Philadelphia5)

y_train_PhiladelphiaAll6.loc[-1] = y_pred_Philadelphia5.item(0)  # adding a row
y_train_PhiladelphiaAll6.index = y_train_PhiladelphiaAll6.index + 1  # shifting index
y_train_PhiladelphiaAll6 = y_train_PhiladelphiaAll6.sort_index()
regressorPhiladelphia6 = LinearRegression()
regressorPhiladelphia6.fit(X_train_PhiladelphiaAll6, y_train_PhiladelphiaAll6)

pd.DataFrame(list(zip(X_train_PhiladelphiaAll6, regressorPhiladelphia6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Philadelphia6 = regressorPhiladelphia6.predict(X_train_Philadelphia6)

y_train_PhiladelphiaAll7.loc[-1] = y_pred_Philadelphia6.item(0)  # adding a row
y_train_PhiladelphiaAll7.index = y_train_PhiladelphiaAll7.index + 1  # shifting index
y_train_PhiladelphiaAll7 = y_train_PhiladelphiaAll7.sort_index()
regressorPhiladelphia7 = LinearRegression()
regressorPhiladelphia7.fit(X_train_PhiladelphiaAll7, y_train_PhiladelphiaAll7)

pd.DataFrame(list(zip(X_train_PhiladelphiaAll7, regressorPhiladelphia7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Philadelphia7 = regressorPhiladelphia7.predict(X_train_Philadelphia7)

y_train_PhiladelphiaAll8.loc[-1] = y_pred_Philadelphia7.item(0)  # adding a row
y_train_PhiladelphiaAll8.index = y_train_PhiladelphiaAll8.index + 1  # shifting index
y_train_PhiladelphiaAll8 = y_train_PhiladelphiaAll8.sort_index()
regressorPhiladelphia8 = LinearRegression()
regressorPhiladelphia8.fit(X_train_PhiladelphiaAll8, y_train_PhiladelphiaAll8)

pd.DataFrame(list(zip(X_train_PhiladelphiaAll8, regressorPhiladelphia8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Philadelphia8 = regressorPhiladelphia8.predict(X_train_Philadelphia8)

y_train_PhiladelphiaAll9.loc[-1] = y_pred_Philadelphia8.item(0)  # adding a row
y_train_PhiladelphiaAll9.index = y_train_PhiladelphiaAll9.index + 1  # shifting index
y_train_PhiladelphiaAll9 = y_train_PhiladelphiaAll9.sort_index()
regressorPhiladelphia9 = LinearRegression()
regressorPhiladelphia9.fit(X_train_PhiladelphiaAll9, y_train_PhiladelphiaAll9)

pd.DataFrame(list(zip(X_train_PhiladelphiaAll9, regressorPhiladelphia9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Philadelphia9 = regressorPhiladelphia9.predict(X_train_Philadelphia9)

y_train_PhiladelphiaAll10.loc[-1] = y_pred_Philadelphia9.item(0)  # adding a row
y_train_PhiladelphiaAll10.index = y_train_PhiladelphiaAll10.index + 1  # shifting index
y_train_PhiladelphiaAll10 = y_train_PhiladelphiaAll10.sort_index()
regressorPhiladelphia10 = LinearRegression()
regressorPhiladelphia10.fit(X_train_PhiladelphiaAll10, y_train_PhiladelphiaAll10)

pd.DataFrame(list(zip(X_train_PhiladelphiaAll10, regressorPhiladelphia10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Philadelphia10 = regressorPhiladelphia10.predict(X_train_Philadelphia10)

y_train_PhiladelphiaAll11.loc[-1] = y_pred_Philadelphia10.item(0)  # adding a row
y_train_PhiladelphiaAll11.index = y_train_PhiladelphiaAll11.index + 1  # shifting index
y_train_PhiladelphiaAll11 = y_train_PhiladelphiaAll11.sort_index()
regressorPhiladelphia11 = LinearRegression()
regressorPhiladelphia11.fit(X_train_PhiladelphiaAll11, y_train_PhiladelphiaAll11)

pd.DataFrame(list(zip(X_train_PhiladelphiaAll11, regressorPhiladelphia11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Philadelphia11 = regressorPhiladelphia11.predict(X_train_Philadelphia11)

y_train_PhiladelphiaAll12.loc[-1] = y_pred_Philadelphia11.item(0)  # adding a row
y_train_PhiladelphiaAll12.index = y_train_PhiladelphiaAll12.index + 1  # shifting index
y_train_PhiladelphiaAll12 = y_train_PhiladelphiaAll12.sort_index()
regressorPhiladelphia12 = LinearRegression()
regressorPhiladelphia12.fit(X_train_PhiladelphiaAll12, y_train_PhiladelphiaAll12)

pd.DataFrame(list(zip(X_train_PhiladelphiaAll12, regressorPhiladelphia12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Philadelphia12 = regressorPhiladelphia12.predict(X_train_Philadelphia12)

y_train_PhiladelphiaAll13.loc[-1] = y_pred_Philadelphia12.item(0)  # adding a row
y_train_PhiladelphiaAll13.index = y_train_PhiladelphiaAll13.index + 1  # shifting index
y_train_PhiladelphiaAll13 = y_train_PhiladelphiaAll13.sort_index()
regressorPhiladelphia13 = LinearRegression()
regressorPhiladelphia13.fit(X_train_PhiladelphiaAll13, y_train_PhiladelphiaAll13)

pd.DataFrame(list(zip(X_train_PhiladelphiaAll13, regressorPhiladelphia13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Philadelphia13 = regressorPhiladelphia13.predict(X_train_Philadelphia13)

y_train_PhiladelphiaAll14.loc[-1] = y_pred_Philadelphia13.item(0)  # adding a row
y_train_PhiladelphiaAll14.index = y_train_PhiladelphiaAll14.index + 1  # shifting index
y_train_PhiladelphiaAll14 = y_train_PhiladelphiaAll14.sort_index()
regressorPhiladelphia14 = LinearRegression()
regressorPhiladelphia14.fit(X_train_PhiladelphiaAll14, y_train_PhiladelphiaAll14)

pd.DataFrame(list(zip(X_train_PhiladelphiaAll14, regressorPhiladelphia14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Philadelphia14 = regressorPhiladelphia14.predict(X_train_Philadelphia14)

y_train_PhiladelphiaAll15.loc[-1] = y_pred_Philadelphia14.item(0)  # adding a row
y_train_PhiladelphiaAll15.index = y_train_PhiladelphiaAll15.index + 1  # shifting index
y_train_PhiladelphiaAll15 = y_train_PhiladelphiaAll15.sort_index()
regressorPhiladelphia15 = LinearRegression()
regressorPhiladelphia15.fit(X_train_PhiladelphiaAll15, y_train_PhiladelphiaAll15)

pd.DataFrame(list(zip(X_train_PhiladelphiaAll15, regressorPhiladelphia15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Philadelphia15 = regressorPhiladelphia15.predict(X_train_Philadelphia15)

y_train_PhiladelphiaAll16.loc[-1] = y_pred_Philadelphia15.item(0)  # adding a row
y_train_PhiladelphiaAll16.index = y_train_PhiladelphiaAll16.index + 1  # shifting index
y_train_PhiladelphiaAll16 = y_train_PhiladelphiaAll16.sort_index()
regressorPhiladelphia16 = LinearRegression()
regressorPhiladelphia16.fit(X_train_PhiladelphiaAll16, y_train_PhiladelphiaAll16)

pd.DataFrame(list(zip(X_train_PhiladelphiaAll16, regressorPhiladelphia16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Philadelphia16 = regressorPhiladelphia16.predict(X_train_Philadelphia16)

y_train_PhiladelphiaAll17.loc[-1] = y_pred_Philadelphia16.item(0)  # adding a row
y_train_PhiladelphiaAll17.index = y_train_PhiladelphiaAll17.index + 1  # shifting index
y_train_PhiladelphiaAll17 = y_train_PhiladelphiaAll17.sort_index()
regressorPhiladelphia17 = LinearRegression()
regressorPhiladelphia17.fit(X_train_PhiladelphiaAll17, y_train_PhiladelphiaAll17)

pd.DataFrame(list(zip(X_train_PhiladelphiaAll17, regressorPhiladelphia17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Philadelphia17 = regressorPhiladelphia17.predict(X_train_Philadelphia17)

y_train_PhiladelphiaAll18.loc[-1] = y_pred_Philadelphia17.item(0)  # adding a row
y_train_PhiladelphiaAll18.index = y_train_PhiladelphiaAll18.index + 1  # shifting index
y_train_PhiladelphiaAll18 = y_train_PhiladelphiaAll18.sort_index()
regressorPhiladelphia18 = LinearRegression()
regressorPhiladelphia18.fit(X_train_PhiladelphiaAll18, y_train_PhiladelphiaAll18)

pd.DataFrame(list(zip(X_train_PhiladelphiaAll18, regressorPhiladelphia18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Philadelphia18 = regressorPhiladelphia18.predict(X_train_Philadelphia18)

y_train_PhiladelphiaAll19.loc[-1] = y_pred_Philadelphia18.item(0)  # adding a row
y_train_PhiladelphiaAll19.index = y_train_PhiladelphiaAll19.index + 1  # shifting index
y_train_PhiladelphiaAll19 = y_train_PhiladelphiaAll19.sort_index()
regressorPhiladelphia19 = LinearRegression()
regressorPhiladelphia19.fit(X_train_PhiladelphiaAll19, y_train_PhiladelphiaAll19)

pd.DataFrame(list(zip(X_train_PhiladelphiaAll19, regressorPhiladelphia19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Philadelphia19 = regressorPhiladelphia19.predict(X_train_Philadelphia19)

y_train_PhiladelphiaAll20.loc[-1] = y_pred_Philadelphia19.item(0)  # adding a row
y_train_PhiladelphiaAll20.index = y_train_PhiladelphiaAll20.index + 1  # shifting index
y_train_PhiladelphiaAll20 = y_train_PhiladelphiaAll20.sort_index()
regressorPhiladelphia20 = LinearRegression()
regressorPhiladelphia20.fit(X_train_PhiladelphiaAll20, y_train_PhiladelphiaAll20)

pd.DataFrame(list(zip(X_train_PhiladelphiaAll20, regressorPhiladelphia20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Philadelphia20 = regressorPhiladelphia20.predict(X_train_Philadelphia20)

y_train_PhiladelphiaAll21.loc[-1] = y_pred_Philadelphia20.item(0)  # adding a row
y_train_PhiladelphiaAll21.index = y_train_PhiladelphiaAll21.index + 1  # shifting index
y_train_PhiladelphiaAll21 = y_train_PhiladelphiaAll21.sort_index()
regressorPhiladelphia21 = LinearRegression()
regressorPhiladelphia21.fit(X_train_PhiladelphiaAll21, y_train_PhiladelphiaAll21)

pd.DataFrame(list(zip(X_train_PhiladelphiaAll21, regressorPhiladelphia21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Philadelphia21 = regressorPhiladelphia21.predict(X_train_Philadelphia21)

# %%
	X_train_Cleveland1=X_Cleveland[0:1]
	y_train_Cleveland1=y_Cleveland[0:1]
	X_train_Cleveland2=X_Cleveland[1:2]
	y_train_Cleveland2=y_Cleveland[1:2]
	X_train_Cleveland3=X_Cleveland[2:3]
	y_train_Cleveland3=y_Cleveland[2:3]
	X_train_Cleveland4=X_Cleveland[3:4]
	y_train_Cleveland4=y_Cleveland[3:4]
	X_train_Cleveland5=X_Cleveland[4:5]
	y_train_Cleveland5=y_Cleveland[4:5]
	y_train_Cleveland6=y_Cleveland[5:6]
	X_train_Cleveland7=X_Cleveland[7:8]
	X_train_Cleveland6=X_Cleveland[5:6]
	y_train_Cleveland7=y_Cleveland[7:8]
	X_train_Cleveland8=X_Cleveland[8:9]
	y_train_Cleveland8=y_Cleveland[8:9]
	X_train_Cleveland9=X_Cleveland[9:10]
	y_train_Cleveland9=y_Cleveland[9:10]
	X_train_Cleveland10=X_Cleveland[10:11]
	y_train_Cleveland10=y_Cleveland[10:11]
	X_train_Cleveland11=X_Cleveland[11:12]
	y_train_Cleveland11=y_Cleveland[11:12]
	X_train_Cleveland12=X_Cleveland[12:13]
	y_train_Cleveland12=y_Cleveland[12:13]
	X_train_Cleveland13=X_Cleveland[13:14]
	y_train_Cleveland13=y_Cleveland[13:14]
	X_train_Cleveland14=X_Cleveland[14:15]
	y_train_Cleveland14=y_Cleveland[14:15]
	X_train_Cleveland15=X_Cleveland[15:16]
	y_train_Cleveland15=y_Cleveland[15:16]
	X_train_Cleveland16=X_Cleveland[16:17]
	y_train_Cleveland16=y_Cleveland[16:17]
	X_train_Cleveland17=X_Cleveland[17:18]
	y_train_Cleveland17=y_Cleveland[17:18]
	X_train_Cleveland18=X_Cleveland[18:19]
	y_train_Cleveland18=y_Cleveland[18:19]
	X_train_Cleveland19=X_Cleveland[19:20]
	y_train_Cleveland19=y_Cleveland[19:20]
	X_train_Cleveland20=X_Cleveland[20:21]
	y_train_Cleveland20=y_Cleveland[20:21]
	X_train_Cleveland21=X_Cleveland[21:22]
	y_train_Cleveland21=y_Cleveland[21:22]
	X_train_Cleveland22=X_Cleveland[22:23]
	y_train_Cleveland22=y_Cleveland[22:23]
	
	X_train_ClevelandAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],[5,11,18,19,20]]
	y_train_ClevelandAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],24:25]
	
	X_train_ClevelandAll2=df.iloc[[0,1,23,45,67,89,111,133,155,177,199,221,243,265,309,331,353,375,397,419,441,463,485,507,529,551,573,595,617,639],[5,11,18,19,20]]
	y_train_ClevelandAll2=df.iloc[[1,23,45,67,89,111,133,155,177,199,221,243,265,309,331,353,375,397,419,441,463,485,507,529,551,573,595,617,639],24:25]
	
	X_train_ClevelandAll3=df.iloc[[0,2,24,46,68,90,112,134,156,178,200,222,244,266,310,332,354,376,398,420,442,464,486,508,530,552,574,596,618,640],[5,11,18,19,20]]
	y_train_ClevelandAll3=df.iloc[[2,24,46,68,90,112,134,156,178,200,222,244,266,310,332,354,376,398,420,442,464,486,508,530,552,574,596,618,640],24:25]
	
	X_train_ClevelandAll4=df.iloc[[0,3,25,47,69,91,113,135,157,179,201,223,245,267,311,333,355,377,399,421,443,465,487,509,531,553,575,597,619,641],[5,11,18,19,20]]
	y_train_ClevelandAll4=df.iloc[[3,25,47,69,91,113,135,158,179,201,223,245,267,311,333,355,377,399,421,443,465,487,509,531,553,575,597,619,641],24:25]
	
	X_train_ClevelandAll5=df.iloc[[0,4,26,48,70,92,114,136,158,180,202,224,246,268,312,334,356,378,400,422,444,466,488,510,532,554,576,598,620,642],[5,11,18,19,20]]
	y_train_ClevelandAll5=df.iloc[[4,26,48,70,92,114,136,158,180,202,224,246,268,312,334,356,378,400,422,444,466,488,510,532,554,576,598,620,642],24:25]
	
	X_train_ClevelandAll6=df.iloc[[0,5,27,49,71,93,115,137,159,181,203,225,247,269,313,335,357,379,401,423,445,467,489,511,533,555,577,599,621,643],[5,11,18,19,20]]
	y_train_ClevelandAll6=df.iloc[[5,27,49,71,93,115,137,159,181,203,225,247,269,313,335,357,379,401,423,445,467,489,511,533,555,577,599,621,643],24:25]
	
	X_train_ClevelandAll7=df.iloc[[0,6,28,50,72,94,116,138,160,182,204,226,248,270,314,336,358,380,402,424,446,468,490,512,534,556,578,600,622,644],[5,11,18,19,20]]
	y_train_ClevelandAll7=df.iloc[[6,28,50,72,94,116,138,160,182,204,226,248,270,314,336,358,380,402,424,446,468,490,512,534,556,578,600,622,644],24:25]
	
	X_train_ClevelandAll8=df.iloc[[0,7,29,51,73,95,117,139,161,183,205,227,249,271,315,337,359,381,403,425,447,469,491,513,535,557,579,601,623,645],[5,11,18,19,20]]
	y_train_ClevelandAll8=df.iloc[[7,29,51,73,95,117,139,161,183,205,227,249,271,315,337,359,381,403,425,447,469,491,513,535,557,579,601,623,645],24:25]
	
	X_train_ClevelandAll9=df.iloc[[0,8,30,52,74,96,118,140,162,184,206,228,250,272,316,338,360,382,404,426,448,470,492,514,536,558,580,602,624,646],[5,11,18,19,20]]
	y_train_ClevelandAll9=df.iloc[[8,30,52,74,96,118,140,162,184,206,228,250,272,316,338,360,382,404,426,448,470,492,514,536,558,580,602,624,646],24:25]
	
	X_train_ClevelandAll10=df.iloc[[0,9,31,53,75,97,119,141,163,185,207,229,251,273,317,339,361,383,405,427,449,471,493,515,537,559,581,603,625,647],[5,11,18,19,20]]
	y_train_ClevelandAll10=df.iloc[[9,31,53,75,97,119,141,163,185,207,229,251,273,317,339,361,383,405,427,449,471,493,515,537,559,581,603,625,647],24:25]
	
	X_train_ClevelandAll11=df.iloc[[0,10,32,54,76,98,120,142,164,186,208,230,252,274,318,340,362,384,406,428,450,472,494,516,538,560,582,604,626,648],[5,11,18,19,20]]
	y_train_ClevelandAll11=df.iloc[[10,32,54,76,98,120,142,164,186,208,230,252,274,318,340,362,384,406,428,450,472,494,516,538,560,582,604,626,648],24:25]
	
	X_train_ClevelandAll12=df.iloc[[0,11,33,55,77,99,121,143,165,187,209,231,253,275,319,341,363,385,407,429,451,473,495,517,539,561,583,605,627,649],[5,11,18,19,20]]
	y_train_ClevelandAll12=df.iloc[[11,33,55,77,99,121,143,165,187,209,231,253,275,319,341,363,385,407,429,451,473,495,517,539,561,583,605,627,649],24:25]
	
	X_train_ClevelandAll13=df.iloc[[0,12,34,56,78,100,122,144,166,188,210,232,254,276,320,342,364,386,408,430,452,474,496,518,540,562,584,606,628,650],[5,11,18,19,20]]
	y_train_ClevelandAll13=df.iloc[[12,34,56,78,100,122,144,166,188,210,232,254,276,320,342,364,386,408,430,452,474,496,518,540,562,584,606,628,650],24:25]
	
	X_train_ClevelandAll14=df.iloc[[0,13,35,57,79,101,123,145,167,189,211,233,255,277,321,343,365,387,409,431,453,475,497,519,541,563,585,607,629,651],[5,11,18,19,20]]
	y_train_ClevelandAll14=df.iloc[[13,35,57,79,101,123,145,167,189,211,233,255,277,321,343,365,387,409,431,453,475,497,519,541,563,585,607,629,651],24:25]
	
	X_train_ClevelandAll15=df.iloc[[0,14,36,58,80,102,124,146,168,190,212,234,256,278,322,344,366,388,410,432,454,476,498,520,542,564,586,608,630,652],[5,11,18,19,20]]
	y_train_ClevelandAll15=df.iloc[[14,36,58,80,102,124,146,168,190,212,234,256,278,322,344,366,388,410,432,454,476,498,520,542,564,586,608,630,652],24:25]
	
	X_train_ClevelandAll16=df.iloc[[0,15,37,59,81,103,125,147,169,191,213,235,257,279,323,345,367,389,411,433,455,477,499,521,543,565,587,609,631,653],[5,11,18,19,20]]
	y_train_ClevelandAll16=df.iloc[[15,37,59,81,103,125,147,169,191,213,235,257,279,323,345,367,389,411,433,455,477,499,521,543,565,587,609,631,653],24:25]
	
	X_train_ClevelandAll17=df.iloc[[0,16,38,60,82,104,126,148,170,192,214,236,258,280,324,346,368,390,412,434,456,478,500,522,544,566,588,610,632,654],[5,11,18,19,20]]
	y_train_ClevelandAll17=df.iloc[[16,38,60,82,104,126,148,170,192,214,236,258,280,324,346,368,390,412,434,456,478,500,522,544,566,588,610,632,654],24:25]

	X_train_ClevelandAll18=df.iloc[[0,17,39,61,83,105,127,149,171,193,215,237,259,281,325,347,369,391,413,435,457,479,501,523,545,567,589,611,633,655],[5,11,18,19,20]]
	y_train_ClevelandAll18=df.iloc[[17,39,61,83,105,127,149,171,193,215,237,259,281,325,347,369,391,413,435,457,479,501,523,545,567,589,611,633,655],24:25]
	
	X_train_ClevelandAll19=df.iloc[[0,18,40,62,84,106,128,150,172,194,216,238,260,282,326,348,370,392,414,436,458,480,502,524,546,568,590,612,634,656],[5,11,18,19,20]]
	y_train_ClevelandAll19=df.iloc[[18,40,62,84,106,128,150,172,194,216,238,260,282,326,348,370,392,414,436,458,480,502,524,546,568,590,612,634,656],24:25]
	
	X_train_ClevelandAll20=df.iloc[[0,19,41,63,85,107,129,151,173,195,217,239,261,283,327,349,371,393,415,437,459,481,503,525,547,569,591,613,635,657],[5,11,18,19,20]]
	y_train_ClevelandAll20=df.iloc[[19,41,63,85,107,129,151,173,195,217,239,261,283,327,349,371,393,415,437,459,481,503,525,547,569,591,613,635,657],24:25]
	
	X_train_ClevelandAll21=df.iloc[[0,20,42,64,86,108,130,152,174,196,218,240,262,284,328,350,372,394,416,438,460,482,504,526,548,570,592,614,636,658],[5,11,18,19,20]]
	y_train_ClevelandAll21=df.iloc[[20,42,64,86,108,130,152,174,196,218,240,262,284,328,350,372,394,416,438,460,482,504,526,548,570,592,614,636,658],24:25]
	
	X_train_ClevelandAll22=df.iloc[[0,21,43,65,87,109,131,153,175,197,219,241,263,285,329,351,373,395,417,439,461,483,505,527,549,571,593,615,637,659],[5,11,18,19,20]]
	y_train_ClevelandAll22=df.iloc[[21,43,65,87,109,131,153,175,197,219,241,263,285,329,351,373,395,417,439,461,483,505,527,549,571,593,615,637,659],24:25]

# %%
regressorCleveland1 = LinearRegression()
regressorCleveland1.fit(X_train_ClevelandAll1, y_train_ClevelandAll1)
pd.DataFrame(list(zip(X_train_ClevelandAll1, regressorCleveland1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_Cleveland1 = regressorCleveland1.predict(X_train_Cleveland1)

# %%
y_train_ClevelandAll2.loc[-1] = y_pred_Cleveland1.item(0)  # adding a row
y_train_ClevelandAll2.index = y_train_ClevelandAll2.index + 1  # shifting index
y_train_ClevelandAll2 = y_train_ClevelandAll2.sort_index()
regressorCleveland2 = LinearRegression()
regressorCleveland2.fit(X_train_ClevelandAll2, y_train_ClevelandAll2)

pd.DataFrame(list(zip(X_train_ClevelandAll2, regressorCleveland2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Cleveland2 = regressorCleveland2.predict(X_train_Cleveland2)

y_train_ClevelandAll3.loc[-1] = y_pred_Cleveland2.item(0)  # adding a row
y_train_ClevelandAll3.index = y_train_ClevelandAll3.index + 1  # shifting index
y_train_ClevelandAll3 = y_train_ClevelandAll3.sort_index()
regressorCleveland3 = LinearRegression()
regressorCleveland3.fit(X_train_ClevelandAll3, y_train_ClevelandAll3)

pd.DataFrame(list(zip(X_train_ClevelandAll3, regressorCleveland3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Cleveland3 = regressorCleveland3.predict(X_train_Cleveland3)

y_train_ClevelandAll4.loc[-1] = y_pred_Cleveland3.item(0)  # adding a row
y_train_ClevelandAll4.index = y_train_ClevelandAll4.index + 1  # shifting index
y_train_ClevelandAll4 = y_train_ClevelandAll4.sort_index()
regressorCleveland4 = LinearRegression()
regressorCleveland4.fit(X_train_ClevelandAll4, y_train_ClevelandAll4)

pd.DataFrame(list(zip(X_train_ClevelandAll4, regressorCleveland4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Cleveland4 = regressorCleveland4.predict(X_train_Cleveland4)

y_train_ClevelandAll5.loc[-1] = y_pred_Cleveland4.item(0)  # adding a row
y_train_ClevelandAll5.index = y_train_ClevelandAll5.index + 1  # shifting index
y_train_ClevelandAll5 = y_train_ClevelandAll5.sort_index()
regressorCleveland5 = LinearRegression()
regressorCleveland5.fit(X_train_ClevelandAll5, y_train_ClevelandAll5)

pd.DataFrame(list(zip(X_train_ClevelandAll5, regressorCleveland5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Cleveland5 = regressorCleveland5.predict(X_train_Cleveland5)

y_train_ClevelandAll6.loc[-1] = y_pred_Cleveland5.item(0)  # adding a row
y_train_ClevelandAll6.index = y_train_ClevelandAll6.index + 1  # shifting index
y_train_ClevelandAll6 = y_train_ClevelandAll6.sort_index()
regressorCleveland6 = LinearRegression()
regressorCleveland6.fit(X_train_ClevelandAll6, y_train_ClevelandAll6)

pd.DataFrame(list(zip(X_train_ClevelandAll6, regressorCleveland6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Cleveland6 = regressorCleveland6.predict(X_train_Cleveland6)

y_train_ClevelandAll7.loc[-1] = y_pred_Cleveland6.item(0)  # adding a row
y_train_ClevelandAll7.index = y_train_ClevelandAll7.index + 1  # shifting index
y_train_ClevelandAll7 = y_train_ClevelandAll7.sort_index()
regressorCleveland7 = LinearRegression()
regressorCleveland7.fit(X_train_ClevelandAll7, y_train_ClevelandAll7)

pd.DataFrame(list(zip(X_train_ClevelandAll7, regressorCleveland7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Cleveland7 = regressorCleveland7.predict(X_train_Cleveland7)

y_train_ClevelandAll8.loc[-1] = y_pred_Cleveland7.item(0)  # adding a row
y_train_ClevelandAll8.index = y_train_ClevelandAll8.index + 1  # shifting index
y_train_ClevelandAll8 = y_train_ClevelandAll8.sort_index()
regressorCleveland8 = LinearRegression()
regressorCleveland8.fit(X_train_ClevelandAll8, y_train_ClevelandAll8)

pd.DataFrame(list(zip(X_train_ClevelandAll8, regressorCleveland8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Cleveland8 = regressorCleveland8.predict(X_train_Cleveland8)

y_train_ClevelandAll9.loc[-1] = y_pred_Cleveland8.item(0)  # adding a row
y_train_ClevelandAll9.index = y_train_ClevelandAll9.index + 1  # shifting index
y_train_ClevelandAll9 = y_train_ClevelandAll9.sort_index()
regressorCleveland9 = LinearRegression()
regressorCleveland9.fit(X_train_ClevelandAll9, y_train_ClevelandAll9)

pd.DataFrame(list(zip(X_train_ClevelandAll9, regressorCleveland9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Cleveland9 = regressorCleveland9.predict(X_train_Cleveland9)

y_train_ClevelandAll10.loc[-1] = y_pred_Cleveland9.item(0)  # adding a row
y_train_ClevelandAll10.index = y_train_ClevelandAll10.index + 1  # shifting index
y_train_ClevelandAll10 = y_train_ClevelandAll10.sort_index()
regressorCleveland10 = LinearRegression()
regressorCleveland10.fit(X_train_ClevelandAll10, y_train_ClevelandAll10)

pd.DataFrame(list(zip(X_train_ClevelandAll10, regressorCleveland10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Cleveland10 = regressorCleveland10.predict(X_train_Cleveland10)

y_train_ClevelandAll11.loc[-1] = y_pred_Cleveland10.item(0)  # adding a row
y_train_ClevelandAll11.index = y_train_ClevelandAll11.index + 1  # shifting index
y_train_ClevelandAll11 = y_train_ClevelandAll11.sort_index()
regressorCleveland11 = LinearRegression()
regressorCleveland11.fit(X_train_ClevelandAll11, y_train_ClevelandAll11)

pd.DataFrame(list(zip(X_train_ClevelandAll11, regressorCleveland11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Cleveland11 = regressorCleveland11.predict(X_train_Cleveland11)

y_train_ClevelandAll12.loc[-1] = y_pred_Cleveland11.item(0)  # adding a row
y_train_ClevelandAll12.index = y_train_ClevelandAll12.index + 1  # shifting index
y_train_ClevelandAll12 = y_train_ClevelandAll12.sort_index()
regressorCleveland12 = LinearRegression()
regressorCleveland12.fit(X_train_ClevelandAll12, y_train_ClevelandAll12)

pd.DataFrame(list(zip(X_train_ClevelandAll12, regressorCleveland12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Cleveland12 = regressorCleveland12.predict(X_train_Cleveland12)

y_train_ClevelandAll13.loc[-1] = y_pred_Cleveland12.item(0)  # adding a row
y_train_ClevelandAll13.index = y_train_ClevelandAll13.index + 1  # shifting index
y_train_ClevelandAll13 = y_train_ClevelandAll13.sort_index()
regressorCleveland13 = LinearRegression()
regressorCleveland13.fit(X_train_ClevelandAll13, y_train_ClevelandAll13)

pd.DataFrame(list(zip(X_train_ClevelandAll13, regressorCleveland13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Cleveland13 = regressorCleveland13.predict(X_train_Cleveland13)

y_train_ClevelandAll14.loc[-1] = y_pred_Cleveland13.item(0)  # adding a row
y_train_ClevelandAll14.index = y_train_ClevelandAll14.index + 1  # shifting index
y_train_ClevelandAll14 = y_train_ClevelandAll14.sort_index()
regressorCleveland14 = LinearRegression()
regressorCleveland14.fit(X_train_ClevelandAll14, y_train_ClevelandAll14)

pd.DataFrame(list(zip(X_train_ClevelandAll14, regressorCleveland14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Cleveland14 = regressorCleveland14.predict(X_train_Cleveland14)

y_train_ClevelandAll15.loc[-1] = y_pred_Cleveland14.item(0)  # adding a row
y_train_ClevelandAll15.index = y_train_ClevelandAll15.index + 1  # shifting index
y_train_ClevelandAll15 = y_train_ClevelandAll15.sort_index()
regressorCleveland15 = LinearRegression()
regressorCleveland15.fit(X_train_ClevelandAll15, y_train_ClevelandAll15)

pd.DataFrame(list(zip(X_train_ClevelandAll15, regressorCleveland15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Cleveland15 = regressorCleveland15.predict(X_train_Cleveland15)

y_train_ClevelandAll16.loc[-1] = y_pred_Cleveland15.item(0)  # adding a row
y_train_ClevelandAll16.index = y_train_ClevelandAll16.index + 1  # shifting index
y_train_ClevelandAll16 = y_train_ClevelandAll16.sort_index()
regressorCleveland16 = LinearRegression()
regressorCleveland16.fit(X_train_ClevelandAll16, y_train_ClevelandAll16)

pd.DataFrame(list(zip(X_train_ClevelandAll16, regressorCleveland16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Cleveland16 = regressorCleveland16.predict(X_train_Cleveland16)

y_train_ClevelandAll17.loc[-1] = y_pred_Cleveland16.item(0)  # adding a row
y_train_ClevelandAll17.index = y_train_ClevelandAll17.index + 1  # shifting index
y_train_ClevelandAll17 = y_train_ClevelandAll17.sort_index()
regressorCleveland17 = LinearRegression()
regressorCleveland17.fit(X_train_ClevelandAll17, y_train_ClevelandAll17)

pd.DataFrame(list(zip(X_train_ClevelandAll17, regressorCleveland17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Cleveland17 = regressorCleveland17.predict(X_train_Cleveland17)

y_train_ClevelandAll18.loc[-1] = y_pred_Cleveland17.item(0)  # adding a row
y_train_ClevelandAll18.index = y_train_ClevelandAll18.index + 1  # shifting index
y_train_ClevelandAll18 = y_train_ClevelandAll18.sort_index()
regressorCleveland18 = LinearRegression()
regressorCleveland18.fit(X_train_ClevelandAll18, y_train_ClevelandAll18)

pd.DataFrame(list(zip(X_train_ClevelandAll18, regressorCleveland18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Cleveland18 = regressorCleveland18.predict(X_train_Cleveland18)

y_train_ClevelandAll19.loc[-1] = y_pred_Cleveland18.item(0)  # adding a row
y_train_ClevelandAll19.index = y_train_ClevelandAll19.index + 1  # shifting index
y_train_ClevelandAll19 = y_train_ClevelandAll19.sort_index()
regressorCleveland19 = LinearRegression()
regressorCleveland19.fit(X_train_ClevelandAll19, y_train_ClevelandAll19)

pd.DataFrame(list(zip(X_train_ClevelandAll19, regressorCleveland19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Cleveland19 = regressorCleveland19.predict(X_train_Cleveland19)

y_train_ClevelandAll20.loc[-1] = y_pred_Cleveland19.item(0)  # adding a row
y_train_ClevelandAll20.index = y_train_ClevelandAll20.index + 1  # shifting index
y_train_ClevelandAll20 = y_train_ClevelandAll20.sort_index()
regressorCleveland20 = LinearRegression()
regressorCleveland20.fit(X_train_ClevelandAll20, y_train_ClevelandAll20)

pd.DataFrame(list(zip(X_train_ClevelandAll20, regressorCleveland20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Cleveland20 = regressorCleveland20.predict(X_train_Cleveland20)

y_train_ClevelandAll21.loc[-1] = y_pred_Cleveland20.item(0)  # adding a row
y_train_ClevelandAll21.index = y_train_ClevelandAll21.index + 1  # shifting index
y_train_ClevelandAll21 = y_train_ClevelandAll21.sort_index()
regressorCleveland21 = LinearRegression()
regressorCleveland21.fit(X_train_ClevelandAll21, y_train_ClevelandAll21)

pd.DataFrame(list(zip(X_train_ClevelandAll21, regressorCleveland21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Cleveland21 = regressorCleveland21.predict(X_train_Cleveland21)

# %%
X_train_Indiana1=X_Indiana[0:1]
y_train_Indiana1=y_Indiana[0:1]
X_train_Indiana2=X_Indiana[1:2]
y_train_Indiana2=y_Indiana[1:2]
X_train_Indiana3=X_Indiana[2:3]
y_train_Indiana3=y_Indiana[2:3]
X_train_Indiana4=X_Indiana[3:4]
y_train_Indiana4=y_Indiana[3:4]
X_train_Indiana5=X_Indiana[4:5]
y_train_Indiana5=y_Indiana[4:5]
y_train_Indiana6=y_Indiana[5:6]
X_train_Indiana7=X_Indiana[7:8]
X_train_Indiana6=X_Indiana[5:6]
y_train_Indiana7=y_Indiana[7:8]
X_train_Indiana8=X_Indiana[8:9]
y_train_Indiana8=y_Indiana[8:9]
X_train_Indiana9=X_Indiana[9:10]
y_train_Indiana9=y_Indiana[9:10]
X_train_Indiana10=X_Indiana[10:11]
y_train_Indiana10=y_Indiana[10:11]
X_train_Indiana11=X_Indiana[11:12]
y_train_Indiana11=y_Indiana[11:12]
X_train_Indiana12=X_Indiana[12:13]
y_train_Indiana12=y_Indiana[12:13]
X_train_Indiana13=X_Indiana[13:14]
y_train_Indiana13=y_Indiana[13:14]
X_train_Indiana14=X_Indiana[14:15]
y_train_Indiana14=y_Indiana[14:15]
X_train_Indiana15=X_Indiana[15:16]
y_train_Indiana15=y_Indiana[15:16]
X_train_Indiana16=X_Indiana[16:17]
y_train_Indiana16=y_Indiana[16:17]
X_train_Indiana17=X_Indiana[17:18]
y_train_Indiana17=y_Indiana[17:18]
X_train_Indiana18=X_Indiana[18:19]
y_train_Indiana18=y_Indiana[18:19]
X_train_Indiana19=X_Indiana[19:20]
y_train_Indiana19=y_Indiana[19:20]
X_train_Indiana20=X_Indiana[20:21]
y_train_Indiana20=y_Indiana[20:21]
X_train_Indiana21=X_Indiana[21:22]
y_train_Indiana21=y_Indiana[21:22]
X_train_Indiana22=X_Indiana[22:23]
y_train_Indiana22=y_Indiana[22:23]

X_train_IndianaAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],[5,11,18,19,20]]
y_train_IndianaAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,330,352,374,396,418,440,462,484,506,528,550,572,594,616,638],24:25]

X_train_IndianaAll2=df.iloc[[0,1,23,45,67,89,111,133,155,177,199,221,243,265,287,331,353,375,397,419,441,463,485,507,529,551,573,595,617,639],[5,11,18,19,20]]
y_train_IndianaAll2=df.iloc[[1,23,45,67,89,111,133,155,177,199,221,243,265,287,331,353,375,397,419,441,463,485,507,529,551,573,595,617,639],24:25]

X_train_IndianaAll3=df.iloc[[0,2,24,46,68,90,112,134,156,178,200,222,244,266,288,332,354,376,398,420,442,464,486,508,530,552,574,596,618,640],[5,11,18,19,20]]
y_train_IndianaAll3=df.iloc[[2,24,46,68,90,112,134,156,178,200,222,244,266,288,332,354,376,398,420,442,464,486,508,530,552,574,596,618,640],24:25]

X_train_IndianaAll4=df.iloc[[0,3,25,47,69,91,113,135,157,179,201,223,245,267,289,333,355,377,399,421,443,465,487,509,531,553,575,597,619,641],[5,11,18,19,20]]
y_train_IndianaAll4=df.iloc[[3,25,47,69,91,113,135,158,179,201,223,245,267,289,333,355,377,399,421,443,465,487,509,531,553,575,597,619,641],24:25]

X_train_IndianaAll5=df.iloc[[0,4,26,48,70,92,114,136,158,180,202,224,246,268,290,334,356,378,400,422,444,466,488,510,532,554,576,598,620,642],[5,11,18,19,20]]
y_train_IndianaAll5=df.iloc[[4,26,48,70,92,114,136,158,180,202,224,246,268,290,334,356,378,400,422,444,466,488,510,532,554,576,598,620,642],24:25]

X_train_IndianaAll6=df.iloc[[0,5,27,49,71,93,115,137,159,181,203,225,247,269,291,335,357,379,401,423,445,467,489,511,533,555,577,599,621,643],[5,11,18,19,20]]
y_train_IndianaAll6=df.iloc[[5,27,49,71,93,115,137,159,181,203,225,247,269,291,335,357,379,401,423,445,467,489,511,533,555,577,599,621,643],24:25]

X_train_IndianaAll7=df.iloc[[0,6,28,50,72,94,116,138,160,182,204,226,248,270,292,336,358,380,402,424,446,468,490,512,534,556,578,600,622,644],[5,11,18,19,20]]
y_train_IndianaAll7=df.iloc[[6,28,50,72,94,116,138,160,182,204,226,248,270,292,336,358,380,402,424,446,468,490,512,534,556,578,600,622,644],24:25]

X_train_IndianaAll8=df.iloc[[0,7,29,51,73,95,117,139,161,183,205,227,249,271,293,337,359,381,403,425,447,469,491,513,535,557,579,601,623,645],[5,11,18,19,20]]
y_train_IndianaAll8=df.iloc[[7,29,51,73,95,117,139,161,183,205,227,249,271,293,337,359,381,403,425,447,469,491,513,535,557,579,601,623,645],24:25]

X_train_IndianaAll9=df.iloc[[0,8,30,52,74,96,118,140,162,184,206,228,250,272,294,338,360,382,404,426,448,470,492,514,536,558,580,602,624,646],[5,11,18,19,20]]
y_train_IndianaAll9=df.iloc[[8,30,52,74,96,118,140,162,184,206,228,250,272,294,338,360,382,404,426,448,470,492,514,536,558,580,602,624,646],24:25]

X_train_IndianaAll10=df.iloc[[0,9,31,53,75,97,119,141,163,185,207,229,251,273,295,339,361,383,405,427,449,471,493,515,537,559,581,603,625,647],[5,11,18,19,20]]
y_train_IndianaAll10=df.iloc[[9,31,53,75,97,119,141,163,185,207,229,251,273,295,339,361,383,405,427,449,471,493,515,537,559,581,603,625,647],24:25]

X_train_IndianaAll11=df.iloc[[0,10,32,54,76,98,120,142,164,186,208,230,252,274,296,340,362,384,406,428,450,472,494,516,538,560,582,604,626,648],[5,11,18,19,20]]
y_train_IndianaAll11=df.iloc[[10,32,54,76,98,120,142,164,186,208,230,252,274,296,340,362,384,406,428,450,472,494,516,538,560,582,604,626,648],24:25]

X_train_IndianaAll12=df.iloc[[0,11,33,55,77,99,121,143,165,187,209,231,253,275,297,341,363,385,407,429,451,473,495,517,539,561,583,605,627,649],[5,11,18,19,20]]
y_train_IndianaAll12=df.iloc[[11,33,55,77,99,121,143,165,187,209,231,253,275,297,341,363,385,407,429,451,473,495,517,539,561,583,605,627,649],24:25]

X_train_IndianaAll13=df.iloc[[0,12,34,56,78,100,122,144,166,188,210,232,254,276,298,342,364,386,408,430,452,474,496,518,540,562,584,606,628,650],[5,11,18,19,20]]
y_train_IndianaAll13=df.iloc[[12,34,56,78,100,122,144,166,188,210,232,254,276,298,342,364,386,408,430,452,474,496,518,540,562,584,606,628,650],24:25]

X_train_IndianaAll14=df.iloc[[0,13,35,57,79,101,123,145,167,189,211,233,255,277,299,343,365,387,409,431,453,475,497,519,541,563,585,607,629,651],[5,11,18,19,20]]
y_train_IndianaAll14=df.iloc[[13,35,57,79,101,123,145,167,189,211,233,255,277,299,343,365,387,409,431,453,475,497,519,541,563,585,607,629,651],24:25]

X_train_IndianaAll15=df.iloc[[0,14,36,58,80,102,124,146,168,190,212,234,256,278,300,344,366,388,410,432,454,476,498,520,542,564,586,608,630,652],[5,11,18,19,20]]
y_train_IndianaAll15=df.iloc[[14,36,58,80,102,124,146,168,190,212,234,256,278,300,344,366,388,410,432,454,476,498,520,542,564,586,608,630,652],24:25]

X_train_IndianaAll16=df.iloc[[0,15,37,59,81,103,125,147,169,191,213,235,257,279,301,345,367,389,411,433,455,477,499,521,543,565,587,609,631,653],[5,11,18,19,20]]
y_train_IndianaAll16=df.iloc[[15,37,59,81,103,125,147,169,191,213,235,257,279,301,345,367,389,411,433,455,477,499,521,543,565,587,609,631,653],24:25]

X_train_IndianaAll17=df.iloc[[0,16,38,60,82,104,126,148,170,192,214,236,258,280,302,346,368,390,412,434,456,478,500,522,544,566,588,610,632,654],[5,11,18,19,20]]
y_train_IndianaAll17=df.iloc[[16,38,60,82,104,126,148,170,192,214,236,258,280,302,346,368,390,412,434,456,478,500,522,544,566,588,610,632,654],24:25]

X_train_IndianaAll18=df.iloc[[0,17,39,61,83,105,127,149,171,193,215,237,259,281,303,347,369,391,413,435,457,479,501,523,545,567,589,611,633,655],[5,11,18,19,20]]
y_train_IndianaAll18=df.iloc[[17,39,61,83,105,127,149,171,193,215,237,259,281,303,347,369,391,413,435,457,479,501,523,545,567,589,611,633,655],24:25]

X_train_IndianaAll19=df.iloc[[0,18,40,62,84,106,128,150,172,194,216,238,260,282,304,348,370,392,414,436,458,480,502,524,546,568,590,612,634,656],[5,11,18,19,20]]
y_train_IndianaAll19=df.iloc[[18,40,62,84,106,128,150,172,194,216,238,260,282,304,348,370,392,414,436,458,480,502,524,546,568,590,612,634,656],24:25]

X_train_IndianaAll20=df.iloc[[0,19,41,63,85,107,129,151,173,195,217,239,261,283,305,349,371,393,415,437,459,481,503,525,547,569,591,613,635,657],[5,11,18,19,20]]
y_train_IndianaAll20=df.iloc[[19,41,63,85,107,129,151,173,195,217,239,261,283,305,349,371,393,415,437,459,481,503,525,547,569,591,613,635,657],24:25]

X_train_IndianaAll21=df.iloc[[0,20,42,64,86,108,130,152,174,196,218,240,262,284,306,350,372,394,416,438,460,482,504,526,548,570,592,614,636,658],[5,11,18,19,20]]
y_train_IndianaAll21=df.iloc[[20,42,64,86,108,130,152,174,196,218,240,262,284,306,350,372,394,416,438,460,482,504,526,548,570,592,614,636,658],24:25]

X_train_IndianaAll22=df.iloc[[0,21,43,65,87,109,131,153,175,197,219,241,263,285,307,351,373,395,417,439,461,483,505,527,549,571,593,615,637,659],[5,11,18,19,20]]
y_train_IndianaAll22=df.iloc[[21,43,65,87,109,131,153,175,197,219,241,263,285,307,351,373,395,417,439,461,483,505,527,549,571,593,615,637,659],24:25]

# %%
regressorIndiana1 = LinearRegression()
regressorIndiana1.fit(X_train_IndianaAll1, y_train_IndianaAll1)
pd.DataFrame(list(zip(X_train_IndianaAll1, regressorIndiana1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_Indiana1 = regressorIndiana1.predict(X_train_Indiana1)

# %%
y_train_IndianaAll2.loc[-1] = y_pred_Indiana1.item(0)  # adding a row
y_train_IndianaAll2.index = y_train_IndianaAll2.index + 1  # shifting index
y_train_IndianaAll2 = y_train_IndianaAll2.sort_index()
regressorIndiana2 = LinearRegression()
regressorIndiana2.fit(X_train_IndianaAll2, y_train_IndianaAll2)

pd.DataFrame(list(zip(X_train_IndianaAll2, regressorIndiana2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Indiana2 = regressorIndiana2.predict(X_train_Indiana2)

y_train_IndianaAll3.loc[-1] = y_pred_Indiana2.item(0)  # adding a row
y_train_IndianaAll3.index = y_train_IndianaAll3.index + 1  # shifting index
y_train_IndianaAll3 = y_train_IndianaAll3.sort_index()
regressorIndiana3 = LinearRegression()
regressorIndiana3.fit(X_train_IndianaAll3, y_train_IndianaAll3)

pd.DataFrame(list(zip(X_train_IndianaAll3, regressorIndiana3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Indiana3 = regressorIndiana3.predict(X_train_Indiana3)

y_train_IndianaAll4.loc[-1] = y_pred_Indiana3.item(0)  # adding a row
y_train_IndianaAll4.index = y_train_IndianaAll4.index + 1  # shifting index
y_train_IndianaAll4 = y_train_IndianaAll4.sort_index()
regressorIndiana4 = LinearRegression()
regressorIndiana4.fit(X_train_IndianaAll4, y_train_IndianaAll4)

pd.DataFrame(list(zip(X_train_IndianaAll4, regressorIndiana4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Indiana4 = regressorIndiana4.predict(X_train_Indiana4)

y_train_IndianaAll5.loc[-1] = y_pred_Indiana4.item(0)  # adding a row
y_train_IndianaAll5.index = y_train_IndianaAll5.index + 1  # shifting index
y_train_IndianaAll5 = y_train_IndianaAll5.sort_index()
regressorIndiana5 = LinearRegression()
regressorIndiana5.fit(X_train_IndianaAll5, y_train_IndianaAll5)

pd.DataFrame(list(zip(X_train_IndianaAll5, regressorIndiana5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Indiana5 = regressorIndiana5.predict(X_train_Indiana5)

y_train_IndianaAll6.loc[-1] = y_pred_Indiana5.item(0)  # adding a row
y_train_IndianaAll6.index = y_train_IndianaAll6.index + 1  # shifting index
y_train_IndianaAll6 = y_train_IndianaAll6.sort_index()
regressorIndiana6 = LinearRegression()
regressorIndiana6.fit(X_train_IndianaAll6, y_train_IndianaAll6)

pd.DataFrame(list(zip(X_train_IndianaAll6, regressorIndiana6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Indiana6 = regressorIndiana6.predict(X_train_Indiana6)

y_train_IndianaAll7.loc[-1] = y_pred_Indiana6.item(0)  # adding a row
y_train_IndianaAll7.index = y_train_IndianaAll7.index + 1  # shifting index
y_train_IndianaAll7 = y_train_IndianaAll7.sort_index()
regressorIndiana7 = LinearRegression()
regressorIndiana7.fit(X_train_IndianaAll7, y_train_IndianaAll7)

pd.DataFrame(list(zip(X_train_IndianaAll7, regressorIndiana7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Indiana7 = regressorIndiana7.predict(X_train_Indiana7)

y_train_IndianaAll8.loc[-1] = y_pred_Indiana7.item(0)  # adding a row
y_train_IndianaAll8.index = y_train_IndianaAll8.index + 1  # shifting index
y_train_IndianaAll8 = y_train_IndianaAll8.sort_index()
regressorIndiana8 = LinearRegression()
regressorIndiana8.fit(X_train_IndianaAll8, y_train_IndianaAll8)

pd.DataFrame(list(zip(X_train_IndianaAll8, regressorIndiana8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Indiana8 = regressorIndiana8.predict(X_train_Indiana8)

y_train_IndianaAll9.loc[-1] = y_pred_Indiana8.item(0)  # adding a row
y_train_IndianaAll9.index = y_train_IndianaAll9.index + 1  # shifting index
y_train_IndianaAll9 = y_train_IndianaAll9.sort_index()
regressorIndiana9 = LinearRegression()
regressorIndiana9.fit(X_train_IndianaAll9, y_train_IndianaAll9)

pd.DataFrame(list(zip(X_train_IndianaAll9, regressorIndiana9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Indiana9 = regressorIndiana9.predict(X_train_Indiana9)

y_train_IndianaAll10.loc[-1] = y_pred_Indiana9.item(0)  # adding a row
y_train_IndianaAll10.index = y_train_IndianaAll10.index + 1  # shifting index
y_train_IndianaAll10 = y_train_IndianaAll10.sort_index()
regressorIndiana10 = LinearRegression()
regressorIndiana10.fit(X_train_IndianaAll10, y_train_IndianaAll10)

pd.DataFrame(list(zip(X_train_IndianaAll10, regressorIndiana10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Indiana10 = regressorIndiana10.predict(X_train_Indiana10)

y_train_IndianaAll11.loc[-1] = y_pred_Indiana10.item(0)  # adding a row
y_train_IndianaAll11.index = y_train_IndianaAll11.index + 1  # shifting index
y_train_IndianaAll11 = y_train_IndianaAll11.sort_index()
regressorIndiana11 = LinearRegression()
regressorIndiana11.fit(X_train_IndianaAll11, y_train_IndianaAll11)

pd.DataFrame(list(zip(X_train_IndianaAll11, regressorIndiana11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Indiana11 = regressorIndiana11.predict(X_train_Indiana11)

y_train_IndianaAll12.loc[-1] = y_pred_Indiana11.item(0)  # adding a row
y_train_IndianaAll12.index = y_train_IndianaAll12.index + 1  # shifting index
y_train_IndianaAll12 = y_train_IndianaAll12.sort_index()
regressorIndiana12 = LinearRegression()
regressorIndiana12.fit(X_train_IndianaAll12, y_train_IndianaAll12)

pd.DataFrame(list(zip(X_train_IndianaAll12, regressorIndiana12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Indiana12 = regressorIndiana12.predict(X_train_Indiana12)

y_train_IndianaAll13.loc[-1] = y_pred_Indiana12.item(0)  # adding a row
y_train_IndianaAll13.index = y_train_IndianaAll13.index + 1  # shifting index
y_train_IndianaAll13 = y_train_IndianaAll13.sort_index()
regressorIndiana13 = LinearRegression()
regressorIndiana13.fit(X_train_IndianaAll13, y_train_IndianaAll13)

pd.DataFrame(list(zip(X_train_IndianaAll13, regressorIndiana13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Indiana13 = regressorIndiana13.predict(X_train_Indiana13)

y_train_IndianaAll14.loc[-1] = y_pred_Indiana13.item(0)  # adding a row
y_train_IndianaAll14.index = y_train_IndianaAll14.index + 1  # shifting index
y_train_IndianaAll14 = y_train_IndianaAll14.sort_index()
regressorIndiana14 = LinearRegression()
regressorIndiana14.fit(X_train_IndianaAll14, y_train_IndianaAll14)

pd.DataFrame(list(zip(X_train_IndianaAll14, regressorIndiana14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Indiana14 = regressorIndiana14.predict(X_train_Indiana14)

y_train_IndianaAll15.loc[-1] = y_pred_Indiana14.item(0)  # adding a row
y_train_IndianaAll15.index = y_train_IndianaAll15.index + 1  # shifting index
y_train_IndianaAll15 = y_train_IndianaAll15.sort_index()
regressorIndiana15 = LinearRegression()
regressorIndiana15.fit(X_train_IndianaAll15, y_train_IndianaAll15)

pd.DataFrame(list(zip(X_train_IndianaAll15, regressorIndiana15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Indiana15 = regressorIndiana15.predict(X_train_Indiana15)

y_train_IndianaAll16.loc[-1] = y_pred_Indiana15.item(0)  # adding a row
y_train_IndianaAll16.index = y_train_IndianaAll16.index + 1  # shifting index
y_train_IndianaAll16 = y_train_IndianaAll16.sort_index()
regressorIndiana16 = LinearRegression()
regressorIndiana16.fit(X_train_IndianaAll16, y_train_IndianaAll16)

pd.DataFrame(list(zip(X_train_IndianaAll16, regressorIndiana16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Indiana16 = regressorIndiana16.predict(X_train_Indiana16)

y_train_IndianaAll17.loc[-1] = y_pred_Indiana16.item(0)  # adding a row
y_train_IndianaAll17.index = y_train_IndianaAll17.index + 1  # shifting index
y_train_IndianaAll17 = y_train_IndianaAll17.sort_index()
regressorIndiana17 = LinearRegression()
regressorIndiana17.fit(X_train_IndianaAll17, y_train_IndianaAll17)

pd.DataFrame(list(zip(X_train_IndianaAll17, regressorIndiana17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Indiana17 = regressorIndiana17.predict(X_train_Indiana17)

y_train_IndianaAll18.loc[-1] = y_pred_Indiana17.item(0)  # adding a row
y_train_IndianaAll18.index = y_train_IndianaAll18.index + 1  # shifting index
y_train_IndianaAll18 = y_train_IndianaAll18.sort_index()
regressorIndiana18 = LinearRegression()
regressorIndiana18.fit(X_train_IndianaAll18, y_train_IndianaAll18)

pd.DataFrame(list(zip(X_train_IndianaAll18, regressorIndiana18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Indiana18 = regressorIndiana18.predict(X_train_Indiana18)

y_train_IndianaAll19.loc[-1] = y_pred_Indiana18.item(0)  # adding a row
y_train_IndianaAll19.index = y_train_IndianaAll19.index + 1  # shifting index
y_train_IndianaAll19 = y_train_IndianaAll19.sort_index()
regressorIndiana19 = LinearRegression()
regressorIndiana19.fit(X_train_IndianaAll19, y_train_IndianaAll19)

pd.DataFrame(list(zip(X_train_IndianaAll19, regressorIndiana19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Indiana19 = regressorIndiana19.predict(X_train_Indiana19)

y_train_IndianaAll20.loc[-1] = y_pred_Indiana19.item(0)  # adding a row
y_train_IndianaAll20.index = y_train_IndianaAll20.index + 1  # shifting index
y_train_IndianaAll20 = y_train_IndianaAll20.sort_index()
regressorIndiana20 = LinearRegression()
regressorIndiana20.fit(X_train_IndianaAll20, y_train_IndianaAll20)

pd.DataFrame(list(zip(X_train_IndianaAll20, regressorIndiana20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Indiana20 = regressorIndiana20.predict(X_train_Indiana20)

y_train_IndianaAll21.loc[-1] = y_pred_Indiana20.item(0)  # adding a row
y_train_IndianaAll21.index = y_train_IndianaAll21.index + 1  # shifting index
y_train_IndianaAll21 = y_train_IndianaAll21.sort_index()
regressorIndiana21 = LinearRegression()
regressorIndiana21.fit(X_train_IndianaAll21, y_train_IndianaAll21)

pd.DataFrame(list(zip(X_train_IndianaAll21, regressorIndiana21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Indiana21 = regressorIndiana21.predict(X_train_Indiana21)

# %%
X_train_LosAngelesLakers1=X_LosAngelesLakers[0:1]
y_train_LosAngelesLakers1=y_LosAngelesLakers[0:1]
X_train_LosAngelesLakers2=X_LosAngelesLakers[1:2]
y_train_LosAngelesLakers2=y_LosAngelesLakers[1:2]
X_train_LosAngelesLakers3=X_LosAngelesLakers[2:3]
y_train_LosAngelesLakers3=y_LosAngelesLakers[2:3]
X_train_LosAngelesLakers4=X_LosAngelesLakers[3:4]
y_train_LosAngelesLakers4=y_LosAngelesLakers[3:4]
X_train_LosAngelesLakers5=X_LosAngelesLakers[4:5]
y_train_LosAngelesLakers5=y_LosAngelesLakers[4:5]
y_train_LosAngelesLakers6=y_LosAngelesLakers[5:6]
X_train_LosAngelesLakers7=X_LosAngelesLakers[7:8]
X_train_LosAngelesLakers6=X_LosAngelesLakers[5:6]
y_train_LosAngelesLakers7=y_LosAngelesLakers[7:8]
X_train_LosAngelesLakers8=X_LosAngelesLakers[8:9]
y_train_LosAngelesLakers8=y_LosAngelesLakers[8:9]
X_train_LosAngelesLakers9=X_LosAngelesLakers[9:10]
y_train_LosAngelesLakers9=y_LosAngelesLakers[9:10]
X_train_LosAngelesLakers10=X_LosAngelesLakers[10:11]
y_train_LosAngelesLakers10=y_LosAngelesLakers[10:11]
X_train_LosAngelesLakers11=X_LosAngelesLakers[11:12]
y_train_LosAngelesLakers11=y_LosAngelesLakers[11:12]
X_train_LosAngelesLakers12=X_LosAngelesLakers[12:13]
y_train_LosAngelesLakers12=y_LosAngelesLakers[12:13]
X_train_LosAngelesLakers13=X_LosAngelesLakers[13:14]
y_train_LosAngelesLakers13=y_LosAngelesLakers[13:14]
X_train_LosAngelesLakers14=X_LosAngelesLakers[14:15]
y_train_LosAngelesLakers14=y_LosAngelesLakers[14:15]
X_train_LosAngelesLakers15=X_LosAngelesLakers[15:16]
y_train_LosAngelesLakers15=y_LosAngelesLakers[15:16]
X_train_LosAngelesLakers16=X_LosAngelesLakers[16:17]
y_train_LosAngelesLakers16=y_LosAngelesLakers[16:17]
X_train_LosAngelesLakers17=X_LosAngelesLakers[17:18]
y_train_LosAngelesLakers17=y_LosAngelesLakers[17:18]
X_train_LosAngelesLakers18=X_LosAngelesLakers[18:19]
y_train_LosAngelesLakers18=y_LosAngelesLakers[18:19]
X_train_LosAngelesLakers19=X_LosAngelesLakers[19:20]
y_train_LosAngelesLakers19=y_LosAngelesLakers[19:20]
X_train_LosAngelesLakers20=X_LosAngelesLakers[20:21]
y_train_LosAngelesLakers20=y_LosAngelesLakers[20:21]
X_train_LosAngelesLakers21=X_LosAngelesLakers[21:22]
y_train_LosAngelesLakers21=y_LosAngelesLakers[21:22]
X_train_LosAngelesLakers22=X_LosAngelesLakers[22:23]
y_train_LosAngelesLakers22=y_LosAngelesLakers[22:23]


X_train_LosAngelesLakersAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,352,374,396,418,440,462,484,506,528,550,572,594,616,638],[5,11,18,19,20]]
y_train_LosAngelesLakersAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,352,374,396,418,440,462,484,506,528,550,572,594,616,638],24:25]

X_train_LosAngelesLakersAll2=df.iloc[[0,1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,353,375,397,419,441,463,485,507,529,551,573,595,617,639],[5,11,18,19,20]]
y_train_LosAngelesLakersAll2=df.iloc[[1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,353,375,397,419,441,463,485,507,529,551,573,595,617,639],24:25]

X_train_LosAngelesLakersAll3=df.iloc[[0,2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,354,376,398,420,442,464,486,508,530,552,574,596,618,640],[5,11,18,19,20]]
y_train_LosAngelesLakersAll3=df.iloc[[2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,354,376,398,420,442,464,486,508,530,552,574,596,618,640],24:25]

X_train_LosAngelesLakersAll4=df.iloc[[0,3,25,47,69,91,113,135,157,179,201,223,245,267,289,311,355,377,399,421,443,465,487,509,531,553,575,597,619,641],[5,11,18,19,20]]
y_train_LosAngelesLakersAll4=df.iloc[[3,25,47,69,91,113,135,158,179,201,223,245,267,289,311,355,377,399,421,443,465,487,509,531,553,575,597,619,641],24:25]

X_train_LosAngelesLakersAll5=df.iloc[[0,4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,356,378,400,422,444,466,488,510,532,554,576,598,620,642],[5,11,18,19,20]]
y_train_LosAngelesLakersAll5=df.iloc[[4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,356,378,400,422,444,466,488,510,532,554,576,598,620,642],24:25]

X_train_LosAngelesLakersAll6=df.iloc[[0,5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,357,379,401,423,445,467,489,511,533,555,577,599,621,643],[5,11,18,19,20]]
y_train_LosAngelesLakersAll6=df.iloc[[5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,357,379,401,423,445,467,489,511,533,555,577,599,621,643],24:25]

X_train_LosAngelesLakersAll7=df.iloc[[0,6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,358,380,402,424,446,468,490,512,534,556,578,600,622,644],[5,11,18,19,20]]
y_train_LosAngelesLakersAll7=df.iloc[[6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,358,380,402,424,446,468,490,512,534,556,578,600,622,644],24:25]

X_train_LosAngelesLakersAll8=df.iloc[[0,7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,359,381,403,425,447,469,491,513,535,557,579,601,623,645],[5,11,18,19,20]]
y_train_LosAngelesLakersAll8=df.iloc[[7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,359,381,403,425,447,469,491,513,535,557,579,601,623,645],24:25]

X_train_LosAngelesLakersAll9=df.iloc[[0,8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,360,382,404,426,448,470,492,514,536,558,580,602,624,646],[5,11,18,19,20]]
y_train_LosAngelesLakersAll9=df.iloc[[8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,360,382,404,426,448,470,492,514,536,558,580,602,624,646],24:25]

X_train_LosAngelesLakersAll10=df.iloc[[0,9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,361,383,405,427,449,471,493,515,537,559,581,603,625,647],[5,11,18,19,20]]
y_train_LosAngelesLakersAll10=df.iloc[[9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,361,383,405,427,449,471,493,515,537,559,581,603,625,647],24:25]

X_train_LosAngelesLakersAll11=df.iloc[[0,10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,362,384,406,428,450,472,494,516,538,560,582,604,626,648],[5,11,18,19,20]]
y_train_LosAngelesLakersAll11=df.iloc[[10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,362,384,406,428,450,472,494,516,538,560,582,604,626,648],24:25]

X_train_LosAngelesLakersAll12=df.iloc[[0,11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,363,385,407,429,451,473,495,517,539,561,583,605,627,649],[5,11,18,19,20]]
y_train_LosAngelesLakersAll12=df.iloc[[11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,363,385,407,429,451,473,495,517,539,561,583,605,627,649],24:25]

X_train_LosAngelesLakersAll13=df.iloc[[0,12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,364,386,408,430,452,474,496,518,540,562,584,606,628,650],[5,11,18,19,20]]
y_train_LosAngelesLakersAll13=df.iloc[[12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,364,386,408,430,452,474,496,518,540,562,584,606,628,650],24:25]

X_train_LosAngelesLakersAll14=df.iloc[[0,13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,365,387,409,431,453,475,497,519,541,563,585,607,629,651],[5,11,18,19,20]]
y_train_LosAngelesLakersAll14=df.iloc[[13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,365,387,409,431,453,475,497,519,541,563,585,607,629,651],24:25]

X_train_LosAngelesLakersAll15=df.iloc[[0,14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,366,388,410,432,454,476,498,520,542,564,586,608,630,652],[5,11,18,19,20]]
y_train_LosAngelesLakersAll15=df.iloc[[14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,366,388,410,432,454,476,498,520,542,564,586,608,630,652],24:25]

X_train_LosAngelesLakersAll16=df.iloc[[0,15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,367,389,411,433,455,477,499,521,543,565,587,609,631,653],[5,11,18,19,20]]
y_train_LosAngelesLakersAll16=df.iloc[[15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,367,389,411,433,455,477,499,521,543,565,587,609,631,653],24:25]

X_train_LosAngelesLakersAll17=df.iloc[[0,16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,368,390,412,434,456,478,500,522,544,566,588,610,632,654],[5,11,18,19,20]]
y_train_LosAngelesLakersAll17=df.iloc[[16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,368,390,412,434,456,478,500,522,544,566,588,610,632,654],24:25]

X_train_LosAngelesLakersAll18=df.iloc[[0,17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,369,391,413,435,457,479,501,523,545,567,589,611,633,655],[5,11,18,19,20]]
y_train_LosAngelesLakersAll18=df.iloc[[17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,369,391,413,435,457,479,501,523,545,567,589,611,633,655],24:25]

X_train_LosAngelesLakersAll19=df.iloc[[0,18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,370,392,414,436,458,480,502,524,546,568,590,612,634,656],[5,11,18,19,20]]
y_train_LosAngelesLakersAll19=df.iloc[[18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,370,392,414,436,458,480,502,524,546,568,590,612,634,656],24:25]

X_train_LosAngelesLakersAll20=df.iloc[[0,19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,371,393,415,437,459,481,503,525,547,569,591,613,635,657],[5,11,18,19,20]]
y_train_LosAngelesLakersAll20=df.iloc[[19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,371,393,415,437,459,481,503,525,547,569,591,613,635,657],24:25]

X_train_LosAngelesLakersAll21=df.iloc[[0,20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,372,394,416,438,460,482,504,526,548,570,592,614,636,658],[5,11,18,19,20]]
y_train_LosAngelesLakersAll21=df.iloc[[20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,372,394,416,438,460,482,504,526,548,570,592,614,636,658],24:25]

X_train_LosAngelesLakersAll22=df.iloc[[0,21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,373,395,417,439,461,483,505,527,549,571,593,615,637,659],[5,11,18,19,20]]
y_train_LosAngelesLakersAll22=df.iloc[[21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,373,395,417,439,461,483,505,527,549,571,593,615,637,659],24:25]

# %%
regressorLosAngelesLakers1 = LinearRegression()
regressorLosAngelesLakers1.fit(X_train_LosAngelesLakersAll1, y_train_LosAngelesLakersAll1)
pd.DataFrame(list(zip(X_train_LosAngelesLakersAll1, regressorLosAngelesLakers1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_LosAngelesLakers1 = regressorLosAngelesLakers1.predict(X_train_LosAngelesLakers1)

# %%
y_train_LosAngelesLakersAll2.loc[-1] = y_pred_LosAngelesLakers1.item(0)  # adding a row
y_train_LosAngelesLakersAll2.index = y_train_LosAngelesLakersAll2.index + 1  # shifting index
y_train_LosAngelesLakersAll2 = y_train_LosAngelesLakersAll2.sort_index()
regressorLosAngelesLakers2 = LinearRegression()
regressorLosAngelesLakers2.fit(X_train_LosAngelesLakersAll2, y_train_LosAngelesLakersAll2)

pd.DataFrame(list(zip(X_train_LosAngelesLakersAll2, regressorLosAngelesLakers2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesLakers2 = regressorLosAngelesLakers2.predict(X_train_LosAngelesLakers2)

y_train_LosAngelesLakersAll3.loc[-1] = y_pred_LosAngelesLakers2.item(0)  # adding a row
y_train_LosAngelesLakersAll3.index = y_train_LosAngelesLakersAll3.index + 1  # shifting index
y_train_LosAngelesLakersAll3 = y_train_LosAngelesLakersAll3.sort_index()
regressorLosAngelesLakers3 = LinearRegression()
regressorLosAngelesLakers3.fit(X_train_LosAngelesLakersAll3, y_train_LosAngelesLakersAll3)

pd.DataFrame(list(zip(X_train_LosAngelesLakersAll3, regressorLosAngelesLakers3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesLakers3 = regressorLosAngelesLakers3.predict(X_train_LosAngelesLakers3)

y_train_LosAngelesLakersAll4.loc[-1] = y_pred_LosAngelesLakers3.item(0)  # adding a row
y_train_LosAngelesLakersAll4.index = y_train_LosAngelesLakersAll4.index + 1  # shifting index
y_train_LosAngelesLakersAll4 = y_train_LosAngelesLakersAll4.sort_index()
regressorLosAngelesLakers4 = LinearRegression()
regressorLosAngelesLakers4.fit(X_train_LosAngelesLakersAll4, y_train_LosAngelesLakersAll4)

pd.DataFrame(list(zip(X_train_LosAngelesLakersAll4, regressorLosAngelesLakers4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesLakers4 = regressorLosAngelesLakers4.predict(X_train_LosAngelesLakers4)

y_train_LosAngelesLakersAll5.loc[-1] = y_pred_LosAngelesLakers4.item(0)  # adding a row
y_train_LosAngelesLakersAll5.index = y_train_LosAngelesLakersAll5.index + 1  # shifting index
y_train_LosAngelesLakersAll5 = y_train_LosAngelesLakersAll5.sort_index()
regressorLosAngelesLakers5 = LinearRegression()
regressorLosAngelesLakers5.fit(X_train_LosAngelesLakersAll5, y_train_LosAngelesLakersAll5)

pd.DataFrame(list(zip(X_train_LosAngelesLakersAll5, regressorLosAngelesLakers5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesLakers5 = regressorLosAngelesLakers5.predict(X_train_LosAngelesLakers5)

y_train_LosAngelesLakersAll6.loc[-1] = y_pred_LosAngelesLakers5.item(0)  # adding a row
y_train_LosAngelesLakersAll6.index = y_train_LosAngelesLakersAll6.index + 1  # shifting index
y_train_LosAngelesLakersAll6 = y_train_LosAngelesLakersAll6.sort_index()
regressorLosAngelesLakers6 = LinearRegression()
regressorLosAngelesLakers6.fit(X_train_LosAngelesLakersAll6, y_train_LosAngelesLakersAll6)

pd.DataFrame(list(zip(X_train_LosAngelesLakersAll6, regressorLosAngelesLakers6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesLakers6 = regressorLosAngelesLakers6.predict(X_train_LosAngelesLakers6)

y_train_LosAngelesLakersAll7.loc[-1] = y_pred_LosAngelesLakers6.item(0)  # adding a row
y_train_LosAngelesLakersAll7.index = y_train_LosAngelesLakersAll7.index + 1  # shifting index
y_train_LosAngelesLakersAll7 = y_train_LosAngelesLakersAll7.sort_index()
regressorLosAngelesLakers7 = LinearRegression()
regressorLosAngelesLakers7.fit(X_train_LosAngelesLakersAll7, y_train_LosAngelesLakersAll7)

pd.DataFrame(list(zip(X_train_LosAngelesLakersAll7, regressorLosAngelesLakers7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesLakers7 = regressorLosAngelesLakers7.predict(X_train_LosAngelesLakers7)

y_train_LosAngelesLakersAll8.loc[-1] = y_pred_LosAngelesLakers7.item(0)  # adding a row
y_train_LosAngelesLakersAll8.index = y_train_LosAngelesLakersAll8.index + 1  # shifting index
y_train_LosAngelesLakersAll8 = y_train_LosAngelesLakersAll8.sort_index()
regressorLosAngelesLakers8 = LinearRegression()
regressorLosAngelesLakers8.fit(X_train_LosAngelesLakersAll8, y_train_LosAngelesLakersAll8)

pd.DataFrame(list(zip(X_train_LosAngelesLakersAll8, regressorLosAngelesLakers8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesLakers8 = regressorLosAngelesLakers8.predict(X_train_LosAngelesLakers8)

y_train_LosAngelesLakersAll9.loc[-1] = y_pred_LosAngelesLakers8.item(0)  # adding a row
y_train_LosAngelesLakersAll9.index = y_train_LosAngelesLakersAll9.index + 1  # shifting index
y_train_LosAngelesLakersAll9 = y_train_LosAngelesLakersAll9.sort_index()
regressorLosAngelesLakers9 = LinearRegression()
regressorLosAngelesLakers9.fit(X_train_LosAngelesLakersAll9, y_train_LosAngelesLakersAll9)

pd.DataFrame(list(zip(X_train_LosAngelesLakersAll9, regressorLosAngelesLakers9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesLakers9 = regressorLosAngelesLakers9.predict(X_train_LosAngelesLakers9)

y_train_LosAngelesLakersAll10.loc[-1] = y_pred_LosAngelesLakers9.item(0)  # adding a row
y_train_LosAngelesLakersAll10.index = y_train_LosAngelesLakersAll10.index + 1  # shifting index
y_train_LosAngelesLakersAll10 = y_train_LosAngelesLakersAll10.sort_index()
regressorLosAngelesLakers10 = LinearRegression()
regressorLosAngelesLakers10.fit(X_train_LosAngelesLakersAll10, y_train_LosAngelesLakersAll10)

pd.DataFrame(list(zip(X_train_LosAngelesLakersAll10, regressorLosAngelesLakers10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesLakers10 = regressorLosAngelesLakers10.predict(X_train_LosAngelesLakers10)

y_train_LosAngelesLakersAll11.loc[-1] = y_pred_LosAngelesLakers10.item(0)  # adding a row
y_train_LosAngelesLakersAll11.index = y_train_LosAngelesLakersAll11.index + 1  # shifting index
y_train_LosAngelesLakersAll11 = y_train_LosAngelesLakersAll11.sort_index()
regressorLosAngelesLakers11 = LinearRegression()
regressorLosAngelesLakers11.fit(X_train_LosAngelesLakersAll11, y_train_LosAngelesLakersAll11)

pd.DataFrame(list(zip(X_train_LosAngelesLakersAll11, regressorLosAngelesLakers11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesLakers11 = regressorLosAngelesLakers11.predict(X_train_LosAngelesLakers11)

y_train_LosAngelesLakersAll12.loc[-1] = y_pred_LosAngelesLakers11.item(0)  # adding a row
y_train_LosAngelesLakersAll12.index = y_train_LosAngelesLakersAll12.index + 1  # shifting index
y_train_LosAngelesLakersAll12 = y_train_LosAngelesLakersAll12.sort_index()
regressorLosAngelesLakers12 = LinearRegression()
regressorLosAngelesLakers12.fit(X_train_LosAngelesLakersAll12, y_train_LosAngelesLakersAll12)

pd.DataFrame(list(zip(X_train_LosAngelesLakersAll12, regressorLosAngelesLakers12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesLakers12 = regressorLosAngelesLakers12.predict(X_train_LosAngelesLakers12)

y_train_LosAngelesLakersAll13.loc[-1] = y_pred_LosAngelesLakers12.item(0)  # adding a row
y_train_LosAngelesLakersAll13.index = y_train_LosAngelesLakersAll13.index + 1  # shifting index
y_train_LosAngelesLakersAll13 = y_train_LosAngelesLakersAll13.sort_index()
regressorLosAngelesLakers13 = LinearRegression()
regressorLosAngelesLakers13.fit(X_train_LosAngelesLakersAll13, y_train_LosAngelesLakersAll13)

pd.DataFrame(list(zip(X_train_LosAngelesLakersAll13, regressorLosAngelesLakers13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesLakers13 = regressorLosAngelesLakers13.predict(X_train_LosAngelesLakers13)

y_train_LosAngelesLakersAll14.loc[-1] = y_pred_LosAngelesLakers13.item(0)  # adding a row
y_train_LosAngelesLakersAll14.index = y_train_LosAngelesLakersAll14.index + 1  # shifting index
y_train_LosAngelesLakersAll14 = y_train_LosAngelesLakersAll14.sort_index()
regressorLosAngelesLakers14 = LinearRegression()
regressorLosAngelesLakers14.fit(X_train_LosAngelesLakersAll14, y_train_LosAngelesLakersAll14)

pd.DataFrame(list(zip(X_train_LosAngelesLakersAll14, regressorLosAngelesLakers14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesLakers14 = regressorLosAngelesLakers14.predict(X_train_LosAngelesLakers14)

y_train_LosAngelesLakersAll15.loc[-1] = y_pred_LosAngelesLakers14.item(0)  # adding a row
y_train_LosAngelesLakersAll15.index = y_train_LosAngelesLakersAll15.index + 1  # shifting index
y_train_LosAngelesLakersAll15 = y_train_LosAngelesLakersAll15.sort_index()
regressorLosAngelesLakers15 = LinearRegression()
regressorLosAngelesLakers15.fit(X_train_LosAngelesLakersAll15, y_train_LosAngelesLakersAll15)

pd.DataFrame(list(zip(X_train_LosAngelesLakersAll15, regressorLosAngelesLakers15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesLakers15 = regressorLosAngelesLakers15.predict(X_train_LosAngelesLakers15)

y_train_LosAngelesLakersAll16.loc[-1] = y_pred_LosAngelesLakers15.item(0)  # adding a row
y_train_LosAngelesLakersAll16.index = y_train_LosAngelesLakersAll16.index + 1  # shifting index
y_train_LosAngelesLakersAll16 = y_train_LosAngelesLakersAll16.sort_index()
regressorLosAngelesLakers16 = LinearRegression()
regressorLosAngelesLakers16.fit(X_train_LosAngelesLakersAll16, y_train_LosAngelesLakersAll16)

pd.DataFrame(list(zip(X_train_LosAngelesLakersAll16, regressorLosAngelesLakers16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesLakers16 = regressorLosAngelesLakers16.predict(X_train_LosAngelesLakers16)

y_train_LosAngelesLakersAll17.loc[-1] = y_pred_LosAngelesLakers16.item(0)  # adding a row
y_train_LosAngelesLakersAll17.index = y_train_LosAngelesLakersAll17.index + 1  # shifting index
y_train_LosAngelesLakersAll17 = y_train_LosAngelesLakersAll17.sort_index()
regressorLosAngelesLakers17 = LinearRegression()
regressorLosAngelesLakers17.fit(X_train_LosAngelesLakersAll17, y_train_LosAngelesLakersAll17)

pd.DataFrame(list(zip(X_train_LosAngelesLakersAll17, regressorLosAngelesLakers17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesLakers17 = regressorLosAngelesLakers17.predict(X_train_LosAngelesLakers17)

y_train_LosAngelesLakersAll18.loc[-1] = y_pred_LosAngelesLakers17.item(0)  # adding a row
y_train_LosAngelesLakersAll18.index = y_train_LosAngelesLakersAll18.index + 1  # shifting index
y_train_LosAngelesLakersAll18 = y_train_LosAngelesLakersAll18.sort_index()
regressorLosAngelesLakers18 = LinearRegression()
regressorLosAngelesLakers18.fit(X_train_LosAngelesLakersAll18, y_train_LosAngelesLakersAll18)

pd.DataFrame(list(zip(X_train_LosAngelesLakersAll18, regressorLosAngelesLakers18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesLakers18 = regressorLosAngelesLakers18.predict(X_train_LosAngelesLakers18)

y_train_LosAngelesLakersAll19.loc[-1] = y_pred_LosAngelesLakers18.item(0)  # adding a row
y_train_LosAngelesLakersAll19.index = y_train_LosAngelesLakersAll19.index + 1  # shifting index
y_train_LosAngelesLakersAll19 = y_train_LosAngelesLakersAll19.sort_index()
regressorLosAngelesLakers19 = LinearRegression()
regressorLosAngelesLakers19.fit(X_train_LosAngelesLakersAll19, y_train_LosAngelesLakersAll19)

pd.DataFrame(list(zip(X_train_LosAngelesLakersAll19, regressorLosAngelesLakers19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesLakers19 = regressorLosAngelesLakers19.predict(X_train_LosAngelesLakers19)

y_train_LosAngelesLakersAll20.loc[-1] = y_pred_LosAngelesLakers19.item(0)  # adding a row
y_train_LosAngelesLakersAll20.index = y_train_LosAngelesLakersAll20.index + 1  # shifting index
y_train_LosAngelesLakersAll20 = y_train_LosAngelesLakersAll20.sort_index()
regressorLosAngelesLakers20 = LinearRegression()
regressorLosAngelesLakers20.fit(X_train_LosAngelesLakersAll20, y_train_LosAngelesLakersAll20)

pd.DataFrame(list(zip(X_train_LosAngelesLakersAll20, regressorLosAngelesLakers20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesLakers20 = regressorLosAngelesLakers20.predict(X_train_LosAngelesLakers20)

y_train_LosAngelesLakersAll21.loc[-1] = y_pred_LosAngelesLakers20.item(0)  # adding a row
y_train_LosAngelesLakersAll21.index = y_train_LosAngelesLakersAll21.index + 1  # shifting index
y_train_LosAngelesLakersAll21 = y_train_LosAngelesLakersAll21.sort_index()
regressorLosAngelesLakers21 = LinearRegression()
regressorLosAngelesLakers21.fit(X_train_LosAngelesLakersAll21, y_train_LosAngelesLakersAll21)

pd.DataFrame(list(zip(X_train_LosAngelesLakersAll21, regressorLosAngelesLakers21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_LosAngelesLakers21 = regressorLosAngelesLakers21.predict(X_train_LosAngelesLakers21)

# %%
X_train_Sacramento1=X_Sacramento[0:1]
y_train_Sacramento1=y_Sacramento[0:1]
X_train_Sacramento2=X_Sacramento[1:2]
y_train_Sacramento2=y_Sacramento[1:2]
X_train_Sacramento3=X_Sacramento[2:3]
y_train_Sacramento3=y_Sacramento[2:3]
X_train_Sacramento4=X_Sacramento[3:4]
y_train_Sacramento4=y_Sacramento[3:4]
X_train_Sacramento5=X_Sacramento[4:5]
y_train_Sacramento5=y_Sacramento[4:5]
y_train_Sacramento6=y_Sacramento[5:6]
X_train_Sacramento7=X_Sacramento[7:8]
X_train_Sacramento6=X_Sacramento[5:6]
y_train_Sacramento7=y_Sacramento[7:8]
X_train_Sacramento8=X_Sacramento[8:9]
y_train_Sacramento8=y_Sacramento[8:9]
X_train_Sacramento9=X_Sacramento[9:10]
y_train_Sacramento9=y_Sacramento[9:10]
X_train_Sacramento10=X_Sacramento[10:11]
y_train_Sacramento10=y_Sacramento[10:11]
X_train_Sacramento11=X_Sacramento[11:12]
y_train_Sacramento11=y_Sacramento[11:12]
X_train_Sacramento12=X_Sacramento[12:13]
y_train_Sacramento12=y_Sacramento[12:13]
X_train_Sacramento13=X_Sacramento[13:14]
y_train_Sacramento13=y_Sacramento[13:14]
X_train_Sacramento14=X_Sacramento[14:15]
y_train_Sacramento14=y_Sacramento[14:15]
X_train_Sacramento15=X_Sacramento[15:16]
y_train_Sacramento15=y_Sacramento[15:16]
X_train_Sacramento16=X_Sacramento[16:17]
y_train_Sacramento16=y_Sacramento[16:17]
X_train_Sacramento17=X_Sacramento[17:18]
y_train_Sacramento17=y_Sacramento[17:18]
X_train_Sacramento18=X_Sacramento[18:19]
y_train_Sacramento18=y_Sacramento[18:19]
X_train_Sacramento19=X_Sacramento[19:20]
y_train_Sacramento19=y_Sacramento[19:20]
X_train_Sacramento20=X_Sacramento[20:21]
y_train_Sacramento20=y_Sacramento[20:21]
X_train_Sacramento21=X_Sacramento[21:22]
y_train_Sacramento21=y_Sacramento[21:22]
X_train_Sacramento22=X_Sacramento[22:23]
y_train_Sacramento22=y_Sacramento[22:23]

X_train_SacramentoAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,374,396,418,440,462,484,506,528,550,572,594,616,638],[5,11,18,19,20]]
y_train_SacramentoAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,374,396,418,440,462,484,506,528,550,572,594,616,638],24:25]

X_train_SacramentoAll2=df.iloc[[0,1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,375,397,419,441,463,485,507,529,551,573,595,617,639],[5,11,18,19,20]]
y_train_SacramentoAll2=df.iloc[[1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,375,397,419,441,463,485,507,529,551,573,595,617,639],24:25]

X_train_SacramentoAll3=df.iloc[[0,2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,376,398,420,442,464,486,508,530,552,574,596,618,640],[5,11,18,19,20]]
y_train_SacramentoAll3=df.iloc[[2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,376,398,420,442,464,486,508,530,552,574,596,618,640],24:25]

X_train_SacramentoAll4=df.iloc[[0,3,25,47,69,91,113,135,157,179,201,223,245,267,289,311,333,377,399,421,443,465,487,509,531,553,575,597,619,641],[5,11,18,19,20]]
y_train_SacramentoAll4=df.iloc[[3,25,47,69,91,113,135,158,179,201,223,245,267,289,311,333,377,399,421,443,465,487,509,531,553,575,597,619,641],24:25]

X_train_SacramentoAll5=df.iloc[[0,4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,378,400,422,444,466,488,510,532,554,576,598,620,642],[5,11,18,19,20]]
y_train_SacramentoAll5=df.iloc[[4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,378,400,422,444,466,488,510,532,554,576,598,620,642],24:25]

X_train_SacramentoAll6=df.iloc[[0,5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,379,401,423,445,467,489,511,533,555,577,599,621,643],[5,11,18,19,20]]
y_train_SacramentoAll6=df.iloc[[5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,379,401,423,445,467,489,511,533,555,577,599,621,643],24:25]

X_train_SacramentoAll7=df.iloc[[0,6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,380,402,424,446,468,490,512,534,556,578,600,622,644],[5,11,18,19,20]]
y_train_SacramentoAll7=df.iloc[[6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,380,402,424,446,468,490,512,534,556,578,600,622,644],24:25]

X_train_SacramentoAll8=df.iloc[[0,7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,381,403,425,447,469,491,513,535,557,579,601,623,645],[5,11,18,19,20]]
y_train_SacramentoAll8=df.iloc[[7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,381,403,425,447,469,491,513,535,557,579,601,623,645],24:25]

X_train_SacramentoAll9=df.iloc[[0,8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,382,404,426,448,470,492,514,536,558,580,602,624,646],[5,11,18,19,20]]
y_train_SacramentoAll9=df.iloc[[8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,382,404,426,448,470,492,514,536,558,580,602,624,646],24:25]

X_train_SacramentoAll10=df.iloc[[0,9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,383,405,427,449,471,493,515,537,559,581,603,625,647],[5,11,18,19,20]]
y_train_SacramentoAll10=df.iloc[[9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,383,405,427,449,471,493,515,537,559,581,603,625,647],24:25]

X_train_SacramentoAll11=df.iloc[[0,10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,384,406,428,450,472,494,516,538,560,582,604,626,648],[5,11,18,19,20]]
y_train_SacramentoAll11=df.iloc[[10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,384,406,428,450,472,494,516,538,560,582,604,626,648],24:25]

X_train_SacramentoAll12=df.iloc[[0,11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,385,407,429,451,473,495,517,539,561,583,605,627,649],[5,11,18,19,20]]
y_train_SacramentoAll12=df.iloc[[11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,385,407,429,451,473,495,517,539,561,583,605,627,649],24:25]

X_train_SacramentoAll13=df.iloc[[0,12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,386,408,430,452,474,496,518,540,562,584,606,628,650],[5,11,18,19,20]]
y_train_SacramentoAll13=df.iloc[[12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,386,408,430,452,474,496,518,540,562,584,606,628,650],24:25]

X_train_SacramentoAll14=df.iloc[[0,13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,387,409,431,453,475,497,519,541,563,585,607,629,651],[5,11,18,19,20]]
y_train_SacramentoAll14=df.iloc[[13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,387,409,431,453,475,497,519,541,563,585,607,629,651],24:25]

X_train_SacramentoAll15=df.iloc[[0,14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,388,410,432,454,476,498,520,542,564,586,608,630,652],[5,11,18,19,20]]
y_train_SacramentoAll15=df.iloc[[14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,388,410,432,454,476,498,520,542,564,586,608,630,652],24:25]

X_train_SacramentoAll16=df.iloc[[0,15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,389,411,433,455,477,499,521,543,565,587,609,631,653],[5,11,18,19,20]]
y_train_SacramentoAll16=df.iloc[[15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,389,411,433,455,477,499,521,543,565,587,609,631,653],24:25]

X_train_SacramentoAll17=df.iloc[[0,16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,390,412,434,456,478,500,522,544,566,588,610,632,654],[5,11,18,19,20]]
y_train_SacramentoAll17=df.iloc[[16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,390,412,434,456,478,500,522,544,566,588,610,632,654],24:25]

X_train_SacramentoAll18=df.iloc[[0,17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,391,413,435,457,479,501,523,545,567,589,611,633,655],[5,11,18,19,20]]
y_train_SacramentoAll18=df.iloc[[17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,391,413,435,457,479,501,523,545,567,589,611,633,655],24:25]

X_train_SacramentoAll19=df.iloc[[0,18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,392,414,436,458,480,502,524,546,568,590,612,634,656],[5,11,18,19,20]]
y_train_SacramentoAll19=df.iloc[[18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,392,414,436,458,480,502,524,546,568,590,612,634,656],24:25]

X_train_SacramentoAll20=df.iloc[[0,19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,393,415,437,459,481,503,525,547,569,591,613,635,657],[5,11,18,19,20]]
y_train_SacramentoAll20=df.iloc[[19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,393,415,437,459,481,503,525,547,569,591,613,635,657],24:25]

X_train_SacramentoAll21=df.iloc[[0,20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,394,416,438,460,482,504,526,548,570,592,614,636,658],[5,11,18,19,20]]
y_train_SacramentoAll21=df.iloc[[20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,394,416,438,460,482,504,526,548,570,592,614,636,658],24:25]

X_train_SacramentoAll22=df.iloc[[0,21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,395,417,439,461,483,505,527,549,571,593,615,637,659],[5,11,18,19,20]]
y_train_SacramentoAll22=df.iloc[[21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,395,417,439,461,483,505,527,549,571,593,615,637,659],24:25]

# %%
regressorSacramento1 = LinearRegression()
regressorSacramento1.fit(X_train_SacramentoAll1, y_train_SacramentoAll1)
pd.DataFrame(list(zip(X_train_SacramentoAll1, regressorSacramento1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_Sacramento1 = regressorSacramento1.predict(X_train_Sacramento1)

# %%
y_train_SacramentoAll2.loc[-1] = y_pred_Sacramento1.item(0)  # adding a row
y_train_SacramentoAll2.index = y_train_SacramentoAll2.index + 1  # shifting index
y_train_SacramentoAll2 = y_train_SacramentoAll2.sort_index()
regressorSacramento2 = LinearRegression()
regressorSacramento2.fit(X_train_SacramentoAll2, y_train_SacramentoAll2)

pd.DataFrame(list(zip(X_train_SacramentoAll2, regressorSacramento2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Sacramento2 = regressorSacramento2.predict(X_train_Sacramento2)

y_train_SacramentoAll3.loc[-1] = y_pred_Sacramento2.item(0)  # adding a row
y_train_SacramentoAll3.index = y_train_SacramentoAll3.index + 1  # shifting index
y_train_SacramentoAll3 = y_train_SacramentoAll3.sort_index()
regressorSacramento3 = LinearRegression()
regressorSacramento3.fit(X_train_SacramentoAll3, y_train_SacramentoAll3)

pd.DataFrame(list(zip(X_train_SacramentoAll3, regressorSacramento3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Sacramento3 = regressorSacramento3.predict(X_train_Sacramento3)

y_train_SacramentoAll4.loc[-1] = y_pred_Sacramento3.item(0)  # adding a row
y_train_SacramentoAll4.index = y_train_SacramentoAll4.index + 1  # shifting index
y_train_SacramentoAll4 = y_train_SacramentoAll4.sort_index()
regressorSacramento4 = LinearRegression()
regressorSacramento4.fit(X_train_SacramentoAll4, y_train_SacramentoAll4)

pd.DataFrame(list(zip(X_train_SacramentoAll4, regressorSacramento4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Sacramento4 = regressorSacramento4.predict(X_train_Sacramento4)

y_train_SacramentoAll5.loc[-1] = y_pred_Sacramento4.item(0)  # adding a row
y_train_SacramentoAll5.index = y_train_SacramentoAll5.index + 1  # shifting index
y_train_SacramentoAll5 = y_train_SacramentoAll5.sort_index()
regressorSacramento5 = LinearRegression()
regressorSacramento5.fit(X_train_SacramentoAll5, y_train_SacramentoAll5)

pd.DataFrame(list(zip(X_train_SacramentoAll5, regressorSacramento5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Sacramento5 = regressorSacramento5.predict(X_train_Sacramento5)

y_train_SacramentoAll6.loc[-1] = y_pred_Sacramento5.item(0)  # adding a row
y_train_SacramentoAll6.index = y_train_SacramentoAll6.index + 1  # shifting index
y_train_SacramentoAll6 = y_train_SacramentoAll6.sort_index()
regressorSacramento6 = LinearRegression()
regressorSacramento6.fit(X_train_SacramentoAll6, y_train_SacramentoAll6)

pd.DataFrame(list(zip(X_train_SacramentoAll6, regressorSacramento6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Sacramento6 = regressorSacramento6.predict(X_train_Sacramento6)

y_train_SacramentoAll7.loc[-1] = y_pred_Sacramento6.item(0)  # adding a row
y_train_SacramentoAll7.index = y_train_SacramentoAll7.index + 1  # shifting index
y_train_SacramentoAll7 = y_train_SacramentoAll7.sort_index()
regressorSacramento7 = LinearRegression()
regressorSacramento7.fit(X_train_SacramentoAll7, y_train_SacramentoAll7)

pd.DataFrame(list(zip(X_train_SacramentoAll7, regressorSacramento7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Sacramento7 = regressorSacramento7.predict(X_train_Sacramento7)

y_train_SacramentoAll8.loc[-1] = y_pred_Sacramento7.item(0)  # adding a row
y_train_SacramentoAll8.index = y_train_SacramentoAll8.index + 1  # shifting index
y_train_SacramentoAll8 = y_train_SacramentoAll8.sort_index()
regressorSacramento8 = LinearRegression()
regressorSacramento8.fit(X_train_SacramentoAll8, y_train_SacramentoAll8)

pd.DataFrame(list(zip(X_train_SacramentoAll8, regressorSacramento8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Sacramento8 = regressorSacramento8.predict(X_train_Sacramento8)

y_train_SacramentoAll9.loc[-1] = y_pred_Sacramento8.item(0)  # adding a row
y_train_SacramentoAll9.index = y_train_SacramentoAll9.index + 1  # shifting index
y_train_SacramentoAll9 = y_train_SacramentoAll9.sort_index()
regressorSacramento9 = LinearRegression()
regressorSacramento9.fit(X_train_SacramentoAll9, y_train_SacramentoAll9)

pd.DataFrame(list(zip(X_train_SacramentoAll9, regressorSacramento9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Sacramento9 = regressorSacramento9.predict(X_train_Sacramento9)

y_train_SacramentoAll10.loc[-1] = y_pred_Sacramento9.item(0)  # adding a row
y_train_SacramentoAll10.index = y_train_SacramentoAll10.index + 1  # shifting index
y_train_SacramentoAll10 = y_train_SacramentoAll10.sort_index()
regressorSacramento10 = LinearRegression()
regressorSacramento10.fit(X_train_SacramentoAll10, y_train_SacramentoAll10)

pd.DataFrame(list(zip(X_train_SacramentoAll10, regressorSacramento10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Sacramento10 = regressorSacramento10.predict(X_train_Sacramento10)

y_train_SacramentoAll11.loc[-1] = y_pred_Sacramento10.item(0)  # adding a row
y_train_SacramentoAll11.index = y_train_SacramentoAll11.index + 1  # shifting index
y_train_SacramentoAll11 = y_train_SacramentoAll11.sort_index()
regressorSacramento11 = LinearRegression()
regressorSacramento11.fit(X_train_SacramentoAll11, y_train_SacramentoAll11)

pd.DataFrame(list(zip(X_train_SacramentoAll11, regressorSacramento11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Sacramento11 = regressorSacramento11.predict(X_train_Sacramento11)

y_train_SacramentoAll12.loc[-1] = y_pred_Sacramento11.item(0)  # adding a row
y_train_SacramentoAll12.index = y_train_SacramentoAll12.index + 1  # shifting index
y_train_SacramentoAll12 = y_train_SacramentoAll12.sort_index()
regressorSacramento12 = LinearRegression()
regressorSacramento12.fit(X_train_SacramentoAll12, y_train_SacramentoAll12)

pd.DataFrame(list(zip(X_train_SacramentoAll12, regressorSacramento12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Sacramento12 = regressorSacramento12.predict(X_train_Sacramento12)

y_train_SacramentoAll13.loc[-1] = y_pred_Sacramento12.item(0)  # adding a row
y_train_SacramentoAll13.index = y_train_SacramentoAll13.index + 1  # shifting index
y_train_SacramentoAll13 = y_train_SacramentoAll13.sort_index()
regressorSacramento13 = LinearRegression()
regressorSacramento13.fit(X_train_SacramentoAll13, y_train_SacramentoAll13)

pd.DataFrame(list(zip(X_train_SacramentoAll13, regressorSacramento13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Sacramento13 = regressorSacramento13.predict(X_train_Sacramento13)

y_train_SacramentoAll14.loc[-1] = y_pred_Sacramento13.item(0)  # adding a row
y_train_SacramentoAll14.index = y_train_SacramentoAll14.index + 1  # shifting index
y_train_SacramentoAll14 = y_train_SacramentoAll14.sort_index()
regressorSacramento14 = LinearRegression()
regressorSacramento14.fit(X_train_SacramentoAll14, y_train_SacramentoAll14)

pd.DataFrame(list(zip(X_train_SacramentoAll14, regressorSacramento14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Sacramento14 = regressorSacramento14.predict(X_train_Sacramento14)

y_train_SacramentoAll15.loc[-1] = y_pred_Sacramento14.item(0)  # adding a row
y_train_SacramentoAll15.index = y_train_SacramentoAll15.index + 1  # shifting index
y_train_SacramentoAll15 = y_train_SacramentoAll15.sort_index()
regressorSacramento15 = LinearRegression()
regressorSacramento15.fit(X_train_SacramentoAll15, y_train_SacramentoAll15)

pd.DataFrame(list(zip(X_train_SacramentoAll15, regressorSacramento15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Sacramento15 = regressorSacramento15.predict(X_train_Sacramento15)

y_train_SacramentoAll16.loc[-1] = y_pred_Sacramento15.item(0)  # adding a row
y_train_SacramentoAll16.index = y_train_SacramentoAll16.index + 1  # shifting index
y_train_SacramentoAll16 = y_train_SacramentoAll16.sort_index()
regressorSacramento16 = LinearRegression()
regressorSacramento16.fit(X_train_SacramentoAll16, y_train_SacramentoAll16)

pd.DataFrame(list(zip(X_train_SacramentoAll16, regressorSacramento16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Sacramento16 = regressorSacramento16.predict(X_train_Sacramento16)

y_train_SacramentoAll17.loc[-1] = y_pred_Sacramento16.item(0)  # adding a row
y_train_SacramentoAll17.index = y_train_SacramentoAll17.index + 1  # shifting index
y_train_SacramentoAll17 = y_train_SacramentoAll17.sort_index()
regressorSacramento17 = LinearRegression()
regressorSacramento17.fit(X_train_SacramentoAll17, y_train_SacramentoAll17)

pd.DataFrame(list(zip(X_train_SacramentoAll17, regressorSacramento17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Sacramento17 = regressorSacramento17.predict(X_train_Sacramento17)

y_train_SacramentoAll18.loc[-1] = y_pred_Sacramento17.item(0)  # adding a row
y_train_SacramentoAll18.index = y_train_SacramentoAll18.index + 1  # shifting index
y_train_SacramentoAll18 = y_train_SacramentoAll18.sort_index()
regressorSacramento18 = LinearRegression()
regressorSacramento18.fit(X_train_SacramentoAll18, y_train_SacramentoAll18)

pd.DataFrame(list(zip(X_train_SacramentoAll18, regressorSacramento18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Sacramento18 = regressorSacramento18.predict(X_train_Sacramento18)

y_train_SacramentoAll19.loc[-1] = y_pred_Sacramento18.item(0)  # adding a row
y_train_SacramentoAll19.index = y_train_SacramentoAll19.index + 1  # shifting index
y_train_SacramentoAll19 = y_train_SacramentoAll19.sort_index()
regressorSacramento19 = LinearRegression()
regressorSacramento19.fit(X_train_SacramentoAll19, y_train_SacramentoAll19)

pd.DataFrame(list(zip(X_train_SacramentoAll19, regressorSacramento19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Sacramento19 = regressorSacramento19.predict(X_train_Sacramento19)

y_train_SacramentoAll20.loc[-1] = y_pred_Sacramento19.item(0)  # adding a row
y_train_SacramentoAll20.index = y_train_SacramentoAll20.index + 1  # shifting index
y_train_SacramentoAll20 = y_train_SacramentoAll20.sort_index()
regressorSacramento20 = LinearRegression()
regressorSacramento20.fit(X_train_SacramentoAll20, y_train_SacramentoAll20)

pd.DataFrame(list(zip(X_train_SacramentoAll20, regressorSacramento20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Sacramento20 = regressorSacramento20.predict(X_train_Sacramento20)

y_train_SacramentoAll21.loc[-1] = y_pred_Sacramento20.item(0)  # adding a row
y_train_SacramentoAll21.index = y_train_SacramentoAll21.index + 1  # shifting index
y_train_SacramentoAll21 = y_train_SacramentoAll21.sort_index()
regressorSacramento21 = LinearRegression()
regressorSacramento21.fit(X_train_SacramentoAll21, y_train_SacramentoAll21)

pd.DataFrame(list(zip(X_train_SacramentoAll21, regressorSacramento21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Sacramento21 = regressorSacramento21.predict(X_train_Sacramento21)

# %%
X_train_Dallas1=X_Dallas[0:1]
y_train_Dallas1=y_Dallas[0:1]
X_train_Dallas2=X_Dallas[1:2]
y_train_Dallas2=y_Dallas[1:2]
X_train_Dallas3=X_Dallas[2:3]
y_train_Dallas3=y_Dallas[2:3]
X_train_Dallas4=X_Dallas[3:4]
y_train_Dallas4=y_Dallas[3:4]
X_train_Dallas5=X_Dallas[4:5]
y_train_Dallas5=y_Dallas[4:5]
y_train_Dallas6=y_Dallas[5:6]
X_train_Dallas7=X_Dallas[7:8]
X_train_Dallas6=X_Dallas[5:6]
y_train_Dallas7=y_Dallas[7:8]
X_train_Dallas8=X_Dallas[8:9]
y_train_Dallas8=y_Dallas[8:9]
X_train_Dallas9=X_Dallas[9:10]
y_train_Dallas9=y_Dallas[9:10]
X_train_Dallas10=X_Dallas[10:11]
y_train_Dallas10=y_Dallas[10:11]
X_train_Dallas11=X_Dallas[11:12]
y_train_Dallas11=y_Dallas[11:12]
X_train_Dallas12=X_Dallas[12:13]
y_train_Dallas12=y_Dallas[12:13]
X_train_Dallas13=X_Dallas[13:14]
y_train_Dallas13=y_Dallas[13:14]
X_train_Dallas14=X_Dallas[14:15]
y_train_Dallas14=y_Dallas[14:15]
X_train_Dallas15=X_Dallas[15:16]
y_train_Dallas15=y_Dallas[15:16]
X_train_Dallas16=X_Dallas[16:17]
y_train_Dallas16=y_Dallas[16:17]
X_train_Dallas17=X_Dallas[17:18]
y_train_Dallas17=y_Dallas[17:18]
X_train_Dallas18=X_Dallas[18:19]
y_train_Dallas18=y_Dallas[18:19]
X_train_Dallas19=X_Dallas[19:20]
y_train_Dallas19=y_Dallas[19:20]
X_train_Dallas20=X_Dallas[20:21]
y_train_Dallas20=y_Dallas[20:21]
X_train_Dallas21=X_Dallas[21:22]
y_train_Dallas21=y_Dallas[21:22]
X_train_Dallas22=X_Dallas[22:23]
y_train_Dallas22=y_Dallas[22:23]


X_train_DallasAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,396,418,440,462,484,506,528,550,572,594,616,638],[5,11,18,19,20]]
y_train_DallasAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,396,418,440,462,484,506,528,550,572,594,616,638],24:25]

X_train_DallasAll2=df.iloc[[0,1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,397,419,441,463,485,507,529,551,573,595,617,639],[5,11,18,19,20]]
y_train_DallasAll2=df.iloc[[1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,397,419,441,463,485,507,529,551,573,595,617,639],24:25]

X_train_DallasAll3=df.iloc[[0,2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,398,420,442,464,486,508,530,552,574,596,618,640],[5,11,18,19,20]]
y_train_DallasAll3=df.iloc[[2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,398,420,442,464,486,508,530,552,574,596,618,640],24:25]

X_train_DallasAll4=df.iloc[[0,3,25,47,69,91,113,135,157,179,201,223,245,267,289,311,333,355,399,421,443,465,487,509,531,553,575,597,619,641],[5,11,18,19,20]]
y_train_DallasAll4=df.iloc[[3,25,47,69,91,113,135,158,179,201,223,245,267,289,311,333,355,399,421,443,465,487,509,531,553,575,597,619,641],24:25]

X_train_DallasAll5=df.iloc[[0,4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,400,422,444,466,488,510,532,554,576,598,620,642],[5,11,18,19,20]]
y_train_DallasAll5=df.iloc[[4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,400,422,444,466,488,510,532,554,576,598,620,642],24:25]

X_train_DallasAll6=df.iloc[[0,5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,401,423,445,467,489,511,533,555,577,599,621,643],[5,11,18,19,20]]
y_train_DallasAll6=df.iloc[[5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,401,423,445,467,489,511,533,555,577,599,621,643],24:25]

X_train_DallasAll7=df.iloc[[0,6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,402,424,446,468,490,512,534,556,578,600,622,644],[5,11,18,19,20]]
y_train_DallasAll7=df.iloc[[6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,402,424,446,468,490,512,534,556,578,600,622,644],24:25]

X_train_DallasAll8=df.iloc[[0,7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,403,425,447,469,491,513,535,557,579,601,623,645],[5,11,18,19,20]]
y_train_DallasAll8=df.iloc[[7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,403,425,447,469,491,513,535,557,579,601,623,645],24:25]

X_train_DallasAll9=df.iloc[[0,8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,404,426,448,470,492,514,536,558,580,602,624,646],[5,11,18,19,20]]
y_train_DallasAll9=df.iloc[[8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,404,426,448,470,492,514,536,558,580,602,624,646],24:25]

X_train_DallasAll10=df.iloc[[0,9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,405,427,449,471,493,515,537,559,581,603,625,647],[5,11,18,19,20]]
y_train_DallasAll10=df.iloc[[9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,405,427,449,471,493,515,537,559,581,603,625,647],24:25]

X_train_DallasAll11=df.iloc[[0,10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,406,428,450,472,494,516,538,560,582,604,626,648],[5,11,18,19,20]]
y_train_DallasAll11=df.iloc[[10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,406,428,450,472,494,516,538,560,582,604,626,648],24:25]

X_train_DallasAll12=df.iloc[[0,11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,407,429,451,473,495,517,539,561,583,605,627,649],[5,11,18,19,20]]
y_train_DallasAll12=df.iloc[[11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,407,429,451,473,495,517,539,561,583,605,627,649],24:25]

X_train_DallasAll13=df.iloc[[0,12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,408,430,452,474,496,518,540,562,584,606,628,650],[5,11,18,19,20]]
y_train_DallasAll13=df.iloc[[12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,408,430,452,474,496,518,540,562,584,606,628,650],24:25]

X_train_DallasAll14=df.iloc[[0,13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,409,431,453,475,497,519,541,563,585,607,629,651],[5,11,18,19,20]]
y_train_DallasAll14=df.iloc[[13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,409,431,453,475,497,519,541,563,585,607,629,651],24:25]

X_train_DallasAll15=df.iloc[[0,14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,410,432,454,476,498,520,542,564,586,608,630,652],[5,11,18,19,20]]
y_train_DallasAll15=df.iloc[[14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,410,432,454,476,498,520,542,564,586,608,630,652],24:25]

X_train_DallasAll16=df.iloc[[0,15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,411,433,455,477,499,521,543,565,587,609,631,653],[5,11,18,19,20]]
y_train_DallasAll16=df.iloc[[15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,411,433,455,477,499,521,543,565,587,609,631,653],24:25]

X_train_DallasAll17=df.iloc[[0,16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,412,434,456,478,500,522,544,566,588,610,632,654],[5,11,18,19,20]]
y_train_DallasAll17=df.iloc[[16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,412,434,456,478,500,522,544,566,588,610,632,654],24:25]

X_train_DallasAll18=df.iloc[[0,17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,413,435,457,479,501,523,545,567,589,611,633,655],[5,11,18,19,20]]
y_train_DallasAll18=df.iloc[[17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,413,435,457,479,501,523,545,567,589,611,633,655],24:25]

X_train_DallasAll19=df.iloc[[0,18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,414,436,458,480,502,524,546,568,590,612,634,656],[5,11,18,19,20]]
y_train_DallasAll19=df.iloc[[18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,414,436,458,480,502,524,546,568,590,612,634,656],24:25]

X_train_DallasAll20=df.iloc[[0,19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,415,437,459,481,503,525,547,569,591,613,635,657],[5,11,18,19,20]]
y_train_DallasAll20=df.iloc[[19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,415,437,459,481,503,525,547,569,591,613,635,657],24:25]

X_train_DallasAll21=df.iloc[[0,20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,416,438,460,482,504,526,548,570,592,614,636,658],[5,11,18,19,20]]
y_train_DallasAll21=df.iloc[[20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,416,438,460,482,504,526,548,570,592,614,636,658],24:25]

X_train_DallasAll22=df.iloc[[0,21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,417,439,461,483,505,527,549,571,593,615,637,659],[5,11,18,19,20]]
y_train_DallasAll22=df.iloc[[21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,417,439,461,483,505,527,549,571,593,615,637,659],24:25]

# %%
regressorDallas1 = LinearRegression()
regressorDallas1.fit(X_train_DallasAll1, y_train_DallasAll1)
pd.DataFrame(list(zip(X_train_DallasAll1, regressorDallas1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_Dallas1 = regressorDallas1.predict(X_train_Dallas1)

# %%
y_train_DallasAll2.loc[-1] = y_pred_Dallas1.item(0)  # adding a row
y_train_DallasAll2.index = y_train_DallasAll2.index + 1  # shifting index
y_train_DallasAll2 = y_train_DallasAll2.sort_index()
regressorDallas2 = LinearRegression()
regressorDallas2.fit(X_train_DallasAll2, y_train_DallasAll2)

pd.DataFrame(list(zip(X_train_DallasAll2, regressorDallas2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Dallas2 = regressorDallas2.predict(X_train_Dallas2)

y_train_DallasAll3.loc[-1] = y_pred_Dallas2.item(0)  # adding a row
y_train_DallasAll3.index = y_train_DallasAll3.index + 1  # shifting index
y_train_DallasAll3 = y_train_DallasAll3.sort_index()
regressorDallas3 = LinearRegression()
regressorDallas3.fit(X_train_DallasAll3, y_train_DallasAll3)

pd.DataFrame(list(zip(X_train_DallasAll3, regressorDallas3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Dallas3 = regressorDallas3.predict(X_train_Dallas3)

y_train_DallasAll4.loc[-1] = y_pred_Dallas3.item(0)  # adding a row
y_train_DallasAll4.index = y_train_DallasAll4.index + 1  # shifting index
y_train_DallasAll4 = y_train_DallasAll4.sort_index()
regressorDallas4 = LinearRegression()
regressorDallas4.fit(X_train_DallasAll4, y_train_DallasAll4)

pd.DataFrame(list(zip(X_train_DallasAll4, regressorDallas4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Dallas4 = regressorDallas4.predict(X_train_Dallas4)

y_train_DallasAll5.loc[-1] = y_pred_Dallas4.item(0)  # adding a row
y_train_DallasAll5.index = y_train_DallasAll5.index + 1  # shifting index
y_train_DallasAll5 = y_train_DallasAll5.sort_index()
regressorDallas5 = LinearRegression()
regressorDallas5.fit(X_train_DallasAll5, y_train_DallasAll5)

pd.DataFrame(list(zip(X_train_DallasAll5, regressorDallas5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Dallas5 = regressorDallas5.predict(X_train_Dallas5)

y_train_DallasAll6.loc[-1] = y_pred_Dallas5.item(0)  # adding a row
y_train_DallasAll6.index = y_train_DallasAll6.index + 1  # shifting index
y_train_DallasAll6 = y_train_DallasAll6.sort_index()
regressorDallas6 = LinearRegression()
regressorDallas6.fit(X_train_DallasAll6, y_train_DallasAll6)

pd.DataFrame(list(zip(X_train_DallasAll6, regressorDallas6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Dallas6 = regressorDallas6.predict(X_train_Dallas6)

y_train_DallasAll7.loc[-1] = y_pred_Dallas6.item(0)  # adding a row
y_train_DallasAll7.index = y_train_DallasAll7.index + 1  # shifting index
y_train_DallasAll7 = y_train_DallasAll7.sort_index()
regressorDallas7 = LinearRegression()
regressorDallas7.fit(X_train_DallasAll7, y_train_DallasAll7)

pd.DataFrame(list(zip(X_train_DallasAll7, regressorDallas7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Dallas7 = regressorDallas7.predict(X_train_Dallas7)

y_train_DallasAll8.loc[-1] = y_pred_Dallas7.item(0)  # adding a row
y_train_DallasAll8.index = y_train_DallasAll8.index + 1  # shifting index
y_train_DallasAll8 = y_train_DallasAll8.sort_index()
regressorDallas8 = LinearRegression()
regressorDallas8.fit(X_train_DallasAll8, y_train_DallasAll8)

pd.DataFrame(list(zip(X_train_DallasAll8, regressorDallas8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Dallas8 = regressorDallas8.predict(X_train_Dallas8)

y_train_DallasAll9.loc[-1] = y_pred_Dallas8.item(0)  # adding a row
y_train_DallasAll9.index = y_train_DallasAll9.index + 1  # shifting index
y_train_DallasAll9 = y_train_DallasAll9.sort_index()
regressorDallas9 = LinearRegression()
regressorDallas9.fit(X_train_DallasAll9, y_train_DallasAll9)

pd.DataFrame(list(zip(X_train_DallasAll9, regressorDallas9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Dallas9 = regressorDallas9.predict(X_train_Dallas9)

y_train_DallasAll10.loc[-1] = y_pred_Dallas9.item(0)  # adding a row
y_train_DallasAll10.index = y_train_DallasAll10.index + 1  # shifting index
y_train_DallasAll10 = y_train_DallasAll10.sort_index()
regressorDallas10 = LinearRegression()
regressorDallas10.fit(X_train_DallasAll10, y_train_DallasAll10)

pd.DataFrame(list(zip(X_train_DallasAll10, regressorDallas10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Dallas10 = regressorDallas10.predict(X_train_Dallas10)

y_train_DallasAll11.loc[-1] = y_pred_Dallas10.item(0)  # adding a row
y_train_DallasAll11.index = y_train_DallasAll11.index + 1  # shifting index
y_train_DallasAll11 = y_train_DallasAll11.sort_index()
regressorDallas11 = LinearRegression()
regressorDallas11.fit(X_train_DallasAll11, y_train_DallasAll11)

pd.DataFrame(list(zip(X_train_DallasAll11, regressorDallas11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Dallas11 = regressorDallas11.predict(X_train_Dallas11)

y_train_DallasAll12.loc[-1] = y_pred_Dallas11.item(0)  # adding a row
y_train_DallasAll12.index = y_train_DallasAll12.index + 1  # shifting index
y_train_DallasAll12 = y_train_DallasAll12.sort_index()
regressorDallas12 = LinearRegression()
regressorDallas12.fit(X_train_DallasAll12, y_train_DallasAll12)

pd.DataFrame(list(zip(X_train_DallasAll12, regressorDallas12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Dallas12 = regressorDallas12.predict(X_train_Dallas12)

y_train_DallasAll13.loc[-1] = y_pred_Dallas12.item(0)  # adding a row
y_train_DallasAll13.index = y_train_DallasAll13.index + 1  # shifting index
y_train_DallasAll13 = y_train_DallasAll13.sort_index()
regressorDallas13 = LinearRegression()
regressorDallas13.fit(X_train_DallasAll13, y_train_DallasAll13)

pd.DataFrame(list(zip(X_train_DallasAll13, regressorDallas13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Dallas13 = regressorDallas13.predict(X_train_Dallas13)

y_train_DallasAll14.loc[-1] = y_pred_Dallas13.item(0)  # adding a row
y_train_DallasAll14.index = y_train_DallasAll14.index + 1  # shifting index
y_train_DallasAll14 = y_train_DallasAll14.sort_index()
regressorDallas14 = LinearRegression()
regressorDallas14.fit(X_train_DallasAll14, y_train_DallasAll14)

pd.DataFrame(list(zip(X_train_DallasAll14, regressorDallas14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Dallas14 = regressorDallas14.predict(X_train_Dallas14)

y_train_DallasAll15.loc[-1] = y_pred_Dallas14.item(0)  # adding a row
y_train_DallasAll15.index = y_train_DallasAll15.index + 1  # shifting index
y_train_DallasAll15 = y_train_DallasAll15.sort_index()
regressorDallas15 = LinearRegression()
regressorDallas15.fit(X_train_DallasAll15, y_train_DallasAll15)

pd.DataFrame(list(zip(X_train_DallasAll15, regressorDallas15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Dallas15 = regressorDallas15.predict(X_train_Dallas15)

y_train_DallasAll16.loc[-1] = y_pred_Dallas15.item(0)  # adding a row
y_train_DallasAll16.index = y_train_DallasAll16.index + 1  # shifting index
y_train_DallasAll16 = y_train_DallasAll16.sort_index()
regressorDallas16 = LinearRegression()
regressorDallas16.fit(X_train_DallasAll16, y_train_DallasAll16)

pd.DataFrame(list(zip(X_train_DallasAll16, regressorDallas16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Dallas16 = regressorDallas16.predict(X_train_Dallas16)

y_train_DallasAll17.loc[-1] = y_pred_Dallas16.item(0)  # adding a row
y_train_DallasAll17.index = y_train_DallasAll17.index + 1  # shifting index
y_train_DallasAll17 = y_train_DallasAll17.sort_index()
regressorDallas17 = LinearRegression()
regressorDallas17.fit(X_train_DallasAll17, y_train_DallasAll17)

pd.DataFrame(list(zip(X_train_DallasAll17, regressorDallas17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Dallas17 = regressorDallas17.predict(X_train_Dallas17)

y_train_DallasAll18.loc[-1] = y_pred_Dallas17.item(0)  # adding a row
y_train_DallasAll18.index = y_train_DallasAll18.index + 1  # shifting index
y_train_DallasAll18 = y_train_DallasAll18.sort_index()
regressorDallas18 = LinearRegression()
regressorDallas18.fit(X_train_DallasAll18, y_train_DallasAll18)

pd.DataFrame(list(zip(X_train_DallasAll18, regressorDallas18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Dallas18 = regressorDallas18.predict(X_train_Dallas18)

y_train_DallasAll19.loc[-1] = y_pred_Dallas18.item(0)  # adding a row
y_train_DallasAll19.index = y_train_DallasAll19.index + 1  # shifting index
y_train_DallasAll19 = y_train_DallasAll19.sort_index()
regressorDallas19 = LinearRegression()
regressorDallas19.fit(X_train_DallasAll19, y_train_DallasAll19)

pd.DataFrame(list(zip(X_train_DallasAll19, regressorDallas19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Dallas19 = regressorDallas19.predict(X_train_Dallas19)

y_train_DallasAll20.loc[-1] = y_pred_Dallas19.item(0)  # adding a row
y_train_DallasAll20.index = y_train_DallasAll20.index + 1  # shifting index
y_train_DallasAll20 = y_train_DallasAll20.sort_index()
regressorDallas20 = LinearRegression()
regressorDallas20.fit(X_train_DallasAll20, y_train_DallasAll20)

pd.DataFrame(list(zip(X_train_DallasAll20, regressorDallas20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Dallas20 = regressorDallas20.predict(X_train_Dallas20)

y_train_DallasAll21.loc[-1] = y_pred_Dallas20.item(0)  # adding a row
y_train_DallasAll21.index = y_train_DallasAll21.index + 1  # shifting index
y_train_DallasAll21 = y_train_DallasAll21.sort_index()
regressorDallas21 = LinearRegression()
regressorDallas21.fit(X_train_DallasAll21, y_train_DallasAll21)

pd.DataFrame(list(zip(X_train_DallasAll21, regressorDallas21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Dallas21 = regressorDallas21.predict(X_train_Dallas21)

# %%
X_train_Memphis1=X_Memphis[0:1]
y_train_Memphis1=y_Memphis[0:1]
X_train_Memphis2=X_Memphis[1:2]
y_train_Memphis2=y_Memphis[1:2]
X_train_Memphis3=X_Memphis[2:3]
y_train_Memphis3=y_Memphis[2:3]
X_train_Memphis4=X_Memphis[3:4]
y_train_Memphis4=y_Memphis[3:4]
X_train_Memphis5=X_Memphis[4:5]
y_train_Memphis5=y_Memphis[4:5]
y_train_Memphis6=y_Memphis[5:6]
X_train_Memphis7=X_Memphis[7:8]
X_train_Memphis6=X_Memphis[5:6]
y_train_Memphis7=y_Memphis[7:8]
X_train_Memphis8=X_Memphis[8:9]
y_train_Memphis8=y_Memphis[8:9]
X_train_Memphis9=X_Memphis[9:10]
y_train_Memphis9=y_Memphis[9:10]
X_train_Memphis10=X_Memphis[10:11]
y_train_Memphis10=y_Memphis[10:11]
X_train_Memphis11=X_Memphis[11:12]
y_train_Memphis11=y_Memphis[11:12]
X_train_Memphis12=X_Memphis[12:13]
y_train_Memphis12=y_Memphis[12:13]
X_train_Memphis13=X_Memphis[13:14]
y_train_Memphis13=y_Memphis[13:14]
X_train_Memphis14=X_Memphis[14:15]
y_train_Memphis14=y_Memphis[14:15]
X_train_Memphis15=X_Memphis[15:16]
y_train_Memphis15=y_Memphis[15:16]
X_train_Memphis16=X_Memphis[16:17]
y_train_Memphis16=y_Memphis[16:17]
X_train_Memphis17=X_Memphis[17:18]
y_train_Memphis17=y_Memphis[17:18]
X_train_Memphis18=X_Memphis[18:19]
y_train_Memphis18=y_Memphis[18:19]
X_train_Memphis19=X_Memphis[19:20]
y_train_Memphis19=y_Memphis[19:20]
X_train_Memphis20=X_Memphis[20:21]
y_train_Memphis20=y_Memphis[20:21]
X_train_Memphis21=X_Memphis[21:22]
y_train_Memphis21=y_Memphis[21:22]
X_train_Memphis22=X_Memphis[22:23]
y_train_Memphis22=y_Memphis[22:23]


X_train_MemphisAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,418,440,462,484,506,528,550,572,594,616,638],[5,11,18,19,20]]
y_train_MemphisAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,418,440,462,484,506,528,550,572,594,616,638],24:25]

X_train_MemphisAll2=df.iloc[[0,1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,375,419,441,463,485,507,529,551,573,595,617,639],[5,11,18,19,20]]
y_train_MemphisAll2=df.iloc[[1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,375,419,441,463,485,507,529,551,573,595,617,639],24:25]

X_train_MemphisAll3=df.iloc[[0,2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,376,420,442,464,486,508,530,552,574,596,618,640],[5,11,18,19,20]]
y_train_MemphisAll3=df.iloc[[2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,376,420,442,464,486,508,530,552,574,596,618,640],24:25]

X_train_MemphisAll4=df.iloc[[0,3,25,47,69,91,113,135,157,179,201,223,245,267,289,311,333,355,377,421,443,465,487,509,531,553,575,597,619,641],[5,11,18,19,20]]
y_train_MemphisAll4=df.iloc[[3,25,47,69,91,113,135,158,179,201,223,245,267,289,311,333,355,377,421,443,465,487,509,531,553,575,597,619,641],24:25]

X_train_MemphisAll5=df.iloc[[0,4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,378,422,444,466,488,510,532,554,576,598,620,642],[5,11,18,19,20]]
y_train_MemphisAll5=df.iloc[[4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,378,422,444,466,488,510,532,554,576,598,620,642],24:25]

X_train_MemphisAll6=df.iloc[[0,5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,379,423,445,467,489,511,533,555,577,599,621,643],[5,11,18,19,20]]
y_train_MemphisAll6=df.iloc[[5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,379,423,445,467,489,511,533,555,577,599,621,643],24:25]

X_train_MemphisAll7=df.iloc[[0,6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,380,424,446,468,490,512,534,556,578,600,622,644],[5,11,18,19,20]]
y_train_MemphisAll7=df.iloc[[6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,380,424,446,468,490,512,534,556,578,600,622,644],24:25]

X_train_MemphisAll8=df.iloc[[0,7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,381,425,447,469,491,513,535,557,579,601,623,645],[5,11,18,19,20]]
y_train_MemphisAll8=df.iloc[[7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,381,425,447,469,491,513,535,557,579,601,623,645],24:25]

X_train_MemphisAll9=df.iloc[[0,8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,382,426,448,470,492,514,536,558,580,602,624,646],[5,11,18,19,20]]
y_train_MemphisAll9=df.iloc[[8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,382,426,448,470,492,514,536,558,580,602,624,646],24:25]

X_train_MemphisAll10=df.iloc[[0,9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,383,427,449,471,493,515,537,559,581,603,625,647],[5,11,18,19,20]]
y_train_MemphisAll10=df.iloc[[9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,383,427,449,471,493,515,537,559,581,603,625,647],24:25]

X_train_MemphisAll11=df.iloc[[0,10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,384,428,450,472,494,516,538,560,582,604,626,648],[5,11,18,19,20]]
y_train_MemphisAll11=df.iloc[[10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,384,428,450,472,494,516,538,560,582,604,626,648],24:25]

X_train_MemphisAll12=df.iloc[[0,11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,385,429,451,473,495,517,539,561,583,605,627,649],[5,11,18,19,20]]
y_train_MemphisAll12=df.iloc[[11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,385,429,451,473,495,517,539,561,583,605,627,649],24:25]

X_train_MemphisAll13=df.iloc[[0,12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,386,430,452,474,496,518,540,562,584,606,628,650],[5,11,18,19,20]]
y_train_MemphisAll13=df.iloc[[12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,386,430,452,474,496,518,540,562,584,606,628,650],24:25]

X_train_MemphisAll14=df.iloc[[0,13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,387,431,453,475,497,519,541,563,585,607,629,651],[5,11,18,19,20]]
y_train_MemphisAll14=df.iloc[[13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,387,431,453,475,497,519,541,563,585,607,629,651],24:25]

X_train_MemphisAll15=df.iloc[[0,14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,388,432,454,476,498,520,542,564,586,608,630,652],[5,11,18,19,20]]
y_train_MemphisAll15=df.iloc[[14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,388,432,454,476,498,520,542,564,586,608,630,652],24:25]

X_train_MemphisAll16=df.iloc[[0,15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,389,433,455,477,499,521,543,565,587,609,631,653],[5,11,18,19,20]]
y_train_MemphisAll16=df.iloc[[15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,389,433,455,477,499,521,543,565,587,609,631,653],24:25]

X_train_MemphisAll17=df.iloc[[0,16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,390,434,456,478,500,522,544,566,588,610,632,654],[5,11,18,19,20]]
y_train_MemphisAll17=df.iloc[[16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,390,434,456,478,500,522,544,566,588,610,632,654],24:25]

X_train_MemphisAll18=df.iloc[[0,17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,391,435,457,479,501,523,545,567,589,611,633,655],[5,11,18,19,20]]
y_train_MemphisAll18=df.iloc[[17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,391,435,457,479,501,523,545,567,589,611,633,655],24:25]

X_train_MemphisAll19=df.iloc[[0,18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,392,436,458,480,502,524,546,568,590,612,634,656],[5,11,18,19,20]]
y_train_MemphisAll19=df.iloc[[18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,392,436,458,480,502,524,546,568,590,612,634,656],24:25]

X_train_MemphisAll20=df.iloc[[0,19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,393,437,459,481,503,525,547,569,591,613,635,657],[5,11,18,19,20]]
y_train_MemphisAll20=df.iloc[[19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,393,437,459,481,503,525,547,569,591,613,635,657],24:25]

X_train_MemphisAll21=df.iloc[[0,20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,394,438,460,482,504,526,548,570,592,614,636,658],[5,11,18,19,20]]
y_train_MemphisAll21=df.iloc[[20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,394,438,460,482,504,526,548,570,592,614,636,658],24:25]

X_train_MemphisAll22=df.iloc[[0,21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,395,439,461,483,505,527,549,571,593,615,637,659],[5,11,18,19,20]]
y_train_MemphisAll22=df.iloc[[21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,395,439,461,483,505,527,549,571,593,615,637,659],24:25]

# %%
regressorMemphis1 = LinearRegression()
regressorMemphis1.fit(X_train_MemphisAll1, y_train_MemphisAll1)
pd.DataFrame(list(zip(X_train_MemphisAll1, regressorMemphis1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_Memphis1 = regressorMemphis1.predict(X_train_Memphis1)

# %%
y_train_MemphisAll2.loc[-1] = y_pred_Memphis1.item(0)  # adding a row
y_train_MemphisAll2.index = y_train_MemphisAll2.index + 1  # shifting index
y_train_MemphisAll2 = y_train_MemphisAll2.sort_index()
regressorMemphis2 = LinearRegression()
regressorMemphis2.fit(X_train_MemphisAll2, y_train_MemphisAll2)

pd.DataFrame(list(zip(X_train_MemphisAll2, regressorMemphis2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Memphis2 = regressorMemphis2.predict(X_train_Memphis2)

y_train_MemphisAll3.loc[-1] = y_pred_Memphis2.item(0)  # adding a row
y_train_MemphisAll3.index = y_train_MemphisAll3.index + 1  # shifting index
y_train_MemphisAll3 = y_train_MemphisAll3.sort_index()
regressorMemphis3 = LinearRegression()
regressorMemphis3.fit(X_train_MemphisAll3, y_train_MemphisAll3)

pd.DataFrame(list(zip(X_train_MemphisAll3, regressorMemphis3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Memphis3 = regressorMemphis3.predict(X_train_Memphis3)

y_train_MemphisAll4.loc[-1] = y_pred_Memphis3.item(0)  # adding a row
y_train_MemphisAll4.index = y_train_MemphisAll4.index + 1  # shifting index
y_train_MemphisAll4 = y_train_MemphisAll4.sort_index()
regressorMemphis4 = LinearRegression()
regressorMemphis4.fit(X_train_MemphisAll4, y_train_MemphisAll4)

pd.DataFrame(list(zip(X_train_MemphisAll4, regressorMemphis4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Memphis4 = regressorMemphis4.predict(X_train_Memphis4)

y_train_MemphisAll5.loc[-1] = y_pred_Memphis4.item(0)  # adding a row
y_train_MemphisAll5.index = y_train_MemphisAll5.index + 1  # shifting index
y_train_MemphisAll5 = y_train_MemphisAll5.sort_index()
regressorMemphis5 = LinearRegression()
regressorMemphis5.fit(X_train_MemphisAll5, y_train_MemphisAll5)

pd.DataFrame(list(zip(X_train_MemphisAll5, regressorMemphis5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Memphis5 = regressorMemphis5.predict(X_train_Memphis5)

y_train_MemphisAll6.loc[-1] = y_pred_Memphis5.item(0)  # adding a row
y_train_MemphisAll6.index = y_train_MemphisAll6.index + 1  # shifting index
y_train_MemphisAll6 = y_train_MemphisAll6.sort_index()
regressorMemphis6 = LinearRegression()
regressorMemphis6.fit(X_train_MemphisAll6, y_train_MemphisAll6)

pd.DataFrame(list(zip(X_train_MemphisAll6, regressorMemphis6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Memphis6 = regressorMemphis6.predict(X_train_Memphis6)

y_train_MemphisAll7.loc[-1] = y_pred_Memphis6.item(0)  # adding a row
y_train_MemphisAll7.index = y_train_MemphisAll7.index + 1  # shifting index
y_train_MemphisAll7 = y_train_MemphisAll7.sort_index()
regressorMemphis7 = LinearRegression()
regressorMemphis7.fit(X_train_MemphisAll7, y_train_MemphisAll7)

pd.DataFrame(list(zip(X_train_MemphisAll7, regressorMemphis7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Memphis7 = regressorMemphis7.predict(X_train_Memphis7)

y_train_MemphisAll8.loc[-1] = y_pred_Memphis7.item(0)  # adding a row
y_train_MemphisAll8.index = y_train_MemphisAll8.index + 1  # shifting index
y_train_MemphisAll8 = y_train_MemphisAll8.sort_index()
regressorMemphis8 = LinearRegression()
regressorMemphis8.fit(X_train_MemphisAll8, y_train_MemphisAll8)

pd.DataFrame(list(zip(X_train_MemphisAll8, regressorMemphis8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Memphis8 = regressorMemphis8.predict(X_train_Memphis8)

y_train_MemphisAll9.loc[-1] = y_pred_Memphis8.item(0)  # adding a row
y_train_MemphisAll9.index = y_train_MemphisAll9.index + 1  # shifting index
y_train_MemphisAll9 = y_train_MemphisAll9.sort_index()
regressorMemphis9 = LinearRegression()
regressorMemphis9.fit(X_train_MemphisAll9, y_train_MemphisAll9)

pd.DataFrame(list(zip(X_train_MemphisAll9, regressorMemphis9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Memphis9 = regressorMemphis9.predict(X_train_Memphis9)

y_train_MemphisAll10.loc[-1] = y_pred_Memphis9.item(0)  # adding a row
y_train_MemphisAll10.index = y_train_MemphisAll10.index + 1  # shifting index
y_train_MemphisAll10 = y_train_MemphisAll10.sort_index()
regressorMemphis10 = LinearRegression()
regressorMemphis10.fit(X_train_MemphisAll10, y_train_MemphisAll10)

pd.DataFrame(list(zip(X_train_MemphisAll10, regressorMemphis10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Memphis10 = regressorMemphis10.predict(X_train_Memphis10)

y_train_MemphisAll11.loc[-1] = y_pred_Memphis10.item(0)  # adding a row
y_train_MemphisAll11.index = y_train_MemphisAll11.index + 1  # shifting index
y_train_MemphisAll11 = y_train_MemphisAll11.sort_index()
regressorMemphis11 = LinearRegression()
regressorMemphis11.fit(X_train_MemphisAll11, y_train_MemphisAll11)

pd.DataFrame(list(zip(X_train_MemphisAll11, regressorMemphis11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Memphis11 = regressorMemphis11.predict(X_train_Memphis11)

y_train_MemphisAll12.loc[-1] = y_pred_Memphis11.item(0)  # adding a row
y_train_MemphisAll12.index = y_train_MemphisAll12.index + 1  # shifting index
y_train_MemphisAll12 = y_train_MemphisAll12.sort_index()
regressorMemphis12 = LinearRegression()
regressorMemphis12.fit(X_train_MemphisAll12, y_train_MemphisAll12)

pd.DataFrame(list(zip(X_train_MemphisAll12, regressorMemphis12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Memphis12 = regressorMemphis12.predict(X_train_Memphis12)

y_train_MemphisAll13.loc[-1] = y_pred_Memphis12.item(0)  # adding a row
y_train_MemphisAll13.index = y_train_MemphisAll13.index + 1  # shifting index
y_train_MemphisAll13 = y_train_MemphisAll13.sort_index()
regressorMemphis13 = LinearRegression()
regressorMemphis13.fit(X_train_MemphisAll13, y_train_MemphisAll13)

pd.DataFrame(list(zip(X_train_MemphisAll13, regressorMemphis13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Memphis13 = regressorMemphis13.predict(X_train_Memphis13)

y_train_MemphisAll14.loc[-1] = y_pred_Memphis13.item(0)  # adding a row
y_train_MemphisAll14.index = y_train_MemphisAll14.index + 1  # shifting index
y_train_MemphisAll14 = y_train_MemphisAll14.sort_index()
regressorMemphis14 = LinearRegression()
regressorMemphis14.fit(X_train_MemphisAll14, y_train_MemphisAll14)

pd.DataFrame(list(zip(X_train_MemphisAll14, regressorMemphis14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Memphis14 = regressorMemphis14.predict(X_train_Memphis14)

y_train_MemphisAll15.loc[-1] = y_pred_Memphis14.item(0)  # adding a row
y_train_MemphisAll15.index = y_train_MemphisAll15.index + 1  # shifting index
y_train_MemphisAll15 = y_train_MemphisAll15.sort_index()
regressorMemphis15 = LinearRegression()
regressorMemphis15.fit(X_train_MemphisAll15, y_train_MemphisAll15)

pd.DataFrame(list(zip(X_train_MemphisAll15, regressorMemphis15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Memphis15 = regressorMemphis15.predict(X_train_Memphis15)

y_train_MemphisAll16.loc[-1] = y_pred_Memphis15.item(0)  # adding a row
y_train_MemphisAll16.index = y_train_MemphisAll16.index + 1  # shifting index
y_train_MemphisAll16 = y_train_MemphisAll16.sort_index()
regressorMemphis16 = LinearRegression()
regressorMemphis16.fit(X_train_MemphisAll16, y_train_MemphisAll16)

pd.DataFrame(list(zip(X_train_MemphisAll16, regressorMemphis16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Memphis16 = regressorMemphis16.predict(X_train_Memphis16)

y_train_MemphisAll17.loc[-1] = y_pred_Memphis16.item(0)  # adding a row
y_train_MemphisAll17.index = y_train_MemphisAll17.index + 1  # shifting index
y_train_MemphisAll17 = y_train_MemphisAll17.sort_index()
regressorMemphis17 = LinearRegression()
regressorMemphis17.fit(X_train_MemphisAll17, y_train_MemphisAll17)

pd.DataFrame(list(zip(X_train_MemphisAll17, regressorMemphis17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Memphis17 = regressorMemphis17.predict(X_train_Memphis17)

y_train_MemphisAll18.loc[-1] = y_pred_Memphis17.item(0)  # adding a row
y_train_MemphisAll18.index = y_train_MemphisAll18.index + 1  # shifting index
y_train_MemphisAll18 = y_train_MemphisAll18.sort_index()
regressorMemphis18 = LinearRegression()
regressorMemphis18.fit(X_train_MemphisAll18, y_train_MemphisAll18)

pd.DataFrame(list(zip(X_train_MemphisAll18, regressorMemphis18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Memphis18 = regressorMemphis18.predict(X_train_Memphis18)

y_train_MemphisAll19.loc[-1] = y_pred_Memphis18.item(0)  # adding a row
y_train_MemphisAll19.index = y_train_MemphisAll19.index + 1  # shifting index
y_train_MemphisAll19 = y_train_MemphisAll19.sort_index()
regressorMemphis19 = LinearRegression()
regressorMemphis19.fit(X_train_MemphisAll19, y_train_MemphisAll19)

pd.DataFrame(list(zip(X_train_MemphisAll19, regressorMemphis19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Memphis19 = regressorMemphis19.predict(X_train_Memphis19)

y_train_MemphisAll20.loc[-1] = y_pred_Memphis19.item(0)  # adding a row
y_train_MemphisAll20.index = y_train_MemphisAll20.index + 1  # shifting index
y_train_MemphisAll20 = y_train_MemphisAll20.sort_index()
regressorMemphis20 = LinearRegression()
regressorMemphis20.fit(X_train_MemphisAll20, y_train_MemphisAll20)

pd.DataFrame(list(zip(X_train_MemphisAll20, regressorMemphis20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Memphis20 = regressorMemphis20.predict(X_train_Memphis20)

y_train_MemphisAll21.loc[-1] = y_pred_Memphis20.item(0)  # adding a row
y_train_MemphisAll21.index = y_train_MemphisAll21.index + 1  # shifting index
y_train_MemphisAll21 = y_train_MemphisAll21.sort_index()
regressorMemphis21 = LinearRegression()
regressorMemphis21.fit(X_train_MemphisAll21, y_train_MemphisAll21)

pd.DataFrame(list(zip(X_train_MemphisAll21, regressorMemphis21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Memphis21 = regressorMemphis21.predict(X_train_Memphis21)

# %%
X_train_Phoenix1=X_Phoenix[0:1]
y_train_Phoenix1=y_Phoenix[0:1]
X_train_Phoenix2=X_Phoenix[1:2]
y_train_Phoenix2=y_Phoenix[1:2]
X_train_Phoenix3=X_Phoenix[2:3]
y_train_Phoenix3=y_Phoenix[2:3]
X_train_Phoenix4=X_Phoenix[3:4]
y_train_Phoenix4=y_Phoenix[3:4]
X_train_Phoenix5=X_Phoenix[4:5]
y_train_Phoenix5=y_Phoenix[4:5]
y_train_Phoenix6=y_Phoenix[5:6]
X_train_Phoenix7=X_Phoenix[7:8]
X_train_Phoenix6=X_Phoenix[5:6]
y_train_Phoenix7=y_Phoenix[7:8]
X_train_Phoenix8=X_Phoenix[8:9]
y_train_Phoenix8=y_Phoenix[8:9]
X_train_Phoenix9=X_Phoenix[9:10]
y_train_Phoenix9=y_Phoenix[9:10]
X_train_Phoenix10=X_Phoenix[10:11]
y_train_Phoenix10=y_Phoenix[10:11]
X_train_Phoenix11=X_Phoenix[11:12]
y_train_Phoenix11=y_Phoenix[11:12]
X_train_Phoenix12=X_Phoenix[12:13]
y_train_Phoenix12=y_Phoenix[12:13]
X_train_Phoenix13=X_Phoenix[13:14]
y_train_Phoenix13=y_Phoenix[13:14]
X_train_Phoenix14=X_Phoenix[14:15]
y_train_Phoenix14=y_Phoenix[14:15]
X_train_Phoenix15=X_Phoenix[15:16]
y_train_Phoenix15=y_Phoenix[15:16]
X_train_Phoenix16=X_Phoenix[16:17]
y_train_Phoenix16=y_Phoenix[16:17]
X_train_Phoenix17=X_Phoenix[17:18]
y_train_Phoenix17=y_Phoenix[17:18]
X_train_Phoenix18=X_Phoenix[18:19]
y_train_Phoenix18=y_Phoenix[18:19]
X_train_Phoenix19=X_Phoenix[19:20]
y_train_Phoenix19=y_Phoenix[19:20]
X_train_Phoenix20=X_Phoenix[20:21]
y_train_Phoenix20=y_Phoenix[20:21]
X_train_Phoenix21=X_Phoenix[21:22]
y_train_Phoenix21=y_Phoenix[21:22]
X_train_Phoenix22=X_Phoenix[22:23]
y_train_Phoenix22=y_Phoenix[22:23]


X_train_PhoenixAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,440,462,484,506,528,550,572,594,616,638],[5,11,18,19,20]]
y_train_PhoenixAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,440,462,484,506,528,550,572,594,616,638],24:25]

X_train_PhoenixAll2=df.iloc[[0,1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,375,397,441,463,485,507,529,551,573,595,617,639],[5,11,18,19,20]]
y_train_PhoenixAll2=df.iloc[[1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,375,397,441,463,485,507,529,551,573,595,617,639],24:25]

X_train_PhoenixAll3=df.iloc[[0,2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,376,398,442,464,486,508,530,552,574,596,618,640],[5,11,18,19,20]]
y_train_PhoenixAll3=df.iloc[[2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,376,398,442,464,486,508,530,552,574,596,618,640],24:25]

X_train_PhoenixAll4=df.iloc[[0,3,25,47,69,91,113,135,157,179,201,223,245,267,289,311,333,355,377,399,443,465,487,509,531,553,575,597,619,641],[5,11,18,19,20]]
y_train_PhoenixAll4=df.iloc[[3,25,47,69,91,113,135,158,179,201,223,245,267,289,311,333,355,377,399,443,465,487,509,531,553,575,597,619,641],24:25]

X_train_PhoenixAll5=df.iloc[[0,4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,378,400,444,466,488,510,532,554,576,598,620,642],[5,11,18,19,20]]
y_train_PhoenixAll5=df.iloc[[4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,378,400,444,466,488,510,532,554,576,598,620,642],24:25]

X_train_PhoenixAll6=df.iloc[[0,5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,379,401,445,467,489,511,533,555,577,599,621,643],[5,11,18,19,20]]
y_train_PhoenixAll6=df.iloc[[5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,379,401,445,467,489,511,533,555,577,599,621,643],24:25]

X_train_PhoenixAll7=df.iloc[[0,6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,380,402,446,468,490,512,534,556,578,600,622,644],[5,11,18,19,20]]
y_train_PhoenixAll7=df.iloc[[6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,380,402,446,468,490,512,534,556,578,600,622,644],24:25]

X_train_PhoenixAll8=df.iloc[[0,7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,381,403,447,469,491,513,535,557,579,601,623,645],[5,11,18,19,20]]
y_train_PhoenixAll8=df.iloc[[7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,381,403,447,469,491,513,535,557,579,601,623,645],24:25]

X_train_PhoenixAll9=df.iloc[[0,8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,382,404,448,470,492,514,536,558,580,602,624,646],[5,11,18,19,20]]
y_train_PhoenixAll9=df.iloc[[8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,382,404,448,470,492,514,536,558,580,602,624,646],24:25]

X_train_PhoenixAll10=df.iloc[[0,9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,383,405,449,471,493,515,537,559,581,603,625,647],[5,11,18,19,20]]
y_train_PhoenixAll10=df.iloc[[9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,383,405,449,471,493,515,537,559,581,603,625,647],24:25]

X_train_PhoenixAll11=df.iloc[[0,10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,384,406,450,472,494,516,538,560,582,604,626,648],[5,11,18,19,20]]
y_train_PhoenixAll11=df.iloc[[10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,384,406,450,472,494,516,538,560,582,604,626,648],24:25]

X_train_PhoenixAll12=df.iloc[[0,11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,385,407,451,473,495,517,539,561,583,605,627,649],[5,11,18,19,20]]
y_train_PhoenixAll12=df.iloc[[11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,385,407,451,473,495,517,539,561,583,605,627,649],24:25]

X_train_PhoenixAll13=df.iloc[[0,12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,386,408,452,474,496,518,540,562,584,606,628,650],[5,11,18,19,20]]
y_train_PhoenixAll13=df.iloc[[12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,386,408,452,474,496,518,540,562,584,606,628,650],24:25]

X_train_PhoenixAll14=df.iloc[[0,13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,387,409,453,475,497,519,541,563,585,607,629,651],[5,11,18,19,20]]
y_train_PhoenixAll14=df.iloc[[13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,387,409,453,475,497,519,541,563,585,607,629,651],24:25]

X_train_PhoenixAll15=df.iloc[[0,14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,388,410,454,476,498,520,542,564,586,608,630,652],[5,11,18,19,20]]
y_train_PhoenixAll15=df.iloc[[14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,388,410,454,476,498,520,542,564,586,608,630,652],24:25]

X_train_PhoenixAll16=df.iloc[[0,15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,389,411,455,477,499,521,543,565,587,609,631,653],[5,11,18,19,20]]
y_train_PhoenixAll16=df.iloc[[15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,389,411,455,477,499,521,543,565,587,609,631,653],24:25]

X_train_PhoenixAll17=df.iloc[[0,16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,390,412,456,478,500,522,544,566,588,610,632,654],[5,11,18,19,20]]
y_train_PhoenixAll17=df.iloc[[16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,390,412,456,478,500,522,544,566,588,610,632,654],24:25]

X_train_PhoenixAll18=df.iloc[[0,17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,391,413,457,479,501,523,545,567,589,611,633,655],[5,11,18,19,20]]
y_train_PhoenixAll18=df.iloc[[17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,391,413,457,479,501,523,545,567,589,611,633,655],24:25]

X_train_PhoenixAll19=df.iloc[[0,18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,392,414,458,480,502,524,546,568,590,612,634,656],[5,11,18,19,20]]
y_train_PhoenixAll19=df.iloc[[18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,392,414,458,480,502,524,546,568,590,612,634,656],24:25]

X_train_PhoenixAll20=df.iloc[[0,19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,393,415,459,481,503,525,547,569,591,613,635,657],[5,11,18,19,20]]
y_train_PhoenixAll20=df.iloc[[19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,393,415,459,481,503,525,547,569,591,613,635,657],24:25]

X_train_PhoenixAll21=df.iloc[[0,20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,394,416,460,482,504,526,548,570,592,614,636,658],[5,11,18,19,20]]
y_train_PhoenixAll21=df.iloc[[20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,394,416,460,482,504,526,548,570,592,614,636,658],24:25]

X_train_PhoenixAll22=df.iloc[[0,21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,395,417,461,483,505,527,549,571,593,615,637,659],[5,11,18,19,20]]
y_train_PhoenixAll22=df.iloc[[21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,395,417,461,483,505,527,549,571,593,615,637,659],24:25]

# %%
regressorPhoenix1 = LinearRegression()
regressorPhoenix1.fit(X_train_PhoenixAll1, y_train_PhoenixAll1)
pd.DataFrame(list(zip(X_train_PhoenixAll1, regressorPhoenix1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_Phoenix1 = regressorPhoenix1.predict(X_train_Phoenix1)

# %%
y_train_PhoenixAll2.loc[-1] = y_pred_Phoenix1.item(0)  # adding a row
y_train_PhoenixAll2.index = y_train_PhoenixAll2.index + 1  # shifting index
y_train_PhoenixAll2 = y_train_PhoenixAll2.sort_index()
regressorPhoenix2 = LinearRegression()
regressorPhoenix2.fit(X_train_PhoenixAll2, y_train_PhoenixAll2)

pd.DataFrame(list(zip(X_train_PhoenixAll2, regressorPhoenix2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Phoenix2 = regressorPhoenix2.predict(X_train_Phoenix2)

y_train_PhoenixAll3.loc[-1] = y_pred_Phoenix2.item(0)  # adding a row
y_train_PhoenixAll3.index = y_train_PhoenixAll3.index + 1  # shifting index
y_train_PhoenixAll3 = y_train_PhoenixAll3.sort_index()
regressorPhoenix3 = LinearRegression()
regressorPhoenix3.fit(X_train_PhoenixAll3, y_train_PhoenixAll3)

pd.DataFrame(list(zip(X_train_PhoenixAll3, regressorPhoenix3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Phoenix3 = regressorPhoenix3.predict(X_train_Phoenix3)

y_train_PhoenixAll4.loc[-1] = y_pred_Phoenix3.item(0)  # adding a row
y_train_PhoenixAll4.index = y_train_PhoenixAll4.index + 1  # shifting index
y_train_PhoenixAll4 = y_train_PhoenixAll4.sort_index()
regressorPhoenix4 = LinearRegression()
regressorPhoenix4.fit(X_train_PhoenixAll4, y_train_PhoenixAll4)

pd.DataFrame(list(zip(X_train_PhoenixAll4, regressorPhoenix4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Phoenix4 = regressorPhoenix4.predict(X_train_Phoenix4)

y_train_PhoenixAll5.loc[-1] = y_pred_Phoenix4.item(0)  # adding a row
y_train_PhoenixAll5.index = y_train_PhoenixAll5.index + 1  # shifting index
y_train_PhoenixAll5 = y_train_PhoenixAll5.sort_index()
regressorPhoenix5 = LinearRegression()
regressorPhoenix5.fit(X_train_PhoenixAll5, y_train_PhoenixAll5)

pd.DataFrame(list(zip(X_train_PhoenixAll5, regressorPhoenix5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Phoenix5 = regressorPhoenix5.predict(X_train_Phoenix5)

y_train_PhoenixAll6.loc[-1] = y_pred_Phoenix5.item(0)  # adding a row
y_train_PhoenixAll6.index = y_train_PhoenixAll6.index + 1  # shifting index
y_train_PhoenixAll6 = y_train_PhoenixAll6.sort_index()
regressorPhoenix6 = LinearRegression()
regressorPhoenix6.fit(X_train_PhoenixAll6, y_train_PhoenixAll6)

pd.DataFrame(list(zip(X_train_PhoenixAll6, regressorPhoenix6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Phoenix6 = regressorPhoenix6.predict(X_train_Phoenix6)

y_train_PhoenixAll7.loc[-1] = y_pred_Phoenix6.item(0)  # adding a row
y_train_PhoenixAll7.index = y_train_PhoenixAll7.index + 1  # shifting index
y_train_PhoenixAll7 = y_train_PhoenixAll7.sort_index()
regressorPhoenix7 = LinearRegression()
regressorPhoenix7.fit(X_train_PhoenixAll7, y_train_PhoenixAll7)

pd.DataFrame(list(zip(X_train_PhoenixAll7, regressorPhoenix7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Phoenix7 = regressorPhoenix7.predict(X_train_Phoenix7)

y_train_PhoenixAll8.loc[-1] = y_pred_Phoenix7.item(0)  # adding a row
y_train_PhoenixAll8.index = y_train_PhoenixAll8.index + 1  # shifting index
y_train_PhoenixAll8 = y_train_PhoenixAll8.sort_index()
regressorPhoenix8 = LinearRegression()
regressorPhoenix8.fit(X_train_PhoenixAll8, y_train_PhoenixAll8)

pd.DataFrame(list(zip(X_train_PhoenixAll8, regressorPhoenix8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Phoenix8 = regressorPhoenix8.predict(X_train_Phoenix8)

y_train_PhoenixAll9.loc[-1] = y_pred_Phoenix8.item(0)  # adding a row
y_train_PhoenixAll9.index = y_train_PhoenixAll9.index + 1  # shifting index
y_train_PhoenixAll9 = y_train_PhoenixAll9.sort_index()
regressorPhoenix9 = LinearRegression()
regressorPhoenix9.fit(X_train_PhoenixAll9, y_train_PhoenixAll9)

pd.DataFrame(list(zip(X_train_PhoenixAll9, regressorPhoenix9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Phoenix9 = regressorPhoenix9.predict(X_train_Phoenix9)

y_train_PhoenixAll10.loc[-1] = y_pred_Phoenix9.item(0)  # adding a row
y_train_PhoenixAll10.index = y_train_PhoenixAll10.index + 1  # shifting index
y_train_PhoenixAll10 = y_train_PhoenixAll10.sort_index()
regressorPhoenix10 = LinearRegression()
regressorPhoenix10.fit(X_train_PhoenixAll10, y_train_PhoenixAll10)

pd.DataFrame(list(zip(X_train_PhoenixAll10, regressorPhoenix10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Phoenix10 = regressorPhoenix10.predict(X_train_Phoenix10)

y_train_PhoenixAll11.loc[-1] = y_pred_Phoenix10.item(0)  # adding a row
y_train_PhoenixAll11.index = y_train_PhoenixAll11.index + 1  # shifting index
y_train_PhoenixAll11 = y_train_PhoenixAll11.sort_index()
regressorPhoenix11 = LinearRegression()
regressorPhoenix11.fit(X_train_PhoenixAll11, y_train_PhoenixAll11)

pd.DataFrame(list(zip(X_train_PhoenixAll11, regressorPhoenix11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Phoenix11 = regressorPhoenix11.predict(X_train_Phoenix11)

y_train_PhoenixAll12.loc[-1] = y_pred_Phoenix11.item(0)  # adding a row
y_train_PhoenixAll12.index = y_train_PhoenixAll12.index + 1  # shifting index
y_train_PhoenixAll12 = y_train_PhoenixAll12.sort_index()
regressorPhoenix12 = LinearRegression()
regressorPhoenix12.fit(X_train_PhoenixAll12, y_train_PhoenixAll12)

pd.DataFrame(list(zip(X_train_PhoenixAll12, regressorPhoenix12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Phoenix12 = regressorPhoenix12.predict(X_train_Phoenix12)

y_train_PhoenixAll13.loc[-1] = y_pred_Phoenix12.item(0)  # adding a row
y_train_PhoenixAll13.index = y_train_PhoenixAll13.index + 1  # shifting index
y_train_PhoenixAll13 = y_train_PhoenixAll13.sort_index()
regressorPhoenix13 = LinearRegression()
regressorPhoenix13.fit(X_train_PhoenixAll13, y_train_PhoenixAll13)

pd.DataFrame(list(zip(X_train_PhoenixAll13, regressorPhoenix13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Phoenix13 = regressorPhoenix13.predict(X_train_Phoenix13)

y_train_PhoenixAll14.loc[-1] = y_pred_Phoenix13.item(0)  # adding a row
y_train_PhoenixAll14.index = y_train_PhoenixAll14.index + 1  # shifting index
y_train_PhoenixAll14 = y_train_PhoenixAll14.sort_index()
regressorPhoenix14 = LinearRegression()
regressorPhoenix14.fit(X_train_PhoenixAll14, y_train_PhoenixAll14)

pd.DataFrame(list(zip(X_train_PhoenixAll14, regressorPhoenix14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Phoenix14 = regressorPhoenix14.predict(X_train_Phoenix14)

y_train_PhoenixAll15.loc[-1] = y_pred_Phoenix14.item(0)  # adding a row
y_train_PhoenixAll15.index = y_train_PhoenixAll15.index + 1  # shifting index
y_train_PhoenixAll15 = y_train_PhoenixAll15.sort_index()
regressorPhoenix15 = LinearRegression()
regressorPhoenix15.fit(X_train_PhoenixAll15, y_train_PhoenixAll15)

pd.DataFrame(list(zip(X_train_PhoenixAll15, regressorPhoenix15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Phoenix15 = regressorPhoenix15.predict(X_train_Phoenix15)

y_train_PhoenixAll16.loc[-1] = y_pred_Phoenix15.item(0)  # adding a row
y_train_PhoenixAll16.index = y_train_PhoenixAll16.index + 1  # shifting index
y_train_PhoenixAll16 = y_train_PhoenixAll16.sort_index()
regressorPhoenix16 = LinearRegression()
regressorPhoenix16.fit(X_train_PhoenixAll16, y_train_PhoenixAll16)

pd.DataFrame(list(zip(X_train_PhoenixAll16, regressorPhoenix16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Phoenix16 = regressorPhoenix16.predict(X_train_Phoenix16)

y_train_PhoenixAll17.loc[-1] = y_pred_Phoenix16.item(0)  # adding a row
y_train_PhoenixAll17.index = y_train_PhoenixAll17.index + 1  # shifting index
y_train_PhoenixAll17 = y_train_PhoenixAll17.sort_index()
regressorPhoenix17 = LinearRegression()
regressorPhoenix17.fit(X_train_PhoenixAll17, y_train_PhoenixAll17)

pd.DataFrame(list(zip(X_train_PhoenixAll17, regressorPhoenix17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Phoenix17 = regressorPhoenix17.predict(X_train_Phoenix17)

y_train_PhoenixAll18.loc[-1] = y_pred_Phoenix17.item(0)  # adding a row
y_train_PhoenixAll18.index = y_train_PhoenixAll18.index + 1  # shifting index
y_train_PhoenixAll18 = y_train_PhoenixAll18.sort_index()
regressorPhoenix18 = LinearRegression()
regressorPhoenix18.fit(X_train_PhoenixAll18, y_train_PhoenixAll18)

pd.DataFrame(list(zip(X_train_PhoenixAll18, regressorPhoenix18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Phoenix18 = regressorPhoenix18.predict(X_train_Phoenix18)

y_train_PhoenixAll19.loc[-1] = y_pred_Phoenix18.item(0)  # adding a row
y_train_PhoenixAll19.index = y_train_PhoenixAll19.index + 1  # shifting index
y_train_PhoenixAll19 = y_train_PhoenixAll19.sort_index()
regressorPhoenix19 = LinearRegression()
regressorPhoenix19.fit(X_train_PhoenixAll19, y_train_PhoenixAll19)

pd.DataFrame(list(zip(X_train_PhoenixAll19, regressorPhoenix19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Phoenix19 = regressorPhoenix19.predict(X_train_Phoenix19)

y_train_PhoenixAll20.loc[-1] = y_pred_Phoenix19.item(0)  # adding a row
y_train_PhoenixAll20.index = y_train_PhoenixAll20.index + 1  # shifting index
y_train_PhoenixAll20 = y_train_PhoenixAll20.sort_index()
regressorPhoenix20 = LinearRegression()
regressorPhoenix20.fit(X_train_PhoenixAll20, y_train_PhoenixAll20)

pd.DataFrame(list(zip(X_train_PhoenixAll20, regressorPhoenix20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Phoenix20 = regressorPhoenix20.predict(X_train_Phoenix20)

y_train_PhoenixAll21.loc[-1] = y_pred_Phoenix20.item(0)  # adding a row
y_train_PhoenixAll21.index = y_train_PhoenixAll21.index + 1  # shifting index
y_train_PhoenixAll21 = y_train_PhoenixAll21.sort_index()
regressorPhoenix21 = LinearRegression()
regressorPhoenix21.fit(X_train_PhoenixAll21, y_train_PhoenixAll21)

pd.DataFrame(list(zip(X_train_PhoenixAll21, regressorPhoenix21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Phoenix21 = regressorPhoenix21.predict(X_train_Phoenix21)

# %%
X_train_Miami1=X_Miami[0:1]
y_train_Miami1=y_Miami[0:1]
X_train_Miami2=X_Miami[1:2]
y_train_Miami2=y_Miami[1:2]
X_train_Miami3=X_Miami[2:3]
y_train_Miami3=y_Miami[2:3]
X_train_Miami4=X_Miami[3:4]
y_train_Miami4=y_Miami[3:4]
X_train_Miami5=X_Miami[4:5]
y_train_Miami5=y_Miami[4:5]
y_train_Miami6=y_Miami[5:6]
X_train_Miami7=X_Miami[7:8]
X_train_Miami6=X_Miami[5:6]
y_train_Miami7=y_Miami[7:8]
X_train_Miami8=X_Miami[8:9]
y_train_Miami8=y_Miami[8:9]
X_train_Miami9=X_Miami[9:10]
y_train_Miami9=y_Miami[9:10]
X_train_Miami10=X_Miami[10:11]
y_train_Miami10=y_Miami[10:11]
X_train_Miami11=X_Miami[11:12]
y_train_Miami11=y_Miami[11:12]
X_train_Miami12=X_Miami[12:13]
y_train_Miami12=y_Miami[12:13]
X_train_Miami13=X_Miami[13:14]
y_train_Miami13=y_Miami[13:14]
X_train_Miami14=X_Miami[14:15]
y_train_Miami14=y_Miami[14:15]
X_train_Miami15=X_Miami[15:16]
y_train_Miami15=y_Miami[15:16]
X_train_Miami16=X_Miami[16:17]
y_train_Miami16=y_Miami[16:17]
X_train_Miami17=X_Miami[17:18]
y_train_Miami17=y_Miami[17:18]
X_train_Miami18=X_Miami[18:19]
y_train_Miami18=y_Miami[18:19]
X_train_Miami19=X_Miami[19:20]
y_train_Miami19=y_Miami[19:20]
X_train_Miami20=X_Miami[20:21]
y_train_Miami20=y_Miami[20:21]
X_train_Miami21=X_Miami[21:22]
y_train_Miami21=y_Miami[21:22]
X_train_Miami22=X_Miami[22:23]
y_train_Miami22=y_Miami[22:23]


X_train_MiamiAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,462,484,506,528,550,572,594,616,638],[5,11,18,19,20]]
y_train_MiamiAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,462,484,506,528,550,572,594,616,638],24:25]

X_train_MiamiAll2=df.iloc[[0,1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,375,397,419,463,485,507,529,551,573,595,617,639],[5,11,18,19,20]]
y_train_MiamiAll2=df.iloc[[1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,375,397,419,463,485,507,529,551,573,595,617,639],24:25]

X_train_MiamiAll3=df.iloc[[0,2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,376,398,420,464,486,508,530,552,574,596,618,640],[5,11,18,19,20]]
y_train_MiamiAll3=df.iloc[[2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,376,398,420,464,486,508,530,552,574,596,618,640],24:25]

X_train_MiamiAll4=df.iloc[[0,3,25,47,69,91,113,135,157,179,201,223,245,267,289,311,333,355,377,399,421,465,487,509,531,553,575,597,619,641],[5,11,18,19,20]]
y_train_MiamiAll4=df.iloc[[3,25,47,69,91,113,135,158,179,201,223,245,267,289,311,333,355,377,399,421,465,487,509,531,553,575,597,619,641],24:25]

X_train_MiamiAll5=df.iloc[[0,4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,378,400,422,466,488,510,532,554,576,598,620,642],[5,11,18,19,20]]
y_train_MiamiAll5=df.iloc[[4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,378,400,422,466,488,510,532,554,576,598,620,642],24:25]

X_train_MiamiAll6=df.iloc[[0,5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,379,401,423,467,489,511,533,555,577,599,621,643],[5,11,18,19,20]]
y_train_MiamiAll6=df.iloc[[5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,379,401,423,467,489,511,533,555,577,599,621,643],24:25]

X_train_MiamiAll7=df.iloc[[0,6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,380,402,424,468,490,512,534,556,578,600,622,644],[5,11,18,19,20]]
y_train_MiamiAll7=df.iloc[[6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,380,402,424,468,490,512,534,556,578,600,622,644],24:25]

X_train_MiamiAll8=df.iloc[[0,7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,381,403,425,469,491,513,535,557,579,601,623,645],[5,11,18,19,20]]
y_train_MiamiAll8=df.iloc[[7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,381,403,425,469,491,513,535,557,579,601,623,645],24:25]

X_train_MiamiAll9=df.iloc[[0,8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,382,404,426,470,492,514,536,558,580,602,624,646],[5,11,18,19,20]]
y_train_MiamiAll9=df.iloc[[8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,382,404,426,470,492,514,536,558,580,602,624,646],24:25]

X_train_MiamiAll10=df.iloc[[0,9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,383,405,427,471,493,515,537,559,581,603,625,647],[5,11,18,19,20]]
y_train_MiamiAll10=df.iloc[[9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,383,405,427,471,493,515,537,559,581,603,625,647],24:25]

X_train_MiamiAll11=df.iloc[[0,10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,384,406,428,472,494,516,538,560,582,604,626,648],[5,11,18,19,20]]
y_train_MiamiAll11=df.iloc[[10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,384,406,428,472,494,516,538,560,582,604,626,648],24:25]

X_train_MiamiAll12=df.iloc[[0,11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,385,407,429,473,495,517,539,561,583,605,627,649],[5,11,18,19,20]]
y_train_MiamiAll12=df.iloc[[11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,385,407,429,473,495,517,539,561,583,605,627,649],24:25]

X_train_MiamiAll13=df.iloc[[0,12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,386,408,430,474,496,518,540,562,584,606,628,650],[5,11,18,19,20]]
y_train_MiamiAll13=df.iloc[[12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,386,408,430,474,496,518,540,562,584,606,628,650],24:25]

X_train_MiamiAll14=df.iloc[[0,13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,387,409,431,475,497,519,541,563,585,607,629,651],[5,11,18,19,20]]
y_train_MiamiAll14=df.iloc[[13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,387,409,431,475,497,519,541,563,585,607,629,651],24:25]

X_train_MiamiAll15=df.iloc[[0,14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,388,410,432,476,498,520,542,564,586,608,630,652],[5,11,18,19,20]]
y_train_MiamiAll15=df.iloc[[14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,388,410,432,476,498,520,542,564,586,608,630,652],24:25]

X_train_MiamiAll16=df.iloc[[0,15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,389,411,433,477,499,521,543,565,587,609,631,653],[5,11,18,19,20]]
y_train_MiamiAll16=df.iloc[[15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,389,411,433,477,499,521,543,565,587,609,631,653],24:25]

X_train_MiamiAll17=df.iloc[[0,16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,390,412,434,478,500,522,544,566,588,610,632,654],[5,11,18,19,20]]
y_train_MiamiAll17=df.iloc[[16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,390,412,434,478,500,522,544,566,588,610,632,654],24:25]

X_train_MiamiAll18=df.iloc[[0,17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,391,413,435,479,501,523,545,567,589,611,633,655],[5,11,18,19,20]]
y_train_MiamiAll18=df.iloc[[17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,391,413,435,479,501,523,545,567,589,611,633,655],24:25]

X_train_MiamiAll19=df.iloc[[0,18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,392,414,436,480,502,524,546,568,590,612,634,656],[5,11,18,19,20]]
y_train_MiamiAll19=df.iloc[[18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,392,414,436,480,502,524,546,568,590,612,634,656],24:25]

X_train_MiamiAll20=df.iloc[[0,19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,393,415,437,481,503,525,547,569,591,613,635,657],[5,11,18,19,20]]
y_train_MiamiAll20=df.iloc[[19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,393,415,437,481,503,525,547,569,591,613,635,657],24:25]

X_train_MiamiAll21=df.iloc[[0,20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,394,416,438,482,504,526,548,570,592,614,636,658],[5,11,18,19,20]]
y_train_MiamiAll21=df.iloc[[20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,394,416,438,482,504,526,548,570,592,614,636,658],24:25]

X_train_MiamiAll22=df.iloc[[0,21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,395,417,439,483,505,527,549,571,593,615,637,659],[5,11,18,19,20]]
y_train_MiamiAll22=df.iloc[[21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,395,417,439,483,505,527,549,571,593,615,637,659],24:25]

# %%
regressorMiami1 = LinearRegression()
regressorMiami1.fit(X_train_MiamiAll1, y_train_MiamiAll1)
pd.DataFrame(list(zip(X_train_MiamiAll1, regressorMiami1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_Miami1 = regressorMiami1.predict(X_train_Miami1)

# %%
y_train_MiamiAll2.loc[-1] = y_pred_Miami1.item(0)  # adding a row
y_train_MiamiAll2.index = y_train_MiamiAll2.index + 1  # shifting index
y_train_MiamiAll2 = y_train_MiamiAll2.sort_index()
regressorMiami2 = LinearRegression()
regressorMiami2.fit(X_train_MiamiAll2, y_train_MiamiAll2)

pd.DataFrame(list(zip(X_train_MiamiAll2, regressorMiami2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Miami2 = regressorMiami2.predict(X_train_Miami2)

y_train_MiamiAll3.loc[-1] = y_pred_Miami2.item(0)  # adding a row
y_train_MiamiAll3.index = y_train_MiamiAll3.index + 1  # shifting index
y_train_MiamiAll3 = y_train_MiamiAll3.sort_index()
regressorMiami3 = LinearRegression()
regressorMiami3.fit(X_train_MiamiAll3, y_train_MiamiAll3)

pd.DataFrame(list(zip(X_train_MiamiAll3, regressorMiami3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Miami3 = regressorMiami3.predict(X_train_Miami3)

y_train_MiamiAll4.loc[-1] = y_pred_Miami3.item(0)  # adding a row
y_train_MiamiAll4.index = y_train_MiamiAll4.index + 1  # shifting index
y_train_MiamiAll4 = y_train_MiamiAll4.sort_index()
regressorMiami4 = LinearRegression()
regressorMiami4.fit(X_train_MiamiAll4, y_train_MiamiAll4)

pd.DataFrame(list(zip(X_train_MiamiAll4, regressorMiami4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Miami4 = regressorMiami4.predict(X_train_Miami4)

y_train_MiamiAll5.loc[-1] = y_pred_Miami4.item(0)  # adding a row
y_train_MiamiAll5.index = y_train_MiamiAll5.index + 1  # shifting index
y_train_MiamiAll5 = y_train_MiamiAll5.sort_index()
regressorMiami5 = LinearRegression()
regressorMiami5.fit(X_train_MiamiAll5, y_train_MiamiAll5)

pd.DataFrame(list(zip(X_train_MiamiAll5, regressorMiami5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Miami5 = regressorMiami5.predict(X_train_Miami5)

y_train_MiamiAll6.loc[-1] = y_pred_Miami5.item(0)  # adding a row
y_train_MiamiAll6.index = y_train_MiamiAll6.index + 1  # shifting index
y_train_MiamiAll6 = y_train_MiamiAll6.sort_index()
regressorMiami6 = LinearRegression()
regressorMiami6.fit(X_train_MiamiAll6, y_train_MiamiAll6)

pd.DataFrame(list(zip(X_train_MiamiAll6, regressorMiami6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Miami6 = regressorMiami6.predict(X_train_Miami6)

y_train_MiamiAll7.loc[-1] = y_pred_Miami6.item(0)  # adding a row
y_train_MiamiAll7.index = y_train_MiamiAll7.index + 1  # shifting index
y_train_MiamiAll7 = y_train_MiamiAll7.sort_index()
regressorMiami7 = LinearRegression()
regressorMiami7.fit(X_train_MiamiAll7, y_train_MiamiAll7)

pd.DataFrame(list(zip(X_train_MiamiAll7, regressorMiami7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Miami7 = regressorMiami7.predict(X_train_Miami7)

y_train_MiamiAll8.loc[-1] = y_pred_Miami7.item(0)  # adding a row
y_train_MiamiAll8.index = y_train_MiamiAll8.index + 1  # shifting index
y_train_MiamiAll8 = y_train_MiamiAll8.sort_index()
regressorMiami8 = LinearRegression()
regressorMiami8.fit(X_train_MiamiAll8, y_train_MiamiAll8)

pd.DataFrame(list(zip(X_train_MiamiAll8, regressorMiami8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Miami8 = regressorMiami8.predict(X_train_Miami8)

y_train_MiamiAll9.loc[-1] = y_pred_Miami8.item(0)  # adding a row
y_train_MiamiAll9.index = y_train_MiamiAll9.index + 1  # shifting index
y_train_MiamiAll9 = y_train_MiamiAll9.sort_index()
regressorMiami9 = LinearRegression()
regressorMiami9.fit(X_train_MiamiAll9, y_train_MiamiAll9)

pd.DataFrame(list(zip(X_train_MiamiAll9, regressorMiami9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Miami9 = regressorMiami9.predict(X_train_Miami9)

y_train_MiamiAll10.loc[-1] = y_pred_Miami9.item(0)  # adding a row
y_train_MiamiAll10.index = y_train_MiamiAll10.index + 1  # shifting index
y_train_MiamiAll10 = y_train_MiamiAll10.sort_index()
regressorMiami10 = LinearRegression()
regressorMiami10.fit(X_train_MiamiAll10, y_train_MiamiAll10)

pd.DataFrame(list(zip(X_train_MiamiAll10, regressorMiami10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Miami10 = regressorMiami10.predict(X_train_Miami10)

y_train_MiamiAll11.loc[-1] = y_pred_Miami10.item(0)  # adding a row
y_train_MiamiAll11.index = y_train_MiamiAll11.index + 1  # shifting index
y_train_MiamiAll11 = y_train_MiamiAll11.sort_index()
regressorMiami11 = LinearRegression()
regressorMiami11.fit(X_train_MiamiAll11, y_train_MiamiAll11)

pd.DataFrame(list(zip(X_train_MiamiAll11, regressorMiami11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Miami11 = regressorMiami11.predict(X_train_Miami11)

y_train_MiamiAll12.loc[-1] = y_pred_Miami11.item(0)  # adding a row
y_train_MiamiAll12.index = y_train_MiamiAll12.index + 1  # shifting index
y_train_MiamiAll12 = y_train_MiamiAll12.sort_index()
regressorMiami12 = LinearRegression()
regressorMiami12.fit(X_train_MiamiAll12, y_train_MiamiAll12)

pd.DataFrame(list(zip(X_train_MiamiAll12, regressorMiami12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Miami12 = regressorMiami12.predict(X_train_Miami12)

y_train_MiamiAll13.loc[-1] = y_pred_Miami12.item(0)  # adding a row
y_train_MiamiAll13.index = y_train_MiamiAll13.index + 1  # shifting index
y_train_MiamiAll13 = y_train_MiamiAll13.sort_index()
regressorMiami13 = LinearRegression()
regressorMiami13.fit(X_train_MiamiAll13, y_train_MiamiAll13)

pd.DataFrame(list(zip(X_train_MiamiAll13, regressorMiami13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Miami13 = regressorMiami13.predict(X_train_Miami13)

y_train_MiamiAll14.loc[-1] = y_pred_Miami13.item(0)  # adding a row
y_train_MiamiAll14.index = y_train_MiamiAll14.index + 1  # shifting index
y_train_MiamiAll14 = y_train_MiamiAll14.sort_index()
regressorMiami14 = LinearRegression()
regressorMiami14.fit(X_train_MiamiAll14, y_train_MiamiAll14)

pd.DataFrame(list(zip(X_train_MiamiAll14, regressorMiami14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Miami14 = regressorMiami14.predict(X_train_Miami14)

y_train_MiamiAll15.loc[-1] = y_pred_Miami14.item(0)  # adding a row
y_train_MiamiAll15.index = y_train_MiamiAll15.index + 1  # shifting index
y_train_MiamiAll15 = y_train_MiamiAll15.sort_index()
regressorMiami15 = LinearRegression()
regressorMiami15.fit(X_train_MiamiAll15, y_train_MiamiAll15)

pd.DataFrame(list(zip(X_train_MiamiAll15, regressorMiami15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Miami15 = regressorMiami15.predict(X_train_Miami15)

y_train_MiamiAll16.loc[-1] = y_pred_Miami15.item(0)  # adding a row
y_train_MiamiAll16.index = y_train_MiamiAll16.index + 1  # shifting index
y_train_MiamiAll16 = y_train_MiamiAll16.sort_index()
regressorMiami16 = LinearRegression()
regressorMiami16.fit(X_train_MiamiAll16, y_train_MiamiAll16)

pd.DataFrame(list(zip(X_train_MiamiAll16, regressorMiami16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Miami16 = regressorMiami16.predict(X_train_Miami16)

y_train_MiamiAll17.loc[-1] = y_pred_Miami16.item(0)  # adding a row
y_train_MiamiAll17.index = y_train_MiamiAll17.index + 1  # shifting index
y_train_MiamiAll17 = y_train_MiamiAll17.sort_index()
regressorMiami17 = LinearRegression()
regressorMiami17.fit(X_train_MiamiAll17, y_train_MiamiAll17)

pd.DataFrame(list(zip(X_train_MiamiAll17, regressorMiami17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Miami17 = regressorMiami17.predict(X_train_Miami17)

y_train_MiamiAll18.loc[-1] = y_pred_Miami17.item(0)  # adding a row
y_train_MiamiAll18.index = y_train_MiamiAll18.index + 1  # shifting index
y_train_MiamiAll18 = y_train_MiamiAll18.sort_index()
regressorMiami18 = LinearRegression()
regressorMiami18.fit(X_train_MiamiAll18, y_train_MiamiAll18)

pd.DataFrame(list(zip(X_train_MiamiAll18, regressorMiami18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Miami18 = regressorMiami18.predict(X_train_Miami18)

y_train_MiamiAll19.loc[-1] = y_pred_Miami18.item(0)  # adding a row
y_train_MiamiAll19.index = y_train_MiamiAll19.index + 1  # shifting index
y_train_MiamiAll19 = y_train_MiamiAll19.sort_index()
regressorMiami19 = LinearRegression()
regressorMiami19.fit(X_train_MiamiAll19, y_train_MiamiAll19)

pd.DataFrame(list(zip(X_train_MiamiAll19, regressorMiami19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Miami19 = regressorMiami19.predict(X_train_Miami19)

y_train_MiamiAll20.loc[-1] = y_pred_Miami19.item(0)  # adding a row
y_train_MiamiAll20.index = y_train_MiamiAll20.index + 1  # shifting index
y_train_MiamiAll20 = y_train_MiamiAll20.sort_index()
regressorMiami20 = LinearRegression()
regressorMiami20.fit(X_train_MiamiAll20, y_train_MiamiAll20)

pd.DataFrame(list(zip(X_train_MiamiAll20, regressorMiami20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Miami20 = regressorMiami20.predict(X_train_Miami20)

y_train_MiamiAll21.loc[-1] = y_pred_Miami20.item(0)  # adding a row
y_train_MiamiAll21.index = y_train_MiamiAll21.index + 1  # shifting index
y_train_MiamiAll21 = y_train_MiamiAll21.sort_index()
regressorMiami21 = LinearRegression()
regressorMiami21.fit(X_train_MiamiAll21, y_train_MiamiAll21)

pd.DataFrame(list(zip(X_train_MiamiAll21, regressorMiami21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Miami21 = regressorMiami21.predict(X_train_Miami21)

# %%
X_train_Milwaukee1=X_Milwaukee[0:1]
y_train_Milwaukee1=y_Milwaukee[0:1]
X_train_Milwaukee2=X_Milwaukee[1:2]
y_train_Milwaukee2=y_Milwaukee[1:2]
X_train_Milwaukee3=X_Milwaukee[2:3]
y_train_Milwaukee3=y_Milwaukee[2:3]
X_train_Milwaukee4=X_Milwaukee[3:4]
y_train_Milwaukee4=y_Milwaukee[3:4]
X_train_Milwaukee5=X_Milwaukee[4:5]
y_train_Milwaukee5=y_Milwaukee[4:5]
y_train_Milwaukee6=y_Milwaukee[5:6]
X_train_Milwaukee7=X_Milwaukee[7:8]
X_train_Milwaukee6=X_Milwaukee[5:6]
y_train_Milwaukee7=y_Milwaukee[7:8]
X_train_Milwaukee8=X_Milwaukee[8:9]
y_train_Milwaukee8=y_Milwaukee[8:9]
X_train_Milwaukee9=X_Milwaukee[9:10]
y_train_Milwaukee9=y_Milwaukee[9:10]
X_train_Milwaukee10=X_Milwaukee[10:11]
y_train_Milwaukee10=y_Milwaukee[10:11]
X_train_Milwaukee11=X_Milwaukee[11:12]
y_train_Milwaukee11=y_Milwaukee[11:12]
X_train_Milwaukee12=X_Milwaukee[12:13]
y_train_Milwaukee12=y_Milwaukee[12:13]
X_train_Milwaukee13=X_Milwaukee[13:14]
y_train_Milwaukee13=y_Milwaukee[13:14]
X_train_Milwaukee14=X_Milwaukee[14:15]
y_train_Milwaukee14=y_Milwaukee[14:15]
X_train_Milwaukee15=X_Milwaukee[15:16]
y_train_Milwaukee15=y_Milwaukee[15:16]
X_train_Milwaukee16=X_Milwaukee[16:17]
y_train_Milwaukee16=y_Milwaukee[16:17]
X_train_Milwaukee17=X_Milwaukee[17:18]
y_train_Milwaukee17=y_Milwaukee[17:18]
X_train_Milwaukee18=X_Milwaukee[18:19]
y_train_Milwaukee18=y_Milwaukee[18:19]
X_train_Milwaukee19=X_Milwaukee[19:20]
y_train_Milwaukee19=y_Milwaukee[19:20]
X_train_Milwaukee20=X_Milwaukee[20:21]
y_train_Milwaukee20=y_Milwaukee[20:21]
X_train_Milwaukee21=X_Milwaukee[21:22]
y_train_Milwaukee21=y_Milwaukee[21:22]
X_train_Milwaukee22=X_Milwaukee[22:23]
y_train_Milwaukee22=y_Milwaukee[22:23]


X_train_MilwaukeeAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,484,506,528,550,572,594,616,638],[5,11,18,19,20]]
y_train_MilwaukeeAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,484,506,528,550,572,594,616,638],24:25]

X_train_MilwaukeeAll2=df.iloc[[0,1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,375,397,419,441,485,507,529,551,573,595,617,639],[5,11,18,19,20]]
y_train_MilwaukeeAll2=df.iloc[[1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,375,397,419,441,485,507,529,551,573,595,617,639],24:25]

X_train_MilwaukeeAll3=df.iloc[[0,2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,376,398,420,442,486,508,530,552,574,596,618,640],[5,11,18,19,20]]
y_train_MilwaukeeAll3=df.iloc[[2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,376,398,420,442,486,508,530,552,574,596,618,640],24:25]

X_train_MilwaukeeAll4=df.iloc[[0,3,25,47,69,91,113,135,157,179,201,223,245,267,289,311,333,355,377,399,421,443,487,509,531,553,575,597,619,641],[5,11,18,19,20]]
y_train_MilwaukeeAll4=df.iloc[[3,25,47,69,91,113,135,158,179,201,223,245,267,289,311,333,355,377,399,421,443,487,509,531,553,575,597,619,641],24:25]

X_train_MilwaukeeAll5=df.iloc[[0,4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,378,400,422,444,488,510,532,554,576,598,620,642],[5,11,18,19,20]]
y_train_MilwaukeeAll5=df.iloc[[4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,378,400,422,444,488,510,532,554,576,598,620,642],24:25]

X_train_MilwaukeeAll6=df.iloc[[0,5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,379,401,423,445,489,511,533,555,577,599,621,643],[5,11,18,19,20]]
y_train_MilwaukeeAll6=df.iloc[[5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,379,401,423,445,489,511,533,555,577,599,621,643],24:25]

X_train_MilwaukeeAll7=df.iloc[[0,6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,380,402,424,446,490,512,534,556,578,600,622,644],[5,11,18,19,20]]
y_train_MilwaukeeAll7=df.iloc[[6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,380,402,424,446,490,512,534,556,578,600,622,644],24:25]

X_train_MilwaukeeAll8=df.iloc[[0,7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,381,403,425,447,491,513,535,557,579,601,623,645],[5,11,18,19,20]]
y_train_MilwaukeeAll8=df.iloc[[7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,381,403,425,447,491,513,535,557,579,601,623,645],24:25]

X_train_MilwaukeeAll9=df.iloc[[0,8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,382,404,426,448,492,514,536,558,580,602,624,646],[5,11,18,19,20]]
y_train_MilwaukeeAll9=df.iloc[[8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,382,404,426,448,492,514,536,558,580,602,624,646],24:25]

X_train_MilwaukeeAll10=df.iloc[[0,9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,383,405,427,449,493,515,537,559,581,603,625,647],[5,11,18,19,20]]
y_train_MilwaukeeAll10=df.iloc[[9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,383,405,427,449,493,515,537,559,581,603,625,647],24:25]

X_train_MilwaukeeAll11=df.iloc[[0,10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,384,406,428,450,494,516,538,560,582,604,626,648],[5,11,18,19,20]]
y_train_MilwaukeeAll11=df.iloc[[10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,384,406,428,450,494,516,538,560,582,604,626,648],24:25]

X_train_MilwaukeeAll12=df.iloc[[0,11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,385,407,429,451,495,517,539,561,583,605,627,649],[5,11,18,19,20]]
y_train_MilwaukeeAll12=df.iloc[[11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,385,407,429,451,495,517,539,561,583,605,627,649],24:25]

X_train_MilwaukeeAll13=df.iloc[[0,12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,386,408,430,452,496,518,540,562,584,606,628,650],[5,11,18,19,20]]
y_train_MilwaukeeAll13=df.iloc[[12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,386,408,430,452,496,518,540,562,584,606,628,650],24:25]

X_train_MilwaukeeAll14=df.iloc[[0,13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,387,409,431,453,497,519,541,563,585,607,629,651],[5,11,18,19,20]]
y_train_MilwaukeeAll14=df.iloc[[13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,387,409,431,453,497,519,541,563,585,607,629,651],24:25]

X_train_MilwaukeeAll15=df.iloc[[0,14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,388,410,432,454,498,520,542,564,586,608,630,652],[5,11,18,19,20]]
y_train_MilwaukeeAll15=df.iloc[[14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,388,410,432,454,498,520,542,564,586,608,630,652],24:25]

X_train_MilwaukeeAll16=df.iloc[[0,15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,389,411,433,455,499,521,543,565,587,609,631,653],[5,11,18,19,20]]
y_train_MilwaukeeAll16=df.iloc[[15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,389,411,433,455,499,521,543,565,587,609,631,653],24:25]

X_train_MilwaukeeAll17=df.iloc[[0,16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,390,412,434,456,500,522,544,566,588,610,632,654],[5,11,18,19,20]]
y_train_MilwaukeeAll17=df.iloc[[16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,390,412,434,456,500,522,544,566,588,610,632,654],24:25]

X_train_MilwaukeeAll18=df.iloc[[0,17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,391,413,435,457,501,523,545,567,589,611,633,655],[5,11,18,19,20]]
y_train_MilwaukeeAll18=df.iloc[[17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,391,413,435,457,501,523,545,567,589,611,633,655],24:25]

X_train_MilwaukeeAll19=df.iloc[[0,18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,392,414,436,458,502,524,546,568,590,612,634,656],[5,11,18,19,20]]
y_train_MilwaukeeAll19=df.iloc[[18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,392,414,436,458,502,524,546,568,590,612,634,656],24:25]

X_train_MilwaukeeAll20=df.iloc[[0,19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,393,415,437,459,503,525,547,569,591,613,635,657],[5,11,18,19,20]]
y_train_MilwaukeeAll20=df.iloc[[19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,393,415,437,459,503,525,547,569,591,613,635,657],24:25]

X_train_MilwaukeeAll21=df.iloc[[0,20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,394,416,438,460,504,526,548,570,592,614,636,658],[5,11,18,19,20]]
y_train_MilwaukeeAll21=df.iloc[[20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,394,416,438,460,504,526,548,570,592,614,636,658],24:25]

X_train_MilwaukeeAll22=df.iloc[[0,21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,395,417,439,461,505,527,549,571,593,615,637,659],[5,11,18,19,20]]
y_train_MilwaukeeAll22=df.iloc[[21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,395,417,439,461,505,527,549,571,593,615,637,659],24:25]

# %%
regressorMilwaukee1 = LinearRegression()
regressorMilwaukee1.fit(X_train_MilwaukeeAll1, y_train_MilwaukeeAll1)
pd.DataFrame(list(zip(X_train_MilwaukeeAll1, regressorMilwaukee1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_Milwaukee1 = regressorMilwaukee1.predict(X_train_Milwaukee1)

# %%
y_train_MilwaukeeAll2.loc[-1] = y_pred_Milwaukee1.item(0)  # adding a row
y_train_MilwaukeeAll2.index = y_train_MilwaukeeAll2.index + 1  # shifting index
y_train_MilwaukeeAll2 = y_train_MilwaukeeAll2.sort_index()
regressorMilwaukee2 = LinearRegression()
regressorMilwaukee2.fit(X_train_MilwaukeeAll2, y_train_MilwaukeeAll2)

pd.DataFrame(list(zip(X_train_MilwaukeeAll2, regressorMilwaukee2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Milwaukee2 = regressorMilwaukee2.predict(X_train_Milwaukee2)

y_train_MilwaukeeAll3.loc[-1] = y_pred_Milwaukee2.item(0)  # adding a row
y_train_MilwaukeeAll3.index = y_train_MilwaukeeAll3.index + 1  # shifting index
y_train_MilwaukeeAll3 = y_train_MilwaukeeAll3.sort_index()
regressorMilwaukee3 = LinearRegression()
regressorMilwaukee3.fit(X_train_MilwaukeeAll3, y_train_MilwaukeeAll3)

pd.DataFrame(list(zip(X_train_MilwaukeeAll3, regressorMilwaukee3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Milwaukee3 = regressorMilwaukee3.predict(X_train_Milwaukee3)

y_train_MilwaukeeAll4.loc[-1] = y_pred_Milwaukee3.item(0)  # adding a row
y_train_MilwaukeeAll4.index = y_train_MilwaukeeAll4.index + 1  # shifting index
y_train_MilwaukeeAll4 = y_train_MilwaukeeAll4.sort_index()
regressorMilwaukee4 = LinearRegression()
regressorMilwaukee4.fit(X_train_MilwaukeeAll4, y_train_MilwaukeeAll4)

pd.DataFrame(list(zip(X_train_MilwaukeeAll4, regressorMilwaukee4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Milwaukee4 = regressorMilwaukee4.predict(X_train_Milwaukee4)

y_train_MilwaukeeAll5.loc[-1] = y_pred_Milwaukee4.item(0)  # adding a row
y_train_MilwaukeeAll5.index = y_train_MilwaukeeAll5.index + 1  # shifting index
y_train_MilwaukeeAll5 = y_train_MilwaukeeAll5.sort_index()
regressorMilwaukee5 = LinearRegression()
regressorMilwaukee5.fit(X_train_MilwaukeeAll5, y_train_MilwaukeeAll5)

pd.DataFrame(list(zip(X_train_MilwaukeeAll5, regressorMilwaukee5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Milwaukee5 = regressorMilwaukee5.predict(X_train_Milwaukee5)

y_train_MilwaukeeAll6.loc[-1] = y_pred_Milwaukee5.item(0)  # adding a row
y_train_MilwaukeeAll6.index = y_train_MilwaukeeAll6.index + 1  # shifting index
y_train_MilwaukeeAll6 = y_train_MilwaukeeAll6.sort_index()
regressorMilwaukee6 = LinearRegression()
regressorMilwaukee6.fit(X_train_MilwaukeeAll6, y_train_MilwaukeeAll6)

pd.DataFrame(list(zip(X_train_MilwaukeeAll6, regressorMilwaukee6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Milwaukee6 = regressorMilwaukee6.predict(X_train_Milwaukee6)

y_train_MilwaukeeAll7.loc[-1] = y_pred_Milwaukee6.item(0)  # adding a row
y_train_MilwaukeeAll7.index = y_train_MilwaukeeAll7.index + 1  # shifting index
y_train_MilwaukeeAll7 = y_train_MilwaukeeAll7.sort_index()
regressorMilwaukee7 = LinearRegression()
regressorMilwaukee7.fit(X_train_MilwaukeeAll7, y_train_MilwaukeeAll7)

pd.DataFrame(list(zip(X_train_MilwaukeeAll7, regressorMilwaukee7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Milwaukee7 = regressorMilwaukee7.predict(X_train_Milwaukee7)

y_train_MilwaukeeAll8.loc[-1] = y_pred_Milwaukee7.item(0)  # adding a row
y_train_MilwaukeeAll8.index = y_train_MilwaukeeAll8.index + 1  # shifting index
y_train_MilwaukeeAll8 = y_train_MilwaukeeAll8.sort_index()
regressorMilwaukee8 = LinearRegression()
regressorMilwaukee8.fit(X_train_MilwaukeeAll8, y_train_MilwaukeeAll8)

pd.DataFrame(list(zip(X_train_MilwaukeeAll8, regressorMilwaukee8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Milwaukee8 = regressorMilwaukee8.predict(X_train_Milwaukee8)

y_train_MilwaukeeAll9.loc[-1] = y_pred_Milwaukee8.item(0)  # adding a row
y_train_MilwaukeeAll9.index = y_train_MilwaukeeAll9.index + 1  # shifting index
y_train_MilwaukeeAll9 = y_train_MilwaukeeAll9.sort_index()
regressorMilwaukee9 = LinearRegression()
regressorMilwaukee9.fit(X_train_MilwaukeeAll9, y_train_MilwaukeeAll9)

pd.DataFrame(list(zip(X_train_MilwaukeeAll9, regressorMilwaukee9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Milwaukee9 = regressorMilwaukee9.predict(X_train_Milwaukee9)

y_train_MilwaukeeAll10.loc[-1] = y_pred_Milwaukee9.item(0)  # adding a row
y_train_MilwaukeeAll10.index = y_train_MilwaukeeAll10.index + 1  # shifting index
y_train_MilwaukeeAll10 = y_train_MilwaukeeAll10.sort_index()
regressorMilwaukee10 = LinearRegression()
regressorMilwaukee10.fit(X_train_MilwaukeeAll10, y_train_MilwaukeeAll10)

pd.DataFrame(list(zip(X_train_MilwaukeeAll10, regressorMilwaukee10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Milwaukee10 = regressorMilwaukee10.predict(X_train_Milwaukee10)

y_train_MilwaukeeAll11.loc[-1] = y_pred_Milwaukee10.item(0)  # adding a row
y_train_MilwaukeeAll11.index = y_train_MilwaukeeAll11.index + 1  # shifting index
y_train_MilwaukeeAll11 = y_train_MilwaukeeAll11.sort_index()
regressorMilwaukee11 = LinearRegression()
regressorMilwaukee11.fit(X_train_MilwaukeeAll11, y_train_MilwaukeeAll11)

pd.DataFrame(list(zip(X_train_MilwaukeeAll11, regressorMilwaukee11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Milwaukee11 = regressorMilwaukee11.predict(X_train_Milwaukee11)

y_train_MilwaukeeAll12.loc[-1] = y_pred_Milwaukee11.item(0)  # adding a row
y_train_MilwaukeeAll12.index = y_train_MilwaukeeAll12.index + 1  # shifting index
y_train_MilwaukeeAll12 = y_train_MilwaukeeAll12.sort_index()
regressorMilwaukee12 = LinearRegression()
regressorMilwaukee12.fit(X_train_MilwaukeeAll12, y_train_MilwaukeeAll12)

pd.DataFrame(list(zip(X_train_MilwaukeeAll12, regressorMilwaukee12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Milwaukee12 = regressorMilwaukee12.predict(X_train_Milwaukee12)

y_train_MilwaukeeAll13.loc[-1] = y_pred_Milwaukee12.item(0)  # adding a row
y_train_MilwaukeeAll13.index = y_train_MilwaukeeAll13.index + 1  # shifting index
y_train_MilwaukeeAll13 = y_train_MilwaukeeAll13.sort_index()
regressorMilwaukee13 = LinearRegression()
regressorMilwaukee13.fit(X_train_MilwaukeeAll13, y_train_MilwaukeeAll13)

pd.DataFrame(list(zip(X_train_MilwaukeeAll13, regressorMilwaukee13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Milwaukee13 = regressorMilwaukee13.predict(X_train_Milwaukee13)

y_train_MilwaukeeAll14.loc[-1] = y_pred_Milwaukee13.item(0)  # adding a row
y_train_MilwaukeeAll14.index = y_train_MilwaukeeAll14.index + 1  # shifting index
y_train_MilwaukeeAll14 = y_train_MilwaukeeAll14.sort_index()
regressorMilwaukee14 = LinearRegression()
regressorMilwaukee14.fit(X_train_MilwaukeeAll14, y_train_MilwaukeeAll14)

pd.DataFrame(list(zip(X_train_MilwaukeeAll14, regressorMilwaukee14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Milwaukee14 = regressorMilwaukee14.predict(X_train_Milwaukee14)

y_train_MilwaukeeAll15.loc[-1] = y_pred_Milwaukee14.item(0)  # adding a row
y_train_MilwaukeeAll15.index = y_train_MilwaukeeAll15.index + 1  # shifting index
y_train_MilwaukeeAll15 = y_train_MilwaukeeAll15.sort_index()
regressorMilwaukee15 = LinearRegression()
regressorMilwaukee15.fit(X_train_MilwaukeeAll15, y_train_MilwaukeeAll15)

pd.DataFrame(list(zip(X_train_MilwaukeeAll15, regressorMilwaukee15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Milwaukee15 = regressorMilwaukee15.predict(X_train_Milwaukee15)

y_train_MilwaukeeAll16.loc[-1] = y_pred_Milwaukee15.item(0)  # adding a row
y_train_MilwaukeeAll16.index = y_train_MilwaukeeAll16.index + 1  # shifting index
y_train_MilwaukeeAll16 = y_train_MilwaukeeAll16.sort_index()
regressorMilwaukee16 = LinearRegression()
regressorMilwaukee16.fit(X_train_MilwaukeeAll16, y_train_MilwaukeeAll16)

pd.DataFrame(list(zip(X_train_MilwaukeeAll16, regressorMilwaukee16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Milwaukee16 = regressorMilwaukee16.predict(X_train_Milwaukee16)

y_train_MilwaukeeAll17.loc[-1] = y_pred_Milwaukee16.item(0)  # adding a row
y_train_MilwaukeeAll17.index = y_train_MilwaukeeAll17.index + 1  # shifting index
y_train_MilwaukeeAll17 = y_train_MilwaukeeAll17.sort_index()
regressorMilwaukee17 = LinearRegression()
regressorMilwaukee17.fit(X_train_MilwaukeeAll17, y_train_MilwaukeeAll17)

pd.DataFrame(list(zip(X_train_MilwaukeeAll17, regressorMilwaukee17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Milwaukee17 = regressorMilwaukee17.predict(X_train_Milwaukee17)

y_train_MilwaukeeAll18.loc[-1] = y_pred_Milwaukee17.item(0)  # adding a row
y_train_MilwaukeeAll18.index = y_train_MilwaukeeAll18.index + 1  # shifting index
y_train_MilwaukeeAll18 = y_train_MilwaukeeAll18.sort_index()
regressorMilwaukee18 = LinearRegression()
regressorMilwaukee18.fit(X_train_MilwaukeeAll18, y_train_MilwaukeeAll18)

pd.DataFrame(list(zip(X_train_MilwaukeeAll18, regressorMilwaukee18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Milwaukee18 = regressorMilwaukee18.predict(X_train_Milwaukee18)

y_train_MilwaukeeAll19.loc[-1] = y_pred_Milwaukee18.item(0)  # adding a row
y_train_MilwaukeeAll19.index = y_train_MilwaukeeAll19.index + 1  # shifting index
y_train_MilwaukeeAll19 = y_train_MilwaukeeAll19.sort_index()
regressorMilwaukee19 = LinearRegression()
regressorMilwaukee19.fit(X_train_MilwaukeeAll19, y_train_MilwaukeeAll19)

pd.DataFrame(list(zip(X_train_MilwaukeeAll19, regressorMilwaukee19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Milwaukee19 = regressorMilwaukee19.predict(X_train_Milwaukee19)

y_train_MilwaukeeAll20.loc[-1] = y_pred_Milwaukee19.item(0)  # adding a row
y_train_MilwaukeeAll20.index = y_train_MilwaukeeAll20.index + 1  # shifting index
y_train_MilwaukeeAll20 = y_train_MilwaukeeAll20.sort_index()
regressorMilwaukee20 = LinearRegression()
regressorMilwaukee20.fit(X_train_MilwaukeeAll20, y_train_MilwaukeeAll20)

pd.DataFrame(list(zip(X_train_MilwaukeeAll20, regressorMilwaukee20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Milwaukee20 = regressorMilwaukee20.predict(X_train_Milwaukee20)

y_train_MilwaukeeAll21.loc[-1] = y_pred_Milwaukee20.item(0)  # adding a row
y_train_MilwaukeeAll21.index = y_train_MilwaukeeAll21.index + 1  # shifting index
y_train_MilwaukeeAll21 = y_train_MilwaukeeAll21.sort_index()
regressorMilwaukee21 = LinearRegression()
regressorMilwaukee21.fit(X_train_MilwaukeeAll21, y_train_MilwaukeeAll21)

pd.DataFrame(list(zip(X_train_MilwaukeeAll21, regressorMilwaukee21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Milwaukee21 = regressorMilwaukee21.predict(X_train_Milwaukee21)

# %%
X_train_Washington1=X_Washington[0:1]
y_train_Washington1=y_Washington[0:1]
X_train_Washington2=X_Washington[1:2]
y_train_Washington2=y_Washington[1:2]
X_train_Washington3=X_Washington[2:3]
y_train_Washington3=y_Washington[2:3]
X_train_Washington4=X_Washington[3:4]
y_train_Washington4=y_Washington[3:4]
X_train_Washington5=X_Washington[4:5]
y_train_Washington5=y_Washington[4:5]
y_train_Washington6=y_Washington[5:6]
X_train_Washington7=X_Washington[7:8]
X_train_Washington6=X_Washington[5:6]
y_train_Washington7=y_Washington[7:8]
X_train_Washington8=X_Washington[8:9]
y_train_Washington8=y_Washington[8:9]
X_train_Washington9=X_Washington[9:10]
y_train_Washington9=y_Washington[9:10]
X_train_Washington10=X_Washington[10:11]
y_train_Washington10=y_Washington[10:11]
X_train_Washington11=X_Washington[11:12]
y_train_Washington11=y_Washington[11:12]
X_train_Washington12=X_Washington[12:13]
y_train_Washington12=y_Washington[12:13]
X_train_Washington13=X_Washington[13:14]
y_train_Washington13=y_Washington[13:14]
X_train_Washington14=X_Washington[14:15]
y_train_Washington14=y_Washington[14:15]
X_train_Washington15=X_Washington[15:16]
y_train_Washington15=y_Washington[15:16]
X_train_Washington16=X_Washington[16:17]
y_train_Washington16=y_Washington[16:17]
X_train_Washington17=X_Washington[17:18]
y_train_Washington17=y_Washington[17:18]
X_train_Washington18=X_Washington[18:19]
y_train_Washington18=y_Washington[18:19]
X_train_Washington19=X_Washington[19:20]
y_train_Washington19=y_Washington[19:20]
X_train_Washington20=X_Washington[20:21]
y_train_Washington20=y_Washington[20:21]
X_train_Washington21=X_Washington[21:22]
y_train_Washington21=y_Washington[21:22]
X_train_Washington22=X_Washington[22:23]
y_train_Washington22=y_Washington[22:23]


X_train_WashingtonAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,506,528,550,572,594,616,638],[5,11,18,19,20]]
y_train_WashingtonAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,506,528,550,572,594,616,638],24:25]

X_train_WashingtonAll2=df.iloc[[0,1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,375,397,419,441,463,507,529,551,573,595,617,639],[5,11,18,19,20]]
y_train_WashingtonAll2=df.iloc[[1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,375,397,419,441,463,507,529,551,573,595,617,639],24:25]

X_train_WashingtonAll3=df.iloc[[0,2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,376,398,420,442,464,508,530,552,574,596,618,640],[5,11,18,19,20]]
y_train_WashingtonAll3=df.iloc[[2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,376,398,420,442,464,508,530,552,574,596,618,640],24:25]

X_train_WashingtonAll4=df.iloc[[0,3,25,47,69,91,113,135,157,179,201,223,245,267,289,311,333,355,377,399,421,443,465,509,531,553,575,597,619,641],[5,11,18,19,20]]
y_train_WashingtonAll4=df.iloc[[3,25,47,69,91,113,135,158,179,201,223,245,267,289,311,333,355,377,399,421,443,465,509,531,553,575,597,619,641],24:25]

X_train_WashingtonAll5=df.iloc[[0,4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,378,400,422,444,466,510,532,554,576,598,620,642],[5,11,18,19,20]]
y_train_WashingtonAll5=df.iloc[[4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,378,400,422,444,466,510,532,554,576,598,620,642],24:25]

X_train_WashingtonAll6=df.iloc[[0,5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,379,401,423,445,467,511,533,555,577,599,621,643],[5,11,18,19,20]]
y_train_WashingtonAll6=df.iloc[[5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,379,401,423,445,467,511,533,555,577,599,621,643],24:25]

X_train_WashingtonAll7=df.iloc[[0,6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,380,402,424,446,468,512,534,556,578,600,622,644],[5,11,18,19,20]]
y_train_WashingtonAll7=df.iloc[[6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,380,402,424,446,468,512,534,556,578,600,622,644],24:25]

X_train_WashingtonAll8=df.iloc[[0,7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,381,403,425,447,469,513,535,557,579,601,623,645],[5,11,18,19,20]]
y_train_WashingtonAll8=df.iloc[[7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,381,403,425,447,469,513,535,557,579,601,623,645],24:25]

X_train_WashingtonAll9=df.iloc[[0,8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,382,404,426,448,470,514,536,558,580,602,624,646],[5,11,18,19,20]]
y_train_WashingtonAll9=df.iloc[[8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,382,404,426,448,470,514,536,558,580,602,624,646],24:25]

X_train_WashingtonAll10=df.iloc[[0,9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,383,405,427,449,471,515,537,559,581,603,625,647],[5,11,18,19,20]]
y_train_WashingtonAll10=df.iloc[[9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,383,405,427,449,471,515,537,559,581,603,625,647],24:25]

X_train_WashingtonAll11=df.iloc[[0,10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,384,406,428,450,472,516,538,560,582,604,626,648],[5,11,18,19,20]]
y_train_WashingtonAll11=df.iloc[[10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,384,406,428,450,472,516,538,560,582,604,626,648],24:25]

X_train_WashingtonAll12=df.iloc[[0,11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,385,407,429,451,473,517,539,561,583,605,627,649],[5,11,18,19,20]]
y_train_WashingtonAll12=df.iloc[[11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,385,407,429,451,473,517,539,561,583,605,627,649],24:25]

X_train_WashingtonAll13=df.iloc[[0,12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,386,408,430,452,474,518,540,562,584,606,628,650],[5,11,18,19,20]]
y_train_WashingtonAll13=df.iloc[[12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,386,408,430,452,474,518,540,562,584,606,628,650],24:25]

X_train_WashingtonAll14=df.iloc[[0,13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,387,409,431,453,475,519,541,563,585,607,629,651],[5,11,18,19,20]]
y_train_WashingtonAll14=df.iloc[[13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,387,409,431,453,475,519,541,563,585,607,629,651],24:25]

X_train_WashingtonAll15=df.iloc[[0,14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,388,410,432,454,476,520,542,564,586,608,630,652],[5,11,18,19,20]]
y_train_WashingtonAll15=df.iloc[[14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,388,410,432,454,476,520,542,564,586,608,630,652],24:25]

X_train_WashingtonAll16=df.iloc[[0,15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,389,411,433,455,477,521,543,565,587,609,631,653],[5,11,18,19,20]]
y_train_WashingtonAll16=df.iloc[[15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,389,411,433,455,477,521,543,565,587,609,631,653],24:25]

X_train_WashingtonAll17=df.iloc[[0,16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,390,412,434,456,478,522,544,566,588,610,632,654],[5,11,18,19,20]]
y_train_WashingtonAll17=df.iloc[[16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,390,412,434,456,478,522,544,566,588,610,632,654],24:25]

X_train_WashingtonAll18=df.iloc[[0,17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,391,413,435,457,479,523,545,567,589,611,633,655],[5,11,18,19,20]]
y_train_WashingtonAll18=df.iloc[[17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,391,413,435,457,479,523,545,567,589,611,633,655],24:25]

X_train_WashingtonAll19=df.iloc[[0,18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,392,414,436,458,480,524,546,568,590,612,634,656],[5,11,18,19,20]]
y_train_WashingtonAll19=df.iloc[[18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,392,414,436,458,480,524,546,568,590,612,634,656],24:25]

X_train_WashingtonAll20=df.iloc[[0,19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,393,415,437,459,481,525,547,569,591,613,635,657],[5,11,18,19,20]]
y_train_WashingtonAll20=df.iloc[[19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,393,415,437,459,481,525,547,569,591,613,635,657],24:25]

X_train_WashingtonAll21=df.iloc[[0,20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,394,416,438,460,482,526,548,570,592,614,636,658],[5,11,18,19,20]]
y_train_WashingtonAll21=df.iloc[[20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,394,416,438,460,482,526,548,570,592,614,636,658],24:25]

X_train_WashingtonAll22=df.iloc[[0,21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,395,417,439,461,483,527,549,571,593,615,637,659],[5,11,18,19,20]]
y_train_WashingtonAll22=df.iloc[[21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,395,417,439,461,483,527,549,571,593,615,637,659],24:25]

# %%
regressorWashington1 = LinearRegression()
regressorWashington1.fit(X_train_WashingtonAll1, y_train_WashingtonAll1)
pd.DataFrame(list(zip(X_train_WashingtonAll1, regressorWashington1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_Washington1 = regressorWashington1.predict(X_train_Washington1)

# %%
y_train_WashingtonAll2.loc[-1] = y_pred_Washington1.item(0)  # adding a row
y_train_WashingtonAll2.index = y_train_WashingtonAll2.index + 1  # shifting index
y_train_WashingtonAll2 = y_train_WashingtonAll2.sort_index()
regressorWashington2 = LinearRegression()
regressorWashington2.fit(X_train_WashingtonAll2, y_train_WashingtonAll2)

pd.DataFrame(list(zip(X_train_WashingtonAll2, regressorWashington2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Washington2 = regressorWashington2.predict(X_train_Washington2)

y_train_WashingtonAll3.loc[-1] = y_pred_Washington2.item(0)  # adding a row
y_train_WashingtonAll3.index = y_train_WashingtonAll3.index + 1  # shifting index
y_train_WashingtonAll3 = y_train_WashingtonAll3.sort_index()
regressorWashington3 = LinearRegression()
regressorWashington3.fit(X_train_WashingtonAll3, y_train_WashingtonAll3)

pd.DataFrame(list(zip(X_train_WashingtonAll3, regressorWashington3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Washington3 = regressorWashington3.predict(X_train_Washington3)

y_train_WashingtonAll4.loc[-1] = y_pred_Washington3.item(0)  # adding a row
y_train_WashingtonAll4.index = y_train_WashingtonAll4.index + 1  # shifting index
y_train_WashingtonAll4 = y_train_WashingtonAll4.sort_index()
regressorWashington4 = LinearRegression()
regressorWashington4.fit(X_train_WashingtonAll4, y_train_WashingtonAll4)

pd.DataFrame(list(zip(X_train_WashingtonAll4, regressorWashington4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Washington4 = regressorWashington4.predict(X_train_Washington4)

y_train_WashingtonAll5.loc[-1] = y_pred_Washington4.item(0)  # adding a row
y_train_WashingtonAll5.index = y_train_WashingtonAll5.index + 1  # shifting index
y_train_WashingtonAll5 = y_train_WashingtonAll5.sort_index()
regressorWashington5 = LinearRegression()
regressorWashington5.fit(X_train_WashingtonAll5, y_train_WashingtonAll5)

pd.DataFrame(list(zip(X_train_WashingtonAll5, regressorWashington5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Washington5 = regressorWashington5.predict(X_train_Washington5)

y_train_WashingtonAll6.loc[-1] = y_pred_Washington5.item(0)  # adding a row
y_train_WashingtonAll6.index = y_train_WashingtonAll6.index + 1  # shifting index
y_train_WashingtonAll6 = y_train_WashingtonAll6.sort_index()
regressorWashington6 = LinearRegression()
regressorWashington6.fit(X_train_WashingtonAll6, y_train_WashingtonAll6)

pd.DataFrame(list(zip(X_train_WashingtonAll6, regressorWashington6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Washington6 = regressorWashington6.predict(X_train_Washington6)

y_train_WashingtonAll7.loc[-1] = y_pred_Washington6.item(0)  # adding a row
y_train_WashingtonAll7.index = y_train_WashingtonAll7.index + 1  # shifting index
y_train_WashingtonAll7 = y_train_WashingtonAll7.sort_index()
regressorWashington7 = LinearRegression()
regressorWashington7.fit(X_train_WashingtonAll7, y_train_WashingtonAll7)

pd.DataFrame(list(zip(X_train_WashingtonAll7, regressorWashington7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Washington7 = regressorWashington7.predict(X_train_Washington7)

y_train_WashingtonAll8.loc[-1] = y_pred_Washington7.item(0)  # adding a row
y_train_WashingtonAll8.index = y_train_WashingtonAll8.index + 1  # shifting index
y_train_WashingtonAll8 = y_train_WashingtonAll8.sort_index()
regressorWashington8 = LinearRegression()
regressorWashington8.fit(X_train_WashingtonAll8, y_train_WashingtonAll8)

pd.DataFrame(list(zip(X_train_WashingtonAll8, regressorWashington8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Washington8 = regressorWashington8.predict(X_train_Washington8)

y_train_WashingtonAll9.loc[-1] = y_pred_Washington8.item(0)  # adding a row
y_train_WashingtonAll9.index = y_train_WashingtonAll9.index + 1  # shifting index
y_train_WashingtonAll9 = y_train_WashingtonAll9.sort_index()
regressorWashington9 = LinearRegression()
regressorWashington9.fit(X_train_WashingtonAll9, y_train_WashingtonAll9)

pd.DataFrame(list(zip(X_train_WashingtonAll9, regressorWashington9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Washington9 = regressorWashington9.predict(X_train_Washington9)

y_train_WashingtonAll10.loc[-1] = y_pred_Washington9.item(0)  # adding a row
y_train_WashingtonAll10.index = y_train_WashingtonAll10.index + 1  # shifting index
y_train_WashingtonAll10 = y_train_WashingtonAll10.sort_index()
regressorWashington10 = LinearRegression()
regressorWashington10.fit(X_train_WashingtonAll10, y_train_WashingtonAll10)

pd.DataFrame(list(zip(X_train_WashingtonAll10, regressorWashington10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Washington10 = regressorWashington10.predict(X_train_Washington10)

y_train_WashingtonAll11.loc[-1] = y_pred_Washington10.item(0)  # adding a row
y_train_WashingtonAll11.index = y_train_WashingtonAll11.index + 1  # shifting index
y_train_WashingtonAll11 = y_train_WashingtonAll11.sort_index()
regressorWashington11 = LinearRegression()
regressorWashington11.fit(X_train_WashingtonAll11, y_train_WashingtonAll11)

pd.DataFrame(list(zip(X_train_WashingtonAll11, regressorWashington11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Washington11 = regressorWashington11.predict(X_train_Washington11)

y_train_WashingtonAll12.loc[-1] = y_pred_Washington11.item(0)  # adding a row
y_train_WashingtonAll12.index = y_train_WashingtonAll12.index + 1  # shifting index
y_train_WashingtonAll12 = y_train_WashingtonAll12.sort_index()
regressorWashington12 = LinearRegression()
regressorWashington12.fit(X_train_WashingtonAll12, y_train_WashingtonAll12)

pd.DataFrame(list(zip(X_train_WashingtonAll12, regressorWashington12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Washington12 = regressorWashington12.predict(X_train_Washington12)

y_train_WashingtonAll13.loc[-1] = y_pred_Washington12.item(0)  # adding a row
y_train_WashingtonAll13.index = y_train_WashingtonAll13.index + 1  # shifting index
y_train_WashingtonAll13 = y_train_WashingtonAll13.sort_index()
regressorWashington13 = LinearRegression()
regressorWashington13.fit(X_train_WashingtonAll13, y_train_WashingtonAll13)

pd.DataFrame(list(zip(X_train_WashingtonAll13, regressorWashington13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Washington13 = regressorWashington13.predict(X_train_Washington13)

y_train_WashingtonAll14.loc[-1] = y_pred_Washington13.item(0)  # adding a row
y_train_WashingtonAll14.index = y_train_WashingtonAll14.index + 1  # shifting index
y_train_WashingtonAll14 = y_train_WashingtonAll14.sort_index()
regressorWashington14 = LinearRegression()
regressorWashington14.fit(X_train_WashingtonAll14, y_train_WashingtonAll14)

pd.DataFrame(list(zip(X_train_WashingtonAll14, regressorWashington14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Washington14 = regressorWashington14.predict(X_train_Washington14)

y_train_WashingtonAll15.loc[-1] = y_pred_Washington14.item(0)  # adding a row
y_train_WashingtonAll15.index = y_train_WashingtonAll15.index + 1  # shifting index
y_train_WashingtonAll15 = y_train_WashingtonAll15.sort_index()
regressorWashington15 = LinearRegression()
regressorWashington15.fit(X_train_WashingtonAll15, y_train_WashingtonAll15)

pd.DataFrame(list(zip(X_train_WashingtonAll15, regressorWashington15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Washington15 = regressorWashington15.predict(X_train_Washington15)

y_train_WashingtonAll16.loc[-1] = y_pred_Washington15.item(0)  # adding a row
y_train_WashingtonAll16.index = y_train_WashingtonAll16.index + 1  # shifting index
y_train_WashingtonAll16 = y_train_WashingtonAll16.sort_index()
regressorWashington16 = LinearRegression()
regressorWashington16.fit(X_train_WashingtonAll16, y_train_WashingtonAll16)

pd.DataFrame(list(zip(X_train_WashingtonAll16, regressorWashington16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Washington16 = regressorWashington16.predict(X_train_Washington16)

y_train_WashingtonAll17.loc[-1] = y_pred_Washington16.item(0)  # adding a row
y_train_WashingtonAll17.index = y_train_WashingtonAll17.index + 1  # shifting index
y_train_WashingtonAll17 = y_train_WashingtonAll17.sort_index()
regressorWashington17 = LinearRegression()
regressorWashington17.fit(X_train_WashingtonAll17, y_train_WashingtonAll17)

pd.DataFrame(list(zip(X_train_WashingtonAll17, regressorWashington17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Washington17 = regressorWashington17.predict(X_train_Washington17)

y_train_WashingtonAll18.loc[-1] = y_pred_Washington17.item(0)  # adding a row
y_train_WashingtonAll18.index = y_train_WashingtonAll18.index + 1  # shifting index
y_train_WashingtonAll18 = y_train_WashingtonAll18.sort_index()
regressorWashington18 = LinearRegression()
regressorWashington18.fit(X_train_WashingtonAll18, y_train_WashingtonAll18)

pd.DataFrame(list(zip(X_train_WashingtonAll18, regressorWashington18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Washington18 = regressorWashington18.predict(X_train_Washington18)

y_train_WashingtonAll19.loc[-1] = y_pred_Washington18.item(0)  # adding a row
y_train_WashingtonAll19.index = y_train_WashingtonAll19.index + 1  # shifting index
y_train_WashingtonAll19 = y_train_WashingtonAll19.sort_index()
regressorWashington19 = LinearRegression()
regressorWashington19.fit(X_train_WashingtonAll19, y_train_WashingtonAll19)

pd.DataFrame(list(zip(X_train_WashingtonAll19, regressorWashington19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Washington19 = regressorWashington19.predict(X_train_Washington19)

y_train_WashingtonAll20.loc[-1] = y_pred_Washington19.item(0)  # adding a row
y_train_WashingtonAll20.index = y_train_WashingtonAll20.index + 1  # shifting index
y_train_WashingtonAll20 = y_train_WashingtonAll20.sort_index()
regressorWashington20 = LinearRegression()
regressorWashington20.fit(X_train_WashingtonAll20, y_train_WashingtonAll20)

pd.DataFrame(list(zip(X_train_WashingtonAll20, regressorWashington20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Washington20 = regressorWashington20.predict(X_train_Washington20)

y_train_WashingtonAll21.loc[-1] = y_pred_Washington20.item(0)  # adding a row
y_train_WashingtonAll21.index = y_train_WashingtonAll21.index + 1  # shifting index
y_train_WashingtonAll21 = y_train_WashingtonAll21.sort_index()
regressorWashington21 = LinearRegression()
regressorWashington21.fit(X_train_WashingtonAll21, y_train_WashingtonAll21)

pd.DataFrame(list(zip(X_train_WashingtonAll21, regressorWashington21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Washington21 = regressorWashington21.predict(X_train_Washington21)

# %%
X_train_Detroit1=X_Detroit[0:1]
y_train_Detroit1=y_Detroit[0:1]
X_train_Detroit2=X_Detroit[1:2]
y_train_Detroit2=y_Detroit[1:2]
X_train_Detroit3=X_Detroit[2:3]
y_train_Detroit3=y_Detroit[2:3]
X_train_Detroit4=X_Detroit[3:4]
y_train_Detroit4=y_Detroit[3:4]
X_train_Detroit5=X_Detroit[4:5]
y_train_Detroit5=y_Detroit[4:5]
y_train_Detroit6=y_Detroit[5:6]
X_train_Detroit7=X_Detroit[7:8]
X_train_Detroit6=X_Detroit[5:6]
y_train_Detroit7=y_Detroit[7:8]
X_train_Detroit8=X_Detroit[8:9]
y_train_Detroit8=y_Detroit[8:9]
X_train_Detroit9=X_Detroit[9:10]
y_train_Detroit9=y_Detroit[9:10]
X_train_Detroit10=X_Detroit[10:11]
y_train_Detroit10=y_Detroit[10:11]
X_train_Detroit11=X_Detroit[11:12]
y_train_Detroit11=y_Detroit[11:12]
X_train_Detroit12=X_Detroit[12:13]
y_train_Detroit12=y_Detroit[12:13]
X_train_Detroit13=X_Detroit[13:14]
y_train_Detroit13=y_Detroit[13:14]
X_train_Detroit14=X_Detroit[14:15]
y_train_Detroit14=y_Detroit[14:15]
X_train_Detroit15=X_Detroit[15:16]
y_train_Detroit15=y_Detroit[15:16]
X_train_Detroit16=X_Detroit[16:17]
y_train_Detroit16=y_Detroit[16:17]
X_train_Detroit17=X_Detroit[17:18]
y_train_Detroit17=y_Detroit[17:18]
X_train_Detroit18=X_Detroit[18:19]
y_train_Detroit18=y_Detroit[18:19]
X_train_Detroit19=X_Detroit[19:20]
y_train_Detroit19=y_Detroit[19:20]
X_train_Detroit20=X_Detroit[20:21]
y_train_Detroit20=y_Detroit[20:21]
X_train_Detroit21=X_Detroit[21:22]
y_train_Detroit21=y_Detroit[21:22]
X_train_Detroit22=X_Detroit[22:23]
y_train_Detroit22=y_Detroit[22:23]


X_train_DetroitAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,528,550,572,594,616,638],[5,11,18,19,20]]
y_train_DetroitAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,528,550,572,594,616,638],24:25]

X_train_DetroitAll2=df.iloc[[0,1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,375,397,419,441,463,485,529,551,573,595,617,639],[5,11,18,19,20]]
y_train_DetroitAll2=df.iloc[[1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,375,397,419,441,463,485,529,551,573,595,617,639],24:25]

X_train_DetroitAll3=df.iloc[[0,2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,376,398,420,442,464,486,530,552,574,596,618,640],[5,11,18,19,20]]
y_train_DetroitAll3=df.iloc[[2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,376,398,420,442,464,486,530,552,574,596,618,640],24:25]

X_train_DetroitAll4=df.iloc[[0,3,25,47,69,91,113,135,157,179,201,223,245,267,289,311,333,355,377,399,421,443,465,487,531,553,575,597,619,641],[5,11,18,19,20]]
y_train_DetroitAll4=df.iloc[[3,25,47,69,91,113,135,158,179,201,223,245,267,289,311,333,355,377,399,421,443,465,487,531,553,575,597,619,641],24:25]

X_train_DetroitAll5=df.iloc[[0,4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,378,400,422,444,466,488,532,554,576,598,620,642],[5,11,18,19,20]]
y_train_DetroitAll5=df.iloc[[4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,378,400,422,444,466,488,532,554,576,598,620,642],24:25]

X_train_DetroitAll6=df.iloc[[0,5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,379,401,423,445,467,489,533,555,577,599,621,643],[5,11,18,19,20]]
y_train_DetroitAll6=df.iloc[[5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,379,401,423,445,467,489,533,555,577,599,621,643],24:25]

X_train_DetroitAll7=df.iloc[[0,6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,380,402,424,446,468,490,534,556,578,600,622,644],[5,11,18,19,20]]
y_train_DetroitAll7=df.iloc[[6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,380,402,424,446,468,490,534,556,578,600,622,644],24:25]

X_train_DetroitAll8=df.iloc[[0,7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,381,403,425,447,469,491,535,557,579,601,623,645],[5,11,18,19,20]]
y_train_DetroitAll8=df.iloc[[7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,381,403,425,447,469,491,535,557,579,601,623,645],24:25]

X_train_DetroitAll9=df.iloc[[0,8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,382,404,426,448,470,492,536,558,580,602,624,646],[5,11,18,19,20]]
y_train_DetroitAll9=df.iloc[[8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,382,404,426,448,470,492,536,558,580,602,624,646],24:25]

X_train_DetroitAll10=df.iloc[[0,9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,383,405,427,449,471,493,537,559,581,603,625,647],[5,11,18,19,20]]
y_train_DetroitAll10=df.iloc[[9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,383,405,427,449,471,493,537,559,581,603,625,647],24:25]

X_train_DetroitAll11=df.iloc[[0,10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,384,406,428,450,472,494,538,560,582,604,626,648],[5,11,18,19,20]]
y_train_DetroitAll11=df.iloc[[10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,384,406,428,450,472,494,538,560,582,604,626,648],24:25]

X_train_DetroitAll12=df.iloc[[0,11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,385,407,429,451,473,495,539,561,583,605,627,649],[5,11,18,19,20]]
y_train_DetroitAll12=df.iloc[[11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,385,407,429,451,473,495,539,561,583,605,627,649],24:25]

X_train_DetroitAll13=df.iloc[[0,12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,386,408,430,452,474,496,540,562,584,606,628,650],[5,11,18,19,20]]
y_train_DetroitAll13=df.iloc[[12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,386,408,430,452,474,496,540,562,584,606,628,650],24:25]

X_train_DetroitAll14=df.iloc[[0,13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,387,409,431,453,475,497,541,563,585,607,629,651],[5,11,18,19,20]]
y_train_DetroitAll14=df.iloc[[13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,387,409,431,453,475,497,541,563,585,607,629,651],24:25]

X_train_DetroitAll15=df.iloc[[0,14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,388,410,432,454,476,498,542,564,586,608,630,652],[5,11,18,19,20]]
y_train_DetroitAll15=df.iloc[[14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,388,410,432,454,476,498,542,564,586,608,630,652],24:25]

X_train_DetroitAll16=df.iloc[[0,15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,389,411,433,455,477,499,543,565,587,609,631,653],[5,11,18,19,20]]
y_train_DetroitAll16=df.iloc[[15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,389,411,433,455,477,499,543,565,587,609,631,653],24:25]

X_train_DetroitAll17=df.iloc[[0,16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,390,412,434,456,478,500,544,566,588,610,632,654],[5,11,18,19,20]]
y_train_DetroitAll17=df.iloc[[16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,390,412,434,456,478,500,544,566,588,610,632,654],24:25]

X_train_DetroitAll18=df.iloc[[0,17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,391,413,435,457,479,501,545,567,589,611,633,655],[5,11,18,19,20]]
y_train_DetroitAll18=df.iloc[[17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,391,413,435,457,479,501,545,567,589,611,633,655],24:25]

X_train_DetroitAll19=df.iloc[[0,18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,392,414,436,458,480,502,546,568,590,612,634,656],[5,11,18,19,20]]
y_train_DetroitAll19=df.iloc[[18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,392,414,436,458,480,502,546,568,590,612,634,656],24:25]

X_train_DetroitAll20=df.iloc[[0,19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,393,415,437,459,481,503,547,569,591,613,635,657],[5,11,18,19,20]]
y_train_DetroitAll20=df.iloc[[19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,393,415,437,459,481,503,547,569,591,613,635,657],24:25]

X_train_DetroitAll21=df.iloc[[0,20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,394,416,438,460,482,504,548,570,592,614,636,658],[5,11,18,19,20]]
y_train_DetroitAll21=df.iloc[[20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,394,416,438,460,482,504,548,570,592,614,636,658],24:25]

X_train_DetroitAll22=df.iloc[[0,21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,395,417,439,461,483,505,549,571,593,615,637,659],[5,11,18,19,20]]
y_train_DetroitAll22=df.iloc[[21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,395,417,439,461,483,505,549,571,593,615,637,659],24:25]

# %%
regressorDetroit1 = LinearRegression()
regressorDetroit1.fit(X_train_DetroitAll1, y_train_DetroitAll1)
pd.DataFrame(list(zip(X_train_DetroitAll1, regressorDetroit1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_Detroit1 = regressorDetroit1.predict(X_train_Detroit1)

# %%
y_train_DetroitAll2.loc[-1] = y_pred_Detroit1.item(0)  # adding a row
y_train_DetroitAll2.index = y_train_DetroitAll2.index + 1  # shifting index
y_train_DetroitAll2 = y_train_DetroitAll2.sort_index()
regressorDetroit2 = LinearRegression()
regressorDetroit2.fit(X_train_DetroitAll2, y_train_DetroitAll2)

pd.DataFrame(list(zip(X_train_DetroitAll2, regressorDetroit2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Detroit2 = regressorDetroit2.predict(X_train_Detroit2)

y_train_DetroitAll3.loc[-1] = y_pred_Detroit2.item(0)  # adding a row
y_train_DetroitAll3.index = y_train_DetroitAll3.index + 1  # shifting index
y_train_DetroitAll3 = y_train_DetroitAll3.sort_index()
regressorDetroit3 = LinearRegression()
regressorDetroit3.fit(X_train_DetroitAll3, y_train_DetroitAll3)

pd.DataFrame(list(zip(X_train_DetroitAll3, regressorDetroit3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Detroit3 = regressorDetroit3.predict(X_train_Detroit3)

y_train_DetroitAll4.loc[-1] = y_pred_Detroit3.item(0)  # adding a row
y_train_DetroitAll4.index = y_train_DetroitAll4.index + 1  # shifting index
y_train_DetroitAll4 = y_train_DetroitAll4.sort_index()
regressorDetroit4 = LinearRegression()
regressorDetroit4.fit(X_train_DetroitAll4, y_train_DetroitAll4)

pd.DataFrame(list(zip(X_train_DetroitAll4, regressorDetroit4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Detroit4 = regressorDetroit4.predict(X_train_Detroit4)

y_train_DetroitAll5.loc[-1] = y_pred_Detroit4.item(0)  # adding a row
y_train_DetroitAll5.index = y_train_DetroitAll5.index + 1  # shifting index
y_train_DetroitAll5 = y_train_DetroitAll5.sort_index()
regressorDetroit5 = LinearRegression()
regressorDetroit5.fit(X_train_DetroitAll5, y_train_DetroitAll5)

pd.DataFrame(list(zip(X_train_DetroitAll5, regressorDetroit5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Detroit5 = regressorDetroit5.predict(X_train_Detroit5)

y_train_DetroitAll6.loc[-1] = y_pred_Detroit5.item(0)  # adding a row
y_train_DetroitAll6.index = y_train_DetroitAll6.index + 1  # shifting index
y_train_DetroitAll6 = y_train_DetroitAll6.sort_index()
regressorDetroit6 = LinearRegression()
regressorDetroit6.fit(X_train_DetroitAll6, y_train_DetroitAll6)

pd.DataFrame(list(zip(X_train_DetroitAll6, regressorDetroit6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Detroit6 = regressorDetroit6.predict(X_train_Detroit6)

y_train_DetroitAll7.loc[-1] = y_pred_Detroit6.item(0)  # adding a row
y_train_DetroitAll7.index = y_train_DetroitAll7.index + 1  # shifting index
y_train_DetroitAll7 = y_train_DetroitAll7.sort_index()
regressorDetroit7 = LinearRegression()
regressorDetroit7.fit(X_train_DetroitAll7, y_train_DetroitAll7)

pd.DataFrame(list(zip(X_train_DetroitAll7, regressorDetroit7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Detroit7 = regressorDetroit7.predict(X_train_Detroit7)

y_train_DetroitAll8.loc[-1] = y_pred_Detroit7.item(0)  # adding a row
y_train_DetroitAll8.index = y_train_DetroitAll8.index + 1  # shifting index
y_train_DetroitAll8 = y_train_DetroitAll8.sort_index()
regressorDetroit8 = LinearRegression()
regressorDetroit8.fit(X_train_DetroitAll8, y_train_DetroitAll8)

pd.DataFrame(list(zip(X_train_DetroitAll8, regressorDetroit8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Detroit8 = regressorDetroit8.predict(X_train_Detroit8)

y_train_DetroitAll9.loc[-1] = y_pred_Detroit8.item(0)  # adding a row
y_train_DetroitAll9.index = y_train_DetroitAll9.index + 1  # shifting index
y_train_DetroitAll9 = y_train_DetroitAll9.sort_index()
regressorDetroit9 = LinearRegression()
regressorDetroit9.fit(X_train_DetroitAll9, y_train_DetroitAll9)

pd.DataFrame(list(zip(X_train_DetroitAll9, regressorDetroit9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Detroit9 = regressorDetroit9.predict(X_train_Detroit9)

y_train_DetroitAll10.loc[-1] = y_pred_Detroit9.item(0)  # adding a row
y_train_DetroitAll10.index = y_train_DetroitAll10.index + 1  # shifting index
y_train_DetroitAll10 = y_train_DetroitAll10.sort_index()
regressorDetroit10 = LinearRegression()
regressorDetroit10.fit(X_train_DetroitAll10, y_train_DetroitAll10)

pd.DataFrame(list(zip(X_train_DetroitAll10, regressorDetroit10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Detroit10 = regressorDetroit10.predict(X_train_Detroit10)

y_train_DetroitAll11.loc[-1] = y_pred_Detroit10.item(0)  # adding a row
y_train_DetroitAll11.index = y_train_DetroitAll11.index + 1  # shifting index
y_train_DetroitAll11 = y_train_DetroitAll11.sort_index()
regressorDetroit11 = LinearRegression()
regressorDetroit11.fit(X_train_DetroitAll11, y_train_DetroitAll11)

pd.DataFrame(list(zip(X_train_DetroitAll11, regressorDetroit11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Detroit11 = regressorDetroit11.predict(X_train_Detroit11)

y_train_DetroitAll12.loc[-1] = y_pred_Detroit11.item(0)  # adding a row
y_train_DetroitAll12.index = y_train_DetroitAll12.index + 1  # shifting index
y_train_DetroitAll12 = y_train_DetroitAll12.sort_index()
regressorDetroit12 = LinearRegression()
regressorDetroit12.fit(X_train_DetroitAll12, y_train_DetroitAll12)

pd.DataFrame(list(zip(X_train_DetroitAll12, regressorDetroit12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Detroit12 = regressorDetroit12.predict(X_train_Detroit12)

y_train_DetroitAll13.loc[-1] = y_pred_Detroit12.item(0)  # adding a row
y_train_DetroitAll13.index = y_train_DetroitAll13.index + 1  # shifting index
y_train_DetroitAll13 = y_train_DetroitAll13.sort_index()
regressorDetroit13 = LinearRegression()
regressorDetroit13.fit(X_train_DetroitAll13, y_train_DetroitAll13)

pd.DataFrame(list(zip(X_train_DetroitAll13, regressorDetroit13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Detroit13 = regressorDetroit13.predict(X_train_Detroit13)

y_train_DetroitAll14.loc[-1] = y_pred_Detroit13.item(0)  # adding a row
y_train_DetroitAll14.index = y_train_DetroitAll14.index + 1  # shifting index
y_train_DetroitAll14 = y_train_DetroitAll14.sort_index()
regressorDetroit14 = LinearRegression()
regressorDetroit14.fit(X_train_DetroitAll14, y_train_DetroitAll14)

pd.DataFrame(list(zip(X_train_DetroitAll14, regressorDetroit14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Detroit14 = regressorDetroit14.predict(X_train_Detroit14)

y_train_DetroitAll15.loc[-1] = y_pred_Detroit14.item(0)  # adding a row
y_train_DetroitAll15.index = y_train_DetroitAll15.index + 1  # shifting index
y_train_DetroitAll15 = y_train_DetroitAll15.sort_index()
regressorDetroit15 = LinearRegression()
regressorDetroit15.fit(X_train_DetroitAll15, y_train_DetroitAll15)

pd.DataFrame(list(zip(X_train_DetroitAll15, regressorDetroit15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Detroit15 = regressorDetroit15.predict(X_train_Detroit15)

y_train_DetroitAll16.loc[-1] = y_pred_Detroit15.item(0)  # adding a row
y_train_DetroitAll16.index = y_train_DetroitAll16.index + 1  # shifting index
y_train_DetroitAll16 = y_train_DetroitAll16.sort_index()
regressorDetroit16 = LinearRegression()
regressorDetroit16.fit(X_train_DetroitAll16, y_train_DetroitAll16)

pd.DataFrame(list(zip(X_train_DetroitAll16, regressorDetroit16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Detroit16 = regressorDetroit16.predict(X_train_Detroit16)

y_train_DetroitAll17.loc[-1] = y_pred_Detroit16.item(0)  # adding a row
y_train_DetroitAll17.index = y_train_DetroitAll17.index + 1  # shifting index
y_train_DetroitAll17 = y_train_DetroitAll17.sort_index()
regressorDetroit17 = LinearRegression()
regressorDetroit17.fit(X_train_DetroitAll17, y_train_DetroitAll17)

pd.DataFrame(list(zip(X_train_DetroitAll17, regressorDetroit17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Detroit17 = regressorDetroit17.predict(X_train_Detroit17)

y_train_DetroitAll18.loc[-1] = y_pred_Detroit17.item(0)  # adding a row
y_train_DetroitAll18.index = y_train_DetroitAll18.index + 1  # shifting index
y_train_DetroitAll18 = y_train_DetroitAll18.sort_index()
regressorDetroit18 = LinearRegression()
regressorDetroit18.fit(X_train_DetroitAll18, y_train_DetroitAll18)

pd.DataFrame(list(zip(X_train_DetroitAll18, regressorDetroit18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Detroit18 = regressorDetroit18.predict(X_train_Detroit18)

y_train_DetroitAll19.loc[-1] = y_pred_Detroit18.item(0)  # adding a row
y_train_DetroitAll19.index = y_train_DetroitAll19.index + 1  # shifting index
y_train_DetroitAll19 = y_train_DetroitAll19.sort_index()
regressorDetroit19 = LinearRegression()
regressorDetroit19.fit(X_train_DetroitAll19, y_train_DetroitAll19)

pd.DataFrame(list(zip(X_train_DetroitAll19, regressorDetroit19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Detroit19 = regressorDetroit19.predict(X_train_Detroit19)

y_train_DetroitAll20.loc[-1] = y_pred_Detroit19.item(0)  # adding a row
y_train_DetroitAll20.index = y_train_DetroitAll20.index + 1  # shifting index
y_train_DetroitAll20 = y_train_DetroitAll20.sort_index()
regressorDetroit20 = LinearRegression()
regressorDetroit20.fit(X_train_DetroitAll20, y_train_DetroitAll20)

pd.DataFrame(list(zip(X_train_DetroitAll20, regressorDetroit20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Detroit20 = regressorDetroit20.predict(X_train_Detroit20)

y_train_DetroitAll21.loc[-1] = y_pred_Detroit20.item(0)  # adding a row
y_train_DetroitAll21.index = y_train_DetroitAll21.index + 1  # shifting index
y_train_DetroitAll21 = y_train_DetroitAll21.sort_index()
regressorDetroit21 = LinearRegression()
regressorDetroit21.fit(X_train_DetroitAll21, y_train_DetroitAll21)

pd.DataFrame(list(zip(X_train_DetroitAll21, regressorDetroit21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Detroit21 = regressorDetroit21.predict(X_train_Detroit21)

# %%
X_train_Charlotte1=X_Charlotte[0:1]
y_train_Charlotte1=y_Charlotte[0:1]
X_train_Charlotte2=X_Charlotte[1:2]
y_train_Charlotte2=y_Charlotte[1:2]
X_train_Charlotte3=X_Charlotte[2:3]
y_train_Charlotte3=y_Charlotte[2:3]
X_train_Charlotte4=X_Charlotte[3:4]
y_train_Charlotte4=y_Charlotte[3:4]
X_train_Charlotte5=X_Charlotte[4:5]
y_train_Charlotte5=y_Charlotte[4:5]
y_train_Charlotte6=y_Charlotte[5:6]
X_train_Charlotte7=X_Charlotte[7:8]
X_train_Charlotte6=X_Charlotte[5:6]
y_train_Charlotte7=y_Charlotte[7:8]
X_train_Charlotte8=X_Charlotte[8:9]
y_train_Charlotte8=y_Charlotte[8:9]
X_train_Charlotte9=X_Charlotte[9:10]
y_train_Charlotte9=y_Charlotte[9:10]
X_train_Charlotte10=X_Charlotte[10:11]
y_train_Charlotte10=y_Charlotte[10:11]
X_train_Charlotte11=X_Charlotte[11:12]
y_train_Charlotte11=y_Charlotte[11:12]
X_train_Charlotte12=X_Charlotte[12:13]
y_train_Charlotte12=y_Charlotte[12:13]
X_train_Charlotte13=X_Charlotte[13:14]
y_train_Charlotte13=y_Charlotte[13:14]
X_train_Charlotte14=X_Charlotte[14:15]
y_train_Charlotte14=y_Charlotte[14:15]
X_train_Charlotte15=X_Charlotte[15:16]
y_train_Charlotte15=y_Charlotte[15:16]
X_train_Charlotte16=X_Charlotte[16:17]
y_train_Charlotte16=y_Charlotte[16:17]
X_train_Charlotte17=X_Charlotte[17:18]
y_train_Charlotte17=y_Charlotte[17:18]
X_train_Charlotte18=X_Charlotte[18:19]
y_train_Charlotte18=y_Charlotte[18:19]
X_train_Charlotte19=X_Charlotte[19:20]
y_train_Charlotte19=y_Charlotte[19:20]
X_train_Charlotte20=X_Charlotte[20:21]
y_train_Charlotte20=y_Charlotte[20:21]
X_train_Charlotte21=X_Charlotte[21:22]
y_train_Charlotte21=y_Charlotte[21:22]
X_train_Charlotte22=X_Charlotte[22:23]
y_train_Charlotte22=y_Charlotte[22:23]


X_train_CharlotteAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,550,572,594,616,638],[5,11,18,19,20]]
y_train_CharlotteAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,550,572,594,616,638],24:25]

X_train_CharlotteAll2=df.iloc[[0,1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,375,397,419,441,463,485,507,551,573,595,617,639],[5,11,18,19,20]]
y_train_CharlotteAll2=df.iloc[[1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,375,397,419,441,463,485,507,551,573,595,617,639],24:25]

X_train_CharlotteAll3=df.iloc[[0,2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,376,398,420,442,464,486,508,552,574,596,618,640],[5,11,18,19,20]]
y_train_CharlotteAll3=df.iloc[[2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,376,398,420,442,464,486,508,552,574,596,618,640],24:25]

X_train_CharlotteAll4=df.iloc[[0,3,25,47,69,91,113,135,157,179,201,223,245,267,289,311,333,355,377,399,421,443,465,487,509,553,575,597,619,641],[5,11,18,19,20]]
y_train_CharlotteAll4=df.iloc[[3,25,47,69,91,113,135,158,179,201,223,245,267,289,311,333,355,377,399,421,443,465,487,509,553,575,597,619,641],24:25]

X_train_CharlotteAll5=df.iloc[[0,4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,378,400,422,444,466,488,510,554,576,598,620,642],[5,11,18,19,20]]
y_train_CharlotteAll5=df.iloc[[4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,378,400,422,444,466,488,510,554,576,598,620,642],24:25]

X_train_CharlotteAll6=df.iloc[[0,5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,379,401,423,445,467,489,511,555,577,599,621,643],[5,11,18,19,20]]
y_train_CharlotteAll6=df.iloc[[5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,379,401,423,445,467,489,511,555,577,599,621,643],24:25]

X_train_CharlotteAll7=df.iloc[[0,6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,380,402,424,446,468,490,512,556,578,600,622,644],[5,11,18,19,20]]
y_train_CharlotteAll7=df.iloc[[6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,380,402,424,446,468,490,512,556,578,600,622,644],24:25]

X_train_CharlotteAll8=df.iloc[[0,7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,381,403,425,447,469,491,513,557,579,601,623,645],[5,11,18,19,20]]
y_train_CharlotteAll8=df.iloc[[7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,381,403,425,447,469,491,513,557,579,601,623,645],24:25]

X_train_CharlotteAll9=df.iloc[[0,8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,382,404,426,448,470,492,514,558,580,602,624,646],[5,11,18,19,20]]
y_train_CharlotteAll9=df.iloc[[8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,382,404,426,448,470,492,514,558,580,602,624,646],24:25]

X_train_CharlotteAll10=df.iloc[[0,9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,383,405,427,449,471,493,515,559,581,603,625,647],[5,11,18,19,20]]
y_train_CharlotteAll10=df.iloc[[9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,383,405,427,449,471,493,515,559,581,603,625,647],24:25]

X_train_CharlotteAll11=df.iloc[[0,10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,384,406,428,450,472,494,516,560,582,604,626,648],[5,11,18,19,20]]
y_train_CharlotteAll11=df.iloc[[10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,384,406,428,450,472,494,516,560,582,604,626,648],24:25]

X_train_CharlotteAll12=df.iloc[[0,11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,385,407,429,451,473,495,517,561,583,605,627,649],[5,11,18,19,20]]
y_train_CharlotteAll12=df.iloc[[11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,385,407,429,451,473,495,517,561,583,605,627,649],24:25]

X_train_CharlotteAll13=df.iloc[[0,12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,386,408,430,452,474,496,518,562,584,606,628,650],[5,11,18,19,20]]
y_train_CharlotteAll13=df.iloc[[12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,386,408,430,452,474,496,518,562,584,606,628,650],24:25]

X_train_CharlotteAll14=df.iloc[[0,13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,387,409,431,453,475,497,519,563,585,607,629,651],[5,11,18,19,20]]
y_train_CharlotteAll14=df.iloc[[13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,387,409,431,453,475,497,519,563,585,607,629,651],24:25]

X_train_CharlotteAll15=df.iloc[[0,14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,388,410,432,454,476,498,520,564,586,608,630,652],[5,11,18,19,20]]
y_train_CharlotteAll15=df.iloc[[14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,388,410,432,454,476,498,520,564,586,608,630,652],24:25]

X_train_CharlotteAll16=df.iloc[[0,15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,389,411,433,455,477,499,521,565,587,609,631,653],[5,11,18,19,20]]
y_train_CharlotteAll16=df.iloc[[15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,389,411,433,455,477,499,521,565,587,609,631,653],24:25]

X_train_CharlotteAll17=df.iloc[[0,16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,390,412,434,456,478,500,522,566,588,610,632,654],[5,11,18,19,20]]
y_train_CharlotteAll17=df.iloc[[16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,390,412,434,456,478,500,522,566,588,610,632,654],24:25]

X_train_CharlotteAll18=df.iloc[[0,17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,391,413,435,457,479,501,523,567,589,611,633,655],[5,11,18,19,20]]
y_train_CharlotteAll18=df.iloc[[17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,391,413,435,457,479,501,523,567,589,611,633,655],24:25]

X_train_CharlotteAll19=df.iloc[[0,18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,392,414,436,458,480,502,524,568,590,612,634,656],[5,11,18,19,20]]
y_train_CharlotteAll19=df.iloc[[18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,392,414,436,458,480,502,524,568,590,612,634,656],24:25]

X_train_CharlotteAll20=df.iloc[[0,19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,393,415,437,459,481,503,525,569,591,613,635,657],[5,11,18,19,20]]
y_train_CharlotteAll20=df.iloc[[19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,393,415,437,459,481,503,525,569,591,613,635,657],24:25]

X_train_CharlotteAll21=df.iloc[[0,20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,394,416,438,460,482,504,526,570,592,614,636,658],[5,11,18,19,20]]
y_train_CharlotteAll21=df.iloc[[20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,394,416,438,460,482,504,526,570,592,614,636,658],24:25]

X_train_CharlotteAll22=df.iloc[[0,21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,395,417,439,461,483,505,527,571,593,615,637,659],[5,11,18,19,20]]
y_train_CharlotteAll22=df.iloc[[21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,395,417,439,461,483,505,527,571,593,615,637,659],24:25]

# %%
regressorCharlotte1 = LinearRegression()
regressorCharlotte1.fit(X_train_CharlotteAll1, y_train_CharlotteAll1)
pd.DataFrame(list(zip(X_train_CharlotteAll1, regressorCharlotte1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_Charlotte1 = regressorCharlotte1.predict(X_train_Charlotte1)

# %%
y_train_CharlotteAll2.loc[-1] = y_pred_Charlotte1.item(0)  # adding a row
y_train_CharlotteAll2.index = y_train_CharlotteAll2.index + 1  # shifting index
y_train_CharlotteAll2 = y_train_CharlotteAll2.sort_index()
regressorCharlotte2 = LinearRegression()
regressorCharlotte2.fit(X_train_CharlotteAll2, y_train_CharlotteAll2)

pd.DataFrame(list(zip(X_train_CharlotteAll2, regressorCharlotte2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Charlotte2 = regressorCharlotte2.predict(X_train_Charlotte2)

y_train_CharlotteAll3.loc[-1] = y_pred_Charlotte2.item(0)  # adding a row
y_train_CharlotteAll3.index = y_train_CharlotteAll3.index + 1  # shifting index
y_train_CharlotteAll3 = y_train_CharlotteAll3.sort_index()
regressorCharlotte3 = LinearRegression()
regressorCharlotte3.fit(X_train_CharlotteAll3, y_train_CharlotteAll3)

pd.DataFrame(list(zip(X_train_CharlotteAll3, regressorCharlotte3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Charlotte3 = regressorCharlotte3.predict(X_train_Charlotte3)

y_train_CharlotteAll4.loc[-1] = y_pred_Charlotte3.item(0)  # adding a row
y_train_CharlotteAll4.index = y_train_CharlotteAll4.index + 1  # shifting index
y_train_CharlotteAll4 = y_train_CharlotteAll4.sort_index()
regressorCharlotte4 = LinearRegression()
regressorCharlotte4.fit(X_train_CharlotteAll4, y_train_CharlotteAll4)

pd.DataFrame(list(zip(X_train_CharlotteAll4, regressorCharlotte4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Charlotte4 = regressorCharlotte4.predict(X_train_Charlotte4)

y_train_CharlotteAll5.loc[-1] = y_pred_Charlotte4.item(0)  # adding a row
y_train_CharlotteAll5.index = y_train_CharlotteAll5.index + 1  # shifting index
y_train_CharlotteAll5 = y_train_CharlotteAll5.sort_index()
regressorCharlotte5 = LinearRegression()
regressorCharlotte5.fit(X_train_CharlotteAll5, y_train_CharlotteAll5)

pd.DataFrame(list(zip(X_train_CharlotteAll5, regressorCharlotte5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Charlotte5 = regressorCharlotte5.predict(X_train_Charlotte5)

y_train_CharlotteAll6.loc[-1] = y_pred_Charlotte5.item(0)  # adding a row
y_train_CharlotteAll6.index = y_train_CharlotteAll6.index + 1  # shifting index
y_train_CharlotteAll6 = y_train_CharlotteAll6.sort_index()
regressorCharlotte6 = LinearRegression()
regressorCharlotte6.fit(X_train_CharlotteAll6, y_train_CharlotteAll6)

pd.DataFrame(list(zip(X_train_CharlotteAll6, regressorCharlotte6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Charlotte6 = regressorCharlotte6.predict(X_train_Charlotte6)

y_train_CharlotteAll7.loc[-1] = y_pred_Charlotte6.item(0)  # adding a row
y_train_CharlotteAll7.index = y_train_CharlotteAll7.index + 1  # shifting index
y_train_CharlotteAll7 = y_train_CharlotteAll7.sort_index()
regressorCharlotte7 = LinearRegression()
regressorCharlotte7.fit(X_train_CharlotteAll7, y_train_CharlotteAll7)

pd.DataFrame(list(zip(X_train_CharlotteAll7, regressorCharlotte7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Charlotte7 = regressorCharlotte7.predict(X_train_Charlotte7)

y_train_CharlotteAll8.loc[-1] = y_pred_Charlotte7.item(0)  # adding a row
y_train_CharlotteAll8.index = y_train_CharlotteAll8.index + 1  # shifting index
y_train_CharlotteAll8 = y_train_CharlotteAll8.sort_index()
regressorCharlotte8 = LinearRegression()
regressorCharlotte8.fit(X_train_CharlotteAll8, y_train_CharlotteAll8)

pd.DataFrame(list(zip(X_train_CharlotteAll8, regressorCharlotte8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Charlotte8 = regressorCharlotte8.predict(X_train_Charlotte8)

y_train_CharlotteAll9.loc[-1] = y_pred_Charlotte8.item(0)  # adding a row
y_train_CharlotteAll9.index = y_train_CharlotteAll9.index + 1  # shifting index
y_train_CharlotteAll9 = y_train_CharlotteAll9.sort_index()
regressorCharlotte9 = LinearRegression()
regressorCharlotte9.fit(X_train_CharlotteAll9, y_train_CharlotteAll9)

pd.DataFrame(list(zip(X_train_CharlotteAll9, regressorCharlotte9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Charlotte9 = regressorCharlotte9.predict(X_train_Charlotte9)

y_train_CharlotteAll10.loc[-1] = y_pred_Charlotte9.item(0)  # adding a row
y_train_CharlotteAll10.index = y_train_CharlotteAll10.index + 1  # shifting index
y_train_CharlotteAll10 = y_train_CharlotteAll10.sort_index()
regressorCharlotte10 = LinearRegression()
regressorCharlotte10.fit(X_train_CharlotteAll10, y_train_CharlotteAll10)

pd.DataFrame(list(zip(X_train_CharlotteAll10, regressorCharlotte10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Charlotte10 = regressorCharlotte10.predict(X_train_Charlotte10)

y_train_CharlotteAll11.loc[-1] = y_pred_Charlotte10.item(0)  # adding a row
y_train_CharlotteAll11.index = y_train_CharlotteAll11.index + 1  # shifting index
y_train_CharlotteAll11 = y_train_CharlotteAll11.sort_index()
regressorCharlotte11 = LinearRegression()
regressorCharlotte11.fit(X_train_CharlotteAll11, y_train_CharlotteAll11)

pd.DataFrame(list(zip(X_train_CharlotteAll11, regressorCharlotte11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Charlotte11 = regressorCharlotte11.predict(X_train_Charlotte11)

y_train_CharlotteAll12.loc[-1] = y_pred_Charlotte11.item(0)  # adding a row
y_train_CharlotteAll12.index = y_train_CharlotteAll12.index + 1  # shifting index
y_train_CharlotteAll12 = y_train_CharlotteAll12.sort_index()
regressorCharlotte12 = LinearRegression()
regressorCharlotte12.fit(X_train_CharlotteAll12, y_train_CharlotteAll12)

pd.DataFrame(list(zip(X_train_CharlotteAll12, regressorCharlotte12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Charlotte12 = regressorCharlotte12.predict(X_train_Charlotte12)

y_train_CharlotteAll13.loc[-1] = y_pred_Charlotte12.item(0)  # adding a row
y_train_CharlotteAll13.index = y_train_CharlotteAll13.index + 1  # shifting index
y_train_CharlotteAll13 = y_train_CharlotteAll13.sort_index()
regressorCharlotte13 = LinearRegression()
regressorCharlotte13.fit(X_train_CharlotteAll13, y_train_CharlotteAll13)

pd.DataFrame(list(zip(X_train_CharlotteAll13, regressorCharlotte13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Charlotte13 = regressorCharlotte13.predict(X_train_Charlotte13)

y_train_CharlotteAll14.loc[-1] = y_pred_Charlotte13.item(0)  # adding a row
y_train_CharlotteAll14.index = y_train_CharlotteAll14.index + 1  # shifting index
y_train_CharlotteAll14 = y_train_CharlotteAll14.sort_index()
regressorCharlotte14 = LinearRegression()
regressorCharlotte14.fit(X_train_CharlotteAll14, y_train_CharlotteAll14)

pd.DataFrame(list(zip(X_train_CharlotteAll14, regressorCharlotte14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Charlotte14 = regressorCharlotte14.predict(X_train_Charlotte14)

y_train_CharlotteAll15.loc[-1] = y_pred_Charlotte14.item(0)  # adding a row
y_train_CharlotteAll15.index = y_train_CharlotteAll15.index + 1  # shifting index
y_train_CharlotteAll15 = y_train_CharlotteAll15.sort_index()
regressorCharlotte15 = LinearRegression()
regressorCharlotte15.fit(X_train_CharlotteAll15, y_train_CharlotteAll15)

pd.DataFrame(list(zip(X_train_CharlotteAll15, regressorCharlotte15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Charlotte15 = regressorCharlotte15.predict(X_train_Charlotte15)

y_train_CharlotteAll16.loc[-1] = y_pred_Charlotte15.item(0)  # adding a row
y_train_CharlotteAll16.index = y_train_CharlotteAll16.index + 1  # shifting index
y_train_CharlotteAll16 = y_train_CharlotteAll16.sort_index()
regressorCharlotte16 = LinearRegression()
regressorCharlotte16.fit(X_train_CharlotteAll16, y_train_CharlotteAll16)

pd.DataFrame(list(zip(X_train_CharlotteAll16, regressorCharlotte16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Charlotte16 = regressorCharlotte16.predict(X_train_Charlotte16)

y_train_CharlotteAll17.loc[-1] = y_pred_Charlotte16.item(0)  # adding a row
y_train_CharlotteAll17.index = y_train_CharlotteAll17.index + 1  # shifting index
y_train_CharlotteAll17 = y_train_CharlotteAll17.sort_index()
regressorCharlotte17 = LinearRegression()
regressorCharlotte17.fit(X_train_CharlotteAll17, y_train_CharlotteAll17)

pd.DataFrame(list(zip(X_train_CharlotteAll17, regressorCharlotte17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Charlotte17 = regressorCharlotte17.predict(X_train_Charlotte17)

y_train_CharlotteAll18.loc[-1] = y_pred_Charlotte17.item(0)  # adding a row
y_train_CharlotteAll18.index = y_train_CharlotteAll18.index + 1  # shifting index
y_train_CharlotteAll18 = y_train_CharlotteAll18.sort_index()
regressorCharlotte18 = LinearRegression()
regressorCharlotte18.fit(X_train_CharlotteAll18, y_train_CharlotteAll18)

pd.DataFrame(list(zip(X_train_CharlotteAll18, regressorCharlotte18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Charlotte18 = regressorCharlotte18.predict(X_train_Charlotte18)

y_train_CharlotteAll19.loc[-1] = y_pred_Charlotte18.item(0)  # adding a row
y_train_CharlotteAll19.index = y_train_CharlotteAll19.index + 1  # shifting index
y_train_CharlotteAll19 = y_train_CharlotteAll19.sort_index()
regressorCharlotte19 = LinearRegression()
regressorCharlotte19.fit(X_train_CharlotteAll19, y_train_CharlotteAll19)

pd.DataFrame(list(zip(X_train_CharlotteAll19, regressorCharlotte19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Charlotte19 = regressorCharlotte19.predict(X_train_Charlotte19)

y_train_CharlotteAll20.loc[-1] = y_pred_Charlotte19.item(0)  # adding a row
y_train_CharlotteAll20.index = y_train_CharlotteAll20.index + 1  # shifting index
y_train_CharlotteAll20 = y_train_CharlotteAll20.sort_index()
regressorCharlotte20 = LinearRegression()
regressorCharlotte20.fit(X_train_CharlotteAll20, y_train_CharlotteAll20)

pd.DataFrame(list(zip(X_train_CharlotteAll20, regressorCharlotte20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Charlotte20 = regressorCharlotte20.predict(X_train_Charlotte20)

y_train_CharlotteAll21.loc[-1] = y_pred_Charlotte20.item(0)  # adding a row
y_train_CharlotteAll21.index = y_train_CharlotteAll21.index + 1  # shifting index
y_train_CharlotteAll21 = y_train_CharlotteAll21.sort_index()
regressorCharlotte21 = LinearRegression()
regressorCharlotte21.fit(X_train_CharlotteAll21, y_train_CharlotteAll21)

pd.DataFrame(list(zip(X_train_CharlotteAll21, regressorCharlotte21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Charlotte21 = regressorCharlotte21.predict(X_train_Charlotte21)

# %%
X_train_NewYork1=X_NewYork[0:1]
y_train_NewYork1=y_NewYork[0:1]
X_train_NewYork2=X_NewYork[1:2]
y_train_NewYork2=y_NewYork[1:2]
X_train_NewYork3=X_NewYork[2:3]
y_train_NewYork3=y_NewYork[2:3]
X_train_NewYork4=X_NewYork[3:4]
y_train_NewYork4=y_NewYork[3:4]
X_train_NewYork5=X_NewYork[4:5]
y_train_NewYork5=y_NewYork[4:5]
y_train_NewYork6=y_NewYork[5:6]
X_train_NewYork7=X_NewYork[7:8]
X_train_NewYork6=X_NewYork[5:6]
y_train_NewYork7=y_NewYork[7:8]
X_train_NewYork8=X_NewYork[8:9]
y_train_NewYork8=y_NewYork[8:9]
X_train_NewYork9=X_NewYork[9:10]
y_train_NewYork9=y_NewYork[9:10]
X_train_NewYork10=X_NewYork[10:11]
y_train_NewYork10=y_NewYork[10:11]
X_train_NewYork11=X_NewYork[11:12]
y_train_NewYork11=y_NewYork[11:12]
X_train_NewYork12=X_NewYork[12:13]
y_train_NewYork12=y_NewYork[12:13]
X_train_NewYork13=X_NewYork[13:14]
y_train_NewYork13=y_NewYork[13:14]
X_train_NewYork14=X_NewYork[14:15]
y_train_NewYork14=y_NewYork[14:15]
X_train_NewYork15=X_NewYork[15:16]
y_train_NewYork15=y_NewYork[15:16]
X_train_NewYork16=X_NewYork[16:17]
y_train_NewYork16=y_NewYork[16:17]
X_train_NewYork17=X_NewYork[17:18]
y_train_NewYork17=y_NewYork[17:18]
X_train_NewYork18=X_NewYork[18:19]
y_train_NewYork18=y_NewYork[18:19]
X_train_NewYork19=X_NewYork[19:20]
y_train_NewYork19=y_NewYork[19:20]
X_train_NewYork20=X_NewYork[20:21]
y_train_NewYork20=y_NewYork[20:21]
X_train_NewYork21=X_NewYork[21:22]
y_train_NewYork21=y_NewYork[21:22]
X_train_NewYork22=X_NewYork[22:23]
y_train_NewYork22=y_NewYork[22:23]

X_train_NewYorkAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,572,594,616,638],[5,11,18,19,20]]
y_train_NewYorkAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,572,594,616,638],24:25]

X_train_NewYorkAll2=df.iloc[[0,1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,375,397,419,441,463,485,507,529,573,595,617,639],[5,11,18,19,20]]
y_train_NewYorkAll2=df.iloc[[1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,375,397,419,441,463,485,507,529,573,595,617,639],24:25]

X_train_NewYorkAll3=df.iloc[[0,2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,376,398,420,442,464,486,508,530,574,596,618,640],[5,11,18,19,20]]
y_train_NewYorkAll3=df.iloc[[2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,376,398,420,442,464,486,508,530,574,596,618,640],24:25]

X_train_NewYorkAll4=df.iloc[[0,3,25,47,69,91,113,135,157,179,201,223,245,267,289,311,333,355,377,399,421,443,465,487,509,531,575,597,619,641],[5,11,18,19,20]]
y_train_NewYorkAll4=df.iloc[[3,25,47,69,91,113,135,158,179,201,223,245,267,289,311,333,355,377,399,421,443,465,487,509,531,575,597,619,641],24:25]

X_train_NewYorkAll5=df.iloc[[0,4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,378,400,422,444,466,488,510,532,576,598,620,642],[5,11,18,19,20]]
y_train_NewYorkAll5=df.iloc[[4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,378,400,422,444,466,488,510,532,576,598,620,642],24:25]

X_train_NewYorkAll6=df.iloc[[0,5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,379,401,423,445,467,489,511,533,577,599,621,643],[5,11,18,19,20]]
y_train_NewYorkAll6=df.iloc[[5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,379,401,423,445,467,489,511,533,577,599,621,643],24:25]

X_train_NewYorkAll7=df.iloc[[0,6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,380,402,424,446,468,490,512,534,578,600,622,644],[5,11,18,19,20]]
y_train_NewYorkAll7=df.iloc[[6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,380,402,424,446,468,490,512,534,578,600,622,644],24:25]

X_train_NewYorkAll8=df.iloc[[0,7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,381,403,425,447,469,491,513,535,579,601,623,645],[5,11,18,19,20]]
y_train_NewYorkAll8=df.iloc[[7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,381,403,425,447,469,491,513,535,579,601,623,645],24:25]

X_train_NewYorkAll9=df.iloc[[0,8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,382,404,426,448,470,492,514,536,580,602,624,646],[5,11,18,19,20]]
y_train_NewYorkAll9=df.iloc[[8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,382,404,426,448,470,492,514,536,580,602,624,646],24:25]

X_train_NewYorkAll10=df.iloc[[0,9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,383,405,427,449,471,493,515,537,581,603,625,647],[5,11,18,19,20]]
y_train_NewYorkAll10=df.iloc[[9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,383,405,427,449,471,493,515,537,581,603,625,647],24:25]

X_train_NewYorkAll11=df.iloc[[0,10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,384,406,428,450,472,494,516,538,582,604,626,648],[5,11,18,19,20]]
y_train_NewYorkAll11=df.iloc[[10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,384,406,428,450,472,494,516,538,582,604,626,648],24:25]

X_train_NewYorkAll12=df.iloc[[0,11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,385,407,429,451,473,495,517,539,583,605,627,649],[5,11,18,19,20]]
y_train_NewYorkAll12=df.iloc[[11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,385,407,429,451,473,495,517,539,583,605,627,649],24:25]

X_train_NewYorkAll13=df.iloc[[0,12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,386,408,430,452,474,496,518,540,584,606,628,650],[5,11,18,19,20]]
y_train_NewYorkAll13=df.iloc[[12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,386,408,430,452,474,496,518,540,584,606,628,650],24:25]

X_train_NewYorkAll14=df.iloc[[0,13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,387,409,431,453,475,497,519,541,585,607,629,651],[5,11,18,19,20]]
y_train_NewYorkAll14=df.iloc[[13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,387,409,431,453,475,497,519,541,585,607,629,651],24:25]

X_train_NewYorkAll15=df.iloc[[0,14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,388,410,432,454,476,498,520,542,586,608,630,652],[5,11,18,19,20]]
y_train_NewYorkAll15=df.iloc[[14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,388,410,432,454,476,498,520,542,586,608,630,652],24:25]

X_train_NewYorkAll16=df.iloc[[0,15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,389,411,433,455,477,499,521,543,587,609,631,653],[5,11,18,19,20]]
y_train_NewYorkAll16=df.iloc[[15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,389,411,433,455,477,499,521,543,587,609,631,653],24:25]

X_train_NewYorkAll17=df.iloc[[0,16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,390,412,434,456,478,500,522,544,588,610,632,654],[5,11,18,19,20]]
y_train_NewYorkAll17=df.iloc[[16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,390,412,434,456,478,500,522,544,588,610,632,654],24:25]

X_train_NewYorkAll18=df.iloc[[0,17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,391,413,435,457,479,501,523,545,589,611,633,655],[5,11,18,19,20]]
y_train_NewYorkAll18=df.iloc[[17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,391,413,435,457,479,501,523,545,589,611,633,655],24:25]

X_train_NewYorkAll19=df.iloc[[0,18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,392,414,436,458,480,502,524,546,590,612,634,656],[5,11,18,19,20]]
y_train_NewYorkAll19=df.iloc[[18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,392,414,436,458,480,502,524,546,590,612,634,656],24:25]

X_train_NewYorkAll20=df.iloc[[0,19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,393,415,437,459,481,503,525,547,591,613,635,657],[5,11,18,19,20]]
y_train_NewYorkAll20=df.iloc[[19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,393,415,437,459,481,503,525,547,591,613,635,657],24:25]

X_train_NewYorkAll21=df.iloc[[0,20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,394,416,438,460,482,504,526,548,592,614,636,658],[5,11,18,19,20]]
y_train_NewYorkAll21=df.iloc[[20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,394,416,438,460,482,504,526,548,592,614,636,658],24:25]

X_train_NewYorkAll22=df.iloc[[0,21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,395,417,439,461,483,505,527,549,593,615,637,659],[5,11,18,19,20]]
y_train_NewYorkAll22=df.iloc[[21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,395,417,439,461,483,505,527,549,593,615,637,659],24:25]

# %%
regressorNewYork1 = LinearRegression()
regressorNewYork1.fit(X_train_NewYorkAll1, y_train_NewYorkAll1)
pd.DataFrame(list(zip(X_train_NewYorkAll1, regressorNewYork1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_NewYork1 = regressorNewYork1.predict(X_train_NewYork1)

# %%
y_train_NewYorkAll2.loc[-1] = y_pred_NewYork1.item(0)  # adding a row
y_train_NewYorkAll2.index = y_train_NewYorkAll2.index + 1  # shifting index
y_train_NewYorkAll2 = y_train_NewYorkAll2.sort_index()
regressorNewYork2 = LinearRegression()
regressorNewYork2.fit(X_train_NewYorkAll2, y_train_NewYorkAll2)

pd.DataFrame(list(zip(X_train_NewYorkAll2, regressorNewYork2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewYork2 = regressorNewYork2.predict(X_train_NewYork2)

y_train_NewYorkAll3.loc[-1] = y_pred_NewYork2.item(0)  # adding a row
y_train_NewYorkAll3.index = y_train_NewYorkAll3.index + 1  # shifting index
y_train_NewYorkAll3 = y_train_NewYorkAll3.sort_index()
regressorNewYork3 = LinearRegression()
regressorNewYork3.fit(X_train_NewYorkAll3, y_train_NewYorkAll3)

pd.DataFrame(list(zip(X_train_NewYorkAll3, regressorNewYork3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewYork3 = regressorNewYork3.predict(X_train_NewYork3)

y_train_NewYorkAll4.loc[-1] = y_pred_NewYork3.item(0)  # adding a row
y_train_NewYorkAll4.index = y_train_NewYorkAll4.index + 1  # shifting index
y_train_NewYorkAll4 = y_train_NewYorkAll4.sort_index()
regressorNewYork4 = LinearRegression()
regressorNewYork4.fit(X_train_NewYorkAll4, y_train_NewYorkAll4)

pd.DataFrame(list(zip(X_train_NewYorkAll4, regressorNewYork4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewYork4 = regressorNewYork4.predict(X_train_NewYork4)

y_train_NewYorkAll5.loc[-1] = y_pred_NewYork4.item(0)  # adding a row
y_train_NewYorkAll5.index = y_train_NewYorkAll5.index + 1  # shifting index
y_train_NewYorkAll5 = y_train_NewYorkAll5.sort_index()
regressorNewYork5 = LinearRegression()
regressorNewYork5.fit(X_train_NewYorkAll5, y_train_NewYorkAll5)

pd.DataFrame(list(zip(X_train_NewYorkAll5, regressorNewYork5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewYork5 = regressorNewYork5.predict(X_train_NewYork5)

y_train_NewYorkAll6.loc[-1] = y_pred_NewYork5.item(0)  # adding a row
y_train_NewYorkAll6.index = y_train_NewYorkAll6.index + 1  # shifting index
y_train_NewYorkAll6 = y_train_NewYorkAll6.sort_index()
regressorNewYork6 = LinearRegression()
regressorNewYork6.fit(X_train_NewYorkAll6, y_train_NewYorkAll6)

pd.DataFrame(list(zip(X_train_NewYorkAll6, regressorNewYork6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewYork6 = regressorNewYork6.predict(X_train_NewYork6)

y_train_NewYorkAll7.loc[-1] = y_pred_NewYork6.item(0)  # adding a row
y_train_NewYorkAll7.index = y_train_NewYorkAll7.index + 1  # shifting index
y_train_NewYorkAll7 = y_train_NewYorkAll7.sort_index()
regressorNewYork7 = LinearRegression()
regressorNewYork7.fit(X_train_NewYorkAll7, y_train_NewYorkAll7)

pd.DataFrame(list(zip(X_train_NewYorkAll7, regressorNewYork7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewYork7 = regressorNewYork7.predict(X_train_NewYork7)

y_train_NewYorkAll8.loc[-1] = y_pred_NewYork7.item(0)  # adding a row
y_train_NewYorkAll8.index = y_train_NewYorkAll8.index + 1  # shifting index
y_train_NewYorkAll8 = y_train_NewYorkAll8.sort_index()
regressorNewYork8 = LinearRegression()
regressorNewYork8.fit(X_train_NewYorkAll8, y_train_NewYorkAll8)

pd.DataFrame(list(zip(X_train_NewYorkAll8, regressorNewYork8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewYork8 = regressorNewYork8.predict(X_train_NewYork8)

y_train_NewYorkAll9.loc[-1] = y_pred_NewYork8.item(0)  # adding a row
y_train_NewYorkAll9.index = y_train_NewYorkAll9.index + 1  # shifting index
y_train_NewYorkAll9 = y_train_NewYorkAll9.sort_index()
regressorNewYork9 = LinearRegression()
regressorNewYork9.fit(X_train_NewYorkAll9, y_train_NewYorkAll9)

pd.DataFrame(list(zip(X_train_NewYorkAll9, regressorNewYork9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewYork9 = regressorNewYork9.predict(X_train_NewYork9)

y_train_NewYorkAll10.loc[-1] = y_pred_NewYork9.item(0)  # adding a row
y_train_NewYorkAll10.index = y_train_NewYorkAll10.index + 1  # shifting index
y_train_NewYorkAll10 = y_train_NewYorkAll10.sort_index()
regressorNewYork10 = LinearRegression()
regressorNewYork10.fit(X_train_NewYorkAll10, y_train_NewYorkAll10)

pd.DataFrame(list(zip(X_train_NewYorkAll10, regressorNewYork10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewYork10 = regressorNewYork10.predict(X_train_NewYork10)

y_train_NewYorkAll11.loc[-1] = y_pred_NewYork10.item(0)  # adding a row
y_train_NewYorkAll11.index = y_train_NewYorkAll11.index + 1  # shifting index
y_train_NewYorkAll11 = y_train_NewYorkAll11.sort_index()
regressorNewYork11 = LinearRegression()
regressorNewYork11.fit(X_train_NewYorkAll11, y_train_NewYorkAll11)

pd.DataFrame(list(zip(X_train_NewYorkAll11, regressorNewYork11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewYork11 = regressorNewYork11.predict(X_train_NewYork11)

y_train_NewYorkAll12.loc[-1] = y_pred_NewYork11.item(0)  # adding a row
y_train_NewYorkAll12.index = y_train_NewYorkAll12.index + 1  # shifting index
y_train_NewYorkAll12 = y_train_NewYorkAll12.sort_index()
regressorNewYork12 = LinearRegression()
regressorNewYork12.fit(X_train_NewYorkAll12, y_train_NewYorkAll12)

pd.DataFrame(list(zip(X_train_NewYorkAll12, regressorNewYork12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewYork12 = regressorNewYork12.predict(X_train_NewYork12)

y_train_NewYorkAll13.loc[-1] = y_pred_NewYork12.item(0)  # adding a row
y_train_NewYorkAll13.index = y_train_NewYorkAll13.index + 1  # shifting index
y_train_NewYorkAll13 = y_train_NewYorkAll13.sort_index()
regressorNewYork13 = LinearRegression()
regressorNewYork13.fit(X_train_NewYorkAll13, y_train_NewYorkAll13)

pd.DataFrame(list(zip(X_train_NewYorkAll13, regressorNewYork13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewYork13 = regressorNewYork13.predict(X_train_NewYork13)

y_train_NewYorkAll14.loc[-1] = y_pred_NewYork13.item(0)  # adding a row
y_train_NewYorkAll14.index = y_train_NewYorkAll14.index + 1  # shifting index
y_train_NewYorkAll14 = y_train_NewYorkAll14.sort_index()
regressorNewYork14 = LinearRegression()
regressorNewYork14.fit(X_train_NewYorkAll14, y_train_NewYorkAll14)

pd.DataFrame(list(zip(X_train_NewYorkAll14, regressorNewYork14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewYork14 = regressorNewYork14.predict(X_train_NewYork14)

y_train_NewYorkAll15.loc[-1] = y_pred_NewYork14.item(0)  # adding a row
y_train_NewYorkAll15.index = y_train_NewYorkAll15.index + 1  # shifting index
y_train_NewYorkAll15 = y_train_NewYorkAll15.sort_index()
regressorNewYork15 = LinearRegression()
regressorNewYork15.fit(X_train_NewYorkAll15, y_train_NewYorkAll15)

pd.DataFrame(list(zip(X_train_NewYorkAll15, regressorNewYork15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewYork15 = regressorNewYork15.predict(X_train_NewYork15)

y_train_NewYorkAll16.loc[-1] = y_pred_NewYork15.item(0)  # adding a row
y_train_NewYorkAll16.index = y_train_NewYorkAll16.index + 1  # shifting index
y_train_NewYorkAll16 = y_train_NewYorkAll16.sort_index()
regressorNewYork16 = LinearRegression()
regressorNewYork16.fit(X_train_NewYorkAll16, y_train_NewYorkAll16)

pd.DataFrame(list(zip(X_train_NewYorkAll16, regressorNewYork16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewYork16 = regressorNewYork16.predict(X_train_NewYork16)

y_train_NewYorkAll17.loc[-1] = y_pred_NewYork16.item(0)  # adding a row
y_train_NewYorkAll17.index = y_train_NewYorkAll17.index + 1  # shifting index
y_train_NewYorkAll17 = y_train_NewYorkAll17.sort_index()
regressorNewYork17 = LinearRegression()
regressorNewYork17.fit(X_train_NewYorkAll17, y_train_NewYorkAll17)

pd.DataFrame(list(zip(X_train_NewYorkAll17, regressorNewYork17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewYork17 = regressorNewYork17.predict(X_train_NewYork17)

y_train_NewYorkAll18.loc[-1] = y_pred_NewYork17.item(0)  # adding a row
y_train_NewYorkAll18.index = y_train_NewYorkAll18.index + 1  # shifting index
y_train_NewYorkAll18 = y_train_NewYorkAll18.sort_index()
regressorNewYork18 = LinearRegression()
regressorNewYork18.fit(X_train_NewYorkAll18, y_train_NewYorkAll18)

pd.DataFrame(list(zip(X_train_NewYorkAll18, regressorNewYork18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewYork18 = regressorNewYork18.predict(X_train_NewYork18)

y_train_NewYorkAll19.loc[-1] = y_pred_NewYork18.item(0)  # adding a row
y_train_NewYorkAll19.index = y_train_NewYorkAll19.index + 1  # shifting index
y_train_NewYorkAll19 = y_train_NewYorkAll19.sort_index()
regressorNewYork19 = LinearRegression()
regressorNewYork19.fit(X_train_NewYorkAll19, y_train_NewYorkAll19)

pd.DataFrame(list(zip(X_train_NewYorkAll19, regressorNewYork19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewYork19 = regressorNewYork19.predict(X_train_NewYork19)

y_train_NewYorkAll20.loc[-1] = y_pred_NewYork19.item(0)  # adding a row
y_train_NewYorkAll20.index = y_train_NewYorkAll20.index + 1  # shifting index
y_train_NewYorkAll20 = y_train_NewYorkAll20.sort_index()
regressorNewYork20 = LinearRegression()
regressorNewYork20.fit(X_train_NewYorkAll20, y_train_NewYorkAll20)

pd.DataFrame(list(zip(X_train_NewYorkAll20, regressorNewYork20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewYork20 = regressorNewYork20.predict(X_train_NewYork20)

y_train_NewYorkAll21.loc[-1] = y_pred_NewYork20.item(0)  # adding a row
y_train_NewYorkAll21.index = y_train_NewYorkAll21.index + 1  # shifting index
y_train_NewYorkAll21 = y_train_NewYorkAll21.sort_index()
regressorNewYork21 = LinearRegression()
regressorNewYork21.fit(X_train_NewYorkAll21, y_train_NewYorkAll21)

pd.DataFrame(list(zip(X_train_NewYorkAll21, regressorNewYork21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_NewYork21 = regressorNewYork21.predict(X_train_NewYork21)

# %%
X_train_Brooklyn1=X_Brooklyn[0:1]
y_train_Brooklyn1=y_Brooklyn[0:1]
X_train_Brooklyn2=X_Brooklyn[1:2]
y_train_Brooklyn2=y_Brooklyn[1:2]
X_train_Brooklyn3=X_Brooklyn[2:3]
y_train_Brooklyn3=y_Brooklyn[2:3]
X_train_Brooklyn4=X_Brooklyn[3:4]
y_train_Brooklyn4=y_Brooklyn[3:4]
X_train_Brooklyn5=X_Brooklyn[4:5]
y_train_Brooklyn5=y_Brooklyn[4:5]
y_train_Brooklyn6=y_Brooklyn[5:6]
X_train_Brooklyn7=X_Brooklyn[7:8]
X_train_Brooklyn6=X_Brooklyn[5:6]
y_train_Brooklyn7=y_Brooklyn[7:8]
X_train_Brooklyn8=X_Brooklyn[8:9]
y_train_Brooklyn8=y_Brooklyn[8:9]
X_train_Brooklyn9=X_Brooklyn[9:10]
y_train_Brooklyn9=y_Brooklyn[9:10]
X_train_Brooklyn10=X_Brooklyn[10:11]
y_train_Brooklyn10=y_Brooklyn[10:11]
X_train_Brooklyn11=X_Brooklyn[11:12]
y_train_Brooklyn11=y_Brooklyn[11:12]
X_train_Brooklyn12=X_Brooklyn[12:13]
y_train_Brooklyn12=y_Brooklyn[12:13]
X_train_Brooklyn13=X_Brooklyn[13:14]
y_train_Brooklyn13=y_Brooklyn[13:14]
X_train_Brooklyn14=X_Brooklyn[14:15]
y_train_Brooklyn14=y_Brooklyn[14:15]
X_train_Brooklyn15=X_Brooklyn[15:16]
y_train_Brooklyn15=y_Brooklyn[15:16]
X_train_Brooklyn16=X_Brooklyn[16:17]
y_train_Brooklyn16=y_Brooklyn[16:17]
X_train_Brooklyn17=X_Brooklyn[17:18]
y_train_Brooklyn17=y_Brooklyn[17:18]
X_train_Brooklyn18=X_Brooklyn[18:19]
y_train_Brooklyn18=y_Brooklyn[18:19]
X_train_Brooklyn19=X_Brooklyn[19:20]
y_train_Brooklyn19=y_Brooklyn[19:20]
X_train_Brooklyn20=X_Brooklyn[20:21]
y_train_Brooklyn20=y_Brooklyn[20:21]
X_train_Brooklyn21=X_Brooklyn[21:22]
y_train_Brooklyn21=y_Brooklyn[21:22]
X_train_Brooklyn22=X_Brooklyn[22:23]
y_train_Brooklyn22=y_Brooklyn[22:23]


X_train_BrooklynAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,594,616,638],[5,11,18,19,20]]
y_train_BrooklynAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,594,616,638],24:25]

X_train_BrooklynAll2=df.iloc[[0,1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,375,397,419,441,463,485,507,529,551,595,617,639],[5,11,18,19,20]]
y_train_BrooklynAll2=df.iloc[[1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,375,397,419,441,463,485,507,529,551,595,617,639],24:25]

X_train_BrooklynAll3=df.iloc[[0,2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,376,398,420,442,464,486,508,530,552,596,618,640],[5,11,18,19,20]]
y_train_BrooklynAll3=df.iloc[[2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,376,398,420,442,464,486,508,530,552,596,618,640],24:25]

X_train_BrooklynAll4=df.iloc[[0,3,25,47,69,91,113,135,157,179,201,223,245,267,289,311,333,355,377,399,421,443,465,487,509,531,553,597,619,641],[5,11,18,19,20]]
y_train_BrooklynAll4=df.iloc[[3,25,47,69,91,113,135,158,179,201,223,245,267,289,311,333,355,377,399,421,443,465,487,509,531,553,597,619,641],24:25]

X_train_BrooklynAll5=df.iloc[[0,4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,378,400,422,444,466,488,510,532,554,598,620,642],[5,11,18,19,20]]
y_train_BrooklynAll5=df.iloc[[4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,378,400,422,444,466,488,510,532,554,598,620,642],24:25]

X_train_BrooklynAll6=df.iloc[[0,5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,379,401,423,445,467,489,511,533,555,599,621,643],[5,11,18,19,20]]
y_train_BrooklynAll6=df.iloc[[5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,379,401,423,445,467,489,511,533,555,599,621,643],24:25]

X_train_BrooklynAll7=df.iloc[[0,6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,380,402,424,446,468,490,512,534,556,600,622,644],[5,11,18,19,20]]
y_train_BrooklynAll7=df.iloc[[6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,380,402,424,446,468,490,512,534,556,600,622,644],24:25]

X_train_BrooklynAll8=df.iloc[[0,7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,381,403,425,447,469,491,513,535,557,601,623,645],[5,11,18,19,20]]
y_train_BrooklynAll8=df.iloc[[7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,381,403,425,447,469,491,513,535,557,601,623,645],24:25]

X_train_BrooklynAll9=df.iloc[[0,8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,382,404,426,448,470,492,514,536,558,602,624,646],[5,11,18,19,20]]
y_train_BrooklynAll9=df.iloc[[8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,382,404,426,448,470,492,514,536,558,602,624,646],24:25]

X_train_BrooklynAll10=df.iloc[[0,9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,383,405,427,449,471,493,515,537,559,603,625,647],[5,11,18,19,20]]
y_train_BrooklynAll10=df.iloc[[9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,383,405,427,449,471,493,515,537,559,603,625,647],24:25]

X_train_BrooklynAll11=df.iloc[[0,10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,384,406,428,450,472,494,516,538,560,604,626,648],[5,11,18,19,20]]
y_train_BrooklynAll11=df.iloc[[10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,384,406,428,450,472,494,516,538,560,604,626,648],24:25]

X_train_BrooklynAll12=df.iloc[[0,11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,385,407,429,451,473,495,517,539,561,605,627,649],[5,11,18,19,20]]
y_train_BrooklynAll12=df.iloc[[11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,385,407,429,451,473,495,517,539,561,605,627,649],24:25]

X_train_BrooklynAll13=df.iloc[[0,12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,386,408,430,452,474,496,518,540,562,606,628,650],[5,11,18,19,20]]
y_train_BrooklynAll13=df.iloc[[12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,386,408,430,452,474,496,518,540,562,606,628,650],24:25]

X_train_BrooklynAll14=df.iloc[[0,13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,387,409,431,453,475,497,519,541,563,607,629,651],[5,11,18,19,20]]
y_train_BrooklynAll14=df.iloc[[13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,387,409,431,453,475,497,519,541,563,607,629,651],24:25]

X_train_BrooklynAll15=df.iloc[[0,14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,388,410,432,454,476,498,520,542,564,608,630,652],[5,11,18,19,20]]
y_train_BrooklynAll15=df.iloc[[14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,388,410,432,454,476,498,520,542,564,608,630,652],24:25]

X_train_BrooklynAll16=df.iloc[[0,15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,389,411,433,455,477,499,521,543,565,609,631,653],[5,11,18,19,20]]
y_train_BrooklynAll16=df.iloc[[15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,389,411,433,455,477,499,521,543,565,609,631,653],24:25]

X_train_BrooklynAll17=df.iloc[[0,16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,390,412,434,456,478,500,522,544,566,610,632,654],[5,11,18,19,20]]
y_train_BrooklynAll17=df.iloc[[16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,390,412,434,456,478,500,522,544,566,610,632,654],24:25]

X_train_BrooklynAll18=df.iloc[[0,17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,391,413,435,457,479,501,523,545,567,611,633,655],[5,11,18,19,20]]
y_train_BrooklynAll18=df.iloc[[17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,391,413,435,457,479,501,523,545,567,611,633,655],24:25]

X_train_BrooklynAll19=df.iloc[[0,18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,392,414,436,458,480,502,524,546,568,612,634,656],[5,11,18,19,20]]
y_train_BrooklynAll19=df.iloc[[18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,392,414,436,458,480,502,524,546,568,612,634,656],24:25]

X_train_BrooklynAll20=df.iloc[[0,19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,393,415,437,459,481,503,525,547,569,613,635,657],[5,11,18,19,20]]
y_train_BrooklynAll20=df.iloc[[19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,393,415,437,459,481,503,525,547,569,613,635,657],24:25]

X_train_BrooklynAll21=df.iloc[[0,20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,394,416,438,460,482,504,526,548,570,614,636,658],[5,11,18,19,20]]
y_train_BrooklynAll21=df.iloc[[20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,394,416,438,460,482,504,526,548,570,614,636,658],24:25]

X_train_BrooklynAll22=df.iloc[[0,21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,395,417,439,461,483,505,527,549,571,615,637,659],[5,11,18,19,20]]
y_train_BrooklynAll22=df.iloc[[21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,395,417,439,461,483,505,527,549,571,615,637,659],24:25]

# %%
regressorBrooklyn1 = LinearRegression()
regressorBrooklyn1.fit(X_train_BrooklynAll1, y_train_BrooklynAll1)
pd.DataFrame(list(zip(X_train_BrooklynAll1, regressorBrooklyn1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_Brooklyn1 = regressorBrooklyn1.predict(X_train_Brooklyn1)

# %%
y_train_BrooklynAll2.loc[-1] = y_pred_Brooklyn1.item(0)  # adding a row
y_train_BrooklynAll2.index = y_train_BrooklynAll2.index + 1  # shifting index
y_train_BrooklynAll2 = y_train_BrooklynAll2.sort_index()
regressorBrooklyn2 = LinearRegression()
regressorBrooklyn2.fit(X_train_BrooklynAll2, y_train_BrooklynAll2)

pd.DataFrame(list(zip(X_train_BrooklynAll2, regressorBrooklyn2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Brooklyn2 = regressorBrooklyn2.predict(X_train_Brooklyn2)

y_train_BrooklynAll3.loc[-1] = y_pred_Brooklyn2.item(0)  # adding a row
y_train_BrooklynAll3.index = y_train_BrooklynAll3.index + 1  # shifting index
y_train_BrooklynAll3 = y_train_BrooklynAll3.sort_index()
regressorBrooklyn3 = LinearRegression()
regressorBrooklyn3.fit(X_train_BrooklynAll3, y_train_BrooklynAll3)

pd.DataFrame(list(zip(X_train_BrooklynAll3, regressorBrooklyn3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Brooklyn3 = regressorBrooklyn3.predict(X_train_Brooklyn3)

y_train_BrooklynAll4.loc[-1] = y_pred_Brooklyn3.item(0)  # adding a row
y_train_BrooklynAll4.index = y_train_BrooklynAll4.index + 1  # shifting index
y_train_BrooklynAll4 = y_train_BrooklynAll4.sort_index()
regressorBrooklyn4 = LinearRegression()
regressorBrooklyn4.fit(X_train_BrooklynAll4, y_train_BrooklynAll4)

pd.DataFrame(list(zip(X_train_BrooklynAll4, regressorBrooklyn4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Brooklyn4 = regressorBrooklyn4.predict(X_train_Brooklyn4)

y_train_BrooklynAll5.loc[-1] = y_pred_Brooklyn4.item(0)  # adding a row
y_train_BrooklynAll5.index = y_train_BrooklynAll5.index + 1  # shifting index
y_train_BrooklynAll5 = y_train_BrooklynAll5.sort_index()
regressorBrooklyn5 = LinearRegression()
regressorBrooklyn5.fit(X_train_BrooklynAll5, y_train_BrooklynAll5)

pd.DataFrame(list(zip(X_train_BrooklynAll5, regressorBrooklyn5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Brooklyn5 = regressorBrooklyn5.predict(X_train_Brooklyn5)

y_train_BrooklynAll6.loc[-1] = y_pred_Brooklyn5.item(0)  # adding a row
y_train_BrooklynAll6.index = y_train_BrooklynAll6.index + 1  # shifting index
y_train_BrooklynAll6 = y_train_BrooklynAll6.sort_index()
regressorBrooklyn6 = LinearRegression()
regressorBrooklyn6.fit(X_train_BrooklynAll6, y_train_BrooklynAll6)

pd.DataFrame(list(zip(X_train_BrooklynAll6, regressorBrooklyn6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Brooklyn6 = regressorBrooklyn6.predict(X_train_Brooklyn6)

y_train_BrooklynAll7.loc[-1] = y_pred_Brooklyn6.item(0)  # adding a row
y_train_BrooklynAll7.index = y_train_BrooklynAll7.index + 1  # shifting index
y_train_BrooklynAll7 = y_train_BrooklynAll7.sort_index()
regressorBrooklyn7 = LinearRegression()
regressorBrooklyn7.fit(X_train_BrooklynAll7, y_train_BrooklynAll7)

pd.DataFrame(list(zip(X_train_BrooklynAll7, regressorBrooklyn7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Brooklyn7 = regressorBrooklyn7.predict(X_train_Brooklyn7)

y_train_BrooklynAll8.loc[-1] = y_pred_Brooklyn7.item(0)  # adding a row
y_train_BrooklynAll8.index = y_train_BrooklynAll8.index + 1  # shifting index
y_train_BrooklynAll8 = y_train_BrooklynAll8.sort_index()
regressorBrooklyn8 = LinearRegression()
regressorBrooklyn8.fit(X_train_BrooklynAll8, y_train_BrooklynAll8)

pd.DataFrame(list(zip(X_train_BrooklynAll8, regressorBrooklyn8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Brooklyn8 = regressorBrooklyn8.predict(X_train_Brooklyn8)

y_train_BrooklynAll9.loc[-1] = y_pred_Brooklyn8.item(0)  # adding a row
y_train_BrooklynAll9.index = y_train_BrooklynAll9.index + 1  # shifting index
y_train_BrooklynAll9 = y_train_BrooklynAll9.sort_index()
regressorBrooklyn9 = LinearRegression()
regressorBrooklyn9.fit(X_train_BrooklynAll9, y_train_BrooklynAll9)

pd.DataFrame(list(zip(X_train_BrooklynAll9, regressorBrooklyn9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Brooklyn9 = regressorBrooklyn9.predict(X_train_Brooklyn9)

y_train_BrooklynAll10.loc[-1] = y_pred_Brooklyn9.item(0)  # adding a row
y_train_BrooklynAll10.index = y_train_BrooklynAll10.index + 1  # shifting index
y_train_BrooklynAll10 = y_train_BrooklynAll10.sort_index()
regressorBrooklyn10 = LinearRegression()
regressorBrooklyn10.fit(X_train_BrooklynAll10, y_train_BrooklynAll10)

pd.DataFrame(list(zip(X_train_BrooklynAll10, regressorBrooklyn10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Brooklyn10 = regressorBrooklyn10.predict(X_train_Brooklyn10)

y_train_BrooklynAll11.loc[-1] = y_pred_Brooklyn10.item(0)  # adding a row
y_train_BrooklynAll11.index = y_train_BrooklynAll11.index + 1  # shifting index
y_train_BrooklynAll11 = y_train_BrooklynAll11.sort_index()
regressorBrooklyn11 = LinearRegression()
regressorBrooklyn11.fit(X_train_BrooklynAll11, y_train_BrooklynAll11)

pd.DataFrame(list(zip(X_train_BrooklynAll11, regressorBrooklyn11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Brooklyn11 = regressorBrooklyn11.predict(X_train_Brooklyn11)

y_train_BrooklynAll12.loc[-1] = y_pred_Brooklyn11.item(0)  # adding a row
y_train_BrooklynAll12.index = y_train_BrooklynAll12.index + 1  # shifting index
y_train_BrooklynAll12 = y_train_BrooklynAll12.sort_index()
regressorBrooklyn12 = LinearRegression()
regressorBrooklyn12.fit(X_train_BrooklynAll12, y_train_BrooklynAll12)

pd.DataFrame(list(zip(X_train_BrooklynAll12, regressorBrooklyn12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Brooklyn12 = regressorBrooklyn12.predict(X_train_Brooklyn12)

y_train_BrooklynAll13.loc[-1] = y_pred_Brooklyn12.item(0)  # adding a row
y_train_BrooklynAll13.index = y_train_BrooklynAll13.index + 1  # shifting index
y_train_BrooklynAll13 = y_train_BrooklynAll13.sort_index()
regressorBrooklyn13 = LinearRegression()
regressorBrooklyn13.fit(X_train_BrooklynAll13, y_train_BrooklynAll13)

pd.DataFrame(list(zip(X_train_BrooklynAll13, regressorBrooklyn13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Brooklyn13 = regressorBrooklyn13.predict(X_train_Brooklyn13)

y_train_BrooklynAll14.loc[-1] = y_pred_Brooklyn13.item(0)  # adding a row
y_train_BrooklynAll14.index = y_train_BrooklynAll14.index + 1  # shifting index
y_train_BrooklynAll14 = y_train_BrooklynAll14.sort_index()
regressorBrooklyn14 = LinearRegression()
regressorBrooklyn14.fit(X_train_BrooklynAll14, y_train_BrooklynAll14)

pd.DataFrame(list(zip(X_train_BrooklynAll14, regressorBrooklyn14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Brooklyn14 = regressorBrooklyn14.predict(X_train_Brooklyn14)

y_train_BrooklynAll15.loc[-1] = y_pred_Brooklyn14.item(0)  # adding a row
y_train_BrooklynAll15.index = y_train_BrooklynAll15.index + 1  # shifting index
y_train_BrooklynAll15 = y_train_BrooklynAll15.sort_index()
regressorBrooklyn15 = LinearRegression()
regressorBrooklyn15.fit(X_train_BrooklynAll15, y_train_BrooklynAll15)

pd.DataFrame(list(zip(X_train_BrooklynAll15, regressorBrooklyn15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Brooklyn15 = regressorBrooklyn15.predict(X_train_Brooklyn15)

y_train_BrooklynAll16.loc[-1] = y_pred_Brooklyn15.item(0)  # adding a row
y_train_BrooklynAll16.index = y_train_BrooklynAll16.index + 1  # shifting index
y_train_BrooklynAll16 = y_train_BrooklynAll16.sort_index()
regressorBrooklyn16 = LinearRegression()
regressorBrooklyn16.fit(X_train_BrooklynAll16, y_train_BrooklynAll16)

pd.DataFrame(list(zip(X_train_BrooklynAll16, regressorBrooklyn16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Brooklyn16 = regressorBrooklyn16.predict(X_train_Brooklyn16)

y_train_BrooklynAll17.loc[-1] = y_pred_Brooklyn16.item(0)  # adding a row
y_train_BrooklynAll17.index = y_train_BrooklynAll17.index + 1  # shifting index
y_train_BrooklynAll17 = y_train_BrooklynAll17.sort_index()
regressorBrooklyn17 = LinearRegression()
regressorBrooklyn17.fit(X_train_BrooklynAll17, y_train_BrooklynAll17)

pd.DataFrame(list(zip(X_train_BrooklynAll17, regressorBrooklyn17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Brooklyn17 = regressorBrooklyn17.predict(X_train_Brooklyn17)

y_train_BrooklynAll18.loc[-1] = y_pred_Brooklyn17.item(0)  # adding a row
y_train_BrooklynAll18.index = y_train_BrooklynAll18.index + 1  # shifting index
y_train_BrooklynAll18 = y_train_BrooklynAll18.sort_index()
regressorBrooklyn18 = LinearRegression()
regressorBrooklyn18.fit(X_train_BrooklynAll18, y_train_BrooklynAll18)

pd.DataFrame(list(zip(X_train_BrooklynAll18, regressorBrooklyn18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Brooklyn18 = regressorBrooklyn18.predict(X_train_Brooklyn18)

y_train_BrooklynAll19.loc[-1] = y_pred_Brooklyn18.item(0)  # adding a row
y_train_BrooklynAll19.index = y_train_BrooklynAll19.index + 1  # shifting index
y_train_BrooklynAll19 = y_train_BrooklynAll19.sort_index()
regressorBrooklyn19 = LinearRegression()
regressorBrooklyn19.fit(X_train_BrooklynAll19, y_train_BrooklynAll19)

pd.DataFrame(list(zip(X_train_BrooklynAll19, regressorBrooklyn19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Brooklyn19 = regressorBrooklyn19.predict(X_train_Brooklyn19)

y_train_BrooklynAll20.loc[-1] = y_pred_Brooklyn19.item(0)  # adding a row
y_train_BrooklynAll20.index = y_train_BrooklynAll20.index + 1  # shifting index
y_train_BrooklynAll20 = y_train_BrooklynAll20.sort_index()
regressorBrooklyn20 = LinearRegression()
regressorBrooklyn20.fit(X_train_BrooklynAll20, y_train_BrooklynAll20)

pd.DataFrame(list(zip(X_train_BrooklynAll20, regressorBrooklyn20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Brooklyn20 = regressorBrooklyn20.predict(X_train_Brooklyn20)

y_train_BrooklynAll21.loc[-1] = y_pred_Brooklyn20.item(0)  # adding a row
y_train_BrooklynAll21.index = y_train_BrooklynAll21.index + 1  # shifting index
y_train_BrooklynAll21 = y_train_BrooklynAll21.sort_index()
regressorBrooklyn21 = LinearRegression()
regressorBrooklyn21.fit(X_train_BrooklynAll21, y_train_BrooklynAll21)

pd.DataFrame(list(zip(X_train_BrooklynAll21, regressorBrooklyn21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Brooklyn21 = regressorBrooklyn21.predict(X_train_Brooklyn21)

# %%
X_train_Chicago1=X_Chicago[0:1]
y_train_Chicago1=y_Chicago[0:1]
X_train_Chicago2=X_Chicago[1:2]
y_train_Chicago2=y_Chicago[1:2]
X_train_Chicago3=X_Chicago[2:3]
y_train_Chicago3=y_Chicago[2:3]
X_train_Chicago4=X_Chicago[3:4]
y_train_Chicago4=y_Chicago[3:4]
X_train_Chicago5=X_Chicago[4:5]
y_train_Chicago5=y_Chicago[4:5]
y_train_Chicago6=y_Chicago[5:6]
X_train_Chicago7=X_Chicago[7:8]
X_train_Chicago6=X_Chicago[5:6]
y_train_Chicago7=y_Chicago[7:8]
X_train_Chicago8=X_Chicago[8:9]
y_train_Chicago8=y_Chicago[8:9]
X_train_Chicago9=X_Chicago[9:10]
y_train_Chicago9=y_Chicago[9:10]
X_train_Chicago10=X_Chicago[10:11]
y_train_Chicago10=y_Chicago[10:11]
X_train_Chicago11=X_Chicago[11:12]
y_train_Chicago11=y_Chicago[11:12]
X_train_Chicago12=X_Chicago[12:13]
y_train_Chicago12=y_Chicago[12:13]
X_train_Chicago13=X_Chicago[13:14]
y_train_Chicago13=y_Chicago[13:14]
X_train_Chicago14=X_Chicago[14:15]
y_train_Chicago14=y_Chicago[14:15]
X_train_Chicago15=X_Chicago[15:16]
y_train_Chicago15=y_Chicago[15:16]
X_train_Chicago16=X_Chicago[16:17]
y_train_Chicago16=y_Chicago[16:17]
X_train_Chicago17=X_Chicago[17:18]
y_train_Chicago17=y_Chicago[17:18]
X_train_Chicago18=X_Chicago[18:19]
y_train_Chicago18=y_Chicago[18:19]
X_train_Chicago19=X_Chicago[19:20]
y_train_Chicago19=y_Chicago[19:20]
X_train_Chicago20=X_Chicago[20:21]
y_train_Chicago20=y_Chicago[20:21]
X_train_Chicago21=X_Chicago[21:22]
y_train_Chicago21=y_Chicago[21:22]
X_train_Chicago22=X_Chicago[22:23]
y_train_Chicago22=y_Chicago[22:23]


X_train_ChicagoAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,616,638],[5,11,18,19,20]]
y_train_ChicagoAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,616,638],24:25]

X_train_ChicagoAll2=df.iloc[[0,1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,375,397,419,441,463,485,507,529,551,573,617,639],[5,11,18,19,20]]
y_train_ChicagoAll2=df.iloc[[1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,375,397,419,441,463,485,507,529,551,573,617,639],24:25]

X_train_ChicagoAll3=df.iloc[[0,2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,376,398,420,442,464,486,508,530,552,574,618,640],[5,11,18,19,20]]
y_train_ChicagoAll3=df.iloc[[2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,376,398,420,442,464,486,508,530,552,574,618,640],24:25]

X_train_ChicagoAll4=df.iloc[[0,3,25,47,69,91,113,135,157,179,201,223,245,267,289,311,333,355,377,399,421,443,465,487,509,531,553,575,619,641],[5,11,18,19,20]]
y_train_ChicagoAll4=df.iloc[[3,25,47,69,91,113,135,158,179,201,223,245,267,289,311,333,355,377,399,421,443,465,487,509,531,553,575,619,641],24:25]

X_train_ChicagoAll5=df.iloc[[0,4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,378,400,422,444,466,488,510,532,554,576,620,642],[5,11,18,19,20]]
y_train_ChicagoAll5=df.iloc[[4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,378,400,422,444,466,488,510,532,554,576,620,642],24:25]

X_train_ChicagoAll6=df.iloc[[0,5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,379,401,423,445,467,489,511,533,555,577,621,643],[5,11,18,19,20]]
y_train_ChicagoAll6=df.iloc[[5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,379,401,423,445,467,489,511,533,555,577,621,643],24:25]

X_train_ChicagoAll7=df.iloc[[0,6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,380,402,424,446,468,490,512,534,556,578,622,644],[5,11,18,19,20]]
y_train_ChicagoAll7=df.iloc[[6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,380,402,424,446,468,490,512,534,556,578,622,644],24:25]

X_train_ChicagoAll8=df.iloc[[0,7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,381,403,425,447,469,491,513,535,557,579,623,645],[5,11,18,19,20]]
y_train_ChicagoAll8=df.iloc[[7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,381,403,425,447,469,491,513,535,557,579,623,645],24:25]

X_train_ChicagoAll9=df.iloc[[0,8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,382,404,426,448,470,492,514,536,558,580,624,646],[5,11,18,19,20]]
y_train_ChicagoAll9=df.iloc[[8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,382,404,426,448,470,492,514,536,558,580,624,646],24:25]

X_train_ChicagoAll10=df.iloc[[0,9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,383,405,427,449,471,493,515,537,559,581,625,647],[5,11,18,19,20]]
y_train_ChicagoAll10=df.iloc[[9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,383,405,427,449,471,493,515,537,559,581,625,647],24:25]

X_train_ChicagoAll11=df.iloc[[0,10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,384,406,428,450,472,494,516,538,560,582,626,648],[5,11,18,19,20]]
y_train_ChicagoAll11=df.iloc[[10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,384,406,428,450,472,494,516,538,560,582,626,648],24:25]

X_train_ChicagoAll12=df.iloc[[0,11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,385,407,429,451,473,495,517,539,561,583,627,649],[5,11,18,19,20]]
y_train_ChicagoAll12=df.iloc[[11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,385,407,429,451,473,495,517,539,561,583,627,649],24:25]

X_train_ChicagoAll13=df.iloc[[0,12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,386,408,430,452,474,496,518,540,562,584,628,650],[5,11,18,19,20]]
y_train_ChicagoAll13=df.iloc[[12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,386,408,430,452,474,496,518,540,562,584,628,650],24:25]

X_train_ChicagoAll14=df.iloc[[0,13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,387,409,431,453,475,497,519,541,563,585,629,651],[5,11,18,19,20]]
y_train_ChicagoAll14=df.iloc[[13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,387,409,431,453,475,497,519,541,563,585,629,651],24:25]

X_train_ChicagoAll15=df.iloc[[0,14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,388,410,432,454,476,498,520,542,564,586,630,652],[5,11,18,19,20]]
y_train_ChicagoAll15=df.iloc[[14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,388,410,432,454,476,498,520,542,564,586,630,652],24:25]

X_train_ChicagoAll16=df.iloc[[0,15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,389,411,433,455,477,499,521,543,565,587,631,653],[5,11,18,19,20]]
y_train_ChicagoAll16=df.iloc[[15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,389,411,433,455,477,499,521,543,565,587,631,653],24:25]

X_train_ChicagoAll17=df.iloc[[0,16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,390,412,434,456,478,500,522,544,566,588,632,654],[5,11,18,19,20]]
y_train_ChicagoAll17=df.iloc[[16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,390,412,434,456,478,500,522,544,566,588,632,654],24:25]

X_train_ChicagoAll18=df.iloc[[0,17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,391,413,435,457,479,501,523,545,567,589,633,655],[5,11,18,19,20]]
y_train_ChicagoAll18=df.iloc[[17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,391,413,435,457,479,501,523,545,567,589,633,655],24:25]

X_train_ChicagoAll19=df.iloc[[0,18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,392,414,436,458,480,502,524,546,568,590,634,656],[5,11,18,19,20]]
y_train_ChicagoAll19=df.iloc[[18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,392,414,436,458,480,502,524,546,568,590,634,656],24:25]

X_train_ChicagoAll20=df.iloc[[0,19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,393,415,437,459,481,503,525,547,569,591,635,657],[5,11,18,19,20]]
y_train_ChicagoAll20=df.iloc[[19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,393,415,437,459,481,503,525,547,569,591,635,657],24:25]

X_train_ChicagoAll21=df.iloc[[0,20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,394,416,438,460,482,504,526,548,570,592,636,658],[5,11,18,19,20]]
y_train_ChicagoAll21=df.iloc[[20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,394,416,438,460,482,504,526,548,570,592,636,658],24:25]

X_train_ChicagoAll22=df.iloc[[0,21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,395,417,439,461,483,505,527,549,571,593,637,659],[5,11,18,19,20]]
y_train_ChicagoAll22=df.iloc[[21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,395,417,439,461,483,505,527,549,571,593,637,659],24:25]

# %%
regressorChicago1 = LinearRegression()
regressorChicago1.fit(X_train_ChicagoAll1, y_train_ChicagoAll1)
pd.DataFrame(list(zip(X_train_ChicagoAll1, regressorChicago1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_Chicago1 = regressorChicago1.predict(X_train_Chicago1)

# %%
y_train_ChicagoAll2.loc[-1] = y_pred_Chicago1.item(0)  # adding a row
y_train_ChicagoAll2.index = y_train_ChicagoAll2.index + 1  # shifting index
y_train_ChicagoAll2 = y_train_ChicagoAll2.sort_index()
regressorChicago2 = LinearRegression()
regressorChicago2.fit(X_train_ChicagoAll2, y_train_ChicagoAll2)

pd.DataFrame(list(zip(X_train_ChicagoAll2, regressorChicago2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Chicago2 = regressorChicago2.predict(X_train_Chicago2)

y_train_ChicagoAll3.loc[-1] = y_pred_Chicago2.item(0)  # adding a row
y_train_ChicagoAll3.index = y_train_ChicagoAll3.index + 1  # shifting index
y_train_ChicagoAll3 = y_train_ChicagoAll3.sort_index()
regressorChicago3 = LinearRegression()
regressorChicago3.fit(X_train_ChicagoAll3, y_train_ChicagoAll3)

pd.DataFrame(list(zip(X_train_ChicagoAll3, regressorChicago3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Chicago3 = regressorChicago3.predict(X_train_Chicago3)

y_train_ChicagoAll4.loc[-1] = y_pred_Chicago3.item(0)  # adding a row
y_train_ChicagoAll4.index = y_train_ChicagoAll4.index + 1  # shifting index
y_train_ChicagoAll4 = y_train_ChicagoAll4.sort_index()
regressorChicago4 = LinearRegression()
regressorChicago4.fit(X_train_ChicagoAll4, y_train_ChicagoAll4)

pd.DataFrame(list(zip(X_train_ChicagoAll4, regressorChicago4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Chicago4 = regressorChicago4.predict(X_train_Chicago4)

y_train_ChicagoAll5.loc[-1] = y_pred_Chicago4.item(0)  # adding a row
y_train_ChicagoAll5.index = y_train_ChicagoAll5.index + 1  # shifting index
y_train_ChicagoAll5 = y_train_ChicagoAll5.sort_index()
regressorChicago5 = LinearRegression()
regressorChicago5.fit(X_train_ChicagoAll5, y_train_ChicagoAll5)

pd.DataFrame(list(zip(X_train_ChicagoAll5, regressorChicago5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Chicago5 = regressorChicago5.predict(X_train_Chicago5)

y_train_ChicagoAll6.loc[-1] = y_pred_Chicago5.item(0)  # adding a row
y_train_ChicagoAll6.index = y_train_ChicagoAll6.index + 1  # shifting index
y_train_ChicagoAll6 = y_train_ChicagoAll6.sort_index()
regressorChicago6 = LinearRegression()
regressorChicago6.fit(X_train_ChicagoAll6, y_train_ChicagoAll6)

pd.DataFrame(list(zip(X_train_ChicagoAll6, regressorChicago6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Chicago6 = regressorChicago6.predict(X_train_Chicago6)

y_train_ChicagoAll7.loc[-1] = y_pred_Chicago6.item(0)  # adding a row
y_train_ChicagoAll7.index = y_train_ChicagoAll7.index + 1  # shifting index
y_train_ChicagoAll7 = y_train_ChicagoAll7.sort_index()
regressorChicago7 = LinearRegression()
regressorChicago7.fit(X_train_ChicagoAll7, y_train_ChicagoAll7)

pd.DataFrame(list(zip(X_train_ChicagoAll7, regressorChicago7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Chicago7 = regressorChicago7.predict(X_train_Chicago7)

y_train_ChicagoAll8.loc[-1] = y_pred_Chicago7.item(0)  # adding a row
y_train_ChicagoAll8.index = y_train_ChicagoAll8.index + 1  # shifting index
y_train_ChicagoAll8 = y_train_ChicagoAll8.sort_index()
regressorChicago8 = LinearRegression()
regressorChicago8.fit(X_train_ChicagoAll8, y_train_ChicagoAll8)

pd.DataFrame(list(zip(X_train_ChicagoAll8, regressorChicago8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Chicago8 = regressorChicago8.predict(X_train_Chicago8)

y_train_ChicagoAll9.loc[-1] = y_pred_Chicago8.item(0)  # adding a row
y_train_ChicagoAll9.index = y_train_ChicagoAll9.index + 1  # shifting index
y_train_ChicagoAll9 = y_train_ChicagoAll9.sort_index()
regressorChicago9 = LinearRegression()
regressorChicago9.fit(X_train_ChicagoAll9, y_train_ChicagoAll9)

pd.DataFrame(list(zip(X_train_ChicagoAll9, regressorChicago9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Chicago9 = regressorChicago9.predict(X_train_Chicago9)

y_train_ChicagoAll10.loc[-1] = y_pred_Chicago9.item(0)  # adding a row
y_train_ChicagoAll10.index = y_train_ChicagoAll10.index + 1  # shifting index
y_train_ChicagoAll10 = y_train_ChicagoAll10.sort_index()
regressorChicago10 = LinearRegression()
regressorChicago10.fit(X_train_ChicagoAll10, y_train_ChicagoAll10)

pd.DataFrame(list(zip(X_train_ChicagoAll10, regressorChicago10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Chicago10 = regressorChicago10.predict(X_train_Chicago10)

y_train_ChicagoAll11.loc[-1] = y_pred_Chicago10.item(0)  # adding a row
y_train_ChicagoAll11.index = y_train_ChicagoAll11.index + 1  # shifting index
y_train_ChicagoAll11 = y_train_ChicagoAll11.sort_index()
regressorChicago11 = LinearRegression()
regressorChicago11.fit(X_train_ChicagoAll11, y_train_ChicagoAll11)

pd.DataFrame(list(zip(X_train_ChicagoAll11, regressorChicago11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Chicago11 = regressorChicago11.predict(X_train_Chicago11)

y_train_ChicagoAll12.loc[-1] = y_pred_Chicago11.item(0)  # adding a row
y_train_ChicagoAll12.index = y_train_ChicagoAll12.index + 1  # shifting index
y_train_ChicagoAll12 = y_train_ChicagoAll12.sort_index()
regressorChicago12 = LinearRegression()
regressorChicago12.fit(X_train_ChicagoAll12, y_train_ChicagoAll12)

pd.DataFrame(list(zip(X_train_ChicagoAll12, regressorChicago12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Chicago12 = regressorChicago12.predict(X_train_Chicago12)

y_train_ChicagoAll13.loc[-1] = y_pred_Chicago12.item(0)  # adding a row
y_train_ChicagoAll13.index = y_train_ChicagoAll13.index + 1  # shifting index
y_train_ChicagoAll13 = y_train_ChicagoAll13.sort_index()
regressorChicago13 = LinearRegression()
regressorChicago13.fit(X_train_ChicagoAll13, y_train_ChicagoAll13)

pd.DataFrame(list(zip(X_train_ChicagoAll13, regressorChicago13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Chicago13 = regressorChicago13.predict(X_train_Chicago13)

y_train_ChicagoAll14.loc[-1] = y_pred_Chicago13.item(0)  # adding a row
y_train_ChicagoAll14.index = y_train_ChicagoAll14.index + 1  # shifting index
y_train_ChicagoAll14 = y_train_ChicagoAll14.sort_index()
regressorChicago14 = LinearRegression()
regressorChicago14.fit(X_train_ChicagoAll14, y_train_ChicagoAll14)

pd.DataFrame(list(zip(X_train_ChicagoAll14, regressorChicago14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Chicago14 = regressorChicago14.predict(X_train_Chicago14)

y_train_ChicagoAll15.loc[-1] = y_pred_Chicago14.item(0)  # adding a row
y_train_ChicagoAll15.index = y_train_ChicagoAll15.index + 1  # shifting index
y_train_ChicagoAll15 = y_train_ChicagoAll15.sort_index()
regressorChicago15 = LinearRegression()
regressorChicago15.fit(X_train_ChicagoAll15, y_train_ChicagoAll15)

pd.DataFrame(list(zip(X_train_ChicagoAll15, regressorChicago15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Chicago15 = regressorChicago15.predict(X_train_Chicago15)

y_train_ChicagoAll16.loc[-1] = y_pred_Chicago15.item(0)  # adding a row
y_train_ChicagoAll16.index = y_train_ChicagoAll16.index + 1  # shifting index
y_train_ChicagoAll16 = y_train_ChicagoAll16.sort_index()
regressorChicago16 = LinearRegression()
regressorChicago16.fit(X_train_ChicagoAll16, y_train_ChicagoAll16)

pd.DataFrame(list(zip(X_train_ChicagoAll16, regressorChicago16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Chicago16 = regressorChicago16.predict(X_train_Chicago16)

y_train_ChicagoAll17.loc[-1] = y_pred_Chicago16.item(0)  # adding a row
y_train_ChicagoAll17.index = y_train_ChicagoAll17.index + 1  # shifting index
y_train_ChicagoAll17 = y_train_ChicagoAll17.sort_index()
regressorChicago17 = LinearRegression()
regressorChicago17.fit(X_train_ChicagoAll17, y_train_ChicagoAll17)

pd.DataFrame(list(zip(X_train_ChicagoAll17, regressorChicago17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Chicago17 = regressorChicago17.predict(X_train_Chicago17)

y_train_ChicagoAll18.loc[-1] = y_pred_Chicago17.item(0)  # adding a row
y_train_ChicagoAll18.index = y_train_ChicagoAll18.index + 1  # shifting index
y_train_ChicagoAll18 = y_train_ChicagoAll18.sort_index()
regressorChicago18 = LinearRegression()
regressorChicago18.fit(X_train_ChicagoAll18, y_train_ChicagoAll18)

pd.DataFrame(list(zip(X_train_ChicagoAll18, regressorChicago18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Chicago18 = regressorChicago18.predict(X_train_Chicago18)

y_train_ChicagoAll19.loc[-1] = y_pred_Chicago18.item(0)  # adding a row
y_train_ChicagoAll19.index = y_train_ChicagoAll19.index + 1  # shifting index
y_train_ChicagoAll19 = y_train_ChicagoAll19.sort_index()
regressorChicago19 = LinearRegression()
regressorChicago19.fit(X_train_ChicagoAll19, y_train_ChicagoAll19)

pd.DataFrame(list(zip(X_train_ChicagoAll19, regressorChicago19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Chicago19 = regressorChicago19.predict(X_train_Chicago19)

y_train_ChicagoAll20.loc[-1] = y_pred_Chicago19.item(0)  # adding a row
y_train_ChicagoAll20.index = y_train_ChicagoAll20.index + 1  # shifting index
y_train_ChicagoAll20 = y_train_ChicagoAll20.sort_index()
regressorChicago20 = LinearRegression()
regressorChicago20.fit(X_train_ChicagoAll20, y_train_ChicagoAll20)

pd.DataFrame(list(zip(X_train_ChicagoAll20, regressorChicago20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Chicago20 = regressorChicago20.predict(X_train_Chicago20)

y_train_ChicagoAll21.loc[-1] = y_pred_Chicago20.item(0)  # adding a row
y_train_ChicagoAll21.index = y_train_ChicagoAll21.index + 1  # shifting index
y_train_ChicagoAll21 = y_train_ChicagoAll21.sort_index()
regressorChicago21 = LinearRegression()
regressorChicago21.fit(X_train_ChicagoAll21, y_train_ChicagoAll21)

pd.DataFrame(list(zip(X_train_ChicagoAll21, regressorChicago21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Chicago21 = regressorChicago21.predict(X_train_Chicago21)

# %%
X_train_Orlando1=X_Orlando[0:1]
y_train_Orlando1=y_Orlando[0:1]
X_train_Orlando2=X_Orlando[1:2]
y_train_Orlando2=y_Orlando[1:2]
X_train_Orlando3=X_Orlando[2:3]
y_train_Orlando3=y_Orlando[2:3]
X_train_Orlando4=X_Orlando[3:4]
y_train_Orlando4=y_Orlando[3:4]
X_train_Orlando5=X_Orlando[4:5]
y_train_Orlando5=y_Orlando[4:5]
y_train_Orlando6=y_Orlando[5:6]
X_train_Orlando7=X_Orlando[7:8]
X_train_Orlando6=X_Orlando[5:6]
y_train_Orlando7=y_Orlando[7:8]
X_train_Orlando8=X_Orlando[8:9]
y_train_Orlando8=y_Orlando[8:9]
X_train_Orlando9=X_Orlando[9:10]
y_train_Orlando9=y_Orlando[9:10]
X_train_Orlando10=X_Orlando[10:11]
y_train_Orlando10=y_Orlando[10:11]
X_train_Orlando11=X_Orlando[11:12]
y_train_Orlando11=y_Orlando[11:12]
X_train_Orlando12=X_Orlando[12:13]
y_train_Orlando12=y_Orlando[12:13]
X_train_Orlando13=X_Orlando[13:14]
y_train_Orlando13=y_Orlando[13:14]
X_train_Orlando14=X_Orlando[14:15]
y_train_Orlando14=y_Orlando[14:15]
X_train_Orlando15=X_Orlando[15:16]
y_train_Orlando15=y_Orlando[15:16]
X_train_Orlando16=X_Orlando[16:17]
y_train_Orlando16=y_Orlando[16:17]
X_train_Orlando17=X_Orlando[17:18]
y_train_Orlando17=y_Orlando[17:18]
X_train_Orlando18=X_Orlando[18:19]
y_train_Orlando18=y_Orlando[18:19]
X_train_Orlando19=X_Orlando[19:20]
y_train_Orlando19=y_Orlando[19:20]
X_train_Orlando20=X_Orlando[20:21]
y_train_Orlando20=y_Orlando[20:21]
X_train_Orlando21=X_Orlando[21:22]
y_train_Orlando21=y_Orlando[21:22]
X_train_Orlando22=X_Orlando[22:23]
y_train_Orlando22=y_Orlando[22:23]


X_train_OrlandoAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,638],[5,11,18,19,20]]
y_train_OrlandoAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,638],24:25]

X_train_OrlandoAll2=df.iloc[[0,1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,375,397,419,441,463,485,507,529,551,573,595,639],[5,11,18,19,20]]
y_train_OrlandoAll2=df.iloc[[1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,375,397,419,441,463,485,507,529,551,573,595,639],24:25]

X_train_OrlandoAll3=df.iloc[[0,2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,376,398,420,442,464,486,508,530,552,574,596,640],[5,11,18,19,20]]
y_train_OrlandoAll3=df.iloc[[2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,376,398,420,442,464,486,508,530,552,574,596,640],24:25]

X_train_OrlandoAll4=df.iloc[[0,3,25,47,69,91,113,135,157,179,201,223,245,267,289,311,333,355,377,399,421,443,465,487,509,531,553,575,597,641],[5,11,18,19,20]]
y_train_OrlandoAll4=df.iloc[[3,25,47,69,91,113,135,158,179,201,223,245,267,289,311,333,355,377,399,421,443,465,487,509,531,553,575,597,641],24:25]

X_train_OrlandoAll5=df.iloc[[0,4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,378,400,422,444,466,488,510,532,554,576,598,642],[5,11,18,19,20]]
y_train_OrlandoAll5=df.iloc[[4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,378,400,422,444,466,488,510,532,554,576,598,642],24:25]

X_train_OrlandoAll6=df.iloc[[0,5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,379,401,423,445,467,489,511,533,555,577,599,643],[5,11,18,19,20]]
y_train_OrlandoAll6=df.iloc[[5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,379,401,423,445,467,489,511,533,555,577,599,643],24:25]

X_train_OrlandoAll7=df.iloc[[0,6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,380,402,424,446,468,490,512,534,556,578,600,644],[5,11,18,19,20]]
y_train_OrlandoAll7=df.iloc[[6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,380,402,424,446,468,490,512,534,556,578,600,644],24:25]

X_train_OrlandoAll8=df.iloc[[0,7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,381,403,425,447,469,491,513,535,557,579,601,645],[5,11,18,19,20]]
y_train_OrlandoAll8=df.iloc[[7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,381,403,425,447,469,491,513,535,557,579,601,645],24:25]

X_train_OrlandoAll9=df.iloc[[0,8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,382,404,426,448,470,492,514,536,558,580,602,646],[5,11,18,19,20]]
y_train_OrlandoAll9=df.iloc[[8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,382,404,426,448,470,492,514,536,558,580,602,646],24:25]

X_train_OrlandoAll10=df.iloc[[0,9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,383,405,427,449,471,493,515,537,559,581,603,647],[5,11,18,19,20]]
y_train_OrlandoAll10=df.iloc[[9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,383,405,427,449,471,493,515,537,559,581,603,647],24:25]

X_train_OrlandoAll11=df.iloc[[0,10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,384,406,428,450,472,494,516,538,560,582,604,648],[5,11,18,19,20]]
y_train_OrlandoAll11=df.iloc[[10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,384,406,428,450,472,494,516,538,560,582,604,648],24:25]

X_train_OrlandoAll12=df.iloc[[0,11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,385,407,429,451,473,495,517,539,561,583,605,649],[5,11,18,19,20]]
y_train_OrlandoAll12=df.iloc[[11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,385,407,429,451,473,495,517,539,561,583,605,649],24:25]

X_train_OrlandoAll13=df.iloc[[0,12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,386,408,430,452,474,496,518,540,562,584,606,650],[5,11,18,19,20]]
y_train_OrlandoAll13=df.iloc[[12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,386,408,430,452,474,496,518,540,562,584,606,650],24:25]

X_train_OrlandoAll14=df.iloc[[0,13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,387,409,431,453,475,497,519,541,563,585,607,651],[5,11,18,19,20]]
y_train_OrlandoAll14=df.iloc[[13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,387,409,431,453,475,497,519,541,563,585,607,651],24:25]

X_train_OrlandoAll15=df.iloc[[0,14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,388,410,432,454,476,498,520,542,564,586,608,652],[5,11,18,19,20]]
y_train_OrlandoAll15=df.iloc[[14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,388,410,432,454,476,498,520,542,564,586,608,652],24:25]

X_train_OrlandoAll16=df.iloc[[0,15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,389,411,433,455,477,499,521,543,565,587,609,653],[5,11,18,19,20]]
y_train_OrlandoAll16=df.iloc[[15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,389,411,433,455,477,499,521,543,565,587,609,653],24:25]

X_train_OrlandoAll17=df.iloc[[0,16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,390,412,434,456,478,500,522,544,566,588,610,654],[5,11,18,19,20]]
y_train_OrlandoAll17=df.iloc[[16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,390,412,434,456,478,500,522,544,566,588,610,654],24:25]

X_train_OrlandoAll18=df.iloc[[0,17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,391,413,435,457,479,501,523,545,567,589,611,655],[5,11,18,19,20]]
y_train_OrlandoAll18=df.iloc[[17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,391,413,435,457,479,501,523,545,567,589,611,655],24:25]

X_train_OrlandoAll19=df.iloc[[0,18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,392,414,436,458,480,502,524,546,568,590,612,656],[5,11,18,19,20]]
y_train_OrlandoAll19=df.iloc[[18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,392,414,436,458,480,502,524,546,568,590,612,656],24:25]

X_train_OrlandoAll20=df.iloc[[0,19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,393,415,437,459,481,503,525,547,569,591,613,657],[5,11,18,19,20]]
y_train_OrlandoAll20=df.iloc[[19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,393,415,437,459,481,503,525,547,569,591,613,657],24:25]

X_train_OrlandoAll21=df.iloc[[0,20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,394,416,438,460,482,504,526,548,570,592,614,658],[5,11,18,19,20]]
y_train_OrlandoAll21=df.iloc[[20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,394,416,438,460,482,504,526,548,570,592,614,658],24:25]

X_train_OrlandoAll22=df.iloc[[0,21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,395,417,439,461,483,505,527,549,571,593,615,659],[5,11,18,19,20]]
y_train_OrlandoAll22=df.iloc[[21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,395,417,439,461,483,505,527,549,571,593,615,659],24:25]

# %%
regressorOrlando1 = LinearRegression()
regressorOrlando1.fit(X_train_OrlandoAll1, y_train_OrlandoAll1)
pd.DataFrame(list(zip(X_train_OrlandoAll1, regressorOrlando1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_Orlando1 = regressorOrlando1.predict(X_train_Orlando1)

# %%
y_train_OrlandoAll2.loc[-1] = y_pred_Orlando1.item(0)  # adding a row
y_train_OrlandoAll2.index = y_train_OrlandoAll2.index + 1  # shifting index
y_train_OrlandoAll2 = y_train_OrlandoAll2.sort_index()
regressorOrlando2 = LinearRegression()
regressorOrlando2.fit(X_train_OrlandoAll2, y_train_OrlandoAll2)

pd.DataFrame(list(zip(X_train_OrlandoAll2, regressorOrlando2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Orlando2 = regressorOrlando2.predict(X_train_Orlando2)

y_train_OrlandoAll3.loc[-1] = y_pred_Orlando2.item(0)  # adding a row
y_train_OrlandoAll3.index = y_train_OrlandoAll3.index + 1  # shifting index
y_train_OrlandoAll3 = y_train_OrlandoAll3.sort_index()
regressorOrlando3 = LinearRegression()
regressorOrlando3.fit(X_train_OrlandoAll3, y_train_OrlandoAll3)

pd.DataFrame(list(zip(X_train_OrlandoAll3, regressorOrlando3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Orlando3 = regressorOrlando3.predict(X_train_Orlando3)

y_train_OrlandoAll4.loc[-1] = y_pred_Orlando3.item(0)  # adding a row
y_train_OrlandoAll4.index = y_train_OrlandoAll4.index + 1  # shifting index
y_train_OrlandoAll4 = y_train_OrlandoAll4.sort_index()
regressorOrlando4 = LinearRegression()
regressorOrlando4.fit(X_train_OrlandoAll4, y_train_OrlandoAll4)

pd.DataFrame(list(zip(X_train_OrlandoAll4, regressorOrlando4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Orlando4 = regressorOrlando4.predict(X_train_Orlando4)

y_train_OrlandoAll5.loc[-1] = y_pred_Orlando4.item(0)  # adding a row
y_train_OrlandoAll5.index = y_train_OrlandoAll5.index + 1  # shifting index
y_train_OrlandoAll5 = y_train_OrlandoAll5.sort_index()
regressorOrlando5 = LinearRegression()
regressorOrlando5.fit(X_train_OrlandoAll5, y_train_OrlandoAll5)

pd.DataFrame(list(zip(X_train_OrlandoAll5, regressorOrlando5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Orlando5 = regressorOrlando5.predict(X_train_Orlando5)

y_train_OrlandoAll6.loc[-1] = y_pred_Orlando5.item(0)  # adding a row
y_train_OrlandoAll6.index = y_train_OrlandoAll6.index + 1  # shifting index
y_train_OrlandoAll6 = y_train_OrlandoAll6.sort_index()
regressorOrlando6 = LinearRegression()
regressorOrlando6.fit(X_train_OrlandoAll6, y_train_OrlandoAll6)

pd.DataFrame(list(zip(X_train_OrlandoAll6, regressorOrlando6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Orlando6 = regressorOrlando6.predict(X_train_Orlando6)

y_train_OrlandoAll7.loc[-1] = y_pred_Orlando6.item(0)  # adding a row
y_train_OrlandoAll7.index = y_train_OrlandoAll7.index + 1  # shifting index
y_train_OrlandoAll7 = y_train_OrlandoAll7.sort_index()
regressorOrlando7 = LinearRegression()
regressorOrlando7.fit(X_train_OrlandoAll7, y_train_OrlandoAll7)

pd.DataFrame(list(zip(X_train_OrlandoAll7, regressorOrlando7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Orlando7 = regressorOrlando7.predict(X_train_Orlando7)

y_train_OrlandoAll8.loc[-1] = y_pred_Orlando7.item(0)  # adding a row
y_train_OrlandoAll8.index = y_train_OrlandoAll8.index + 1  # shifting index
y_train_OrlandoAll8 = y_train_OrlandoAll8.sort_index()
regressorOrlando8 = LinearRegression()
regressorOrlando8.fit(X_train_OrlandoAll8, y_train_OrlandoAll8)

pd.DataFrame(list(zip(X_train_OrlandoAll8, regressorOrlando8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Orlando8 = regressorOrlando8.predict(X_train_Orlando8)

y_train_OrlandoAll9.loc[-1] = y_pred_Orlando8.item(0)  # adding a row
y_train_OrlandoAll9.index = y_train_OrlandoAll9.index + 1  # shifting index
y_train_OrlandoAll9 = y_train_OrlandoAll9.sort_index()
regressorOrlando9 = LinearRegression()
regressorOrlando9.fit(X_train_OrlandoAll9, y_train_OrlandoAll9)

pd.DataFrame(list(zip(X_train_OrlandoAll9, regressorOrlando9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Orlando9 = regressorOrlando9.predict(X_train_Orlando9)

y_train_OrlandoAll10.loc[-1] = y_pred_Orlando9.item(0)  # adding a row
y_train_OrlandoAll10.index = y_train_OrlandoAll10.index + 1  # shifting index
y_train_OrlandoAll10 = y_train_OrlandoAll10.sort_index()
regressorOrlando10 = LinearRegression()
regressorOrlando10.fit(X_train_OrlandoAll10, y_train_OrlandoAll10)

pd.DataFrame(list(zip(X_train_OrlandoAll10, regressorOrlando10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Orlando10 = regressorOrlando10.predict(X_train_Orlando10)

y_train_OrlandoAll11.loc[-1] = y_pred_Orlando10.item(0)  # adding a row
y_train_OrlandoAll11.index = y_train_OrlandoAll11.index + 1  # shifting index
y_train_OrlandoAll11 = y_train_OrlandoAll11.sort_index()
regressorOrlando11 = LinearRegression()
regressorOrlando11.fit(X_train_OrlandoAll11, y_train_OrlandoAll11)

pd.DataFrame(list(zip(X_train_OrlandoAll11, regressorOrlando11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Orlando11 = regressorOrlando11.predict(X_train_Orlando11)

y_train_OrlandoAll12.loc[-1] = y_pred_Orlando11.item(0)  # adding a row
y_train_OrlandoAll12.index = y_train_OrlandoAll12.index + 1  # shifting index
y_train_OrlandoAll12 = y_train_OrlandoAll12.sort_index()
regressorOrlando12 = LinearRegression()
regressorOrlando12.fit(X_train_OrlandoAll12, y_train_OrlandoAll12)

pd.DataFrame(list(zip(X_train_OrlandoAll12, regressorOrlando12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Orlando12 = regressorOrlando12.predict(X_train_Orlando12)

y_train_OrlandoAll13.loc[-1] = y_pred_Orlando12.item(0)  # adding a row
y_train_OrlandoAll13.index = y_train_OrlandoAll13.index + 1  # shifting index
y_train_OrlandoAll13 = y_train_OrlandoAll13.sort_index()
regressorOrlando13 = LinearRegression()
regressorOrlando13.fit(X_train_OrlandoAll13, y_train_OrlandoAll13)

pd.DataFrame(list(zip(X_train_OrlandoAll13, regressorOrlando13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Orlando13 = regressorOrlando13.predict(X_train_Orlando13)

y_train_OrlandoAll14.loc[-1] = y_pred_Orlando13.item(0)  # adding a row
y_train_OrlandoAll14.index = y_train_OrlandoAll14.index + 1  # shifting index
y_train_OrlandoAll14 = y_train_OrlandoAll14.sort_index()
regressorOrlando14 = LinearRegression()
regressorOrlando14.fit(X_train_OrlandoAll14, y_train_OrlandoAll14)

pd.DataFrame(list(zip(X_train_OrlandoAll14, regressorOrlando14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Orlando14 = regressorOrlando14.predict(X_train_Orlando14)

y_train_OrlandoAll15.loc[-1] = y_pred_Orlando14.item(0)  # adding a row
y_train_OrlandoAll15.index = y_train_OrlandoAll15.index + 1  # shifting index
y_train_OrlandoAll15 = y_train_OrlandoAll15.sort_index()
regressorOrlando15 = LinearRegression()
regressorOrlando15.fit(X_train_OrlandoAll15, y_train_OrlandoAll15)

pd.DataFrame(list(zip(X_train_OrlandoAll15, regressorOrlando15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Orlando15 = regressorOrlando15.predict(X_train_Orlando15)

y_train_OrlandoAll16.loc[-1] = y_pred_Orlando15.item(0)  # adding a row
y_train_OrlandoAll16.index = y_train_OrlandoAll16.index + 1  # shifting index
y_train_OrlandoAll16 = y_train_OrlandoAll16.sort_index()
regressorOrlando16 = LinearRegression()
regressorOrlando16.fit(X_train_OrlandoAll16, y_train_OrlandoAll16)

pd.DataFrame(list(zip(X_train_OrlandoAll16, regressorOrlando16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Orlando16 = regressorOrlando16.predict(X_train_Orlando16)

y_train_OrlandoAll17.loc[-1] = y_pred_Orlando16.item(0)  # adding a row
y_train_OrlandoAll17.index = y_train_OrlandoAll17.index + 1  # shifting index
y_train_OrlandoAll17 = y_train_OrlandoAll17.sort_index()
regressorOrlando17 = LinearRegression()
regressorOrlando17.fit(X_train_OrlandoAll17, y_train_OrlandoAll17)

pd.DataFrame(list(zip(X_train_OrlandoAll17, regressorOrlando17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Orlando17 = regressorOrlando17.predict(X_train_Orlando17)

y_train_OrlandoAll18.loc[-1] = y_pred_Orlando17.item(0)  # adding a row
y_train_OrlandoAll18.index = y_train_OrlandoAll18.index + 1  # shifting index
y_train_OrlandoAll18 = y_train_OrlandoAll18.sort_index()
regressorOrlando18 = LinearRegression()
regressorOrlando18.fit(X_train_OrlandoAll18, y_train_OrlandoAll18)

pd.DataFrame(list(zip(X_train_OrlandoAll18, regressorOrlando18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Orlando18 = regressorOrlando18.predict(X_train_Orlando18)

y_train_OrlandoAll19.loc[-1] = y_pred_Orlando18.item(0)  # adding a row
y_train_OrlandoAll19.index = y_train_OrlandoAll19.index + 1  # shifting index
y_train_OrlandoAll19 = y_train_OrlandoAll19.sort_index()
regressorOrlando19 = LinearRegression()
regressorOrlando19.fit(X_train_OrlandoAll19, y_train_OrlandoAll19)

pd.DataFrame(list(zip(X_train_OrlandoAll19, regressorOrlando19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Orlando19 = regressorOrlando19.predict(X_train_Orlando19)

y_train_OrlandoAll20.loc[-1] = y_pred_Orlando19.item(0)  # adding a row
y_train_OrlandoAll20.index = y_train_OrlandoAll20.index + 1  # shifting index
y_train_OrlandoAll20 = y_train_OrlandoAll20.sort_index()
regressorOrlando20 = LinearRegression()
regressorOrlando20.fit(X_train_OrlandoAll20, y_train_OrlandoAll20)

pd.DataFrame(list(zip(X_train_OrlandoAll20, regressorOrlando20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Orlando20 = regressorOrlando20.predict(X_train_Orlando20)

y_train_OrlandoAll21.loc[-1] = y_pred_Orlando20.item(0)  # adding a row
y_train_OrlandoAll21.index = y_train_OrlandoAll21.index + 1  # shifting index
y_train_OrlandoAll21 = y_train_OrlandoAll21.sort_index()
regressorOrlando21 = LinearRegression()
regressorOrlando21.fit(X_train_OrlandoAll21, y_train_OrlandoAll21)

pd.DataFrame(list(zip(X_train_OrlandoAll21, regressorOrlando21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Orlando21 = regressorOrlando21.predict(X_train_Orlando21)

# %%
X_train_Atlanta1=X_Atlanta[0:1]
y_train_Atlanta1=y_Atlanta[0:1]
X_train_Atlanta2=X_Atlanta[1:2]
y_train_Atlanta2=y_Atlanta[1:2]
X_train_Atlanta3=X_Atlanta[2:3]
y_train_Atlanta3=y_Atlanta[2:3]
X_train_Atlanta4=X_Atlanta[3:4]
y_train_Atlanta4=y_Atlanta[3:4]
X_train_Atlanta5=X_Atlanta[4:5]
y_train_Atlanta5=y_Atlanta[4:5]
y_train_Atlanta6=y_Atlanta[5:6]
X_train_Atlanta7=X_Atlanta[7:8]
X_train_Atlanta6=X_Atlanta[5:6]
y_train_Atlanta7=y_Atlanta[7:8]
X_train_Atlanta8=X_Atlanta[8:9]
y_train_Atlanta8=y_Atlanta[8:9]
X_train_Atlanta9=X_Atlanta[9:10]
y_train_Atlanta9=y_Atlanta[9:10]
X_train_Atlanta10=X_Atlanta[10:11]
y_train_Atlanta10=y_Atlanta[10:11]
X_train_Atlanta11=X_Atlanta[11:12]
y_train_Atlanta11=y_Atlanta[11:12]
X_train_Atlanta12=X_Atlanta[12:13]
y_train_Atlanta12=y_Atlanta[12:13]
X_train_Atlanta13=X_Atlanta[13:14]
y_train_Atlanta13=y_Atlanta[13:14]
X_train_Atlanta14=X_Atlanta[14:15]
y_train_Atlanta14=y_Atlanta[14:15]
X_train_Atlanta15=X_Atlanta[15:16]
y_train_Atlanta15=y_Atlanta[15:16]
X_train_Atlanta16=X_Atlanta[16:17]
y_train_Atlanta16=y_Atlanta[16:17]
X_train_Atlanta17=X_Atlanta[17:18]
y_train_Atlanta17=y_Atlanta[17:18]
X_train_Atlanta18=X_Atlanta[18:19]
y_train_Atlanta18=y_Atlanta[18:19]
X_train_Atlanta19=X_Atlanta[19:20]
y_train_Atlanta19=y_Atlanta[19:20]
X_train_Atlanta20=X_Atlanta[20:21]
y_train_Atlanta20=y_Atlanta[20:21]
X_train_Atlanta21=X_Atlanta[21:22]
y_train_Atlanta21=y_Atlanta[21:22]
X_train_Atlanta22=X_Atlanta[22:23]
y_train_Atlanta22=y_Atlanta[22:23]


X_train_AtlantaAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616],[5,11,18,19,20]]
y_train_AtlantaAll1=df.iloc[[0,22,44,66,88,110,132,154,176,198,220,242,264,286,308,330,352,374,396,418,440,462,484,506,528,550,572,594,616],24:25]

X_train_AtlantaAll2=df.iloc[[0,1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,375,397,419,441,463,485,507,529,551,573,595,617],[5,11,18,19,20]]
y_train_AtlantaAll2=df.iloc[[1,23,45,67,89,111,133,155,177,199,221,243,265,287,309,331,353,375,397,419,441,463,485,507,529,551,573,595,617],24:25]

X_train_AtlantaAll3=df.iloc[[0,2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,376,398,420,442,464,486,508,530,552,574,596,618],[5,11,18,19,20]]
y_train_AtlantaAll3=df.iloc[[2,24,46,68,90,112,134,156,178,200,222,244,266,288,310,332,354,376,398,420,442,464,486,508,530,552,574,596,618],24:25]

X_train_AtlantaAll4=df.iloc[[0,3,25,47,69,91,113,135,157,179,201,223,245,267,289,311,333,355,377,399,421,443,465,487,509,531,553,575,597,619],[5,11,18,19,20]]
y_train_AtlantaAll4=df.iloc[[3,25,47,69,91,113,135,158,179,201,223,245,267,289,311,333,355,377,399,421,443,465,487,509,531,553,575,597,619],24:25]

X_train_AtlantaAll5=df.iloc[[0,4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,378,400,422,444,466,488,510,532,554,576,598,620],[5,11,18,19,20]]
y_train_AtlantaAll5=df.iloc[[4,26,48,70,92,114,136,158,180,202,224,246,268,290,312,334,356,378,400,422,444,466,488,510,532,554,576,598,620],24:25]

X_train_AtlantaAll6=df.iloc[[0,5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,379,401,423,445,467,489,511,533,555,577,599,621],[5,11,18,19,20]]
y_train_AtlantaAll6=df.iloc[[5,27,49,71,93,115,137,159,181,203,225,247,269,291,313,335,357,379,401,423,445,467,489,511,533,555,577,599,621],24:25]

X_train_AtlantaAll7=df.iloc[[0,6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,380,402,424,446,468,490,512,534,556,578,600,622],[5,11,18,19,20]]
y_train_AtlantaAll7=df.iloc[[6,28,50,72,94,116,138,160,182,204,226,248,270,292,314,336,358,380,402,424,446,468,490,512,534,556,578,600,622],24:25]

X_train_AtlantaAll8=df.iloc[[0,7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,381,403,425,447,469,491,513,535,557,579,601,623],[5,11,18,19,20]]
y_train_AtlantaAll8=df.iloc[[7,29,51,73,95,117,139,161,183,205,227,249,271,293,315,337,359,381,403,425,447,469,491,513,535,557,579,601,623],24:25]

X_train_AtlantaAll9=df.iloc[[0,8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,382,404,426,448,470,492,514,536,558,580,602,624],[5,11,18,19,20]]
y_train_AtlantaAll9=df.iloc[[8,30,52,74,96,118,140,162,184,206,228,250,272,294,316,338,360,382,404,426,448,470,492,514,536,558,580,602,624],24:25]

X_train_AtlantaAll10=df.iloc[[0,9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,383,405,427,449,471,493,515,537,559,581,603,625],[5,11,18,19,20]]
y_train_AtlantaAll10=df.iloc[[9,31,53,75,97,119,141,163,185,207,229,251,273,295,317,339,361,383,405,427,449,471,493,515,537,559,581,603,625],24:25]

X_train_AtlantaAll11=df.iloc[[0,10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,384,406,428,450,472,494,516,538,560,582,604,626],[5,11,18,19,20]]
y_train_AtlantaAll11=df.iloc[[10,32,54,76,98,120,142,164,186,208,230,252,274,296,318,340,362,384,406,428,450,472,494,516,538,560,582,604,626],24:25]

X_train_AtlantaAll12=df.iloc[[0,11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,385,407,429,451,473,495,517,539,561,583,605,627],[5,11,18,19,20]]
y_train_AtlantaAll12=df.iloc[[11,33,55,77,99,121,143,165,187,209,231,253,275,297,319,341,363,385,407,429,451,473,495,517,539,561,583,605,627],24:25]

X_train_AtlantaAll13=df.iloc[[0,12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,386,408,430,452,474,496,518,540,562,584,606,628],[5,11,18,19,20]]
y_train_AtlantaAll13=df.iloc[[12,34,56,78,100,122,144,166,188,210,232,254,276,298,320,342,364,386,408,430,452,474,496,518,540,562,584,606,628],24:25]

X_train_AtlantaAll14=df.iloc[[0,13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,387,409,431,453,475,497,519,541,563,585,607,629],[5,11,18,19,20]]
y_train_AtlantaAll14=df.iloc[[13,35,57,79,101,123,145,167,189,211,233,255,277,299,321,343,365,387,409,431,453,475,497,519,541,563,585,607,629],24:25]

X_train_AtlantaAll15=df.iloc[[0,14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,388,410,432,454,476,498,520,542,564,586,608,630],[5,11,18,19,20]]
y_train_AtlantaAll15=df.iloc[[14,36,58,80,102,124,146,168,190,212,234,256,278,300,322,344,366,388,410,432,454,476,498,520,542,564,586,608,630],24:25]

X_train_AtlantaAll16=df.iloc[[0,15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,389,411,433,455,477,499,521,543,565,587,609,631],[5,11,18,19,20]]
y_train_AtlantaAll16=df.iloc[[15,37,59,81,103,125,147,169,191,213,235,257,279,301,323,345,367,389,411,433,455,477,499,521,543,565,587,609,631],24:25]

X_train_AtlantaAll17=df.iloc[[0,16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,390,412,434,456,478,500,522,544,566,588,610,632],[5,11,18,19,20]]
y_train_AtlantaAll17=df.iloc[[16,38,60,82,104,126,148,170,192,214,236,258,280,302,324,346,368,390,412,434,456,478,500,522,544,566,588,610,632],24:25]

X_train_AtlantaAll18=df.iloc[[0,17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,391,413,435,457,479,501,523,545,567,589,611,633],[5,11,18,19,20]]
y_train_AtlantaAll18=df.iloc[[17,39,61,83,105,127,149,171,193,215,237,259,281,303,325,347,369,391,413,435,457,479,501,523,545,567,589,611,633],24:25]

X_train_AtlantaAll19=df.iloc[[0,18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,392,414,436,458,480,502,524,546,568,590,612,634],[5,11,18,19,20]]
y_train_AtlantaAll19=df.iloc[[18,40,62,84,106,128,150,172,194,216,238,260,282,304,326,348,370,392,414,436,458,480,502,524,546,568,590,612,634],24:25]

X_train_AtlantaAll20=df.iloc[[0,19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,393,415,437,459,481,503,525,547,569,591,613,635],[5,11,18,19,20]]
y_train_AtlantaAll20=df.iloc[[19,41,63,85,107,129,151,173,195,217,239,261,283,305,327,349,371,393,415,437,459,481,503,525,547,569,591,613,635],24:25]

X_train_AtlantaAll21=df.iloc[[0,20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,394,416,438,460,482,504,526,548,570,592,614,636],[5,11,18,19,20]]
y_train_AtlantaAll21=df.iloc[[20,42,64,86,108,130,152,174,196,218,240,262,284,306,328,350,372,394,416,438,460,482,504,526,548,570,592,614,636],24:25]

X_train_AtlantaAll22=df.iloc[[0,21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,395,417,439,461,483,505,527,549,571,593,615,637],[5,11,18,19,20]]
y_train_AtlantaAll22=df.iloc[[21,43,65,87,109,131,153,175,197,219,241,263,285,307,329,351,373,395,417,439,461,483,505,527,549,571,593,615,637],24:25]

# %%
regressorAtlanta1 = LinearRegression()
regressorAtlanta1.fit(X_train_AtlantaAll1, y_train_AtlantaAll1)
pd.DataFrame(list(zip(X_train_AtlantaAll1, regressorAtlanta1.coef_)), columns=['Features', 'Beta Coefficient'])
y_pred_Atlanta1 = regressorAtlanta1.predict(X_train_Atlanta1)

# %%
y_train_AtlantaAll2.loc[-1] = y_pred_Atlanta1.item(0)  # adding a row
y_train_AtlantaAll2.index = y_train_AtlantaAll2.index + 1  # shifting index
y_train_AtlantaAll2 = y_train_AtlantaAll2.sort_index()
regressorAtlanta2 = LinearRegression()
regressorAtlanta2.fit(X_train_AtlantaAll2, y_train_AtlantaAll2)

pd.DataFrame(list(zip(X_train_AtlantaAll2, regressorAtlanta2.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Atlanta2 = regressorAtlanta2.predict(X_train_Atlanta2)

y_train_AtlantaAll3.loc[-1] = y_pred_Atlanta2.item(0)  # adding a row
y_train_AtlantaAll3.index = y_train_AtlantaAll3.index + 1  # shifting index
y_train_AtlantaAll3 = y_train_AtlantaAll3.sort_index()
regressorAtlanta3 = LinearRegression()
regressorAtlanta3.fit(X_train_AtlantaAll3, y_train_AtlantaAll3)

pd.DataFrame(list(zip(X_train_AtlantaAll3, regressorAtlanta3.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Atlanta3 = regressorAtlanta3.predict(X_train_Atlanta3)

y_train_AtlantaAll4.loc[-1] = y_pred_Atlanta3.item(0)  # adding a row
y_train_AtlantaAll4.index = y_train_AtlantaAll4.index + 1  # shifting index
y_train_AtlantaAll4 = y_train_AtlantaAll4.sort_index()
regressorAtlanta4 = LinearRegression()
regressorAtlanta4.fit(X_train_AtlantaAll4, y_train_AtlantaAll4)

pd.DataFrame(list(zip(X_train_AtlantaAll4, regressorAtlanta4.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Atlanta4 = regressorAtlanta4.predict(X_train_Atlanta4)

y_train_AtlantaAll5.loc[-1] = y_pred_Atlanta4.item(0)  # adding a row
y_train_AtlantaAll5.index = y_train_AtlantaAll5.index + 1  # shifting index
y_train_AtlantaAll5 = y_train_AtlantaAll5.sort_index()
regressorAtlanta5 = LinearRegression()
regressorAtlanta5.fit(X_train_AtlantaAll5, y_train_AtlantaAll5)

pd.DataFrame(list(zip(X_train_AtlantaAll5, regressorAtlanta5.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Atlanta5 = regressorAtlanta5.predict(X_train_Atlanta5)

y_train_AtlantaAll6.loc[-1] = y_pred_Atlanta5.item(0)  # adding a row
y_train_AtlantaAll6.index = y_train_AtlantaAll6.index + 1  # shifting index
y_train_AtlantaAll6 = y_train_AtlantaAll6.sort_index()
regressorAtlanta6 = LinearRegression()
regressorAtlanta6.fit(X_train_AtlantaAll6, y_train_AtlantaAll6)

pd.DataFrame(list(zip(X_train_AtlantaAll6, regressorAtlanta6.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Atlanta6 = regressorAtlanta6.predict(X_train_Atlanta6)

y_train_AtlantaAll7.loc[-1] = y_pred_Atlanta6.item(0)  # adding a row
y_train_AtlantaAll7.index = y_train_AtlantaAll7.index + 1  # shifting index
y_train_AtlantaAll7 = y_train_AtlantaAll7.sort_index()
regressorAtlanta7 = LinearRegression()
regressorAtlanta7.fit(X_train_AtlantaAll7, y_train_AtlantaAll7)

pd.DataFrame(list(zip(X_train_AtlantaAll7, regressorAtlanta7.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Atlanta7 = regressorAtlanta7.predict(X_train_Atlanta7)

y_train_AtlantaAll8.loc[-1] = y_pred_Atlanta7.item(0)  # adding a row
y_train_AtlantaAll8.index = y_train_AtlantaAll8.index + 1  # shifting index
y_train_AtlantaAll8 = y_train_AtlantaAll8.sort_index()
regressorAtlanta8 = LinearRegression()
regressorAtlanta8.fit(X_train_AtlantaAll8, y_train_AtlantaAll8)

pd.DataFrame(list(zip(X_train_AtlantaAll8, regressorAtlanta8.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Atlanta8 = regressorAtlanta8.predict(X_train_Atlanta8)

y_train_AtlantaAll9.loc[-1] = y_pred_Atlanta8.item(0)  # adding a row
y_train_AtlantaAll9.index = y_train_AtlantaAll9.index + 1  # shifting index
y_train_AtlantaAll9 = y_train_AtlantaAll9.sort_index()
regressorAtlanta9 = LinearRegression()
regressorAtlanta9.fit(X_train_AtlantaAll9, y_train_AtlantaAll9)

pd.DataFrame(list(zip(X_train_AtlantaAll9, regressorAtlanta9.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Atlanta9 = regressorAtlanta9.predict(X_train_Atlanta9)

y_train_AtlantaAll10.loc[-1] = y_pred_Atlanta9.item(0)  # adding a row
y_train_AtlantaAll10.index = y_train_AtlantaAll10.index + 1  # shifting index
y_train_AtlantaAll10 = y_train_AtlantaAll10.sort_index()
regressorAtlanta10 = LinearRegression()
regressorAtlanta10.fit(X_train_AtlantaAll10, y_train_AtlantaAll10)

pd.DataFrame(list(zip(X_train_AtlantaAll10, regressorAtlanta10.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Atlanta10 = regressorAtlanta10.predict(X_train_Atlanta10)

y_train_AtlantaAll11.loc[-1] = y_pred_Atlanta10.item(0)  # adding a row
y_train_AtlantaAll11.index = y_train_AtlantaAll11.index + 1  # shifting index
y_train_AtlantaAll11 = y_train_AtlantaAll11.sort_index()
regressorAtlanta11 = LinearRegression()
regressorAtlanta11.fit(X_train_AtlantaAll11, y_train_AtlantaAll11)

pd.DataFrame(list(zip(X_train_AtlantaAll11, regressorAtlanta11.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Atlanta11 = regressorAtlanta11.predict(X_train_Atlanta11)

y_train_AtlantaAll12.loc[-1] = y_pred_Atlanta11.item(0)  # adding a row
y_train_AtlantaAll12.index = y_train_AtlantaAll12.index + 1  # shifting index
y_train_AtlantaAll12 = y_train_AtlantaAll12.sort_index()
regressorAtlanta12 = LinearRegression()
regressorAtlanta12.fit(X_train_AtlantaAll12, y_train_AtlantaAll12)

pd.DataFrame(list(zip(X_train_AtlantaAll12, regressorAtlanta12.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Atlanta12 = regressorAtlanta12.predict(X_train_Atlanta12)

y_train_AtlantaAll13.loc[-1] = y_pred_Atlanta12.item(0)  # adding a row
y_train_AtlantaAll13.index = y_train_AtlantaAll13.index + 1  # shifting index
y_train_AtlantaAll13 = y_train_AtlantaAll13.sort_index()
regressorAtlanta13 = LinearRegression()
regressorAtlanta13.fit(X_train_AtlantaAll13, y_train_AtlantaAll13)

pd.DataFrame(list(zip(X_train_AtlantaAll13, regressorAtlanta13.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Atlanta13 = regressorAtlanta13.predict(X_train_Atlanta13)

y_train_AtlantaAll14.loc[-1] = y_pred_Atlanta13.item(0)  # adding a row
y_train_AtlantaAll14.index = y_train_AtlantaAll14.index + 1  # shifting index
y_train_AtlantaAll14 = y_train_AtlantaAll14.sort_index()
regressorAtlanta14 = LinearRegression()
regressorAtlanta14.fit(X_train_AtlantaAll14, y_train_AtlantaAll14)

pd.DataFrame(list(zip(X_train_AtlantaAll14, regressorAtlanta14.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Atlanta14 = regressorAtlanta14.predict(X_train_Atlanta14)

y_train_AtlantaAll15.loc[-1] = y_pred_Atlanta14.item(0)  # adding a row
y_train_AtlantaAll15.index = y_train_AtlantaAll15.index + 1  # shifting index
y_train_AtlantaAll15 = y_train_AtlantaAll15.sort_index()
regressorAtlanta15 = LinearRegression()
regressorAtlanta15.fit(X_train_AtlantaAll15, y_train_AtlantaAll15)

pd.DataFrame(list(zip(X_train_AtlantaAll15, regressorAtlanta15.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Atlanta15 = regressorAtlanta15.predict(X_train_Atlanta15)

y_train_AtlantaAll16.loc[-1] = y_pred_Atlanta15.item(0)  # adding a row
y_train_AtlantaAll16.index = y_train_AtlantaAll16.index + 1  # shifting index
y_train_AtlantaAll16 = y_train_AtlantaAll16.sort_index()
regressorAtlanta16 = LinearRegression()
regressorAtlanta16.fit(X_train_AtlantaAll16, y_train_AtlantaAll16)

pd.DataFrame(list(zip(X_train_AtlantaAll16, regressorAtlanta16.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Atlanta16 = regressorAtlanta16.predict(X_train_Atlanta16)

y_train_AtlantaAll17.loc[-1] = y_pred_Atlanta16.item(0)  # adding a row
y_train_AtlantaAll17.index = y_train_AtlantaAll17.index + 1  # shifting index
y_train_AtlantaAll17 = y_train_AtlantaAll17.sort_index()
regressorAtlanta17 = LinearRegression()
regressorAtlanta17.fit(X_train_AtlantaAll17, y_train_AtlantaAll17)

pd.DataFrame(list(zip(X_train_AtlantaAll17, regressorAtlanta17.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Atlanta17 = regressorAtlanta17.predict(X_train_Atlanta17)

y_train_AtlantaAll18.loc[-1] = y_pred_Atlanta17.item(0)  # adding a row
y_train_AtlantaAll18.index = y_train_AtlantaAll18.index + 1  # shifting index
y_train_AtlantaAll18 = y_train_AtlantaAll18.sort_index()
regressorAtlanta18 = LinearRegression()
regressorAtlanta18.fit(X_train_AtlantaAll18, y_train_AtlantaAll18)

pd.DataFrame(list(zip(X_train_AtlantaAll18, regressorAtlanta18.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Atlanta18 = regressorAtlanta18.predict(X_train_Atlanta18)

y_train_AtlantaAll19.loc[-1] = y_pred_Atlanta18.item(0)  # adding a row
y_train_AtlantaAll19.index = y_train_AtlantaAll19.index + 1  # shifting index
y_train_AtlantaAll19 = y_train_AtlantaAll19.sort_index()
regressorAtlanta19 = LinearRegression()
regressorAtlanta19.fit(X_train_AtlantaAll19, y_train_AtlantaAll19)

pd.DataFrame(list(zip(X_train_AtlantaAll19, regressorAtlanta19.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Atlanta19 = regressorAtlanta19.predict(X_train_Atlanta19)

y_train_AtlantaAll20.loc[-1] = y_pred_Atlanta19.item(0)  # adding a row
y_train_AtlantaAll20.index = y_train_AtlantaAll20.index + 1  # shifting index
y_train_AtlantaAll20 = y_train_AtlantaAll20.sort_index()
regressorAtlanta20 = LinearRegression()
regressorAtlanta20.fit(X_train_AtlantaAll20, y_train_AtlantaAll20)

pd.DataFrame(list(zip(X_train_AtlantaAll20, regressorAtlanta20.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Atlanta20 = regressorAtlanta20.predict(X_train_Atlanta20)

y_train_AtlantaAll21.loc[-1] = y_pred_Atlanta20.item(0)  # adding a row
y_train_AtlantaAll21.index = y_train_AtlantaAll21.index + 1  # shifting index
y_train_AtlantaAll21 = y_train_AtlantaAll21.sort_index()
regressorAtlanta21 = LinearRegression()
regressorAtlanta21.fit(X_train_AtlantaAll21, y_train_AtlantaAll21)

pd.DataFrame(list(zip(X_train_AtlantaAll21, regressorAtlanta21.coef_)), columns=['Features', 'Beta Coefficient'])

y_pred_Atlanta21 = regressorAtlanta21.predict(X_train_Atlanta21)

# %%
output = { 'Houston Actual Team Performance' : [y_train1_Houston.iloc[0],y_train2_Houston.iloc[0],y_train3_Houston.iloc[0],y_train4_Houston.iloc[0],
                                       y_train5_Houston.iloc[0],y_train6_Houston.iloc[0],y_train7_Houston.iloc[0],y_train8_Houston.iloc[0],
                                       y_train9_Houston.iloc[0],y_train10_Houston.iloc[0],y_train11_Houston.iloc[0],y_train12_Houston.iloc[0],
                                       y_train13_Houston.iloc[0],y_train14_Houston.iloc[0],y_train15_Houston.iloc[0],y_train16_Houston.iloc[0],
                                       y_train17_Houston.iloc[0],y_train18_Houston.iloc[0],y_train19_Houston.iloc[0],y_train20_Houston.iloc[0],
                                       y_train21_Houston.iloc[0]],  
          'Houston Predicted Team Performance' : [y_pred1_Houston.item(0),y_pred2_Houston.item(0),y_pred3_Houston.item(0),y_pred4_Houston.item(0),
                                       y_pred5_Houston.item(0),y_pred6_Houston.item(0),y_pred7_Houston.item(0),y_pred8_Houston.item(0),
                                       y_pred9_Houston.item(0),y_pred10_Houston.item(0),y_pred11_Houston.item(0),y_pred12_Houston.item(0),
                                       y_pred13_Houston.item(0),y_pred14_Houston.item(0),y_pred15_Houston.item(0),y_pred16_Houston.item(0),
                                       y_pred17_Houston.item(0),y_pred18_Houston.item(0),y_pred19_Houston.item(0),y_pred20_Houston.item(0),
                                       y_pred21_Houston.item(0)]}
pd.DataFrame(output)
# Out:
#     Houston Actual Team Performance  Houston Predicted Team Performance
# 0                                50                           51.620756
# 1                                62                           57.684284
# 2                                58                           64.183512
# 3                                62                           44.323913
# 4                                65                           51.503425
# 5                                70                           72.392854
# 6                                71                           45.084086
# 7                                75                           62.826382
# 8                                75                           57.776838
# 9                                72                           48.140577
# 10                               70                           63.745939
# 11                               69                           52.090756
# ...

# %%
#np.r is for concatenating the data
all1 = np.r_[y_train1_Houston,y_train2_Houston,y_train3_Houston,y_train4_Houston,y_train5_Houston,y_train6_Houston,y_train7_Houston,
            y_train8_Houston,y_train9_Houston,y_train10_Houston,y_train11_Houston,y_train12_Houston,y_train13_Houston,y_train14_Houston,
            y_train15_Houston,y_train16_Houston,y_train17_Houston,y_train18_Houston,y_train19_Houston,y_train20_Houston,y_train21_Houston]
all2 = np.r_[y_pred1_Houston,y_pred2_Houston,y_pred3_Houston,y_pred4_Houston,y_pred5_Houston,y_pred6_Houston,y_pred7_Houston,
            y_pred8_Houston,y_pred9_Houston,y_pred10_Houston,y_pred11_Houston,y_pred12_Houston,y_pred13_Houston,y_pred14_Houston,
            y_pred15_Houston,y_pred16_Houston,y_pred17_Houston,y_pred18_Houston,y_pred19_Houston,y_pred20_Houston,y_pred21_Houston]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'Houston Target Team Performance Mean', 'Houston Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    Houston Target Team Performance Mean  \
# 0                             67.238095
#
#    Houston Team Performance Predicted Mean  \
# 0                                54.225305
#
#    Difference Between Target and Predicted
# 0                                -13.01279

# %%
output = { 'GoldenState Actual Team Performance' : [y_train1_GoldenState.iloc[0],y_train2_GoldenState.iloc[0],y_train3_GoldenState.iloc[0],y_train4_GoldenState.iloc[0],
                                       y_train5_GoldenState.iloc[0],y_train6_GoldenState.iloc[0],y_train7_GoldenState.iloc[0],y_train8_GoldenState.iloc[0],
                                       y_train9_GoldenState.iloc[0],y_train10_GoldenState.iloc[0],y_train11_GoldenState.iloc[0],y_train12_GoldenState.iloc[0],
                                       y_train13_GoldenState.iloc[0],y_train14_GoldenState.iloc[0],y_train15_GoldenState.iloc[0],y_train16_GoldenState.iloc[0],
                                       y_train17_GoldenState.iloc[0],y_train18_GoldenState.iloc[0],y_train19_GoldenState.iloc[0],y_train20_GoldenState.iloc[0],
                                       y_train21_GoldenState.iloc[0]],  
          'GoldenState Predicted Team Performance' : [y_pred1_GoldenState.item(0),y_pred2_GoldenState.item(0),y_pred3_GoldenState.item(0),y_pred4_GoldenState.item(0),
                                       y_pred5_GoldenState.item(0),y_pred6_GoldenState.item(0),y_pred7_GoldenState.item(0),y_pred8_GoldenState.item(0),
                                       y_pred9_GoldenState.item(0),y_pred10_GoldenState.item(0),y_pred11_GoldenState.item(0),y_pred12_GoldenState.item(0),
                                       y_pred13_GoldenState.item(0),y_pred14_GoldenState.item(0),y_pred15_GoldenState.item(0),y_pred16_GoldenState.item(0),
                                       y_pred17_GoldenState.item(0),y_pred18_GoldenState.item(0),y_pred19_GoldenState.item(0),y_pred20_GoldenState.item(0),
                                       y_pred21_GoldenState.item(0)]}
pd.DataFrame(output)
# Out:
#     GoldenState Actual Team Performance  \
# 0                                    75
# 1                                    75
# 2                                    83
# 3                                    87
# 4                                    85
# 5                                    83
# 6                                    84
# 7                                    86
# 8                                    85
# 9                                    86
# 10                                   85
# 11                                   84
# 12                                   83
# 13                                   83
# 14                                   81
# 15                                   79
# 16                                   80
# 17                                   80
# 18                                   81
# 19                                   82
# 20                                   81
#
#     GoldenState Predicted Team Performance
# ...

# %%
all1 = np.r_[y_train1_GoldenState,y_train2_GoldenState,y_train3_GoldenState,y_train4_GoldenState,y_train5_GoldenState,y_train6_GoldenState,y_train7_GoldenState,
            y_train8_GoldenState,y_train9_GoldenState,y_train10_GoldenState,y_train11_GoldenState,y_train12_GoldenState,y_train13_GoldenState,y_train14_GoldenState,
            y_train15_GoldenState,y_train16_GoldenState,y_train17_GoldenState,y_train18_GoldenState,y_train19_GoldenState,y_train20_GoldenState,y_train21_GoldenState]
all2 = np.r_[y_pred1_GoldenState,y_pred2_GoldenState,y_pred3_GoldenState,y_pred4_GoldenState,y_pred5_GoldenState,y_pred6_GoldenState,y_pred7_GoldenState,
            y_pred8_GoldenState,y_pred9_GoldenState,y_pred10_GoldenState,y_pred11_GoldenState,y_pred12_GoldenState,y_pred13_GoldenState,y_pred14_GoldenState,
            y_pred15_GoldenState,y_pred16_GoldenState,y_pred17_GoldenState,y_pred18_GoldenState,y_pred19_GoldenState,y_pred20_GoldenState,y_pred21_GoldenState]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'GoldenState Target Team Performance Mean', 'GoldenState Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    GoldenState Target Team Performance Mean  \
# 0                                 82.285714
#
#    GoldenState Team Performance Predicted Mean  \
# 0                                    74.334864
#
#    Difference Between Target and Predicted
# 0                                -7.950851

# %%
output = { 'Portland Actual Team Performance' : [y_train1_Portland.iloc[0],y_train2_Portland.iloc[0],y_train3_Portland.iloc[0],y_train4_Portland.iloc[0],
                                       y_train5_Portland.iloc[0],y_train6_Portland.iloc[0],y_train7_Portland.iloc[0],y_train8_Portland.iloc[0],
                                       y_train9_Portland.iloc[0],y_train10_Portland.iloc[0],y_train11_Portland.iloc[0],y_train12_Portland.iloc[0],
                                       y_train13_Portland.iloc[0],y_train14_Portland.iloc[0],y_train15_Portland.iloc[0],y_train16_Portland.iloc[0],
                                       y_train17_Portland.iloc[0],y_train18_Portland.iloc[0],y_train19_Portland.iloc[0],y_train20_Portland.iloc[0],
                                       y_train21_Portland.iloc[0]],  
          'Portland Predicted Team Performance' : [y_pred1_Portland.item(0),y_pred2_Portland.item(0),y_pred3_Portland.item(0),y_pred4_Portland.item(0),
                                       y_pred5_Portland.item(0),y_pred6_Portland.item(0),y_pred7_Portland.item(0),y_pred8_Portland.item(0),
                                       y_pred9_Portland.item(0),y_pred10_Portland.item(0),y_pred11_Portland.item(0),y_pred12_Portland.item(0),
                                       y_pred13_Portland.item(0),y_pred14_Portland.item(0),y_pred15_Portland.item(0),y_pred16_Portland.item(0),
                                       y_pred17_Portland.item(0),y_pred18_Portland.item(0),y_pred19_Portland.item(0),y_pred20_Portland.item(0),
                                       y_pred21_Portland.item(0)]}
pd.DataFrame(output)
# Out:
#     Portland Actual Team Performance  Portland Predicted Team Performance
# 0                                 50                            58.129039
# 1                                 62                            45.835550
# 2                                 58                            40.478298
# 3                                 50                            42.090686
# 4                                 50                            65.798029
# 5                                 50                            48.696333
# 6                                 40                            37.139511
# 7                                 41                            41.838063
# 8                                 42                            70.989004
# 9                                 40                            53.169839
# 10                                43                            44.501538
# 11                                42                            50.760002
# ...

# %%
all1 = np.r_[y_train1_Portland,y_train2_Portland,y_train3_Portland,y_train4_Portland,y_train5_Portland,y_train6_Portland,y_train7_Portland,
            y_train8_Portland,y_train9_Portland,y_train10_Portland,y_train11_Portland,y_train12_Portland,y_train13_Portland,y_train14_Portland,
            y_train15_Portland,y_train16_Portland,y_train17_Portland,y_train18_Portland,y_train19_Portland,y_train20_Portland,y_train21_Portland]
all2 = np.r_[y_pred1_Portland,y_pred2_Portland,y_pred3_Portland,y_pred4_Portland,y_pred5_Portland,y_pred6_Portland,y_pred7_Portland,
            y_pred8_Portland,y_pred9_Portland,y_pred10_Portland,y_pred11_Portland,y_pred12_Portland,y_pred13_Portland,y_pred14_Portland,
            y_pred15_Portland,y_pred16_Portland,y_pred17_Portland,y_pred18_Portland,y_pred19_Portland,y_pred20_Portland,y_pred21_Portland]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'Portland Target Team Performance Mean', 'Portland Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    Portland Target Team Performance Mean  \
# 0                              46.571429
#
#    Portland Team Performance Predicted Mean  \
# 0                                 50.359111
#
#    Difference Between Target and Predicted
# 0                                 3.787682

# %%
output = { 'OklahomaCity Actual Team Performance' : [y_train_OklahomaCity1.iloc[0],y_train_OklahomaCity2.iloc[0],y_train_OklahomaCity3.iloc[0],y_train_OklahomaCity4.iloc[0],
                                       y_train_OklahomaCity5.iloc[0],y_train_OklahomaCity6.iloc[0],y_train_OklahomaCity7.iloc[0],y_train_OklahomaCity8.iloc[0],
                                       y_train_OklahomaCity9.iloc[0],y_train_OklahomaCity10.iloc[0],y_train_OklahomaCity11.iloc[0],y_train_OklahomaCity12.iloc[0],
                                       y_train_OklahomaCity13.iloc[0],y_train_OklahomaCity14.iloc[0],y_train_OklahomaCity15.iloc[0],y_train_OklahomaCity16.iloc[0],
                                       y_train_OklahomaCity17.iloc[0],y_train_OklahomaCity18.iloc[0],y_train_OklahomaCity19.iloc[0],y_train_OklahomaCity20.iloc[0],
                                       y_train_OklahomaCity21.iloc[0]],  
          'OklahomaCity Predicted Team Performance' : [y_pred_OklahomaCity1.item(0),y_pred_OklahomaCity2.item(0),y_pred_OklahomaCity3.item(0),y_pred_OklahomaCity4.item(0),
                                       y_pred_OklahomaCity5.item(0),y_pred_OklahomaCity6.item(0),y_pred_OklahomaCity7.item(0),y_pred_OklahomaCity8.item(0),
                                       y_pred_OklahomaCity9.item(0),y_pred_OklahomaCity10.item(0),y_pred_OklahomaCity11.item(0),y_pred_OklahomaCity12.item(0),
                                       y_pred_OklahomaCity13.item(0),y_pred_OklahomaCity14.item(0),y_pred_OklahomaCity15.item(0),y_pred_OklahomaCity16.item(0),
                                       y_pred_OklahomaCity17.item(0),y_pred_OklahomaCity18.item(0),y_pred_OklahomaCity19.item(0),y_pred_OklahomaCity20.item(0),
                                       y_pred_OklahomaCity21.item(0)]}
pd.DataFrame(output)
# Out:
#     OklahomaCity Actual Team Performance  \
# 0                                    100
# 1                                     75
# 2                                     58
# 3                                     50
# 4                                     60
# 5                                     60
# 6                                     62
# 7                                     58
# 8                                     60
# 9                                     56
# 10                                    58
# 11                                    57
# 12                                    55
# 13                                    58
# 14                                    54
# 15                                    56
# 16                                    57
# 17                                    57
# 18                                    56
# 19                                    56
# 20                                    57
#
#     OklahomaCity Predicted Team Performance
# ...

# %%
all1 = np.r_[y_train_OklahomaCity1,y_train_OklahomaCity2,y_train_OklahomaCity3,y_train_OklahomaCity4,y_train_OklahomaCity5,y_train_OklahomaCity6,y_train_OklahomaCity7,
            y_train_OklahomaCity8,y_train_OklahomaCity9,y_train_OklahomaCity10,y_train_OklahomaCity11,y_train_OklahomaCity12,y_train_OklahomaCity13,y_train_OklahomaCity14,
            y_train_OklahomaCity15,y_train_OklahomaCity16,y_train_OklahomaCity17,y_train_OklahomaCity18,y_train_OklahomaCity19,y_train_OklahomaCity20,y_train_OklahomaCity21]
all2 = np.r_[y_pred_OklahomaCity1,y_pred_OklahomaCity2,y_pred_OklahomaCity3,y_pred_OklahomaCity4,y_pred_OklahomaCity5,y_pred_OklahomaCity6,y_pred_OklahomaCity7,
            y_pred_OklahomaCity8,y_pred_OklahomaCity9,y_pred_OklahomaCity10,y_pred_OklahomaCity11,y_pred_OklahomaCity12,y_pred_OklahomaCity13,y_pred_OklahomaCity14,
            y_pred_OklahomaCity15,y_pred_OklahomaCity16,y_pred_OklahomaCity17,y_pred_OklahomaCity18,y_pred_OklahomaCity19,y_pred_OklahomaCity20,y_pred_OklahomaCity21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'OklahomaCity Target Team Performance Mean', 'OklahomaCity Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    OklahomaCity Target Team Performance Mean  \
# 0                                       60.0
#
#    OklahomaCity Team Performance Predicted Mean  \
# 0                                     48.620752
#
#    Difference Between Target and Predicted
# 0                               -11.379248

# %%
output = { 'Utah Actual Team Performance' : [y_train_Utah1.iloc[0],y_train_Utah2.iloc[0],y_train_Utah3.iloc[0],y_train_Utah4.iloc[0],
                                       y_train_Utah5.iloc[0],y_train_Utah6.iloc[0],y_train_Utah7.iloc[0],y_train_Utah8.iloc[0],
                                       y_train_Utah9.iloc[0],y_train_Utah10.iloc[0],y_train_Utah11.iloc[0],y_train_Utah12.iloc[0],
                                       y_train_Utah13.iloc[0],y_train_Utah14.iloc[0],y_train_Utah15.iloc[0],y_train_Utah16.iloc[0],
                                       y_train_Utah17.iloc[0],y_train_Utah18.iloc[0],y_train_Utah19.iloc[0],y_train_Utah20.iloc[0],
                                       y_train_Utah21.iloc[0]],  
          'Utah Predicted Team Performance' : [y_pred_Utah1.item(0),y_pred_Utah2.item(0),y_pred_Utah3.item(0),y_pred_Utah4.item(0),
                                       y_pred_Utah5.item(0),y_pred_Utah6.item(0),y_pred_Utah7.item(0),y_pred_Utah8.item(0),
                                       y_pred_Utah9.item(0),y_pred_Utah10.item(0),y_pred_Utah11.item(0),y_pred_Utah12.item(0),
                                       y_pred_Utah13.item(0),y_pred_Utah14.item(0),y_pred_Utah15.item(0),y_pred_Utah16.item(0),
                                       y_pred_Utah17.item(0),y_pred_Utah18.item(0),y_pred_Utah19.item(0),y_pred_Utah20.item(0),
                                       y_pred_Utah21.item(0)]}
pd.DataFrame(output)
# Out:
#     Utah Actual Team Performance  Utah Predicted Team Performance
# 0                             50                        39.460164
# 1                             62                        48.380373
# 2                             58                        52.443817
# 3                             50                        26.904356
# 4                             55                        51.804348
# 5                             60                        52.997939
# 6                             59                        36.111400
# 7                             61                        49.142589
# 8                             60                        21.543339
# 9                             63                        57.118998
# 10                            62                        38.807198
# 11                            63                        51.802110
# 12                            60                        51.616526
# ...

# %%
all1 = np.r_[y_train_Utah1,y_train_Utah2,y_train_Utah3,y_train_Utah4,y_train_Utah5,y_train_Utah6,y_train_Utah7,
            y_train_Utah8,y_train_Utah9,y_train_Utah10,y_train_Utah11,y_train_Utah12,y_train_Utah13,y_train_Utah14,
            y_train_Utah15,y_train_Utah16,y_train_Utah17,y_train_Utah18,y_train_Utah19,y_train_Utah20,y_train_Utah21]
all2 = np.r_[y_pred_Utah1,y_pred_Utah2,y_pred_Utah3,y_pred_Utah4,y_pred_Utah5,y_pred_Utah6,y_pred_Utah7,
            y_pred_Utah8,y_pred_Utah9,y_pred_Utah10,y_pred_Utah11,y_pred_Utah12,y_pred_Utah13,y_pred_Utah14,
            y_pred_Utah15,y_pred_Utah16,y_pred_Utah17,y_pred_Utah18,y_pred_Utah19,y_pred_Utah20,y_pred_Utah21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'Utah Target Team Performance Mean', 'Utah Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    Utah Target Team Performance Mean  Utah Team Performance Predicted Mean  \
# 0                          59.714286                             49.076207
#
#    Difference Between Target and Predicted
# 0                               -10.638078

# %%
output = { 'NewOrleans Actual Team Performance' : [y_train_NewOrleans1.iloc[0],y_train_NewOrleans2.iloc[0],y_train_NewOrleans3.iloc[0],y_train_NewOrleans4.iloc[0],
                                       y_train_NewOrleans5.iloc[0],y_train_NewOrleans6.iloc[0],y_train_NewOrleans7.iloc[0],y_train_NewOrleans8.iloc[0],
                                       y_train_NewOrleans9.iloc[0],y_train_NewOrleans10.iloc[0],y_train_NewOrleans11.iloc[0],y_train_NewOrleans12.iloc[0],
                                       y_train_NewOrleans13.iloc[0],y_train_NewOrleans14.iloc[0],y_train_NewOrleans15.iloc[0],y_train_NewOrleans16.iloc[0],
                                       y_train_NewOrleans17.iloc[0],y_train_NewOrleans18.iloc[0],y_train_NewOrleans19.iloc[0],y_train_NewOrleans20.iloc[0],
                                       y_train_NewOrleans21.iloc[0]],  
          'NewOrleans Predicted Team Performance' : [y_pred_NewOrleans1.item(0),y_pred_NewOrleans2.item(0),y_pred_NewOrleans3.item(0),y_pred_NewOrleans4.item(0),
                                       y_pred_NewOrleans5.item(0),y_pred_NewOrleans6.item(0),y_pred_NewOrleans7.item(0),y_pred_NewOrleans8.item(0),
                                       y_pred_NewOrleans9.item(0),y_pred_NewOrleans10.item(0),y_pred_NewOrleans11.item(0),y_pred_NewOrleans12.item(0),
                                       y_pred_NewOrleans13.item(0),y_pred_NewOrleans14.item(0),y_pred_NewOrleans15.item(0),y_pred_NewOrleans16.item(0),
                                       y_pred_NewOrleans17.item(0),y_pred_NewOrleans18.item(0),y_pred_NewOrleans19.item(0),y_pred_NewOrleans20.item(0),
                                       y_pred_NewOrleans21.item(0)]}
pd.DataFrame(output)
# Out:
#     NewOrleans Actual Team Performance  NewOrleans Predicted Team Performance
# 0                                    0                              47.048853
# 1                                    0                              44.690911
# 2                                   18                              41.100801
# 3                                   37                              69.613956
# 4                                   35                              48.978862
# 5                                   29                              38.939099
# 6                                   34                              52.019517
# 7                                   38                              58.475724
# 8                                   40                              44.809160
# 9                                   38                              51.054023
# 10                                  39                              59.014862
# ...

# %%
all1 = np.r_[y_train_NewOrleans1,y_train_NewOrleans2,y_train_NewOrleans3,y_train_NewOrleans4,y_train_NewOrleans5,y_train_NewOrleans6,y_train_NewOrleans7,
            y_train_NewOrleans8,y_train_NewOrleans9,y_train_NewOrleans10,y_train_NewOrleans11,y_train_NewOrleans12,y_train_NewOrleans13,y_train_NewOrleans14,
            y_train_NewOrleans15,y_train_NewOrleans16,y_train_NewOrleans17,y_train_NewOrleans18,y_train_NewOrleans19,y_train_NewOrleans20,y_train_NewOrleans21]
all2 = np.r_[y_pred_NewOrleans1,y_pred_NewOrleans2,y_pred_NewOrleans3,y_pred_NewOrleans4,y_pred_NewOrleans5,y_pred_NewOrleans6,y_pred_NewOrleans7,
            y_pred_NewOrleans8,y_pred_NewOrleans9,y_pred_NewOrleans10,y_pred_NewOrleans11,y_pred_NewOrleans12,y_pred_NewOrleans13,y_pred_NewOrleans14,
            y_pred_NewOrleans15,y_pred_NewOrleans16,y_pred_NewOrleans17,y_pred_NewOrleans18,y_pred_NewOrleans19,y_pred_NewOrleans20,y_pred_NewOrleans21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'NewOrleans Target Team Performance Mean', 'NewOrleans Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    NewOrleans Target Team Performance Mean  \
# 0                                33.809524
#
#    NewOrleans Team Performance Predicted Mean  \
# 0                                   49.196736
#
#    Difference Between Target and Predicted
# 0                                15.387212

# %%
output = { 'SanAntonio Actual Team Performance' : [y_train_SanAntonio1.iloc[0],y_train_SanAntonio2.iloc[0],y_train_SanAntonio3.iloc[0],y_train_SanAntonio4.iloc[0],
                                       y_train_SanAntonio5.iloc[0],y_train_SanAntonio6.iloc[0],y_train_SanAntonio7.iloc[0],y_train_SanAntonio8.iloc[0],
                                       y_train_SanAntonio9.iloc[0],y_train_SanAntonio10.iloc[0],y_train_SanAntonio11.iloc[0],y_train_SanAntonio12.iloc[0],
                                       y_train_SanAntonio13.iloc[0],y_train_SanAntonio14.iloc[0],y_train_SanAntonio15.iloc[0],y_train_SanAntonio16.iloc[0],
                                       y_train_SanAntonio17.iloc[0],y_train_SanAntonio18.iloc[0],y_train_SanAntonio19.iloc[0],y_train_SanAntonio20.iloc[0],
                                       y_train_SanAntonio21.iloc[0]],  
          'SanAntonio Predicted Team Performance' : [y_pred_SanAntonio1.item(0),y_pred_SanAntonio2.item(0),y_pred_SanAntonio3.item(0),y_pred_SanAntonio4.item(0),
                                       y_pred_SanAntonio5.item(0),y_pred_SanAntonio6.item(0),y_pred_SanAntonio7.item(0),y_pred_SanAntonio8.item(0),
                                       y_pred_SanAntonio9.item(0),y_pred_SanAntonio10.item(0),y_pred_SanAntonio11.item(0),y_pred_SanAntonio12.item(0),
                                       y_pred_SanAntonio13.item(0),y_pred_SanAntonio14.item(0),y_pred_SanAntonio15.item(0),y_pred_SanAntonio16.item(0),
                                       y_pred_SanAntonio17.item(0),y_pred_SanAntonio18.item(0),y_pred_SanAntonio19.item(0),y_pred_SanAntonio20.item(0),
                                       y_pred_SanAntonio21.item(0)]}
pd.DataFrame(output)
# Out:
#     SanAntonio Actual Team Performance  SanAntonio Predicted Team Performance
# 0                                  100                              80.630002
# 1                                   62                              38.348492
# 2                                   75                              58.815218
# 3                                   81                              66.805634
# 4                                   80                              48.010182
# 5                                   79                              59.503259
# 6                                   81                              65.648152
# 7                                   80                              63.994024
# 8                                   77                              61.735620
# 9                                   79                              59.365283
# 10                                  77                              36.540838
# ...

# %%
all1 = np.r_[y_train_SanAntonio1,y_train_SanAntonio2,y_train_SanAntonio3,y_train_SanAntonio4,y_train_SanAntonio5,y_train_SanAntonio6,y_train_SanAntonio7,
            y_train_SanAntonio8,y_train_SanAntonio9,y_train_SanAntonio10,y_train_SanAntonio11,y_train_SanAntonio12,y_train_SanAntonio13,y_train_SanAntonio14,
            y_train_SanAntonio15,y_train_SanAntonio16,y_train_SanAntonio17,y_train_SanAntonio18,y_train_SanAntonio19,y_train_SanAntonio20,y_train_SanAntonio21]
all2 = np.r_[y_pred_SanAntonio1,y_pred_SanAntonio2,y_pred_SanAntonio3,y_pred_SanAntonio4,y_pred_SanAntonio5,y_pred_SanAntonio6,y_pred_SanAntonio7,
            y_pred_SanAntonio8,y_pred_SanAntonio9,y_pred_SanAntonio10,y_pred_SanAntonio11,y_pred_SanAntonio12,y_pred_SanAntonio13,y_pred_SanAntonio14,
            y_pred_SanAntonio15,y_pred_SanAntonio16,y_pred_SanAntonio17,y_pred_SanAntonio18,y_pred_SanAntonio19,y_pred_SanAntonio20,y_pred_SanAntonio21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'SanAntonio Target Team Performance Mean', 'SanAntonio Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    SanAntonio Target Team Performance Mean  \
# 0                                78.047619
#
#    SanAntonio Team Performance Predicted Mean  \
# 0                                   56.356469
#
#    Difference Between Target and Predicted
# 0                                -21.69115

# %%
output = { 'Minnesota Actual Team Performance' : [y_train_Minnesota1.iloc[0],y_train_Minnesota2.iloc[0],y_train_Minnesota3.iloc[0],y_train_Minnesota4.iloc[0],
                                       y_train_Minnesota5.iloc[0],y_train_Minnesota6.iloc[0],y_train_Minnesota7.iloc[0],y_train_Minnesota8.iloc[0],
                                       y_train_Minnesota9.iloc[0],y_train_Minnesota10.iloc[0],y_train_Minnesota11.iloc[0],y_train_Minnesota12.iloc[0],
                                       y_train_Minnesota13.iloc[0],y_train_Minnesota14.iloc[0],y_train_Minnesota15.iloc[0],y_train_Minnesota16.iloc[0],
                                       y_train_Minnesota17.iloc[0],y_train_Minnesota18.iloc[0],y_train_Minnesota19.iloc[0],y_train_Minnesota20.iloc[0],
                                       y_train_Minnesota21.iloc[0]],  
          'Minnesota Predicted Team Performance' : [y_pred_Minnesota1.item(0),y_pred_Minnesota2.item(0),y_pred_Minnesota3.item(0),y_pred_Minnesota4.item(0),
                                       y_pred_Minnesota5.item(0),y_pred_Minnesota6.item(0),y_pred_Minnesota7.item(0),y_pred_Minnesota8.item(0),
                                       y_pred_Minnesota9.item(0),y_pred_Minnesota10.item(0),y_pred_Minnesota11.item(0),y_pred_Minnesota12.item(0),
                                       y_pred_Minnesota13.item(0),y_pred_Minnesota14.item(0),y_pred_Minnesota15.item(0),y_pred_Minnesota16.item(0),
                                       y_pred_Minnesota17.item(0),y_pred_Minnesota18.item(0),y_pred_Minnesota19.item(0),y_pred_Minnesota20.item(0),
                                       y_pred_Minnesota21.item(0)]}
pd.DataFrame(output)
# Out:
#     Minnesota Actual Team Performance  Minnesota Predicted Team Performance
# 0                                  25                             35.807714
# 1                                  25                             49.528663
# 2                                  36                             35.588484
# 3                                  31                             37.711689
# 4                                  30                             41.560986
# 5                                  25                             31.350007
# 6                                  31                             47.441312
# 7                                  30                             42.622034
# 8                                  35                             25.144689
# 9                                  36                             43.093083
# 10                                 39                             62.792538
# ...

# %%
all1 = np.r_[y_train_Minnesota1,y_train_Minnesota2,y_train_Minnesota3,y_train_Minnesota4,y_train_Minnesota5,y_train_Minnesota6,y_train_Minnesota7,
            y_train_Minnesota8,y_train_Minnesota9,y_train_Minnesota10,y_train_Minnesota11,y_train_Minnesota12,y_train_Minnesota13,y_train_Minnesota14,
            y_train_Minnesota15,y_train_Minnesota16,y_train_Minnesota17,y_train_Minnesota18,y_train_Minnesota19,y_train_Minnesota20,y_train_Minnesota21]
all2 = np.r_[y_pred_Minnesota1,y_pred_Minnesota2,y_pred_Minnesota3,y_pred_Minnesota4,y_pred_Minnesota5,y_pred_Minnesota6,y_pred_Minnesota7,
            y_pred_Minnesota8,y_pred_Minnesota9,y_pred_Minnesota10,y_pred_Minnesota11,y_pred_Minnesota12,y_pred_Minnesota13,y_pred_Minnesota14,
            y_pred_Minnesota15,y_pred_Minnesota16,y_pred_Minnesota17,y_pred_Minnesota18,y_pred_Minnesota19,y_pred_Minnesota20,y_pred_Minnesota21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'Minnesota Target Team Performance Mean', 'Minnesota Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    Minnesota Target Team Performance Mean  \
# 0                               34.952381
#
#    Minnesota Team Performance Predicted Mean  \
# 0                                  44.516283
#
#    Difference Between Target and Predicted
# 0                                 9.563903

# %%
output = { 'Denver Actual Team Performance' : [y_train_Denver1.iloc[0],y_train_Denver2.iloc[0],y_train_Denver3.iloc[0],y_train_Denver4.iloc[0],
                                       y_train_Denver5.iloc[0],y_train_Denver6.iloc[0],y_train_Denver7.iloc[0],y_train_Denver8.iloc[0],
                                       y_train_Denver9.iloc[0],y_train_Denver10.iloc[0],y_train_Denver11.iloc[0],y_train_Denver12.iloc[0],
                                       y_train_Denver13.iloc[0],y_train_Denver14.iloc[0],y_train_Denver15.iloc[0],y_train_Denver16.iloc[0],
                                       y_train_Denver17.iloc[0],y_train_Denver18.iloc[0],y_train_Denver19.iloc[0],y_train_Denver20.iloc[0],
                                       y_train_Denver21.iloc[0]],  
          'Denver Predicted Team Performance' : [y_pred_Denver1.item(0),y_pred_Denver2.item(0),y_pred_Denver3.item(0),y_pred_Denver4.item(0),
                                       y_pred_Denver5.item(0),y_pred_Denver6.item(0),y_pred_Denver7.item(0),y_pred_Denver8.item(0),
                                       y_pred_Denver9.item(0),y_pred_Denver10.item(0),y_pred_Denver11.item(0),y_pred_Denver12.item(0),
                                       y_pred_Denver13.item(0),y_pred_Denver14.item(0),y_pred_Denver15.item(0),y_pred_Denver16.item(0),
                                       y_pred_Denver17.item(0),y_pred_Denver18.item(0),y_pred_Denver19.item(0),y_pred_Denver20.item(0),
                                       y_pred_Denver21.item(0)]}
pd.DataFrame(output)
# Out:
#     Denver Actual Team Performance  Denver Predicted Team Performance
# 0                               50                          57.302977
# 1                               37                          29.649260
# 2                               33                          45.774253
# 3                               37                          46.754728
# 4                               35                          43.341962
# 5                               37                          31.176069
# 6                               43                          50.404412
# 7                               38                          34.634263
# 8                               42                          73.930414
# 9                               43                          38.270740
# 10                              43                          69.380281
# 11                              44                          51.619210
# ...

# %%
all1 = np.r_[y_train_Denver1,y_train_Denver2,y_train_Denver3,y_train_Denver4,y_train_Denver5,y_train_Denver6,y_train_Denver7,
            y_train_Denver8,y_train_Denver9,y_train_Denver10,y_train_Denver11,y_train_Denver12,y_train_Denver13,y_train_Denver14,
            y_train_Denver15,y_train_Denver16,y_train_Denver17,y_train_Denver18,y_train_Denver19,y_train_Denver20,y_train_Denver21]
all2 = np.r_[y_pred_Denver1,y_pred_Denver2,y_pred_Denver3,y_pred_Denver4,y_pred_Denver5,y_pred_Denver6,y_pred_Denver7,
            y_pred_Denver8,y_pred_Denver9,y_pred_Denver10,y_pred_Denver11,y_pred_Denver12,y_pred_Denver13,y_pred_Denver14,
            y_pred_Denver15,y_pred_Denver16,y_pred_Denver17,y_pred_Denver18,y_pred_Denver19,y_pred_Denver20,y_pred_Denver21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'Denver Target Team Performance Mean', 'Denver Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    Denver Target Team Performance Mean  \
# 0                            42.857143
#
#    Denver Team Performance Predicted Mean  \
# 0                               49.948957
#
#    Difference Between Target and Predicted
# 0                                 7.091814

# %%
output = { 'LosAngelesClippers Actual Team Performance' : [y_train_LosAngelesClippers1.iloc[0],y_train_LosAngelesClippers2.iloc[0],y_train_LosAngelesClippers3.iloc[0],y_train_LosAngelesClippers4.iloc[0],
                                       y_train_LosAngelesClippers5.iloc[0],y_train_LosAngelesClippers6.iloc[0],y_train_LosAngelesClippers7.iloc[0],y_train_LosAngelesClippers8.iloc[0],
                                       y_train_LosAngelesClippers9.iloc[0],y_train_LosAngelesClippers10.iloc[0],y_train_LosAngelesClippers11.iloc[0],y_train_LosAngelesClippers12.iloc[0],
                                       y_train_LosAngelesClippers13.iloc[0],y_train_LosAngelesClippers14.iloc[0],y_train_LosAngelesClippers15.iloc[0],y_train_LosAngelesClippers16.iloc[0],
                                       y_train_LosAngelesClippers17.iloc[0],y_train_LosAngelesClippers18.iloc[0],y_train_LosAngelesClippers19.iloc[0],y_train_LosAngelesClippers20.iloc[0],
                                       y_train_LosAngelesClippers21.iloc[0]],  
          'LosAngelesClippers Predicted Team Performance' : [y_pred_LosAngelesClippers1.item(0),y_pred_LosAngelesClippers2.item(0),y_pred_LosAngelesClippers3.item(0),y_pred_LosAngelesClippers4.item(0),
                                       y_pred_LosAngelesClippers5.item(0),y_pred_LosAngelesClippers6.item(0),y_pred_LosAngelesClippers7.item(0),y_pred_LosAngelesClippers8.item(0),
                                       y_pred_LosAngelesClippers9.item(0),y_pred_LosAngelesClippers10.item(0),y_pred_LosAngelesClippers11.item(0),y_pred_LosAngelesClippers12.item(0),
                                       y_pred_LosAngelesClippers13.item(0),y_pred_LosAngelesClippers14.item(0),y_pred_LosAngelesClippers15.item(0),y_pred_LosAngelesClippers16.item(0),
                                       y_pred_LosAngelesClippers17.item(0),y_pred_LosAngelesClippers18.item(0),y_pred_LosAngelesClippers19.item(0),y_pred_LosAngelesClippers20.item(0),
                                       y_pred_LosAngelesClippers21.item(0)]}
pd.DataFrame(output)
# Out:
#     LosAngelesClippers Actual Team Performance  \
# 0                                           75
# 1                                           87
# 2                                           83
# 3                                           87
# 4                                           75
# 5                                           70
# 6                                           64
# 7                                           70
# 8                                           65
# 9                                           65
# 10                                          62
# 11                                          59
# 12                                          62
# 13                                          60
# 14                                          59
# 15                                          59
# 16                                          58
# 17                                          58
# 18                                          59
# ...

# %%
all1 = np.r_[y_train_LosAngelesClippers1,y_train_LosAngelesClippers2,y_train_LosAngelesClippers3,y_train_LosAngelesClippers4,y_train_LosAngelesClippers5,y_train_LosAngelesClippers6,y_train_LosAngelesClippers7,
            y_train_LosAngelesClippers8,y_train_LosAngelesClippers9,y_train_LosAngelesClippers10,y_train_LosAngelesClippers11,y_train_LosAngelesClippers12,y_train_LosAngelesClippers13,y_train_LosAngelesClippers14,
            y_train_LosAngelesClippers15,y_train_LosAngelesClippers16,y_train_LosAngelesClippers17,y_train_LosAngelesClippers18,y_train_LosAngelesClippers19,y_train_LosAngelesClippers20,y_train_LosAngelesClippers21]
all2 = np.r_[y_pred_LosAngelesClippers1,y_pred_LosAngelesClippers2,y_pred_LosAngelesClippers3,y_pred_LosAngelesClippers4,y_pred_LosAngelesClippers5,y_pred_LosAngelesClippers6,y_pred_LosAngelesClippers7,
            y_pred_LosAngelesClippers8,y_pred_LosAngelesClippers9,y_pred_LosAngelesClippers10,y_pred_LosAngelesClippers11,y_pred_LosAngelesClippers12,y_pred_LosAngelesClippers13,y_pred_LosAngelesClippers14,
            y_pred_LosAngelesClippers15,y_pred_LosAngelesClippers16,y_pred_LosAngelesClippers17,y_pred_LosAngelesClippers18,y_pred_LosAngelesClippers19,y_pred_LosAngelesClippers20,y_pred_LosAngelesClippers21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'LosAngelesClippers Target Team Performance Mean', 'LosAngelesClippers Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    LosAngelesClippers Target Team Performance Mean  \
# 0                                        66.619048
#
#    LosAngelesClippers Team Performance Predicted Mean  \
# 0                                           54.87922
#
#    Difference Between Target and Predicted
# 0                               -11.739828

# %%
output = { 'Toronto Actual Team Performance' : [y_train_Toronto1.iloc[0],y_train_Toronto2.iloc[0],y_train_Toronto3.iloc[0],y_train_Toronto4.iloc[0],
                                       y_train_Toronto5.iloc[0],y_train_Toronto6.iloc[0],y_train_Toronto7.iloc[0],y_train_Toronto8.iloc[0],
                                       y_train_Toronto9.iloc[0],y_train_Toronto10.iloc[0],y_train_Toronto11.iloc[0],y_train_Toronto12.iloc[0],
                                       y_train_Toronto13.iloc[0],y_train_Toronto14.iloc[0],y_train_Toronto15.iloc[0],y_train_Toronto16.iloc[0],
                                       y_train_Toronto17.iloc[0],y_train_Toronto18.iloc[0],y_train_Toronto19.iloc[0],y_train_Toronto20.iloc[0],
                                       y_train_Toronto21.iloc[0]],  
          'Toronto Predicted Team Performance' : [y_pred_Toronto1.item(0),y_pred_Toronto2.item(0),y_pred_Toronto3.item(0),y_pred_Toronto4.item(0),
                                       y_pred_Toronto5.item(0),y_pred_Toronto6.item(0),y_pred_Toronto7.item(0),y_pred_Toronto8.item(0),
                                       y_pred_Toronto9.item(0),y_pred_Toronto10.item(0),y_pred_Toronto11.item(0),y_pred_Toronto12.item(0),
                                       y_pred_Toronto13.item(0),y_pred_Toronto14.item(0),y_pred_Toronto15.item(0),y_pred_Toronto16.item(0),
                                       y_pred_Toronto17.item(0),y_pred_Toronto18.item(0),y_pred_Toronto19.item(0),y_pred_Toronto20.item(0),
                                       y_pred_Toronto21.item(0)]}
pd.DataFrame(output)
# Out:
#     Toronto Actual Team Performance  Toronto Predicted Team Performance
# 0                                75                           56.630682
# 1                                75                           56.302211
# 2                                66                           53.122714
# 3                                62                           59.222488
# 4                                70                           79.013882
# 5                                70                           62.535563
# 6                                70                           49.509098
# 7                                66                           42.774246
# 8                                67                           83.863237
# 9                                63                           37.505208
# 10                               60                           43.845687
# 11                               59                           49.057269
# ...

# %%
all1 = np.r_[y_train_Toronto1,y_train_Toronto2,y_train_Toronto3,y_train_Toronto4,y_train_Toronto5,y_train_Toronto6,y_train_Toronto7,
            y_train_Toronto8,y_train_Toronto9,y_train_Toronto10,y_train_Toronto11,y_train_Toronto12,y_train_Toronto13,y_train_Toronto14,
            y_train_Toronto15,y_train_Toronto16,y_train_Toronto17,y_train_Toronto18,y_train_Toronto19,y_train_Toronto20,y_train_Toronto21]
all2 = np.r_[y_pred_Toronto1,y_pred_Toronto2,y_pred_Toronto3,y_pred_Toronto4,y_pred_Toronto5,y_pred_Toronto6,y_pred_Toronto7,
            y_pred_Toronto8,y_pred_Toronto9,y_pred_Toronto10,y_pred_Toronto11,y_pred_Toronto12,y_pred_Toronto13,y_pred_Toronto14,
            y_pred_Toronto15,y_pred_Toronto16,y_pred_Toronto17,y_pred_Toronto18,y_pred_Toronto19,y_pred_Toronto20,y_pred_Toronto21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'Toronto Target Team Performance Mean', 'Toronto Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    Toronto Target Team Performance Mean  \
# 0                             63.666667
#
#    Toronto Team Performance Predicted Mean  \
# 0                                  52.4752
#
#    Difference Between Target and Predicted
# 0                               -11.191467

# %%
output = { 'Boston Actual Team Performance' : [y_train_Boston1.iloc[0],y_train_Boston2.iloc[0],y_train_Boston3.iloc[0],y_train_Boston4.iloc[0],
                                       y_train_Boston5.iloc[0],y_train_Boston6.iloc[0],y_train_Boston7.iloc[0],y_train_Boston8.iloc[0],
                                       y_train_Boston9.iloc[0],y_train_Boston10.iloc[0],y_train_Boston11.iloc[0],y_train_Boston12.iloc[0],
                                       y_train_Boston13.iloc[0],y_train_Boston14.iloc[0],y_train_Boston15.iloc[0],y_train_Boston16.iloc[0],
                                       y_train_Boston17.iloc[0],y_train_Boston18.iloc[0],y_train_Boston19.iloc[0],y_train_Boston20.iloc[0],
                                       y_train_Boston21.iloc[0]],  
          'Boston Predicted Team Performance' : [y_pred_Boston1.item(0),y_pred_Boston2.item(0),y_pred_Boston3.item(0),y_pred_Boston4.item(0),
                                       y_pred_Boston5.item(0),y_pred_Boston6.item(0),y_pred_Boston7.item(0),y_pred_Boston8.item(0),
                                       y_pred_Boston9.item(0),y_pred_Boston10.item(0),y_pred_Boston11.item(0),y_pred_Boston12.item(0),
                                       y_pred_Boston13.item(0),y_pred_Boston14.item(0),y_pred_Boston15.item(0),y_pred_Boston16.item(0),
                                       y_pred_Boston17.item(0),y_pred_Boston18.item(0),y_pred_Boston19.item(0),y_pred_Boston20.item(0),
                                       y_pred_Boston21.item(0)]}
pd.DataFrame(output)
# Out:
#     Boston Actual Team Performance  Boston Predicted Team Performance
# 0                               75                          81.445136
# 1                               50                          56.255956
# 2                               50                          44.823242
# 3                               56                          43.197540
# 4                               60                          46.944881
# 5                               52                          42.952715
# 6                               59                          51.821249
# 7                               61                          54.364778
# 8                               62                          59.899857
# 9                               59                          54.307291
# 10                              62                          65.508035
# 11                              63                          57.252091
# ...

# %%
all1 = np.r_[y_train_Boston1,y_train_Boston2,y_train_Boston3,y_train_Boston4,y_train_Boston5,y_train_Boston6,y_train_Boston7,
            y_train_Boston8,y_train_Boston9,y_train_Boston10,y_train_Boston11,y_train_Boston12,y_train_Boston13,y_train_Boston14,
            y_train_Boston15,y_train_Boston16,y_train_Boston17,y_train_Boston18,y_train_Boston19,y_train_Boston20,y_train_Boston21]
all2 = np.r_[y_pred_Boston1,y_pred_Boston2,y_pred_Boston3,y_pred_Boston4,y_pred_Boston5,y_pred_Boston6,y_pred_Boston7,
            y_pred_Boston8,y_pred_Boston9,y_pred_Boston10,y_pred_Boston11,y_pred_Boston12,y_pred_Boston13,y_pred_Boston14,
            y_pred_Boston15,y_pred_Boston16,y_pred_Boston17,y_pred_Boston18,y_pred_Boston19,y_pred_Boston20,y_pred_Boston21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'Boston Target Team Performance Mean', 'Boston Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    Boston Target Team Performance Mean  \
# 0                            60.904762
#
#    Boston Team Performance Predicted Mean  \
# 0                               55.382682
#
#    Difference Between Target and Predicted
# 0                                 -5.52208

# %%
output = { 'Philadelphia Actual Team Performance' : [y_train_Philadelphia1.iloc[0],y_train_Philadelphia2.iloc[0],y_train_Philadelphia3.iloc[0],y_train_Philadelphia4.iloc[0],
                                       y_train_Philadelphia5.iloc[0],y_train_Philadelphia6.iloc[0],y_train_Philadelphia7.iloc[0],y_train_Philadelphia8.iloc[0],
                                       y_train_Philadelphia9.iloc[0],y_train_Philadelphia10.iloc[0],y_train_Philadelphia11.iloc[0],y_train_Philadelphia12.iloc[0],
                                       y_train_Philadelphia13.iloc[0],y_train_Philadelphia14.iloc[0],y_train_Philadelphia15.iloc[0],y_train_Philadelphia16.iloc[0],
                                       y_train_Philadelphia17.iloc[0],y_train_Philadelphia18.iloc[0],y_train_Philadelphia19.iloc[0],y_train_Philadelphia20.iloc[0],
                                       y_train_Philadelphia21.iloc[0]],  
          'Philadelphia Predicted Team Performance' : [y_pred_Philadelphia1.item(0),y_pred_Philadelphia2.item(0),y_pred_Philadelphia3.item(0),y_pred_Philadelphia4.item(0),
                                       y_pred_Philadelphia5.item(0),y_pred_Philadelphia6.item(0),y_pred_Philadelphia7.item(0),y_pred_Philadelphia8.item(0),
                                       y_pred_Philadelphia9.item(0),y_pred_Philadelphia10.item(0),y_pred_Philadelphia11.item(0),y_pred_Philadelphia12.item(0),
                                       y_pred_Philadelphia13.item(0),y_pred_Philadelphia14.item(0),y_pred_Philadelphia15.item(0),y_pred_Philadelphia16.item(0),
                                       y_pred_Philadelphia17.item(0),y_pred_Philadelphia18.item(0),y_pred_Philadelphia19.item(0),y_pred_Philadelphia20.item(0),
                                       y_pred_Philadelphia21.item(0)]}
pd.DataFrame(output)
# Out:
#     Philadelphia Actual Team Performance  \
# 0                                      0
# 1                                     12
# 2                                     18
# 3                                     25
# 4                                     20
# 5                                     25
# 6                                     25
# 7                                     30
# 8                                     35
# 9                                     38
# 10                                    37
# 11                                    34
# 12                                    37
# 13                                    36
# 14                                    35
# 15                                    35
# 16                                    37
# 17                                    36
# 18                                    36
# 19                                    35
# 20                                    34
#
#     Philadelphia Predicted Team Performance
# ...

# %%
all1 = np.r_[y_train_Philadelphia1,y_train_Philadelphia2,y_train_Philadelphia3,y_train_Philadelphia4,y_train_Philadelphia5,y_train_Philadelphia6,y_train_Philadelphia7,
            y_train_Philadelphia8,y_train_Philadelphia9,y_train_Philadelphia10,y_train_Philadelphia11,y_train_Philadelphia12,y_train_Philadelphia13,y_train_Philadelphia14,
            y_train_Philadelphia15,y_train_Philadelphia16,y_train_Philadelphia17,y_train_Philadelphia18,y_train_Philadelphia19,y_train_Philadelphia20,y_train_Philadelphia21]
all2 = np.r_[y_pred_Philadelphia1,y_pred_Philadelphia2,y_pred_Philadelphia3,y_pred_Philadelphia4,y_pred_Philadelphia5,y_pred_Philadelphia6,y_pred_Philadelphia7,
            y_pred_Philadelphia8,y_pred_Philadelphia9,y_pred_Philadelphia10,y_pred_Philadelphia11,y_pred_Philadelphia12,y_pred_Philadelphia13,y_pred_Philadelphia14,
            y_pred_Philadelphia15,y_pred_Philadelphia16,y_pred_Philadelphia17,y_pred_Philadelphia18,y_pred_Philadelphia19,y_pred_Philadelphia20,y_pred_Philadelphia21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'Philadelphia Target Team Performance Mean', 'Philadelphia Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    Philadelphia Target Team Performance Mean  \
# 0                                   29.52381
#
#    Philadelphia Team Performance Predicted Mean  \
# 0                                     43.470359
#
#    Difference Between Target and Predicted
# 0                                 13.94655

# %%
output = { 'Cleveland Actual Team Performance' : [y_train_Cleveland1.iloc[0],y_train_Cleveland2.iloc[0],y_train_Cleveland3.iloc[0],y_train_Cleveland4.iloc[0],
                                       y_train_Cleveland5.iloc[0],y_train_Cleveland6.iloc[0],y_train_Cleveland7.iloc[0],y_train_Cleveland8.iloc[0],
                                       y_train_Cleveland9.iloc[0],y_train_Cleveland10.iloc[0],y_train_Cleveland11.iloc[0],y_train_Cleveland12.iloc[0],
                                       y_train_Cleveland13.iloc[0],y_train_Cleveland14.iloc[0],y_train_Cleveland15.iloc[0],y_train_Cleveland16.iloc[0],
                                       y_train_Cleveland17.iloc[0],y_train_Cleveland18.iloc[0],y_train_Cleveland19.iloc[0],y_train_Cleveland20.iloc[0],
                                       y_train_Cleveland21.iloc[0]],  
          'Cleveland Predicted Team Performance' : [y_pred_Cleveland1.item(0),y_pred_Cleveland2.item(0),y_pred_Cleveland3.item(0),y_pred_Cleveland4.item(0),
                                       y_pred_Cleveland5.item(0),y_pred_Cleveland6.item(0),y_pred_Cleveland7.item(0),y_pred_Cleveland8.item(0),
                                       y_pred_Cleveland9.item(0),y_pred_Cleveland10.item(0),y_pred_Cleveland11.item(0),y_pred_Cleveland12.item(0),
                                       y_pred_Cleveland13.item(0),y_pred_Cleveland14.item(0),y_pred_Cleveland15.item(0),y_pred_Cleveland16.item(0),
                                       y_pred_Cleveland17.item(0),y_pred_Cleveland18.item(0),y_pred_Cleveland19.item(0),y_pred_Cleveland20.item(0),
                                       y_pred_Cleveland21.item(0)]}
pd.DataFrame(output)
# Out:
#     Cleveland Actual Team Performance  Cleveland Predicted Team Performance
# 0                                 100                             70.280489
# 1                                  87                             68.775430
# 2                                  83                             91.302572
# 3                                  81                             70.323333
# 4                                  73                             63.679037
# 5                                  76                             63.134276
# 6                                  78                             51.385992
# 7                                  77                             45.182908
# 8                                  72                             43.870593
# 9                                  68                             61.895794
# 10                                 68                             63.015614
# ...

# %%
all1 = np.r_[y_train_Cleveland1,y_train_Cleveland2,y_train_Cleveland3,y_train_Cleveland4,y_train_Cleveland5,y_train_Cleveland6,y_train_Cleveland7,
            y_train_Cleveland8,y_train_Cleveland9,y_train_Cleveland10,y_train_Cleveland11,y_train_Cleveland12,y_train_Cleveland13,y_train_Cleveland14,
            y_train_Cleveland15,y_train_Cleveland16,y_train_Cleveland17,y_train_Cleveland18,y_train_Cleveland19,y_train_Cleveland20,y_train_Cleveland21]
all2 = np.r_[y_pred_Cleveland1,y_pred_Cleveland2,y_pred_Cleveland3,y_pred_Cleveland4,y_pred_Cleveland5,y_pred_Cleveland6,y_pred_Cleveland7,
            y_pred_Cleveland8,y_pred_Cleveland9,y_pred_Cleveland10,y_pred_Cleveland11,y_pred_Cleveland12,y_pred_Cleveland13,y_pred_Cleveland14,
            y_pred_Cleveland15,y_pred_Cleveland16,y_pred_Cleveland17,y_pred_Cleveland18,y_pred_Cleveland19,y_pred_Cleveland20,y_pred_Cleveland21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'Cleveland Target Team Performance Mean', 'Cleveland Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    Cleveland Target Team Performance Mean  \
# 0                               72.666667
#
#    Cleveland Team Performance Predicted Mean  \
# 0                                  61.661351
#
#    Difference Between Target and Predicted
# 0                               -11.005315

# %%
output = { 'Indiana Actual Team Performance' : [y_train_Indiana1.iloc[0],y_train_Indiana2.iloc[0],y_train_Indiana3.iloc[0],y_train_Indiana4.iloc[0],
                                       y_train_Indiana5.iloc[0],y_train_Indiana6.iloc[0],y_train_Indiana7.iloc[0],y_train_Indiana8.iloc[0],
                                       y_train_Indiana9.iloc[0],y_train_Indiana10.iloc[0],y_train_Indiana11.iloc[0],y_train_Indiana12.iloc[0],
                                       y_train_Indiana13.iloc[0],y_train_Indiana14.iloc[0],y_train_Indiana15.iloc[0],y_train_Indiana16.iloc[0],
                                       y_train_Indiana17.iloc[0],y_train_Indiana18.iloc[0],y_train_Indiana19.iloc[0],y_train_Indiana20.iloc[0],
                                       y_train_Indiana21.iloc[0]],  
          'Indiana Predicted Team Performance' : [y_pred_Indiana1.item(0),y_pred_Indiana2.item(0),y_pred_Indiana3.item(0),y_pred_Indiana4.item(0),
                                       y_pred_Indiana5.item(0),y_pred_Indiana6.item(0),y_pred_Indiana7.item(0),y_pred_Indiana8.item(0),
                                       y_pred_Indiana9.item(0),y_pred_Indiana10.item(0),y_pred_Indiana11.item(0),y_pred_Indiana12.item(0),
                                       y_pred_Indiana13.item(0),y_pred_Indiana14.item(0),y_pred_Indiana15.item(0),y_pred_Indiana16.item(0),
                                       y_pred_Indiana17.item(0),y_pred_Indiana18.item(0),y_pred_Indiana19.item(0),y_pred_Indiana20.item(0),
                                       y_pred_Indiana21.item(0)]}
pd.DataFrame(output)
# Out:
#     Indiana Actual Team Performance  Indiana Predicted Team Performance
# 0                                50                           72.997433
# 1                                50                           51.562131
# 2                                50                           53.293608
# 3                                43                           33.150056
# 4                                50                           57.882951
# 5                                50                           56.361801
# 6                                46                           46.360602
# 7                                50                           40.884990
# 8                                52                           62.320393
# 9                                50                           47.984862
# 10                               54                           53.209354
# 11                               55                           46.263175
# ...

# %%
all1 = np.r_[y_train_Indiana1,y_train_Indiana2,y_train_Indiana3,y_train_Indiana4,y_train_Indiana5,y_train_Indiana6,y_train_Indiana7,
            y_train_Indiana8,y_train_Indiana9,y_train_Indiana10,y_train_Indiana11,y_train_Indiana12,y_train_Indiana13,y_train_Indiana14,
            y_train_Indiana15,y_train_Indiana16,y_train_Indiana17,y_train_Indiana18,y_train_Indiana19,y_train_Indiana20,y_train_Indiana21]
all2 = np.r_[y_pred_Indiana1,y_pred_Indiana2,y_pred_Indiana3,y_pred_Indiana4,y_pred_Indiana5,y_pred_Indiana6,y_pred_Indiana7,
            y_pred_Indiana8,y_pred_Indiana9,y_pred_Indiana10,y_pred_Indiana11,y_pred_Indiana12,y_pred_Indiana13,y_pred_Indiana14,
            y_pred_Indiana15,y_pred_Indiana16,y_pred_Indiana17,y_pred_Indiana18,y_pred_Indiana19,y_pred_Indiana20,y_pred_Indiana21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'Indiana Target Team Performance Mean', 'Indiana Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    Indiana Target Team Performance Mean  \
# 0                             50.095238
#
#    Indiana Team Performance Predicted Mean  \
# 0                                49.917862
#
#    Difference Between Target and Predicted
# 0                                -0.177377

# %%
output = { 'LosAngelesLakers Actual Team Performance' : [y_train_LosAngelesLakers1.iloc[0],y_train_LosAngelesLakers2.iloc[0],y_train_LosAngelesLakers3.iloc[0],y_train_LosAngelesLakers4.iloc[0],
                                       y_train_LosAngelesLakers5.iloc[0],y_train_LosAngelesLakers6.iloc[0],y_train_LosAngelesLakers7.iloc[0],y_train_LosAngelesLakers8.iloc[0],
                                       y_train_LosAngelesLakers9.iloc[0],y_train_LosAngelesLakers10.iloc[0],y_train_LosAngelesLakers11.iloc[0],y_train_LosAngelesLakers12.iloc[0],
                                       y_train_LosAngelesLakers13.iloc[0],y_train_LosAngelesLakers14.iloc[0],y_train_LosAngelesLakers15.iloc[0],y_train_LosAngelesLakers16.iloc[0],
                                       y_train_LosAngelesLakers17.iloc[0],y_train_LosAngelesLakers18.iloc[0],y_train_LosAngelesLakers19.iloc[0],y_train_LosAngelesLakers20.iloc[0],
                                       y_train_LosAngelesLakers21.iloc[0]],  
          'LosAngelesLakers Predicted Team Performance' : [y_pred_LosAngelesLakers1.item(0),y_pred_LosAngelesLakers2.item(0),y_pred_LosAngelesLakers3.item(0),y_pred_LosAngelesLakers4.item(0),
                                       y_pred_LosAngelesLakers5.item(0),y_pred_LosAngelesLakers6.item(0),y_pred_LosAngelesLakers7.item(0),y_pred_LosAngelesLakers8.item(0),
                                       y_pred_LosAngelesLakers9.item(0),y_pred_LosAngelesLakers10.item(0),y_pred_LosAngelesLakers11.item(0),y_pred_LosAngelesLakers12.item(0),
                                       y_pred_LosAngelesLakers13.item(0),y_pred_LosAngelesLakers14.item(0),y_pred_LosAngelesLakers15.item(0),y_pred_LosAngelesLakers16.item(0),
                                       y_pred_LosAngelesLakers17.item(0),y_pred_LosAngelesLakers18.item(0),y_pred_LosAngelesLakers19.item(0),y_pred_LosAngelesLakers20.item(0),
                                       y_pred_LosAngelesLakers21.item(0)]}
pd.DataFrame(output)
# Out:
#     LosAngelesLakers Actual Team Performance  \
# 0                                         25
# 1                                         50
# 2                                         58
# 3                                         50
# 4                                         50
# 5                                         41
# 6                                         34
# 7                                         33
# 8                                         35
# 9                                         34
# 10                                        33
# 11                                        32
# 12                                        33
# 13                                        31
# 14                                        29
# 15                                        29
# 16                                        28
# 17                                        28
# 18                                        27
# 19                                        30
# ...

# %%
all1 = np.r_[y_train_LosAngelesLakers1,y_train_LosAngelesLakers2,y_train_LosAngelesLakers3,y_train_LosAngelesLakers4,y_train_LosAngelesLakers5,y_train_LosAngelesLakers6,y_train_LosAngelesLakers7,
            y_train_LosAngelesLakers8,y_train_LosAngelesLakers9,y_train_LosAngelesLakers10,y_train_LosAngelesLakers11,y_train_LosAngelesLakers12,y_train_LosAngelesLakers13,y_train_LosAngelesLakers14,
            y_train_LosAngelesLakers15,y_train_LosAngelesLakers16,y_train_LosAngelesLakers17,y_train_LosAngelesLakers18,y_train_LosAngelesLakers19,y_train_LosAngelesLakers20,y_train_LosAngelesLakers21]
all2 = np.r_[y_pred_LosAngelesLakers1,y_pred_LosAngelesLakers2,y_pred_LosAngelesLakers3,y_pred_LosAngelesLakers4,y_pred_LosAngelesLakers5,y_pred_LosAngelesLakers6,y_pred_LosAngelesLakers7,
            y_pred_LosAngelesLakers8,y_pred_LosAngelesLakers9,y_pred_LosAngelesLakers10,y_pred_LosAngelesLakers11,y_pred_LosAngelesLakers12,y_pred_LosAngelesLakers13,y_pred_LosAngelesLakers14,
            y_pred_LosAngelesLakers15,y_pred_LosAngelesLakers16,y_pred_LosAngelesLakers17,y_pred_LosAngelesLakers18,y_pred_LosAngelesLakers19,y_pred_LosAngelesLakers20,y_pred_LosAngelesLakers21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'LosAngelesLakers Target Team Performance Mean', 'LosAngelesLakers Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    LosAngelesLakers Target Team Performance Mean  \
# 0                                      35.285714
#
#    LosAngelesLakers Team Performance Predicted Mean  \
# 0                                         46.342281
#
#    Difference Between Target and Predicted
# 0                                11.056566

# %%
output = { 'Sacramento Actual Team Performance' : [y_train_Sacramento1.iloc[0],y_train_Sacramento2.iloc[0],y_train_Sacramento3.iloc[0],y_train_Sacramento4.iloc[0],
                                       y_train_Sacramento5.iloc[0],y_train_Sacramento6.iloc[0],y_train_Sacramento7.iloc[0],y_train_Sacramento8.iloc[0],
                                       y_train_Sacramento9.iloc[0],y_train_Sacramento10.iloc[0],y_train_Sacramento11.iloc[0],y_train_Sacramento12.iloc[0],
                                       y_train_Sacramento13.iloc[0],y_train_Sacramento14.iloc[0],y_train_Sacramento15.iloc[0],y_train_Sacramento16.iloc[0],
                                       y_train_Sacramento17.iloc[0],y_train_Sacramento18.iloc[0],y_train_Sacramento19.iloc[0],y_train_Sacramento20.iloc[0],
                                       y_train_Sacramento21.iloc[0]],  
          'Sacramento Predicted Team Performance' : [y_pred_Sacramento1.item(0),y_pred_Sacramento2.item(0),y_pred_Sacramento3.item(0),y_pred_Sacramento4.item(0),
                                       y_pred_Sacramento5.item(0),y_pred_Sacramento6.item(0),y_pred_Sacramento7.item(0),y_pred_Sacramento8.item(0),
                                       y_pred_Sacramento9.item(0),y_pred_Sacramento10.item(0),y_pred_Sacramento11.item(0),y_pred_Sacramento12.item(0),
                                       y_pred_Sacramento13.item(0),y_pred_Sacramento14.item(0),y_pred_Sacramento15.item(0),y_pred_Sacramento16.item(0),
                                       y_pred_Sacramento17.item(0),y_pred_Sacramento18.item(0),y_pred_Sacramento19.item(0),y_pred_Sacramento20.item(0),
                                       y_pred_Sacramento21.item(0)]}
pd.DataFrame(output)
# Out:
#     Sacramento Actual Team Performance  Sacramento Predicted Team Performance
# 0                                   40                              28.414090
# 1                                   44                              39.601333
# 2                                   30                              43.165496
# 3                                   41                              54.969319
# 4                                   38                              52.621813
# 5                                   36                              44.779696
# 6                                   42                              42.107671
# 7                                   40                              30.073127
# 8                                   39                              46.355379
# 9                                   40                              52.988520
# 10                                  38                              52.580781
# ...

# %%
all1 = np.r_[y_train_Sacramento1,y_train_Sacramento2,y_train_Sacramento3,y_train_Sacramento4,y_train_Sacramento5,y_train_Sacramento6,y_train_Sacramento7,
            y_train_Sacramento8,y_train_Sacramento9,y_train_Sacramento10,y_train_Sacramento11,y_train_Sacramento12,y_train_Sacramento13,y_train_Sacramento14,
            y_train_Sacramento15,y_train_Sacramento16,y_train_Sacramento17,y_train_Sacramento18,y_train_Sacramento19,y_train_Sacramento20,y_train_Sacramento21]
all2 = np.r_[y_pred_Sacramento1,y_pred_Sacramento2,y_pred_Sacramento3,y_pred_Sacramento4,y_pred_Sacramento5,y_pred_Sacramento6,y_pred_Sacramento7,
            y_pred_Sacramento8,y_pred_Sacramento9,y_pred_Sacramento10,y_pred_Sacramento11,y_pred_Sacramento12,y_pred_Sacramento13,y_pred_Sacramento14,
            y_pred_Sacramento15,y_pred_Sacramento16,y_pred_Sacramento17,y_pred_Sacramento18,y_pred_Sacramento19,y_pred_Sacramento20,y_pred_Sacramento21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'Sacramento Target Team Performance Mean', 'Sacramento Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    Sacramento Target Team Performance Mean  \
# 0                                38.952381
#
#    Sacramento Team Performance Predicted Mean  \
# 0                                   43.637719
#
#    Difference Between Target and Predicted
# 0                                 4.685338

# %%
output = { 'Dallas Actual Team Performance' : [y_train_Dallas1.iloc[0],y_train_Dallas2.iloc[0],y_train_Dallas3.iloc[0],y_train_Dallas4.iloc[0],
                                       y_train_Dallas5.iloc[0],y_train_Dallas6.iloc[0],y_train_Dallas7.iloc[0],y_train_Dallas8.iloc[0],
                                       y_train_Dallas9.iloc[0],y_train_Dallas10.iloc[0],y_train_Dallas11.iloc[0],y_train_Dallas12.iloc[0],
                                       y_train_Dallas13.iloc[0],y_train_Dallas14.iloc[0],y_train_Dallas15.iloc[0],y_train_Dallas16.iloc[0],
                                       y_train_Dallas17.iloc[0],y_train_Dallas18.iloc[0],y_train_Dallas19.iloc[0],y_train_Dallas20.iloc[0],
                                       y_train_Dallas21.iloc[0]],  
          'Dallas Predicted Team Performance' : [y_pred_Dallas1.item(0),y_pred_Dallas2.item(0),y_pred_Dallas3.item(0),y_pred_Dallas4.item(0),
                                       y_pred_Dallas5.item(0),y_pred_Dallas6.item(0),y_pred_Dallas7.item(0),y_pred_Dallas8.item(0),
                                       y_pred_Dallas9.item(0),y_pred_Dallas10.item(0),y_pred_Dallas11.item(0),y_pred_Dallas12.item(0),
                                       y_pred_Dallas13.item(0),y_pred_Dallas14.item(0),y_pred_Dallas15.item(0),y_pred_Dallas16.item(0),
                                       y_pred_Dallas17.item(0),y_pred_Dallas18.item(0),y_pred_Dallas19.item(0),y_pred_Dallas20.item(0),
                                       y_pred_Dallas21.item(0)]}
pd.DataFrame(output)
# Out:
#     Dallas Actual Team Performance  Dallas Predicted Team Performance
# 0                                0                          40.985699
# 1                               15                          28.107832
# 2                               25                          51.962182
# 3                               18                          52.953547
# 4                               20                          47.354338
# 5                               25                          48.537816
# 6                               28                          55.372114
# 7                               30                          49.157568
# 8                               32                          32.633282
# 9                               34                          60.490130
# 10                              37                          55.195896
# 11                              38                          42.653287
# ...

# %%
all1 = np.r_[y_train_Dallas1,y_train_Dallas2,y_train_Dallas3,y_train_Dallas4,y_train_Dallas5,y_train_Dallas6,y_train_Dallas7,
            y_train_Dallas8,y_train_Dallas9,y_train_Dallas10,y_train_Dallas11,y_train_Dallas12,y_train_Dallas13,y_train_Dallas14,
            y_train_Dallas15,y_train_Dallas16,y_train_Dallas17,y_train_Dallas18,y_train_Dallas19,y_train_Dallas20,y_train_Dallas21]
all2 = np.r_[y_pred_Dallas1,y_pred_Dallas2,y_pred_Dallas3,y_pred_Dallas4,y_pred_Dallas5,y_pred_Dallas6,y_pred_Dallas7,
            y_pred_Dallas8,y_pred_Dallas9,y_pred_Dallas10,y_pred_Dallas11,y_pred_Dallas12,y_pred_Dallas13,y_pred_Dallas14,
            y_pred_Dallas15,y_pred_Dallas16,y_pred_Dallas17,y_pred_Dallas18,y_pred_Dallas19,y_pred_Dallas20,y_pred_Dallas21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'Dallas Target Team Performance Mean', 'Dallas Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    Dallas Target Team Performance Mean  \
# 0                            32.047619
#
#    Dallas Team Performance Predicted Mean  \
# 0                               50.067621
#
#    Difference Between Target and Predicted
# 0                                18.020002

# %%
output = { 'Memphis Actual Team Performance' : [y_train_Memphis1.iloc[0],y_train_Memphis2.iloc[0],y_train_Memphis3.iloc[0],y_train_Memphis4.iloc[0],
                                       y_train_Memphis5.iloc[0],y_train_Memphis6.iloc[0],y_train_Memphis7.iloc[0],y_train_Memphis8.iloc[0],
                                       y_train_Memphis9.iloc[0],y_train_Memphis10.iloc[0],y_train_Memphis11.iloc[0],y_train_Memphis12.iloc[0],
                                       y_train_Memphis13.iloc[0],y_train_Memphis14.iloc[0],y_train_Memphis15.iloc[0],y_train_Memphis16.iloc[0],
                                       y_train_Memphis17.iloc[0],y_train_Memphis18.iloc[0],y_train_Memphis19.iloc[0],y_train_Memphis20.iloc[0],
                                       y_train_Memphis21.iloc[0]],  
          'Memphis Predicted Team Performance' : [y_pred_Memphis1.item(0),y_pred_Memphis2.item(0),y_pred_Memphis3.item(0),y_pred_Memphis4.item(0),
                                       y_pred_Memphis5.item(0),y_pred_Memphis6.item(0),y_pred_Memphis7.item(0),y_pred_Memphis8.item(0),
                                       y_pred_Memphis9.item(0),y_pred_Memphis10.item(0),y_pred_Memphis11.item(0),y_pred_Memphis12.item(0),
                                       y_pred_Memphis13.item(0),y_pred_Memphis14.item(0),y_pred_Memphis15.item(0),y_pred_Memphis16.item(0),
                                       y_pred_Memphis17.item(0),y_pred_Memphis18.item(0),y_pred_Memphis19.item(0),y_pred_Memphis20.item(0),
                                       y_pred_Memphis21.item(0)]}
pd.DataFrame(output)
# Out:
#     Memphis Actual Team Performance  Memphis Predicted Team Performance
# 0                                50                           13.141854
# 1                                50                           29.016715
# 2                                58                           34.114231
# 3                                62                           37.090409
# 4                                60                           24.824730
# 5                                66                           50.255485
# 6                                62                           49.350621
# 7                                61                           49.791977
# 8                                60                           52.524212
# 9                                56                           41.956326
# 10                               56                           43.796363
# 11                               57                           41.891358
# ...

# %%
all1 = np.r_[y_train_Memphis1,y_train_Memphis2,y_train_Memphis3,y_train_Memphis4,y_train_Memphis5,y_train_Memphis6,y_train_Memphis7,
            y_train_Memphis8,y_train_Memphis9,y_train_Memphis10,y_train_Memphis11,y_train_Memphis12,y_train_Memphis13,y_train_Memphis14,
            y_train_Memphis15,y_train_Memphis16,y_train_Memphis17,y_train_Memphis18,y_train_Memphis19,y_train_Memphis20,y_train_Memphis21]
all2 = np.r_[y_pred_Memphis1,y_pred_Memphis2,y_pred_Memphis3,y_pred_Memphis4,y_pred_Memphis5,y_pred_Memphis6,y_pred_Memphis7,
            y_pred_Memphis8,y_pred_Memphis9,y_pred_Memphis10,y_pred_Memphis11,y_pred_Memphis12,y_pred_Memphis13,y_pred_Memphis14,
            y_pred_Memphis15,y_pred_Memphis16,y_pred_Memphis17,y_pred_Memphis18,y_pred_Memphis19,y_pred_Memphis20,y_pred_Memphis21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'Memphis Target Team Performance Mean', 'Memphis Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    Memphis Target Team Performance Mean  \
# 0                             56.952381
#
#    Memphis Team Performance Predicted Mean  \
# 0                                41.521284
#
#    Difference Between Target and Predicted
# 0                               -15.431097

# %%
output = { 'Phoenix Actual Team Performance' : [y_train_Phoenix1.iloc[0],y_train_Phoenix2.iloc[0],y_train_Phoenix3.iloc[0],y_train_Phoenix4.iloc[0],
                                       y_train_Phoenix5.iloc[0],y_train_Phoenix6.iloc[0],y_train_Phoenix7.iloc[0],y_train_Phoenix8.iloc[0],
                                       y_train_Phoenix9.iloc[0],y_train_Phoenix10.iloc[0],y_train_Phoenix11.iloc[0],y_train_Phoenix12.iloc[0],
                                       y_train_Phoenix13.iloc[0],y_train_Phoenix14.iloc[0],y_train_Phoenix15.iloc[0],y_train_Phoenix16.iloc[0],
                                       y_train_Phoenix17.iloc[0],y_train_Phoenix18.iloc[0],y_train_Phoenix19.iloc[0],y_train_Phoenix20.iloc[0],
                                       y_train_Phoenix21.iloc[0]],  
          'Phoenix Predicted Team Performance' : [y_pred_Phoenix1.item(0),y_pred_Phoenix2.item(0),y_pred_Phoenix3.item(0),y_pred_Phoenix4.item(0),
                                       y_pred_Phoenix5.item(0),y_pred_Phoenix6.item(0),y_pred_Phoenix7.item(0),y_pred_Phoenix8.item(0),
                                       y_pred_Phoenix9.item(0),y_pred_Phoenix10.item(0),y_pred_Phoenix11.item(0),y_pred_Phoenix12.item(0),
                                       y_pred_Phoenix13.item(0),y_pred_Phoenix14.item(0),y_pred_Phoenix15.item(0),y_pred_Phoenix16.item(0),
                                       y_pred_Phoenix17.item(0),y_pred_Phoenix18.item(0),y_pred_Phoenix19.item(0),y_pred_Phoenix20.item(0),
                                       y_pred_Phoenix21.item(0)]}
pd.DataFrame(output)
# Out:
#     Phoenix Actual Team Performance  Phoenix Predicted Team Performance
# 0                                 0                           38.723252
# 1                                25                           40.854137
# 2                                25                           35.338409
# 3                                31                           43.851692
# 4                                30                           42.985675
# 5                                29                           50.039879
# 6                                28                           49.220437
# 7                                30                           32.392162
# 8                                32                           65.161689
# 9                                34                           50.793616
# 10                               31                           51.118435
# 11                               30                           38.413928
# ...

# %%
all1 = np.r_[y_train_Phoenix1,y_train_Phoenix2,y_train_Phoenix3,y_train_Phoenix4,y_train_Phoenix5,y_train_Phoenix6,y_train_Phoenix7,
            y_train_Phoenix8,y_train_Phoenix9,y_train_Phoenix10,y_train_Phoenix11,y_train_Phoenix12,y_train_Phoenix13,y_train_Phoenix14,
            y_train_Phoenix15,y_train_Phoenix16,y_train_Phoenix17,y_train_Phoenix18,y_train_Phoenix19,y_train_Phoenix20,y_train_Phoenix21]
all2 = np.r_[y_pred_Phoenix1,y_pred_Phoenix2,y_pred_Phoenix3,y_pred_Phoenix4,y_pred_Phoenix5,y_pred_Phoenix6,y_pred_Phoenix7,
            y_pred_Phoenix8,y_pred_Phoenix9,y_pred_Phoenix10,y_pred_Phoenix11,y_pred_Phoenix12,y_pred_Phoenix13,y_pred_Phoenix14,
            y_pred_Phoenix15,y_pred_Phoenix16,y_pred_Phoenix17,y_pred_Phoenix18,y_pred_Phoenix19,y_pred_Phoenix20,y_pred_Phoenix21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'Phoenix Target Team Performance Mean', 'Phoenix Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    Phoenix Target Team Performance Mean  \
# 0                             28.285714
#
#    Phoenix Team Performance Predicted Mean  \
# 0                                42.618805
#
#    Difference Between Target and Predicted
# 0                                14.333091

# %%
output = { 'Miami Actual Team Performance' : [y_train_Miami1.iloc[0],y_train_Miami2.iloc[0],y_train_Miami3.iloc[0],y_train_Miami4.iloc[0],
                                       y_train_Miami5.iloc[0],y_train_Miami6.iloc[0],y_train_Miami7.iloc[0],y_train_Miami8.iloc[0],
                                       y_train_Miami9.iloc[0],y_train_Miami10.iloc[0],y_train_Miami11.iloc[0],y_train_Miami12.iloc[0],
                                       y_train_Miami13.iloc[0],y_train_Miami14.iloc[0],y_train_Miami15.iloc[0],y_train_Miami16.iloc[0],
                                       y_train_Miami17.iloc[0],y_train_Miami18.iloc[0],y_train_Miami19.iloc[0],y_train_Miami20.iloc[0],
                                       y_train_Miami21.iloc[0]],  
          'Miami Predicted Team Performance' : [y_pred_Miami1.item(0),y_pred_Miami2.item(0),y_pred_Miami3.item(0),y_pred_Miami4.item(0),
                                       y_pred_Miami5.item(0),y_pred_Miami6.item(0),y_pred_Miami7.item(0),y_pred_Miami8.item(0),
                                       y_pred_Miami9.item(0),y_pred_Miami10.item(0),y_pred_Miami11.item(0),y_pred_Miami12.item(0),
                                       y_pred_Miami13.item(0),y_pred_Miami14.item(0),y_pred_Miami15.item(0),y_pred_Miami16.item(0),
                                       y_pred_Miami17.item(0),y_pred_Miami18.item(0),y_pred_Miami19.item(0),y_pred_Miami20.item(0),
                                       y_pred_Miami21.item(0)]}
pd.DataFrame(output)
# Out:
#     Miami Actual Team Performance  Miami Predicted Team Performance
# 0                              50                         68.615940
# 1                              25                         40.066479
# 2                              28                         45.149058
# 3                              31                         53.631593
# 4                              35                         53.603836
# 5                              29                         35.907903
# 6                              31                         54.874019
# 7                              27                         52.104208
# 8                              27                         44.455266
# 9                              31                         55.218127
# 10                             37                         57.418524
# 11                             42                         55.361703
# 12                             42                         38.390738
# ...

# %%
all1 = np.r_[y_train_Miami1,y_train_Miami2,y_train_Miami3,y_train_Miami4,y_train_Miami5,y_train_Miami6,y_train_Miami7,
            y_train_Miami8,y_train_Miami9,y_train_Miami10,y_train_Miami11,y_train_Miami12,y_train_Miami13,y_train_Miami14,
            y_train_Miami15,y_train_Miami16,y_train_Miami17,y_train_Miami18,y_train_Miami19,y_train_Miami20,y_train_Miami21]
all2 = np.r_[y_pred_Miami1,y_pred_Miami2,y_pred_Miami3,y_pred_Miami4,y_pred_Miami5,y_pred_Miami6,y_pred_Miami7,
            y_pred_Miami8,y_pred_Miami9,y_pred_Miami10,y_pred_Miami11,y_pred_Miami12,y_pred_Miami13,y_pred_Miami14,
            y_pred_Miami15,y_pred_Miami16,y_pred_Miami17,y_pred_Miami18,y_pred_Miami19,y_pred_Miami20,y_pred_Miami21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'Miami Target Team Performance Mean', 'Miami Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    Miami Target Team Performance Mean  Miami Team Performance Predicted Mean  \
# 0                           38.761905                              53.421418
#
#    Difference Between Target and Predicted
# 0                                14.659514

# %%
output = { 'Milwaukee Actual Team Performance' : [y_train_Milwaukee1.iloc[0],y_train_Milwaukee2.iloc[0],y_train_Milwaukee3.iloc[0],y_train_Milwaukee4.iloc[0],
                                       y_train_Milwaukee5.iloc[0],y_train_Milwaukee6.iloc[0],y_train_Milwaukee7.iloc[0],y_train_Milwaukee8.iloc[0],
                                       y_train_Milwaukee9.iloc[0],y_train_Milwaukee10.iloc[0],y_train_Milwaukee11.iloc[0],y_train_Milwaukee12.iloc[0],
                                       y_train_Milwaukee13.iloc[0],y_train_Milwaukee14.iloc[0],y_train_Milwaukee15.iloc[0],y_train_Milwaukee16.iloc[0],
                                       y_train_Milwaukee17.iloc[0],y_train_Milwaukee18.iloc[0],y_train_Milwaukee19.iloc[0],y_train_Milwaukee20.iloc[0],
                                       y_train_Milwaukee21.iloc[0]],  
          'Milwaukee Predicted Team Performance' : [y_pred_Milwaukee1.item(0),y_pred_Milwaukee2.item(0),y_pred_Milwaukee3.item(0),y_pred_Milwaukee4.item(0),
                                       y_pred_Milwaukee5.item(0),y_pred_Milwaukee6.item(0),y_pred_Milwaukee7.item(0),y_pred_Milwaukee8.item(0),
                                       y_pred_Milwaukee9.item(0),y_pred_Milwaukee10.item(0),y_pred_Milwaukee11.item(0),y_pred_Milwaukee12.item(0),
                                       y_pred_Milwaukee13.item(0),y_pred_Milwaukee14.item(0),y_pred_Milwaukee15.item(0),y_pred_Milwaukee16.item(0),
                                       y_pred_Milwaukee17.item(0),y_pred_Milwaukee18.item(0),y_pred_Milwaukee19.item(0),y_pred_Milwaukee20.item(0),
                                       y_pred_Milwaukee21.item(0)]}
pd.DataFrame(output)
# Out:
#     Milwaukee Actual Team Performance  Milwaukee Predicted Team Performance
# 0                                  50                             39.942468
# 1                                  50                             51.224217
# 2                                  41                             32.905762
# 3                                  50                             51.608639
# 4                                  52                             38.351767
# 5                                  50                             48.590818
# 6                                  50                             69.899679
# 7                                  50                             43.087062
# 8                                  50                             34.211298
# 9                                  47                             45.592430
# 10                                 43                             37.447603
# ...

# %%
all1 = np.r_[y_train_Milwaukee1,y_train_Milwaukee2,y_train_Milwaukee3,y_train_Milwaukee4,y_train_Milwaukee5,y_train_Milwaukee6,y_train_Milwaukee7,
            y_train_Milwaukee8,y_train_Milwaukee9,y_train_Milwaukee10,y_train_Milwaukee11,y_train_Milwaukee12,y_train_Milwaukee13,y_train_Milwaukee14,
            y_train_Milwaukee15,y_train_Milwaukee16,y_train_Milwaukee17,y_train_Milwaukee18,y_train_Milwaukee19,y_train_Milwaukee20,y_train_Milwaukee21]
all2 = np.r_[y_pred_Milwaukee1,y_pred_Milwaukee2,y_pred_Milwaukee3,y_pred_Milwaukee4,y_pred_Milwaukee5,y_pred_Milwaukee6,y_pred_Milwaukee7,
            y_pred_Milwaukee8,y_pred_Milwaukee9,y_pred_Milwaukee10,y_pred_Milwaukee11,y_pred_Milwaukee12,y_pred_Milwaukee13,y_pred_Milwaukee14,
            y_pred_Milwaukee15,y_pred_Milwaukee16,y_pred_Milwaukee17,y_pred_Milwaukee18,y_pred_Milwaukee19,y_pred_Milwaukee20,y_pred_Milwaukee21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'Milwaukee Target Team Performance Mean', 'Milwaukee Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    Milwaukee Target Team Performance Mean  \
# 0                               48.285714
#
#    Milwaukee Team Performance Predicted Mean  \
# 0                                  47.257123
#
#    Difference Between Target and Predicted
# 0                                -1.028591

# %%
output = { 'Washington Actual Team Performance' : [y_train_Washington1.iloc[0],y_train_Washington2.iloc[0],y_train_Washington3.iloc[0],y_train_Washington4.iloc[0],
                                       y_train_Washington5.iloc[0],y_train_Washington6.iloc[0],y_train_Washington7.iloc[0],y_train_Washington8.iloc[0],
                                       y_train_Washington9.iloc[0],y_train_Washington10.iloc[0],y_train_Washington11.iloc[0],y_train_Washington12.iloc[0],
                                       y_train_Washington13.iloc[0],y_train_Washington14.iloc[0],y_train_Washington15.iloc[0],y_train_Washington16.iloc[0],
                                       y_train_Washington17.iloc[0],y_train_Washington18.iloc[0],y_train_Washington19.iloc[0],y_train_Washington20.iloc[0],
                                       y_train_Washington21.iloc[0]],  
          'Washington Predicted Team Performance' : [y_pred_Washington1.item(0),y_pred_Washington2.item(0),y_pred_Washington3.item(0),y_pred_Washington4.item(0),
                                       y_pred_Washington5.item(0),y_pred_Washington6.item(0),y_pred_Washington7.item(0),y_pred_Washington8.item(0),
                                       y_pred_Washington9.item(0),y_pred_Washington10.item(0),y_pred_Washington11.item(0),y_pred_Washington12.item(0),
                                       y_pred_Washington13.item(0),y_pred_Washington14.item(0),y_pred_Washington15.item(0),y_pred_Washington16.item(0),
                                       y_pred_Washington17.item(0),y_pred_Washington18.item(0),y_pred_Washington19.item(0),y_pred_Washington20.item(0),
                                       y_pred_Washington21.item(0)]}
pd.DataFrame(output)
# Out:
#     Washington Actual Team Performance  Washington Predicted Team Performance
# 0                                   25                              19.786545
# 1                                   25                              48.022830
# 2                                   25                              34.770482
# 3                                   37                              41.797123
# 4                                   35                              45.380784
# 5                                   41                              34.774070
# 6                                   50                              52.129687
# 7                                   50                              45.517727
# 8                                   52                              54.895146
# 9                                   54                              48.097908
# 10                                  58                              58.649476
# ...

# %%
all1 = np.r_[y_train_Washington1,y_train_Washington2,y_train_Washington3,y_train_Washington4,y_train_Washington5,y_train_Washington6,y_train_Washington7,
            y_train_Washington8,y_train_Washington9,y_train_Washington10,y_train_Washington11,y_train_Washington12,y_train_Washington13,y_train_Washington14,
            y_train_Washington15,y_train_Washington16,y_train_Washington17,y_train_Washington18,y_train_Washington19,y_train_Washington20,y_train_Washington21]
all2 = np.r_[y_pred_Washington1,y_pred_Washington2,y_pred_Washington3,y_pred_Washington4,y_pred_Washington5,y_pred_Washington6,y_pred_Washington7,
            y_pred_Washington8,y_pred_Washington9,y_pred_Washington10,y_pred_Washington11,y_pred_Washington12,y_pred_Washington13,y_pred_Washington14,
            y_pred_Washington15,y_pred_Washington16,y_pred_Washington17,y_pred_Washington18,y_pred_Washington19,y_pred_Washington20,y_pred_Washington21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'Washington Target Team Performance Mean', 'Washington Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    Washington Target Team Performance Mean  \
# 0                                50.190476
#
#    Washington Team Performance Predicted Mean  \
# 0                                   46.961251
#
#    Difference Between Target and Predicted
# 0                                -3.229226

# %%
output = { 'Detroit Actual Team Performance' : [y_train_Detroit1.iloc[0],y_train_Detroit2.iloc[0],y_train_Detroit3.iloc[0],y_train_Detroit4.iloc[0],
                                       y_train_Detroit5.iloc[0],y_train_Detroit6.iloc[0],y_train_Detroit7.iloc[0],y_train_Detroit8.iloc[0],
                                       y_train_Detroit9.iloc[0],y_train_Detroit10.iloc[0],y_train_Detroit11.iloc[0],y_train_Detroit12.iloc[0],
                                       y_train_Detroit13.iloc[0],y_train_Detroit14.iloc[0],y_train_Detroit15.iloc[0],y_train_Detroit16.iloc[0],
                                       y_train_Detroit17.iloc[0],y_train_Detroit18.iloc[0],y_train_Detroit19.iloc[0],y_train_Detroit20.iloc[0],
                                       y_train_Detroit21.iloc[0]],  
          'Detroit Predicted Team Performance' : [y_pred_Detroit1.item(0),y_pred_Detroit2.item(0),y_pred_Detroit3.item(0),y_pred_Detroit4.item(0),
                                       y_pred_Detroit5.item(0),y_pred_Detroit6.item(0),y_pred_Detroit7.item(0),y_pred_Detroit8.item(0),
                                       y_pred_Detroit9.item(0),y_pred_Detroit10.item(0),y_pred_Detroit11.item(0),y_pred_Detroit12.item(0),
                                       y_pred_Detroit13.item(0),y_pred_Detroit14.item(0),y_pred_Detroit15.item(0),y_pred_Detroit16.item(0),
                                       y_pred_Detroit17.item(0),y_pred_Detroit18.item(0),y_pred_Detroit19.item(0),y_pred_Detroit20.item(0),
                                       y_pred_Detroit21.item(0)]}
pd.DataFrame(output)
# Out:
#     Detroit Actual Team Performance  Detroit Predicted Team Performance
# 0                                75                           60.218876
# 1                                50                           24.426125
# 2                                50                           43.278663
# 3                                43                           40.307319
# 4                                50                           48.704380
# 5                                50                           61.940643
# 6                                43                           34.891172
# 7                                44                           52.279428
# 8                                45                           40.986156
# 9                                45                           44.227260
# 10                               43                           41.976698
# 11                               46                           51.446630
# ...

# %%
all1 = np.r_[y_train_Detroit1,y_train_Detroit2,y_train_Detroit3,y_train_Detroit4,y_train_Detroit5,y_train_Detroit6,y_train_Detroit7,
            y_train_Detroit8,y_train_Detroit9,y_train_Detroit10,y_train_Detroit11,y_train_Detroit12,y_train_Detroit13,y_train_Detroit14,
            y_train_Detroit15,y_train_Detroit16,y_train_Detroit17,y_train_Detroit18,y_train_Detroit19,y_train_Detroit20,y_train_Detroit21]
all2 = np.r_[y_pred_Detroit1,y_pred_Detroit2,y_pred_Detroit3,y_pred_Detroit4,y_pred_Detroit5,y_pred_Detroit6,y_pred_Detroit7,
            y_pred_Detroit8,y_pred_Detroit9,y_pred_Detroit10,y_pred_Detroit11,y_pred_Detroit12,y_pred_Detroit13,y_pred_Detroit14,
            y_pred_Detroit15,y_pred_Detroit16,y_pred_Detroit17,y_pred_Detroit18,y_pred_Detroit19,y_pred_Detroit20,y_pred_Detroit21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'Detroit Target Team Performance Mean', 'Detroit Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    Detroit Target Team Performance Mean  \
# 0                             47.857143
#
#    Detroit Team Performance Predicted Mean  \
# 0                                45.996241
#
#    Difference Between Target and Predicted
# 0                                -1.860902

# %%
output = { 'Charlotte Actual Team Performance' : [y_train_Charlotte1.iloc[0],y_train_Charlotte2.iloc[0],y_train_Charlotte3.iloc[0],y_train_Charlotte4.iloc[0],
                                       y_train_Charlotte5.iloc[0],y_train_Charlotte6.iloc[0],y_train_Charlotte7.iloc[0],y_train_Charlotte8.iloc[0],
                                       y_train_Charlotte9.iloc[0],y_train_Charlotte10.iloc[0],y_train_Charlotte11.iloc[0],y_train_Charlotte12.iloc[0],
                                       y_train_Charlotte13.iloc[0],y_train_Charlotte14.iloc[0],y_train_Charlotte15.iloc[0],y_train_Charlotte16.iloc[0],
                                       y_train_Charlotte17.iloc[0],y_train_Charlotte18.iloc[0],y_train_Charlotte19.iloc[0],y_train_Charlotte20.iloc[0],
                                       y_train_Charlotte21.iloc[0]],  
          'Charlotte Predicted Team Performance' : [y_pred_Charlotte1.item(0),y_pred_Charlotte2.item(0),y_pred_Charlotte3.item(0),y_pred_Charlotte4.item(0),
                                       y_pred_Charlotte5.item(0),y_pred_Charlotte6.item(0),y_pred_Charlotte7.item(0),y_pred_Charlotte8.item(0),
                                       y_pred_Charlotte9.item(0),y_pred_Charlotte10.item(0),y_pred_Charlotte11.item(0),y_pred_Charlotte12.item(0),
                                       y_pred_Charlotte13.item(0),y_pred_Charlotte14.item(0),y_pred_Charlotte15.item(0),y_pred_Charlotte16.item(0),
                                       y_pred_Charlotte17.item(0),y_pred_Charlotte18.item(0),y_pred_Charlotte19.item(0),y_pred_Charlotte20.item(0),
                                       y_pred_Charlotte21.item(0)]}
pd.DataFrame(output)
# Out:
#     Charlotte Actual Team Performance  Charlotte Predicted Team Performance
# 0                                  75                             67.846548
# 1                                  75                             56.633914
# 2                                  66                             55.281967
# 3                                  56                             54.752261
# 4                                  55                             35.776985
# 5                                  56                             47.829221
# 6                                  56                             69.568703
# 7                                  55                             59.020886
# 8                                  50                             41.783122
# 9                                  52                             57.908616
# 10                                 47                             47.705160
# ...

# %%
all1 = np.r_[y_train_Charlotte1,y_train_Charlotte2,y_train_Charlotte3,y_train_Charlotte4,y_train_Charlotte5,y_train_Charlotte6,y_train_Charlotte7,
            y_train_Charlotte8,y_train_Charlotte9,y_train_Charlotte10,y_train_Charlotte11,y_train_Charlotte12,y_train_Charlotte13,y_train_Charlotte14,
            y_train_Charlotte15,y_train_Charlotte16,y_train_Charlotte17,y_train_Charlotte18,y_train_Charlotte19,y_train_Charlotte20,y_train_Charlotte21]
all2 = np.r_[y_pred_Charlotte1,y_pred_Charlotte2,y_pred_Charlotte3,y_pred_Charlotte4,y_pred_Charlotte5,y_pred_Charlotte6,y_pred_Charlotte7,
            y_pred_Charlotte8,y_pred_Charlotte9,y_pred_Charlotte10,y_pred_Charlotte11,y_pred_Charlotte12,y_pred_Charlotte13,y_pred_Charlotte14,
            y_pred_Charlotte15,y_pred_Charlotte16,y_pred_Charlotte17,y_pred_Charlotte18,y_pred_Charlotte19,y_pred_Charlotte20,y_pred_Charlotte21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'Charlotte Target Team Performance Mean', 'Charlotte Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    Charlotte Target Team Performance Mean  \
# 0                               51.571429
#
#    Charlotte Team Performance Predicted Mean  \
# 0                                  53.662207
#
#    Difference Between Target and Predicted
# 0                                 2.090779

# %%
output = { 'NewYork Actual Team Performance' : [y_train_NewYork1.iloc[0],y_train_NewYork2.iloc[0],y_train_NewYork3.iloc[0],y_train_NewYork4.iloc[0],
                                       y_train_NewYork5.iloc[0],y_train_NewYork6.iloc[0],y_train_NewYork7.iloc[0],y_train_NewYork8.iloc[0],
                                       y_train_NewYork9.iloc[0],y_train_NewYork10.iloc[0],y_train_NewYork11.iloc[0],y_train_NewYork12.iloc[0],
                                       y_train_NewYork13.iloc[0],y_train_NewYork14.iloc[0],y_train_NewYork15.iloc[0],y_train_NewYork16.iloc[0],
                                       y_train_NewYork17.iloc[0],y_train_NewYork18.iloc[0],y_train_NewYork19.iloc[0],y_train_NewYork20.iloc[0],
                                       y_train_NewYork21.iloc[0]],  
          'NewYork Predicted Team Performance' : [y_pred_NewYork1.item(0),y_pred_NewYork2.item(0),y_pred_NewYork3.item(0),y_pred_NewYork4.item(0),
                                       y_pred_NewYork5.item(0),y_pred_NewYork6.item(0),y_pred_NewYork7.item(0),y_pred_NewYork8.item(0),
                                       y_pred_NewYork9.item(0),y_pred_NewYork10.item(0),y_pred_NewYork11.item(0),y_pred_NewYork12.item(0),
                                       y_pred_NewYork13.item(0),y_pred_NewYork14.item(0),y_pred_NewYork15.item(0),y_pred_NewYork16.item(0),
                                       y_pred_NewYork17.item(0),y_pred_NewYork18.item(0),y_pred_NewYork19.item(0),y_pred_NewYork20.item(0),
                                       y_pred_NewYork21.item(0)]}
pd.DataFrame(output)
# Out:
#     NewYork Actual Team Performance  NewYork Predicted Team Performance
# 0                                25                           25.729522
# 1                                37                           65.522085
# 2                                41                           57.798156
# 3                                50                           59.676647
# 4                                55                           55.730968
# 5                                58                           66.559436
# 6                                50                           47.777293
# 7                                47                           48.502132
# 8                                45                           48.271675
# 9                                43                           59.410626
# 10                               43                           39.191479
# 11                               42                           56.546683
# ...

# %%
all1 = np.r_[y_train_NewYork1,y_train_NewYork2,y_train_NewYork3,y_train_NewYork4,y_train_NewYork5,y_train_NewYork6,y_train_NewYork7,
            y_train_NewYork8,y_train_NewYork9,y_train_NewYork10,y_train_NewYork11,y_train_NewYork12,y_train_NewYork13,y_train_NewYork14,
            y_train_NewYork15,y_train_NewYork16,y_train_NewYork17,y_train_NewYork18,y_train_NewYork19,y_train_NewYork20,y_train_NewYork21]
all2 = np.r_[y_pred_NewYork1,y_pred_NewYork2,y_pred_NewYork3,y_pred_NewYork4,y_pred_NewYork5,y_pred_NewYork6,y_pred_NewYork7,
            y_pred_NewYork8,y_pred_NewYork9,y_pred_NewYork10,y_pred_NewYork11,y_pred_NewYork12,y_pred_NewYork13,y_pred_NewYork14,
            y_pred_NewYork15,y_pred_NewYork16,y_pred_NewYork17,y_pred_NewYork18,y_pred_NewYork19,y_pred_NewYork20,y_pred_NewYork21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'NewYork Target Team Performance Mean', 'NewYork Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    NewYork Target Team Performance Mean  \
# 0                             41.952381
#
#    NewYork Team Performance Predicted Mean  \
# 0                                51.970832
#
#    Difference Between Target and Predicted
# 0                                10.018451

# %%
output = { 'Brooklyn Actual Team Performance' : [y_train_Brooklyn1.iloc[0],y_train_Brooklyn2.iloc[0],y_train_Brooklyn3.iloc[0],y_train_Brooklyn4.iloc[0],
                                       y_train_Brooklyn5.iloc[0],y_train_Brooklyn6.iloc[0],y_train_Brooklyn7.iloc[0],y_train_Brooklyn8.iloc[0],
                                       y_train_Brooklyn9.iloc[0],y_train_Brooklyn10.iloc[0],y_train_Brooklyn11.iloc[0],y_train_Brooklyn12.iloc[0],
                                       y_train_Brooklyn13.iloc[0],y_train_Brooklyn14.iloc[0],y_train_Brooklyn15.iloc[0],y_train_Brooklyn16.iloc[0],
                                       y_train_Brooklyn17.iloc[0],y_train_Brooklyn18.iloc[0],y_train_Brooklyn19.iloc[0],y_train_Brooklyn20.iloc[0],
                                       y_train_Brooklyn21.iloc[0]],  
          'Brooklyn Predicted Team Performance' : [y_pred_Brooklyn1.item(0),y_pred_Brooklyn2.item(0),y_pred_Brooklyn3.item(0),y_pred_Brooklyn4.item(0),
                                       y_pred_Brooklyn5.item(0),y_pred_Brooklyn6.item(0),y_pred_Brooklyn7.item(0),y_pred_Brooklyn8.item(0),
                                       y_pred_Brooklyn9.item(0),y_pred_Brooklyn10.item(0),y_pred_Brooklyn11.item(0),y_pred_Brooklyn12.item(0),
                                       y_pred_Brooklyn13.item(0),y_pred_Brooklyn14.item(0),y_pred_Brooklyn15.item(0),y_pred_Brooklyn16.item(0),
                                       y_pred_Brooklyn17.item(0),y_pred_Brooklyn18.item(0),y_pred_Brooklyn19.item(0),y_pred_Brooklyn20.item(0),
                                       y_pred_Brooklyn21.item(0)]}
pd.DataFrame(output)
# Out:
#     Brooklyn Actual Team Performance  Brooklyn Predicted Team Performance
# 0                                 25                            14.903570
# 1                                 37                            37.928642
# 2                                 44                            45.868505
# 3                                 30                            48.512588
# 4                                 25                            42.012416
# 5                                 29                            46.570210
# 6                                 25                            43.248989
# 7                                 22                            36.518162
# 8                                 20                            42.689904
# 9                                 20                            41.395428
# 10                                18                            41.387935
# 11                                17                            54.594250
# ...

# %%
all1 = np.r_[y_train_Brooklyn1,y_train_Brooklyn2,y_train_Brooklyn3,y_train_Brooklyn4,y_train_Brooklyn5,y_train_Brooklyn6,y_train_Brooklyn7,
            y_train_Brooklyn8,y_train_Brooklyn9,y_train_Brooklyn10,y_train_Brooklyn11,y_train_Brooklyn12,y_train_Brooklyn13,y_train_Brooklyn14,
            y_train_Brooklyn15,y_train_Brooklyn16,y_train_Brooklyn17,y_train_Brooklyn18,y_train_Brooklyn19,y_train_Brooklyn20,y_train_Brooklyn21]
all2 = np.r_[y_pred_Brooklyn1,y_pred_Brooklyn2,y_pred_Brooklyn3,y_pred_Brooklyn4,y_pred_Brooklyn5,y_pred_Brooklyn6,y_pred_Brooklyn7,
            y_pred_Brooklyn8,y_pred_Brooklyn9,y_pred_Brooklyn10,y_pred_Brooklyn11,y_pred_Brooklyn12,y_pred_Brooklyn13,y_pred_Brooklyn14,
            y_pred_Brooklyn15,y_pred_Brooklyn16,y_pred_Brooklyn17,y_pred_Brooklyn18,y_pred_Brooklyn19,y_pred_Brooklyn20,y_pred_Brooklyn21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'Brooklyn Target Team Performance Mean', 'Brooklyn Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    Brooklyn Target Team Performance Mean  \
# 0                              23.380952
#
#    Brooklyn Team Performance Predicted Mean  \
# 0                                 41.724901
#
#    Difference Between Target and Predicted
# 0                                18.343949

# %%
output = { 'Chicago Actual Team Performance' : [y_train_Chicago1.iloc[0],y_train_Chicago2.iloc[0],y_train_Chicago3.iloc[0],y_train_Chicago4.iloc[0],
                                       y_train_Chicago5.iloc[0],y_train_Chicago6.iloc[0],y_train_Chicago7.iloc[0],y_train_Chicago8.iloc[0],
                                       y_train_Chicago9.iloc[0],y_train_Chicago10.iloc[0],y_train_Chicago11.iloc[0],y_train_Chicago12.iloc[0],
                                       y_train_Chicago13.iloc[0],y_train_Chicago14.iloc[0],y_train_Chicago15.iloc[0],y_train_Chicago16.iloc[0],
                                       y_train_Chicago17.iloc[0],y_train_Chicago18.iloc[0],y_train_Chicago19.iloc[0],y_train_Chicago20.iloc[0],
                                       y_train_Chicago21.iloc[0]],  
          'Chicago Predicted Team Performance' : [y_pred_Chicago1.item(0),y_pred_Chicago2.item(0),y_pred_Chicago3.item(0),y_pred_Chicago4.item(0),
                                       y_pred_Chicago5.item(0),y_pred_Chicago6.item(0),y_pred_Chicago7.item(0),y_pred_Chicago8.item(0),
                                       y_pred_Chicago9.item(0),y_pred_Chicago10.item(0),y_pred_Chicago11.item(0),y_pred_Chicago12.item(0),
                                       y_pred_Chicago13.item(0),y_pred_Chicago14.item(0),y_pred_Chicago15.item(0),y_pred_Chicago16.item(0),
                                       y_pred_Chicago17.item(0),y_pred_Chicago18.item(0),y_pred_Chicago19.item(0),y_pred_Chicago20.item(0),
                                       y_pred_Chicago21.item(0)]}
pd.DataFrame(output)
# Out:
#     Chicago Actual Team Performance  Chicago Predicted Team Performance
# 0                                75                          109.458495
# 1                                50                           59.024749
# 2                                66                           66.387737
# 3                                62                           57.683600
# 4                                57                           59.296897
# 5                                52                           82.506812
# 6                                50                           54.170749
# 7                                50                           59.053920
# 8                                47                           53.167867
# 9                                47                           52.421046
# 10                               47                           40.774840
# 11                               50                           58.225987
# ...

# %%
all1 = np.r_[y_train_Chicago1,y_train_Chicago2,y_train_Chicago3,y_train_Chicago4,y_train_Chicago5,y_train_Chicago6,y_train_Chicago7,
            y_train_Chicago8,y_train_Chicago9,y_train_Chicago10,y_train_Chicago11,y_train_Chicago12,y_train_Chicago13,y_train_Chicago14,
            y_train_Chicago15,y_train_Chicago16,y_train_Chicago17,y_train_Chicago18,y_train_Chicago19,y_train_Chicago20,y_train_Chicago21]
all2 = np.r_[y_pred_Chicago1,y_pred_Chicago2,y_pred_Chicago3,y_pred_Chicago4,y_pred_Chicago5,y_pred_Chicago6,y_pred_Chicago7,
            y_pred_Chicago8,y_pred_Chicago9,y_pred_Chicago10,y_pred_Chicago11,y_pred_Chicago12,y_pred_Chicago13,y_pred_Chicago14,
            y_pred_Chicago15,y_pred_Chicago16,y_pred_Chicago17,y_pred_Chicago18,y_pred_Chicago19,y_pred_Chicago20,y_pred_Chicago21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'Chicago Target Team Performance Mean', 'Chicago Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    Chicago Target Team Performance Mean  \
# 0                             51.714286
#
#    Chicago Team Performance Predicted Mean  \
# 0                                61.772142
#
#    Difference Between Target and Predicted
# 0                                10.057856

# %%
output = { 'Orlando Actual Team Performance' : [y_train_Orlando1.iloc[0],y_train_Orlando2.iloc[0],y_train_Orlando3.iloc[0],y_train_Orlando4.iloc[0],
                                       y_train_Orlando5.iloc[0],y_train_Orlando6.iloc[0],y_train_Orlando7.iloc[0],y_train_Orlando8.iloc[0],
                                       y_train_Orlando9.iloc[0],y_train_Orlando10.iloc[0],y_train_Orlando11.iloc[0],y_train_Orlando12.iloc[0],
                                       y_train_Orlando13.iloc[0],y_train_Orlando14.iloc[0],y_train_Orlando15.iloc[0],y_train_Orlando16.iloc[0],
                                       y_train_Orlando17.iloc[0],y_train_Orlando18.iloc[0],y_train_Orlando19.iloc[0],y_train_Orlando20.iloc[0],
                                       y_train_Orlando21.iloc[0]],  
          'Orlando Predicted Team Performance' : [y_pred_Orlando1.item(0),y_pred_Orlando2.item(0),y_pred_Orlando3.item(0),y_pred_Orlando4.item(0),
                                       y_pred_Orlando5.item(0),y_pred_Orlando6.item(0),y_pred_Orlando7.item(0),y_pred_Orlando8.item(0),
                                       y_pred_Orlando9.item(0),y_pred_Orlando10.item(0),y_pred_Orlando11.item(0),y_pred_Orlando12.item(0),
                                       y_pred_Orlando13.item(0),y_pred_Orlando14.item(0),y_pred_Orlando15.item(0),y_pred_Orlando16.item(0),
                                       y_pred_Orlando17.item(0),y_pred_Orlando18.item(0),y_pred_Orlando19.item(0),y_pred_Orlando20.item(0),
                                       y_pred_Orlando21.item(0)]}
pd.DataFrame(output)
# Out:
#     Orlando Actual Team Performance  Orlando Predicted Team Performance
# 0                                25                           27.553973
# 1                                37                           43.586251
# 2                                41                           39.635412
# 3                                42                           31.687072
# 4                                40                           41.969935
# 5                                41                           41.934995
# 6                                43                           44.609915
# 7                                44                           53.492125
# 8                                40                           35.867141
# 9                                38                           34.630476
# 10                               37                           40.913975
# 11                               38                           45.189560
# ...

# %%
all1 = np.r_[y_train_Orlando1,y_train_Orlando2,y_train_Orlando3,y_train_Orlando4,y_train_Orlando5,y_train_Orlando6,y_train_Orlando7,
            y_train_Orlando8,y_train_Orlando9,y_train_Orlando10,y_train_Orlando11,y_train_Orlando12,y_train_Orlando13,y_train_Orlando14,
            y_train_Orlando15,y_train_Orlando16,y_train_Orlando17,y_train_Orlando18,y_train_Orlando19,y_train_Orlando20,y_train_Orlando21]
all2 = np.r_[y_pred_Orlando1,y_pred_Orlando2,y_pred_Orlando3,y_pred_Orlando4,y_pred_Orlando5,y_pred_Orlando6,y_pred_Orlando7,
            y_pred_Orlando8,y_pred_Orlando9,y_pred_Orlando10,y_pred_Orlando11,y_pred_Orlando12,y_pred_Orlando13,y_pred_Orlando14,
            y_pred_Orlando15,y_pred_Orlando16,y_pred_Orlando17,y_pred_Orlando18,y_pred_Orlando19,y_pred_Orlando20,y_pred_Orlando21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'Orlando Target Team Performance Mean', 'Orlando Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    Orlando Target Team Performance Mean  \
# 0                             37.285714
#
#    Orlando Team Performance Predicted Mean  \
# 0                                42.157906
#
#    Difference Between Target and Predicted
# 0                                 4.872192

# %%
output = { 'Atlanta Actual Team Performance' : [y_train_Atlanta1.iloc[0],y_train_Atlanta2.iloc[0],y_train_Atlanta3.iloc[0],y_train_Atlanta4.iloc[0],
                                       y_train_Atlanta5.iloc[0],y_train_Atlanta6.iloc[0],y_train_Atlanta7.iloc[0],y_train_Atlanta8.iloc[0],
                                       y_train_Atlanta9.iloc[0],y_train_Atlanta10.iloc[0],y_train_Atlanta11.iloc[0],y_train_Atlanta12.iloc[0],
                                       y_train_Atlanta13.iloc[0],y_train_Atlanta14.iloc[0],y_train_Atlanta15.iloc[0],y_train_Atlanta16.iloc[0],
                                       y_train_Atlanta17.iloc[0],y_train_Atlanta18.iloc[0],y_train_Atlanta19.iloc[0],y_train_Atlanta20.iloc[0],
                                       y_train_Atlanta21.iloc[0]],  
          'Atlanta Predicted Team Performance' : [y_pred_Atlanta1.item(0),y_pred_Atlanta2.item(0),y_pred_Atlanta3.item(0),y_pred_Atlanta4.item(0),
                                       y_pred_Atlanta5.item(0),y_pred_Atlanta6.item(0),y_pred_Atlanta7.item(0),y_pred_Atlanta8.item(0),
                                       y_pred_Atlanta9.item(0),y_pred_Atlanta10.item(0),y_pred_Atlanta11.item(0),y_pred_Atlanta12.item(0),
                                       y_pred_Atlanta13.item(0),y_pred_Atlanta14.item(0),y_pred_Atlanta15.item(0),y_pred_Atlanta16.item(0),
                                       y_pred_Atlanta17.item(0),y_pred_Atlanta18.item(0),y_pred_Atlanta19.item(0),y_pred_Atlanta20.item(0),
                                       y_pred_Atlanta21.item(0)]}
pd.DataFrame(output)
# Out:
#     Atlanta Actual Team Performance  Atlanta Predicted Team Performance
# 0                                75                           51.890453
# 1                                75                           53.305771
# 2                                75                           62.570946
# 3                                62                           38.482471
# 4                                50                           38.186873
# 5                                50                           54.134636
# 6                                50                           40.461315
# 7                                55                           59.292982
# 8                                57                           41.352944
# 9                                59                           41.864598
# 10                               58                           42.288833
# 11                               57                           47.861999
# ...

# %%
all1 = np.r_[y_train_Atlanta1,y_train_Atlanta2,y_train_Atlanta3,y_train_Atlanta4,y_train_Atlanta5,y_train_Atlanta6,y_train_Atlanta7,
            y_train_Atlanta8,y_train_Atlanta9,y_train_Atlanta10,y_train_Atlanta11,y_train_Atlanta12,y_train_Atlanta13,y_train_Atlanta14,
            y_train_Atlanta15,y_train_Atlanta16,y_train_Atlanta17,y_train_Atlanta18,y_train_Atlanta19,y_train_Atlanta20,y_train_Atlanta21]
all2 = np.r_[y_pred_Atlanta1,y_pred_Atlanta2,y_pred_Atlanta3,y_pred_Atlanta4,y_pred_Atlanta5,y_pred_Atlanta6,y_pred_Atlanta7,
            y_pred_Atlanta8,y_pred_Atlanta9,y_pred_Atlanta10,y_pred_Atlanta11,y_pred_Atlanta12,y_pred_Atlanta13,y_pred_Atlanta14,
            y_pred_Atlanta15,y_pred_Atlanta16,y_pred_Atlanta17,y_pred_Atlanta18,y_pred_Atlanta19,y_pred_Atlanta20,y_pred_Atlanta21]
all3 = all2.mean() - all1.mean()
col_names =  ['Formula Used', 'Atlanta Target Team Performance Mean', 'Atlanta Team Performance Predicted Mean','Difference Between Target and Predicted']
my_df  = pd.DataFrame(columns = col_names)
my_df.loc[len(my_df)] = ['Predicting the Instance based on the previous result',all1.mean(), all2.mean(),all3]
my_df
# Out:
#                                         Formula Used  \
# 0  Predicting the Instance based on the previous ...
#
#    Atlanta Target Team Performance Mean  \
# 0                             57.190476
#
#    Atlanta Team Performance Predicted Mean  \
# 0                                45.957523
#
#    Difference Between Target and Predicted
# 0                               -11.232953

# %%
east_seeding = ['E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8', 'E9', 'E10', 'E11', 'E12', 'E13', 'E14', 'E15']
west_seeding = ['W1', 'W2', 'W3', 'W4', 'W5', 'W6', 'W7', 'W8', 'W9', 'W10', 'W11', 'W12', 'W13', 'W14', 'W15']
classification = ['Finalist', 'Semi-Finalist', 'Playoffs Maker', 'Playoffs Maker', 'Playoffs Maker', 'Playoffs Maker', 'Playoffs Maker', 'Playoffs Maker',
                 'Did not make Playoffs', 'Did not make Playoffs', 'Did not make Playoffs', 'Did not make Playoffs', 'Did not make Playoffs', 'Did not make Playoffs'
                 , 'Did not make Playoffs']
class_dict = {'Finalist': 1, 'Semi-Finalist': 2, 'Playoffs Maker': 3, 'Did not make Playoffs' : 4}

# %%
#get Eastern Conference Seedings based on average predicted team performance 1-21

allAtlanta2 = np.r_[y_pred_Atlanta1,y_pred_Atlanta2,y_pred_Atlanta3,y_pred_Atlanta4,y_pred_Atlanta5,y_pred_Atlanta6,y_pred_Atlanta7,
            y_pred_Atlanta8,y_pred_Atlanta9,y_pred_Atlanta10,y_pred_Atlanta11,y_pred_Atlanta12,y_pred_Atlanta13,y_pred_Atlanta14,
            y_pred_Atlanta15,y_pred_Atlanta16,y_pred_Atlanta17,y_pred_Atlanta18,y_pred_Atlanta19,y_pred_Atlanta20,y_pred_Atlanta21]

allBoston2 = np.r_[y_pred_Boston1,y_pred_Boston2,y_pred_Boston3,y_pred_Boston4,y_pred_Boston5,y_pred_Boston6,y_pred_Boston7,
            y_pred_Boston8,y_pred_Boston9,y_pred_Boston10,y_pred_Boston11,y_pred_Boston12,y_pred_Boston13,y_pred_Boston14,
            y_pred_Boston15,y_pred_Boston16,y_pred_Boston17,y_pred_Boston18,y_pred_Boston19,y_pred_Boston20,y_pred_Boston21]

allBrooklyn2 = np.r_[y_pred_Brooklyn1,y_pred_Brooklyn2,y_pred_Brooklyn3,y_pred_Brooklyn4,y_pred_Brooklyn5,y_pred_Brooklyn6,y_pred_Brooklyn7,
            y_pred_Brooklyn8,y_pred_Brooklyn9,y_pred_Brooklyn10,y_pred_Brooklyn11,y_pred_Brooklyn12,y_pred_Brooklyn13,y_pred_Brooklyn14,
            y_pred_Brooklyn15,y_pred_Brooklyn16,y_pred_Brooklyn17,y_pred_Brooklyn18,y_pred_Brooklyn19,y_pred_Brooklyn20,y_pred_Brooklyn21]

allCharlotte2 = np.r_[y_pred_Charlotte1,y_pred_Charlotte2,y_pred_Charlotte3,y_pred_Charlotte4,y_pred_Charlotte5,y_pred_Charlotte6,y_pred_Charlotte7,
            y_pred_Charlotte8,y_pred_Charlotte9,y_pred_Charlotte10,y_pred_Charlotte11,y_pred_Charlotte12,y_pred_Charlotte13,y_pred_Charlotte14,
            y_pred_Charlotte15,y_pred_Charlotte16,y_pred_Charlotte17,y_pred_Charlotte18,y_pred_Charlotte19,y_pred_Charlotte20,y_pred_Charlotte21]

allChicago2 = np.r_[y_pred_Chicago1,y_pred_Chicago2,y_pred_Chicago3,y_pred_Chicago4,y_pred_Chicago5,y_pred_Chicago6,y_pred_Chicago7,
            y_pred_Chicago8,y_pred_Chicago9,y_pred_Chicago10,y_pred_Chicago11,y_pred_Chicago12,y_pred_Chicago13,y_pred_Chicago14,
            y_pred_Chicago15,y_pred_Chicago16,y_pred_Chicago17,y_pred_Chicago18,y_pred_Chicago19,y_pred_Chicago20,y_pred_Chicago21]

allCleveland2 = np.r_[y_pred_Cleveland1,y_pred_Cleveland2,y_pred_Cleveland3,y_pred_Cleveland4,y_pred_Cleveland5,y_pred_Cleveland6,y_pred_Cleveland7,
            y_pred_Cleveland8,y_pred_Cleveland9,y_pred_Cleveland10,y_pred_Cleveland11,y_pred_Cleveland12,y_pred_Cleveland13,y_pred_Cleveland14,
            y_pred_Cleveland15,y_pred_Cleveland16,y_pred_Cleveland17,y_pred_Cleveland18,y_pred_Cleveland19,y_pred_Cleveland20,y_pred_Cleveland21]

allDetroit2 = np.r_[y_pred_Detroit1,y_pred_Detroit2,y_pred_Detroit3,y_pred_Detroit4,y_pred_Detroit5,y_pred_Detroit6,y_pred_Detroit7,
            y_pred_Detroit8,y_pred_Detroit9,y_pred_Detroit10,y_pred_Detroit11,y_pred_Detroit12,y_pred_Detroit13,y_pred_Detroit14,
            y_pred_Detroit15,y_pred_Detroit16,y_pred_Detroit17,y_pred_Detroit18,y_pred_Detroit19,y_pred_Detroit20,y_pred_Detroit21]

allIndiana2 = np.r_[y_pred_Indiana1,y_pred_Indiana2,y_pred_Indiana3,y_pred_Indiana4,y_pred_Indiana5,y_pred_Indiana6,y_pred_Indiana7,
            y_pred_Indiana8,y_pred_Indiana9,y_pred_Indiana10,y_pred_Indiana11,y_pred_Indiana12,y_pred_Indiana13,y_pred_Indiana14,
            y_pred_Indiana15,y_pred_Indiana16,y_pred_Indiana17,y_pred_Indiana18,y_pred_Indiana19,y_pred_Indiana20,y_pred_Indiana21]

allMiami2 = np.r_[y_pred_Miami1,y_pred_Miami2,y_pred_Miami3,y_pred_Miami4,y_pred_Miami5,y_pred_Miami6,y_pred_Miami7,
            y_pred_Miami8,y_pred_Miami9,y_pred_Miami10,y_pred_Miami11,y_pred_Miami12,y_pred_Miami13,y_pred_Miami14,
            y_pred_Miami15,y_pred_Miami16,y_pred_Miami17,y_pred_Miami18,y_pred_Miami19,y_pred_Miami20,y_pred_Miami21]

allMilwaukee2 = np.r_[y_pred_Milwaukee1,y_pred_Milwaukee2,y_pred_Milwaukee3,y_pred_Milwaukee4,y_pred_Milwaukee5,y_pred_Milwaukee6,y_pred_Milwaukee7,
            y_pred_Milwaukee8,y_pred_Milwaukee9,y_pred_Milwaukee10,y_pred_Milwaukee11,y_pred_Milwaukee12,y_pred_Milwaukee13,y_pred_Milwaukee14,
            y_pred_Milwaukee15,y_pred_Milwaukee16,y_pred_Milwaukee17,y_pred_Milwaukee18,y_pred_Milwaukee19,y_pred_Milwaukee20,y_pred_Milwaukee21]

allNewYork2 = np.r_[y_pred_NewYork1,y_pred_NewYork2,y_pred_NewYork3,y_pred_NewYork4,y_pred_NewYork5,y_pred_NewYork6,y_pred_NewYork7,
            y_pred_NewYork8,y_pred_NewYork9,y_pred_NewYork10,y_pred_NewYork11,y_pred_NewYork12,y_pred_NewYork13,y_pred_NewYork14,
            y_pred_NewYork15,y_pred_NewYork16,y_pred_NewYork17,y_pred_NewYork18,y_pred_NewYork19,y_pred_NewYork20,y_pred_NewYork21]

allOrlando2 = np.r_[y_pred_Orlando1,y_pred_Orlando2,y_pred_Orlando3,y_pred_Orlando4,y_pred_Orlando5,y_pred_Orlando6,y_pred_Orlando7,
            y_pred_Orlando8,y_pred_Orlando9,y_pred_Orlando10,y_pred_Orlando11,y_pred_Orlando12,y_pred_Orlando13,y_pred_Orlando14,
            y_pred_Orlando15,y_pred_Orlando16,y_pred_Orlando17,y_pred_Orlando18,y_pred_Orlando19,y_pred_Orlando20,y_pred_Orlando21]

allPhiladelphia2 = np.r_[y_pred_Philadelphia1,y_pred_Philadelphia2,y_pred_Philadelphia3,y_pred_Philadelphia4,y_pred_Philadelphia5,y_pred_Philadelphia6,y_pred_Philadelphia7,
            y_pred_Philadelphia8,y_pred_Philadelphia9,y_pred_Philadelphia10,y_pred_Philadelphia11,y_pred_Philadelphia12,y_pred_Philadelphia13,y_pred_Philadelphia14,
            y_pred_Philadelphia15,y_pred_Philadelphia16,y_pred_Philadelphia17,y_pred_Philadelphia18,y_pred_Philadelphia19,y_pred_Philadelphia20,y_pred_Philadelphia21]

allToronto2 = np.r_[y_pred_Toronto1,y_pred_Toronto2,y_pred_Toronto3,y_pred_Toronto4,y_pred_Toronto5,y_pred_Toronto6,y_pred_Toronto7,
            y_pred_Toronto8,y_pred_Toronto9,y_pred_Toronto10,y_pred_Toronto11,y_pred_Toronto12,y_pred_Toronto13,y_pred_Toronto14,
            y_pred_Toronto15,y_pred_Toronto16,y_pred_Toronto17,y_pred_Toronto18,y_pred_Toronto19,y_pred_Toronto20,y_pred_Toronto21]

allWashington2 = np.r_[y_pred_Washington1,y_pred_Washington2,y_pred_Washington3,y_pred_Washington4,y_pred_Washington5,y_pred_Washington6,y_pred_Washington7,
            y_pred_Washington8,y_pred_Washington9,y_pred_Washington10,y_pred_Washington11,y_pred_Washington12,y_pred_Washington13,y_pred_Washington14,
            y_pred_Washington15,y_pred_Washington16,y_pred_Washington17,y_pred_Washington18,y_pred_Washington19,y_pred_Washington20,y_pred_Washington21]



ECF = pd.DataFrame(
  {
      "Team": ['Atlanta', 'Boston', 'Brooklyn', 'Charlotte', 'Chicago', 
               'Cleveland', 'Detroit', 'Indiana','Miami', 'Milwaukee', 'New York',
              'Orlando', 'Philadelphia', 'Toronto', 'Washington'],
      "Team Performance (Predicted Average)": [np.mean(allAtlanta2),
                                           np.mean(allBoston2), np.mean(allBrooklyn2),
                                           np.mean(allCharlotte2), np.mean(allChicago2),
                                           np.mean(allCleveland2), np.mean(allDetroit2),
                                           np.mean(allIndiana2), np.mean(allMiami2),
                                           np.mean(allMilwaukee2), np.mean(allNewYork2),
                                           np.mean(allOrlando2), np.mean(allPhiladelphia2),
                                           np.mean(allToronto2), np.mean(allWashington2)],
  }
).sort_values(by='Team Performance (Predicted Average)', ascending=False)

ECF.insert(0, 'Seeding', east_seeding)
ECF.insert(3, 'Classification', classification)

ECF[:8]
# Out:
#    Seeding       Team  Team Performance (Predicted Average)  Classification
# 4       E1    Chicago                             61.772142        Finalist
# 5       E2  Cleveland                             61.661351   Semi-Finalist
# 1       E3     Boston                             55.382682  Playoffs Maker
# 3       E4  Charlotte                             53.662207  Playoffs Maker
# 8       E5      Miami                             53.421418  Playoffs Maker
# 13      E6    Toronto                             52.475200  Playoffs Maker
# 10      E7   New York                             51.970832  Playoffs Maker
# 7       E8    Indiana                             49.917862  Playoffs Maker

# %%
allDallas2 = np.r_[y_pred_Dallas1,y_pred_Dallas2,y_pred_Dallas3,y_pred_Dallas4,y_pred_Dallas5,y_pred_Dallas6,y_pred_Dallas7,
            y_pred_Dallas8,y_pred_Dallas9,y_pred_Dallas10,y_pred_Dallas11,y_pred_Dallas12,y_pred_Dallas13,y_pred_Dallas14,
            y_pred_Dallas15,y_pred_Dallas16,y_pred_Dallas17,y_pred_Dallas18,y_pred_Dallas19,y_pred_Dallas20,y_pred_Dallas21]

allDenver2 = np.r_[y_pred_Denver1,y_pred_Denver2,y_pred_Denver3,y_pred_Denver4,y_pred_Denver5,y_pred_Denver6,y_pred_Denver7,
            y_pred_Denver8,y_pred_Denver9,y_pred_Denver10,y_pred_Denver11,y_pred_Denver12,y_pred_Denver13,y_pred_Denver14,
            y_pred_Denver15,y_pred_Denver16,y_pred_Denver17,y_pred_Denver18,y_pred_Denver19,y_pred_Denver20,y_pred_Denver21]

allGoldenState2 = np.r_[y_pred1_GoldenState,y_pred2_GoldenState,y_pred3_GoldenState,y_pred4_GoldenState,y_pred5_GoldenState,y_pred6_GoldenState,y_pred7_GoldenState,
            y_pred8_GoldenState,y_pred9_GoldenState,y_pred10_GoldenState,y_pred11_GoldenState,y_pred12_GoldenState,y_pred13_GoldenState,y_pred14_GoldenState,
            y_pred15_GoldenState,y_pred16_GoldenState,y_pred17_GoldenState,y_pred18_GoldenState,y_pred19_GoldenState,y_pred20_GoldenState,y_pred21_GoldenState]

allHouston2 = np.r_[y_pred1_Houston,y_pred2_Houston,y_pred3_Houston,y_pred4_Houston,y_pred5_Houston,y_pred6_Houston,y_pred7_Houston,
            y_pred8_Houston,y_pred9_Houston,y_pred10_Houston,y_pred11_Houston,y_pred12_Houston,y_pred13_Houston,y_pred14_Houston,
            y_pred15_Houston,y_pred16_Houston,y_pred17_Houston,y_pred18_Houston,y_pred19_Houston,y_pred20_Houston,y_pred21_Houston]

allLosAngelesClippers2 = np.r_[y_pred_LosAngelesClippers1,y_pred_LosAngelesClippers2,y_pred_LosAngelesClippers3,y_pred_LosAngelesClippers4,y_pred_LosAngelesClippers5,y_pred_LosAngelesClippers6,y_pred_LosAngelesClippers7,
            y_pred_LosAngelesClippers8,y_pred_LosAngelesClippers9,y_pred_LosAngelesClippers10,y_pred_LosAngelesClippers11,y_pred_LosAngelesClippers12,y_pred_LosAngelesClippers13,y_pred_LosAngelesClippers14,
            y_pred_LosAngelesClippers15,y_pred_LosAngelesClippers16,y_pred_LosAngelesClippers17,y_pred_LosAngelesClippers18,y_pred_LosAngelesClippers19,y_pred_LosAngelesClippers20,y_pred_LosAngelesClippers21]

allLosAngelesLakers2 = np.r_[y_pred_LosAngelesLakers1,y_pred_LosAngelesLakers2,y_pred_LosAngelesLakers3,y_pred_LosAngelesLakers4,y_pred_LosAngelesLakers5,y_pred_LosAngelesLakers6,y_pred_LosAngelesLakers7,
            y_pred_LosAngelesLakers8,y_pred_LosAngelesLakers9,y_pred_LosAngelesLakers10,y_pred_LosAngelesLakers11,y_pred_LosAngelesLakers12,y_pred_LosAngelesLakers13,y_pred_LosAngelesLakers14,
            y_pred_LosAngelesLakers15,y_pred_LosAngelesLakers16,y_pred_LosAngelesLakers17,y_pred_LosAngelesLakers18,y_pred_LosAngelesLakers19,y_pred_LosAngelesLakers20,y_pred_LosAngelesLakers21]

allMemphis2 = np.r_[y_pred_Memphis1,y_pred_Memphis2,y_pred_Memphis3,y_pred_Memphis4,y_pred_Memphis5,y_pred_Memphis6,y_pred_Memphis7,
            y_pred_Memphis8,y_pred_Memphis9,y_pred_Memphis10,y_pred_Memphis11,y_pred_Memphis12,y_pred_Memphis13,y_pred_Memphis14,
            y_pred_Memphis15,y_pred_Memphis16,y_pred_Memphis17,y_pred_Memphis18,y_pred_Memphis19,y_pred_Memphis20,y_pred_Memphis21]

allMinnesota2 = np.r_[y_pred_Minnesota1,y_pred_Minnesota2,y_pred_Minnesota3,y_pred_Minnesota4,y_pred_Minnesota5,y_pred_Minnesota6,y_pred_Minnesota7,
            y_pred_Minnesota8,y_pred_Minnesota9,y_pred_Minnesota10,y_pred_Minnesota11,y_pred_Minnesota12,y_pred_Minnesota13,y_pred_Minnesota14,
            y_pred_Minnesota15,y_pred_Minnesota16,y_pred_Minnesota17,y_pred_Minnesota18,y_pred_Minnesota19,y_pred_Minnesota20,y_pred_Minnesota21]

allNewOrleans2 = np.r_[y_pred_NewOrleans1,y_pred_NewOrleans2,y_pred_NewOrleans3,y_pred_NewOrleans4,y_pred_NewOrleans5,y_pred_NewOrleans6,y_pred_NewOrleans7,
            y_pred_NewOrleans8,y_pred_NewOrleans9,y_pred_NewOrleans10,y_pred_NewOrleans11,y_pred_NewOrleans12,y_pred_NewOrleans13,y_pred_NewOrleans14,
            y_pred_NewOrleans15,y_pred_NewOrleans16,y_pred_NewOrleans17,y_pred_NewOrleans18,y_pred_NewOrleans19,y_pred_NewOrleans20,y_pred_NewOrleans21]

allOklahomaCity2 = np.r_[y_pred_OklahomaCity1,y_pred_OklahomaCity2,y_pred_OklahomaCity3,y_pred_OklahomaCity4,y_pred_OklahomaCity5,y_pred_OklahomaCity6,y_pred_OklahomaCity7,
            y_pred_OklahomaCity8,y_pred_OklahomaCity9,y_pred_OklahomaCity10,y_pred_OklahomaCity11,y_pred_OklahomaCity12,y_pred_OklahomaCity13,y_pred_OklahomaCity14,
            y_pred_OklahomaCity15,y_pred_OklahomaCity16,y_pred_OklahomaCity17,y_pred_OklahomaCity18,y_pred_OklahomaCity19,y_pred_OklahomaCity20,y_pred_OklahomaCity21]

allPhoenix2 = np.r_[y_pred_Phoenix1,y_pred_Phoenix2,y_pred_Phoenix3,y_pred_Phoenix4,y_pred_Phoenix5,y_pred_Phoenix6,y_pred_Phoenix7,
            y_pred_Phoenix8,y_pred_Phoenix9,y_pred_Phoenix10,y_pred_Phoenix11,y_pred_Phoenix12,y_pred_Phoenix13,y_pred_Phoenix14,
            y_pred_Phoenix15,y_pred_Phoenix16,y_pred_Phoenix17,y_pred_Phoenix18,y_pred_Phoenix19,y_pred_Phoenix20,y_pred_Phoenix21]

allPortland2 = np.r_[y_pred1_Portland,y_pred2_Portland,y_pred3_Portland,y_pred4_Portland,y_pred5_Portland,y_pred6_Portland,y_pred7_Portland,
            y_pred8_Portland,y_pred9_Portland,y_pred10_Portland,y_pred11_Portland,y_pred12_Portland,y_pred13_Portland,y_pred14_Portland,
            y_pred15_Portland,y_pred16_Portland,y_pred17_Portland,y_pred18_Portland,y_pred19_Portland,y_pred20_Portland,y_pred21_Portland]

allSacramento2 = np.r_[y_pred_Sacramento1,y_pred_Sacramento2,y_pred_Sacramento3,y_pred_Sacramento4,y_pred_Sacramento5,y_pred_Sacramento6,y_pred_Sacramento7,
            y_pred_Sacramento8,y_pred_Sacramento9,y_pred_Sacramento10,y_pred_Sacramento11,y_pred_Sacramento12,y_pred_Sacramento13,y_pred_Sacramento14,
            y_pred_Sacramento15,y_pred_Sacramento16,y_pred_Sacramento17,y_pred_Sacramento18,y_pred_Sacramento19,y_pred_Sacramento20,y_pred_Sacramento21]

allSanAntonio2 = np.r_[y_pred_SanAntonio1,y_pred_SanAntonio2,y_pred_SanAntonio3,y_pred_SanAntonio4,y_pred_SanAntonio5,y_pred_SanAntonio6,y_pred_SanAntonio7,
            y_pred_SanAntonio8,y_pred_SanAntonio9,y_pred_SanAntonio10,y_pred_SanAntonio11,y_pred_SanAntonio12,y_pred_SanAntonio13,y_pred_SanAntonio14,
            y_pred_SanAntonio15,y_pred_SanAntonio16,y_pred_SanAntonio17,y_pred_SanAntonio18,y_pred_SanAntonio19,y_pred_SanAntonio20,y_pred_SanAntonio21]

allUtah2 = np.r_[y_pred_Utah1,y_pred_Utah2,y_pred_Utah3,y_pred_Utah4,y_pred_Utah5,y_pred_Utah6,y_pred_Utah7,
            y_pred_Utah8,y_pred_Utah9,y_pred_Utah10,y_pred_Utah11,y_pred_Utah12,y_pred_Utah13,y_pred_Utah14,
            y_pred_Utah15,y_pred_Utah16,y_pred_Utah17,y_pred_Utah18,y_pred_Utah19,y_pred_Utah20,y_pred_Utah21]

# %%
WCF = pd.DataFrame(
  {
      "Team": ['Dallas', 'Denver', 'Golden State', 'Houston', 'Los Angeles Clippers', 
               'Los Angeles Lakers', 'Memphis', 'Minnesota','New Orleans', 'Oklahoma City', 'Phoenix',
              'Portland', 'Sacramento', 'San Antonio', 'Utah'],
      "Team Performance (Predicted Average)": [np.mean(allDallas2),
                                           np.mean(allDenver2), np.mean(allGoldenState2),
                                           np.mean(allHouston2), np.mean(allLosAngelesClippers2),
                                           np.mean(allLosAngelesLakers2), np.mean(allMemphis2),
                                           np.mean(allMinnesota2), np.mean(allNewOrleans2),
                                           np.mean(allOklahomaCity2), np.mean(allPhoenix2),
                                           np.mean(allPortland2), np.mean(allSacramento2),
                                           np.mean(allSanAntonio2), np.mean(allUtah2)],
  }
).sort_values(by='Team Performance (Predicted Average)', ascending=False)

WCF.insert(0, 'Seeding', west_seeding)
WCF.insert(3, 'Classification', classification)

WCF[:8]
# Out:
#    Seeding                  Team  Team Performance (Predicted Average)  \
# 2       W1          Golden State                             74.334864
# 13      W2           San Antonio                             56.356469
# 4       W3  Los Angeles Clippers                             54.879220
# 3       W4               Houston                             54.225305
# 11      W5              Portland                             50.359111
# 0       W6                Dallas                             50.067621
# 1       W7                Denver                             49.948957
# 8       W8           New Orleans                             49.196736
#
#     Classification
# 2         Finalist
# 13   Semi-Finalist
# 4   Playoffs Maker
# 3   Playoffs Maker
# 11  Playoffs Maker
# 0   Playoffs Maker
# 1   Playoffs Maker
# 8   Playoffs Maker

# %%
overall = pd.concat([ECF,WCF], axis=0, join='outer', ignore_index=True)

overall['Rank'] = overall['Classification'].map(class_dict)

overall.sort_values(by='Rank')

#overall.style.hide_index() #pandas version 0.23
#overall.style.hide_columns('Rank') #pandas version 0.23
# Out:
#    Seeding                  Team  Team Performance (Predicted Average)  \
# 0       E1               Chicago                             61.772142
# 15      W1          Golden State                             74.334864
# 1       E2             Cleveland                             61.661351
# 16      W2           San Antonio                             56.356469
# 18      W4               Houston                             54.225305
# 17      W3  Los Angeles Clippers                             54.879220
# 21      W7                Denver                             49.948957
# 22      W8           New Orleans                             49.196736
# 19      W5              Portland                             50.359111
# 20      W6                Dallas                             50.067621
# 7       E8               Indiana                             49.917862
# 6       E7              New York                             51.970832
# ...
